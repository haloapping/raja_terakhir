# %% [markdown]
# # Import modules

# %%
import csv
import os
import pickle
import pytz
import torch
import timeit
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from copy import deepcopy
from datetime import datetime
from einops import rearrange
from itertools import chain
from time import time
from torch import nn, optim
from torchmetrics.classification import MulticlassAccuracy, MulticlassF1Score, MulticlassConfusionMatrix
from torch.optim import lr_scheduler
from tqdm.notebook import tqdm
from torch.utils.data import TensorDataset, DataLoader
from polyglot.mapping import Embedding, CaseExpander, DigitExpander

# %% [markdown]
# # Hyperparameters

# %%
class Hyperparams:
     def __init__(
        self,
        fold=4,
        max_seq_len=82,
        input_size=64,
        batch_size=32,
        num_hidden_layer=1,
        hidden_size=128,
        dropout=0,
        bias=True,
        output_size=24,
        shuffle=True,
        lr=0.005,
        batch_first=False,
        bidirectional=True,
        init_wb_with_kaiming_normal=True,
        n_epoch=50,
        patience=50,
        device="cuda" if torch.cuda.is_available() else "cpu"
    ):
        self.fold = fold
        self.input_size = input_size
        self.max_seq_len = max_seq_len
        self.batch_size = batch_size
        self.num_hidden_layer = num_hidden_layer
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.output_size = output_size
        self.shuffle = shuffle
        self.lr = lr
        self.batch_first = batch_first
        self.bidirectional = bidirectional
        self.init_wb_with_kaiming_normal = init_wb_with_kaiming_normal
        self.n_epoch = n_epoch
        self.patience = patience
        self.device = device

hyperparams = Hyperparams()

# %% [markdown]
# # Dataset

# %%
id_pos_tag = pd.read_csv("../../datasets/raw/Indonesian_Manually_Tagged_Corpus.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False) 
train = pd.read_csv(f"../../datasets/raw/cv/train/train.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
val = pd.read_csv(f"../../datasets/raw/cv/val/val.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
test = pd.read_csv(f"../../datasets/raw/cv/test/test.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)

# %% [markdown]
# # Pre-trained Word Embedding

# %%
embeddings = Embedding.load("../../word_embeddings/polyglot/idn_embeddings.tar.bz2")
embeddings.apply_expansion(DigitExpander)
embeddings.apply_expansion(CaseExpander)

oov_embeddings = pickle.load(open(f"../../logs/comick/79_contexts/10-11-2022_19-39-04/oov_embedding_dict.pkl", "rb"))
oov_embeddings = {key: np.zeros((64), dtype=np.float32) for key, _ in oov_embeddings.items()}

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Add OOV Flag

# %%
def add_oov_flag(tokens, embeddings):
    oov_flags = []
    
    for token in tqdm(tokens):
        try:
            if token not in embeddings:
                oov_flags.append(True)
            else:
                oov_flags.append(False)
        except:
            oov_flags.append(False)
        
    return pd.DataFrame(oov_flags, columns=["is_oov"])

id_pos_tag_oov_flags = add_oov_flag(id_pos_tag["token"].values, embeddings)
train_oov_flags = add_oov_flag(train["token"].values, embeddings)
val_oov_flags = add_oov_flag(val["token"].values, embeddings)
test_oov_flags = add_oov_flag(test["token"].values, embeddings)
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/191849 [00:00<?, ?it/s]
#   0%|          | 0/21364 [00:00<?, ?it/s]
#   0%|          | 0/53439 [00:00<?, ?it/s]

# %% [markdown]
# ## Concate OOV Flag

# %%
id_pos_tag_df = pd.concat([id_pos_tag, id_pos_tag_oov_flags], axis=1)
train_df = pd.concat([train, train_oov_flags], axis=1)
val_df = pd.concat([val, val_oov_flags], axis=1)
test_df = pd.concat([test, test_oov_flags], axis=1)

# %% [markdown]
# ## Lowercase OOV Token

# %%
id_pos_tag_df['token'] = np.where(id_pos_tag_df['is_oov'] == True, id_pos_tag_df['token'].str.lower(), id_pos_tag_df['token'])
train_df['token'] = np.where(train_df['is_oov'] == True, train_df['token'].str.lower(), train_df['token'])
val_df['token'] = np.where(val_df['is_oov'] == True, val_df['token'].str.lower(), val_df['token'])
test_df['token'] = np.where(test_df['is_oov'] == True, test_df['token'].str.lower(), test_df['token'])

# %% [markdown]
# ## Embedding Dict, Index to Token and Token to Index

# %%
tokens = list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None))

def embedding_dict(tokens, embeddings, oov_embeddings):
    embedding = {}
    
    for token in tokens:
        if token[0] is not np.nan:
            if token[2] == False or token[0] in embeddings:
                embedding[token[0]] = embeddings[token[0]]
            else:
                embedding[token[0]] = oov_embeddings[token[0].lower()]

    return embedding

embedding_dict = embedding_dict(tokens, embeddings, oov_embeddings)
embedding_dict["<PAD>"] = embeddings["<PAD>"]
word_embeddings = nn.Embedding.from_pretrained(torch.FloatTensor(np.array(list(embedding_dict.values()))), padding_idx=list(embedding_dict.keys()).index("<PAD>"), freeze=True)

idx_to_token = {idx: token for idx, token in enumerate(list(embedding_dict.keys()))}
token_to_idx = {token: idx for idx, token in enumerate(list(embedding_dict.keys()))}

# %% [markdown]
# ## Token to Sentence

# %%
def make_sentence(tokens, max_length_sentence=hyperparams.max_seq_len):
    sentence = []
    sentences = []

    for token in tqdm(tokens):
        if token[0] is not np.nan:
            sentence.append(token)
        else:
            sentences.append(sentence[:max_length_sentence])
            sentence = []

    return sentences

all_sentence = make_sentence(list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
train_sentences = make_sentence(list(train_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
val_sentences = make_sentence(list(test_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
test_sentences = make_sentence(list(val_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/191849 [00:00<?, ?it/s]
#   0%|          | 0/53439 [00:00<?, ?it/s]
#   0%|          | 0/21364 [00:00<?, ?it/s]

# %% [markdown]
# ## Word Token, Padding, and Word token to Index

# %%
def tokenize_docs(docs, idx_token):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token[idx_token])
        sentences.append(new_sentence)
        new_sentence = []

    return sentences

def padding(docs, max_seq_len=hyperparams.max_seq_len, mode="post", val_pad="<PAD>"):
    docs = deepcopy(docs)
    doc_with_pad = []
    docs_with_pad = []

    for doc in tqdm(docs):
        if mode == "pre":
            for _ in range(max_seq_len - len(doc)):
                doc.insert(0, val_pad)
        elif mode == "post":
            for _ in range(max_seq_len - len(doc)):
                doc.append(val_pad)
        else:
            return f"Mode {mode} is not available, use instead 'pre' or 'post'."
        
        docs_with_pad.append(doc)
        
    return np.array(docs_with_pad)

def sent_to_idx(docs, token_to_idx):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token_to_idx[token])
        sentences.append(new_sentence)
        new_sentence = []

    return np.array(sentences)

def convert_feature_to_idx(docs, idx_token, token_to_idx, max_seq_len):
    sentences = tokenize_docs(docs, idx_token)
    sentences_with_pad = padding(sentences, max_seq_len=max_seq_len, mode="post", val_pad="<PAD>")
    sentences_to_idx = sent_to_idx(sentences_with_pad, token_to_idx)
    
    return sentences_to_idx

train_sentence_idxs = convert_feature_to_idx(train_sentences, 0, token_to_idx, hyperparams.max_seq_len)
val_sentence_idxs = convert_feature_to_idx(val_sentences, 0, token_to_idx, hyperparams.max_seq_len)
test_sentence_idxs = convert_feature_to_idx(test_sentences, 0, token_to_idx, hyperparams.max_seq_len)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]

# %% [markdown]
# ## Encode Class

# %%
classes = sorted(np.delete(id_pos_tag_df["tag"].unique(), 3))
idx_to_label = {idx: label for idx, label in enumerate(classes + ["<PAD>"])}
label_to_idx = {label: idx for idx, label in enumerate(classes + ["<PAD>"])}

def encode_class(docs, label_to_idx, seq_len=hyperparams.max_seq_len):
    class_idxs = []
    classes = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            class_idxs.append(label_to_idx[token[1]])
            
        for _ in range(seq_len - len(sentence)):
            class_idxs.append(label_to_idx["<PAD>"])
                
        classes.append(class_idxs)
        class_idxs = []

    return np.array(classes)
        
train_class_idxs = encode_class(train_sentences, label_to_idx)
val_class_idxs = encode_class(val_sentences, label_to_idx)
test_class_idxs = encode_class(test_sentences, label_to_idx)

print(f"Training shape   : {train_sentence_idxs.shape, train_class_idxs.shape}")
print(f"validation shape : {val_class_idxs.shape, val_class_idxs.shape}")
print(f"Test shape       : {test_sentence_idxs.shape, test_class_idxs.shape}")
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# Training shape   : ((7222, 82), (7222, 82))
# validation shape : ((2006, 82), (2006, 82))
# Test shape       : ((802, 82), (802, 82))

# %% [markdown]
# ## Note
#
# - Number of sentences = 10030
# - Train : 72% (7222)
# - Val   : 8% (802)
# - Test  : 20% (2006)

# %% [markdown]
# # Build Model

# %% [markdown]
# ## Feature and Actual Class

# %%
train_feature = torch.LongTensor(train_sentence_idxs)
val_feature = torch.LongTensor(val_sentence_idxs)
test_feature = torch.LongTensor(test_sentence_idxs)

train_class = torch.LongTensor(train_class_idxs)
val_class = torch.LongTensor(val_class_idxs)
test_class = torch.LongTensor(test_class_idxs)

# %%
train_feature.shape, val_feature.shape, test_feature.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %%
train_class.shape, val_class.shape, test_class.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %% [markdown]
# ## Tensor Dataset

# %%
train_dataset = TensorDataset(train_feature, train_class)
val_dataset = TensorDataset(val_feature, val_class)
test_dataset = TensorDataset(test_feature, test_class)

# %% [markdown]
# ## Dataloader

# %%
train_dataloader = DataLoader(train_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
val_dataloader = DataLoader(val_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
test_dataloader = DataLoader(test_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)

# %% [markdown]
# ## Model

# %%
class POSTagger(nn.Module):
    def __init__(
        self,
        input_size=hyperparams.input_size,
        hidden_size=hyperparams.hidden_size,
        dropout=hyperparams.dropout,
        bias=hyperparams.bias,
        num_layers=hyperparams.num_hidden_layer,
        output_size=hyperparams.output_size,
        batch_first=hyperparams.batch_first,
        bidirectional=hyperparams.bidirectional,
        init_wb_with_kaiming_normal=hyperparams.init_wb_with_kaiming_normal
    ):
        super(POSTagger, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.num_layers = num_layers
        self.output_size = output_size
        self.batch_first = batch_first
        self.bidirectional = bidirectional
                
        self.feature = nn.LSTM(
            input_size = self.input_size,
            hidden_size = self.hidden_size,
            bias = self.bias,
            dropout = self.dropout,
            num_layers = self.num_layers,
            batch_first = self.batch_first,
            bidirectional = self.bidirectional
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(in_features=2 * self.hidden_size if hyperparams.bidirectional else self.hidden_size, out_features=self.output_size, bias=self.bias),
            nn.Softmax(dim=-1)
        )
        
        if init_wb_with_kaiming_normal:
            self.init_wb()

    def init_wb(self):
        for module in self.modules():
            if isinstance(module, (nn.Linear, nn.LSTM)):
                for name, param in module.named_parameters():
                    if "weight" in name:
                        nn.init.kaiming_normal_(param)
                    else:
                        nn.init.kaiming_normal_(param.reshape(1, -1))
        
    def forward(self, feature, hidden=None):
        output, (hidden, memory) = self.feature(feature, None)
        prob = self.classifier(output)

        return prob
    
model = POSTagger().to(hyperparams.device)
model
# Out:
# POSTagger(
#   (feature): LSTM(64, 128, bidirectional=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=24, bias=True)
#     (1): Softmax(dim=-1)
#   )
# )

# %% [markdown]
# ## Optimizer, Criterion, and Metric

# %%
optimizer = optim.Adam(model.parameters(), lr=hyperparams.lr)
criterion = nn.CrossEntropyLoss().to(hyperparams.device)
train_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", verbose=True, factor=0.5)

# %%
sum(param.numel() for param in model.parameters() if param.requires_grad)
# Out:
# 204824

# %% [markdown]
# ## Training Step

# %%
def training_step(dataloader, model, optimizer, criterion, metric, scheduler=None):
    model.train()
    
    batch_losses = []
    batch_metric_scores = []
    
    for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
        # Forward Propagation
        feature = rearrange(feature, "n s -> s n")
        actual_label = rearrange(actual_label, "n s -> s n")
        embedding = word_embeddings(feature)
        
        prob = model(
            embedding.to(hyperparams.device),
            actual_label.to(hyperparams.device)
        )
        
        prob = prob.reshape(-1, prob.shape[-1])
        actual_label = actual_label.reshape(-1)

        loss = criterion(prob, actual_label.to(hyperparams.device))
        metric_score = metric(prob, actual_label.to(hyperparams.device))
        metric_score = metric.compute()
                
        if scheduler is not None:
            scheduler.step(loss)
        
        batch_losses.append(loss.item())
        batch_metric_scores.append(metric_score)
        
        if len(dataloader) < 10:
            if batch % 1 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../logs/zero/fold_{hyperparams.fold}/{path_name}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
        else:
            if batch % 15 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../logs/zero/fold_{hyperparams.fold}/{path_name}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            
        # Backward Propagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Validation Step

# %%
def validation_step(dataloader, model, criterion, metric):
    model.eval()
    
    batch_losses = []
    batch_metric_scores = []
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob, actual_label.to(hyperparams.device))
            metric_score = metric.compute()

            batch_losses.append(loss.item())
            batch_metric_scores.append(metric_score)
            
            if len(dataloader) < 10 and (batch % 1 == 0 or batch == len(dataloader)):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../logs/zero/fold_{hyperparams.fold}/{path_name}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            else:
                if batch % 15 == 0 or batch == len(dataloader):
                    batch_name = "Batch-" + str(batch)
                    print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                    with open(f"../../logs/zero/fold_{hyperparams.fold}/{path_name}/training_history.txt", "a") as f:
                        f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Looping Step

# %%
now = datetime.now(pytz.timezone("Asia/Ujung_Pandang"))
path_name = now.strftime("%m-%d-%Y_%H-%M-%S")
root_path = f"../../logs/zero/fold_{hyperparams.fold}/{path_name}"
os.makedirs(root_path)

def looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric, n_epoch=hyperparams.n_epoch, patience=hyperparams.patience, monitor="loss"):    
    start_time = time()
    
    epoch_training_losses = []
    epoch_training_metric_scores = []
    epoch_val_losses = []
    epoch_val_metric_scores = []
    patience_counter = 0
    
    # Hyperparameters
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write(f"HYPERPARAMETERS\n")
        f.write(f"{'-' * 80}\n")
        for name, value in vars(hyperparams).items():
            f.write(f"{name}: {value}\n")
        
        f.write("\n\nTRAINING PROGRESS\n")
        f.write(f"{'-' * 80}\n")
    
    # Training Progress
    for epoch in range(1, n_epoch + 1):
        print(f"EPOCH-{epoch}")
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"EPOCH-{epoch}\n")
            f.write(f"Training Step\n")
            
        # Training Step
        print("Training Step")
        batch_training_losses, batch_training_metric_scores = training_step(train_dataloader, model, optimizer, criterion, train_metric, scheduler=None)
        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))

        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))
        epoch_training_losses.append(epoch_training_loss.item())

        epoch_training_metric_score = torch.mean(torch.FloatTensor(batch_training_metric_scores))
        epoch_training_metric_scores.append(epoch_training_metric_score.item())
        
        # Validation Step
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"\nValidation Step\n")
            
        print("\nValidation Step")
        batch_val_losses, batch_val_metric_scores = validation_step(val_dataloader, model, criterion, val_metric)
        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))

        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))
        epoch_val_losses.append(epoch_val_loss.item())

        epoch_val_metric_score = torch.mean(torch.FloatTensor(batch_val_metric_scores))
        epoch_val_metric_scores.append(epoch_val_metric_score.item())
        
        with open(f"{root_path}/training_history.txt", "a") as f:
            if monitor == "loss":
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_losses[-1] < epoch_training_losses[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
            else:
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_metric_scores[-1] > epoch_training_metric_scores[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗\n")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
                    
            print("=" * 80, end="\n\n")
            
            f.write(f"{'=' * 80}\n\n")
            
            if patience_counter == patience:
                print(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                
                f.write(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                break
        
        train_metric.reset()
        val_metric.reset()
        
    finish_time = time()
    
    # Training plot 
    fig, (ax_loss, ax_metric_score) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    fig.suptitle(f"Training with oov embedding = zero")

    ax_loss.set_title("Loss")
    ax_loss.set_xlabel("Epoch")
    ax_loss.set_ylabel("Score")
    ax_loss.plot(epoch_training_losses, "green", label="Training")
    ax_loss.plot(epoch_val_losses, "orange", label="Validation")
    ax_loss.legend()
    ax_loss.grid()

    ax_metric_score.set_title("F1 Score")
    ax_metric_score.set_xlabel("Epoch")
    ax_metric_score.set_ylabel("Score")
    ax_metric_score.plot(epoch_training_metric_scores, "green", label="Training")
    ax_metric_score.plot(epoch_val_metric_scores, "orange", label="Validation")
    ax_metric_score.legend()
    ax_metric_score.grid()

    plt.savefig(f"{root_path}/training_plot.jpg", dpi=200)                        
    
    print("TRAINING SUMMARY")
    name_best_training_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_training_metric = f"Best {str(train_metric).split('(')[0]} validation".ljust(34)
    name_best_validation_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_validation_metric = f"Best {str(val_metric).split('(')[0]} validation".ljust(34)
    name_training_time = f"Training duration".ljust(34)
    name_training_date = f"Training date".ljust(34)
    
    print(f"{name_best_training_loss}: {best_training_loss:.4f}")
    print(f"{name_best_validation_loss}: {best_val_loss:.4f}")
    print(f"{name_best_training_metric}: {best_training_metric:.4f}")
    print(f"{name_best_validation_metric}: {best_val_metric:.4f}")
    print(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.")
    print(f"{name_training_date}: {now}")
    
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write("\nTRAINING SUMMARY\n")
        f.write(f"{'-' * 80}\n")
        f.write(f"{name_best_training_loss}: {best_training_loss:.4f}\n")
        f.write(f"{name_best_validation_loss}: {best_val_loss:.4f}\n")
        f.write(f"{name_best_training_metric}: {best_training_metric:.4f}\n")
        f.write(f"{name_best_validation_metric}: {best_val_metric:.4f}\n")
        f.write(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.\n")
        f.write(f"{name_training_date}: {now}\n")
    
    # Save epoch losses, epoch metric scores, model, state dict, and oov embedding dict
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_training_losses
    }).to_csv(f"{root_path}/training_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_training_metric_scores
    }).to_csv(f"{root_path}/training_metric_scores.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_val_losses
    }).to_csv(f"{root_path}/val_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_val_metric_scores
    }).to_csv(f"{root_path}/val_metric_scores.csv", index=False)    
    
    filename_model_params = f"{root_path}/model_params.pth"
    torch.save(best_state_dict, filename_model_params)
    
    return epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores

epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores = looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric)
# Out:
# EPOCH-1
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.4789 | MulticlassF1Score=0.1430
# Batch-30 : CrossEntropyLoss=2.4331 | MulticlassF1Score=0.1902
# Batch-45 : CrossEntropyLoss=2.5025 | MulticlassF1Score=0.2078
# Batch-60 : CrossEntropyLoss=2.4985 | MulticlassF1Score=0.2171
# Batch-75 : CrossEntropyLoss=2.4982 | MulticlassF1Score=0.2226
# Batch-90 : CrossEntropyLoss=2.4822 | MulticlassF1Score=0.2245
# Batch-105: CrossEntropyLoss=2.4528 | MulticlassF1Score=0.2270
# Batch-120: CrossEntropyLoss=2.5008 | MulticlassF1Score=0.2293
# Batch-135: CrossEntropyLoss=2.4876 | MulticlassF1Score=0.2300
# Batch-150: CrossEntropyLoss=2.4627 | MulticlassF1Score=0.2321
# Batch-165: CrossEntropyLoss=2.4778 | MulticlassF1Score=0.2327
# Batch-180: CrossEntropyLoss=2.5070 | MulticlassF1Score=0.2354
# Batch-195: CrossEntropyLoss=2.4580 | MulticlassF1Score=0.2435
# Batch-210: CrossEntropyLoss=2.4201 | MulticlassF1Score=0.2513
# Batch-225: CrossEntropyLoss=2.4408 | MulticlassF1Score=0.2634
# Batch-226: CrossEntropyLoss=2.4562 | MulticlassF1Score=0.2638
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.4058 | MulticlassF1Score=0.4412
# Batch-30 : CrossEntropyLoss=2.4024 | MulticlassF1Score=0.4502
# Batch-45 : CrossEntropyLoss=2.4322 | MulticlassF1Score=0.4465
# Batch-60 : CrossEntropyLoss=2.4120 | MulticlassF1Score=0.4445
# Batch-63 : CrossEntropyLoss=2.4517 | MulticlassF1Score=0.4439
#
# Training   : Mean CrossEntropyLoss = 2.4844 | Mean MulticlassF1Score = 0.2161
# Validation : Mean CrossEntropyLoss = 2.4224 | Mean MulticlassF1Score = 0.4465
# ================================================================================
#
# EPOCH-2
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3979 | MulticlassF1Score=0.4478
# Batch-30 : CrossEntropyLoss=2.3714 | MulticlassF1Score=0.4968
# Batch-45 : CrossEntropyLoss=2.3841 | MulticlassF1Score=0.5410
# Batch-60 : CrossEntropyLoss=2.3506 | MulticlassF1Score=0.5650
# Batch-75 : CrossEntropyLoss=2.3628 | MulticlassF1Score=0.5816
# Batch-90 : CrossEntropyLoss=2.3572 | MulticlassF1Score=0.5916
# Batch-105: CrossEntropyLoss=2.3670 | MulticlassF1Score=0.5996
# Batch-120: CrossEntropyLoss=2.3592 | MulticlassF1Score=0.6054
# Batch-135: CrossEntropyLoss=2.3551 | MulticlassF1Score=0.6103
# Batch-150: CrossEntropyLoss=2.3534 | MulticlassF1Score=0.6134
# Batch-165: CrossEntropyLoss=2.3673 | MulticlassF1Score=0.6159
# Batch-180: CrossEntropyLoss=2.3455 | MulticlassF1Score=0.6204
# Batch-195: CrossEntropyLoss=2.3474 | MulticlassF1Score=0.6244
# Batch-210: CrossEntropyLoss=2.3566 | MulticlassF1Score=0.6290
# Batch-225: CrossEntropyLoss=2.3355 | MulticlassF1Score=0.6328
# Batch-226: CrossEntropyLoss=2.3295 | MulticlassF1Score=0.6330
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3452 | MulticlassF1Score=0.6843
# Batch-30 : CrossEntropyLoss=2.3481 | MulticlassF1Score=0.6879
# Batch-45 : CrossEntropyLoss=2.3446 | MulticlassF1Score=0.6877
# Batch-60 : CrossEntropyLoss=2.3423 | MulticlassF1Score=0.6890
# Batch-63 : CrossEntropyLoss=2.3418 | MulticlassF1Score=0.6890
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3630 | Mean MulticlassF1Score = 0.5791
# Validation : Mean CrossEntropyLoss = 2.3454 | Mean MulticlassF1Score = 0.6871
# ================================================================================
#
# EPOCH-3
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3390 | MulticlassF1Score=0.6896
# Batch-30 : CrossEntropyLoss=2.3570 | MulticlassF1Score=0.6949
# Batch-45 : CrossEntropyLoss=2.3286 | MulticlassF1Score=0.6968
# Batch-60 : CrossEntropyLoss=2.3477 | MulticlassF1Score=0.6957
# Batch-75 : CrossEntropyLoss=2.3450 | MulticlassF1Score=0.6962
# Batch-90 : CrossEntropyLoss=2.3283 | MulticlassF1Score=0.6953
# Batch-105: CrossEntropyLoss=2.3214 | MulticlassF1Score=0.6964
# Batch-120: CrossEntropyLoss=2.3282 | MulticlassF1Score=0.6981
# Batch-135: CrossEntropyLoss=2.3441 | MulticlassF1Score=0.6996
# Batch-150: CrossEntropyLoss=2.3173 | MulticlassF1Score=0.7055
# Batch-165: CrossEntropyLoss=2.3250 | MulticlassF1Score=0.7101
# Batch-180: CrossEntropyLoss=2.3120 | MulticlassF1Score=0.7156
# Batch-195: CrossEntropyLoss=2.3215 | MulticlassF1Score=0.7201
# Batch-210: CrossEntropyLoss=2.3185 | MulticlassF1Score=0.7237
# Batch-225: CrossEntropyLoss=2.3208 | MulticlassF1Score=0.7269
# Batch-226: CrossEntropyLoss=2.3201 | MulticlassF1Score=0.7271
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3121 | MulticlassF1Score=0.7822
# Batch-30 : CrossEntropyLoss=2.3117 | MulticlassF1Score=0.7826
# Batch-45 : CrossEntropyLoss=2.3198 | MulticlassF1Score=0.7801
# Batch-60 : CrossEntropyLoss=2.3197 | MulticlassF1Score=0.7805
# Batch-63 : CrossEntropyLoss=2.3065 | MulticlassF1Score=0.7809
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3333 | Mean MulticlassF1Score = 0.7031
# Validation : Mean CrossEntropyLoss = 2.3163 | Mean MulticlassF1Score = 0.7812
# ================================================================================
#
# EPOCH-4
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3164 | MulticlassF1Score=0.7817
# Batch-30 : CrossEntropyLoss=2.3164 | MulticlassF1Score=0.7893
# Batch-45 : CrossEntropyLoss=2.3142 | MulticlassF1Score=0.7906
# Batch-60 : CrossEntropyLoss=2.3138 | MulticlassF1Score=0.7927
# Batch-75 : CrossEntropyLoss=2.3238 | MulticlassF1Score=0.7950
# Batch-90 : CrossEntropyLoss=2.2994 | MulticlassF1Score=0.7964
# Batch-105: CrossEntropyLoss=2.3027 | MulticlassF1Score=0.7978
# Batch-120: CrossEntropyLoss=2.3049 | MulticlassF1Score=0.7979
# Batch-135: CrossEntropyLoss=2.3025 | MulticlassF1Score=0.7986
# Batch-150: CrossEntropyLoss=2.3064 | MulticlassF1Score=0.7984
# Batch-165: CrossEntropyLoss=2.2997 | MulticlassF1Score=0.7990
# Batch-180: CrossEntropyLoss=2.3057 | MulticlassF1Score=0.7995
# Batch-195: CrossEntropyLoss=2.3047 | MulticlassF1Score=0.8001
# Batch-210: CrossEntropyLoss=2.3137 | MulticlassF1Score=0.8005
# Batch-225: CrossEntropyLoss=2.3062 | MulticlassF1Score=0.8007
# Batch-226: CrossEntropyLoss=2.3022 | MulticlassF1Score=0.8007
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3094 | MulticlassF1Score=0.8033
# Batch-30 : CrossEntropyLoss=2.3118 | MulticlassF1Score=0.8057
# Batch-45 : CrossEntropyLoss=2.3150 | MulticlassF1Score=0.8042
# Batch-60 : CrossEntropyLoss=2.3056 | MulticlassF1Score=0.8028
# Batch-63 : CrossEntropyLoss=2.3211 | MulticlassF1Score=0.8029
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3101 | Mean MulticlassF1Score = 0.7950
# Validation : Mean CrossEntropyLoss = 2.3094 | Mean MulticlassF1Score = 0.8035
# ================================================================================
#
# EPOCH-5
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3034 | MulticlassF1Score=0.8043
# Batch-30 : CrossEntropyLoss=2.3200 | MulticlassF1Score=0.8052
# Batch-45 : CrossEntropyLoss=2.2987 | MulticlassF1Score=0.8065
# Batch-60 : CrossEntropyLoss=2.3118 | MulticlassF1Score=0.8061
# Batch-75 : CrossEntropyLoss=2.3063 | MulticlassF1Score=0.8077
# Batch-90 : CrossEntropyLoss=2.3131 | MulticlassF1Score=0.8088
# Batch-105: CrossEntropyLoss=2.3069 | MulticlassF1Score=0.8084
# Batch-120: CrossEntropyLoss=2.2986 | MulticlassF1Score=0.8080
# Batch-135: CrossEntropyLoss=2.3050 | MulticlassF1Score=0.8082
# Batch-150: CrossEntropyLoss=2.3006 | MulticlassF1Score=0.8088
# Batch-165: CrossEntropyLoss=2.3013 | MulticlassF1Score=0.8091
# Batch-180: CrossEntropyLoss=2.3102 | MulticlassF1Score=0.8086
# Batch-195: CrossEntropyLoss=2.3133 | MulticlassF1Score=0.8082
# Batch-210: CrossEntropyLoss=2.3020 | MulticlassF1Score=0.8081
# Batch-225: CrossEntropyLoss=2.3130 | MulticlassF1Score=0.8080
# Batch-226: CrossEntropyLoss=2.3047 | MulticlassF1Score=0.8079
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3067 | MulticlassF1Score=0.8048
# Batch-30 : CrossEntropyLoss=2.3060 | MulticlassF1Score=0.8081
# Batch-45 : CrossEntropyLoss=2.3110 | MulticlassF1Score=0.8069
# Batch-60 : CrossEntropyLoss=2.3083 | MulticlassF1Score=0.8075
# Batch-63 : CrossEntropyLoss=2.2993 | MulticlassF1Score=0.8077
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3074 | Mean MulticlassF1Score = 0.8076
# Validation : Mean CrossEntropyLoss = 2.3075 | Mean MulticlassF1Score = 0.8059
# ================================================================================
#
# EPOCH-6
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3107 | MulticlassF1Score=0.8084
# Batch-30 : CrossEntropyLoss=2.3048 | MulticlassF1Score=0.8078
# Batch-45 : CrossEntropyLoss=2.3077 | MulticlassF1Score=0.8090
# Batch-60 : CrossEntropyLoss=2.3062 | MulticlassF1Score=0.8096
# Batch-75 : CrossEntropyLoss=2.2938 | MulticlassF1Score=0.8109
# Batch-90 : CrossEntropyLoss=2.3122 | MulticlassF1Score=0.8101
# Batch-105: CrossEntropyLoss=2.2963 | MulticlassF1Score=0.8103
# Batch-120: CrossEntropyLoss=2.3098 | MulticlassF1Score=0.8102
# Batch-135: CrossEntropyLoss=2.3073 | MulticlassF1Score=0.8099
# Batch-150: CrossEntropyLoss=2.3079 | MulticlassF1Score=0.8107
# Batch-165: CrossEntropyLoss=2.3127 | MulticlassF1Score=0.8106
# Batch-180: CrossEntropyLoss=2.3062 | MulticlassF1Score=0.8113
# Batch-195: CrossEntropyLoss=2.3207 | MulticlassF1Score=0.8114
# Batch-210: CrossEntropyLoss=2.3007 | MulticlassF1Score=0.8117
# Batch-225: CrossEntropyLoss=2.3017 | MulticlassF1Score=0.8117
# Batch-226: CrossEntropyLoss=2.3183 | MulticlassF1Score=0.8117
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2961 | MulticlassF1Score=0.8199
# Batch-30 : CrossEntropyLoss=2.2980 | MulticlassF1Score=0.8179
# Batch-45 : CrossEntropyLoss=2.2991 | MulticlassF1Score=0.8170
# Batch-60 : CrossEntropyLoss=2.3008 | MulticlassF1Score=0.8173
# Batch-63 : CrossEntropyLoss=2.2949 | MulticlassF1Score=0.8181
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3062 | Mean MulticlassF1Score = 0.8100
# Validation : Mean CrossEntropyLoss = 2.3043 | Mean MulticlassF1Score = 0.8186
# ================================================================================
#
# EPOCH-7
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3047 | MulticlassF1Score=0.8266
# Batch-30 : CrossEntropyLoss=2.3038 | MulticlassF1Score=0.8220
# Batch-45 : CrossEntropyLoss=2.3132 | MulticlassF1Score=0.8209
# Batch-60 : CrossEntropyLoss=2.2967 | MulticlassF1Score=0.8228
# Batch-75 : CrossEntropyLoss=2.2977 | MulticlassF1Score=0.8217
# Batch-90 : CrossEntropyLoss=2.3022 | MulticlassF1Score=0.8219
# Batch-105: CrossEntropyLoss=2.3015 | MulticlassF1Score=0.8219
# Batch-120: CrossEntropyLoss=2.3037 | MulticlassF1Score=0.8222
# Batch-135: CrossEntropyLoss=2.3030 | MulticlassF1Score=0.8215
# Batch-150: CrossEntropyLoss=2.2991 | MulticlassF1Score=0.8219
# Batch-165: CrossEntropyLoss=2.3015 | MulticlassF1Score=0.8212
# Batch-180: CrossEntropyLoss=2.2978 | MulticlassF1Score=0.8213
# Batch-195: CrossEntropyLoss=2.2962 | MulticlassF1Score=0.8213
# Batch-210: CrossEntropyLoss=2.3008 | MulticlassF1Score=0.8214
# Batch-225: CrossEntropyLoss=2.3054 | MulticlassF1Score=0.8213
# Batch-226: CrossEntropyLoss=2.3182 | MulticlassF1Score=0.8213
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3043 | MulticlassF1Score=0.8188
# Batch-30 : CrossEntropyLoss=2.3056 | MulticlassF1Score=0.8178
# Batch-45 : CrossEntropyLoss=2.3048 | MulticlassF1Score=0.8180
# Batch-60 : CrossEntropyLoss=2.3037 | MulticlassF1Score=0.8186
# Batch-63 : CrossEntropyLoss=2.2981 | MulticlassF1Score=0.8188
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3032 | Mean MulticlassF1Score = 0.8217
# Validation : Mean CrossEntropyLoss = 2.3040 | Mean MulticlassF1Score = 0.8190
# ================================================================================
#
# EPOCH-8
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2980 | MulticlassF1Score=0.8238
# Batch-30 : CrossEntropyLoss=2.2956 | MulticlassF1Score=0.8243
# Batch-45 : CrossEntropyLoss=2.3074 | MulticlassF1Score=0.8248
# Batch-60 : CrossEntropyLoss=2.3128 | MulticlassF1Score=0.8241
# Batch-75 : CrossEntropyLoss=2.3077 | MulticlassF1Score=0.8234
# Batch-90 : CrossEntropyLoss=2.3096 | MulticlassF1Score=0.8224
# Batch-105: CrossEntropyLoss=2.2941 | MulticlassF1Score=0.8223
# Batch-120: CrossEntropyLoss=2.3079 | MulticlassF1Score=0.8224
# Batch-135: CrossEntropyLoss=2.3024 | MulticlassF1Score=0.8222
# Batch-150: CrossEntropyLoss=2.2989 | MulticlassF1Score=0.8226
# Batch-165: CrossEntropyLoss=2.2949 | MulticlassF1Score=0.8232
# Batch-180: CrossEntropyLoss=2.3083 | MulticlassF1Score=0.8233
# Batch-195: CrossEntropyLoss=2.2999 | MulticlassF1Score=0.8240
# Batch-210: CrossEntropyLoss=2.3081 | MulticlassF1Score=0.8234
# Batch-225: CrossEntropyLoss=2.2920 | MulticlassF1Score=0.8235
# Batch-226: CrossEntropyLoss=2.3112 | MulticlassF1Score=0.8234
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3011 | MulticlassF1Score=0.8118
# Batch-30 : CrossEntropyLoss=2.3176 | MulticlassF1Score=0.8142
# Batch-45 : CrossEntropyLoss=2.2973 | MulticlassF1Score=0.8171
# Batch-60 : CrossEntropyLoss=2.3040 | MulticlassF1Score=0.8188
# Batch-63 : CrossEntropyLoss=2.2993 | MulticlassF1Score=0.8196
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3024 | Mean MulticlassF1Score = 0.8232
# Validation : Mean CrossEntropyLoss = 2.3037 | Mean MulticlassF1Score = 0.8149
# ================================================================================
#
# EPOCH-9
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3034 | MulticlassF1Score=0.8231
# Batch-30 : CrossEntropyLoss=2.3081 | MulticlassF1Score=0.8228
# Batch-45 : CrossEntropyLoss=2.2957 | MulticlassF1Score=0.8242
# Batch-60 : CrossEntropyLoss=2.2946 | MulticlassF1Score=0.8249
# Batch-75 : CrossEntropyLoss=2.3062 | MulticlassF1Score=0.8254
# Batch-90 : CrossEntropyLoss=2.3095 | MulticlassF1Score=0.8241
# Batch-105: CrossEntropyLoss=2.3148 | MulticlassF1Score=0.8245
# Batch-120: CrossEntropyLoss=2.3036 | MulticlassF1Score=0.8246
# Batch-135: CrossEntropyLoss=2.2923 | MulticlassF1Score=0.8242
# Batch-150: CrossEntropyLoss=2.2915 | MulticlassF1Score=0.8247
# Batch-165: CrossEntropyLoss=2.3023 | MulticlassF1Score=0.8243
# Batch-180: CrossEntropyLoss=2.2988 | MulticlassF1Score=0.8246
# Batch-195: CrossEntropyLoss=2.3093 | MulticlassF1Score=0.8246
# Batch-210: CrossEntropyLoss=2.2988 | MulticlassF1Score=0.8251
# Batch-225: CrossEntropyLoss=2.2947 | MulticlassF1Score=0.8252
# Batch-226: CrossEntropyLoss=2.2950 | MulticlassF1Score=0.8252
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3156 | MulticlassF1Score=0.8198
# Batch-30 : CrossEntropyLoss=2.3032 | MulticlassF1Score=0.8232
# Batch-45 : CrossEntropyLoss=2.2964 | MulticlassF1Score=0.8225
# Batch-60 : CrossEntropyLoss=2.3081 | MulticlassF1Score=0.8212
# Batch-63 : CrossEntropyLoss=2.3132 | MulticlassF1Score=0.8211
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3018 | Mean MulticlassF1Score = 0.8246
# Validation : Mean CrossEntropyLoss = 2.3033 | Mean MulticlassF1Score = 0.8235
# ================================================================================
#
# EPOCH-10
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2910 | MulticlassF1Score=0.8321
# Batch-30 : CrossEntropyLoss=2.3029 | MulticlassF1Score=0.8304
# Batch-45 : CrossEntropyLoss=2.2889 | MulticlassF1Score=0.8290
# Batch-60 : CrossEntropyLoss=2.3041 | MulticlassF1Score=0.8278
# Batch-75 : CrossEntropyLoss=2.3023 | MulticlassF1Score=0.8282
# Batch-90 : CrossEntropyLoss=2.3029 | MulticlassF1Score=0.8279
# Batch-105: CrossEntropyLoss=2.3006 | MulticlassF1Score=0.8282
# Batch-120: CrossEntropyLoss=2.3049 | MulticlassF1Score=0.8278
# Batch-135: CrossEntropyLoss=2.2988 | MulticlassF1Score=0.8280
# Batch-150: CrossEntropyLoss=2.2986 | MulticlassF1Score=0.8282
# Batch-165: CrossEntropyLoss=2.2929 | MulticlassF1Score=0.8276
# Batch-180: CrossEntropyLoss=2.3095 | MulticlassF1Score=0.8270
# Batch-195: CrossEntropyLoss=2.2876 | MulticlassF1Score=0.8280
# Batch-210: CrossEntropyLoss=2.2971 | MulticlassF1Score=0.8287
# Batch-225: CrossEntropyLoss=2.2972 | MulticlassF1Score=0.8296
# Batch-226: CrossEntropyLoss=2.2966 | MulticlassF1Score=0.8296
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2933 | MulticlassF1Score=0.8452
# Batch-30 : CrossEntropyLoss=2.3074 | MulticlassF1Score=0.8396
# Batch-45 : CrossEntropyLoss=2.3034 | MulticlassF1Score=0.8369
# Batch-60 : CrossEntropyLoss=2.3081 | MulticlassF1Score=0.8359
# Batch-63 : CrossEntropyLoss=2.3020 | MulticlassF1Score=0.8356
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3005 | Mean MulticlassF1Score = 0.8285
# Validation : Mean CrossEntropyLoss = 2.2990 | Mean MulticlassF1Score = 0.8404
# ================================================================================
#
# EPOCH-11
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2911 | MulticlassF1Score=0.8423
# Batch-30 : CrossEntropyLoss=2.3068 | MulticlassF1Score=0.8438
# Batch-45 : CrossEntropyLoss=2.2967 | MulticlassF1Score=0.8420
# Batch-60 : CrossEntropyLoss=2.2937 | MulticlassF1Score=0.8429
# Batch-75 : CrossEntropyLoss=2.3036 | MulticlassF1Score=0.8434
# Batch-90 : CrossEntropyLoss=2.3058 | MulticlassF1Score=0.8426
# Batch-105: CrossEntropyLoss=2.3030 | MulticlassF1Score=0.8419
# Batch-120: CrossEntropyLoss=2.2949 | MulticlassF1Score=0.8427
# Batch-135: CrossEntropyLoss=2.3022 | MulticlassF1Score=0.8427
# Batch-150: CrossEntropyLoss=2.2950 | MulticlassF1Score=0.8426
# Batch-165: CrossEntropyLoss=2.2912 | MulticlassF1Score=0.8425
# Batch-180: CrossEntropyLoss=2.2915 | MulticlassF1Score=0.8427
# Batch-195: CrossEntropyLoss=2.2995 | MulticlassF1Score=0.8432
# Batch-210: CrossEntropyLoss=2.2980 | MulticlassF1Score=0.8435
# Batch-225: CrossEntropyLoss=2.2969 | MulticlassF1Score=0.8434
# Batch-226: CrossEntropyLoss=2.3043 | MulticlassF1Score=0.8434
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3092 | MulticlassF1Score=0.8313
# Batch-30 : CrossEntropyLoss=2.3105 | MulticlassF1Score=0.8352
# Batch-45 : CrossEntropyLoss=2.2960 | MulticlassF1Score=0.8356
# Batch-60 : CrossEntropyLoss=2.2834 | MulticlassF1Score=0.8361
# Batch-63 : CrossEntropyLoss=2.2998 | MulticlassF1Score=0.8367
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2963 | Mean MulticlassF1Score = 0.8429
# Validation : Mean CrossEntropyLoss = 2.2985 | Mean MulticlassF1Score = 0.8352
# ================================================================================
#
# EPOCH-12
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3009 | MulticlassF1Score=0.8469
# Batch-30 : CrossEntropyLoss=2.2981 | MulticlassF1Score=0.8445
# Batch-45 : CrossEntropyLoss=2.2833 | MulticlassF1Score=0.8466
# Batch-60 : CrossEntropyLoss=2.2879 | MulticlassF1Score=0.8465
# Batch-75 : CrossEntropyLoss=2.2982 | MulticlassF1Score=0.8460
# Batch-90 : CrossEntropyLoss=2.2967 | MulticlassF1Score=0.8457
# Batch-105: CrossEntropyLoss=2.2936 | MulticlassF1Score=0.8461
# Batch-120: CrossEntropyLoss=2.3021 | MulticlassF1Score=0.8452
# Batch-135: CrossEntropyLoss=2.2994 | MulticlassF1Score=0.8455
# Batch-150: CrossEntropyLoss=2.2989 | MulticlassF1Score=0.8454
# Batch-165: CrossEntropyLoss=2.2884 | MulticlassF1Score=0.8451
# Batch-180: CrossEntropyLoss=2.2970 | MulticlassF1Score=0.8449
# Batch-195: CrossEntropyLoss=2.2922 | MulticlassF1Score=0.8448
# Batch-210: CrossEntropyLoss=2.3060 | MulticlassF1Score=0.8452
# Batch-225: CrossEntropyLoss=2.2871 | MulticlassF1Score=0.8455
# Batch-226: CrossEntropyLoss=2.3056 | MulticlassF1Score=0.8454
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2909 | MulticlassF1Score=0.8384
# Batch-30 : CrossEntropyLoss=2.3065 | MulticlassF1Score=0.8378
# Batch-45 : CrossEntropyLoss=2.2990 | MulticlassF1Score=0.8386
# Batch-60 : CrossEntropyLoss=2.2937 | MulticlassF1Score=0.8392
# Batch-63 : CrossEntropyLoss=2.3049 | MulticlassF1Score=0.8393
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2956 | Mean MulticlassF1Score = 0.8455
# Validation : Mean CrossEntropyLoss = 2.2978 | Mean MulticlassF1Score = 0.8390
# ================================================================================
#
# EPOCH-13
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2962 | MulticlassF1Score=0.8457
# Batch-30 : CrossEntropyLoss=2.2838 | MulticlassF1Score=0.8506
# Batch-45 : CrossEntropyLoss=2.2988 | MulticlassF1Score=0.8511
# Batch-60 : CrossEntropyLoss=2.2958 | MulticlassF1Score=0.8479
# Batch-75 : CrossEntropyLoss=2.2838 | MulticlassF1Score=0.8482
# Batch-90 : CrossEntropyLoss=2.2982 | MulticlassF1Score=0.8475
# Batch-105: CrossEntropyLoss=2.2935 | MulticlassF1Score=0.8470
# Batch-120: CrossEntropyLoss=2.2980 | MulticlassF1Score=0.8473
# Batch-135: CrossEntropyLoss=2.2949 | MulticlassF1Score=0.8469
# Batch-150: CrossEntropyLoss=2.2969 | MulticlassF1Score=0.8468
# Batch-165: CrossEntropyLoss=2.2965 | MulticlassF1Score=0.8469
# Batch-180: CrossEntropyLoss=2.2883 | MulticlassF1Score=0.8473
# Batch-195: CrossEntropyLoss=2.2938 | MulticlassF1Score=0.8474
# Batch-210: CrossEntropyLoss=2.2899 | MulticlassF1Score=0.8479
# Batch-225: CrossEntropyLoss=2.3014 | MulticlassF1Score=0.8480
# Batch-226: CrossEntropyLoss=2.2902 | MulticlassF1Score=0.8481
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3027 | MulticlassF1Score=0.8387
# Batch-30 : CrossEntropyLoss=2.2903 | MulticlassF1Score=0.8401
# Batch-45 : CrossEntropyLoss=2.3053 | MulticlassF1Score=0.8420
# Batch-60 : CrossEntropyLoss=2.2954 | MulticlassF1Score=0.8398
# Batch-63 : CrossEntropyLoss=2.2994 | MulticlassF1Score=0.8400
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2947 | Mean MulticlassF1Score = 0.8477
# Validation : Mean CrossEntropyLoss = 2.2973 | Mean MulticlassF1Score = 0.8400
# ================================================================================
#
# EPOCH-14
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2912 | MulticlassF1Score=0.8504
# Batch-30 : CrossEntropyLoss=2.2897 | MulticlassF1Score=0.8530
# Batch-45 : CrossEntropyLoss=2.3020 | MulticlassF1Score=0.8525
# Batch-60 : CrossEntropyLoss=2.2944 | MulticlassF1Score=0.8513
# Batch-75 : CrossEntropyLoss=2.2896 | MulticlassF1Score=0.8522
# Batch-90 : CrossEntropyLoss=2.2958 | MulticlassF1Score=0.8518
# Batch-105: CrossEntropyLoss=2.2898 | MulticlassF1Score=0.8503
# Batch-120: CrossEntropyLoss=2.2976 | MulticlassF1Score=0.8502
# Batch-135: CrossEntropyLoss=2.2916 | MulticlassF1Score=0.8501
# Batch-150: CrossEntropyLoss=2.3049 | MulticlassF1Score=0.8499
# Batch-165: CrossEntropyLoss=2.2858 | MulticlassF1Score=0.8497
# Batch-180: CrossEntropyLoss=2.2896 | MulticlassF1Score=0.8494
# Batch-195: CrossEntropyLoss=2.2923 | MulticlassF1Score=0.8496
# Batch-210: CrossEntropyLoss=2.2911 | MulticlassF1Score=0.8499
# Batch-225: CrossEntropyLoss=2.2903 | MulticlassF1Score=0.8497
# Batch-226: CrossEntropyLoss=2.2990 | MulticlassF1Score=0.8496
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3016 | MulticlassF1Score=0.8366
# Batch-30 : CrossEntropyLoss=2.2942 | MulticlassF1Score=0.8387
# Batch-45 : CrossEntropyLoss=2.2933 | MulticlassF1Score=0.8392
# Batch-60 : CrossEntropyLoss=2.2971 | MulticlassF1Score=0.8402
# Batch-63 : CrossEntropyLoss=2.2890 | MulticlassF1Score=0.8401
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2941 | Mean MulticlassF1Score = 0.8507
# Validation : Mean CrossEntropyLoss = 2.2973 | Mean MulticlassF1Score = 0.8393
# ================================================================================
#
# EPOCH-15
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2954 | MulticlassF1Score=0.8427
# Batch-30 : CrossEntropyLoss=2.2939 | MulticlassF1Score=0.8464
# Batch-45 : CrossEntropyLoss=2.2869 | MulticlassF1Score=0.8505
# Batch-60 : CrossEntropyLoss=2.2959 | MulticlassF1Score=0.8507
# Batch-75 : CrossEntropyLoss=2.2893 | MulticlassF1Score=0.8510
# Batch-90 : CrossEntropyLoss=2.2969 | MulticlassF1Score=0.8510
# Batch-105: CrossEntropyLoss=2.3022 | MulticlassF1Score=0.8509
# Batch-120: CrossEntropyLoss=2.2935 | MulticlassF1Score=0.8513
# Batch-135: CrossEntropyLoss=2.2873 | MulticlassF1Score=0.8517
# Batch-150: CrossEntropyLoss=2.2910 | MulticlassF1Score=0.8516
# Batch-165: CrossEntropyLoss=2.2985 | MulticlassF1Score=0.8512
# Batch-180: CrossEntropyLoss=2.2884 | MulticlassF1Score=0.8512
# Batch-195: CrossEntropyLoss=2.2948 | MulticlassF1Score=0.8511
# Batch-210: CrossEntropyLoss=2.2918 | MulticlassF1Score=0.8511
# Batch-225: CrossEntropyLoss=2.3056 | MulticlassF1Score=0.8506
# Batch-226: CrossEntropyLoss=2.3035 | MulticlassF1Score=0.8506
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3037 | MulticlassF1Score=0.8365
# Batch-30 : CrossEntropyLoss=2.2934 | MulticlassF1Score=0.8406
# Batch-45 : CrossEntropyLoss=2.2930 | MulticlassF1Score=0.8421
# Batch-60 : CrossEntropyLoss=2.3025 | MulticlassF1Score=0.8405
# Batch-63 : CrossEntropyLoss=2.2824 | MulticlassF1Score=0.8414
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2938 | Mean MulticlassF1Score = 0.8500
# Validation : Mean CrossEntropyLoss = 2.2968 | Mean MulticlassF1Score = 0.8406
# ================================================================================
#
# EPOCH-16
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2960 | MulticlassF1Score=0.8564
# Batch-30 : CrossEntropyLoss=2.2940 | MulticlassF1Score=0.8546
# Batch-45 : CrossEntropyLoss=2.2903 | MulticlassF1Score=0.8562
# Batch-60 : CrossEntropyLoss=2.2823 | MulticlassF1Score=0.8549
# Batch-75 : CrossEntropyLoss=2.2934 | MulticlassF1Score=0.8536
# Batch-90 : CrossEntropyLoss=2.2946 | MulticlassF1Score=0.8534
# Batch-105: CrossEntropyLoss=2.2890 | MulticlassF1Score=0.8531
# Batch-120: CrossEntropyLoss=2.2840 | MulticlassF1Score=0.8530
# Batch-135: CrossEntropyLoss=2.2900 | MulticlassF1Score=0.8532
# Batch-150: CrossEntropyLoss=2.2918 | MulticlassF1Score=0.8530
# Batch-165: CrossEntropyLoss=2.2950 | MulticlassF1Score=0.8532
# Batch-180: CrossEntropyLoss=2.3040 | MulticlassF1Score=0.8525
# Batch-195: CrossEntropyLoss=2.2885 | MulticlassF1Score=0.8524
# Batch-210: CrossEntropyLoss=2.2938 | MulticlassF1Score=0.8523
# Batch-225: CrossEntropyLoss=2.2989 | MulticlassF1Score=0.8521
# Batch-226: CrossEntropyLoss=2.3043 | MulticlassF1Score=0.8520
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2986 | MulticlassF1Score=0.8461
# Batch-30 : CrossEntropyLoss=2.2930 | MulticlassF1Score=0.8410
# Batch-45 : CrossEntropyLoss=2.2883 | MulticlassF1Score=0.8399
# Batch-60 : CrossEntropyLoss=2.2950 | MulticlassF1Score=0.8414
# Batch-63 : CrossEntropyLoss=2.2878 | MulticlassF1Score=0.8410
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2934 | Mean MulticlassF1Score = 0.8539
# Validation : Mean CrossEntropyLoss = 2.2969 | Mean MulticlassF1Score = 0.8435
# ================================================================================
#
# EPOCH-17
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3049 | MulticlassF1Score=0.8450
# Batch-30 : CrossEntropyLoss=2.2921 | MulticlassF1Score=0.8491
# Batch-45 : CrossEntropyLoss=2.2867 | MulticlassF1Score=0.8516
# Batch-60 : CrossEntropyLoss=2.2901 | MulticlassF1Score=0.8542
# Batch-75 : CrossEntropyLoss=2.2874 | MulticlassF1Score=0.8594
# Batch-90 : CrossEntropyLoss=2.2848 | MulticlassF1Score=0.8620
# Batch-105: CrossEntropyLoss=2.2859 | MulticlassF1Score=0.8636
# Batch-120: CrossEntropyLoss=2.2991 | MulticlassF1Score=0.8648
# Batch-135: CrossEntropyLoss=2.2929 | MulticlassF1Score=0.8658
# Batch-150: CrossEntropyLoss=2.2902 | MulticlassF1Score=0.8667
# Batch-165: CrossEntropyLoss=2.2965 | MulticlassF1Score=0.8674
# Batch-180: CrossEntropyLoss=2.2823 | MulticlassF1Score=0.8678
# Batch-195: CrossEntropyLoss=2.2842 | MulticlassF1Score=0.8689
# Batch-210: CrossEntropyLoss=2.2883 | MulticlassF1Score=0.8698
# Batch-225: CrossEntropyLoss=2.2845 | MulticlassF1Score=0.8698
# Batch-226: CrossEntropyLoss=2.2824 | MulticlassF1Score=0.8699
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2894 | MulticlassF1Score=0.8696
# Batch-30 : CrossEntropyLoss=2.2955 | MulticlassF1Score=0.8675
# Batch-45 : CrossEntropyLoss=2.2908 | MulticlassF1Score=0.8659
# Batch-60 : CrossEntropyLoss=2.2916 | MulticlassF1Score=0.8656
# Batch-63 : CrossEntropyLoss=2.2824 | MulticlassF1Score=0.8656
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2880 | Mean MulticlassF1Score = 0.8610
# Validation : Mean CrossEntropyLoss = 2.2895 | Mean MulticlassF1Score = 0.8674
# ================================================================================
#
# EPOCH-18
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2817 | MulticlassF1Score=0.8830
# Batch-30 : CrossEntropyLoss=2.2850 | MulticlassF1Score=0.8815
# Batch-45 : CrossEntropyLoss=2.2886 | MulticlassF1Score=0.8816
# Batch-60 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.8818
# Batch-75 : CrossEntropyLoss=2.2817 | MulticlassF1Score=0.8820
# Batch-90 : CrossEntropyLoss=2.2849 | MulticlassF1Score=0.8817
# Batch-105: CrossEntropyLoss=2.2771 | MulticlassF1Score=0.8831
# Batch-120: CrossEntropyLoss=2.2882 | MulticlassF1Score=0.8846
# Batch-135: CrossEntropyLoss=2.2787 | MulticlassF1Score=0.8867
# Batch-150: CrossEntropyLoss=2.2785 | MulticlassF1Score=0.8886
# Batch-165: CrossEntropyLoss=2.2737 | MulticlassF1Score=0.8898
# Batch-180: CrossEntropyLoss=2.2805 | MulticlassF1Score=0.8914
# Batch-195: CrossEntropyLoss=2.2724 | MulticlassF1Score=0.8920
# Batch-210: CrossEntropyLoss=2.2768 | MulticlassF1Score=0.8928
# Batch-225: CrossEntropyLoss=2.2866 | MulticlassF1Score=0.8933
# Batch-226: CrossEntropyLoss=2.2755 | MulticlassF1Score=0.8933
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2796 | MulticlassF1Score=0.8955
# Batch-30 : CrossEntropyLoss=2.2756 | MulticlassF1Score=0.8953
# Batch-45 : CrossEntropyLoss=2.2772 | MulticlassF1Score=0.8947
# Batch-60 : CrossEntropyLoss=2.2772 | MulticlassF1Score=0.8933
# Batch-63 : CrossEntropyLoss=2.2805 | MulticlassF1Score=0.8937
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2809 | Mean MulticlassF1Score = 0.8862
# Validation : Mean CrossEntropyLoss = 2.2809 | Mean MulticlassF1Score = 0.8948
# ================================================================================
#
# EPOCH-19
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2806 | MulticlassF1Score=0.9084
# Batch-30 : CrossEntropyLoss=2.2754 | MulticlassF1Score=0.9090
# Batch-45 : CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9097
# Batch-60 : CrossEntropyLoss=2.2782 | MulticlassF1Score=0.9083
# Batch-75 : CrossEntropyLoss=2.2766 | MulticlassF1Score=0.9084
# Batch-90 : CrossEntropyLoss=2.2783 | MulticlassF1Score=0.9081
# Batch-105: CrossEntropyLoss=2.2775 | MulticlassF1Score=0.9086
# Batch-120: CrossEntropyLoss=2.2783 | MulticlassF1Score=0.9091
# Batch-135: CrossEntropyLoss=2.2785 | MulticlassF1Score=0.9094
# Batch-150: CrossEntropyLoss=2.2824 | MulticlassF1Score=0.9087
# Batch-165: CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9087
# Batch-180: CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9091
# Batch-195: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9093
# Batch-210: CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9092
# Batch-225: CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9091
# Batch-226: CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9091
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2848 | MulticlassF1Score=0.8933
# Batch-30 : CrossEntropyLoss=2.2702 | MulticlassF1Score=0.8962
# Batch-45 : CrossEntropyLoss=2.2785 | MulticlassF1Score=0.8950
# Batch-60 : CrossEntropyLoss=2.2818 | MulticlassF1Score=0.8967
# Batch-63 : CrossEntropyLoss=2.2858 | MulticlassF1Score=0.8964
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2760 | Mean MulticlassF1Score = 0.9093
# Validation : Mean CrossEntropyLoss = 2.2800 | Mean MulticlassF1Score = 0.8954
# ================================================================================
#
# EPOCH-20
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9111
# Batch-30 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9146
# Batch-45 : CrossEntropyLoss=2.2812 | MulticlassF1Score=0.9132
# Batch-60 : CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9136
# Batch-75 : CrossEntropyLoss=2.2788 | MulticlassF1Score=0.9121
# Batch-90 : CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9120
# Batch-105: CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9120
# Batch-120: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9121
# Batch-135: CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9125
# Batch-150: CrossEntropyLoss=2.2818 | MulticlassF1Score=0.9123
# Batch-165: CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9120
# Batch-180: CrossEntropyLoss=2.2751 | MulticlassF1Score=0.9126
# Batch-195: CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9120
# Batch-210: CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9116
# Batch-225: CrossEntropyLoss=2.2777 | MulticlassF1Score=0.9117
# Batch-226: CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9118
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2763 | MulticlassF1Score=0.8991
# Batch-30 : CrossEntropyLoss=2.2825 | MulticlassF1Score=0.8995
# Batch-45 : CrossEntropyLoss=2.2828 | MulticlassF1Score=0.8979
# Batch-60 : CrossEntropyLoss=2.2864 | MulticlassF1Score=0.8976
# Batch-63 : CrossEntropyLoss=2.2953 | MulticlassF1Score=0.8972
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2751 | Mean MulticlassF1Score = 0.9126
# Validation : Mean CrossEntropyLoss = 2.2797 | Mean MulticlassF1Score = 0.8987
# ================================================================================
#
# EPOCH-21
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2753 | MulticlassF1Score=0.9143
# Batch-30 : CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9122
# Batch-45 : CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9128
# Batch-60 : CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9131
# Batch-75 : CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9130
# Batch-90 : CrossEntropyLoss=2.2796 | MulticlassF1Score=0.9126
# Batch-105: CrossEntropyLoss=2.2753 | MulticlassF1Score=0.9127
# Batch-120: CrossEntropyLoss=2.2768 | MulticlassF1Score=0.9126
# Batch-135: CrossEntropyLoss=2.2777 | MulticlassF1Score=0.9125
# Batch-150: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9126
# Batch-165: CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9131
# Batch-180: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9131
# Batch-195: CrossEntropyLoss=2.2747 | MulticlassF1Score=0.9133
# Batch-210: CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9134
# Batch-225: CrossEntropyLoss=2.2773 | MulticlassF1Score=0.9137
# Batch-226: CrossEntropyLoss=2.2839 | MulticlassF1Score=0.9136
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2833 | MulticlassF1Score=0.8933
# Batch-30 : CrossEntropyLoss=2.2830 | MulticlassF1Score=0.8963
# Batch-45 : CrossEntropyLoss=2.2814 | MulticlassF1Score=0.8967
# Batch-60 : CrossEntropyLoss=2.2828 | MulticlassF1Score=0.8971
# Batch-63 : CrossEntropyLoss=2.2793 | MulticlassF1Score=0.8973
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2744 | Mean MulticlassF1Score = 0.9132
# Validation : Mean CrossEntropyLoss = 2.2796 | Mean MulticlassF1Score = 0.8965
# ================================================================================
#
# EPOCH-22
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9195
# Batch-30 : CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9164
# Batch-45 : CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9157
# Batch-60 : CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9168
# Batch-75 : CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9163
# Batch-90 : CrossEntropyLoss=2.2766 | MulticlassF1Score=0.9167
# Batch-105: CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9161
# Batch-120: CrossEntropyLoss=2.2759 | MulticlassF1Score=0.9160
# Batch-135: CrossEntropyLoss=2.2795 | MulticlassF1Score=0.9159
# Batch-150: CrossEntropyLoss=2.2768 | MulticlassF1Score=0.9161
# Batch-165: CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9161
# Batch-180: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9157
# Batch-195: CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9157
# Batch-210: CrossEntropyLoss=2.2827 | MulticlassF1Score=0.9157
# Batch-225: CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9154
# Batch-226: CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9155
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2689 | MulticlassF1Score=0.8992
# Batch-30 : CrossEntropyLoss=2.2788 | MulticlassF1Score=0.8983
# Batch-45 : CrossEntropyLoss=2.2793 | MulticlassF1Score=0.8968
# Batch-60 : CrossEntropyLoss=2.2781 | MulticlassF1Score=0.8977
# Batch-63 : CrossEntropyLoss=2.2783 | MulticlassF1Score=0.8978
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2738 | Mean MulticlassF1Score = 0.9161
# Validation : Mean CrossEntropyLoss = 2.2793 | Mean MulticlassF1Score = 0.8981
# ================================================================================
#
# EPOCH-23
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2807 | MulticlassF1Score=0.9111
# Batch-30 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9157
# Batch-45 : CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9166
# Batch-60 : CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9169
# Batch-75 : CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9166
# Batch-90 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9188
# Batch-105: CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9211
# Batch-120: CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9230
# Batch-135: CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9241
# Batch-150: CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9255
# Batch-165: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9265
# Batch-180: CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9273
# Batch-195: CrossEntropyLoss=2.2764 | MulticlassF1Score=0.9277
# Batch-210: CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9283
# Batch-225: CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9287
# Batch-226: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9287
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9192
# Batch-30 : CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9169
# Batch-45 : CrossEntropyLoss=2.2774 | MulticlassF1Score=0.9176
# Batch-60 : CrossEntropyLoss=2.2758 | MulticlassF1Score=0.9183
# Batch-63 : CrossEntropyLoss=2.2837 | MulticlassF1Score=0.9176
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2698 | Mean MulticlassF1Score = 0.9214
# Validation : Mean CrossEntropyLoss = 2.2734 | Mean MulticlassF1Score = 0.9180
# ================================================================================
#
# EPOCH-24
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9365
# Batch-30 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9384
# Batch-45 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9383
# Batch-60 : CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9390
# Batch-75 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9383
# Batch-90 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9385
# Batch-105: CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9386
# Batch-120: CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9380
# Batch-135: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9381
# Batch-150: CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9384
# Batch-165: CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9386
# Batch-180: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9383
# Batch-195: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9384
# Batch-210: CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9383
# Batch-225: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9382
# Batch-226: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9382
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9232
# Batch-30 : CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9242
# Batch-45 : CrossEntropyLoss=2.2798 | MulticlassF1Score=0.9251
# Batch-60 : CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9236
# Batch-63 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9235
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2669 | Mean MulticlassF1Score = 0.9383
# Validation : Mean CrossEntropyLoss = 2.2715 | Mean MulticlassF1Score = 0.9234
# ================================================================================
#
# EPOCH-25
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9438
# Batch-30 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9431
# Batch-45 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9430
# Batch-60 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9433
# Batch-75 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9435
# Batch-90 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9427
# Batch-105: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9428
# Batch-120: CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9426
# Batch-135: CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9421
# Batch-150: CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9417
# Batch-165: CrossEntropyLoss=2.2622 | MulticlassF1Score=0.9416
# Batch-180: CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9420
# Batch-195: CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9419
# Batch-210: CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9419
# Batch-225: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9419
# Batch-226: CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9419
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9217
# Batch-30 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9228
# Batch-45 : CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9232
# Batch-60 : CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9236
# Batch-63 : CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9238
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2657 | Mean MulticlassF1Score = 0.9426
# Validation : Mean CrossEntropyLoss = 2.2714 | Mean MulticlassF1Score = 0.9225
# ================================================================================
#
# EPOCH-26
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2622 | MulticlassF1Score=0.9446
# Batch-30 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9429
# Batch-45 : CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9432
# Batch-60 : CrossEntropyLoss=2.2622 | MulticlassF1Score=0.9428
# Batch-75 : CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9425
# Batch-90 : CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9428
# Batch-105: CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9428
# Batch-120: CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9426
# Batch-135: CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9425
# Batch-150: CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9426
# Batch-165: CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9424
# Batch-180: CrossEntropyLoss=2.2611 | MulticlassF1Score=0.9425
# Batch-195: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9426
# Batch-210: CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9427
# Batch-225: CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9430
# Batch-226: CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9430
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9271
# Batch-30 : CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9267
# Batch-45 : CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9249
# Batch-60 : CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9254
# Batch-63 : CrossEntropyLoss=2.2787 | MulticlassF1Score=0.9247
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2653 | Mean MulticlassF1Score = 0.9429
# Validation : Mean CrossEntropyLoss = 2.2711 | Mean MulticlassF1Score = 0.9259
# ================================================================================
#
# EPOCH-27
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9463
# Batch-30 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9449
# Batch-45 : CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9454
# Batch-60 : CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9451
# Batch-75 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9446
# Batch-90 : CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9449
# Batch-105: CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9450
# Batch-120: CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9451
# Batch-135: CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9453
# Batch-150: CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9453
# Batch-165: CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9451
# Batch-180: CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9449
# Batch-195: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9447
# Batch-210: CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9444
# Batch-225: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9443
# Batch-226: CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9443
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9258
# Batch-30 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9281
# Batch-45 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9250
# Batch-60 : CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9248
# Batch-63 : CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9249
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2649 | Mean MulticlassF1Score = 0.9452
# Validation : Mean CrossEntropyLoss = 2.2709 | Mean MulticlassF1Score = 0.9253
# ================================================================================
#
# EPOCH-28
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9471
# Batch-30 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9452
# Batch-45 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9449
# Batch-60 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9454
# Batch-75 : CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9461
# Batch-90 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9460
# Batch-105: CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9463
# Batch-120: CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9470
# Batch-135: CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9467
# Batch-150: CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9469
# Batch-165: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9465
# Batch-180: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9467
# Batch-195: CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9471
# Batch-210: CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9474
# Batch-225: CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9476
# Batch-226: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9476
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9233
# Batch-30 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9297
# Batch-45 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9300
# Batch-60 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9301
# Batch-63 : CrossEntropyLoss=2.2771 | MulticlassF1Score=0.9297
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2638 | Mean MulticlassF1Score = 0.9463
# Validation : Mean CrossEntropyLoss = 2.2696 | Mean MulticlassF1Score = 0.9278
# ================================================================================
#
# EPOCH-29
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9501
# Batch-30 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9503
# Batch-45 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9495
# Batch-60 : CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9499
# Batch-75 : CrossEntropyLoss=2.2611 | MulticlassF1Score=0.9493
# Batch-90 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9497
# Batch-105: CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9504
# Batch-120: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9496
# Batch-135: CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9495
# Batch-150: CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9494
# Batch-165: CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9492
# Batch-180: CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9492
# ...
# Batch-45 : CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9304
# Batch-60 : CrossEntropyLoss=2.2776 | MulticlassF1Score=0.9298
# Batch-63 : CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9305
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2614 | Mean MulticlassF1Score = 0.9546
# Validation : Mean CrossEntropyLoss = 2.2690 | Mean MulticlassF1Score = 0.9296
# ================================================================================
#
# EPOCH-42
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9553
# Batch-30 : CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9556
# Batch-45 : CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9554
# Batch-60 : CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9558
# Batch-75 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9558
# Batch-90 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9554
# Batch-105: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9554
# Batch-120: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9552
# Batch-135: CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9549
# Batch-150: CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9550
# Batch-165: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9551
# Batch-180: CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9552
# Batch-195: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9548
# Batch-210: CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9545
# Batch-225: CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9539
# Batch-226: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9539
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9290
# Batch-30 : CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9266
# Batch-45 : CrossEntropyLoss=2.2779 | MulticlassF1Score=0.9268
# Batch-60 : CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9283
# Batch-63 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9282
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2618 | Mean MulticlassF1Score = 0.9553
# Validation : Mean CrossEntropyLoss = 2.2699 | Mean MulticlassF1Score = 0.9277
# Patience = 3/50❗
# ================================================================================
#
# EPOCH-43
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9467
# Batch-30 : CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9491
# Batch-45 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9505
# Batch-60 : CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9508
# Batch-75 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9511
# Batch-90 : CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9515
# Batch-105: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9518
# Batch-120: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9514
# Batch-135: CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9514
# Batch-150: CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9513
# Batch-165: CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9515
# Batch-180: CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9517
# Batch-195: CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9515
# Batch-210: CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9515
# Batch-225: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9518
# Batch-226: CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9518
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9276
# Batch-30 : CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9288
# Batch-45 : CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9307
# Batch-60 : CrossEntropyLoss=2.2759 | MulticlassF1Score=0.9307
# Batch-63 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9306
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2625 | Mean MulticlassF1Score = 0.9508
# Validation : Mean CrossEntropyLoss = 2.2690 | Mean MulticlassF1Score = 0.9290
# Patience = 4/50❗
# ================================================================================
#
# EPOCH-44
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9513
# Batch-30 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9527
# Batch-45 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9521
# Batch-60 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9535
# Batch-75 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9538
# Batch-90 : CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9538
# Batch-105: CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9543
# Batch-120: CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9542
# Batch-135: CrossEntropyLoss=2.2597 | MulticlassF1Score=0.9540
# Batch-150: CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9539
# Batch-165: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9541
# Batch-180: CrossEntropyLoss=2.2589 | MulticlassF1Score=0.9542
# Batch-195: CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9542
# Batch-210: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9542
# Batch-225: CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9543
# Batch-226: CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9543
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9271
# Batch-30 : CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9290
# Batch-45 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9288
# Batch-60 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9304
# Batch-63 : CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9307
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2616 | Mean MulticlassF1Score = 0.9537
# Validation : Mean CrossEntropyLoss = 2.2689 | Mean MulticlassF1Score = 0.9290
# ================================================================================
#
# EPOCH-45
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9580
# Batch-30 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9576
# Batch-45 : CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9569
# Batch-60 : CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9570
# Batch-75 : CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9561
# Batch-90 : CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9563
# Batch-105: CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9561
# Batch-120: CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9558
# Batch-135: CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9561
# Batch-150: CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9559
# Batch-165: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9560
# Batch-180: CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9558
# Batch-195: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9556
# Batch-210: CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9555
# Batch-225: CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9553
# Batch-226: CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9553
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9317
# Batch-30 : CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9317
# Batch-45 : CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9318
# Batch-60 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9313
# Batch-63 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9311
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2613 | Mean MulticlassF1Score = 0.9563
# Validation : Mean CrossEntropyLoss = 2.2689 | Mean MulticlassF1Score = 0.9324
# ================================================================================
#
# EPOCH-46
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9561
# Batch-30 : CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9576
# Batch-45 : CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9571
# Batch-60 : CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9565
# Batch-75 : CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9568
# Batch-90 : CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9565
# Batch-105: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9565
# Batch-120: CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9561
# Batch-135: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9561
# Batch-150: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9558
# Batch-165: CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9560
# Batch-180: CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9559
# Batch-195: CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9559
# Batch-210: CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9558
# Batch-225: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9559
# Batch-226: CrossEntropyLoss=2.2622 | MulticlassF1Score=0.9559
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9324
# Batch-30 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9305
# Batch-45 : CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9297
# Batch-60 : CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9316
# Batch-63 : CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9313
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2610 | Mean MulticlassF1Score = 0.9565
# Validation : Mean CrossEntropyLoss = 2.2688 | Mean MulticlassF1Score = 0.9314
# ================================================================================
#
# EPOCH-47
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9572
# Batch-30 : CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9548
# Batch-45 : CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9559
# Batch-60 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9566
# Batch-75 : CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9565
# Batch-90 : CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9567
# Batch-105: CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9563
# Batch-120: CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9565
# Batch-135: CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9565
# Batch-150: CrossEntropyLoss=2.2597 | MulticlassF1Score=0.9565
# Batch-165: CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9564
# Batch-180: CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9565
# Batch-195: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9564
# Batch-210: CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9564
# Batch-225: CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9563
# Batch-226: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9564
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9350
# Batch-30 : CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9334
# Batch-45 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9318
# Batch-60 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9316
# Batch-63 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9314
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2608 | Mean MulticlassF1Score = 0.9563
# Validation : Mean CrossEntropyLoss = 2.2687 | Mean MulticlassF1Score = 0.9341
# ================================================================================
#
# EPOCH-48
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9551
# Batch-30 : CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9543
# Batch-45 : CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9549
# Batch-60 : CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9555
# Batch-75 : CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9562
# Batch-90 : CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9563
# Batch-105: CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9561
# Batch-120: CrossEntropyLoss=2.2597 | MulticlassF1Score=0.9565
# Batch-135: CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9569
# Batch-150: CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9571
# Batch-165: CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9572
# Batch-180: CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9572
# Batch-195: CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9570
# Batch-210: CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9568
# Batch-225: CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9566
# Batch-226: CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9566
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9338
# Batch-30 : CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9313
# Batch-45 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9319
# Batch-60 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9316
# Batch-63 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9316
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2607 | Mean MulticlassF1Score = 0.9561
# Validation : Mean CrossEntropyLoss = 2.2687 | Mean MulticlassF1Score = 0.9319
# ================================================================================
#
# EPOCH-49
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9556
# Batch-30 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9579
# Batch-45 : CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9567
# Batch-60 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9560
# Batch-75 : CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9558
# Batch-90 : CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9559
# Batch-105: CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9566
# Batch-120: CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9565
# Batch-135: CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9563
# Batch-150: CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9565
# Batch-165: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9568
# Batch-180: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9568
# Batch-195: CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9566
# Batch-210: CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9565
# Batch-225: CrossEntropyLoss=2.2612 | MulticlassF1Score=0.9566
# Batch-226: CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9566
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9273
# Batch-30 : CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9303
# Batch-45 : CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9301
# Batch-60 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9307
# Batch-63 : CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9311
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2608 | Mean MulticlassF1Score = 0.9565
# Validation : Mean CrossEntropyLoss = 2.2689 | Mean MulticlassF1Score = 0.9292
# Patience = 5/50❗
# ================================================================================
#
# EPOCH-50
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9574
# Batch-30 : CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9559
# Batch-45 : CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9555
# Batch-60 : CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9550
# Batch-75 : CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9559
# Batch-90 : CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9559
# Batch-105: CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9562
# Batch-120: CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9561
# Batch-135: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9563
# Batch-150: CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9564
# Batch-165: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9565
# Batch-180: CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9569
# Batch-195: CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9571
# Batch-210: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9569
# Batch-225: CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9571
# Batch-226: CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9571
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9318
# Batch-30 : CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9308
# Batch-45 : CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9310
# Batch-60 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9316
# Batch-63 : CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9318
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2607 | Mean MulticlassF1Score = 0.9564
# Validation : Mean CrossEntropyLoss = 2.2687 | Mean MulticlassF1Score = 0.9313
# ================================================================================
#
# TRAINING SUMMARY
# Best CrossEntropyLoss training    : 2.2607
# Best CrossEntropyLoss training    : 2.2687
# Best MulticlassF1Score validation : 0.9564
# Best MulticlassF1Score validation : 0.9313
# Training duration                 : 2.4643 minutes.
# Training date                     : 2022-10-24 18:31:50.805290+08:00

# %% [markdown]
# ## End Training

# %% [markdown]
# # Evaluation

# %%
def evaluation(dataloader, model, criterion, metric):
    model.eval()
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)
            pred = rearrange(prob.argmax(dim=1).reshape(feature.shape[0], len(dataloader.dataset)), "s n -> n s")

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob.argmax(dim=1), actual_label.to(hyperparams.device))
            metric_score = metric.compute()

    return loss, metric_score, pred

train_dataloader = DataLoader(train_dataset, batch_size=len(train_dataset))
val_dataloader = DataLoader(val_dataset, batch_size=len(val_dataset))
test_dataloader = DataLoader(test_dataset, batch_size=len(test_dataset))

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
train_loss, train_f1_score, train_pred_label = evaluation(train_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_loss, val_f1_score, val_pred_label = evaluation(val_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
test_loss, test_f1_score, test_pred_label = evaluation(test_dataloader, model, criterion, metric)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9578, device='cuda:0'),
#  tensor(0.9318, device='cuda:0'),
#  tensor(0.9281, device='cuda:0'))

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9578, device='cuda:0'),
#  tensor(0.9318, device='cuda:0'),
#  tensor(0.9281, device='cuda:0'))

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns

def viz_evaluation(pred_label, actual_label, title):
    plt.figure(figsize=(15, 7), dpi=200)
    sns.heatmap(pred_label.detach().cpu() == actual_label, cbar=True, cmap="binary_r")
    plt.xlabel("Sentence Length")
    plt.ylabel("Sentence")
    plt.title(title)
    plt.savefig(f"{root_path}/heatmap_{title.lower()}.jpg", dpi=200)
    plt.show()

train_actual_label = train_dataloader.dataset.tensors[1]
val_actual_label = val_dataloader.dataset.tensors[1]
test_actual_label = test_dataloader.dataset.tensors[1]

viz_evaluation(train_pred_label, train_actual_label, f"Training (F1-Score: {(train_f1_score):.4f})")
viz_evaluation(val_pred_label, val_actual_label, f"Validation (F1-Score: {(val_f1_score):.4f})")
viz_evaluation(test_pred_label, test_actual_label, f"Test (F1-Score: {(test_f1_score):.4f})")

# %% [markdown]
# ## Confusion Matrix

# %%
def confusion_matrix(pred_class, actual_class, title, normalize=None):
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize=normalize)
    plt.figure(figsize=(20, 10), dpi=200)
    sns.heatmap(conf_mat(pred_class.detach().cpu(), actual_class), annot=True, fmt=".2g", xticklabels=list(label_to_idx.keys()), yticklabels=list(label_to_idx.keys()));
    plt.yticks(rotation=0)
    plt.title(title)
    plt.xlabel("Actual Class")
    plt.ylabel("Predict Class")
    plt.savefig(f"{root_path}/conf_matrix_{title.lower()}.jpg", dpi=200)

confusion_matrix(train_pred_label, train_actual_label, "Training", "pred")
confusion_matrix(val_pred_label,val_actual_label, "Validation", "pred")
confusion_matrix(test_pred_label, test_actual_label, "Test", "pred")
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 144 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)

# %% [markdown]
# ## Prediction Table

# %%
def number_wrong_pred_each_class(pred_class, actual_class):
    classes, count_class = actual_class.flatten().unique(return_counts=True)
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize="none")
    correct_pred_count_class = conf_mat(pred_class.detach().cpu(), actual_class).diag()
    
    correct_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (correct_pred_count_class))}
    wrong_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (count_class - correct_pred_count_class))}
    
    return correct_pred, wrong_pred

correct_pred, wrong_pred = number_wrong_pred_each_class(train_pred_label, train_actual_label)
print(f"| {'Number class'.ljust(14)} | {'Correct prediction'.ljust(12)} | {'Wrong prediction'.ljust(12)} |")
for (label_correct_pred, count_correct_pred), (label_wrong_pred, count_wrong_pred) in zip(correct_pred.items(), wrong_pred.items()):
    print(f"| {str(label_correct_pred).ljust(6)}: {str(count_correct_pred + count_wrong_pred).ljust(7)}| {label_correct_pred.ljust(6)}: {str(count_correct_pred).ljust(10)} | {label_wrong_pred.ljust(6)}: {str(count_wrong_pred).ljust(8)} |")
# Out:
# | Number class   | Correct prediction | Wrong prediction |
# | CC    : 5397   | CC    : 5277       | CC    : 120      |
# | CD    : 12862  | CD    : 12691      | CD    : 171      |
# | DT    : 278    | DT    : 0          | DT    : 278      |
# | FW    : 1605   | FW    : 1250       | FW    : 355      |
# | IN    : 15290  | IN    : 15105      | IN    : 185      |
# | JJ    : 7025   | JJ    : 6577       | JJ    : 448      |
# | MD    : 3798   | MD    : 3774       | MD    : 24       |
# | NEG   : 1101   | NEG   : 0          | NEG   : 1101     |
# | NN    : 44472  | NN    : 43880      | NN    : 592      |
# | NND   : 1033   | NND   : 838        | NND   : 195      |
# | NNP   : 25007  | NNP   : 24196      | NNP   : 811      |
# | OD    : 519    | OD    : 501        | OD    : 18       |
# | PR    : 3880   | PR    : 3820       | PR    : 60       |
# | PRP   : 5449   | PRP   : 5291       | PRP   : 158      |
# | RB    : 3502   | RB    : 3201       | RB    : 301      |
# | RP    : 131    | RP    : 0          | RP    : 131      |
# | SC    : 9421   | SC    : 9106       | SC    : 315      |
# | SYM   : 1564   | SYM   : 1484       | SYM   : 80       |
# | UH    : 21     | UH    : 0          | UH    : 21       |
# | VB    : 22760  | VB    : 20841      | VB    : 1919     |
# | WH    : 180    | WH    : 0          | WH    : 180      |
# | X     : 290    | X     : 0          | X     : 290      |
# | Z     : 19042  | Z     : 18999      | Z     : 43       |
# | <PAD> : 407577 | <PAD> : 407577     | <PAD> : 0        |

# %%
train_actual_label[308], train_pred_label[308]
# Out:
# (tensor([ 8,  3, 12, 19,  8,  8,  8, 16, 19,  4, 10,  8, 10,  0,  4,  1,  8,  8,
#           8,  5,  4,  8, 10,  0, 10, 10, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23]),
#  tensor([ 8,  8, 12, 19,  8,  8,  5, 16, 19,  4, 10,  8, 10,  0,  4,  1,  8,  8,
#           8,  5,  4,  8, 10,  0, 10, 10, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23], device='cuda:0'))

# %%
train_actual_label[308].detach().cpu() == train_pred_label[308].detach().cpu()
# Out:
# tensor([ True, False,  True,  True,  True,  True, False,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True])

# %% [markdown]
# ## OOV prediction is correct

# %%
def oov_flag_token(sentences, max_seq_len=hyperparams.max_seq_len):
    sent_copy = deepcopy(sentences)
    sent = []
    oov_flag = []
    
    for sentence in tqdm(sent_copy):
        for token in sentence:
            sent.append(token[2])
        
        for _ in range(max_seq_len- len(sentence)):
            sent.append(False)
        
        oov_flag.append(sent)
        sent = []
        
    return np.array(oov_flag)

train_oov_flag = oov_flag_token(train_sentences, max_seq_len=hyperparams.max_seq_len)
val_oov_flag = oov_flag_token(val_sentences, max_seq_len=hyperparams.max_seq_len)
test_oov_flag = oov_flag_token(test_sentences, max_seq_len=hyperparams.max_seq_len)

def pencentage_oov_pred_correct(pred_oov_flag, oov_flag_tensor):
    oov_correct_counter = 0
    oov_wrong_counter = 0

    for pred, oov_label in tqdm(zip(pred_oov_flag, oov_flag_tensor)):
        if pred == True and oov_label == True:
            oov_correct_counter += 1
        elif pred == False and oov_label == True:
            oov_wrong_counter += 1
        else:
            continue
            
    return oov_correct_counter, oov_wrong_counter

train_pred_oov_flag = (train_actual_label == train_pred_label.detach().cpu()).flatten()
val_pred_oov_flag = (val_actual_label == val_pred_label.detach().cpu()).flatten()
test_pred_oov_flag = (test_actual_label == test_pred_label.detach().cpu()).flatten()
train_oov_flag_tensor = torch.tensor(train_oov_flag).flatten()
val_oov_flag_tensor = torch.tensor(val_oov_flag).flatten()
test_oov_flag_tensor = torch.tensor(test_oov_flag).flatten()

train_oov_correct_counter, train_oov_wrong_counter = pencentage_oov_pred_correct(train_pred_oov_flag, train_oov_flag_tensor)
val_oov_correct_counter, val_oov_wrong_counter = pencentage_oov_pred_correct(val_pred_oov_flag, val_oov_flag_tensor)
test_oov_correct_counter, test_oov_wrong_counter = pencentage_oov_pred_correct(test_pred_oov_flag, test_oov_flag_tensor)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
def print_percentage_pred_oov(title, oov_correct_counter, oov_wrong_counter):
    print(f"{title}")
    print(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}")
    print(f"Correct prediction          : {oov_correct_counter}")
    print(f"Wrong prediction            : {oov_wrong_counter}")
    print(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n")
    
    with open(f"{root_path}/oov_summary.txt", "a") as f:
        f.write(f"{title}\n")
        f.write(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}\n")
        f.write(f"Correct prediction          : {oov_correct_counter}\n")
        f.write(f"Wrong prediction            : {oov_wrong_counter}\n")
        f.write(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n\n")

# %%
print_percentage_pred_oov("Training", train_oov_correct_counter, train_oov_wrong_counter)
print_percentage_pred_oov("Validation", val_oov_correct_counter, val_oov_wrong_counter)
print_percentage_pred_oov("Test", test_oov_correct_counter, test_oov_wrong_counter)
# Out:
# Training
# Number OOV token            : 11971
# Correct prediction          : 10344
# Wrong prediction            : 1627
# Percentage correct oov pred : 86.40882131818562
#
# Validation
# Number OOV token            : 3190
# Correct prediction          : 2314
# Wrong prediction            : 876
# Percentage correct oov pred : 72.53918495297805
#
# Test
# Number OOV token            : 1401
# Correct prediction          : 989
# Wrong prediction            : 412
# Percentage correct oov pred : 70.59243397573162

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(train_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(val_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(test_oov_flag, cmap=plt.cm.binary_r);
