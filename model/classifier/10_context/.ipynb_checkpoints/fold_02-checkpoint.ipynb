# %% [markdown]
# # Import modules

# %%
import csv
import os
import pickle
import pytz
import torch
import timeit
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from copy import deepcopy
from datetime import datetime
from einops import rearrange
from itertools import chain
from time import time
from torch import nn, optim
from torchmetrics.classification import MulticlassAccuracy, MulticlassF1Score, MulticlassConfusionMatrix
from torch.optim import lr_scheduler
from tqdm.notebook import tqdm
from torch.utils.data import TensorDataset, DataLoader
from polyglot.mapping import Embedding, CaseExpander, DigitExpander

# %% [markdown]
# # Hyperparameters

# %%
class Hyperparams:
     def __init__(
        self,
        context_size=10,
        fold=2,
        max_seq_len=82,
        input_size=64,
        batch_size=32,
        num_hidden_layer=1,
        hidden_size=128,
        dropout=0,
        bias=True,
        output_size=24,
        shuffle=True,
        lr=0.005,
        batch_first=False,
        bidirectional=True,
        init_wb_with_kaiming_normal=True,
        n_epoch=50,
        patience=50,
        device="cuda" if torch.cuda.is_available() else "cpu"
    ):
        self.context_size = context_size
        self.fold = fold
        self.input_size = input_size
        self.max_seq_len = max_seq_len
        self.batch_size = batch_size
        self.num_hidden_layer = num_hidden_layer
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.output_size = output_size
        self.shuffle = shuffle
        self.lr = lr
        self.batch_first = batch_first
        self.bidirectional = bidirectional
        self.init_wb_with_kaiming_normal = init_wb_with_kaiming_normal
        self.n_epoch = n_epoch
        self.patience = patience
        self.device = device

hyperparams = Hyperparams()

# %% [markdown]
# # Dataset

# %%
id_pos_tag = pd.read_csv("../../../datasets/raw/Indonesian_Manually_Tagged_Corpus.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False) 
train = pd.read_csv(f"../../../datasets/raw/cv/train/train.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
val = pd.read_csv(f"../../../datasets/raw/cv/val/val.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
test = pd.read_csv(f"../../../datasets/raw/cv/test/test.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)

# %% [markdown]
# # Pre-trained Word Embedding

# %%
embeddings = Embedding.load("../../../word_embeddings/polyglot/idn_embeddings.tar.bz2")
embeddings.apply_expansion(DigitExpander)
embeddings.apply_expansion(CaseExpander)

oov_embeddings = pickle.load(open(f"../../../logs/comick/{hyperparams.context_size}_contexts/10-11-2022_11-02-37/oov_embedding_dict.pkl", "rb"))

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Add OOV Flag

# %%
def add_oov_flag(tokens, embeddings):
    oov_flags = []
    
    for token in tqdm(tokens):
        try:
            if token not in embeddings:
                oov_flags.append(True)
            else:
                oov_flags.append(False)
        except:
            oov_flags.append(False)
        
    return pd.DataFrame(oov_flags, columns=["is_oov"])

id_pos_tag_oov_flags = add_oov_flag(id_pos_tag["token"].values, embeddings)
train_oov_flags = add_oov_flag(train["token"].values, embeddings)
val_oov_flags = add_oov_flag(val["token"].values, embeddings)
test_oov_flags = add_oov_flag(test["token"].values, embeddings)
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/192008 [00:00<?, ?it/s]
#   0%|          | 0/21405 [00:00<?, ?it/s]
#   0%|          | 0/53239 [00:00<?, ?it/s]

# %% [markdown]
# ## Concate OOV Flag

# %%
id_pos_tag_df = pd.concat([id_pos_tag, id_pos_tag_oov_flags], axis=1)
train_df = pd.concat([train, train_oov_flags], axis=1)
val_df = pd.concat([val, val_oov_flags], axis=1)
test_df = pd.concat([test, test_oov_flags], axis=1)

# %% [markdown]
# ## Lowercase OOV Token

# %%
id_pos_tag_df['token'] = np.where(id_pos_tag_df['is_oov'] == True, id_pos_tag_df['token'].str.lower(), id_pos_tag_df['token'])
train_df['token'] = np.where(train_df['is_oov'] == True, train_df['token'].str.lower(), train_df['token'])
val_df['token'] = np.where(val_df['is_oov'] == True, val_df['token'].str.lower(), val_df['token'])
test_df['token'] = np.where(test_df['is_oov'] == True, test_df['token'].str.lower(), test_df['token'])

# %% [markdown]
# ## Embedding Dict, Index to Token and Token to Index

# %%
tokens = list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None))

def embedding_dict(tokens, embeddings, oov_embeddings):
    embedding = {}
    
    for token in tokens:
        if token[0] is not np.nan:
            if token[2] == False or token[0] in embeddings:
                embedding[token[0]] = embeddings[token[0]]
            else:
                embedding[token[0]] = oov_embeddings[token[0].lower()]

    return embedding

embedding_dict = embedding_dict(tokens, embeddings, oov_embeddings)
embedding_dict["<PAD>"] = embeddings["<PAD>"]
word_embeddings = nn.Embedding.from_pretrained(torch.FloatTensor(np.array(list(embedding_dict.values()))), padding_idx=list(embedding_dict.keys()).index("<PAD>"), freeze=True)

idx_to_token = {idx: token for idx, token in enumerate(list(embedding_dict.keys()))}
token_to_idx = {token: idx for idx, token in enumerate(list(embedding_dict.keys()))}

# %% [markdown]
# ## Token to Sentence

# %%
def make_sentence(tokens, max_length_sentence=hyperparams.max_seq_len):
    sentence = []
    sentences = []

    for token in tqdm(tokens):
        if token[0] is not np.nan:
            sentence.append(token)
        else:
            sentences.append(sentence[:max_length_sentence])
            sentence = []

    return sentences

all_sentence = make_sentence(list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
train_sentences = make_sentence(list(train_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
val_sentences = make_sentence(list(test_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
test_sentences = make_sentence(list(val_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/192008 [00:00<?, ?it/s]
#   0%|          | 0/53239 [00:00<?, ?it/s]
#   0%|          | 0/21405 [00:00<?, ?it/s]

# %% [markdown]
# ## Word Token, Padding, and Word token to Index

# %%
def tokenize_docs(docs, idx_token):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token[idx_token])
        sentences.append(new_sentence)
        new_sentence = []

    return sentences

def padding(docs, max_seq_len=hyperparams.max_seq_len, mode="post", val_pad="<PAD>"):
    docs = deepcopy(docs)
    doc_with_pad = []
    docs_with_pad = []

    for doc in tqdm(docs):
        if mode == "pre":
            for _ in range(max_seq_len - len(doc)):
                doc.insert(0, val_pad)
        elif mode == "post":
            for _ in range(max_seq_len - len(doc)):
                doc.append(val_pad)
        else:
            return f"Mode {mode} is not available, use instead 'pre' or 'post'."
        
        docs_with_pad.append(doc)
        
    return np.array(docs_with_pad)

def sent_to_idx(docs, token_to_idx):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token_to_idx[token])
        sentences.append(new_sentence)
        new_sentence = []

    return np.array(sentences)

def convert_feature_to_idx(docs, idx_token, token_to_idx, max_seq_len):
    sentences = tokenize_docs(docs, idx_token)
    sentences_with_pad = padding(sentences, max_seq_len=max_seq_len, mode="post", val_pad="<PAD>")
    sentences_to_idx = sent_to_idx(sentences_with_pad, token_to_idx)
    
    return sentences_to_idx

train_sentence_idxs = convert_feature_to_idx(train_sentences, 0, token_to_idx, hyperparams.max_seq_len)
val_sentence_idxs = convert_feature_to_idx(val_sentences, 0, token_to_idx, hyperparams.max_seq_len)
test_sentence_idxs = convert_feature_to_idx(test_sentences, 0, token_to_idx, hyperparams.max_seq_len)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]

# %% [markdown]
# ## Encode Class

# %%
classes = sorted(np.delete(id_pos_tag_df["tag"].unique(), 3))
idx_to_label = {idx: label for idx, label in enumerate(classes + ["<PAD>"])}
label_to_idx = {label: idx for idx, label in enumerate(classes + ["<PAD>"])}

def encode_class(docs, label_to_idx, seq_len=hyperparams.max_seq_len):
    class_idxs = []
    classes = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            class_idxs.append(label_to_idx[token[1]])
            
        for _ in range(seq_len - len(sentence)):
            class_idxs.append(label_to_idx["<PAD>"])
                
        classes.append(class_idxs)
        class_idxs = []

    return np.array(classes)
        
train_class_idxs = encode_class(train_sentences, label_to_idx)
val_class_idxs = encode_class(val_sentences, label_to_idx)
test_class_idxs = encode_class(test_sentences, label_to_idx)

print(f"Training shape   : {train_sentence_idxs.shape, train_class_idxs.shape}")
print(f"validation shape : {val_class_idxs.shape, val_class_idxs.shape}")
print(f"Test shape       : {test_sentence_idxs.shape, test_class_idxs.shape}")
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# Training shape   : ((7222, 82), (7222, 82))
# validation shape : ((2006, 82), (2006, 82))
# Test shape       : ((802, 82), (802, 82))

# %% [markdown]
# ## Note
#
# - Number of sentences = 10030
# - Train : 72% (7222)
# - Val   : 8% (802)
# - Test  : 20% (2006)

# %% [markdown]
# # Build Model

# %% [markdown]
# ## Feature and Actual Class

# %%
train_feature = torch.LongTensor(train_sentence_idxs)
val_feature = torch.LongTensor(val_sentence_idxs)
test_feature = torch.LongTensor(test_sentence_idxs)

train_class = torch.LongTensor(train_class_idxs)
val_class = torch.LongTensor(val_class_idxs)
test_class = torch.LongTensor(test_class_idxs)

# %%
train_feature.shape, val_feature.shape, test_feature.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %%
train_class.shape, val_class.shape, test_class.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %% [markdown]
# ## Tensor Dataset

# %%
train_dataset = TensorDataset(train_feature, train_class)
val_dataset = TensorDataset(val_feature, val_class)
test_dataset = TensorDataset(test_feature, test_class)

# %% [markdown]
# ## Dataloader

# %%
train_dataloader = DataLoader(train_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
val_dataloader = DataLoader(val_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
test_dataloader = DataLoader(test_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)

# %% [markdown]
# ## Model

# %%
class POSTagger(nn.Module):
    def __init__(
        self,
        input_size=hyperparams.input_size,
        hidden_size=hyperparams.hidden_size,
        dropout=hyperparams.dropout,
        bias=hyperparams.bias,
        num_layers=hyperparams.num_hidden_layer,
        output_size=hyperparams.output_size,
        batch_first=hyperparams.batch_first,
        bidirectional=hyperparams.bidirectional,
        init_wb_with_kaiming_normal=hyperparams.init_wb_with_kaiming_normal
    ):
        super(POSTagger, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.num_layers = num_layers
        self.output_size = output_size
        self.batch_first = batch_first
        self.bidirectional = bidirectional
                
        self.feature = nn.LSTM(
            input_size = self.input_size,
            hidden_size = self.hidden_size,
            bias = self.bias,
            dropout = self.dropout,
            num_layers = self.num_layers,
            batch_first = self.batch_first,
            bidirectional = self.bidirectional
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(in_features=2 * self.hidden_size if hyperparams.bidirectional else self.hidden_size, out_features=self.output_size, bias=self.bias),
            nn.Softmax(dim=-1)
        )
        
        if init_wb_with_kaiming_normal:
            self.init_wb()

    def init_wb(self):
        for module in self.modules():
            if isinstance(module, (nn.Linear, nn.LSTM)):
                for name, param in module.named_parameters():
                    if "weight" in name:
                        nn.init.kaiming_normal_(param)
                    else:
                        nn.init.kaiming_normal_(param.reshape(1, -1))
        
    def forward(self, feature, hidden=None):
        output, (hidden, memory) = self.feature(feature, None)
        prob = self.classifier(output)

        return prob
    
model = POSTagger().to(hyperparams.device)
model
# Out:
# POSTagger(
#   (feature): LSTM(64, 128, bidirectional=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=24, bias=True)
#     (1): Softmax(dim=-1)
#   )
# )

# %% [markdown]
# ## Optimizer, Criterion, and Metric

# %%
optimizer = optim.Adam(model.parameters(), lr=hyperparams.lr)
criterion = nn.CrossEntropyLoss().to(hyperparams.device)
train_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", verbose=True, factor=0.5)

# %%
sum(param.numel() for param in model.parameters() if param.requires_grad)
# Out:
# 204824

# %% [markdown]
# ## Training Step

# %%
def training_step(dataloader, model, optimizer, criterion, metric, scheduler=None):
    model.train()
    
    batch_losses = []
    batch_metric_scores = []
    
    for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
        # Forward Propagation
        feature = rearrange(feature, "n s -> s n")
        actual_label = rearrange(actual_label, "n s -> s n")
        embedding = word_embeddings(feature)
        
        prob = model(
            embedding.to(hyperparams.device),
            actual_label.to(hyperparams.device)
        )
        
        prob = prob.reshape(-1, prob.shape[-1])
        actual_label = actual_label.reshape(-1)

        loss = criterion(prob, actual_label.to(hyperparams.device))
        metric_score = metric(prob, actual_label.to(hyperparams.device))
        metric_score = metric.compute()
                
        if scheduler is not None:
            scheduler.step(loss)
        
        batch_losses.append(loss.item())
        batch_metric_scores.append(metric_score)
        
        if len(dataloader) < 10:
            if batch % 1 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
        else:
            if batch % 15 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            
        # Backward Propagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Validation Step

# %%
def validation_step(dataloader, model, criterion, metric):
    model.eval()
    
    batch_losses = []
    batch_metric_scores = []
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob, actual_label.to(hyperparams.device))
            metric_score = metric.compute()

            batch_losses.append(loss.item())
            batch_metric_scores.append(metric_score)
            
            if len(dataloader) < 10 and (batch % 1 == 0 or batch == len(dataloader)):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            else:
                if batch % 15 == 0 or batch == len(dataloader):
                    batch_name = "Batch-" + str(batch)
                    print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                    with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                        f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Looping Step

# %%
now = datetime.now(pytz.timezone("Asia/Ujung_Pandang"))
path_name = now.strftime("%m-%d-%Y_%H-%M-%S")
root_path = f"../../../logs/classifier/{hyperparams.context_size}_contexts/fold_0{hyperparams.fold}/{path_name}"
os.makedirs(root_path)

def looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric, n_epoch=hyperparams.n_epoch, patience=hyperparams.patience, monitor="loss"):    
    start_time = time()
    
    epoch_training_losses = []
    epoch_training_metric_scores = []
    epoch_val_losses = []
    epoch_val_metric_scores = []
    patience_counter = 0
    
    # Hyperparameters
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write(f"HYPERPARAMETERS\n")
        f.write(f"{'-' * 80}\n")
        for name, value in vars(hyperparams).items():
            f.write(f"{name}: {value}\n")
        
        f.write("\n\nTRAINING PROGRESS\n")
        f.write(f"{'-' * 80}\n")
    
    # Training Progress
    for epoch in range(1, n_epoch + 1):
        print(f"EPOCH-{epoch}")
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"EPOCH-{epoch}\n")
            f.write(f"Training Step\n")
            
        # Training Step
        print("Training Step")
        batch_training_losses, batch_training_metric_scores = training_step(train_dataloader, model, optimizer, criterion, train_metric, scheduler=None)
        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))

        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))
        epoch_training_losses.append(epoch_training_loss.item())

        epoch_training_metric_score = torch.mean(torch.FloatTensor(batch_training_metric_scores))
        epoch_training_metric_scores.append(epoch_training_metric_score.item())
        
        # Validation Step
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"\nValidation Step\n")
            
        print("\nValidation Step")
        batch_val_losses, batch_val_metric_scores = validation_step(val_dataloader, model, criterion, val_metric)
        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))

        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))
        epoch_val_losses.append(epoch_val_loss.item())

        epoch_val_metric_score = torch.mean(torch.FloatTensor(batch_val_metric_scores))
        epoch_val_metric_scores.append(epoch_val_metric_score.item())
        
        with open(f"{root_path}/training_history.txt", "a") as f:
            if monitor == "loss":
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_losses[-1] < epoch_training_losses[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
            else:
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_metric_scores[-1] > epoch_training_metric_scores[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗\n")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
                    
            print("=" * 80, end="\n\n")
            
            f.write(f"{'=' * 80}\n\n")
            
            if patience_counter == patience:
                print(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                
                f.write(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                break
        
        train_metric.reset()
        val_metric.reset()
        
    finish_time = time()
    
    # Training plot 
    fig, (ax_loss, ax_metric_score) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    fig.suptitle(f"Training with context size = {hyperparams.context_size}")

    ax_loss.set_title("Loss")
    ax_loss.set_xlabel("Epoch")
    ax_loss.set_ylabel("Score")
    ax_loss.plot(epoch_training_losses, "green", label="Training")
    ax_loss.plot(epoch_val_losses, "orange", label="Validation")
    ax_loss.legend()
    ax_loss.grid()

    ax_metric_score.set_title("F1 Score")
    ax_metric_score.set_xlabel("Epoch")
    ax_metric_score.set_ylabel("Score")
    ax_metric_score.plot(epoch_training_metric_scores, "green", label="Training")
    ax_metric_score.plot(epoch_val_metric_scores, "orange", label="Validation")
    ax_metric_score.legend()
    ax_metric_score.grid()

    plt.savefig(f"{root_path}/training_plot.jpg", dpi=200)                        
    
    print("TRAINING SUMMARY")
    name_best_training_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_training_metric = f"Best {str(train_metric).split('(')[0]} validation".ljust(34)
    name_best_validation_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_validation_metric = f"Best {str(val_metric).split('(')[0]} validation".ljust(34)
    name_training_time = f"Training duration".ljust(34)
    name_training_date = f"Training date".ljust(34)
    
    print(f"{name_best_training_loss}: {best_training_loss:.4f}")
    print(f"{name_best_validation_loss}: {best_val_loss:.4f}")
    print(f"{name_best_training_metric}: {best_training_metric:.4f}")
    print(f"{name_best_validation_metric}: {best_val_metric:.4f}")
    print(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.")
    print(f"{name_training_date}: {now}")
    
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write("\nTRAINING SUMMARY\n")
        f.write(f"{'-' * 80}\n")
        f.write(f"{name_best_training_loss}: {best_training_loss:.4f}\n")
        f.write(f"{name_best_validation_loss}: {best_val_loss:.4f}\n")
        f.write(f"{name_best_training_metric}: {best_training_metric:.4f}\n")
        f.write(f"{name_best_validation_metric}: {best_val_metric:.4f}\n")
        f.write(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.\n")
        f.write(f"{name_training_date}: {now}\n")
    
    # Save epoch losses, epoch metric scores, model, state dict, and oov embedding dict
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_training_losses
    }).to_csv(f"{root_path}/training_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_training_metric_scores
    }).to_csv(f"{root_path}/training_metric_scores.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_val_losses
    }).to_csv(f"{root_path}/val_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_val_metric_scores
    }).to_csv(f"{root_path}/val_metric_scores.csv", index=False)    
    
    filename_model_params = f"{root_path}/model_params.pth"
    torch.save(best_state_dict, filename_model_params)
    
    return epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores

epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores = looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric)
# Out:
# EPOCH-1
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.5177 | MulticlassF1Score=0.0645
# Batch-30 : CrossEntropyLoss=2.4804 | MulticlassF1Score=0.1428
# Batch-45 : CrossEntropyLoss=2.4457 | MulticlassF1Score=0.1944
# Batch-60 : CrossEntropyLoss=2.3990 | MulticlassF1Score=0.2725
# Batch-75 : CrossEntropyLoss=2.3794 | MulticlassF1Score=0.3317
# Batch-90 : CrossEntropyLoss=2.3893 | MulticlassF1Score=0.3732
# Batch-105: CrossEntropyLoss=2.3701 | MulticlassF1Score=0.4046
# Batch-120: CrossEntropyLoss=2.3820 | MulticlassF1Score=0.4282
# Batch-135: CrossEntropyLoss=2.3404 | MulticlassF1Score=0.4529
# Batch-150: CrossEntropyLoss=2.3351 | MulticlassF1Score=0.4797
# Batch-165: CrossEntropyLoss=2.3308 | MulticlassF1Score=0.5027
# Batch-180: CrossEntropyLoss=2.3355 | MulticlassF1Score=0.5217
# Batch-195: CrossEntropyLoss=2.3246 | MulticlassF1Score=0.5386
# Batch-210: CrossEntropyLoss=2.3429 | MulticlassF1Score=0.5535
# Batch-225: CrossEntropyLoss=2.3271 | MulticlassF1Score=0.5650
# Batch-226: CrossEntropyLoss=2.3251 | MulticlassF1Score=0.5654
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3196 | MulticlassF1Score=0.7442
# Batch-30 : CrossEntropyLoss=2.3358 | MulticlassF1Score=0.7435
# Batch-45 : CrossEntropyLoss=2.3284 | MulticlassF1Score=0.7435
# Batch-60 : CrossEntropyLoss=2.3426 | MulticlassF1Score=0.7418
# Batch-63 : CrossEntropyLoss=2.3284 | MulticlassF1Score=0.7420
#
# Training   : Mean CrossEntropyLoss = 2.3948 | Mean MulticlassF1Score = 0.3755
# Validation : Mean CrossEntropyLoss = 2.3284 | Mean MulticlassF1Score = 0.7446
# ================================================================================
#
# EPOCH-2
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3273 | MulticlassF1Score=0.7381
# Batch-30 : CrossEntropyLoss=2.3154 | MulticlassF1Score=0.7441
# Batch-45 : CrossEntropyLoss=2.3116 | MulticlassF1Score=0.7581
# Batch-60 : CrossEntropyLoss=2.3147 | MulticlassF1Score=0.7626
# Batch-75 : CrossEntropyLoss=2.3113 | MulticlassF1Score=0.7668
# Batch-90 : CrossEntropyLoss=2.3133 | MulticlassF1Score=0.7713
# Batch-105: CrossEntropyLoss=2.3152 | MulticlassF1Score=0.7749
# Batch-120: CrossEntropyLoss=2.3121 | MulticlassF1Score=0.7768
# Batch-135: CrossEntropyLoss=2.3161 | MulticlassF1Score=0.7778
# Batch-150: CrossEntropyLoss=2.3190 | MulticlassF1Score=0.7791
# Batch-165: CrossEntropyLoss=2.3147 | MulticlassF1Score=0.7794
# Batch-180: CrossEntropyLoss=2.3151 | MulticlassF1Score=0.7801
# Batch-195: CrossEntropyLoss=2.3139 | MulticlassF1Score=0.7808
# Batch-210: CrossEntropyLoss=2.3020 | MulticlassF1Score=0.7814
# Batch-225: CrossEntropyLoss=2.3125 | MulticlassF1Score=0.7822
# Batch-226: CrossEntropyLoss=2.3315 | MulticlassF1Score=0.7821
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3076 | MulticlassF1Score=0.7974
# Batch-30 : CrossEntropyLoss=2.3240 | MulticlassF1Score=0.7947
# Batch-45 : CrossEntropyLoss=2.3157 | MulticlassF1Score=0.7925
# Batch-60 : CrossEntropyLoss=2.3059 | MulticlassF1Score=0.7915
# Batch-63 : CrossEntropyLoss=2.3220 | MulticlassF1Score=0.7917
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3163 | Mean MulticlassF1Score = 0.7691
# Validation : Mean CrossEntropyLoss = 2.3128 | Mean MulticlassF1Score = 0.7942
# ================================================================================
#
# EPOCH-3
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3089 | MulticlassF1Score=0.7910
# Batch-30 : CrossEntropyLoss=2.3061 | MulticlassF1Score=0.7910
# Batch-45 : CrossEntropyLoss=2.3056 | MulticlassF1Score=0.7940
# Batch-60 : CrossEntropyLoss=2.3162 | MulticlassF1Score=0.7945
# Batch-75 : CrossEntropyLoss=2.3047 | MulticlassF1Score=0.7968
# Batch-90 : CrossEntropyLoss=2.3154 | MulticlassF1Score=0.7986
# Batch-105: CrossEntropyLoss=2.3105 | MulticlassF1Score=0.7983
# Batch-120: CrossEntropyLoss=2.3036 | MulticlassF1Score=0.7989
# Batch-135: CrossEntropyLoss=2.3124 | MulticlassF1Score=0.7997
# Batch-150: CrossEntropyLoss=2.2921 | MulticlassF1Score=0.8000
# Batch-165: CrossEntropyLoss=2.3105 | MulticlassF1Score=0.8006
# Batch-180: CrossEntropyLoss=2.3107 | MulticlassF1Score=0.8010
# Batch-195: CrossEntropyLoss=2.3084 | MulticlassF1Score=0.8009
# Batch-210: CrossEntropyLoss=2.3304 | MulticlassF1Score=0.8012
# Batch-225: CrossEntropyLoss=2.3133 | MulticlassF1Score=0.8009
# Batch-226: CrossEntropyLoss=2.3145 | MulticlassF1Score=0.8009
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3171 | MulticlassF1Score=0.8070
# Batch-30 : CrossEntropyLoss=2.3076 | MulticlassF1Score=0.8074
# Batch-45 : CrossEntropyLoss=2.3120 | MulticlassF1Score=0.8049
# Batch-60 : CrossEntropyLoss=2.2984 | MulticlassF1Score=0.8063
# Batch-63 : CrossEntropyLoss=2.3024 | MulticlassF1Score=0.8051
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3097 | Mean MulticlassF1Score = 0.7980
# Validation : Mean CrossEntropyLoss = 2.3081 | Mean MulticlassF1Score = 0.8086
# ================================================================================
#
# EPOCH-4
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3077 | MulticlassF1Score=0.8075
# Batch-30 : CrossEntropyLoss=2.3069 | MulticlassF1Score=0.8039
# Batch-45 : CrossEntropyLoss=2.3104 | MulticlassF1Score=0.8060
# Batch-60 : CrossEntropyLoss=2.3096 | MulticlassF1Score=0.8052
# Batch-75 : CrossEntropyLoss=2.3097 | MulticlassF1Score=0.8065
# Batch-90 : CrossEntropyLoss=2.3030 | MulticlassF1Score=0.8070
# Batch-105: CrossEntropyLoss=2.3052 | MulticlassF1Score=0.8071
# Batch-120: CrossEntropyLoss=2.3059 | MulticlassF1Score=0.8061
# Batch-135: CrossEntropyLoss=2.2999 | MulticlassF1Score=0.8071
# Batch-150: CrossEntropyLoss=2.3074 | MulticlassF1Score=0.8073
# Batch-165: CrossEntropyLoss=2.3105 | MulticlassF1Score=0.8072
# Batch-180: CrossEntropyLoss=2.3004 | MulticlassF1Score=0.8077
# Batch-195: CrossEntropyLoss=2.3019 | MulticlassF1Score=0.8088
# Batch-210: CrossEntropyLoss=2.3030 | MulticlassF1Score=0.8099
# Batch-225: CrossEntropyLoss=2.3001 | MulticlassF1Score=0.8113
# Batch-226: CrossEntropyLoss=2.3013 | MulticlassF1Score=0.8113
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2928 | MulticlassF1Score=0.8293
# Batch-30 : CrossEntropyLoss=2.3061 | MulticlassF1Score=0.8276
# Batch-45 : CrossEntropyLoss=2.3077 | MulticlassF1Score=0.8256
# Batch-60 : CrossEntropyLoss=2.3029 | MulticlassF1Score=0.8252
# Batch-63 : CrossEntropyLoss=2.2973 | MulticlassF1Score=0.8255
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3063 | Mean MulticlassF1Score = 0.8073
# Validation : Mean CrossEntropyLoss = 2.3017 | Mean MulticlassF1Score = 0.8267
# ================================================================================
#
# EPOCH-5
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3024 | MulticlassF1Score=0.8274
# Batch-30 : CrossEntropyLoss=2.3001 | MulticlassF1Score=0.8307
# Batch-45 : CrossEntropyLoss=2.3010 | MulticlassF1Score=0.8305
# Batch-60 : CrossEntropyLoss=2.2970 | MulticlassF1Score=0.8320
# Batch-75 : CrossEntropyLoss=2.3140 | MulticlassF1Score=0.8310
# Batch-90 : CrossEntropyLoss=2.2930 | MulticlassF1Score=0.8336
# Batch-105: CrossEntropyLoss=2.3076 | MulticlassF1Score=0.8340
# Batch-120: CrossEntropyLoss=2.2912 | MulticlassF1Score=0.8346
# Batch-135: CrossEntropyLoss=2.2977 | MulticlassF1Score=0.8350
# Batch-150: CrossEntropyLoss=2.2977 | MulticlassF1Score=0.8349
# Batch-165: CrossEntropyLoss=2.2988 | MulticlassF1Score=0.8353
# Batch-180: CrossEntropyLoss=2.3060 | MulticlassF1Score=0.8352
# Batch-195: CrossEntropyLoss=2.3080 | MulticlassF1Score=0.8354
# Batch-210: CrossEntropyLoss=2.2991 | MulticlassF1Score=0.8347
# Batch-225: CrossEntropyLoss=2.3015 | MulticlassF1Score=0.8348
# Batch-226: CrossEntropyLoss=2.2992 | MulticlassF1Score=0.8347
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3007 | MulticlassF1Score=0.8326
# Batch-30 : CrossEntropyLoss=2.3079 | MulticlassF1Score=0.8337
# Batch-45 : CrossEntropyLoss=2.2988 | MulticlassF1Score=0.8345
# Batch-60 : CrossEntropyLoss=2.3026 | MulticlassF1Score=0.8352
# Batch-63 : CrossEntropyLoss=2.3016 | MulticlassF1Score=0.8353
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2990 | Mean MulticlassF1Score = 0.8329
# Validation : Mean CrossEntropyLoss = 2.2988 | Mean MulticlassF1Score = 0.8331
# ================================================================================
#
# EPOCH-6
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3007 | MulticlassF1Score=0.8356
# Batch-30 : CrossEntropyLoss=2.2969 | MulticlassF1Score=0.8381
# Batch-45 : CrossEntropyLoss=2.2903 | MulticlassF1Score=0.8375
# Batch-60 : CrossEntropyLoss=2.3018 | MulticlassF1Score=0.8372
# Batch-75 : CrossEntropyLoss=2.2996 | MulticlassF1Score=0.8381
# Batch-90 : CrossEntropyLoss=2.2963 | MulticlassF1Score=0.8387
# Batch-105: CrossEntropyLoss=2.2929 | MulticlassF1Score=0.8392
# Batch-120: CrossEntropyLoss=2.2899 | MulticlassF1Score=0.8392
# Batch-135: CrossEntropyLoss=2.3070 | MulticlassF1Score=0.8382
# Batch-150: CrossEntropyLoss=2.3058 | MulticlassF1Score=0.8384
# Batch-165: CrossEntropyLoss=2.2945 | MulticlassF1Score=0.8383
# Batch-180: CrossEntropyLoss=2.2932 | MulticlassF1Score=0.8386
# Batch-195: CrossEntropyLoss=2.2885 | MulticlassF1Score=0.8390
# Batch-210: CrossEntropyLoss=2.2967 | MulticlassF1Score=0.8392
# Batch-225: CrossEntropyLoss=2.3019 | MulticlassF1Score=0.8391
# Batch-226: CrossEntropyLoss=2.2979 | MulticlassF1Score=0.8391
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2998 | MulticlassF1Score=0.8412
# Batch-30 : CrossEntropyLoss=2.3056 | MulticlassF1Score=0.8359
# Batch-45 : CrossEntropyLoss=2.2961 | MulticlassF1Score=0.8355
# Batch-60 : CrossEntropyLoss=2.2874 | MulticlassF1Score=0.8371
# Batch-63 : CrossEntropyLoss=2.3004 | MulticlassF1Score=0.8370
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2976 | Mean MulticlassF1Score = 0.8378
# Validation : Mean CrossEntropyLoss = 2.2982 | Mean MulticlassF1Score = 0.8388
# ================================================================================
#
# EPOCH-7
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2942 | MulticlassF1Score=0.8415
# Batch-30 : CrossEntropyLoss=2.2933 | MulticlassF1Score=0.8422
# Batch-45 : CrossEntropyLoss=2.3000 | MulticlassF1Score=0.8420
# Batch-60 : CrossEntropyLoss=2.2876 | MulticlassF1Score=0.8420
# Batch-75 : CrossEntropyLoss=2.3091 | MulticlassF1Score=0.8409
# Batch-90 : CrossEntropyLoss=2.3037 | MulticlassF1Score=0.8397
# Batch-105: CrossEntropyLoss=2.2974 | MulticlassF1Score=0.8401
# Batch-120: CrossEntropyLoss=2.2923 | MulticlassF1Score=0.8403
# Batch-135: CrossEntropyLoss=2.2883 | MulticlassF1Score=0.8399
# Batch-150: CrossEntropyLoss=2.2966 | MulticlassF1Score=0.8395
# Batch-165: CrossEntropyLoss=2.2884 | MulticlassF1Score=0.8401
# Batch-180: CrossEntropyLoss=2.3005 | MulticlassF1Score=0.8411
# Batch-195: CrossEntropyLoss=2.2895 | MulticlassF1Score=0.8411
# Batch-210: CrossEntropyLoss=2.2945 | MulticlassF1Score=0.8412
# Batch-225: CrossEntropyLoss=2.3015 | MulticlassF1Score=0.8418
# Batch-226: CrossEntropyLoss=2.2951 | MulticlassF1Score=0.8418
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2949 | MulticlassF1Score=0.8482
# Batch-30 : CrossEntropyLoss=2.2917 | MulticlassF1Score=0.8505
# Batch-45 : CrossEntropyLoss=2.2940 | MulticlassF1Score=0.8499
# Batch-60 : CrossEntropyLoss=2.2966 | MulticlassF1Score=0.8495
# Batch-63 : CrossEntropyLoss=2.3046 | MulticlassF1Score=0.8494
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2967 | Mean MulticlassF1Score = 0.8407
# Validation : Mean CrossEntropyLoss = 2.2949 | Mean MulticlassF1Score = 0.8502
# ================================================================================
#
# EPOCH-8
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2912 | MulticlassF1Score=0.8548
# Batch-30 : CrossEntropyLoss=2.2897 | MulticlassF1Score=0.8618
# Batch-45 : CrossEntropyLoss=2.2875 | MulticlassF1Score=0.8680
# Batch-60 : CrossEntropyLoss=2.2830 | MulticlassF1Score=0.8700
# Batch-75 : CrossEntropyLoss=2.2850 | MulticlassF1Score=0.8720
# Batch-90 : CrossEntropyLoss=2.2806 | MulticlassF1Score=0.8739
# Batch-105: CrossEntropyLoss=2.2940 | MulticlassF1Score=0.8744
# Batch-120: CrossEntropyLoss=2.2831 | MulticlassF1Score=0.8761
# Batch-135: CrossEntropyLoss=2.2857 | MulticlassF1Score=0.8767
# Batch-150: CrossEntropyLoss=2.2864 | MulticlassF1Score=0.8771
# Batch-165: CrossEntropyLoss=2.2849 | MulticlassF1Score=0.8779
# Batch-180: CrossEntropyLoss=2.2881 | MulticlassF1Score=0.8788
# Batch-195: CrossEntropyLoss=2.2786 | MulticlassF1Score=0.8791
# Batch-210: CrossEntropyLoss=2.2855 | MulticlassF1Score=0.8793
# Batch-225: CrossEntropyLoss=2.2768 | MulticlassF1Score=0.8795
# Batch-226: CrossEntropyLoss=2.2883 | MulticlassF1Score=0.8795
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2881 | MulticlassF1Score=0.8791
# Batch-30 : CrossEntropyLoss=2.2745 | MulticlassF1Score=0.8797
# Batch-45 : CrossEntropyLoss=2.2874 | MulticlassF1Score=0.8799
# Batch-60 : CrossEntropyLoss=2.2826 | MulticlassF1Score=0.8817
# Batch-63 : CrossEntropyLoss=2.2893 | MulticlassF1Score=0.8816
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2855 | Mean MulticlassF1Score = 0.8722
# Validation : Mean CrossEntropyLoss = 2.2848 | Mean MulticlassF1Score = 0.8808
# ================================================================================
#
# EPOCH-9
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2846 | MulticlassF1Score=0.8908
# Batch-30 : CrossEntropyLoss=2.2781 | MulticlassF1Score=0.8874
# Batch-45 : CrossEntropyLoss=2.2843 | MulticlassF1Score=0.8873
# Batch-60 : CrossEntropyLoss=2.2909 | MulticlassF1Score=0.8877
# Batch-75 : CrossEntropyLoss=2.2900 | MulticlassF1Score=0.8872
# Batch-90 : CrossEntropyLoss=2.2802 | MulticlassF1Score=0.8881
# Batch-105: CrossEntropyLoss=2.2847 | MulticlassF1Score=0.8882
# Batch-120: CrossEntropyLoss=2.2860 | MulticlassF1Score=0.8881
# Batch-135: CrossEntropyLoss=2.2766 | MulticlassF1Score=0.8880
# Batch-150: CrossEntropyLoss=2.2744 | MulticlassF1Score=0.8895
# Batch-165: CrossEntropyLoss=2.2776 | MulticlassF1Score=0.8916
# Batch-180: CrossEntropyLoss=2.2791 | MulticlassF1Score=0.8934
# Batch-195: CrossEntropyLoss=2.2700 | MulticlassF1Score=0.8950
# Batch-210: CrossEntropyLoss=2.2763 | MulticlassF1Score=0.8960
# Batch-225: CrossEntropyLoss=2.2760 | MulticlassF1Score=0.8971
# Batch-226: CrossEntropyLoss=2.2823 | MulticlassF1Score=0.8972
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9097
# Batch-30 : CrossEntropyLoss=2.2759 | MulticlassF1Score=0.9067
# Batch-45 : CrossEntropyLoss=2.2816 | MulticlassF1Score=0.9079
# Batch-60 : CrossEntropyLoss=2.2769 | MulticlassF1Score=0.9088
# Batch-63 : CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9086
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2799 | Mean MulticlassF1Score = 0.8903
# Validation : Mean CrossEntropyLoss = 2.2765 | Mean MulticlassF1Score = 0.9094
# ================================================================================
#
# EPOCH-10
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2784 | MulticlassF1Score=0.9151
# Batch-30 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9150
# Batch-45 : CrossEntropyLoss=2.2769 | MulticlassF1Score=0.9144
# Batch-60 : CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9150
# Batch-75 : CrossEntropyLoss=2.2788 | MulticlassF1Score=0.9153
# Batch-90 : CrossEntropyLoss=2.2784 | MulticlassF1Score=0.9163
# Batch-105: CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9168
# Batch-120: CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9167
# Batch-135: CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9165
# Batch-150: CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9174
# Batch-165: CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9176
# Batch-180: CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9177
# Batch-195: CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9177
# Batch-210: CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9180
# Batch-225: CrossEntropyLoss=2.2779 | MulticlassF1Score=0.9178
# Batch-226: CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9179
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2792 | MulticlassF1Score=0.9112
# Batch-30 : CrossEntropyLoss=2.2759 | MulticlassF1Score=0.9116
# Batch-45 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9114
# Batch-60 : CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9122
# Batch-63 : CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9125
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2735 | Mean MulticlassF1Score = 0.9164
# Validation : Mean CrossEntropyLoss = 2.2750 | Mean MulticlassF1Score = 0.9131
# ================================================================================
#
# EPOCH-11
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9215
# Batch-30 : CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9237
# Batch-45 : CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9228
# Batch-60 : CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9217
# Batch-75 : CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9214
# Batch-90 : CrossEntropyLoss=2.2775 | MulticlassF1Score=0.9214
# Batch-105: CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9212
# Batch-120: CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9211
# Batch-135: CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9213
# Batch-150: CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9211
# Batch-165: CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9209
# Batch-180: CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9212
# Batch-195: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9213
# Batch-210: CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9211
# Batch-225: CrossEntropyLoss=2.2796 | MulticlassF1Score=0.9211
# Batch-226: CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9211
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9177
# Batch-30 : CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9161
# Batch-45 : CrossEntropyLoss=2.2771 | MulticlassF1Score=0.9152
# Batch-60 : CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9139
# Batch-63 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9139
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2724 | Mean MulticlassF1Score = 0.9214
# Validation : Mean CrossEntropyLoss = 2.2745 | Mean MulticlassF1Score = 0.9156
# ================================================================================
#
# EPOCH-12
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9243
# Batch-30 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9216
# Batch-45 : CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9230
# Batch-60 : CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9243
# Batch-75 : CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9241
# Batch-90 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9228
# Batch-105: CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9225
# Batch-120: CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9230
# Batch-135: CrossEntropyLoss=2.2756 | MulticlassF1Score=0.9228
# Batch-150: CrossEntropyLoss=2.2756 | MulticlassF1Score=0.9228
# Batch-165: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9230
# Batch-180: CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9228
# Batch-195: CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9232
# Batch-210: CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9232
# Batch-225: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9232
# Batch-226: CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9233
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2761 | MulticlassF1Score=0.9122
# Batch-30 : CrossEntropyLoss=2.2747 | MulticlassF1Score=0.9117
# Batch-45 : CrossEntropyLoss=2.2751 | MulticlassF1Score=0.9140
# Batch-60 : CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9139
# Batch-63 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9139
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2716 | Mean MulticlassF1Score = 0.9232
# Validation : Mean CrossEntropyLoss = 2.2744 | Mean MulticlassF1Score = 0.9133
# ================================================================================
#
# EPOCH-13
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9252
# Batch-30 : CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9228
# Batch-45 : CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9236
# Batch-60 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9238
# Batch-75 : CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9249
# Batch-90 : CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9250
# Batch-105: CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9244
# Batch-120: CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9247
# Batch-135: CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9251
# Batch-150: CrossEntropyLoss=2.2769 | MulticlassF1Score=0.9249
# Batch-165: CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9252
# Batch-180: CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9253
# Batch-195: CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9251
# Batch-210: CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9252
# Batch-225: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9252
# Batch-226: CrossEntropyLoss=2.2762 | MulticlassF1Score=0.9252
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2756 | MulticlassF1Score=0.9122
# Batch-30 : CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9111
# Batch-45 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9118
# Batch-60 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9144
# Batch-63 : CrossEntropyLoss=2.2775 | MulticlassF1Score=0.9144
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2710 | Mean MulticlassF1Score = 0.9249
# Validation : Mean CrossEntropyLoss = 2.2743 | Mean MulticlassF1Score = 0.9124
# ================================================================================
#
# EPOCH-14
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9245
# Batch-30 : CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9262
# Batch-45 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9264
# Batch-60 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9265
# Batch-75 : CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9269
# Batch-90 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9265
# Batch-105: CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9262
# Batch-120: CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9261
# Batch-135: CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9262
# Batch-150: CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9259
# Batch-165: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9261
# Batch-180: CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9260
# Batch-195: CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9262
# Batch-210: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9263
# Batch-225: CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9261
# Batch-226: CrossEntropyLoss=2.2781 | MulticlassF1Score=0.9260
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2769 | MulticlassF1Score=0.9164
# Batch-30 : CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9166
# Batch-45 : CrossEntropyLoss=2.2764 | MulticlassF1Score=0.9157
# Batch-60 : CrossEntropyLoss=2.2809 | MulticlassF1Score=0.9147
# Batch-63 : CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9143
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2706 | Mean MulticlassF1Score = 0.9260
# Validation : Mean CrossEntropyLoss = 2.2741 | Mean MulticlassF1Score = 0.9160
# ================================================================================
#
# EPOCH-15
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9266
# Batch-30 : CrossEntropyLoss=2.2790 | MulticlassF1Score=0.9277
# Batch-45 : CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9286
# Batch-60 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9274
# Batch-75 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9271
# Batch-90 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9279
# Batch-105: CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9277
# Batch-120: CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9278
# Batch-135: CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9276
# Batch-150: CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9277
# Batch-165: CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9277
# Batch-180: CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9278
# Batch-195: CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9280
# Batch-210: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9282
# Batch-225: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9283
# Batch-226: CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9283
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2751 | MulticlassF1Score=0.9200
# Batch-30 : CrossEntropyLoss=2.2778 | MulticlassF1Score=0.9176
# Batch-45 : CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9203
# Batch-60 : CrossEntropyLoss=2.2765 | MulticlassF1Score=0.9189
# Batch-63 : CrossEntropyLoss=2.2858 | MulticlassF1Score=0.9189
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2699 | Mean MulticlassF1Score = 0.9276
# Validation : Mean CrossEntropyLoss = 2.2729 | Mean MulticlassF1Score = 0.9191
# ================================================================================
#
# EPOCH-16
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9303
# Batch-30 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9301
# Batch-45 : CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9309
# Batch-60 : CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9318
# Batch-75 : CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9320
# Batch-90 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9322
# Batch-105: CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9319
# Batch-120: CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9319
# Batch-135: CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9319
# Batch-150: CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9324
# Batch-165: CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9324
# Batch-180: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9326
# Batch-195: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9323
# Batch-210: CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9323
# Batch-225: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9321
# Batch-226: CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9321
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2786 | MulticlassF1Score=0.9226
# Batch-30 : CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9192
# Batch-45 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9198
# Batch-60 : CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9196
# Batch-63 : CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9201
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2687 | Mean MulticlassF1Score = 0.9320
# Validation : Mean CrossEntropyLoss = 2.2724 | Mean MulticlassF1Score = 0.9208
# ================================================================================
#
# EPOCH-17
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9372
# Batch-30 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9354
# Batch-45 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9358
# Batch-60 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9356
# Batch-75 : CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9350
# Batch-90 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9352
# Batch-105: CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9351
# Batch-120: CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9345
# Batch-135: CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9339
# Batch-150: CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9339
# Batch-165: CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9338
# Batch-180: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9339
# Batch-195: CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9339
# Batch-210: CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9338
# Batch-225: CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9336
# Batch-226: CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9336
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9218
# Batch-30 : CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9196
# Batch-45 : CrossEntropyLoss=2.2766 | MulticlassF1Score=0.9190
# Batch-60 : CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9192
# Batch-63 : CrossEntropyLoss=2.2801 | MulticlassF1Score=0.9190
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2682 | Mean MulticlassF1Score = 0.9346
# Validation : Mean CrossEntropyLoss = 2.2728 | Mean MulticlassF1Score = 0.9193
# ================================================================================
#
# EPOCH-18
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9327
# Batch-30 : CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9353
# Batch-45 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9350
# Batch-60 : CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9349
# Batch-75 : CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9361
# Batch-90 : CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9359
# Batch-105: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9354
# Batch-120: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9349
# Batch-135: CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9347
# Batch-150: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9347
# Batch-165: CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9346
# Batch-180: CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9346
# Batch-195: CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9347
# Batch-210: CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9344
# Batch-225: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9346
# Batch-226: CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9345
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9253
# Batch-30 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9208
# Batch-45 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9206
# Batch-60 : CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9201
# Batch-63 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9203
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2679 | Mean MulticlassF1Score = 0.9349
# Validation : Mean CrossEntropyLoss = 2.2723 | Mean MulticlassF1Score = 0.9231
# ================================================================================
#
# EPOCH-19
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9333
# Batch-30 : CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9351
# Batch-45 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9353
# Batch-60 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9349
# Batch-75 : CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9345
# Batch-90 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9340
# Batch-105: CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9343
# Batch-120: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9348
# Batch-135: CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9346
# Batch-150: CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9349
# Batch-165: CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9350
# Batch-180: CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9354
# Batch-195: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9353
# Batch-210: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9355
# Batch-225: CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9353
# Batch-226: CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9354
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9192
# Batch-30 : CrossEntropyLoss=2.2751 | MulticlassF1Score=0.9187
# Batch-45 : CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9178
# Batch-60 : CrossEntropyLoss=2.2761 | MulticlassF1Score=0.9196
# Batch-63 : CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9201
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2676 | Mean MulticlassF1Score = 0.9349
# Validation : Mean CrossEntropyLoss = 2.2723 | Mean MulticlassF1Score = 0.9187
# ================================================================================
#
# EPOCH-20
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9383
# Batch-30 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9380
# Batch-45 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9371
# Batch-60 : CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9368
# Batch-75 : CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9366
# Batch-90 : CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9363
# Batch-105: CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9363
# Batch-120: CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9360
# Batch-135: CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9360
# Batch-150: CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9364
# Batch-165: CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9363
# Batch-180: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9360
# Batch-195: CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9364
# Batch-210: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9364
# Batch-225: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9364
# Batch-226: CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9364
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2823 | MulticlassF1Score=0.9185
# Batch-30 : CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9202
# Batch-45 : CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9202
# Batch-60 : CrossEntropyLoss=2.2772 | MulticlassF1Score=0.9205
# Batch-63 : CrossEntropyLoss=2.2772 | MulticlassF1Score=0.9203
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2672 | Mean MulticlassF1Score = 0.9370
# Validation : Mean CrossEntropyLoss = 2.2723 | Mean MulticlassF1Score = 0.9199
# ================================================================================
#
# EPOCH-21
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9349
# Batch-30 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9377
# Batch-45 : CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9379
# Batch-60 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9368
# Batch-75 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9381
# Batch-90 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9375
# Batch-105: CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9373
# Batch-120: CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9377
# Batch-135: CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9371
# Batch-150: CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9371
# Batch-165: CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9371
# Batch-180: CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9370
# Batch-195: CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9370
# Batch-210: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9371
# Batch-225: CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9371
# Batch-226: CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9371
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2758 | MulticlassF1Score=0.9180
# Batch-30 : CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9206
# Batch-45 : CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9214
# Batch-60 : CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9207
# Batch-63 : CrossEntropyLoss=2.2747 | MulticlassF1Score=0.9210
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2670 | Mean MulticlassF1Score = 0.9369
# Validation : Mean CrossEntropyLoss = 2.2721 | Mean MulticlassF1Score = 0.9202
# ================================================================================
#
# EPOCH-22
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9392
# Batch-30 : CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9376
# Batch-45 : CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9374
# Batch-60 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9376
# Batch-75 : CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9376
# Batch-90 : CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9378
# Batch-105: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9382
# Batch-120: CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9384
# Batch-135: CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9386
# Batch-150: CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9386
# Batch-165: CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9386
# Batch-180: CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9383
# Batch-195: CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9380
# Batch-210: CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9380
# Batch-225: CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9380
# Batch-226: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9381
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9296
# Batch-30 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9254
# Batch-45 : CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9230
# Batch-60 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9229
# Batch-63 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9235
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2667 | Mean MulticlassF1Score = 0.9382
# Validation : Mean CrossEntropyLoss = 2.2713 | Mean MulticlassF1Score = 0.9264
# ================================================================================
#
# EPOCH-23
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9432
# Batch-30 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9432
# Batch-45 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9417
# Batch-60 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9413
# Batch-75 : CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9411
# Batch-90 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9410
# Batch-105: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9410
# Batch-120: CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9414
# Batch-135: CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9417
# Batch-150: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9415
# Batch-165: CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9416
# Batch-180: CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9414
# Batch-195: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9413
# Batch-210: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9410
# Batch-225: CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9409
# Batch-226: CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9409
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2774 | MulticlassF1Score=0.9225
# Batch-30 : CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9243
# Batch-45 : CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9239
# Batch-60 : CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9241
# Batch-63 : CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9238
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2658 | Mean MulticlassF1Score = 0.9416
# Validation : Mean CrossEntropyLoss = 2.2712 | Mean MulticlassF1Score = 0.9237
# ================================================================================
#
# EPOCH-24
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9460
# Batch-30 : CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9449
# Batch-45 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9443
# Batch-60 : CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9431
# Batch-75 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9423
# Batch-90 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9416
# Batch-105: CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9414
# Batch-120: CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9416
# Batch-135: CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9415
# Batch-150: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9415
# Batch-165: CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9413
# Batch-180: CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9414
# Batch-195: CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9414
# Batch-210: CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9414
# Batch-225: CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9414
# Batch-226: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9414
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9252
# Batch-30 : CrossEntropyLoss=2.2781 | MulticlassF1Score=0.9234
# Batch-45 : CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9224
# Batch-60 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9241
# Batch-63 : CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9240
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2656 | Mean MulticlassF1Score = 0.9425
# Validation : Mean CrossEntropyLoss = 2.2711 | Mean MulticlassF1Score = 0.9240
# ================================================================================
#
# EPOCH-25
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9393
# Batch-30 : CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9415
# Batch-45 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9421
# Batch-60 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9413
# Batch-75 : CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9415
# Batch-90 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9423
# Batch-105: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9416
# Batch-120: CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9419
# Batch-135: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9417
# Batch-150: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9416
# Batch-165: CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9419
# Batch-180: CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9421
# Batch-195: CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9420
# Batch-210: CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9421
# Batch-225: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9417
# Batch-226: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9417
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9220
# Batch-30 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9219
# Batch-45 : CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9241
# Batch-60 : CrossEntropyLoss=2.2761 | MulticlassF1Score=0.9241
# Batch-63 : CrossEntropyLoss=2.2773 | MulticlassF1Score=0.9243
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2655 | Mean MulticlassF1Score = 0.9417
# Validation : Mean CrossEntropyLoss = 2.2709 | Mean MulticlassF1Score = 0.9228
# ================================================================================
#
# EPOCH-26
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9461
# Batch-30 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9432
# Batch-45 : CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9421
# Batch-60 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9415
# Batch-75 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9421
# Batch-90 : CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9421
# Batch-105: CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9418
# Batch-120: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9419
# Batch-135: CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9418
# Batch-150: CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9416
# Batch-165: CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9417
# Batch-180: CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9419
# Batch-195: CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9421
# Batch-210: CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9422
# Batch-225: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9419
# Batch-226: CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9420
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2756 | MulticlassF1Score=0.9206
# Batch-30 : CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9223
# Batch-45 : CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9245
# Batch-60 : CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9242
# Batch-63 : CrossEntropyLoss=2.2764 | MulticlassF1Score=0.9244
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2654 | Mean MulticlassF1Score = 0.9426
# Validation : Mean CrossEntropyLoss = 2.2710 | Mean MulticlassF1Score = 0.9231
# ================================================================================
#
# EPOCH-27
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9410
# Batch-30 : CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9404
# Batch-45 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9394
# Batch-60 : CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9397
# Batch-75 : CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9410
# Batch-90 : CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9407
# Batch-105: CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9406
# Batch-120: CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9405
# Batch-135: CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9411
# Batch-150: CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9411
# Batch-165: CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9413
# Batch-180: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9416
# Batch-195: CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9417
# Batch-210: CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9418
# Batch-225: CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9417
# Batch-226: CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9418
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9268
# Batch-30 : CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9232
# Batch-45 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9231
# Batch-60 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9238
# Batch-63 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9240
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2655 | Mean MulticlassF1Score = 0.9410
# Validation : Mean CrossEntropyLoss = 2.2711 | Mean MulticlassF1Score = 0.9244
# Patience = 1/50❗
# ================================================================================
#
# EPOCH-28
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9406
# Batch-30 : CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9406
# Batch-45 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9407
# Batch-60 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9406
# Batch-75 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9410
# Batch-90 : CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9416
# Batch-105: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9417
# Batch-120: CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9418
# Batch-135: CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9420
# Batch-150: CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9422
# Batch-165: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9424
# Batch-180: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9424
# Batch-195: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9423
# Batch-210: CrossEntropyLoss=2.2597 | MulticlassF1Score=0.9426
# Batch-225: CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9429
# Batch-226: CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9429
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9245
# Batch-30 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9249
# Batch-45 : CrossEntropyLoss=2.2776 | MulticlassF1Score=0.9238
# Batch-60 : CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9252
# Batch-63 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9250
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2651 | Mean MulticlassF1Score = 0.9417
# Validation : Mean CrossEntropyLoss = 2.2706 | Mean MulticlassF1Score = 0.9238
# ================================================================================
#
# EPOCH-29
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9444
# Batch-30 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9446
# Batch-45 : CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9449
# Batch-60 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9442
# Batch-75 : CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9436
# Batch-90 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9432
# Batch-105: CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9434
# Batch-120: CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9436
# Batch-135: CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9433
# Batch-150: CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9430
# Batch-165: CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9436
# Batch-180: CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9438
# ...
# Batch-45 : CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9474
# Batch-60 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9468
# Batch-63 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9466
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2573 | Mean MulticlassF1Score = 0.9680
# Validation : Mean CrossEntropyLoss = 2.2641 | Mean MulticlassF1Score = 0.9474
# ================================================================================
#
# EPOCH-42
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9679
# Batch-30 : CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9684
# Batch-45 : CrossEntropyLoss=2.2612 | MulticlassF1Score=0.9675
# Batch-60 : CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9679
# Batch-75 : CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9680
# Batch-90 : CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9684
# Batch-105: CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9685
# Batch-120: CrossEntropyLoss=2.2597 | MulticlassF1Score=0.9687
# Batch-135: CrossEntropyLoss=2.2529 | MulticlassF1Score=0.9686
# Batch-150: CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9684
# Batch-165: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9684
# Batch-180: CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9685
# Batch-195: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9685
# Batch-210: CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9684
# Batch-225: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9683
# Batch-226: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9682
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9461
# Batch-30 : CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9461
# Batch-45 : CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9465
# Batch-60 : CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9466
# Batch-63 : CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9464
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2572 | Mean MulticlassF1Score = 0.9684
# Validation : Mean CrossEntropyLoss = 2.2641 | Mean MulticlassF1Score = 0.9457
# ================================================================================
#
# EPOCH-43
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9663
# Batch-30 : CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9673
# Batch-45 : CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9676
# Batch-60 : CrossEntropyLoss=2.2532 | MulticlassF1Score=0.9671
# Batch-75 : CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9679
# Batch-90 : CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9677
# Batch-105: CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9678
# Batch-120: CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9674
# Batch-135: CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9677
# Batch-150: CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9678
# Batch-165: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9680
# Batch-180: CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9679
# Batch-195: CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9681
# Batch-210: CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9681
# Batch-225: CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9683
# Batch-226: CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9683
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9463
# Batch-30 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9486
# Batch-45 : CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9481
# Batch-60 : CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9465
# Batch-63 : CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9465
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2572 | Mean MulticlassF1Score = 0.9674
# Validation : Mean CrossEntropyLoss = 2.2641 | Mean MulticlassF1Score = 0.9468
# ================================================================================
#
# EPOCH-44
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9667
# Batch-30 : CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9665
# Batch-45 : CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9664
# Batch-60 : CrossEntropyLoss=2.2527 | MulticlassF1Score=0.9671
# Batch-75 : CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9677
# Batch-90 : CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9679
# Batch-105: CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9677
# Batch-120: CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9676
# Batch-135: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9679
# Batch-150: CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9683
# Batch-165: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9685
# Batch-180: CrossEntropyLoss=2.2589 | MulticlassF1Score=0.9687
# Batch-195: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9689
# Batch-210: CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9686
# Batch-225: CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9687
# Batch-226: CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9687
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9491
# Batch-30 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9465
# Batch-45 : CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9463
# Batch-60 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9471
# Batch-63 : CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9473
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2571 | Mean MulticlassF1Score = 0.9677
# Validation : Mean CrossEntropyLoss = 2.2639 | Mean MulticlassF1Score = 0.9471
# ================================================================================
#
# EPOCH-45
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9717
# Batch-30 : CrossEntropyLoss=2.2535 | MulticlassF1Score=0.9700
# Batch-45 : CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9692
# Batch-60 : CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9677
# Batch-75 : CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9669
# Batch-90 : CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9669
# Batch-105: CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9668
# Batch-120: CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9667
# Batch-135: CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9664
# Batch-150: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9665
# Batch-165: CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9664
# Batch-180: CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9662
# Batch-195: CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9664
# Batch-210: CrossEntropyLoss=2.2543 | MulticlassF1Score=0.9664
# Batch-225: CrossEntropyLoss=2.2603 | MulticlassF1Score=0.9663
# Batch-226: CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9663
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9446
# Batch-30 : CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9449
# Batch-45 : CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9458
# Batch-60 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9460
# Batch-63 : CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9462
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2580 | Mean MulticlassF1Score = 0.9676
# Validation : Mean CrossEntropyLoss = 2.2642 | Mean MulticlassF1Score = 0.9451
# Patience = 3/50❗
# ================================================================================
#
# EPOCH-46
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9666
# Batch-30 : CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9660
# Batch-45 : CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9664
# Batch-60 : CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9668
# Batch-75 : CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9676
# Batch-90 : CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9680
# Batch-105: CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9678
# Batch-120: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9675
# Batch-135: CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9673
# Batch-150: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9674
# Batch-165: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9673
# Batch-180: CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9672
# Batch-195: CrossEntropyLoss=2.2551 | MulticlassF1Score=0.9673
# Batch-210: CrossEntropyLoss=2.2542 | MulticlassF1Score=0.9673
# Batch-225: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9674
# Batch-226: CrossEntropyLoss=2.2529 | MulticlassF1Score=0.9674
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9471
# Batch-30 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9465
# Batch-45 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9469
# Batch-60 : CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9464
# Batch-63 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9461
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2575 | Mean MulticlassF1Score = 0.9671
# Validation : Mean CrossEntropyLoss = 2.2642 | Mean MulticlassF1Score = 0.9463
# ================================================================================
#
# EPOCH-47
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2543 | MulticlassF1Score=0.9674
# Batch-30 : CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9681
# Batch-45 : CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9679
# Batch-60 : CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9679
# Batch-75 : CrossEntropyLoss=2.2540 | MulticlassF1Score=0.9683
# Batch-90 : CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9686
# Batch-105: CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9685
# Batch-120: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9686
# Batch-135: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9689
# Batch-150: CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9690
# Batch-165: CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9688
# Batch-180: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9685
# Batch-195: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9683
# Batch-210: CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9684
# Batch-225: CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9685
# Batch-226: CrossEntropyLoss=2.2603 | MulticlassF1Score=0.9685
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9473
# Batch-30 : CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9483
# Batch-45 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9472
# Batch-60 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9472
# Batch-63 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9470
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2572 | Mean MulticlassF1Score = 0.9682
# Validation : Mean CrossEntropyLoss = 2.2639 | Mean MulticlassF1Score = 0.9482
# ================================================================================
#
# EPOCH-48
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9730
# Batch-30 : CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9721
# Batch-45 : CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9715
# Batch-60 : CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9710
# Batch-75 : CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9707
# Batch-90 : CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9708
# Batch-105: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9710
# Batch-120: CrossEntropyLoss=2.2535 | MulticlassF1Score=0.9710
# Batch-135: CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9710
# Batch-150: CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9708
# Batch-165: CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9705
# Batch-180: CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9705
# Batch-195: CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9706
# Batch-210: CrossEntropyLoss=2.2589 | MulticlassF1Score=0.9706
# Batch-225: CrossEntropyLoss=2.2589 | MulticlassF1Score=0.9704
# Batch-226: CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9704
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9461
# Batch-30 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9463
# Batch-45 : CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9466
# Batch-60 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9474
# Batch-63 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9476
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2566 | Mean MulticlassF1Score = 0.9710
# Validation : Mean CrossEntropyLoss = 2.2638 | Mean MulticlassF1Score = 0.9468
# ================================================================================
#
# EPOCH-49
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9673
# Batch-30 : CrossEntropyLoss=2.2533 | MulticlassF1Score=0.9695
# Batch-45 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9705
# Batch-60 : CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9710
# Batch-75 : CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9711
# Batch-90 : CrossEntropyLoss=2.2533 | MulticlassF1Score=0.9712
# Batch-105: CrossEntropyLoss=2.2543 | MulticlassF1Score=0.9712
# Batch-120: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9711
# Batch-135: CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9712
# Batch-150: CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9713
# Batch-165: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9714
# Batch-180: CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9713
# Batch-195: CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9713
# Batch-210: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9713
# Batch-225: CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9711
# Batch-226: CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9711
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9485
# Batch-30 : CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9485
# Batch-45 : CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9479
# Batch-60 : CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9484
# Batch-63 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9482
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2563 | Mean MulticlassF1Score = 0.9709
# Validation : Mean CrossEntropyLoss = 2.2634 | Mean MulticlassF1Score = 0.9484
# ================================================================================
#
# EPOCH-50
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9721
# Batch-30 : CrossEntropyLoss=2.2534 | MulticlassF1Score=0.9724
# Batch-45 : CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9722
# Batch-60 : CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9710
# Batch-75 : CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9708
# Batch-90 : CrossEntropyLoss=2.2530 | MulticlassF1Score=0.9713
# Batch-105: CrossEntropyLoss=2.2533 | MulticlassF1Score=0.9715
# Batch-120: CrossEntropyLoss=2.2547 | MulticlassF1Score=0.9715
# Batch-135: CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9714
# Batch-150: CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9715
# Batch-165: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9716
# Batch-180: CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9715
# Batch-195: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9715
# Batch-210: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9715
# Batch-225: CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9716
# Batch-226: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9716
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9482
# Batch-30 : CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9474
# Batch-45 : CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9478
# Batch-60 : CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9474
# Batch-63 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9475
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2561 | Mean MulticlassF1Score = 0.9714
# Validation : Mean CrossEntropyLoss = 2.2637 | Mean MulticlassF1Score = 0.9477
# ================================================================================
#
# TRAINING SUMMARY
# Best CrossEntropyLoss training    : 2.2561
# Best CrossEntropyLoss training    : 2.2637
# Best MulticlassF1Score validation : 0.9714
# Best MulticlassF1Score validation : 0.9477
# Training duration                 : 2.8280 minutes.
# Training date                     : 2022-10-19 13:58:08.555251+08:00

# %% [markdown]
# ## End Training

# %% [markdown]
# # Evaluation

# %%
def evaluation(dataloader, model, criterion, metric):
    model.eval()
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)
            pred = rearrange(prob.argmax(dim=1).reshape(feature.shape[0], len(dataloader.dataset)), "s n -> n s")

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob.argmax(dim=1), actual_label.to(hyperparams.device))
            metric_score = metric.compute()

    return loss, metric_score, pred

train_dataloader = DataLoader(train_dataset, batch_size=len(train_dataset))
val_dataloader = DataLoader(val_dataset, batch_size=len(val_dataset))
test_dataloader = DataLoader(test_dataset, batch_size=len(test_dataset))

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
train_loss, train_f1_score, train_pred_label = evaluation(train_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_loss, val_f1_score, val_pred_label = evaluation(val_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
test_loss, test_f1_score, test_pred_label = evaluation(test_dataloader, model, criterion, metric)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9719, device='cuda:0'),
#  tensor(0.9475, device='cuda:0'),
#  tensor(0.9495, device='cuda:0'))

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9719, device='cuda:0'),
#  tensor(0.9475, device='cuda:0'),
#  tensor(0.9495, device='cuda:0'))

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns

def viz_evaluation(pred_label, actual_label, title):
    plt.figure(figsize=(15, 7), dpi=200)
    sns.heatmap(pred_label.detach().cpu() == actual_label, cbar=True, cmap="binary_r")
    plt.xlabel("Sentence Length")
    plt.ylabel("Sentence")
    plt.title(title)
    plt.savefig(f"{root_path}/heatmap_{title.lower()}.jpg", dpi=200)
    plt.show()

train_actual_label = train_dataloader.dataset.tensors[1]
val_actual_label = val_dataloader.dataset.tensors[1]
test_actual_label = test_dataloader.dataset.tensors[1]

viz_evaluation(train_pred_label, train_actual_label, f"Training (F1-Score: {(train_f1_score):.4f})")
viz_evaluation(val_pred_label, val_actual_label, f"Validation (F1-Score: {(val_f1_score):.4f})")
viz_evaluation(test_pred_label, test_actual_label, f"Test (F1-Score: {(test_f1_score):.4f})")

# %% [markdown]
# ## Confusion Matrix

# %%
def confusion_matrix(pred_class, actual_class, title, normalize=None):
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize=normalize)
    plt.figure(figsize=(20, 10), dpi=200)
    sns.heatmap(conf_mat(pred_class.detach().cpu(), actual_class), annot=True, fmt=".2g", xticklabels=list(label_to_idx.keys()), yticklabels=list(label_to_idx.keys()));
    plt.yticks(rotation=0)
    plt.title(title)
    plt.xlabel("Actual Class")
    plt.ylabel("Predict Class")
    plt.savefig(f"{root_path}/conf_matrix_{title.lower()}.jpg", dpi=200)

confusion_matrix(train_pred_label, train_actual_label, "Training", "pred")
confusion_matrix(val_pred_label,val_actual_label, "Validation", "pred")
confusion_matrix(test_pred_label, test_actual_label, "Test", "pred")
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 96 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 120 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)

# %% [markdown]
# ## Prediction Table

# %%
def number_wrong_pred_each_class(pred_class, actual_class):
    classes, count_class = actual_class.flatten().unique(return_counts=True)
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize="none")
    correct_pred_count_class = conf_mat(pred_class.detach().cpu(), actual_class).diag()
    
    correct_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (correct_pred_count_class))}
    wrong_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (count_class - correct_pred_count_class))}
    
    return correct_pred, wrong_pred

correct_pred, wrong_pred = number_wrong_pred_each_class(train_pred_label, train_actual_label)
print(f"| {'Number class'.ljust(14)} | {'Correct prediction'.ljust(12)} | {'Wrong prediction'.ljust(12)} |")
for (label_correct_pred, count_correct_pred), (label_wrong_pred, count_wrong_pred) in zip(correct_pred.items(), wrong_pred.items()):
    print(f"| {str(label_correct_pred).ljust(6)}: {str(count_correct_pred + count_wrong_pred).ljust(7)}| {label_correct_pred.ljust(6)}: {str(count_correct_pred).ljust(10)} | {label_wrong_pred.ljust(6)}: {str(count_wrong_pred).ljust(8)} |")
# Out:
# | Number class   | Correct prediction | Wrong prediction |
# | CC    : 5336   | CC    : 5210       | CC    : 126      |
# | CD    : 12904  | CD    : 12744      | CD    : 160      |
# | DT    : 263    | DT    : 0          | DT    : 263      |
# | FW    : 1697   | FW    : 1435       | FW    : 262      |
# | IN    : 15290  | IN    : 15163      | IN    : 127      |
# | JJ    : 7049   | JJ    : 6746       | JJ    : 303      |
# | MD    : 3783   | MD    : 3761       | MD    : 22       |
# | NEG   : 1126   | NEG   : 0          | NEG   : 1126     |
# | NN    : 44769  | NN    : 44183      | NN    : 586      |
# | NND   : 998    | NND   : 925        | NND   : 73       |
# | NNP   : 24884  | NNP   : 24388      | NNP   : 496      |
# | OD    : 550    | OD    : 393        | OD    : 157      |
# | PR    : 3878   | PR    : 3841       | PR    : 37       |
# | PRP   : 5355   | PRP   : 5290       | PRP   : 65       |
# | RB    : 3517   | RB    : 3353       | RB    : 164      |
# | RP    : 131    | RP    : 0          | RP    : 131      |
# | SC    : 9467   | SC    : 9228       | SC    : 239      |
# | SYM   : 1570   | SYM   : 1505       | SYM   : 65       |
# | UH    : 21     | UH    : 0          | UH    : 21       |
# | VB    : 22796  | VB    : 22485      | VB    : 311      |
# | WH    : 180    | WH    : 0          | WH    : 180      |
# | X     : 282    | X     : 8          | X     : 274      |
# | Z     : 18940  | Z     : 18938      | Z     : 2        |
# | <PAD> : 407418 | <PAD> : 407418     | <PAD> : 0        |

# %%
train_actual_label[308], train_pred_label[308]
# Out:
# (tensor([ 8, 19, 22, 10, 22, 19, 10,  6, 19,  4,  1,  8, 16, 19,  8, 19,  0,  8,
#           5, 16, 19, 19,  8,  8, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23]),
#  tensor([ 8, 19, 22, 10, 22, 19, 10,  6, 19,  4,  1,  8, 16, 19,  8, 19,  0,  8,
#           5, 16, 19, 19,  8,  8, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23], device='cuda:0'))

# %%
train_actual_label[308] == train_pred_label[308].detach().cpu()
# Out:
# tensor([True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True])

# %% [markdown]
# ## OOV prediction is correct

# %%
def oov_flag_token(sentences, max_seq_len=hyperparams.max_seq_len):
    sent_copy = deepcopy(sentences)
    sent = []
    oov_flag = []
    
    for sentence in tqdm(sent_copy):
        for token in sentence:
            sent.append(token[2])
        
        for _ in range(max_seq_len- len(sentence)):
            sent.append(False)
        
        oov_flag.append(sent)
        sent = []
        
    return np.array(oov_flag)

train_oov_flag = oov_flag_token(train_sentences, max_seq_len=hyperparams.max_seq_len)
val_oov_flag = oov_flag_token(val_sentences, max_seq_len=hyperparams.max_seq_len)
test_oov_flag = oov_flag_token(test_sentences, max_seq_len=hyperparams.max_seq_len)

def pencentage_oov_pred_correct(pred_oov_flag, oov_flag_tensor):
    oov_correct_counter = 0
    oov_wrong_counter = 0

    for pred, oov_label in tqdm(zip(pred_oov_flag, oov_flag_tensor)):
        if pred == True and oov_label == True:
            oov_correct_counter += 1
        elif pred == False and oov_label == True:
            oov_wrong_counter += 1
        else:
            continue
            
    return oov_correct_counter, oov_wrong_counter

train_pred_oov_flag = (train_actual_label == train_pred_label.detach().cpu()).flatten()
val_pred_oov_flag = (val_actual_label == val_pred_label.detach().cpu()).flatten()
test_pred_oov_flag = (test_actual_label == test_pred_label.detach().cpu()).flatten()
train_oov_flag_tensor = torch.tensor(train_oov_flag).flatten()
val_oov_flag_tensor = torch.tensor(val_oov_flag).flatten()
test_oov_flag_tensor = torch.tensor(test_oov_flag).flatten()

train_oov_correct_counter, train_oov_wrong_counter = pencentage_oov_pred_correct(train_pred_oov_flag, train_oov_flag_tensor)
val_oov_correct_counter, val_oov_wrong_counter = pencentage_oov_pred_correct(val_pred_oov_flag, val_oov_flag_tensor)
test_oov_correct_counter, test_oov_wrong_counter = pencentage_oov_pred_correct(test_pred_oov_flag, test_oov_flag_tensor)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
def print_percentage_pred_oov(title, oov_correct_counter, oov_wrong_counter):
    print(f"{title}")
    print(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}")
    print(f"Correct prediction          : {oov_correct_counter}")
    print(f"Wrong prediction            : {oov_wrong_counter}")
    print(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n")
    
    with open(f"{root_path}/oov_summary.txt", "a") as f:
        f.write(f"{title}\n")
        f.write(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}\n")
        f.write(f"Correct prediction          : {oov_correct_counter}\n")
        f.write(f"Wrong prediction            : {oov_wrong_counter}\n")
        f.write(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n\n")

# %%
print_percentage_pred_oov("Training", train_oov_correct_counter, train_oov_wrong_counter)
print_percentage_pred_oov("Validation", val_oov_correct_counter, val_oov_wrong_counter)
print_percentage_pred_oov("Test", test_oov_correct_counter, test_oov_wrong_counter)
# Out:
# Training
# Number OOV token            : 11934
# Correct prediction          : 11237
# Wrong prediction            : 697
# Percentage correct oov pred : 94.15954415954417
#
# Validation
# Number OOV token            : 3261
# Correct prediction          : 2920
# Wrong prediction            : 341
# Percentage correct oov pred : 89.54308494326894
#
# Test
# Number OOV token            : 1367
# Correct prediction          : 1228
# Wrong prediction            : 139
# Percentage correct oov pred : 89.83174835405998

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(train_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(val_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(test_oov_flag, cmap=plt.cm.binary_r);
