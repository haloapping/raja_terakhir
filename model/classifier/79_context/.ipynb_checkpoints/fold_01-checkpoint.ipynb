# %% [markdown]
# # Import modules

# %%
import csv
import os
import pickle
import pytz
import torch
import timeit
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from copy import deepcopy
from datetime import datetime
from einops import rearrange
from itertools import chain
from time import time
from torch import nn, optim
from torchmetrics.classification import MulticlassAccuracy, MulticlassF1Score, MulticlassConfusionMatrix
from torch.optim import lr_scheduler
from tqdm.notebook import tqdm
from torch.utils.data import TensorDataset, DataLoader
from polyglot.mapping import Embedding, CaseExpander, DigitExpander

# %% [markdown]
# # Hyperparameters

# %%
class Hyperparams:
     def __init__(
        self,
        fold=1,
        max_seq_len=82,
        input_size=64,
        batch_size=32,
        num_hidden_layer=1,
        hidden_size=128,
        dropout=0,
        bias=True,
        output_size=24,
        shuffle=True,
        lr=0.005,
        batch_first=False,
        bidirectional=True,
        init_wb_with_kaiming_normal=True,
        n_epoch=50,
        patience=50,
        device="cuda" if torch.cuda.is_available() else "cpu"
    ):
        self.fold = fold
        self.input_size = input_size
        self.max_seq_len = max_seq_len
        self.batch_size = batch_size
        self.num_hidden_layer = num_hidden_layer
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.output_size = output_size
        self.shuffle = shuffle
        self.lr = lr
        self.batch_first = batch_first
        self.bidirectional = bidirectional
        self.init_wb_with_kaiming_normal = init_wb_with_kaiming_normal
        self.n_epoch = n_epoch
        self.patience = patience
        self.device = device

hyperparams = Hyperparams()

# %% [markdown]
# # Dataset

# %%
id_pos_tag = pd.read_csv("../../../datasets/raw/Indonesian_Manually_Tagged_Corpus.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False) 
train = pd.read_csv(f"../../../datasets/raw/cv/train/train.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
val = pd.read_csv(f"../../../datasets/raw/cv/val/val.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
test = pd.read_csv(f"../../../datasets/raw/cv/test/test.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)

# %% [markdown]
# # Pre-trained Word Embedding

# %%
embeddings = Embedding.load("../../../word_embeddings/polyglot/idn_embeddings.tar.bz2")
embeddings.apply_expansion(DigitExpander)
embeddings.apply_expansion(CaseExpander)

oov_embeddings = pickle.load(open(f"../../../logs/comick/79_contexts/10-11-2022_19-39-04/oov_embedding_dict.pkl", "rb"))
oov_embeddings = {key: np.zeros((64), dtype=np.float32) for key, _ in oov_embeddings.items()}

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Add OOV Flag

# %%
def add_oov_flag(tokens, embeddings):
    oov_flags = []
    
    for token in tqdm(tokens):
        try:
            if token not in embeddings:
                oov_flags.append(True)
            else:
                oov_flags.append(False)
        except:
            oov_flags.append(False)
        
    return pd.DataFrame(oov_flags, columns=["is_oov"])

id_pos_tag_oov_flags = add_oov_flag(id_pos_tag["token"].values, embeddings)
train_oov_flags = add_oov_flag(train["token"].values, embeddings)
val_oov_flags = add_oov_flag(val["token"].values, embeddings)
test_oov_flags = add_oov_flag(test["token"].values, embeddings)
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/191567 [00:00<?, ?it/s]
#   0%|          | 0/21461 [00:00<?, ?it/s]
#   0%|          | 0/53624 [00:00<?, ?it/s]

# %% [markdown]
# ## Concate OOV Flag

# %%
id_pos_tag_df = pd.concat([id_pos_tag, id_pos_tag_oov_flags], axis=1)
train_df = pd.concat([train, train_oov_flags], axis=1)
val_df = pd.concat([val, val_oov_flags], axis=1)
test_df = pd.concat([test, test_oov_flags], axis=1)

# %% [markdown]
# ## Lowercase OOV Token

# %%
id_pos_tag_df['token'] = np.where(id_pos_tag_df['is_oov'] == True, id_pos_tag_df['token'].str.lower(), id_pos_tag_df['token'])
train_df['token'] = np.where(train_df['is_oov'] == True, train_df['token'].str.lower(), train_df['token'])
val_df['token'] = np.where(val_df['is_oov'] == True, val_df['token'].str.lower(), val_df['token'])
test_df['token'] = np.where(test_df['is_oov'] == True, test_df['token'].str.lower(), test_df['token'])

# %% [markdown]
# ## Embedding Dict, Index to Token and Token to Index

# %%
tokens = list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None))

def embedding_dict(tokens, embeddings, oov_embeddings):
    embedding = {}
    
    for token in tokens:
        if token[0] is not np.nan:
            if token[2] == False or token[0] in embeddings:
                embedding[token[0]] = embeddings[token[0]]
            else:
                embedding[token[0]] = oov_embeddings[token[0].lower()]

    return embedding

embedding_dict = embedding_dict(tokens, embeddings, oov_embeddings)
embedding_dict["<PAD>"] = embeddings["<PAD>"]
word_embeddings = nn.Embedding.from_pretrained(torch.FloatTensor(np.array(list(embedding_dict.values()))), padding_idx=list(embedding_dict.keys()).index("<PAD>"), freeze=True)

idx_to_token = {idx: token for idx, token in enumerate(list(embedding_dict.keys()))}
token_to_idx = {token: idx for idx, token in enumerate(list(embedding_dict.keys()))}

# %% [markdown]
# ## Token to Sentence

# %%
def make_sentence(tokens, max_length_sentence=hyperparams.max_seq_len):
    sentence = []
    sentences = []

    for token in tqdm(tokens):
        if token[0] is not np.nan:
            sentence.append(token)
        else:
            sentences.append(sentence[:max_length_sentence])
            sentence = []

    return sentences

all_sentence = make_sentence(list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
train_sentences = make_sentence(list(train_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
val_sentences = make_sentence(list(test_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
test_sentences = make_sentence(list(val_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/191567 [00:00<?, ?it/s]
#   0%|          | 0/53624 [00:00<?, ?it/s]
#   0%|          | 0/21461 [00:00<?, ?it/s]

# %% [markdown]
# ## Word Token, Padding, and Word token to Index

# %%
def tokenize_docs(docs, idx_token):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token[idx_token])
        sentences.append(new_sentence)
        new_sentence = []

    return sentences

def padding(docs, max_seq_len=hyperparams.max_seq_len, mode="post", val_pad="<PAD>"):
    docs = deepcopy(docs)
    doc_with_pad = []
    docs_with_pad = []

    for doc in tqdm(docs):
        if mode == "pre":
            for _ in range(max_seq_len - len(doc)):
                doc.insert(0, val_pad)
        elif mode == "post":
            for _ in range(max_seq_len - len(doc)):
                doc.append(val_pad)
        else:
            return f"Mode {mode} is not available, use instead 'pre' or 'post'."
        
        docs_with_pad.append(doc)
        
    return np.array(docs_with_pad)

def sent_to_idx(docs, token_to_idx):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token_to_idx[token])
        sentences.append(new_sentence)
        new_sentence = []

    return np.array(sentences)

def convert_feature_to_idx(docs, idx_token, token_to_idx, max_seq_len):
    sentences = tokenize_docs(docs, idx_token)
    sentences_with_pad = padding(sentences, max_seq_len=max_seq_len, mode="post", val_pad="<PAD>")
    sentences_to_idx = sent_to_idx(sentences_with_pad, token_to_idx)
    
    return sentences_to_idx

train_sentence_idxs = convert_feature_to_idx(train_sentences, 0, token_to_idx, hyperparams.max_seq_len)
val_sentence_idxs = convert_feature_to_idx(val_sentences, 0, token_to_idx, hyperparams.max_seq_len)
test_sentence_idxs = convert_feature_to_idx(test_sentences, 0, token_to_idx, hyperparams.max_seq_len)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]

# %% [markdown]
# ## Encode Class

# %%
classes = sorted(np.delete(id_pos_tag_df["tag"].unique(), 3))
idx_to_label = {idx: label for idx, label in enumerate(classes + ["<PAD>"])}
label_to_idx = {label: idx for idx, label in enumerate(classes + ["<PAD>"])}

def encode_class(docs, label_to_idx, seq_len=hyperparams.max_seq_len):
    class_idxs = []
    classes = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            class_idxs.append(label_to_idx[token[1]])
            
        for _ in range(seq_len - len(sentence)):
            class_idxs.append(label_to_idx["<PAD>"])
                
        classes.append(class_idxs)
        class_idxs = []

    return np.array(classes)
        
train_class_idxs = encode_class(train_sentences, label_to_idx)
val_class_idxs = encode_class(val_sentences, label_to_idx)
test_class_idxs = encode_class(test_sentences, label_to_idx)

print(f"Training shape   : {train_sentence_idxs.shape, train_class_idxs.shape}")
print(f"validation shape : {val_class_idxs.shape, val_class_idxs.shape}")
print(f"Test shape       : {test_sentence_idxs.shape, test_class_idxs.shape}")
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# Training shape   : ((7222, 82), (7222, 82))
# validation shape : ((2006, 82), (2006, 82))
# Test shape       : ((802, 82), (802, 82))

# %% [markdown]
# ## Note
#
# - Number of sentences = 10030
# - Train : 72% (7222)
# - Val   : 8% (802)
# - Test  : 20% (2006)

# %% [markdown]
# # Build Model

# %% [markdown]
# ## Feature and Actual Class

# %%
train_feature = torch.LongTensor(train_sentence_idxs)
val_feature = torch.LongTensor(val_sentence_idxs)
test_feature = torch.LongTensor(test_sentence_idxs)

train_class = torch.LongTensor(train_class_idxs)
val_class = torch.LongTensor(val_class_idxs)
test_class = torch.LongTensor(test_class_idxs)

# %%
train_feature.shape, val_feature.shape, test_feature.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %%
train_class.shape, val_class.shape, test_class.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %% [markdown]
# ## Tensor Dataset

# %%
train_dataset = TensorDataset(train_feature, train_class)
val_dataset = TensorDataset(val_feature, val_class)
test_dataset = TensorDataset(test_feature, test_class)

# %% [markdown]
# ## Dataloader

# %%
train_dataloader = DataLoader(train_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
val_dataloader = DataLoader(val_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
test_dataloader = DataLoader(test_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)

# %% [markdown]
# ## Model

# %%
class POSTagger(nn.Module):
    def __init__(
        self,
        input_size=hyperparams.input_size,
        hidden_size=hyperparams.hidden_size,
        dropout=hyperparams.dropout,
        bias=hyperparams.bias,
        num_layers=hyperparams.num_hidden_layer,
        output_size=hyperparams.output_size,
        batch_first=hyperparams.batch_first,
        bidirectional=hyperparams.bidirectional,
        init_wb_with_kaiming_normal=hyperparams.init_wb_with_kaiming_normal
    ):
        super(POSTagger, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.num_layers = num_layers
        self.output_size = output_size
        self.batch_first = batch_first
        self.bidirectional = bidirectional
                
        self.feature = nn.LSTM(
            input_size = self.input_size,
            hidden_size = self.hidden_size,
            bias = self.bias,
            dropout = self.dropout,
            num_layers = self.num_layers,
            batch_first = self.batch_first,
            bidirectional = self.bidirectional
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(in_features=2 * self.hidden_size if hyperparams.bidirectional else self.hidden_size, out_features=self.output_size, bias=self.bias),
            nn.Softmax(dim=-1)
        )
        
        if init_wb_with_kaiming_normal:
            self.init_wb()

    def init_wb(self):
        for module in self.modules():
            if isinstance(module, (nn.Linear, nn.LSTM)):
                for name, param in module.named_parameters():
                    if "weight" in name:
                        nn.init.kaiming_normal_(param)
                    else:
                        nn.init.kaiming_normal_(param.reshape(1, -1))
        
    def forward(self, feature, hidden=None):
        output, (hidden, memory) = self.feature(feature, None)
        prob = self.classifier(output)

        return prob
    
model = POSTagger().to(hyperparams.device)
model
# Out:
# POSTagger(
#   (feature): LSTM(64, 128, bidirectional=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=24, bias=True)
#     (1): Softmax(dim=-1)
#   )
# )

# %% [markdown]
# ## Optimizer, Criterion, and Metric

# %%
optimizer = optim.Adam(model.parameters(), lr=hyperparams.lr)
criterion = nn.CrossEntropyLoss().to(hyperparams.device)
train_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", verbose=True, factor=0.5)

# %%
sum(param.numel() for param in model.parameters() if param.requires_grad)
# Out:
# 204824

# %% [markdown]
# ## Training Step

# %%
def training_step(dataloader, model, optimizer, criterion, metric, scheduler=None):
    model.train()
    
    batch_losses = []
    batch_metric_scores = []
    
    for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
        # Forward Propagation
        feature = rearrange(feature, "n s -> s n")
        actual_label = rearrange(actual_label, "n s -> s n")
        embedding = word_embeddings(feature)
        
        prob = model(
            embedding.to(hyperparams.device),
            actual_label.to(hyperparams.device)
        )
        
        prob = prob.reshape(-1, prob.shape[-1])
        actual_label = actual_label.reshape(-1)

        loss = criterion(prob, actual_label.to(hyperparams.device))
        metric_score = metric(prob, actual_label.to(hyperparams.device))
        metric_score = metric.compute()
                
        if scheduler is not None:
            scheduler.step(loss)
        
        batch_losses.append(loss.item())
        batch_metric_scores.append(metric_score)
        
        if len(dataloader) < 10:
            if batch % 1 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/zero/fold_{hyperparams.fold}/{path_name}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
        else:
            if batch % 15 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/zero/fold_{hyperparams.fold}/{path_name}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            
        # Backward Propagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Validation Step

# %%
def validation_step(dataloader, model, criterion, metric):
    model.eval()
    
    batch_losses = []
    batch_metric_scores = []
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob, actual_label.to(hyperparams.device))
            metric_score = metric.compute()

            batch_losses.append(loss.item())
            batch_metric_scores.append(metric_score)
            
            if len(dataloader) < 10 and (batch % 1 == 0 or batch == len(dataloader)):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/zero/fold_{hyperparams.fold}/{path_name}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            else:
                if batch % 15 == 0 or batch == len(dataloader):
                    batch_name = "Batch-" + str(batch)
                    print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                    with open(f"../../../logs/zero/fold_{hyperparams.fold}/{path_name}/training_history.txt", "a") as f:
                        f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Looping Step

# %%
now = datetime.now(pytz.timezone("Asia/Ujung_Pandang"))
path_name = now.strftime("%m-%d-%Y_%H-%M-%S")
root_path = f"../../../logs/zero/fold_{hyperparams.fold}/{path_name}"
os.makedirs(root_path)

def looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric, n_epoch=hyperparams.n_epoch, patience=hyperparams.patience, monitor="loss"):    
    start_time = time()
    
    epoch_training_losses = []
    epoch_training_metric_scores = []
    epoch_val_losses = []
    epoch_val_metric_scores = []
    patience_counter = 0
    
    # Hyperparameters
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write(f"HYPERPARAMETERS\n")
        f.write(f"{'-' * 80}\n")
        for name, value in vars(hyperparams).items():
            f.write(f"{name}: {value}\n")
        
        f.write("\n\nTRAINING PROGRESS\n")
        f.write(f"{'-' * 80}\n")
    
    # Training Progress
    for epoch in range(1, n_epoch + 1):
        print(f"EPOCH-{epoch}")
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"EPOCH-{epoch}\n")
            f.write(f"Training Step\n")
            
        # Training Step
        print("Training Step")
        batch_training_losses, batch_training_metric_scores = training_step(train_dataloader, model, optimizer, criterion, train_metric, scheduler=None)
        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))

        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))
        epoch_training_losses.append(epoch_training_loss.item())

        epoch_training_metric_score = torch.mean(torch.FloatTensor(batch_training_metric_scores))
        epoch_training_metric_scores.append(epoch_training_metric_score.item())
        
        # Validation Step
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"\nValidation Step\n")
            
        print("\nValidation Step")
        batch_val_losses, batch_val_metric_scores = validation_step(val_dataloader, model, criterion, val_metric)
        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))

        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))
        epoch_val_losses.append(epoch_val_loss.item())

        epoch_val_metric_score = torch.mean(torch.FloatTensor(batch_val_metric_scores))
        epoch_val_metric_scores.append(epoch_val_metric_score.item())
        
        with open(f"{root_path}/training_history.txt", "a") as f:
            if monitor == "loss":
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_losses[-1] < epoch_training_losses[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
            else:
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_metric_scores[-1] > epoch_training_metric_scores[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗\n")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
                    
            print("=" * 80, end="\n\n")
            
            f.write(f"{'=' * 80}\n\n")
            
            if patience_counter == patience:
                print(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                
                f.write(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                break
        
        train_metric.reset()
        val_metric.reset()
        
    finish_time = time()
    
    # Training plot 
    fig, (ax_loss, ax_metric_score) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    fig.suptitle(f"Training with oov embedding = zero")

    ax_loss.set_title("Loss")
    ax_loss.set_xlabel("Epoch")
    ax_loss.set_ylabel("Score")
    ax_loss.plot(epoch_training_losses, "green", label="Training")
    ax_loss.plot(epoch_val_losses, "orange", label="Validation")
    ax_loss.legend()
    ax_loss.grid()

    ax_metric_score.set_title("F1 Score")
    ax_metric_score.set_xlabel("Epoch")
    ax_metric_score.set_ylabel("Score")
    ax_metric_score.plot(epoch_training_metric_scores, "green", label="Training")
    ax_metric_score.plot(epoch_val_metric_scores, "orange", label="Validation")
    ax_metric_score.legend()
    ax_metric_score.grid()

    plt.savefig(f"{root_path}/training_plot.jpg", dpi=200)                        
    
    print("TRAINING SUMMARY")
    name_best_training_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_training_metric = f"Best {str(train_metric).split('(')[0]} validation".ljust(34)
    name_best_validation_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_validation_metric = f"Best {str(val_metric).split('(')[0]} validation".ljust(34)
    name_training_time = f"Training duration".ljust(34)
    name_training_date = f"Training date".ljust(34)
    
    print(f"{name_best_training_loss}: {best_training_loss:.4f}")
    print(f"{name_best_validation_loss}: {best_val_loss:.4f}")
    print(f"{name_best_training_metric}: {best_training_metric:.4f}")
    print(f"{name_best_validation_metric}: {best_val_metric:.4f}")
    print(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.")
    print(f"{name_training_date}: {now}")
    
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write("\nTRAINING SUMMARY\n")
        f.write(f"{'-' * 80}\n")
        f.write(f"{name_best_training_loss}: {best_training_loss:.4f}\n")
        f.write(f"{name_best_validation_loss}: {best_val_loss:.4f}\n")
        f.write(f"{name_best_training_metric}: {best_training_metric:.4f}\n")
        f.write(f"{name_best_validation_metric}: {best_val_metric:.4f}\n")
        f.write(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.\n")
        f.write(f"{name_training_date}: {now}\n")
    
    # Save epoch losses, epoch metric scores, model, state dict, and oov embedding dict
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_training_losses
    }).to_csv(f"{root_path}/training_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_training_metric_scores
    }).to_csv(f"{root_path}/training_metric_scores.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_val_losses
    }).to_csv(f"{root_path}/val_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_val_metric_scores
    }).to_csv(f"{root_path}/val_metric_scores.csv", index=False)    
    
    filename_model_params = f"{root_path}/model_params.pth"
    torch.save(best_state_dict, filename_model_params)
    
    return epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores

epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores = looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric)
# Out:
# EPOCH-1
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.4864 | MulticlassF1Score=0.1490
# Batch-30 : CrossEntropyLoss=2.4712 | MulticlassF1Score=0.1935
# Batch-45 : CrossEntropyLoss=2.4822 | MulticlassF1Score=0.2094
# Batch-60 : CrossEntropyLoss=2.5028 | MulticlassF1Score=0.2170
# Batch-75 : CrossEntropyLoss=2.4718 | MulticlassF1Score=0.2224
# Batch-90 : CrossEntropyLoss=2.4605 | MulticlassF1Score=0.2285
# Batch-105: CrossEntropyLoss=2.4476 | MulticlassF1Score=0.2425
# Batch-120: CrossEntropyLoss=2.4278 | MulticlassF1Score=0.2657
# Batch-135: CrossEntropyLoss=2.3946 | MulticlassF1Score=0.2918
# Batch-150: CrossEntropyLoss=2.3929 | MulticlassF1Score=0.3172
# Batch-165: CrossEntropyLoss=2.3833 | MulticlassF1Score=0.3438
# Batch-180: CrossEntropyLoss=2.3326 | MulticlassF1Score=0.3707
# Batch-195: CrossEntropyLoss=2.3320 | MulticlassF1Score=0.3947
# Batch-210: CrossEntropyLoss=2.3444 | MulticlassF1Score=0.4155
# Batch-225: CrossEntropyLoss=2.3363 | MulticlassF1Score=0.4342
# Batch-226: CrossEntropyLoss=2.3431 | MulticlassF1Score=0.4350
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3530 | MulticlassF1Score=0.6905
# Batch-30 : CrossEntropyLoss=2.3436 | MulticlassF1Score=0.6862
# Batch-45 : CrossEntropyLoss=2.3489 | MulticlassF1Score=0.6870
# Batch-60 : CrossEntropyLoss=2.3554 | MulticlassF1Score=0.6868
# Batch-63 : CrossEntropyLoss=2.3526 | MulticlassF1Score=0.6877
#
# Training   : Mean CrossEntropyLoss = 2.4347 | Mean MulticlassF1Score = 0.2754
# Validation : Mean CrossEntropyLoss = 2.3463 | Mean MulticlassF1Score = 0.6882
# ================================================================================
#
# EPOCH-2
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3489 | MulticlassF1Score=0.6921
# Batch-30 : CrossEntropyLoss=2.3408 | MulticlassF1Score=0.6925
# Batch-45 : CrossEntropyLoss=2.3522 | MulticlassF1Score=0.6913
# Batch-60 : CrossEntropyLoss=2.3452 | MulticlassF1Score=0.6928
# Batch-75 : CrossEntropyLoss=2.3357 | MulticlassF1Score=0.6931
# Batch-90 : CrossEntropyLoss=2.3397 | MulticlassF1Score=0.6931
# Batch-105: CrossEntropyLoss=2.3511 | MulticlassF1Score=0.6931
# Batch-120: CrossEntropyLoss=2.3480 | MulticlassF1Score=0.6945
# Batch-135: CrossEntropyLoss=2.3290 | MulticlassF1Score=0.6975
# Batch-150: CrossEntropyLoss=2.3155 | MulticlassF1Score=0.7008
# Batch-165: CrossEntropyLoss=2.3305 | MulticlassF1Score=0.7045
# Batch-180: CrossEntropyLoss=2.3253 | MulticlassF1Score=0.7081
# Batch-195: CrossEntropyLoss=2.3370 | MulticlassF1Score=0.7105
# Batch-210: CrossEntropyLoss=2.3323 | MulticlassF1Score=0.7137
# Batch-225: CrossEntropyLoss=2.3191 | MulticlassF1Score=0.7163
# Batch-226: CrossEntropyLoss=2.3279 | MulticlassF1Score=0.7165
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3291 | MulticlassF1Score=0.7537
# Batch-30 : CrossEntropyLoss=2.3201 | MulticlassF1Score=0.7519
# Batch-45 : CrossEntropyLoss=2.3353 | MulticlassF1Score=0.7509
# Batch-60 : CrossEntropyLoss=2.3229 | MulticlassF1Score=0.7507
# Batch-63 : CrossEntropyLoss=2.3279 | MulticlassF1Score=0.7508
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3363 | Mean MulticlassF1Score = 0.6991
# Validation : Mean CrossEntropyLoss = 2.3261 | Mean MulticlassF1Score = 0.7502
# ================================================================================
#
# EPOCH-3
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3186 | MulticlassF1Score=0.7551
# Batch-30 : CrossEntropyLoss=2.3163 | MulticlassF1Score=0.7606
# Batch-45 : CrossEntropyLoss=2.3146 | MulticlassF1Score=0.7630
# Batch-60 : CrossEntropyLoss=2.3208 | MulticlassF1Score=0.7624
# Batch-75 : CrossEntropyLoss=2.3168 | MulticlassF1Score=0.7640
# Batch-90 : CrossEntropyLoss=2.3135 | MulticlassF1Score=0.7689
# Batch-105: CrossEntropyLoss=2.3120 | MulticlassF1Score=0.7723
# Batch-120: CrossEntropyLoss=2.3081 | MulticlassF1Score=0.7739
# Batch-135: CrossEntropyLoss=2.3137 | MulticlassF1Score=0.7752
# Batch-150: CrossEntropyLoss=2.3189 | MulticlassF1Score=0.7766
# Batch-165: CrossEntropyLoss=2.3081 | MulticlassF1Score=0.7778
# Batch-180: CrossEntropyLoss=2.3075 | MulticlassF1Score=0.7785
# Batch-195: CrossEntropyLoss=2.3159 | MulticlassF1Score=0.7798
# Batch-210: CrossEntropyLoss=2.3053 | MulticlassF1Score=0.7803
# Batch-225: CrossEntropyLoss=2.3075 | MulticlassF1Score=0.7801
# Batch-226: CrossEntropyLoss=2.3291 | MulticlassF1Score=0.7801
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3078 | MulticlassF1Score=0.7884
# Batch-30 : CrossEntropyLoss=2.3110 | MulticlassF1Score=0.7900
# Batch-45 : CrossEntropyLoss=2.3156 | MulticlassF1Score=0.7907
# Batch-60 : CrossEntropyLoss=2.3122 | MulticlassF1Score=0.7901
# Batch-63 : CrossEntropyLoss=2.3028 | MulticlassF1Score=0.7899
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3162 | Mean MulticlassF1Score = 0.7700
# Validation : Mean CrossEntropyLoss = 2.3135 | Mean MulticlassF1Score = 0.7898
# ================================================================================
#
# EPOCH-4
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2949 | MulticlassF1Score=0.7949
# Batch-30 : CrossEntropyLoss=2.3094 | MulticlassF1Score=0.7952
# Batch-45 : CrossEntropyLoss=2.3049 | MulticlassF1Score=0.7939
# Batch-60 : CrossEntropyLoss=2.3163 | MulticlassF1Score=0.7916
# Batch-75 : CrossEntropyLoss=2.3246 | MulticlassF1Score=0.7909
# Batch-90 : CrossEntropyLoss=2.3099 | MulticlassF1Score=0.7896
# Batch-105: CrossEntropyLoss=2.3193 | MulticlassF1Score=0.7900
# Batch-120: CrossEntropyLoss=2.3088 | MulticlassF1Score=0.7903
# Batch-135: CrossEntropyLoss=2.3115 | MulticlassF1Score=0.7912
# Batch-150: CrossEntropyLoss=2.3139 | MulticlassF1Score=0.7912
# Batch-165: CrossEntropyLoss=2.3096 | MulticlassF1Score=0.7918
# Batch-180: CrossEntropyLoss=2.3194 | MulticlassF1Score=0.7920
# Batch-195: CrossEntropyLoss=2.2926 | MulticlassF1Score=0.7927
# Batch-210: CrossEntropyLoss=2.3109 | MulticlassF1Score=0.7930
# Batch-225: CrossEntropyLoss=2.3125 | MulticlassF1Score=0.7938
# Batch-226: CrossEntropyLoss=2.3129 | MulticlassF1Score=0.7938
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3068 | MulticlassF1Score=0.8010
# Batch-30 : CrossEntropyLoss=2.3175 | MulticlassF1Score=0.8012
# Batch-45 : CrossEntropyLoss=2.3125 | MulticlassF1Score=0.8006
# Batch-60 : CrossEntropyLoss=2.3163 | MulticlassF1Score=0.7996
# Batch-63 : CrossEntropyLoss=2.3181 | MulticlassF1Score=0.7999
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3117 | Mean MulticlassF1Score = 0.7917
# Validation : Mean CrossEntropyLoss = 2.3103 | Mean MulticlassF1Score = 0.8008
# ================================================================================
#
# EPOCH-5
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3096 | MulticlassF1Score=0.8004
# Batch-30 : CrossEntropyLoss=2.3073 | MulticlassF1Score=0.7989
# Batch-45 : CrossEntropyLoss=2.3111 | MulticlassF1Score=0.8009
# Batch-60 : CrossEntropyLoss=2.3031 | MulticlassF1Score=0.8036
# Batch-75 : CrossEntropyLoss=2.3090 | MulticlassF1Score=0.8026
# Batch-90 : CrossEntropyLoss=2.3073 | MulticlassF1Score=0.8026
# Batch-105: CrossEntropyLoss=2.3222 | MulticlassF1Score=0.8014
# Batch-120: CrossEntropyLoss=2.3032 | MulticlassF1Score=0.8022
# Batch-135: CrossEntropyLoss=2.2989 | MulticlassF1Score=0.8029
# Batch-150: CrossEntropyLoss=2.3109 | MulticlassF1Score=0.8033
# Batch-165: CrossEntropyLoss=2.3067 | MulticlassF1Score=0.8031
# Batch-180: CrossEntropyLoss=2.3048 | MulticlassF1Score=0.8035
# Batch-195: CrossEntropyLoss=2.2989 | MulticlassF1Score=0.8042
# Batch-210: CrossEntropyLoss=2.2954 | MulticlassF1Score=0.8052
# Batch-225: CrossEntropyLoss=2.3091 | MulticlassF1Score=0.8053
# Batch-226: CrossEntropyLoss=2.2981 | MulticlassF1Score=0.8054
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3110 | MulticlassF1Score=0.8206
# Batch-30 : CrossEntropyLoss=2.3125 | MulticlassF1Score=0.8140
# Batch-45 : CrossEntropyLoss=2.3014 | MulticlassF1Score=0.8128
# Batch-60 : CrossEntropyLoss=2.3085 | MulticlassF1Score=0.8134
# Batch-63 : CrossEntropyLoss=2.2982 | MulticlassF1Score=0.8137
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3081 | Mean MulticlassF1Score = 0.8025
# Validation : Mean CrossEntropyLoss = 2.3058 | Mean MulticlassF1Score = 0.8157
# ================================================================================
#
# EPOCH-6
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2940 | MulticlassF1Score=0.8116
# Batch-30 : CrossEntropyLoss=2.2959 | MulticlassF1Score=0.8168
# Batch-45 : CrossEntropyLoss=2.3061 | MulticlassF1Score=0.8185
# Batch-60 : CrossEntropyLoss=2.3001 | MulticlassF1Score=0.8196
# Batch-75 : CrossEntropyLoss=2.3015 | MulticlassF1Score=0.8200
# Batch-90 : CrossEntropyLoss=2.3055 | MulticlassF1Score=0.8204
# Batch-105: CrossEntropyLoss=2.3106 | MulticlassF1Score=0.8208
# Batch-120: CrossEntropyLoss=2.3046 | MulticlassF1Score=0.8211
# Batch-135: CrossEntropyLoss=2.3011 | MulticlassF1Score=0.8216
# Batch-150: CrossEntropyLoss=2.2967 | MulticlassF1Score=0.8245
# Batch-165: CrossEntropyLoss=2.2971 | MulticlassF1Score=0.8264
# Batch-180: CrossEntropyLoss=2.2988 | MulticlassF1Score=0.8276
# Batch-195: CrossEntropyLoss=2.2948 | MulticlassF1Score=0.8284
# Batch-210: CrossEntropyLoss=2.2979 | MulticlassF1Score=0.8301
# Batch-225: CrossEntropyLoss=2.2959 | MulticlassF1Score=0.8314
# Batch-226: CrossEntropyLoss=2.2878 | MulticlassF1Score=0.8314
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3030 | MulticlassF1Score=0.8419
# Batch-30 : CrossEntropyLoss=2.2990 | MulticlassF1Score=0.8444
# Batch-45 : CrossEntropyLoss=2.2944 | MulticlassF1Score=0.8436
# Batch-60 : CrossEntropyLoss=2.2974 | MulticlassF1Score=0.8438
# Batch-63 : CrossEntropyLoss=2.2939 | MulticlassF1Score=0.8436
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3003 | Mean MulticlassF1Score = 0.8221
# Validation : Mean CrossEntropyLoss = 2.2969 | Mean MulticlassF1Score = 0.8432
# ================================================================================
#
# EPOCH-7
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2948 | MulticlassF1Score=0.8503
# Batch-30 : CrossEntropyLoss=2.2946 | MulticlassF1Score=0.8500
# Batch-45 : CrossEntropyLoss=2.2858 | MulticlassF1Score=0.8512
# Batch-60 : CrossEntropyLoss=2.2870 | MulticlassF1Score=0.8506
# Batch-75 : CrossEntropyLoss=2.2915 | MulticlassF1Score=0.8507
# Batch-90 : CrossEntropyLoss=2.2960 | MulticlassF1Score=0.8500
# Batch-105: CrossEntropyLoss=2.2905 | MulticlassF1Score=0.8496
# Batch-120: CrossEntropyLoss=2.2969 | MulticlassF1Score=0.8495
# Batch-135: CrossEntropyLoss=2.2887 | MulticlassF1Score=0.8495
# Batch-150: CrossEntropyLoss=2.2968 | MulticlassF1Score=0.8495
# Batch-165: CrossEntropyLoss=2.2950 | MulticlassF1Score=0.8497
# Batch-180: CrossEntropyLoss=2.2896 | MulticlassF1Score=0.8493
# Batch-195: CrossEntropyLoss=2.2963 | MulticlassF1Score=0.8494
# Batch-210: CrossEntropyLoss=2.2880 | MulticlassF1Score=0.8494
# Batch-225: CrossEntropyLoss=2.2917 | MulticlassF1Score=0.8496
# Batch-226: CrossEntropyLoss=2.2888 | MulticlassF1Score=0.8497
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2931 | MulticlassF1Score=0.8496
# Batch-30 : CrossEntropyLoss=2.2921 | MulticlassF1Score=0.8508
# Batch-45 : CrossEntropyLoss=2.2973 | MulticlassF1Score=0.8487
# Batch-60 : CrossEntropyLoss=2.2935 | MulticlassF1Score=0.8508
# Batch-63 : CrossEntropyLoss=2.2913 | MulticlassF1Score=0.8506
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2945 | Mean MulticlassF1Score = 0.8503
# Validation : Mean CrossEntropyLoss = 2.2945 | Mean MulticlassF1Score = 0.8491
# ================================================================================
#
# EPOCH-8
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2885 | MulticlassF1Score=0.8553
# Batch-30 : CrossEntropyLoss=2.2983 | MulticlassF1Score=0.8520
# Batch-45 : CrossEntropyLoss=2.2856 | MulticlassF1Score=0.8529
# Batch-60 : CrossEntropyLoss=2.2876 | MulticlassF1Score=0.8516
# Batch-75 : CrossEntropyLoss=2.2843 | MulticlassF1Score=0.8547
# Batch-90 : CrossEntropyLoss=2.2939 | MulticlassF1Score=0.8553
# Batch-105: CrossEntropyLoss=2.2893 | MulticlassF1Score=0.8549
# Batch-120: CrossEntropyLoss=2.2958 | MulticlassF1Score=0.8553
# Batch-135: CrossEntropyLoss=2.2900 | MulticlassF1Score=0.8553
# Batch-150: CrossEntropyLoss=2.2960 | MulticlassF1Score=0.8552
# Batch-165: CrossEntropyLoss=2.3002 | MulticlassF1Score=0.8550
# Batch-180: CrossEntropyLoss=2.2898 | MulticlassF1Score=0.8552
# Batch-195: CrossEntropyLoss=2.2908 | MulticlassF1Score=0.8553
# Batch-210: CrossEntropyLoss=2.2938 | MulticlassF1Score=0.8558
# Batch-225: CrossEntropyLoss=2.2934 | MulticlassF1Score=0.8561
# Batch-226: CrossEntropyLoss=2.2829 | MulticlassF1Score=0.8561
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2913 | MulticlassF1Score=0.8556
# Batch-30 : CrossEntropyLoss=2.3049 | MulticlassF1Score=0.8551
# Batch-45 : CrossEntropyLoss=2.2894 | MulticlassF1Score=0.8561
# Batch-60 : CrossEntropyLoss=2.2844 | MulticlassF1Score=0.8562
# Batch-63 : CrossEntropyLoss=2.2862 | MulticlassF1Score=0.8555
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2924 | Mean MulticlassF1Score = 0.8547
# Validation : Mean CrossEntropyLoss = 2.2928 | Mean MulticlassF1Score = 0.8564
# ================================================================================
#
# EPOCH-9
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2951 | MulticlassF1Score=0.8634
# Batch-30 : CrossEntropyLoss=2.2938 | MulticlassF1Score=0.8611
# Batch-45 : CrossEntropyLoss=2.2919 | MulticlassF1Score=0.8606
# Batch-60 : CrossEntropyLoss=2.2824 | MulticlassF1Score=0.8614
# Batch-75 : CrossEntropyLoss=2.2815 | MulticlassF1Score=0.8608
# Batch-90 : CrossEntropyLoss=2.2957 | MulticlassF1Score=0.8612
# Batch-105: CrossEntropyLoss=2.2822 | MulticlassF1Score=0.8612
# Batch-120: CrossEntropyLoss=2.2984 | MulticlassF1Score=0.8615
# Batch-135: CrossEntropyLoss=2.2966 | MulticlassF1Score=0.8625
# Batch-150: CrossEntropyLoss=2.2855 | MulticlassF1Score=0.8633
# Batch-165: CrossEntropyLoss=2.2893 | MulticlassF1Score=0.8642
# Batch-180: CrossEntropyLoss=2.2933 | MulticlassF1Score=0.8650
# Batch-195: CrossEntropyLoss=2.2914 | MulticlassF1Score=0.8656
# Batch-210: CrossEntropyLoss=2.2865 | MulticlassF1Score=0.8659
# Batch-225: CrossEntropyLoss=2.2848 | MulticlassF1Score=0.8666
# Batch-226: CrossEntropyLoss=2.2880 | MulticlassF1Score=0.8665
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2858 | MulticlassF1Score=0.8714
# Batch-30 : CrossEntropyLoss=2.2905 | MulticlassF1Score=0.8694
# Batch-45 : CrossEntropyLoss=2.2924 | MulticlassF1Score=0.8712
# Batch-60 : CrossEntropyLoss=2.2875 | MulticlassF1Score=0.8723
# Batch-63 : CrossEntropyLoss=2.2811 | MulticlassF1Score=0.8725
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2893 | Mean MulticlassF1Score = 0.8628
# Validation : Mean CrossEntropyLoss = 2.2878 | Mean MulticlassF1Score = 0.8718
# ================================================================================
#
# EPOCH-10
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2846 | MulticlassF1Score=0.8719
# Batch-30 : CrossEntropyLoss=2.2881 | MulticlassF1Score=0.8765
# Batch-45 : CrossEntropyLoss=2.2894 | MulticlassF1Score=0.8756
# Batch-60 : CrossEntropyLoss=2.2866 | MulticlassF1Score=0.8771
# Batch-75 : CrossEntropyLoss=2.2914 | MulticlassF1Score=0.8759
# Batch-90 : CrossEntropyLoss=2.2950 | MulticlassF1Score=0.8754
# Batch-105: CrossEntropyLoss=2.2881 | MulticlassF1Score=0.8761
# Batch-120: CrossEntropyLoss=2.2823 | MulticlassF1Score=0.8765
# Batch-135: CrossEntropyLoss=2.2772 | MulticlassF1Score=0.8772
# Batch-150: CrossEntropyLoss=2.2888 | MulticlassF1Score=0.8766
# Batch-165: CrossEntropyLoss=2.2883 | MulticlassF1Score=0.8765
# Batch-180: CrossEntropyLoss=2.2890 | MulticlassF1Score=0.8768
# Batch-195: CrossEntropyLoss=2.2898 | MulticlassF1Score=0.8769
# Batch-210: CrossEntropyLoss=2.2880 | MulticlassF1Score=0.8769
# Batch-225: CrossEntropyLoss=2.2792 | MulticlassF1Score=0.8771
# Batch-226: CrossEntropyLoss=2.2862 | MulticlassF1Score=0.8772
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2902 | MulticlassF1Score=0.8849
# Batch-30 : CrossEntropyLoss=2.2806 | MulticlassF1Score=0.8877
# Batch-45 : CrossEntropyLoss=2.2856 | MulticlassF1Score=0.8839
# Batch-60 : CrossEntropyLoss=2.2823 | MulticlassF1Score=0.8841
# Batch-63 : CrossEntropyLoss=2.2941 | MulticlassF1Score=0.8838
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2859 | Mean MulticlassF1Score = 0.8763
# Validation : Mean CrossEntropyLoss = 2.2846 | Mean MulticlassF1Score = 0.8847
# ================================================================================
#
# EPOCH-11
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2787 | MulticlassF1Score=0.8987
# Batch-30 : CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9014
# Batch-45 : CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9033
# Batch-60 : CrossEntropyLoss=2.2815 | MulticlassF1Score=0.9028
# Batch-75 : CrossEntropyLoss=2.2837 | MulticlassF1Score=0.9032
# Batch-90 : CrossEntropyLoss=2.2770 | MulticlassF1Score=0.9034
# Batch-105: CrossEntropyLoss=2.2888 | MulticlassF1Score=0.9034
# Batch-120: CrossEntropyLoss=2.2841 | MulticlassF1Score=0.9040
# Batch-135: CrossEntropyLoss=2.2784 | MulticlassF1Score=0.9037
# Batch-150: CrossEntropyLoss=2.2806 | MulticlassF1Score=0.9039
# Batch-165: CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9040
# Batch-180: CrossEntropyLoss=2.2782 | MulticlassF1Score=0.9044
# Batch-195: CrossEntropyLoss=2.2814 | MulticlassF1Score=0.9043
# Batch-210: CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9050
# Batch-225: CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9049
# Batch-226: CrossEntropyLoss=2.2759 | MulticlassF1Score=0.9049
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9006
# Batch-30 : CrossEntropyLoss=2.2850 | MulticlassF1Score=0.9014
# Batch-45 : CrossEntropyLoss=2.2795 | MulticlassF1Score=0.9016
# Batch-60 : CrossEntropyLoss=2.2832 | MulticlassF1Score=0.9021
# Batch-63 : CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9025
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2776 | Mean MulticlassF1Score = 0.9029
# Validation : Mean CrossEntropyLoss = 2.2783 | Mean MulticlassF1Score = 0.9006
# ================================================================================
#
# EPOCH-12
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2805 | MulticlassF1Score=0.9101
# Batch-30 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9101
# Batch-45 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9106
# Batch-60 : CrossEntropyLoss=2.2817 | MulticlassF1Score=0.9106
# Batch-75 : CrossEntropyLoss=2.2774 | MulticlassF1Score=0.9105
# Batch-90 : CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9102
# Batch-105: CrossEntropyLoss=2.2759 | MulticlassF1Score=0.9096
# Batch-120: CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9098
# Batch-135: CrossEntropyLoss=2.2767 | MulticlassF1Score=0.9101
# Batch-150: CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9105
# Batch-165: CrossEntropyLoss=2.2787 | MulticlassF1Score=0.9103
# Batch-180: CrossEntropyLoss=2.2776 | MulticlassF1Score=0.9103
# Batch-195: CrossEntropyLoss=2.2765 | MulticlassF1Score=0.9102
# Batch-210: CrossEntropyLoss=2.2754 | MulticlassF1Score=0.9103
# Batch-225: CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9103
# Batch-226: CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9103
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2806 | MulticlassF1Score=0.9048
# Batch-30 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9048
# Batch-45 : CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9058
# Batch-60 : CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9065
# Batch-63 : CrossEntropyLoss=2.2814 | MulticlassF1Score=0.9064
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2758 | Mean MulticlassF1Score = 0.9103
# Validation : Mean CrossEntropyLoss = 2.2774 | Mean MulticlassF1Score = 0.9052
# ================================================================================
#
# EPOCH-13
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9148
# Batch-30 : CrossEntropyLoss=2.2781 | MulticlassF1Score=0.9146
# Batch-45 : CrossEntropyLoss=2.2753 | MulticlassF1Score=0.9142
# Batch-60 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9153
# Batch-75 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9156
# Batch-90 : CrossEntropyLoss=2.2816 | MulticlassF1Score=0.9154
# Batch-105: CrossEntropyLoss=2.2768 | MulticlassF1Score=0.9155
# Batch-120: CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9158
# Batch-135: CrossEntropyLoss=2.2786 | MulticlassF1Score=0.9154
# Batch-150: CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9159
# Batch-165: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9158
# Batch-180: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9162
# Batch-195: CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9161
# Batch-210: CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9159
# Batch-225: CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9157
# Batch-226: CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9157
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9117
# Batch-30 : CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9102
# Batch-45 : CrossEntropyLoss=2.2792 | MulticlassF1Score=0.9108
# Batch-60 : CrossEntropyLoss=2.2838 | MulticlassF1Score=0.9087
# Batch-63 : CrossEntropyLoss=2.2775 | MulticlassF1Score=0.9089
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2740 | Mean MulticlassF1Score = 0.9155
# Validation : Mean CrossEntropyLoss = 2.2763 | Mean MulticlassF1Score = 0.9103
# ================================================================================
#
# EPOCH-14
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9167
# Batch-30 : CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9164
# Batch-45 : CrossEntropyLoss=2.2759 | MulticlassF1Score=0.9177
# Batch-60 : CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9168
# Batch-75 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9171
# Batch-90 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9178
# Batch-105: CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9178
# Batch-120: CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9179
# Batch-135: CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9182
# Batch-150: CrossEntropyLoss=2.2818 | MulticlassF1Score=0.9186
# Batch-165: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9183
# Batch-180: CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9186
# Batch-195: CrossEntropyLoss=2.2765 | MulticlassF1Score=0.9187
# Batch-210: CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9184
# Batch-225: CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9183
# Batch-226: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9183
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2809 | MulticlassF1Score=0.9099
# Batch-30 : CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9111
# Batch-45 : CrossEntropyLoss=2.2800 | MulticlassF1Score=0.9112
# Batch-60 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9103
# Batch-63 : CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9104
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2731 | Mean MulticlassF1Score = 0.9179
# Validation : Mean CrossEntropyLoss = 2.2757 | Mean MulticlassF1Score = 0.9116
# ================================================================================
#
# EPOCH-15
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9236
# Batch-30 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9228
# Batch-45 : CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9224
# Batch-60 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9212
# Batch-75 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9215
# Batch-90 : CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9210
# Batch-105: CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9208
# Batch-120: CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9211
# Batch-135: CrossEntropyLoss=2.2753 | MulticlassF1Score=0.9209
# Batch-150: CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9207
# Batch-165: CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9206
# Batch-180: CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9210
# Batch-195: CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9210
# Batch-210: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9205
# Batch-225: CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9206
# Batch-226: CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9206
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9096
# Batch-30 : CrossEntropyLoss=2.2808 | MulticlassF1Score=0.9104
# Batch-45 : CrossEntropyLoss=2.2775 | MulticlassF1Score=0.9106
# Batch-60 : CrossEntropyLoss=2.2764 | MulticlassF1Score=0.9114
# Batch-63 : CrossEntropyLoss=2.2770 | MulticlassF1Score=0.9112
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2723 | Mean MulticlassF1Score = 0.9214
# Validation : Mean CrossEntropyLoss = 2.2756 | Mean MulticlassF1Score = 0.9099
# ================================================================================
#
# EPOCH-16
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9232
# Batch-30 : CrossEntropyLoss=2.2771 | MulticlassF1Score=0.9210
# Batch-45 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9237
# Batch-60 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9231
# Batch-75 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9235
# Batch-90 : CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9234
# Batch-105: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9235
# Batch-120: CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9235
# Batch-135: CrossEntropyLoss=2.2771 | MulticlassF1Score=0.9233
# Batch-150: CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9232
# Batch-165: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9236
# Batch-180: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9234
# Batch-195: CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9230
# Batch-210: CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9227
# Batch-225: CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9223
# Batch-226: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9224
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2792 | MulticlassF1Score=0.9087
# Batch-30 : CrossEntropyLoss=2.2767 | MulticlassF1Score=0.9100
# Batch-45 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9115
# Batch-60 : CrossEntropyLoss=2.2776 | MulticlassF1Score=0.9113
# Batch-63 : CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9114
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2717 | Mean MulticlassF1Score = 0.9232
# Validation : Mean CrossEntropyLoss = 2.2754 | Mean MulticlassF1Score = 0.9105
# ================================================================================
#
# EPOCH-17
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9254
# Batch-30 : CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9251
# Batch-45 : CrossEntropyLoss=2.2789 | MulticlassF1Score=0.9240
# Batch-60 : CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9228
# Batch-75 : CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9231
# Batch-90 : CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9238
# Batch-105: CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9243
# Batch-120: CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9242
# Batch-135: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9249
# Batch-150: CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9251
# Batch-165: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9251
# Batch-180: CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9246
# Batch-195: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9245
# Batch-210: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9244
# Batch-225: CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9245
# Batch-226: CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9245
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9198
# Batch-30 : CrossEntropyLoss=2.2776 | MulticlassF1Score=0.9143
# Batch-45 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9139
# Batch-60 : CrossEntropyLoss=2.2781 | MulticlassF1Score=0.9126
# Batch-63 : CrossEntropyLoss=2.2758 | MulticlassF1Score=0.9128
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2710 | Mean MulticlassF1Score = 0.9245
# Validation : Mean CrossEntropyLoss = 2.2749 | Mean MulticlassF1Score = 0.9149
# ================================================================================
#
# EPOCH-18
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9268
# Batch-30 : CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9263
# Batch-45 : CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9252
# Batch-60 : CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9255
# Batch-75 : CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9270
# Batch-90 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9268
# Batch-105: CrossEntropyLoss=2.2772 | MulticlassF1Score=0.9261
# Batch-120: CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9264
# Batch-135: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9261
# Batch-150: CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9257
# Batch-165: CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9261
# Batch-180: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9263
# Batch-195: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9264
# Batch-210: CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9265
# Batch-225: CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9264
# Batch-226: CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9264
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9121
# Batch-30 : CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9116
# Batch-45 : CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9131
# Batch-60 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9132
# Batch-63 : CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9134
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2704 | Mean MulticlassF1Score = 0.9263
# Validation : Mean CrossEntropyLoss = 2.2747 | Mean MulticlassF1Score = 0.9133
# ================================================================================
#
# EPOCH-19
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9312
# Batch-30 : CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9289
# Batch-45 : CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9282
# Batch-60 : CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9273
# Batch-75 : CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9273
# Batch-90 : CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9281
# Batch-105: CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9285
# Batch-120: CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9282
# Batch-135: CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9280
# Batch-150: CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9275
# Batch-165: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9273
# Batch-180: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9274
# Batch-195: CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9276
# Batch-210: CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9275
# Batch-225: CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9274
# Batch-226: CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9274
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2756 | MulticlassF1Score=0.9133
# Batch-30 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9135
# Batch-45 : CrossEntropyLoss=2.2783 | MulticlassF1Score=0.9123
# Batch-60 : CrossEntropyLoss=2.2747 | MulticlassF1Score=0.9125
# Batch-63 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9125
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2701 | Mean MulticlassF1Score = 0.9281
# Validation : Mean CrossEntropyLoss = 2.2748 | Mean MulticlassF1Score = 0.9134
# ================================================================================
#
# EPOCH-20
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9303
# Batch-30 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9307
# Batch-45 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9296
# Batch-60 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9290
# Batch-75 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9288
# Batch-90 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9286
# Batch-105: CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9285
# Batch-120: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9283
# Batch-135: CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9288
# Batch-150: CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9287
# Batch-165: CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9289
# Batch-180: CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9291
# Batch-195: CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9292
# Batch-210: CrossEntropyLoss=2.2754 | MulticlassF1Score=0.9289
# Batch-225: CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9287
# Batch-226: CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9287
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9089
# Batch-30 : CrossEntropyLoss=2.2847 | MulticlassF1Score=0.9098
# Batch-45 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9112
# Batch-60 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9134
# Batch-63 : CrossEntropyLoss=2.2776 | MulticlassF1Score=0.9132
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2697 | Mean MulticlassF1Score = 0.9289
# Validation : Mean CrossEntropyLoss = 2.2748 | Mean MulticlassF1Score = 0.9096
# ================================================================================
#
# EPOCH-21
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2764 | MulticlassF1Score=0.9337
# Batch-30 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9308
# Batch-45 : CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9302
# Batch-60 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9304
# Batch-75 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9294
# Batch-90 : CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9291
# Batch-105: CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9288
# Batch-120: CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9308
# Batch-135: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9324
# Batch-150: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9341
# Batch-165: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9352
# Batch-180: CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9364
# Batch-195: CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9375
# Batch-210: CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9380
# Batch-225: CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9388
# Batch-226: CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9389
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9333
# Batch-30 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9332
# Batch-45 : CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9327
# Batch-60 : CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9329
# Batch-63 : CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9330
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2667 | Mean MulticlassF1Score = 0.9329
# Validation : Mean CrossEntropyLoss = 2.2686 | Mean MulticlassF1Score = 0.9345
# ================================================================================
#
# EPOCH-22
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2622 | MulticlassF1Score=0.9510
# Batch-30 : CrossEntropyLoss=2.2603 | MulticlassF1Score=0.9511
# Batch-45 : CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9510
# Batch-60 : CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9498
# Batch-75 : CrossEntropyLoss=2.2589 | MulticlassF1Score=0.9506
# Batch-90 : CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9504
# Batch-105: CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9501
# Batch-120: CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9494
# Batch-135: CrossEntropyLoss=2.2611 | MulticlassF1Score=0.9497
# Batch-150: CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9493
# Batch-165: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9492
# Batch-180: CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9494
# Batch-195: CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9491
# Batch-210: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9490
# Batch-225: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9489
# Batch-226: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9490
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9307
# Batch-30 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9330
# Batch-45 : CrossEntropyLoss=2.2747 | MulticlassF1Score=0.9329
# Batch-60 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9329
# Batch-63 : CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9326
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2635 | Mean MulticlassF1Score = 0.9501
# Validation : Mean CrossEntropyLoss = 2.2688 | Mean MulticlassF1Score = 0.9330
# ================================================================================
#
# EPOCH-23
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9532
# Batch-30 : CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9511
# Batch-45 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9492
# Batch-60 : CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9500
# Batch-75 : CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9503
# Batch-90 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9507
# Batch-105: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9506
# Batch-120: CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9504
# Batch-135: CrossEntropyLoss=2.2612 | MulticlassF1Score=0.9505
# Batch-150: CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9504
# Batch-165: CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9507
# Batch-180: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9507
# Batch-195: CrossEntropyLoss=2.2612 | MulticlassF1Score=0.9505
# Batch-210: CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9504
# Batch-225: CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9502
# Batch-226: CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9502
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9342
# Batch-30 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9332
# Batch-45 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9332
# Batch-60 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9330
# Batch-63 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9332
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2630 | Mean MulticlassF1Score = 0.9505
# Validation : Mean CrossEntropyLoss = 2.2684 | Mean MulticlassF1Score = 0.9337
# ================================================================================
#
# EPOCH-24
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9506
# Batch-30 : CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9515
# Batch-45 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9507
# Batch-60 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9502
# Batch-75 : CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9506
# Batch-90 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9506
# Batch-105: CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9512
# Batch-120: CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9510
# Batch-135: CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9510
# Batch-150: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9513
# Batch-165: CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9514
# Batch-180: CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9513
# Batch-195: CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9513
# Batch-210: CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9514
# Batch-225: CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9512
# Batch-226: CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9512
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9352
# Batch-30 : CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9354
# Batch-45 : CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9343
# Batch-60 : CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9339
# Batch-63 : CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9335
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2627 | Mean MulticlassF1Score = 0.9509
# Validation : Mean CrossEntropyLoss = 2.2684 | Mean MulticlassF1Score = 0.9348
# ================================================================================
#
# EPOCH-25
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9553
# Batch-30 : CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9544
# Batch-45 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9543
# Batch-60 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9537
# Batch-75 : CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9533
# Batch-90 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9525
# Batch-105: CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9522
# Batch-120: CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9524
# Batch-135: CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9524
# Batch-150: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9518
# Batch-165: CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9519
# Batch-180: CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9520
# Batch-195: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9522
# Batch-210: CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9522
# Batch-225: CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9520
# Batch-226: CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9520
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9358
# Batch-30 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9351
# Batch-45 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9346
# Batch-60 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9344
# Batch-63 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9345
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2624 | Mean MulticlassF1Score = 0.9530
# Validation : Mean CrossEntropyLoss = 2.2680 | Mean MulticlassF1Score = 0.9342
# ================================================================================
#
# EPOCH-26
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9514
# Batch-30 : CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9517
# Batch-45 : CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9517
# Batch-60 : CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9515
# Batch-75 : CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9521
# Batch-90 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9516
# Batch-105: CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9515
# Batch-120: CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9517
# Batch-135: CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9520
# Batch-150: CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9520
# Batch-165: CrossEntropyLoss=2.2597 | MulticlassF1Score=0.9523
# Batch-180: CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9526
# Batch-195: CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9528
# Batch-210: CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9527
# Batch-225: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9527
# Batch-226: CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9527
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9280
# Batch-30 : CrossEntropyLoss=2.2753 | MulticlassF1Score=0.9298
# Batch-45 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9325
# Batch-60 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9338
# Batch-63 : CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9336
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2621 | Mean MulticlassF1Score = 0.9519
# Validation : Mean CrossEntropyLoss = 2.2683 | Mean MulticlassF1Score = 0.9297
# ================================================================================
#
# EPOCH-27
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9570
# Batch-30 : CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9535
# Batch-45 : CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9542
# Batch-60 : CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9534
# Batch-75 : CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9534
# Batch-90 : CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9529
# Batch-105: CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9536
# Batch-120: CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9542
# Batch-135: CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9543
# Batch-150: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9540
# Batch-165: CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9539
# Batch-180: CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9538
# Batch-195: CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9534
# Batch-210: CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9531
# Batch-225: CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9529
# Batch-226: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9529
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9320
# Batch-30 : CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9315
# Batch-45 : CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9337
# Batch-60 : CrossEntropyLoss=2.2758 | MulticlassF1Score=0.9341
# Batch-63 : CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9339
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2621 | Mean MulticlassF1Score = 0.9539
# Validation : Mean CrossEntropyLoss = 2.2682 | Mean MulticlassF1Score = 0.9328
# ================================================================================
#
# EPOCH-28
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9520
# Batch-30 : CrossEntropyLoss=2.2612 | MulticlassF1Score=0.9533
# Batch-45 : CrossEntropyLoss=2.2612 | MulticlassF1Score=0.9526
# Batch-60 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9526
# Batch-75 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9535
# Batch-90 : CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9539
# Batch-105: CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9537
# Batch-120: CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9542
# Batch-135: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9546
# Batch-150: CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9545
# Batch-165: CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9546
# Batch-180: CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9546
# Batch-195: CrossEntropyLoss=2.2603 | MulticlassF1Score=0.9544
# Batch-210: CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9544
# Batch-225: CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9543
# Batch-226: CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9543
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9336
# Batch-30 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9328
# Batch-45 : CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9334
# Batch-60 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9342
# Batch-63 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9344
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2616 | Mean MulticlassF1Score = 0.9537
# Validation : Mean CrossEntropyLoss = 2.2681 | Mean MulticlassF1Score = 0.9337
# ================================================================================
#
# EPOCH-29
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9534
# Batch-30 : CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9537
# Batch-45 : CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9557
# Batch-60 : CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9558
# Batch-75 : CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9553
# Batch-90 : CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9554
# Batch-105: CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9549
# Batch-120: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9552
# Batch-135: CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9551
# Batch-150: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9553
# Batch-165: CrossEntropyLoss=2.2612 | MulticlassF1Score=0.9552
# Batch-180: CrossEntropyLoss=2.2603 | MulticlassF1Score=0.9551
# ...
# Batch-45 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9380
# Batch-60 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9390
# Batch-63 : CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9388
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2597 | Mean MulticlassF1Score = 0.9608
# Validation : Mean CrossEntropyLoss = 2.2665 | Mean MulticlassF1Score = 0.9389
# Patience = 3/50❗
# ================================================================================
#
# EPOCH-42
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2527 | MulticlassF1Score=0.9649
# Batch-30 : CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9626
# Batch-45 : CrossEntropyLoss=2.2597 | MulticlassF1Score=0.9622
# Batch-60 : CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9622
# Batch-75 : CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9622
# Batch-90 : CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9617
# Batch-105: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9618
# Batch-120: CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9615
# Batch-135: CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9613
# Batch-150: CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9616
# Batch-165: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9614
# Batch-180: CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9613
# Batch-195: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9612
# Batch-210: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9612
# Batch-225: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9614
# Batch-226: CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9614
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2762 | MulticlassF1Score=0.9347
# Batch-30 : CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9359
# Batch-45 : CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9373
# Batch-60 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9373
# Batch-63 : CrossEntropyLoss=2.2611 | MulticlassF1Score=0.9380
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2594 | Mean MulticlassF1Score = 0.9620
# Validation : Mean CrossEntropyLoss = 2.2667 | Mean MulticlassF1Score = 0.9362
# ================================================================================
#
# EPOCH-43
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9633
# Batch-30 : CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9627
# Batch-45 : CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9630
# Batch-60 : CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9631
# Batch-75 : CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9624
# Batch-90 : CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9618
# Batch-105: CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9617
# Batch-120: CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9619
# Batch-135: CrossEntropyLoss=2.2611 | MulticlassF1Score=0.9619
# Batch-150: CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9619
# Batch-165: CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9619
# Batch-180: CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9620
# Batch-195: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9618
# Batch-210: CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9616
# Batch-225: CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9615
# Batch-226: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9616
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9373
# Batch-30 : CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9382
# Batch-45 : CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9384
# Batch-60 : CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9390
# Batch-63 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9388
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2593 | Mean MulticlassF1Score = 0.9622
# Validation : Mean CrossEntropyLoss = 2.2665 | Mean MulticlassF1Score = 0.9385
# ================================================================================
#
# EPOCH-44
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9613
# Batch-30 : CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9614
# Batch-45 : CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9620
# Batch-60 : CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9614
# Batch-75 : CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9614
# Batch-90 : CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9611
# Batch-105: CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9609
# Batch-120: CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9609
# Batch-135: CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9613
# Batch-150: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9616
# Batch-165: CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9615
# Batch-180: CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9618
# Batch-195: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9620
# Batch-210: CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9620
# Batch-225: CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9617
# Batch-226: CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9617
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9386
# Batch-30 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9385
# Batch-45 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9383
# Batch-60 : CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9386
# Batch-63 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9386
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2592 | Mean MulticlassF1Score = 0.9615
# Validation : Mean CrossEntropyLoss = 2.2666 | Mean MulticlassF1Score = 0.9369
# ================================================================================
#
# EPOCH-45
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9618
# Batch-30 : CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9622
# Batch-45 : CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9627
# Batch-60 : CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9623
# Batch-75 : CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9622
# Batch-90 : CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9625
# Batch-105: CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9625
# Batch-120: CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9625
# Batch-135: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9621
# Batch-150: CrossEntropyLoss=2.2597 | MulticlassF1Score=0.9616
# Batch-165: CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9617
# Batch-180: CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9616
# Batch-195: CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9615
# Batch-210: CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9617
# Batch-225: CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9616
# Batch-226: CrossEntropyLoss=2.2589 | MulticlassF1Score=0.9616
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9405
# Batch-30 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9403
# Batch-45 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9417
# Batch-60 : CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9398
# Batch-63 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9397
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2593 | Mean MulticlassF1Score = 0.9619
# Validation : Mean CrossEntropyLoss = 2.2663 | Mean MulticlassF1Score = 0.9403
# Patience = 4/50❗
# ================================================================================
#
# EPOCH-46
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9608
# Batch-30 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9612
# Batch-45 : CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9623
# Batch-60 : CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9629
# Batch-75 : CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9623
# Batch-90 : CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9620
# Batch-105: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9618
# Batch-120: CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9621
# Batch-135: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9620
# Batch-150: CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9617
# Batch-165: CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9617
# Batch-180: CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9618
# Batch-195: CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9620
# Batch-210: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9621
# Batch-225: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9620
# Batch-226: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9621
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9434
# Batch-30 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9400
# Batch-45 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9381
# Batch-60 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9389
# Batch-63 : CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9393
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2591 | Mean MulticlassF1Score = 0.9621
# Validation : Mean CrossEntropyLoss = 2.2664 | Mean MulticlassF1Score = 0.9405
# ================================================================================
#
# EPOCH-47
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9627
# Batch-30 : CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9610
# Batch-45 : CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9605
# Batch-60 : CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9608
# Batch-75 : CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9610
# Batch-90 : CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9613
# Batch-105: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9615
# Batch-120: CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9615
# Batch-135: CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9615
# Batch-150: CrossEntropyLoss=2.2597 | MulticlassF1Score=0.9616
# Batch-165: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9618
# Batch-180: CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9620
# Batch-195: CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9621
# Batch-210: CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9622
# Batch-225: CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9623
# Batch-226: CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9622
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9385
# Batch-30 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9407
# Batch-45 : CrossEntropyLoss=2.2622 | MulticlassF1Score=0.9401
# Batch-60 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9391
# Batch-63 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9387
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2591 | Mean MulticlassF1Score = 0.9616
# Validation : Mean CrossEntropyLoss = 2.2666 | Mean MulticlassF1Score = 0.9380
# ================================================================================
#
# EPOCH-48
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9639
# Batch-30 : CrossEntropyLoss=2.2547 | MulticlassF1Score=0.9635
# Batch-45 : CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9631
# Batch-60 : CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9638
# Batch-75 : CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9634
# Batch-90 : CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9631
# Batch-105: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9627
# Batch-120: CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9629
# Batch-135: CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9621
# Batch-150: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9622
# Batch-165: CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9623
# Batch-180: CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9625
# Batch-195: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9625
# Batch-210: CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9624
# Batch-225: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9624
# Batch-226: CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9624
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9383
# Batch-30 : CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9380
# Batch-45 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9388
# Batch-60 : CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9395
# Batch-63 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9395
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2590 | Mean MulticlassF1Score = 0.9625
# Validation : Mean CrossEntropyLoss = 2.2664 | Mean MulticlassF1Score = 0.9380
# ================================================================================
#
# EPOCH-49
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9630
# Batch-30 : CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9624
# Batch-45 : CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9627
# Batch-60 : CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9627
# Batch-75 : CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9622
# Batch-90 : CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9624
# Batch-105: CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9626
# Batch-120: CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9627
# Batch-135: CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9626
# Batch-150: CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9625
# Batch-165: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9625
# Batch-180: CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9627
# Batch-195: CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9625
# Batch-210: CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9624
# Batch-225: CrossEntropyLoss=2.2544 | MulticlassF1Score=0.9626
# Batch-226: CrossEntropyLoss=2.2531 | MulticlassF1Score=0.9626
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9377
# Batch-30 : CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9391
# Batch-45 : CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9384
# Batch-60 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9390
# Batch-63 : CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9388
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2590 | Mean MulticlassF1Score = 0.9626
# Validation : Mean CrossEntropyLoss = 2.2666 | Mean MulticlassF1Score = 0.9382
# ================================================================================
#
# EPOCH-50
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9628
# Batch-30 : CrossEntropyLoss=2.2589 | MulticlassF1Score=0.9633
# Batch-45 : CrossEntropyLoss=2.2603 | MulticlassF1Score=0.9629
# Batch-60 : CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9620
# Batch-75 : CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9621
# Batch-90 : CrossEntropyLoss=2.2612 | MulticlassF1Score=0.9621
# Batch-105: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9622
# Batch-120: CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9624
# Batch-135: CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9622
# Batch-150: CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9627
# Batch-165: CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9626
# Batch-180: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9626
# Batch-195: CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9627
# Batch-210: CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9627
# Batch-225: CrossEntropyLoss=2.2597 | MulticlassF1Score=0.9627
# Batch-226: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9627
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9348
# Batch-30 : CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9385
# Batch-45 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9383
# Batch-60 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9393
# Batch-63 : CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9392
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2589 | Mean MulticlassF1Score = 0.9626
# Validation : Mean CrossEntropyLoss = 2.2664 | Mean MulticlassF1Score = 0.9379
# ================================================================================
#
# TRAINING SUMMARY
# Best CrossEntropyLoss training    : 2.2589
# Best CrossEntropyLoss training    : 2.2664
# Best MulticlassF1Score validation : 0.9626
# Best MulticlassF1Score validation : 0.9379
# Training duration                 : 2.0167 minutes.
# Training date                     : 2022-10-24 18:06:24.539060+08:00

# %% [markdown]
# ## End Training

# %% [markdown]
# # Evaluation

# %%
def evaluation(dataloader, model, criterion, metric):
    model.eval()
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)
            pred = rearrange(prob.argmax(dim=1).reshape(feature.shape[0], len(dataloader.dataset)), "s n -> n s")

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob.argmax(dim=1), actual_label.to(hyperparams.device))
            metric_score = metric.compute()

    return loss, metric_score, pred

train_dataloader = DataLoader(train_dataset, batch_size=len(train_dataset))
val_dataloader = DataLoader(val_dataset, batch_size=len(val_dataset))
test_dataloader = DataLoader(test_dataset, batch_size=len(test_dataset))

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
train_loss, train_f1_score, train_pred_label = evaluation(train_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_loss, val_f1_score, val_pred_label = evaluation(val_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
test_loss, test_f1_score, test_pred_label = evaluation(test_dataloader, model, criterion, metric)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9632, device='cuda:0'),
#  tensor(0.9392, device='cuda:0'),
#  tensor(0.9369, device='cuda:0'))

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9632, device='cuda:0'),
#  tensor(0.9392, device='cuda:0'),
#  tensor(0.9369, device='cuda:0'))

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns

def viz_evaluation(pred_label, actual_label, title):
    plt.figure(figsize=(15, 7), dpi=200)
    sns.heatmap(pred_label.detach().cpu() == actual_label, cbar=True, cmap="binary_r")
    plt.xlabel("Sentence Length")
    plt.ylabel("Sentence")
    plt.title(title)
    plt.savefig(f"{root_path}/heatmap_{title.lower()}.jpg", dpi=200)
    plt.show()

train_actual_label = train_dataloader.dataset.tensors[1]
val_actual_label = val_dataloader.dataset.tensors[1]
test_actual_label = test_dataloader.dataset.tensors[1]

viz_evaluation(train_pred_label, train_actual_label, f"Training (F1-Score: {(train_f1_score):.4f})")
viz_evaluation(val_pred_label, val_actual_label, f"Validation (F1-Score: {(val_f1_score):.4f})")
viz_evaluation(test_pred_label, test_actual_label, f"Test (F1-Score: {(test_f1_score):.4f})")

# %% [markdown]
# ## Confusion Matrix

# %%
def confusion_matrix(pred_class, actual_class, title, normalize=None):
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize=normalize)
    plt.figure(figsize=(20, 10), dpi=200)
    sns.heatmap(conf_mat(pred_class.detach().cpu(), actual_class), annot=True, fmt=".2g", xticklabels=list(label_to_idx.keys()), yticklabels=list(label_to_idx.keys()));
    plt.yticks(rotation=0)
    plt.title(title)
    plt.xlabel("Actual Class")
    plt.ylabel("Predict Class")
    plt.savefig(f"{root_path}/conf_matrix_{title.lower()}.jpg", dpi=200)

confusion_matrix(train_pred_label, train_actual_label, "Training", "pred")
confusion_matrix(val_pred_label,val_actual_label, "Validation", "pred")
confusion_matrix(test_pred_label, test_actual_label, "Test", "pred")
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 168 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)

# %% [markdown]
# ## Prediction Table

# %%
def number_wrong_pred_each_class(pred_class, actual_class):
    classes, count_class = actual_class.flatten().unique(return_counts=True)
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize="none")
    correct_pred_count_class = conf_mat(pred_class.detach().cpu(), actual_class).diag()
    
    correct_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (correct_pred_count_class))}
    wrong_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (count_class - correct_pred_count_class))}
    
    return correct_pred, wrong_pred

correct_pred, wrong_pred = number_wrong_pred_each_class(train_pred_label, train_actual_label)
print(f"| {'Number class'.ljust(14)} | {'Correct prediction'.ljust(12)} | {'Wrong prediction'.ljust(12)} |")
for (label_correct_pred, count_correct_pred), (label_wrong_pred, count_wrong_pred) in zip(correct_pred.items(), wrong_pred.items()):
    print(f"| {str(label_correct_pred).ljust(6)}: {str(count_correct_pred + count_wrong_pred).ljust(7)}| {label_correct_pred.ljust(6)}: {str(count_correct_pred).ljust(10)} | {label_wrong_pred.ljust(6)}: {str(count_wrong_pred).ljust(8)} |")
# Out:
# | Number class   | Correct prediction | Wrong prediction |
# | CC    : 5322   | CC    : 5203       | CC    : 119      |
# | CD    : 12758  | CD    : 12572      | CD    : 186      |
# | DT    : 277    | DT    : 0          | DT    : 277      |
# | FW    : 1666   | FW    : 1409       | FW    : 257      |
# | IN    : 15371  | IN    : 15189      | IN    : 182      |
# | JJ    : 6997   | JJ    : 6571       | JJ    : 426      |
# | MD    : 3774   | MD    : 3677       | MD    : 97       |
# | NEG   : 1113   | NEG   : 0          | NEG   : 1113     |
# | NN    : 44672  | NN    : 43963      | NN    : 709      |
# | NND   : 1021   | NND   : 919        | NND   : 102      |
# | NNP   : 24845  | NNP   : 24077      | NNP   : 768      |
# | OD    : 541    | OD    : 0          | OD    : 541      |
# | PR    : 3896   | PR    : 3828       | PR    : 68       |
# | PRP   : 5408   | PRP   : 5270       | PRP   : 138      |
# | RB    : 3463   | RB    : 3202       | RB    : 261      |
# | RP    : 137    | RP    : 0          | RP    : 137      |
# | SC    : 9366   | SC    : 9004       | SC    : 362      |
# | SYM   : 1569   | SYM   : 1493       | SYM   : 76       |
# | UH    : 23     | UH    : 0          | UH    : 23       |
# | VB    : 22790  | VB    : 22347      | VB    : 443      |
# | WH    : 180    | WH    : 0          | WH    : 180      |
# | X     : 294    | X     : 0          | X     : 294      |
# | Z     : 18862  | Z     : 18830      | Z     : 32       |
# | <PAD> : 407859 | <PAD> : 407859     | <PAD> : 0        |

# %%
train_actual_label[308], train_pred_label[308]
# Out:
# (tensor([ 8, 19, 22, 10, 22, 19, 10,  6, 19,  4,  1,  8, 16, 19,  8, 19,  0,  8,
#           5, 16, 19, 19,  8,  8, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23]),
#  tensor([ 8, 19, 22, 10, 22, 19, 10,  6, 19,  4,  1,  8, 16, 19,  8, 19,  0,  8,
#           5, 16, 19,  8,  8,  8, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23], device='cuda:0'))

# %%
train_actual_label[308].detach().cpu() == train_pred_label[308].detach().cpu()
# Out:
# tensor([ True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True, False,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True])

# %% [markdown]
# ## OOV prediction is correct

# %%
def oov_flag_token(sentences, max_seq_len=hyperparams.max_seq_len):
    sent_copy = deepcopy(sentences)
    sent = []
    oov_flag = []
    
    for sentence in tqdm(sent_copy):
        for token in sentence:
            sent.append(token[2])
        
        for _ in range(max_seq_len- len(sentence)):
            sent.append(False)
        
        oov_flag.append(sent)
        sent = []
        
    return np.array(oov_flag)

train_oov_flag = oov_flag_token(train_sentences, max_seq_len=hyperparams.max_seq_len)
val_oov_flag = oov_flag_token(val_sentences, max_seq_len=hyperparams.max_seq_len)
test_oov_flag = oov_flag_token(test_sentences, max_seq_len=hyperparams.max_seq_len)

def pencentage_oov_pred_correct(pred_oov_flag, oov_flag_tensor):
    oov_correct_counter = 0
    oov_wrong_counter = 0

    for pred, oov_label in tqdm(zip(pred_oov_flag, oov_flag_tensor)):
        if pred == True and oov_label == True:
            oov_correct_counter += 1
        elif pred == False and oov_label == True:
            oov_wrong_counter += 1
        else:
            continue
            
    return oov_correct_counter, oov_wrong_counter

train_pred_oov_flag = (train_actual_label == train_pred_label.detach().cpu()).flatten()
val_pred_oov_flag = (val_actual_label == val_pred_label.detach().cpu()).flatten()
test_pred_oov_flag = (test_actual_label == test_pred_label.detach().cpu()).flatten()
train_oov_flag_tensor = torch.tensor(train_oov_flag).flatten()
val_oov_flag_tensor = torch.tensor(val_oov_flag).flatten()
test_oov_flag_tensor = torch.tensor(test_oov_flag).flatten()

train_oov_correct_counter, train_oov_wrong_counter = pencentage_oov_pred_correct(train_pred_oov_flag, train_oov_flag_tensor)
val_oov_correct_counter, val_oov_wrong_counter = pencentage_oov_pred_correct(val_pred_oov_flag, val_oov_flag_tensor)
test_oov_correct_counter, test_oov_wrong_counter = pencentage_oov_pred_correct(test_pred_oov_flag, test_oov_flag_tensor)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
def print_percentage_pred_oov(title, oov_correct_counter, oov_wrong_counter):
    print(f"{title}")
    print(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}")
    print(f"Correct prediction          : {oov_correct_counter}")
    print(f"Wrong prediction            : {oov_wrong_counter}")
    print(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n")
    
    with open(f"{root_path}/oov_summary.txt", "a") as f:
        f.write(f"{title}\n")
        f.write(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}\n")
        f.write(f"Correct prediction          : {oov_correct_counter}\n")
        f.write(f"Wrong prediction            : {oov_wrong_counter}\n")
        f.write(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n\n")

# %%
print_percentage_pred_oov("Training", train_oov_correct_counter, train_oov_wrong_counter)
print_percentage_pred_oov("Validation", val_oov_correct_counter, val_oov_wrong_counter)
print_percentage_pred_oov("Test", test_oov_correct_counter, test_oov_wrong_counter)
# Out:
# Training
# Number OOV token            : 11821
# Correct prediction          : 10315
# Wrong prediction            : 1506
# Percentage correct oov pred : 87.25996108620252
#
# Validation
# Number OOV token            : 3350
# Correct prediction          : 2399
# Wrong prediction            : 951
# Percentage correct oov pred : 71.61194029850746
#
# Test
# Number OOV token            : 1391
# Correct prediction          : 994
# Wrong prediction            : 397
# Percentage correct oov pred : 71.45938173975557

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(train_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(val_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(test_oov_flag, cmap=plt.cm.binary_r);
