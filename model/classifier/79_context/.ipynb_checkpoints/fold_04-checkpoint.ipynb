# %% [markdown]
# # Import modules

# %%
import csv
import os
import pickle
import pytz
import torch
import timeit
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from copy import deepcopy
from datetime import datetime
from einops import rearrange
from itertools import chain
from time import time
from torch import nn, optim
from torchmetrics.classification import MulticlassAccuracy, MulticlassF1Score, MulticlassConfusionMatrix
from torch.optim import lr_scheduler
from tqdm.notebook import tqdm
from torch.utils.data import TensorDataset, DataLoader
from polyglot.mapping import Embedding, CaseExpander, DigitExpander

# %% [markdown]
# # Hyperparameters

# %%
class Hyperparams:
     def __init__(
        self,
        context_size=79,
        fold=4,
        max_seq_len=82,
        input_size=64,
        batch_size=32,
        num_hidden_layer=1,
        hidden_size=128,
        dropout=0,
        bias=True,
        output_size=24,
        shuffle=True,
        lr=0.005,
        batch_first=False,
        bidirectional=True,
        init_wb_with_kaiming_normal=True,
        n_epoch=50,
        patience=50,
        device="cuda" if torch.cuda.is_available() else "cpu"
    ):
        self.context_size = context_size
        self.fold = fold
        self.input_size = input_size
        self.max_seq_len = max_seq_len
        self.batch_size = batch_size
        self.num_hidden_layer = num_hidden_layer
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.output_size = output_size
        self.shuffle = shuffle
        self.lr = lr
        self.batch_first = batch_first
        self.bidirectional = bidirectional
        self.init_wb_with_kaiming_normal = init_wb_with_kaiming_normal
        self.n_epoch = n_epoch
        self.patience = patience
        self.device = device

hyperparams = Hyperparams()

# %% [markdown]
# # Dataset

# %%
id_pos_tag = pd.read_csv("../../../datasets/raw/Indonesian_Manually_Tagged_Corpus.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False) 
train = pd.read_csv(f"../../../datasets/raw/cv/train/train.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
val = pd.read_csv(f"../../../datasets/raw/cv/val/val.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
test = pd.read_csv(f"../../../datasets/raw/cv/test/test.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)

# %% [markdown]
# # Pre-trained Word Embedding

# %%
embeddings = Embedding.load("../../../word_embeddings/polyglot/idn_embeddings.tar.bz2")
embeddings.apply_expansion(DigitExpander)
embeddings.apply_expansion(CaseExpander)

oov_embeddings = pickle.load(open(f"../../../logs/comick/{hyperparams.context_size}_contexts/10-11-2022_19-39-04/oov_embedding_dict.pkl", "rb"))

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Add OOV Flag

# %%
def add_oov_flag(tokens, embeddings):
    oov_flags = []
    
    for token in tqdm(tokens):
        try:
            if token not in embeddings:
                oov_flags.append(True)
            else:
                oov_flags.append(False)
        except:
            oov_flags.append(False)
        
    return pd.DataFrame(oov_flags, columns=["is_oov"])

id_pos_tag_oov_flags = add_oov_flag(id_pos_tag["token"].values, embeddings)
train_oov_flags = add_oov_flag(train["token"].values, embeddings)
val_oov_flags = add_oov_flag(val["token"].values, embeddings)
test_oov_flags = add_oov_flag(test["token"].values, embeddings)
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/191849 [00:00<?, ?it/s]
#   0%|          | 0/21364 [00:00<?, ?it/s]
#   0%|          | 0/53439 [00:00<?, ?it/s]

# %% [markdown]
# ## Concate OOV Flag

# %%
id_pos_tag_df = pd.concat([id_pos_tag, id_pos_tag_oov_flags], axis=1)
train_df = pd.concat([train, train_oov_flags], axis=1)
val_df = pd.concat([val, val_oov_flags], axis=1)
test_df = pd.concat([test, test_oov_flags], axis=1)

# %% [markdown]
# ## Lowercase OOV Token

# %%
id_pos_tag_df['token'] = np.where(id_pos_tag_df['is_oov'] == True, id_pos_tag_df['token'].str.lower(), id_pos_tag_df['token'])
train_df['token'] = np.where(train_df['is_oov'] == True, train_df['token'].str.lower(), train_df['token'])
val_df['token'] = np.where(val_df['is_oov'] == True, val_df['token'].str.lower(), val_df['token'])
test_df['token'] = np.where(test_df['is_oov'] == True, test_df['token'].str.lower(), test_df['token'])

# %% [markdown]
# ## Embedding Dict, Index to Token and Token to Index

# %%
tokens = list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None))

def embedding_dict(tokens, embeddings, oov_embeddings):
    embedding = {}
    
    for token in tokens:
        if token[0] is not np.nan:
            if token[2] == False or token[0] in embeddings:
                embedding[token[0]] = embeddings[token[0]]
            else:
                embedding[token[0]] = oov_embeddings[token[0].lower()]

    return embedding

embedding_dict = embedding_dict(tokens, embeddings, oov_embeddings)
embedding_dict["<PAD>"] = embeddings["<PAD>"]
word_embeddings = nn.Embedding.from_pretrained(torch.FloatTensor(np.array(list(embedding_dict.values()))), padding_idx=list(embedding_dict.keys()).index("<PAD>"), freeze=True)

idx_to_token = {idx: token for idx, token in enumerate(list(embedding_dict.keys()))}
token_to_idx = {token: idx for idx, token in enumerate(list(embedding_dict.keys()))}

# %% [markdown]
# ## Token to Sentence

# %%
def make_sentence(tokens, max_length_sentence=hyperparams.max_seq_len):
    sentence = []
    sentences = []

    for token in tqdm(tokens):
        if token[0] is not np.nan:
            sentence.append(token)
        else:
            sentences.append(sentence[:max_length_sentence])
            sentence = []

    return sentences

all_sentence = make_sentence(list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
train_sentences = make_sentence(list(train_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
val_sentences = make_sentence(list(test_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
test_sentences = make_sentence(list(val_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/191849 [00:00<?, ?it/s]
#   0%|          | 0/53439 [00:00<?, ?it/s]
#   0%|          | 0/21364 [00:00<?, ?it/s]

# %% [markdown]
# ## Word Token, Padding, and Word token to Index

# %%
def tokenize_docs(docs, idx_token):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token[idx_token])
        sentences.append(new_sentence)
        new_sentence = []

    return sentences

def padding(docs, max_seq_len=hyperparams.max_seq_len, mode="post", val_pad="<PAD>"):
    docs = deepcopy(docs)
    doc_with_pad = []
    docs_with_pad = []

    for doc in tqdm(docs):
        if mode == "pre":
            for _ in range(max_seq_len - len(doc)):
                doc.insert(0, val_pad)
        elif mode == "post":
            for _ in range(max_seq_len - len(doc)):
                doc.append(val_pad)
        else:
            return f"Mode {mode} is not available, use instead 'pre' or 'post'."
        
        docs_with_pad.append(doc)
        
    return np.array(docs_with_pad)

def sent_to_idx(docs, token_to_idx):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token_to_idx[token])
        sentences.append(new_sentence)
        new_sentence = []

    return np.array(sentences)

def convert_feature_to_idx(docs, idx_token, token_to_idx, max_seq_len):
    sentences = tokenize_docs(docs, idx_token)
    sentences_with_pad = padding(sentences, max_seq_len=max_seq_len, mode="post", val_pad="<PAD>")
    sentences_to_idx = sent_to_idx(sentences_with_pad, token_to_idx)
    
    return sentences_to_idx

train_sentence_idxs = convert_feature_to_idx(train_sentences, 0, token_to_idx, hyperparams.max_seq_len)
val_sentence_idxs = convert_feature_to_idx(val_sentences, 0, token_to_idx, hyperparams.max_seq_len)
test_sentence_idxs = convert_feature_to_idx(test_sentences, 0, token_to_idx, hyperparams.max_seq_len)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]

# %% [markdown]
# ## Encode Class

# %%
classes = sorted(np.delete(id_pos_tag_df["tag"].unique(), 3))
idx_to_label = {idx: label for idx, label in enumerate(classes + ["<PAD>"])}
label_to_idx = {label: idx for idx, label in enumerate(classes + ["<PAD>"])}

def encode_class(docs, label_to_idx, seq_len=hyperparams.max_seq_len):
    class_idxs = []
    classes = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            class_idxs.append(label_to_idx[token[1]])
            
        for _ in range(seq_len - len(sentence)):
            class_idxs.append(label_to_idx["<PAD>"])
                
        classes.append(class_idxs)
        class_idxs = []

    return np.array(classes)
        
train_class_idxs = encode_class(train_sentences, label_to_idx)
val_class_idxs = encode_class(val_sentences, label_to_idx)
test_class_idxs = encode_class(test_sentences, label_to_idx)

print(f"Training shape   : {train_sentence_idxs.shape, train_class_idxs.shape}")
print(f"validation shape : {val_class_idxs.shape, val_class_idxs.shape}")
print(f"Test shape       : {test_sentence_idxs.shape, test_class_idxs.shape}")
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# Training shape   : ((7222, 82), (7222, 82))
# validation shape : ((2006, 82), (2006, 82))
# Test shape       : ((802, 82), (802, 82))

# %% [markdown]
# ## Note
#
# - Number of sentences = 10030
# - Train : 72% (7222)
# - Val   : 8% (802)
# - Test  : 20% (2006)

# %% [markdown]
# # Build Model

# %% [markdown]
# ## Feature and Actual Class

# %%
train_feature = torch.LongTensor(train_sentence_idxs)
val_feature = torch.LongTensor(val_sentence_idxs)
test_feature = torch.LongTensor(test_sentence_idxs)

train_class = torch.LongTensor(train_class_idxs)
val_class = torch.LongTensor(val_class_idxs)
test_class = torch.LongTensor(test_class_idxs)

# %%
train_feature.shape, val_feature.shape, test_feature.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %%
train_class.shape, val_class.shape, test_class.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %% [markdown]
# ## Tensor Dataset

# %%
train_dataset = TensorDataset(train_feature, train_class)
val_dataset = TensorDataset(val_feature, val_class)
test_dataset = TensorDataset(test_feature, test_class)

# %% [markdown]
# ## Dataloader

# %%
train_dataloader = DataLoader(train_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
val_dataloader = DataLoader(val_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
test_dataloader = DataLoader(test_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)

# %% [markdown]
# ## Model

# %%
class POSTagger(nn.Module):
    def __init__(
        self,
        input_size=hyperparams.input_size,
        hidden_size=hyperparams.hidden_size,
        dropout=hyperparams.dropout,
        bias=hyperparams.bias,
        num_layers=hyperparams.num_hidden_layer,
        output_size=hyperparams.output_size,
        batch_first=hyperparams.batch_first,
        bidirectional=hyperparams.bidirectional,
        init_wb_with_kaiming_normal=hyperparams.init_wb_with_kaiming_normal
    ):
        super(POSTagger, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.num_layers = num_layers
        self.output_size = output_size
        self.batch_first = batch_first
        self.bidirectional = bidirectional
                
        self.feature = nn.LSTM(
            input_size = self.input_size,
            hidden_size = self.hidden_size,
            bias = self.bias,
            dropout = self.dropout,
            num_layers = self.num_layers,
            batch_first = self.batch_first,
            bidirectional = self.bidirectional
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(in_features=2 * self.hidden_size if hyperparams.bidirectional else self.hidden_size, out_features=self.output_size, bias=self.bias),
            nn.Softmax(dim=-1)
        )
        
        if init_wb_with_kaiming_normal:
            self.init_wb()

    def init_wb(self):
        for module in self.modules():
            if isinstance(module, (nn.Linear, nn.LSTM)):
                for name, param in module.named_parameters():
                    if "weight" in name:
                        nn.init.kaiming_normal_(param)
                    else:
                        nn.init.kaiming_normal_(param.reshape(1, -1))
        
    def forward(self, feature, hidden=None):
        output, (hidden, memory) = self.feature(feature, None)
        prob = self.classifier(output)

        return prob
    
model = POSTagger().to(hyperparams.device)
model
# Out:
# POSTagger(
#   (feature): LSTM(64, 128, bidirectional=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=24, bias=True)
#     (1): Softmax(dim=-1)
#   )
# )

# %% [markdown]
# ## Optimizer, Criterion, and Metric

# %%
optimizer = optim.Adam(model.parameters(), lr=hyperparams.lr)
criterion = nn.CrossEntropyLoss().to(hyperparams.device)
train_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", verbose=True, factor=0.5)

# %%
sum(param.numel() for param in model.parameters() if param.requires_grad)
# Out:
# 204824

# %% [markdown]
# ## Training Step

# %%
def training_step(dataloader, model, optimizer, criterion, metric, scheduler=None):
    model.train()
    
    batch_losses = []
    batch_metric_scores = []
    
    for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
        # Forward Propagation
        feature = rearrange(feature, "n s -> s n")
        actual_label = rearrange(actual_label, "n s -> s n")
        embedding = word_embeddings(feature)
        
        prob = model(
            embedding.to(hyperparams.device),
            actual_label.to(hyperparams.device)
        )
        
        prob = prob.reshape(-1, prob.shape[-1])
        actual_label = actual_label.reshape(-1)

        loss = criterion(prob, actual_label.to(hyperparams.device))
        metric_score = metric(prob, actual_label.to(hyperparams.device))
        metric_score = metric.compute()
                
        if scheduler is not None:
            scheduler.step(loss)
        
        batch_losses.append(loss.item())
        batch_metric_scores.append(metric_score)
        
        if len(dataloader) < 10:
            if batch % 1 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
        else:
            if batch % 15 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            
        # Backward Propagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Validation Step

# %%
def validation_step(dataloader, model, criterion, metric):
    model.eval()
    
    batch_losses = []
    batch_metric_scores = []
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob, actual_label.to(hyperparams.device))
            metric_score = metric.compute()

            batch_losses.append(loss.item())
            batch_metric_scores.append(metric_score)
            
            if len(dataloader) < 10 and (batch % 1 == 0 or batch == len(dataloader)):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            else:
                if batch % 15 == 0 or batch == len(dataloader):
                    batch_name = "Batch-" + str(batch)
                    print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                    with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                        f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Looping Step

# %%
now = datetime.now(pytz.timezone("Asia/Ujung_Pandang"))
path_name = now.strftime("%m-%d-%Y_%H-%M-%S")
root_path = f"../../../logs/classifier/{hyperparams.context_size}_contexts/fold_0{hyperparams.fold}/{path_name}"
os.makedirs(root_path)

def looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric, n_epoch=hyperparams.n_epoch, patience=hyperparams.patience, monitor="loss"):    
    start_time = time()
    
    epoch_training_losses = []
    epoch_training_metric_scores = []
    epoch_val_losses = []
    epoch_val_metric_scores = []
    patience_counter = 0
    
    # Hyperparameters
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write(f"HYPERPARAMETERS\n")
        f.write(f"{'-' * 80}\n")
        for name, value in vars(hyperparams).items():
            f.write(f"{name}: {value}\n")
        
        f.write("\n\nTRAINING PROGRESS\n")
        f.write(f"{'-' * 80}\n")
    
    # Training Progress
    for epoch in range(1, n_epoch + 1):
        print(f"EPOCH-{epoch}")
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"EPOCH-{epoch}\n")
            f.write(f"Training Step\n")
            
        # Training Step
        print("Training Step")
        batch_training_losses, batch_training_metric_scores = training_step(train_dataloader, model, optimizer, criterion, train_metric, scheduler=None)
        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))

        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))
        epoch_training_losses.append(epoch_training_loss.item())

        epoch_training_metric_score = torch.mean(torch.FloatTensor(batch_training_metric_scores))
        epoch_training_metric_scores.append(epoch_training_metric_score.item())
        
        # Validation Step
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"\nValidation Step\n")
            
        print("\nValidation Step")
        batch_val_losses, batch_val_metric_scores = validation_step(val_dataloader, model, criterion, val_metric)
        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))

        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))
        epoch_val_losses.append(epoch_val_loss.item())

        epoch_val_metric_score = torch.mean(torch.FloatTensor(batch_val_metric_scores))
        epoch_val_metric_scores.append(epoch_val_metric_score.item())
        
        with open(f"{root_path}/training_history.txt", "a") as f:
            if monitor == "loss":
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_losses[-1] < epoch_training_losses[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
            else:
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_metric_scores[-1] > epoch_training_metric_scores[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗\n")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
                    
            print("=" * 80, end="\n\n")
            
            f.write(f"{'=' * 80}\n\n")
            
            if patience_counter == patience:
                print(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                
                f.write(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                break
        
        train_metric.reset()
        val_metric.reset()
        
    finish_time = time()
    
    # Training plot 
    fig, (ax_loss, ax_metric_score) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    fig.suptitle(f"Training with context size = {hyperparams.context_size}")

    ax_loss.set_title("Loss")
    ax_loss.set_xlabel("Epoch")
    ax_loss.set_ylabel("Score")
    ax_loss.plot(epoch_training_losses, "green", label="Training")
    ax_loss.plot(epoch_val_losses, "orange", label="Validation")
    ax_loss.legend()
    ax_loss.grid()

    ax_metric_score.set_title("F1 Score")
    ax_metric_score.set_xlabel("Epoch")
    ax_metric_score.set_ylabel("Score")
    ax_metric_score.plot(epoch_training_metric_scores, "green", label="Training")
    ax_metric_score.plot(epoch_val_metric_scores, "orange", label="Validation")
    ax_metric_score.legend()
    ax_metric_score.grid()

    plt.savefig(f"{root_path}/training_plot.jpg", dpi=200)                        
    
    print("TRAINING SUMMARY")
    name_best_training_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_training_metric = f"Best {str(train_metric).split('(')[0]} validation".ljust(34)
    name_best_validation_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_validation_metric = f"Best {str(val_metric).split('(')[0]} validation".ljust(34)
    name_training_time = f"Training duration".ljust(34)
    name_training_date = f"Training date".ljust(34)
    
    print(f"{name_best_training_loss}: {best_training_loss:.4f}")
    print(f"{name_best_validation_loss}: {best_val_loss:.4f}")
    print(f"{name_best_training_metric}: {best_training_metric:.4f}")
    print(f"{name_best_validation_metric}: {best_val_metric:.4f}")
    print(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.")
    print(f"{name_training_date}: {now}")
    
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write("\nTRAINING SUMMARY\n")
        f.write(f"{'-' * 80}\n")
        f.write(f"{name_best_training_loss}: {best_training_loss:.4f}\n")
        f.write(f"{name_best_validation_loss}: {best_val_loss:.4f}\n")
        f.write(f"{name_best_training_metric}: {best_training_metric:.4f}\n")
        f.write(f"{name_best_validation_metric}: {best_val_metric:.4f}\n")
        f.write(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.\n")
        f.write(f"{name_training_date}: {now}\n")
    
    # Save epoch losses, epoch metric scores, model, state dict, and oov embedding dict
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_training_losses
    }).to_csv(f"{root_path}/training_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_training_metric_scores
    }).to_csv(f"{root_path}/training_metric_scores.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_val_losses
    }).to_csv(f"{root_path}/val_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_val_metric_scores
    }).to_csv(f"{root_path}/val_metric_scores.csv", index=False)    
    
    filename_model_params = f"{root_path}/model_params.pth"
    torch.save(best_state_dict, filename_model_params)
    
    return epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores

epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores = looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric)
# Out:
# EPOCH-1
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.4928 | MulticlassF1Score=0.1455
# Batch-30 : CrossEntropyLoss=2.4678 | MulticlassF1Score=0.2044
# Batch-45 : CrossEntropyLoss=2.5012 | MulticlassF1Score=0.2300
# Batch-60 : CrossEntropyLoss=2.4388 | MulticlassF1Score=0.2814
# Batch-75 : CrossEntropyLoss=2.3864 | MulticlassF1Score=0.3325
# Batch-90 : CrossEntropyLoss=2.3829 | MulticlassF1Score=0.3698
# Batch-105: CrossEntropyLoss=2.3654 | MulticlassF1Score=0.4033
# Batch-120: CrossEntropyLoss=2.3553 | MulticlassF1Score=0.4333
# Batch-135: CrossEntropyLoss=2.3458 | MulticlassF1Score=0.4594
# Batch-150: CrossEntropyLoss=2.3482 | MulticlassF1Score=0.4795
# Batch-165: CrossEntropyLoss=2.3390 | MulticlassF1Score=0.4966
# Batch-180: CrossEntropyLoss=2.3416 | MulticlassF1Score=0.5117
# Batch-195: CrossEntropyLoss=2.3479 | MulticlassF1Score=0.5244
# Batch-210: CrossEntropyLoss=2.3601 | MulticlassF1Score=0.5349
# Batch-225: CrossEntropyLoss=2.3417 | MulticlassF1Score=0.5438
# Batch-226: CrossEntropyLoss=2.3475 | MulticlassF1Score=0.5442
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3428 | MulticlassF1Score=0.6737
# Batch-30 : CrossEntropyLoss=2.3484 | MulticlassF1Score=0.6760
# Batch-45 : CrossEntropyLoss=2.3492 | MulticlassF1Score=0.6754
# Batch-60 : CrossEntropyLoss=2.3397 | MulticlassF1Score=0.6745
# Batch-63 : CrossEntropyLoss=2.3430 | MulticlassF1Score=0.6743
#
# Training   : Mean CrossEntropyLoss = 2.4018 | Mean MulticlassF1Score = 0.3829
# Validation : Mean CrossEntropyLoss = 2.3495 | Mean MulticlassF1Score = 0.6738
# ================================================================================
#
# EPOCH-2
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3502 | MulticlassF1Score=0.6713
# Batch-30 : CrossEntropyLoss=2.3708 | MulticlassF1Score=0.6744
# Batch-45 : CrossEntropyLoss=2.3456 | MulticlassF1Score=0.6751
# Batch-60 : CrossEntropyLoss=2.3578 | MulticlassF1Score=0.6754
# Batch-75 : CrossEntropyLoss=2.3442 | MulticlassF1Score=0.6765
# Batch-90 : CrossEntropyLoss=2.3259 | MulticlassF1Score=0.6758
# Batch-105: CrossEntropyLoss=2.3629 | MulticlassF1Score=0.6812
# Batch-120: CrossEntropyLoss=2.3519 | MulticlassF1Score=0.6862
# Batch-135: CrossEntropyLoss=2.3352 | MulticlassF1Score=0.6903
# Batch-150: CrossEntropyLoss=2.3224 | MulticlassF1Score=0.6937
# Batch-165: CrossEntropyLoss=2.3161 | MulticlassF1Score=0.6997
# Batch-180: CrossEntropyLoss=2.3274 | MulticlassF1Score=0.7067
# Batch-195: CrossEntropyLoss=2.3168 | MulticlassF1Score=0.7126
# Batch-210: CrossEntropyLoss=2.3178 | MulticlassF1Score=0.7178
# Batch-225: CrossEntropyLoss=2.3233 | MulticlassF1Score=0.7229
# Batch-226: CrossEntropyLoss=2.3025 | MulticlassF1Score=0.7231
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3199 | MulticlassF1Score=0.7828
# Batch-30 : CrossEntropyLoss=2.3265 | MulticlassF1Score=0.7899
# Batch-45 : CrossEntropyLoss=2.3237 | MulticlassF1Score=0.7881
# Batch-60 : CrossEntropyLoss=2.3083 | MulticlassF1Score=0.7878
# Batch-63 : CrossEntropyLoss=2.3078 | MulticlassF1Score=0.7878
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3347 | Mean MulticlassF1Score = 0.6892
# Validation : Mean CrossEntropyLoss = 2.3146 | Mean MulticlassF1Score = 0.7875
# ================================================================================
#
# EPOCH-3
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3099 | MulticlassF1Score=0.7926
# Batch-30 : CrossEntropyLoss=2.3100 | MulticlassF1Score=0.7962
# Batch-45 : CrossEntropyLoss=2.3205 | MulticlassF1Score=0.7943
# Batch-60 : CrossEntropyLoss=2.3168 | MulticlassF1Score=0.7934
# Batch-75 : CrossEntropyLoss=2.3199 | MulticlassF1Score=0.7921
# Batch-90 : CrossEntropyLoss=2.3171 | MulticlassF1Score=0.7910
# Batch-105: CrossEntropyLoss=2.3166 | MulticlassF1Score=0.7916
# Batch-120: CrossEntropyLoss=2.3135 | MulticlassF1Score=0.7908
# Batch-135: CrossEntropyLoss=2.3140 | MulticlassF1Score=0.7916
# Batch-150: CrossEntropyLoss=2.3111 | MulticlassF1Score=0.7914
# Batch-165: CrossEntropyLoss=2.3109 | MulticlassF1Score=0.7921
# Batch-180: CrossEntropyLoss=2.3136 | MulticlassF1Score=0.7919
# Batch-195: CrossEntropyLoss=2.3037 | MulticlassF1Score=0.7925
# Batch-210: CrossEntropyLoss=2.2993 | MulticlassF1Score=0.7927
# Batch-225: CrossEntropyLoss=2.3071 | MulticlassF1Score=0.7927
# Batch-226: CrossEntropyLoss=2.2976 | MulticlassF1Score=0.7929
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3085 | MulticlassF1Score=0.7906
# Batch-30 : CrossEntropyLoss=2.3153 | MulticlassF1Score=0.7928
# Batch-45 : CrossEntropyLoss=2.3180 | MulticlassF1Score=0.7933
# Batch-60 : CrossEntropyLoss=2.3160 | MulticlassF1Score=0.7936
# Batch-63 : CrossEntropyLoss=2.3207 | MulticlassF1Score=0.7927
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3124 | Mean MulticlassF1Score = 0.7928
# Validation : Mean CrossEntropyLoss = 2.3125 | Mean MulticlassF1Score = 0.7915
# ================================================================================
#
# EPOCH-4
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3068 | MulticlassF1Score=0.8007
# Batch-30 : CrossEntropyLoss=2.3086 | MulticlassF1Score=0.7971
# Batch-45 : CrossEntropyLoss=2.3070 | MulticlassF1Score=0.7980
# Batch-60 : CrossEntropyLoss=2.3165 | MulticlassF1Score=0.7968
# Batch-75 : CrossEntropyLoss=2.3056 | MulticlassF1Score=0.7960
# Batch-90 : CrossEntropyLoss=2.3131 | MulticlassF1Score=0.7966
# Batch-105: CrossEntropyLoss=2.3046 | MulticlassF1Score=0.7987
# Batch-120: CrossEntropyLoss=2.3067 | MulticlassF1Score=0.8010
# Batch-135: CrossEntropyLoss=2.3149 | MulticlassF1Score=0.8033
# Batch-150: CrossEntropyLoss=2.3061 | MulticlassF1Score=0.8048
# Batch-165: CrossEntropyLoss=2.3099 | MulticlassF1Score=0.8058
# Batch-180: CrossEntropyLoss=2.3007 | MulticlassF1Score=0.8086
# Batch-195: CrossEntropyLoss=2.2976 | MulticlassF1Score=0.8102
# Batch-210: CrossEntropyLoss=2.3065 | MulticlassF1Score=0.8117
# Batch-225: CrossEntropyLoss=2.3047 | MulticlassF1Score=0.8130
# Batch-226: CrossEntropyLoss=2.2972 | MulticlassF1Score=0.8131
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3068 | MulticlassF1Score=0.8291
# Batch-30 : CrossEntropyLoss=2.2962 | MulticlassF1Score=0.8319
# Batch-45 : CrossEntropyLoss=2.3111 | MulticlassF1Score=0.8309
# Batch-60 : CrossEntropyLoss=2.2934 | MulticlassF1Score=0.8313
# Batch-63 : CrossEntropyLoss=2.3035 | MulticlassF1Score=0.8315
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3059 | Mean MulticlassF1Score = 0.8025
# Validation : Mean CrossEntropyLoss = 2.3002 | Mean MulticlassF1Score = 0.8297
# ================================================================================
#
# EPOCH-5
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2865 | MulticlassF1Score=0.8388
# Batch-30 : CrossEntropyLoss=2.2972 | MulticlassF1Score=0.8368
# Batch-45 : CrossEntropyLoss=2.2846 | MulticlassF1Score=0.8383
# Batch-60 : CrossEntropyLoss=2.3087 | MulticlassF1Score=0.8373
# Batch-75 : CrossEntropyLoss=2.2888 | MulticlassF1Score=0.8385
# Batch-90 : CrossEntropyLoss=2.2905 | MulticlassF1Score=0.8382
# Batch-105: CrossEntropyLoss=2.2926 | MulticlassF1Score=0.8383
# Batch-120: CrossEntropyLoss=2.3002 | MulticlassF1Score=0.8369
# Batch-135: CrossEntropyLoss=2.2984 | MulticlassF1Score=0.8367
# Batch-150: CrossEntropyLoss=2.3027 | MulticlassF1Score=0.8367
# Batch-165: CrossEntropyLoss=2.3073 | MulticlassF1Score=0.8361
# Batch-180: CrossEntropyLoss=2.3041 | MulticlassF1Score=0.8363
# Batch-195: CrossEntropyLoss=2.2944 | MulticlassF1Score=0.8364
# Batch-210: CrossEntropyLoss=2.2904 | MulticlassF1Score=0.8366
# Batch-225: CrossEntropyLoss=2.2962 | MulticlassF1Score=0.8364
# Batch-226: CrossEntropyLoss=2.3059 | MulticlassF1Score=0.8363
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3064 | MulticlassF1Score=0.8339
# Batch-30 : CrossEntropyLoss=2.3082 | MulticlassF1Score=0.8328
# Batch-45 : CrossEntropyLoss=2.3095 | MulticlassF1Score=0.8322
# Batch-60 : CrossEntropyLoss=2.2976 | MulticlassF1Score=0.8339
# Batch-63 : CrossEntropyLoss=2.3039 | MulticlassF1Score=0.8334
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2985 | Mean MulticlassF1Score = 0.8371
# Validation : Mean CrossEntropyLoss = 2.2995 | Mean MulticlassF1Score = 0.8351
# ================================================================================
#
# EPOCH-6
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3003 | MulticlassF1Score=0.8477
# Batch-30 : CrossEntropyLoss=2.3072 | MulticlassF1Score=0.8405
# Batch-45 : CrossEntropyLoss=2.2919 | MulticlassF1Score=0.8367
# Batch-60 : CrossEntropyLoss=2.2934 | MulticlassF1Score=0.8379
# Batch-75 : CrossEntropyLoss=2.2934 | MulticlassF1Score=0.8382
# Batch-90 : CrossEntropyLoss=2.2981 | MulticlassF1Score=0.8376
# Batch-105: CrossEntropyLoss=2.3037 | MulticlassF1Score=0.8378
# Batch-120: CrossEntropyLoss=2.3040 | MulticlassF1Score=0.8381
# Batch-135: CrossEntropyLoss=2.3016 | MulticlassF1Score=0.8385
# Batch-150: CrossEntropyLoss=2.2935 | MulticlassF1Score=0.8383
# Batch-165: CrossEntropyLoss=2.2982 | MulticlassF1Score=0.8380
# Batch-180: CrossEntropyLoss=2.3015 | MulticlassF1Score=0.8382
# Batch-195: CrossEntropyLoss=2.2961 | MulticlassF1Score=0.8384
# Batch-210: CrossEntropyLoss=2.2949 | MulticlassF1Score=0.8389
# Batch-225: CrossEntropyLoss=2.3095 | MulticlassF1Score=0.8386
# Batch-226: CrossEntropyLoss=2.2967 | MulticlassF1Score=0.8386
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3039 | MulticlassF1Score=0.8347
# Batch-30 : CrossEntropyLoss=2.2891 | MulticlassF1Score=0.8344
# Batch-45 : CrossEntropyLoss=2.2955 | MulticlassF1Score=0.8357
# Batch-60 : CrossEntropyLoss=2.3013 | MulticlassF1Score=0.8342
# Batch-63 : CrossEntropyLoss=2.2949 | MulticlassF1Score=0.8342
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2976 | Mean MulticlassF1Score = 0.8390
# Validation : Mean CrossEntropyLoss = 2.2990 | Mean MulticlassF1Score = 0.8338
# ================================================================================
#
# EPOCH-7
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2896 | MulticlassF1Score=0.8393
# Batch-30 : CrossEntropyLoss=2.2884 | MulticlassF1Score=0.8426
# Batch-45 : CrossEntropyLoss=2.2932 | MulticlassF1Score=0.8423
# Batch-60 : CrossEntropyLoss=2.2941 | MulticlassF1Score=0.8415
# Batch-75 : CrossEntropyLoss=2.2922 | MulticlassF1Score=0.8411
# Batch-90 : CrossEntropyLoss=2.2961 | MulticlassF1Score=0.8407
# Batch-105: CrossEntropyLoss=2.2893 | MulticlassF1Score=0.8410
# Batch-120: CrossEntropyLoss=2.2949 | MulticlassF1Score=0.8409
# Batch-135: CrossEntropyLoss=2.2969 | MulticlassF1Score=0.8409
# Batch-150: CrossEntropyLoss=2.2920 | MulticlassF1Score=0.8407
# Batch-165: CrossEntropyLoss=2.3016 | MulticlassF1Score=0.8410
# Batch-180: CrossEntropyLoss=2.2957 | MulticlassF1Score=0.8405
# Batch-195: CrossEntropyLoss=2.2988 | MulticlassF1Score=0.8406
# Batch-210: CrossEntropyLoss=2.2947 | MulticlassF1Score=0.8408
# Batch-225: CrossEntropyLoss=2.3018 | MulticlassF1Score=0.8406
# Batch-226: CrossEntropyLoss=2.2980 | MulticlassF1Score=0.8407
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2959 | MulticlassF1Score=0.8404
# Batch-30 : CrossEntropyLoss=2.3054 | MulticlassF1Score=0.8347
# Batch-45 : CrossEntropyLoss=2.2937 | MulticlassF1Score=0.8346
# Batch-60 : CrossEntropyLoss=2.2946 | MulticlassF1Score=0.8352
# Batch-63 : CrossEntropyLoss=2.3057 | MulticlassF1Score=0.8348
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2970 | Mean MulticlassF1Score = 0.8411
# Validation : Mean CrossEntropyLoss = 2.2989 | Mean MulticlassF1Score = 0.8363
# ================================================================================
#
# EPOCH-8
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2931 | MulticlassF1Score=0.8368
# Batch-30 : CrossEntropyLoss=2.3016 | MulticlassF1Score=0.8403
# Batch-45 : CrossEntropyLoss=2.2915 | MulticlassF1Score=0.8457
# Batch-60 : CrossEntropyLoss=2.2909 | MulticlassF1Score=0.8502
# Batch-75 : CrossEntropyLoss=2.2893 | MulticlassF1Score=0.8532
# Batch-90 : CrossEntropyLoss=2.2876 | MulticlassF1Score=0.8563
# Batch-105: CrossEntropyLoss=2.2876 | MulticlassF1Score=0.8575
# Batch-120: CrossEntropyLoss=2.2930 | MulticlassF1Score=0.8587
# Batch-135: CrossEntropyLoss=2.2926 | MulticlassF1Score=0.8599
# Batch-150: CrossEntropyLoss=2.2975 | MulticlassF1Score=0.8605
# Batch-165: CrossEntropyLoss=2.2875 | MulticlassF1Score=0.8614
# Batch-180: CrossEntropyLoss=2.2852 | MulticlassF1Score=0.8621
# Batch-195: CrossEntropyLoss=2.2915 | MulticlassF1Score=0.8629
# Batch-210: CrossEntropyLoss=2.2781 | MulticlassF1Score=0.8630
# Batch-225: CrossEntropyLoss=2.2813 | MulticlassF1Score=0.8640
# Batch-226: CrossEntropyLoss=2.2932 | MulticlassF1Score=0.8640
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2981 | MulticlassF1Score=0.8638
# Batch-30 : CrossEntropyLoss=2.2803 | MulticlassF1Score=0.8678
# Batch-45 : CrossEntropyLoss=2.2849 | MulticlassF1Score=0.8655
# Batch-60 : CrossEntropyLoss=2.2936 | MulticlassF1Score=0.8641
# Batch-63 : CrossEntropyLoss=2.2798 | MulticlassF1Score=0.8640
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2900 | Mean MulticlassF1Score = 0.8550
# Validation : Mean CrossEntropyLoss = 2.2900 | Mean MulticlassF1Score = 0.8664
# ================================================================================
#
# EPOCH-9
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2877 | MulticlassF1Score=0.8695
# Batch-30 : CrossEntropyLoss=2.2872 | MulticlassF1Score=0.8714
# Batch-45 : CrossEntropyLoss=2.2872 | MulticlassF1Score=0.8704
# Batch-60 : CrossEntropyLoss=2.2898 | MulticlassF1Score=0.8708
# Batch-75 : CrossEntropyLoss=2.2841 | MulticlassF1Score=0.8711
# Batch-90 : CrossEntropyLoss=2.2834 | MulticlassF1Score=0.8716
# Batch-105: CrossEntropyLoss=2.2854 | MulticlassF1Score=0.8722
# Batch-120: CrossEntropyLoss=2.2874 | MulticlassF1Score=0.8720
# Batch-135: CrossEntropyLoss=2.2977 | MulticlassF1Score=0.8717
# Batch-150: CrossEntropyLoss=2.2801 | MulticlassF1Score=0.8725
# Batch-165: CrossEntropyLoss=2.2919 | MulticlassF1Score=0.8726
# Batch-180: CrossEntropyLoss=2.2901 | MulticlassF1Score=0.8727
# Batch-195: CrossEntropyLoss=2.2789 | MulticlassF1Score=0.8726
# Batch-210: CrossEntropyLoss=2.2898 | MulticlassF1Score=0.8727
# Batch-225: CrossEntropyLoss=2.2766 | MulticlassF1Score=0.8727
# Batch-226: CrossEntropyLoss=2.2888 | MulticlassF1Score=0.8727
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2889 | MulticlassF1Score=0.8660
# Batch-30 : CrossEntropyLoss=2.2947 | MulticlassF1Score=0.8662
# Batch-45 : CrossEntropyLoss=2.2834 | MulticlassF1Score=0.8670
# Batch-60 : CrossEntropyLoss=2.2963 | MulticlassF1Score=0.8665
# Batch-63 : CrossEntropyLoss=2.2950 | MulticlassF1Score=0.8667
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2873 | Mean MulticlassF1Score = 0.8714
# Validation : Mean CrossEntropyLoss = 2.2892 | Mean MulticlassF1Score = 0.8655
# ================================================================================
#
# EPOCH-10
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2875 | MulticlassF1Score=0.8742
# Batch-30 : CrossEntropyLoss=2.2742 | MulticlassF1Score=0.8776
# Batch-45 : CrossEntropyLoss=2.2851 | MulticlassF1Score=0.8779
# Batch-60 : CrossEntropyLoss=2.2876 | MulticlassF1Score=0.8810
# Batch-75 : CrossEntropyLoss=2.2783 | MulticlassF1Score=0.8832
# Batch-90 : CrossEntropyLoss=2.2791 | MulticlassF1Score=0.8852
# Batch-105: CrossEntropyLoss=2.2836 | MulticlassF1Score=0.8865
# Batch-120: CrossEntropyLoss=2.2796 | MulticlassF1Score=0.8872
# Batch-135: CrossEntropyLoss=2.2815 | MulticlassF1Score=0.8885
# Batch-150: CrossEntropyLoss=2.2829 | MulticlassF1Score=0.8889
# Batch-165: CrossEntropyLoss=2.2838 | MulticlassF1Score=0.8895
# Batch-180: CrossEntropyLoss=2.2748 | MulticlassF1Score=0.8897
# Batch-195: CrossEntropyLoss=2.2795 | MulticlassF1Score=0.8898
# Batch-210: CrossEntropyLoss=2.2844 | MulticlassF1Score=0.8902
# Batch-225: CrossEntropyLoss=2.2797 | MulticlassF1Score=0.8905
# Batch-226: CrossEntropyLoss=2.2752 | MulticlassF1Score=0.8905
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2788 | MulticlassF1Score=0.8865
# Batch-30 : CrossEntropyLoss=2.2837 | MulticlassF1Score=0.8858
# Batch-45 : CrossEntropyLoss=2.2872 | MulticlassF1Score=0.8867
# Batch-60 : CrossEntropyLoss=2.2796 | MulticlassF1Score=0.8884
# Batch-63 : CrossEntropyLoss=2.2734 | MulticlassF1Score=0.8886
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2820 | Mean MulticlassF1Score = 0.8849
# Validation : Mean CrossEntropyLoss = 2.2825 | Mean MulticlassF1Score = 0.8861
# ================================================================================
#
# EPOCH-11
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2813 | MulticlassF1Score=0.8953
# Batch-30 : CrossEntropyLoss=2.2762 | MulticlassF1Score=0.8963
# Batch-45 : CrossEntropyLoss=2.2857 | MulticlassF1Score=0.8964
# Batch-60 : CrossEntropyLoss=2.2792 | MulticlassF1Score=0.8972
# Batch-75 : CrossEntropyLoss=2.2771 | MulticlassF1Score=0.8976
# Batch-90 : CrossEntropyLoss=2.2855 | MulticlassF1Score=0.8976
# Batch-105: CrossEntropyLoss=2.2853 | MulticlassF1Score=0.8971
# Batch-120: CrossEntropyLoss=2.2809 | MulticlassF1Score=0.8967
# Batch-135: CrossEntropyLoss=2.2804 | MulticlassF1Score=0.8972
# Batch-150: CrossEntropyLoss=2.2792 | MulticlassF1Score=0.8973
# Batch-165: CrossEntropyLoss=2.2699 | MulticlassF1Score=0.8974
# Batch-180: CrossEntropyLoss=2.2780 | MulticlassF1Score=0.8973
# Batch-195: CrossEntropyLoss=2.2731 | MulticlassF1Score=0.8974
# Batch-210: CrossEntropyLoss=2.2777 | MulticlassF1Score=0.8976
# Batch-225: CrossEntropyLoss=2.2732 | MulticlassF1Score=0.8975
# Batch-226: CrossEntropyLoss=2.2789 | MulticlassF1Score=0.8975
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2868 | MulticlassF1Score=0.8855
# Batch-30 : CrossEntropyLoss=2.2829 | MulticlassF1Score=0.8900
# Batch-45 : CrossEntropyLoss=2.2880 | MulticlassF1Score=0.8904
# Batch-60 : CrossEntropyLoss=2.2811 | MulticlassF1Score=0.8905
# Batch-63 : CrossEntropyLoss=2.2936 | MulticlassF1Score=0.8902
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2796 | Mean MulticlassF1Score = 0.8971
# Validation : Mean CrossEntropyLoss = 2.2820 | Mean MulticlassF1Score = 0.8887
# ================================================================================
#
# EPOCH-12
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2755 | MulticlassF1Score=0.8989
# Batch-30 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.8991
# Batch-45 : CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9019
# Batch-60 : CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9019
# Batch-75 : CrossEntropyLoss=2.2838 | MulticlassF1Score=0.9018
# Batch-90 : CrossEntropyLoss=2.2796 | MulticlassF1Score=0.9014
# Batch-105: CrossEntropyLoss=2.2889 | MulticlassF1Score=0.9004
# Batch-120: CrossEntropyLoss=2.2814 | MulticlassF1Score=0.9003
# Batch-135: CrossEntropyLoss=2.2838 | MulticlassF1Score=0.9003
# Batch-150: CrossEntropyLoss=2.2917 | MulticlassF1Score=0.8999
# Batch-165: CrossEntropyLoss=2.2799 | MulticlassF1Score=0.8993
# Batch-180: CrossEntropyLoss=2.2799 | MulticlassF1Score=0.8992
# Batch-195: CrossEntropyLoss=2.2760 | MulticlassF1Score=0.8998
# Batch-210: CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9002
# Batch-225: CrossEntropyLoss=2.2783 | MulticlassF1Score=0.8999
# Batch-226: CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9000
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2803 | MulticlassF1Score=0.8930
# Batch-30 : CrossEntropyLoss=2.2851 | MulticlassF1Score=0.8935
# Batch-45 : CrossEntropyLoss=2.2813 | MulticlassF1Score=0.8930
# Batch-60 : CrossEntropyLoss=2.2868 | MulticlassF1Score=0.8924
# Batch-63 : CrossEntropyLoss=2.2799 | MulticlassF1Score=0.8923
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2788 | Mean MulticlassF1Score = 0.9001
# Validation : Mean CrossEntropyLoss = 2.2813 | Mean MulticlassF1Score = 0.8934
# ================================================================================
#
# EPOCH-13
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9048
# Batch-30 : CrossEntropyLoss=2.2825 | MulticlassF1Score=0.9012
# Batch-45 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9017
# Batch-60 : CrossEntropyLoss=2.2802 | MulticlassF1Score=0.9023
# Batch-75 : CrossEntropyLoss=2.2777 | MulticlassF1Score=0.9028
# Batch-90 : CrossEntropyLoss=2.2872 | MulticlassF1Score=0.9026
# Batch-105: CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9028
# Batch-120: CrossEntropyLoss=2.2782 | MulticlassF1Score=0.9029
# Batch-135: CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9030
# Batch-150: CrossEntropyLoss=2.2765 | MulticlassF1Score=0.9031
# Batch-165: CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9030
# Batch-180: CrossEntropyLoss=2.2770 | MulticlassF1Score=0.9027
# Batch-195: CrossEntropyLoss=2.2751 | MulticlassF1Score=0.9025
# Batch-210: CrossEntropyLoss=2.2794 | MulticlassF1Score=0.9022
# Batch-225: CrossEntropyLoss=2.2803 | MulticlassF1Score=0.9023
# Batch-226: CrossEntropyLoss=2.2804 | MulticlassF1Score=0.9023
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2767 | MulticlassF1Score=0.8932
# Batch-30 : CrossEntropyLoss=2.2791 | MulticlassF1Score=0.8964
# Batch-45 : CrossEntropyLoss=2.2808 | MulticlassF1Score=0.8952
# Batch-60 : CrossEntropyLoss=2.2872 | MulticlassF1Score=0.8927
# Batch-63 : CrossEntropyLoss=2.2822 | MulticlassF1Score=0.8924
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2780 | Mean MulticlassF1Score = 0.9024
# Validation : Mean CrossEntropyLoss = 2.2812 | Mean MulticlassF1Score = 0.8929
# ================================================================================
#
# EPOCH-14
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2778 | MulticlassF1Score=0.9002
# Batch-30 : CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9014
# Batch-45 : CrossEntropyLoss=2.2805 | MulticlassF1Score=0.9015
# Batch-60 : CrossEntropyLoss=2.2863 | MulticlassF1Score=0.9022
# Batch-75 : CrossEntropyLoss=2.2820 | MulticlassF1Score=0.9031
# Batch-90 : CrossEntropyLoss=2.2771 | MulticlassF1Score=0.9030
# Batch-105: CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9033
# Batch-120: CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9032
# Batch-135: CrossEntropyLoss=2.2802 | MulticlassF1Score=0.9029
# Batch-150: CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9032
# Batch-165: CrossEntropyLoss=2.2805 | MulticlassF1Score=0.9030
# Batch-180: CrossEntropyLoss=2.2847 | MulticlassF1Score=0.9029
# Batch-195: CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9033
# Batch-210: CrossEntropyLoss=2.2771 | MulticlassF1Score=0.9032
# Batch-225: CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9034
# Batch-226: CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9035
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2837 | MulticlassF1Score=0.8937
# Batch-30 : CrossEntropyLoss=2.2819 | MulticlassF1Score=0.8936
# Batch-45 : CrossEntropyLoss=2.2812 | MulticlassF1Score=0.8929
# Batch-60 : CrossEntropyLoss=2.2824 | MulticlassF1Score=0.8928
# Batch-63 : CrossEntropyLoss=2.2758 | MulticlassF1Score=0.8929
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2776 | Mean MulticlassF1Score = 0.9025
# Validation : Mean CrossEntropyLoss = 2.2809 | Mean MulticlassF1Score = 0.8938
# ================================================================================
#
# EPOCH-15
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9079
# Batch-30 : CrossEntropyLoss=2.2802 | MulticlassF1Score=0.9082
# Batch-45 : CrossEntropyLoss=2.2781 | MulticlassF1Score=0.9072
# Batch-60 : CrossEntropyLoss=2.2828 | MulticlassF1Score=0.9062
# Batch-75 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9062
# Batch-90 : CrossEntropyLoss=2.2761 | MulticlassF1Score=0.9057
# Batch-105: CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9052
# Batch-120: CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9049
# Batch-135: CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9047
# Batch-150: CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9044
# Batch-165: CrossEntropyLoss=2.2785 | MulticlassF1Score=0.9041
# Batch-180: CrossEntropyLoss=2.2768 | MulticlassF1Score=0.9046
# Batch-195: CrossEntropyLoss=2.2772 | MulticlassF1Score=0.9045
# Batch-210: CrossEntropyLoss=2.2787 | MulticlassF1Score=0.9042
# Batch-225: CrossEntropyLoss=2.2776 | MulticlassF1Score=0.9045
# Batch-226: CrossEntropyLoss=2.2767 | MulticlassF1Score=0.9045
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2819 | MulticlassF1Score=0.8951
# Batch-30 : CrossEntropyLoss=2.2825 | MulticlassF1Score=0.8939
# Batch-45 : CrossEntropyLoss=2.2799 | MulticlassF1Score=0.8936
# Batch-60 : CrossEntropyLoss=2.2765 | MulticlassF1Score=0.8940
# Batch-63 : CrossEntropyLoss=2.2822 | MulticlassF1Score=0.8941
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2772 | Mean MulticlassF1Score = 0.9059
# Validation : Mean CrossEntropyLoss = 2.2807 | Mean MulticlassF1Score = 0.8943
# ================================================================================
#
# EPOCH-16
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9032
# Batch-30 : CrossEntropyLoss=2.2778 | MulticlassF1Score=0.9044
# Batch-45 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9049
# Batch-60 : CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9048
# Batch-75 : CrossEntropyLoss=2.2801 | MulticlassF1Score=0.9056
# Batch-90 : CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9063
# Batch-105: CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9061
# Batch-120: CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9061
# Batch-135: CrossEntropyLoss=2.2790 | MulticlassF1Score=0.9061
# Batch-150: CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9062
# Batch-165: CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9062
# Batch-180: CrossEntropyLoss=2.2768 | MulticlassF1Score=0.9059
# Batch-195: CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9057
# Batch-210: CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9059
# Batch-225: CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9058
# Batch-226: CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9058
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2857 | MulticlassF1Score=0.8900
# Batch-30 : CrossEntropyLoss=2.2831 | MulticlassF1Score=0.8913
# Batch-45 : CrossEntropyLoss=2.2865 | MulticlassF1Score=0.8926
# Batch-60 : CrossEntropyLoss=2.2872 | MulticlassF1Score=0.8936
# Batch-63 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.8936
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2768 | Mean MulticlassF1Score = 0.9054
# Validation : Mean CrossEntropyLoss = 2.2806 | Mean MulticlassF1Score = 0.8904
# ================================================================================
#
# EPOCH-17
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2747 | MulticlassF1Score=0.9015
# Batch-30 : CrossEntropyLoss=2.2791 | MulticlassF1Score=0.9033
# Batch-45 : CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9056
# Batch-60 : CrossEntropyLoss=2.2781 | MulticlassF1Score=0.9051
# Batch-75 : CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9060
# Batch-90 : CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9063
# Batch-105: CrossEntropyLoss=2.2792 | MulticlassF1Score=0.9070
# Batch-120: CrossEntropyLoss=2.2786 | MulticlassF1Score=0.9074
# Batch-135: CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9075
# Batch-150: CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9080
# Batch-165: CrossEntropyLoss=2.2784 | MulticlassF1Score=0.9079
# Batch-180: CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9075
# Batch-195: CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9076
# Batch-210: CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9072
# Batch-225: CrossEntropyLoss=2.2788 | MulticlassF1Score=0.9068
# Batch-226: CrossEntropyLoss=2.2851 | MulticlassF1Score=0.9068
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2862 | MulticlassF1Score=0.8885
# Batch-30 : CrossEntropyLoss=2.2785 | MulticlassF1Score=0.8917
# Batch-45 : CrossEntropyLoss=2.2739 | MulticlassF1Score=0.8937
# Batch-60 : CrossEntropyLoss=2.2756 | MulticlassF1Score=0.8933
# Batch-63 : CrossEntropyLoss=2.2800 | MulticlassF1Score=0.8934
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2764 | Mean MulticlassF1Score = 0.9064
# Validation : Mean CrossEntropyLoss = 2.2807 | Mean MulticlassF1Score = 0.8925
# ================================================================================
#
# EPOCH-18
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9096
# Batch-30 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9090
# Batch-45 : CrossEntropyLoss=2.2853 | MulticlassF1Score=0.9083
# Batch-60 : CrossEntropyLoss=2.2772 | MulticlassF1Score=0.9086
# Batch-75 : CrossEntropyLoss=2.2793 | MulticlassF1Score=0.9091
# Batch-90 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9090
# Batch-105: CrossEntropyLoss=2.2796 | MulticlassF1Score=0.9083
# Batch-120: CrossEntropyLoss=2.2762 | MulticlassF1Score=0.9084
# Batch-135: CrossEntropyLoss=2.2786 | MulticlassF1Score=0.9082
# Batch-150: CrossEntropyLoss=2.2753 | MulticlassF1Score=0.9085
# Batch-165: CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9084
# Batch-180: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9088
# Batch-195: CrossEntropyLoss=2.2808 | MulticlassF1Score=0.9082
# Batch-210: CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9081
# Batch-225: CrossEntropyLoss=2.2813 | MulticlassF1Score=0.9080
# Batch-226: CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9080
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2807 | MulticlassF1Score=0.8954
# Batch-30 : CrossEntropyLoss=2.2782 | MulticlassF1Score=0.8958
# Batch-45 : CrossEntropyLoss=2.2839 | MulticlassF1Score=0.8941
# Batch-60 : CrossEntropyLoss=2.2875 | MulticlassF1Score=0.8944
# Batch-63 : CrossEntropyLoss=2.2757 | MulticlassF1Score=0.8943
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2760 | Mean MulticlassF1Score = 0.9088
# Validation : Mean CrossEntropyLoss = 2.2804 | Mean MulticlassF1Score = 0.8946
# ================================================================================
#
# EPOCH-19
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9103
# Batch-30 : CrossEntropyLoss=2.2773 | MulticlassF1Score=0.9104
# Batch-45 : CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9100
# Batch-60 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9101
# Batch-75 : CrossEntropyLoss=2.2796 | MulticlassF1Score=0.9086
# Batch-90 : CrossEntropyLoss=2.2781 | MulticlassF1Score=0.9088
# Batch-105: CrossEntropyLoss=2.2769 | MulticlassF1Score=0.9092
# Batch-120: CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9094
# Batch-135: CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9091
# Batch-150: CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9091
# Batch-165: CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9089
# Batch-180: CrossEntropyLoss=2.2818 | MulticlassF1Score=0.9086
# Batch-195: CrossEntropyLoss=2.2753 | MulticlassF1Score=0.9088
# Batch-210: CrossEntropyLoss=2.2769 | MulticlassF1Score=0.9086
# Batch-225: CrossEntropyLoss=2.2761 | MulticlassF1Score=0.9086
# Batch-226: CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9086
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2794 | MulticlassF1Score=0.8941
# Batch-30 : CrossEntropyLoss=2.2751 | MulticlassF1Score=0.8940
# Batch-45 : CrossEntropyLoss=2.2827 | MulticlassF1Score=0.8946
# Batch-60 : CrossEntropyLoss=2.2904 | MulticlassF1Score=0.8952
# Batch-63 : CrossEntropyLoss=2.2833 | MulticlassF1Score=0.8950
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2758 | Mean MulticlassF1Score = 0.9092
# Validation : Mean CrossEntropyLoss = 2.2802 | Mean MulticlassF1Score = 0.8947
# ================================================================================
#
# EPOCH-20
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2753 | MulticlassF1Score=0.9107
# Batch-30 : CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9108
# Batch-45 : CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9097
# Batch-60 : CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9103
# Batch-75 : CrossEntropyLoss=2.2801 | MulticlassF1Score=0.9096
# Batch-90 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9092
# Batch-105: CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9094
# Batch-120: CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9093
# Batch-135: CrossEntropyLoss=2.2815 | MulticlassF1Score=0.9092
# Batch-150: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9089
# Batch-165: CrossEntropyLoss=2.2776 | MulticlassF1Score=0.9089
# Batch-180: CrossEntropyLoss=2.2780 | MulticlassF1Score=0.9090
# Batch-195: CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9089
# Batch-210: CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9094
# Batch-225: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9093
# Batch-226: CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9093
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2785 | MulticlassF1Score=0.8924
# Batch-30 : CrossEntropyLoss=2.2792 | MulticlassF1Score=0.8925
# Batch-45 : CrossEntropyLoss=2.2771 | MulticlassF1Score=0.8934
# Batch-60 : CrossEntropyLoss=2.2770 | MulticlassF1Score=0.8946
# Batch-63 : CrossEntropyLoss=2.2788 | MulticlassF1Score=0.8942
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2756 | Mean MulticlassF1Score = 0.9095
# Validation : Mean CrossEntropyLoss = 2.2804 | Mean MulticlassF1Score = 0.8920
# ================================================================================
#
# EPOCH-21
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9144
# Batch-30 : CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9104
# Batch-45 : CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9091
# Batch-60 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9087
# Batch-75 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9096
# Batch-90 : CrossEntropyLoss=2.2767 | MulticlassF1Score=0.9094
# Batch-105: CrossEntropyLoss=2.2771 | MulticlassF1Score=0.9095
# Batch-120: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9097
# Batch-135: CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9097
# Batch-150: CrossEntropyLoss=2.2751 | MulticlassF1Score=0.9093
# Batch-165: CrossEntropyLoss=2.2766 | MulticlassF1Score=0.9095
# Batch-180: CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9093
# Batch-195: CrossEntropyLoss=2.2759 | MulticlassF1Score=0.9093
# Batch-210: CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9093
# Batch-225: CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9094
# Batch-226: CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9094
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2768 | MulticlassF1Score=0.8959
# Batch-30 : CrossEntropyLoss=2.2802 | MulticlassF1Score=0.8952
# Batch-45 : CrossEntropyLoss=2.2809 | MulticlassF1Score=0.8952
# Batch-60 : CrossEntropyLoss=2.2814 | MulticlassF1Score=0.8947
# Batch-63 : CrossEntropyLoss=2.2814 | MulticlassF1Score=0.8948
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2755 | Mean MulticlassF1Score = 0.9099
# Validation : Mean CrossEntropyLoss = 2.2803 | Mean MulticlassF1Score = 0.8957
# ================================================================================
#
# EPOCH-22
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2758 | MulticlassF1Score=0.9123
# Batch-30 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9100
# Batch-45 : CrossEntropyLoss=2.2779 | MulticlassF1Score=0.9092
# Batch-60 : CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9078
# Batch-75 : CrossEntropyLoss=2.2774 | MulticlassF1Score=0.9089
# Batch-90 : CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9119
# Batch-105: CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9147
# Batch-120: CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9170
# Batch-135: CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9184
# Batch-150: CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9196
# Batch-165: CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9209
# Batch-180: CrossEntropyLoss=2.2611 | MulticlassF1Score=0.9221
# Batch-195: CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9227
# Batch-210: CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9233
# Batch-225: CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9239
# Batch-226: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9239
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9145
# Batch-30 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9150
# Batch-45 : CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9166
# Batch-60 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9168
# Batch-63 : CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9167
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2712 | Mean MulticlassF1Score = 0.9160
# Validation : Mean CrossEntropyLoss = 2.2736 | Mean MulticlassF1Score = 0.9147
# ================================================================================
#
# EPOCH-23
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9369
# Batch-30 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9354
# Batch-45 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9354
# Batch-60 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9348
# Batch-75 : CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9336
# Batch-90 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9337
# Batch-105: CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9337
# Batch-120: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9339
# Batch-135: CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9339
# Batch-150: CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9340
# Batch-165: CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9343
# Batch-180: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9345
# Batch-195: CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9348
# Batch-210: CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9351
# Batch-225: CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9350
# Batch-226: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9350
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9196
# Batch-30 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9189
# Batch-45 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9191
# Batch-60 : CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9188
# Batch-63 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9187
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2677 | Mean MulticlassF1Score = 0.9344
# Validation : Mean CrossEntropyLoss = 2.2729 | Mean MulticlassF1Score = 0.9185
# ================================================================================
#
# EPOCH-24
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9303
# Batch-30 : CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9335
# Batch-45 : CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9358
# Batch-60 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9354
# Batch-75 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9362
# Batch-90 : CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9362
# Batch-105: CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9363
# Batch-120: CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9365
# Batch-135: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9369
# Batch-150: CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9370
# Batch-165: CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9370
# Batch-180: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9371
# Batch-195: CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9369
# Batch-210: CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9371
# Batch-225: CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9371
# Batch-226: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9371
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9222
# Batch-30 : CrossEntropyLoss=2.2774 | MulticlassF1Score=0.9212
# Batch-45 : CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9198
# Batch-60 : CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9199
# Batch-63 : CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9201
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2670 | Mean MulticlassF1Score = 0.9359
# Validation : Mean CrossEntropyLoss = 2.2724 | Mean MulticlassF1Score = 0.9211
# ================================================================================
#
# EPOCH-25
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9369
# Batch-30 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9386
# Batch-45 : CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9377
# Batch-60 : CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9383
# Batch-75 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9391
# Batch-90 : CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9390
# Batch-105: CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9391
# Batch-120: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9392
# Batch-135: CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9389
# Batch-150: CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9383
# Batch-165: CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9385
# Batch-180: CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9387
# Batch-195: CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9385
# Batch-210: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9384
# Batch-225: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9381
# Batch-226: CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9382
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9179
# Batch-30 : CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9187
# Batch-45 : CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9188
# Batch-60 : CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9197
# Batch-63 : CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9200
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2666 | Mean MulticlassF1Score = 0.9385
# Validation : Mean CrossEntropyLoss = 2.2724 | Mean MulticlassF1Score = 0.9188
# ================================================================================
#
# EPOCH-26
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9423
# Batch-30 : CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9404
# Batch-45 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9397
# Batch-60 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9395
# Batch-75 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9399
# Batch-90 : CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9397
# Batch-105: CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9388
# Batch-120: CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9387
# Batch-135: CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9388
# Batch-150: CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9392
# Batch-165: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9393
# Batch-180: CrossEntropyLoss=2.2611 | MulticlassF1Score=0.9390
# Batch-195: CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9387
# Batch-210: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9389
# Batch-225: CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9390
# Batch-226: CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9390
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9238
# Batch-30 : CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9213
# Batch-45 : CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9213
# Batch-60 : CrossEntropyLoss=2.2770 | MulticlassF1Score=0.9208
# Batch-63 : CrossEntropyLoss=2.2761 | MulticlassF1Score=0.9214
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2663 | Mean MulticlassF1Score = 0.9396
# Validation : Mean CrossEntropyLoss = 2.2721 | Mean MulticlassF1Score = 0.9217
# ================================================================================
#
# EPOCH-27
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9374
# Batch-30 : CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9385
# Batch-45 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9390
# Batch-60 : CrossEntropyLoss=2.2611 | MulticlassF1Score=0.9404
# Batch-75 : CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9414
# Batch-90 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9412
# Batch-105: CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9411
# Batch-120: CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9411
# Batch-135: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9410
# Batch-150: CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9405
# Batch-165: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9404
# Batch-180: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9405
# Batch-195: CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9405
# Batch-210: CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9406
# Batch-225: CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9404
# Batch-226: CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9404
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9197
# Batch-30 : CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9211
# Batch-45 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9224
# Batch-60 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9215
# Batch-63 : CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9214
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2659 | Mean MulticlassF1Score = 0.9404
# Validation : Mean CrossEntropyLoss = 2.2719 | Mean MulticlassF1Score = 0.9215
# ================================================================================
#
# EPOCH-28
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9409
# Batch-30 : CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9419
# Batch-45 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9417
# Batch-60 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9415
# Batch-75 : CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9409
# Batch-90 : CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9413
# Batch-105: CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9417
# Batch-120: CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9409
# Batch-135: CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9415
# Batch-150: CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9418
# Batch-165: CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9418
# Batch-180: CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9420
# Batch-195: CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9418
# Batch-210: CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9413
# Batch-225: CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9413
# Batch-226: CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9414
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9234
# Batch-30 : CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9223
# Batch-45 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9225
# Batch-60 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9231
# Batch-63 : CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9231
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2656 | Mean MulticlassF1Score = 0.9413
# Validation : Mean CrossEntropyLoss = 2.2715 | Mean MulticlassF1Score = 0.9222
# ================================================================================
#
# EPOCH-29
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9450
# Batch-30 : CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9422
# Batch-45 : CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9430
# Batch-60 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9437
# Batch-75 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9428
# Batch-90 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9422
# Batch-105: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9426
# Batch-120: CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9429
# Batch-135: CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9429
# Batch-150: CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9426
# Batch-165: CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9426
# Batch-180: CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9425
# ...
# Batch-30 : CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9461
# Batch-45 : CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9465
# Batch-60 : CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9455
# Batch-63 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9455
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2611 | Mean MulticlassF1Score = 0.9503
# Validation : Mean CrossEntropyLoss = 2.2645 | Mean MulticlassF1Score = 0.9449
# ================================================================================
#
# EPOCH-42
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9689
# Batch-30 : CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9671
# Batch-45 : CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9660
# Batch-60 : CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9663
# Batch-75 : CrossEntropyLoss=2.2544 | MulticlassF1Score=0.9668
# Batch-90 : CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9671
# Batch-105: CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9668
# Batch-120: CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9672
# Batch-135: CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9674
# Batch-150: CrossEntropyLoss=2.2539 | MulticlassF1Score=0.9674
# Batch-165: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9674
# Batch-180: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9675
# Batch-195: CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9674
# Batch-210: CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9672
# Batch-225: CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9674
# Batch-226: CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9674
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9450
# Batch-30 : CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9454
# Batch-45 : CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9448
# Batch-60 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9462
# Batch-63 : CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9466
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2576 | Mean MulticlassF1Score = 0.9675
# Validation : Mean CrossEntropyLoss = 2.2642 | Mean MulticlassF1Score = 0.9447
# ================================================================================
#
# EPOCH-43
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9684
# Batch-30 : CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9699
# Batch-45 : CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9686
# Batch-60 : CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9680
# Batch-75 : CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9676
# Batch-90 : CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9675
# Batch-105: CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9678
# Batch-120: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9677
# Batch-135: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9680
# Batch-150: CrossEntropyLoss=2.2529 | MulticlassF1Score=0.9678
# Batch-165: CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9678
# Batch-180: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9680
# Batch-195: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9681
# Batch-210: CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9681
# Batch-225: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9681
# Batch-226: CrossEntropyLoss=2.2589 | MulticlassF1Score=0.9681
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9499
# Batch-30 : CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9481
# Batch-45 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9463
# Batch-60 : CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9468
# Batch-63 : CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9463
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2573 | Mean MulticlassF1Score = 0.9682
# Validation : Mean CrossEntropyLoss = 2.2641 | Mean MulticlassF1Score = 0.9475
# ================================================================================
#
# EPOCH-44
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2540 | MulticlassF1Score=0.9682
# Batch-30 : CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9672
# Batch-45 : CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9676
# Batch-60 : CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9674
# Batch-75 : CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9682
# Batch-90 : CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9681
# Batch-105: CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9681
# Batch-120: CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9686
# Batch-135: CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9684
# Batch-150: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9686
# Batch-165: CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9686
# Batch-180: CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9685
# Batch-195: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9685
# Batch-210: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9687
# Batch-225: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9689
# Batch-226: CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9689
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9493
# Batch-30 : CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9473
# Batch-45 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9480
# Batch-60 : CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9482
# Batch-63 : CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9482
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2570 | Mean MulticlassF1Score = 0.9683
# Validation : Mean CrossEntropyLoss = 2.2637 | Mean MulticlassF1Score = 0.9484
# ================================================================================
#
# EPOCH-45
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9694
# Batch-30 : CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9690
# Batch-45 : CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9696
# Batch-60 : CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9688
# Batch-75 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9689
# Batch-90 : CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9691
# Batch-105: CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9692
# Batch-120: CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9690
# Batch-135: CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9692
# Batch-150: CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9692
# Batch-165: CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9693
# Batch-180: CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9692
# Batch-195: CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9692
# Batch-210: CrossEntropyLoss=2.2538 | MulticlassF1Score=0.9693
# Batch-225: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9694
# Batch-226: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9694
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9470
# Batch-30 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9483
# Batch-45 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9473
# Batch-60 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9485
# Batch-63 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9486
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2569 | Mean MulticlassF1Score = 0.9692
# Validation : Mean CrossEntropyLoss = 2.2635 | Mean MulticlassF1Score = 0.9476
# ================================================================================
#
# EPOCH-46
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2544 | MulticlassF1Score=0.9681
# Batch-30 : CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9670
# Batch-45 : CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9673
# Batch-60 : CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9681
# Batch-75 : CrossEntropyLoss=2.2535 | MulticlassF1Score=0.9686
# Batch-90 : CrossEntropyLoss=2.2589 | MulticlassF1Score=0.9686
# Batch-105: CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9685
# Batch-120: CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9689
# Batch-135: CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9690
# Batch-150: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9692
# Batch-165: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9695
# Batch-180: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9697
# Batch-195: CrossEntropyLoss=2.2540 | MulticlassF1Score=0.9698
# Batch-210: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9699
# Batch-225: CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9698
# Batch-226: CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9698
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9504
# Batch-30 : CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9505
# Batch-45 : CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9498
# Batch-60 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9495
# Batch-63 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9492
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2567 | Mean MulticlassF1Score = 0.9688
# Validation : Mean CrossEntropyLoss = 2.2633 | Mean MulticlassF1Score = 0.9510
# ================================================================================
#
# EPOCH-47
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9709
# Batch-30 : CrossEntropyLoss=2.2542 | MulticlassF1Score=0.9713
# Batch-45 : CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9691
# Batch-60 : CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9697
# Batch-75 : CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9697
# Batch-90 : CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9701
# Batch-105: CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9702
# Batch-120: CrossEntropyLoss=2.2533 | MulticlassF1Score=0.9703
# Batch-135: CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9704
# Batch-150: CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9701
# Batch-165: CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9702
# Batch-180: CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9704
# Batch-195: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9702
# Batch-210: CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9701
# Batch-225: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9701
# Batch-226: CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9701
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9474
# Batch-30 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9484
# Batch-45 : CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9489
# Batch-60 : CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9482
# Batch-63 : CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9485
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2566 | Mean MulticlassF1Score = 0.9701
# Validation : Mean CrossEntropyLoss = 2.2635 | Mean MulticlassF1Score = 0.9485
# ================================================================================
#
# EPOCH-48
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9703
# Batch-30 : CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9695
# Batch-45 : CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9700
# Batch-60 : CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9697
# Batch-75 : CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9700
# Batch-90 : CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9703
# Batch-105: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9702
# Batch-120: CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9707
# Batch-135: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9705
# Batch-150: CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9706
# Batch-165: CrossEntropyLoss=2.2543 | MulticlassF1Score=0.9708
# Batch-180: CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9706
# Batch-195: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9705
# Batch-210: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9704
# Batch-225: CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9702
# Batch-226: CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9702
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9486
# Batch-30 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9480
# Batch-45 : CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9472
# Batch-60 : CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9479
# Batch-63 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9476
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2566 | Mean MulticlassF1Score = 0.9703
# Validation : Mean CrossEntropyLoss = 2.2637 | Mean MulticlassF1Score = 0.9483
# ================================================================================
#
# EPOCH-49
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9699
# Batch-30 : CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9709
# Batch-45 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9716
# Batch-60 : CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9714
# Batch-75 : CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9718
# Batch-90 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9718
# Batch-105: CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9717
# Batch-120: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9713
# Batch-135: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9711
# Batch-150: CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9709
# Batch-165: CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9709
# Batch-180: CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9707
# Batch-195: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9706
# Batch-210: CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9703
# Batch-225: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9703
# Batch-226: CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9703
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9519
# Batch-30 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9511
# Batch-45 : CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9503
# Batch-60 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9486
# Batch-63 : CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9488
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2566 | Mean MulticlassF1Score = 0.9711
# Validation : Mean CrossEntropyLoss = 2.2634 | Mean MulticlassF1Score = 0.9516
# ================================================================================
#
# EPOCH-50
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9698
# Batch-30 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9703
# Batch-45 : CrossEntropyLoss=2.2541 | MulticlassF1Score=0.9708
# Batch-60 : CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9700
# Batch-75 : CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9702
# Batch-90 : CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9703
# Batch-105: CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9705
# Batch-120: CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9704
# Batch-135: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9704
# Batch-150: CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9704
# Batch-165: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9704
# Batch-180: CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9707
# Batch-195: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9705
# Batch-210: CrossEntropyLoss=2.2597 | MulticlassF1Score=0.9706
# Batch-225: CrossEntropyLoss=2.2530 | MulticlassF1Score=0.9705
# Batch-226: CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9705
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9478
# Batch-30 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9461
# Batch-45 : CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9466
# Batch-60 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9477
# Batch-63 : CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9482
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2565 | Mean MulticlassF1Score = 0.9703
# Validation : Mean CrossEntropyLoss = 2.2637 | Mean MulticlassF1Score = 0.9479
# ================================================================================
#
# TRAINING SUMMARY
# Best CrossEntropyLoss training    : 2.2565
# Best CrossEntropyLoss training    : 2.2637
# Best MulticlassF1Score validation : 0.9703
# Best MulticlassF1Score validation : 0.9479
# Training duration                 : 2.7785 minutes.
# Training date                     : 2022-10-19 14:47:02.123778+08:00

# %% [markdown]
# ## End Training

# %% [markdown]
# # Evaluation

# %%
def evaluation(dataloader, model, criterion, metric):
    model.eval()
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)
            pred = rearrange(prob.argmax(dim=1).reshape(feature.shape[0], len(dataloader.dataset)), "s n -> n s")

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob.argmax(dim=1), actual_label.to(hyperparams.device))
            metric_score = metric.compute()

    return loss, metric_score, pred

train_dataloader = DataLoader(train_dataset, batch_size=len(train_dataset))
val_dataloader = DataLoader(val_dataset, batch_size=len(val_dataset))
test_dataloader = DataLoader(test_dataset, batch_size=len(test_dataset))

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
train_loss, train_f1_score, train_pred_label = evaluation(train_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_loss, val_f1_score, val_pred_label = evaluation(val_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
test_loss, test_f1_score, test_pred_label = evaluation(test_dataloader, model, criterion, metric)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9706, device='cuda:0'),
#  tensor(0.9482, device='cuda:0'),
#  tensor(0.9492, device='cuda:0'))

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9706, device='cuda:0'),
#  tensor(0.9482, device='cuda:0'),
#  tensor(0.9492, device='cuda:0'))

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns

def viz_evaluation(pred_label, actual_label, title):
    plt.figure(figsize=(15, 7), dpi=200)
    sns.heatmap(pred_label.detach().cpu() == actual_label, cbar=True, cmap="binary_r")
    plt.xlabel("Sentence Length")
    plt.ylabel("Sentence")
    plt.title(title)
    plt.savefig(f"{root_path}/heatmap_{title.lower()}.jpg", dpi=200)
    plt.show()

train_actual_label = train_dataloader.dataset.tensors[1]
val_actual_label = val_dataloader.dataset.tensors[1]
test_actual_label = test_dataloader.dataset.tensors[1]

viz_evaluation(train_pred_label, train_actual_label, f"Training (F1-Score: {(train_f1_score):.4f})")
viz_evaluation(val_pred_label, val_actual_label, f"Validation (F1-Score: {(val_f1_score):.4f})")
viz_evaluation(test_pred_label, test_actual_label, f"Test (F1-Score: {(test_f1_score):.4f})")

# %% [markdown]
# ## Confusion Matrix

# %%
def confusion_matrix(pred_class, actual_class, title, normalize=None):
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize=normalize)
    plt.figure(figsize=(20, 10), dpi=200)
    sns.heatmap(conf_mat(pred_class.detach().cpu(), actual_class), annot=True, fmt=".2g", xticklabels=list(label_to_idx.keys()), yticklabels=list(label_to_idx.keys()));
    plt.yticks(rotation=0)
    plt.title(title)
    plt.xlabel("Actual Class")
    plt.ylabel("Predict Class")
    plt.savefig(f"{root_path}/conf_matrix_{title.lower()}.jpg", dpi=200)

confusion_matrix(train_pred_label, train_actual_label, "Training", "pred")
confusion_matrix(val_pred_label,val_actual_label, "Validation", "pred")
confusion_matrix(test_pred_label, test_actual_label, "Test", "pred")
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 144 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)

# %% [markdown]
# ## Prediction Table

# %%
def number_wrong_pred_each_class(pred_class, actual_class):
    classes, count_class = actual_class.flatten().unique(return_counts=True)
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize="none")
    correct_pred_count_class = conf_mat(pred_class.detach().cpu(), actual_class).diag()
    
    correct_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (correct_pred_count_class))}
    wrong_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (count_class - correct_pred_count_class))}
    
    return correct_pred, wrong_pred

correct_pred, wrong_pred = number_wrong_pred_each_class(train_pred_label, train_actual_label)
print(f"| {'Number class'.ljust(14)} | {'Correct prediction'.ljust(12)} | {'Wrong prediction'.ljust(12)} |")
for (label_correct_pred, count_correct_pred), (label_wrong_pred, count_wrong_pred) in zip(correct_pred.items(), wrong_pred.items()):
    print(f"| {str(label_correct_pred).ljust(6)}: {str(count_correct_pred + count_wrong_pred).ljust(7)}| {label_correct_pred.ljust(6)}: {str(count_correct_pred).ljust(10)} | {label_wrong_pred.ljust(6)}: {str(count_wrong_pred).ljust(8)} |")
# Out:
# | Number class   | Correct prediction | Wrong prediction |
# | CC    : 5397   | CC    : 5282       | CC    : 115      |
# | CD    : 12862  | CD    : 12774      | CD    : 88       |
# | DT    : 278    | DT    : 0          | DT    : 278      |
# | FW    : 1605   | FW    : 1390       | FW    : 215      |
# | IN    : 15290  | IN    : 15110      | IN    : 180      |
# | JJ    : 7025   | JJ    : 6603       | JJ    : 422      |
# | MD    : 3798   | MD    : 3660       | MD    : 138      |
# | NEG   : 1101   | NEG   : 0          | NEG   : 1101     |
# | NN    : 44472  | NN    : 43937      | NN    : 535      |
# | NND   : 1033   | NND   : 534        | NND   : 499      |
# | NNP   : 25007  | NNP   : 24546      | NNP   : 461      |
# | OD    : 519    | OD    : 500        | OD    : 19       |
# | PR    : 3880   | PR    : 3855       | PR    : 25       |
# | PRP   : 5449   | PRP   : 5438       | PRP   : 11       |
# | RB    : 3502   | RB    : 3336       | RB    : 166      |
# | RP    : 131    | RP    : 0          | RP    : 131      |
# | SC    : 9421   | SC    : 9202       | SC    : 219      |
# | SYM   : 1564   | SYM   : 1476       | SYM   : 88       |
# | UH    : 21     | UH    : 0          | UH    : 21       |
# | VB    : 22760  | VB    : 22510      | VB    : 250      |
# | WH    : 180    | WH    : 0          | WH    : 180      |
# | X     : 290    | X     : 0          | X     : 290      |
# | Z     : 19042  | Z     : 19042      | Z     : 0        |
# | <PAD> : 407577 | <PAD> : 407577     | <PAD> : 0        |

# %%
train_actual_label[308], train_pred_label[308]
# Out:
# (tensor([ 8,  3, 12, 19,  8,  8,  8, 16, 19,  4, 10,  8, 10,  0,  4,  1,  8,  8,
#           8,  5,  4,  8, 10,  0, 10, 10, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23]),
#  tensor([ 8,  8, 12, 19,  8,  8,  5, 16, 19,  4, 10,  8, 10,  0,  4,  1,  8,  8,
#           8,  5,  4,  8, 10,  0, 10, 10, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23], device='cuda:0'))

# %%
train_actual_label[308] == train_pred_label[308].detach().cpu()
# Out:
# tensor([ True, False,  True,  True,  True,  True, False,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True])

# %% [markdown]
# ## OOV prediction is correct

# %%
def oov_flag_token(sentences, max_seq_len=hyperparams.max_seq_len):
    sent_copy = deepcopy(sentences)
    sent = []
    oov_flag = []
    
    for sentence in tqdm(sent_copy):
        for token in sentence:
            sent.append(token[2])
        
        for _ in range(max_seq_len- len(sentence)):
            sent.append(False)
        
        oov_flag.append(sent)
        sent = []
        
    return np.array(oov_flag)

train_oov_flag = oov_flag_token(train_sentences, max_seq_len=hyperparams.max_seq_len)
val_oov_flag = oov_flag_token(val_sentences, max_seq_len=hyperparams.max_seq_len)
test_oov_flag = oov_flag_token(test_sentences, max_seq_len=hyperparams.max_seq_len)

def pencentage_oov_pred_correct(pred_oov_flag, oov_flag_tensor):
    oov_correct_counter = 0
    oov_wrong_counter = 0

    for pred, oov_label in tqdm(zip(pred_oov_flag, oov_flag_tensor)):
        if pred == True and oov_label == True:
            oov_correct_counter += 1
        elif pred == False and oov_label == True:
            oov_wrong_counter += 1
        else:
            continue
            
    return oov_correct_counter, oov_wrong_counter

train_pred_oov_flag = (train_actual_label == train_pred_label.detach().cpu()).flatten()
val_pred_oov_flag = (val_actual_label == val_pred_label.detach().cpu()).flatten()
test_pred_oov_flag = (test_actual_label == test_pred_label.detach().cpu()).flatten()
train_oov_flag_tensor = torch.tensor(train_oov_flag).flatten()
val_oov_flag_tensor = torch.tensor(val_oov_flag).flatten()
test_oov_flag_tensor = torch.tensor(test_oov_flag).flatten()

train_oov_correct_counter, train_oov_wrong_counter = pencentage_oov_pred_correct(train_pred_oov_flag, train_oov_flag_tensor)
val_oov_correct_counter, val_oov_wrong_counter = pencentage_oov_pred_correct(val_pred_oov_flag, val_oov_flag_tensor)
test_oov_correct_counter, test_oov_wrong_counter = pencentage_oov_pred_correct(test_pred_oov_flag, test_oov_flag_tensor)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
def print_percentage_pred_oov(title, oov_correct_counter, oov_wrong_counter):
    print(f"{title}")
    print(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}")
    print(f"Correct prediction          : {oov_correct_counter}")
    print(f"Wrong prediction            : {oov_wrong_counter}")
    print(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n")
    
    with open(f"{root_path}/oov_summary.txt", "a") as f:
        f.write(f"{title}\n")
        f.write(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}\n")
        f.write(f"Correct prediction          : {oov_correct_counter}\n")
        f.write(f"Wrong prediction            : {oov_wrong_counter}\n")
        f.write(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n\n")

# %%
print_percentage_pred_oov("Training", train_oov_correct_counter, train_oov_wrong_counter)
print_percentage_pred_oov("Validation", val_oov_correct_counter, val_oov_wrong_counter)
print_percentage_pred_oov("Test", test_oov_correct_counter, test_oov_wrong_counter)
# Out:
# Training
# Number OOV token            : 11971
# Correct prediction          : 11240
# Wrong prediction            : 731
# Percentage correct oov pred : 93.89357614234399
#
# Validation
# Number OOV token            : 3190
# Correct prediction          : 2831
# Wrong prediction            : 359
# Percentage correct oov pred : 88.74608150470219
#
# Test
# Number OOV token            : 1401
# Correct prediction          : 1254
# Wrong prediction            : 147
# Percentage correct oov pred : 89.50749464668094

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(train_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(val_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(test_oov_flag, cmap=plt.cm.binary_r);
