# %% [markdown]
# # Import modules

# %%
import csv
import os
import pickle
import pytz
import torch
import timeit
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from copy import deepcopy
from datetime import datetime
from einops import rearrange
from itertools import chain
from time import time
from torch import nn, optim
from torchmetrics.classification import MulticlassAccuracy, MulticlassF1Score, MulticlassConfusionMatrix
from torch.optim import lr_scheduler
from tqdm.notebook import tqdm
from torch.utils.data import TensorDataset, DataLoader
from polyglot.mapping import Embedding, CaseExpander, DigitExpander

# %% [markdown]
# # Hyperparameters

# %%
class Hyperparams:
     def __init__(
        self,
        context_size=79,
        fold=2,
        max_seq_len=82,
        input_size=64,
        batch_size=32,
        num_hidden_layer=1,
        hidden_size=128,
        dropout=0,
        bias=True,
        output_size=24,
        shuffle=True,
        lr=0.005,
        batch_first=False,
        bidirectional=True,
        init_wb_with_kaiming_normal=True,
        n_epoch=50,
        patience=50,
        device="cuda" if torch.cuda.is_available() else "cpu"
    ):
        self.context_size = context_size
        self.fold = fold
        self.input_size = input_size
        self.max_seq_len = max_seq_len
        self.batch_size = batch_size
        self.num_hidden_layer = num_hidden_layer
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.output_size = output_size
        self.shuffle = shuffle
        self.lr = lr
        self.batch_first = batch_first
        self.bidirectional = bidirectional
        self.init_wb_with_kaiming_normal = init_wb_with_kaiming_normal
        self.n_epoch = n_epoch
        self.patience = patience
        self.device = device

hyperparams = Hyperparams()

# %% [markdown]
# # Dataset

# %%
id_pos_tag = pd.read_csv("../../../datasets/raw/Indonesian_Manually_Tagged_Corpus.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False) 
train = pd.read_csv(f"../../../datasets/raw/cv/train/train.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
val = pd.read_csv(f"../../../datasets/raw/cv/val/val.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
test = pd.read_csv(f"../../../datasets/raw/cv/test/test.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)

# %% [markdown]
# # Pre-trained Word Embedding

# %%
embeddings = Embedding.load("../../../word_embeddings/polyglot/idn_embeddings.tar.bz2")
embeddings.apply_expansion(DigitExpander)
embeddings.apply_expansion(CaseExpander)

oov_embeddings = pickle.load(open(f"../../../logs/comick/{hyperparams.context_size}_contexts/10-11-2022_19-39-04/oov_embedding_dict.pkl", "rb"))

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Add OOV Flag

# %%
def add_oov_flag(tokens, embeddings):
    oov_flags = []
    
    for token in tqdm(tokens):
        try:
            if token not in embeddings:
                oov_flags.append(True)
            else:
                oov_flags.append(False)
        except:
            oov_flags.append(False)
        
    return pd.DataFrame(oov_flags, columns=["is_oov"])

id_pos_tag_oov_flags = add_oov_flag(id_pos_tag["token"].values, embeddings)
train_oov_flags = add_oov_flag(train["token"].values, embeddings)
val_oov_flags = add_oov_flag(val["token"].values, embeddings)
test_oov_flags = add_oov_flag(test["token"].values, embeddings)
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/192008 [00:00<?, ?it/s]
#   0%|          | 0/21405 [00:00<?, ?it/s]
#   0%|          | 0/53239 [00:00<?, ?it/s]

# %% [markdown]
# ## Concate OOV Flag

# %%
id_pos_tag_df = pd.concat([id_pos_tag, id_pos_tag_oov_flags], axis=1)
train_df = pd.concat([train, train_oov_flags], axis=1)
val_df = pd.concat([val, val_oov_flags], axis=1)
test_df = pd.concat([test, test_oov_flags], axis=1)

# %% [markdown]
# ## Lowercase OOV Token

# %%
id_pos_tag_df['token'] = np.where(id_pos_tag_df['is_oov'] == True, id_pos_tag_df['token'].str.lower(), id_pos_tag_df['token'])
train_df['token'] = np.where(train_df['is_oov'] == True, train_df['token'].str.lower(), train_df['token'])
val_df['token'] = np.where(val_df['is_oov'] == True, val_df['token'].str.lower(), val_df['token'])
test_df['token'] = np.where(test_df['is_oov'] == True, test_df['token'].str.lower(), test_df['token'])

# %% [markdown]
# ## Embedding Dict, Index to Token and Token to Index

# %%
tokens = list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None))

def embedding_dict(tokens, embeddings, oov_embeddings):
    embedding = {}
    
    for token in tokens:
        if token[0] is not np.nan:
            if token[2] == False or token[0] in embeddings:
                embedding[token[0]] = embeddings[token[0]]
            else:
                embedding[token[0]] = oov_embeddings[token[0].lower()]

    return embedding

embedding_dict = embedding_dict(tokens, embeddings, oov_embeddings)
embedding_dict["<PAD>"] = embeddings["<PAD>"]
word_embeddings = nn.Embedding.from_pretrained(torch.FloatTensor(np.array(list(embedding_dict.values()))), padding_idx=list(embedding_dict.keys()).index("<PAD>"), freeze=True)

idx_to_token = {idx: token for idx, token in enumerate(list(embedding_dict.keys()))}
token_to_idx = {token: idx for idx, token in enumerate(list(embedding_dict.keys()))}

# %% [markdown]
# ## Token to Sentence

# %%
def make_sentence(tokens, max_length_sentence=hyperparams.max_seq_len):
    sentence = []
    sentences = []

    for token in tqdm(tokens):
        if token[0] is not np.nan:
            sentence.append(token)
        else:
            sentences.append(sentence[:max_length_sentence])
            sentence = []

    return sentences

all_sentence = make_sentence(list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
train_sentences = make_sentence(list(train_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
val_sentences = make_sentence(list(test_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
test_sentences = make_sentence(list(val_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/192008 [00:00<?, ?it/s]
#   0%|          | 0/53239 [00:00<?, ?it/s]
#   0%|          | 0/21405 [00:00<?, ?it/s]

# %% [markdown]
# ## Word Token, Padding, and Word token to Index

# %%
def tokenize_docs(docs, idx_token):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token[idx_token])
        sentences.append(new_sentence)
        new_sentence = []

    return sentences

def padding(docs, max_seq_len=hyperparams.max_seq_len, mode="post", val_pad="<PAD>"):
    docs = deepcopy(docs)
    doc_with_pad = []
    docs_with_pad = []

    for doc in tqdm(docs):
        if mode == "pre":
            for _ in range(max_seq_len - len(doc)):
                doc.insert(0, val_pad)
        elif mode == "post":
            for _ in range(max_seq_len - len(doc)):
                doc.append(val_pad)
        else:
            return f"Mode {mode} is not available, use instead 'pre' or 'post'."
        
        docs_with_pad.append(doc)
        
    return np.array(docs_with_pad)

def sent_to_idx(docs, token_to_idx):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token_to_idx[token])
        sentences.append(new_sentence)
        new_sentence = []

    return np.array(sentences)

def convert_feature_to_idx(docs, idx_token, token_to_idx, max_seq_len):
    sentences = tokenize_docs(docs, idx_token)
    sentences_with_pad = padding(sentences, max_seq_len=max_seq_len, mode="post", val_pad="<PAD>")
    sentences_to_idx = sent_to_idx(sentences_with_pad, token_to_idx)
    
    return sentences_to_idx

train_sentence_idxs = convert_feature_to_idx(train_sentences, 0, token_to_idx, hyperparams.max_seq_len)
val_sentence_idxs = convert_feature_to_idx(val_sentences, 0, token_to_idx, hyperparams.max_seq_len)
test_sentence_idxs = convert_feature_to_idx(test_sentences, 0, token_to_idx, hyperparams.max_seq_len)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]

# %% [markdown]
# ## Encode Class

# %%
classes = sorted(np.delete(id_pos_tag_df["tag"].unique(), 3))
idx_to_label = {idx: label for idx, label in enumerate(classes + ["<PAD>"])}
label_to_idx = {label: idx for idx, label in enumerate(classes + ["<PAD>"])}

def encode_class(docs, label_to_idx, seq_len=hyperparams.max_seq_len):
    class_idxs = []
    classes = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            class_idxs.append(label_to_idx[token[1]])
            
        for _ in range(seq_len - len(sentence)):
            class_idxs.append(label_to_idx["<PAD>"])
                
        classes.append(class_idxs)
        class_idxs = []

    return np.array(classes)
        
train_class_idxs = encode_class(train_sentences, label_to_idx)
val_class_idxs = encode_class(val_sentences, label_to_idx)
test_class_idxs = encode_class(test_sentences, label_to_idx)

print(f"Training shape   : {train_sentence_idxs.shape, train_class_idxs.shape}")
print(f"validation shape : {val_class_idxs.shape, val_class_idxs.shape}")
print(f"Test shape       : {test_sentence_idxs.shape, test_class_idxs.shape}")
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# Training shape   : ((7222, 82), (7222, 82))
# validation shape : ((2006, 82), (2006, 82))
# Test shape       : ((802, 82), (802, 82))

# %% [markdown]
# ## Note
#
# - Number of sentences = 10030
# - Train : 72% (7222)
# - Val   : 8% (802)
# - Test  : 20% (2006)

# %% [markdown]
# # Build Model

# %% [markdown]
# ## Feature and Actual Class

# %%
train_feature = torch.LongTensor(train_sentence_idxs)
val_feature = torch.LongTensor(val_sentence_idxs)
test_feature = torch.LongTensor(test_sentence_idxs)

train_class = torch.LongTensor(train_class_idxs)
val_class = torch.LongTensor(val_class_idxs)
test_class = torch.LongTensor(test_class_idxs)

# %%
train_feature.shape, val_feature.shape, test_feature.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %%
train_class.shape, val_class.shape, test_class.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %% [markdown]
# ## Tensor Dataset

# %%
train_dataset = TensorDataset(train_feature, train_class)
val_dataset = TensorDataset(val_feature, val_class)
test_dataset = TensorDataset(test_feature, test_class)

# %% [markdown]
# ## Dataloader

# %%
train_dataloader = DataLoader(train_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
val_dataloader = DataLoader(val_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
test_dataloader = DataLoader(test_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)

# %% [markdown]
# ## Model

# %%
class POSTagger(nn.Module):
    def __init__(
        self,
        input_size=hyperparams.input_size,
        hidden_size=hyperparams.hidden_size,
        dropout=hyperparams.dropout,
        bias=hyperparams.bias,
        num_layers=hyperparams.num_hidden_layer,
        output_size=hyperparams.output_size,
        batch_first=hyperparams.batch_first,
        bidirectional=hyperparams.bidirectional,
        init_wb_with_kaiming_normal=hyperparams.init_wb_with_kaiming_normal
    ):
        super(POSTagger, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.num_layers = num_layers
        self.output_size = output_size
        self.batch_first = batch_first
        self.bidirectional = bidirectional
                
        self.feature = nn.LSTM(
            input_size = self.input_size,
            hidden_size = self.hidden_size,
            bias = self.bias,
            dropout = self.dropout,
            num_layers = self.num_layers,
            batch_first = self.batch_first,
            bidirectional = self.bidirectional
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(in_features=2 * self.hidden_size if hyperparams.bidirectional else self.hidden_size, out_features=self.output_size, bias=self.bias),
            nn.Softmax(dim=-1)
        )
        
        if init_wb_with_kaiming_normal:
            self.init_wb()

    def init_wb(self):
        for module in self.modules():
            if isinstance(module, (nn.Linear, nn.LSTM)):
                for name, param in module.named_parameters():
                    if "weight" in name:
                        nn.init.kaiming_normal_(param)
                    else:
                        nn.init.kaiming_normal_(param.reshape(1, -1))
        
    def forward(self, feature, hidden=None):
        output, (hidden, memory) = self.feature(feature, None)
        prob = self.classifier(output)

        return prob
    
model = POSTagger().to(hyperparams.device)
model
# Out:
# POSTagger(
#   (feature): LSTM(64, 128, bidirectional=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=24, bias=True)
#     (1): Softmax(dim=-1)
#   )
# )

# %% [markdown]
# ## Optimizer, Criterion, and Metric

# %%
optimizer = optim.Adam(model.parameters(), lr=hyperparams.lr)
criterion = nn.CrossEntropyLoss().to(hyperparams.device)
train_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", verbose=True, factor=0.5)

# %%
sum(param.numel() for param in model.parameters() if param.requires_grad)
# Out:
# 204824

# %% [markdown]
# ## Training Step

# %%
def training_step(dataloader, model, optimizer, criterion, metric, scheduler=None):
    model.train()
    
    batch_losses = []
    batch_metric_scores = []
    
    for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
        # Forward Propagation
        feature = rearrange(feature, "n s -> s n")
        actual_label = rearrange(actual_label, "n s -> s n")
        embedding = word_embeddings(feature)
        
        prob = model(
            embedding.to(hyperparams.device),
            actual_label.to(hyperparams.device)
        )
        
        prob = prob.reshape(-1, prob.shape[-1])
        actual_label = actual_label.reshape(-1)

        loss = criterion(prob, actual_label.to(hyperparams.device))
        metric_score = metric(prob, actual_label.to(hyperparams.device))
        metric_score = metric.compute()
                
        if scheduler is not None:
            scheduler.step(loss)
        
        batch_losses.append(loss.item())
        batch_metric_scores.append(metric_score)
        
        if len(dataloader) < 10:
            if batch % 1 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
        else:
            if batch % 15 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            
        # Backward Propagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Validation Step

# %%
def validation_step(dataloader, model, criterion, metric):
    model.eval()
    
    batch_losses = []
    batch_metric_scores = []
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob, actual_label.to(hyperparams.device))
            metric_score = metric.compute()

            batch_losses.append(loss.item())
            batch_metric_scores.append(metric_score)
            
            if len(dataloader) < 10 and (batch % 1 == 0 or batch == len(dataloader)):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            else:
                if batch % 15 == 0 or batch == len(dataloader):
                    batch_name = "Batch-" + str(batch)
                    print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                    with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                        f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Looping Step

# %%
now = datetime.now(pytz.timezone("Asia/Ujung_Pandang"))
path_name = now.strftime("%m-%d-%Y_%H-%M-%S")
root_path = f"../../../logs/classifier/{hyperparams.context_size}_contexts/fold_0{hyperparams.fold}/{path_name}"
os.makedirs(root_path)

def looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric, n_epoch=hyperparams.n_epoch, patience=hyperparams.patience, monitor="loss"):    
    start_time = time()
    
    epoch_training_losses = []
    epoch_training_metric_scores = []
    epoch_val_losses = []
    epoch_val_metric_scores = []
    patience_counter = 0
    
    # Hyperparameters
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write(f"HYPERPARAMETERS\n")
        f.write(f"{'-' * 80}\n")
        for name, value in vars(hyperparams).items():
            f.write(f"{name}: {value}\n")
        
        f.write("\n\nTRAINING PROGRESS\n")
        f.write(f"{'-' * 80}\n")
    
    # Training Progress
    for epoch in range(1, n_epoch + 1):
        print(f"EPOCH-{epoch}")
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"EPOCH-{epoch}\n")
            f.write(f"Training Step\n")
            
        # Training Step
        print("Training Step")
        batch_training_losses, batch_training_metric_scores = training_step(train_dataloader, model, optimizer, criterion, train_metric, scheduler=None)
        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))

        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))
        epoch_training_losses.append(epoch_training_loss.item())

        epoch_training_metric_score = torch.mean(torch.FloatTensor(batch_training_metric_scores))
        epoch_training_metric_scores.append(epoch_training_metric_score.item())
        
        # Validation Step
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"\nValidation Step\n")
            
        print("\nValidation Step")
        batch_val_losses, batch_val_metric_scores = validation_step(val_dataloader, model, criterion, val_metric)
        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))

        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))
        epoch_val_losses.append(epoch_val_loss.item())

        epoch_val_metric_score = torch.mean(torch.FloatTensor(batch_val_metric_scores))
        epoch_val_metric_scores.append(epoch_val_metric_score.item())
        
        with open(f"{root_path}/training_history.txt", "a") as f:
            if monitor == "loss":
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_losses[-1] < epoch_training_losses[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
            else:
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_metric_scores[-1] > epoch_training_metric_scores[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗\n")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
                    
            print("=" * 80, end="\n\n")
            
            f.write(f"{'=' * 80}\n\n")
            
            if patience_counter == patience:
                print(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                
                f.write(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                break
        
        train_metric.reset()
        val_metric.reset()
        
    finish_time = time()
    
    # Training plot 
    fig, (ax_loss, ax_metric_score) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    fig.suptitle(f"Training with context size = {hyperparams.context_size}")

    ax_loss.set_title("Loss")
    ax_loss.set_xlabel("Epoch")
    ax_loss.set_ylabel("Score")
    ax_loss.plot(epoch_training_losses, "green", label="Training")
    ax_loss.plot(epoch_val_losses, "orange", label="Validation")
    ax_loss.legend()
    ax_loss.grid()

    ax_metric_score.set_title("F1 Score")
    ax_metric_score.set_xlabel("Epoch")
    ax_metric_score.set_ylabel("Score")
    ax_metric_score.plot(epoch_training_metric_scores, "green", label="Training")
    ax_metric_score.plot(epoch_val_metric_scores, "orange", label="Validation")
    ax_metric_score.legend()
    ax_metric_score.grid()

    plt.savefig(f"{root_path}/training_plot.jpg", dpi=200)                        
    
    print("TRAINING SUMMARY")
    name_best_training_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_training_metric = f"Best {str(train_metric).split('(')[0]} validation".ljust(34)
    name_best_validation_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_validation_metric = f"Best {str(val_metric).split('(')[0]} validation".ljust(34)
    name_training_time = f"Training duration".ljust(34)
    name_training_date = f"Training date".ljust(34)
    
    print(f"{name_best_training_loss}: {best_training_loss:.4f}")
    print(f"{name_best_validation_loss}: {best_val_loss:.4f}")
    print(f"{name_best_training_metric}: {best_training_metric:.4f}")
    print(f"{name_best_validation_metric}: {best_val_metric:.4f}")
    print(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.")
    print(f"{name_training_date}: {now}")
    
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write("\nTRAINING SUMMARY\n")
        f.write(f"{'-' * 80}\n")
        f.write(f"{name_best_training_loss}: {best_training_loss:.4f}\n")
        f.write(f"{name_best_validation_loss}: {best_val_loss:.4f}\n")
        f.write(f"{name_best_training_metric}: {best_training_metric:.4f}\n")
        f.write(f"{name_best_validation_metric}: {best_val_metric:.4f}\n")
        f.write(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.\n")
        f.write(f"{name_training_date}: {now}\n")
    
    # Save epoch losses, epoch metric scores, model, state dict, and oov embedding dict
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_training_losses
    }).to_csv(f"{root_path}/training_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_training_metric_scores
    }).to_csv(f"{root_path}/training_metric_scores.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_val_losses
    }).to_csv(f"{root_path}/val_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_val_metric_scores
    }).to_csv(f"{root_path}/val_metric_scores.csv", index=False)    
    
    filename_model_params = f"{root_path}/model_params.pth"
    torch.save(best_state_dict, filename_model_params)
    
    return epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores

epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores = looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric)
# Out:
# EPOCH-1
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.4586 | MulticlassF1Score=0.1602
# Batch-30 : CrossEntropyLoss=2.4436 | MulticlassF1Score=0.2227
# Batch-45 : CrossEntropyLoss=2.4532 | MulticlassF1Score=0.2689
# Batch-60 : CrossEntropyLoss=2.4302 | MulticlassF1Score=0.2937
# Batch-75 : CrossEntropyLoss=2.3947 | MulticlassF1Score=0.3221
# Batch-90 : CrossEntropyLoss=2.4158 | MulticlassF1Score=0.3485
# Batch-105: CrossEntropyLoss=2.4116 | MulticlassF1Score=0.3681
# Batch-120: CrossEntropyLoss=2.4091 | MulticlassF1Score=0.3865
# Batch-135: CrossEntropyLoss=2.3682 | MulticlassF1Score=0.4088
# Batch-150: CrossEntropyLoss=2.3437 | MulticlassF1Score=0.4292
# Batch-165: CrossEntropyLoss=2.3551 | MulticlassF1Score=0.4509
# Batch-180: CrossEntropyLoss=2.3358 | MulticlassF1Score=0.4687
# Batch-195: CrossEntropyLoss=2.3514 | MulticlassF1Score=0.4847
# Batch-210: CrossEntropyLoss=2.3654 | MulticlassF1Score=0.4976
# Batch-225: CrossEntropyLoss=2.3431 | MulticlassF1Score=0.5093
# Batch-226: CrossEntropyLoss=2.3734 | MulticlassF1Score=0.5097
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3365 | MulticlassF1Score=0.6722
# Batch-30 : CrossEntropyLoss=2.3500 | MulticlassF1Score=0.6744
# Batch-45 : CrossEntropyLoss=2.3443 | MulticlassF1Score=0.6754
# Batch-60 : CrossEntropyLoss=2.3629 | MulticlassF1Score=0.6774
# Batch-63 : CrossEntropyLoss=2.3369 | MulticlassF1Score=0.6779
#
# Training   : Mean CrossEntropyLoss = 2.4097 | Mean MulticlassF1Score = 0.3624
# Validation : Mean CrossEntropyLoss = 2.3480 | Mean MulticlassF1Score = 0.6750
# ================================================================================
#
# EPOCH-2
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3336 | MulticlassF1Score=0.6813
# Batch-30 : CrossEntropyLoss=2.3502 | MulticlassF1Score=0.6782
# Batch-45 : CrossEntropyLoss=2.3614 | MulticlassF1Score=0.6780
# Batch-60 : CrossEntropyLoss=2.3592 | MulticlassF1Score=0.6799
# Batch-75 : CrossEntropyLoss=2.3496 | MulticlassF1Score=0.6789
# Batch-90 : CrossEntropyLoss=2.3334 | MulticlassF1Score=0.6853
# Batch-105: CrossEntropyLoss=2.3264 | MulticlassF1Score=0.6901
# Batch-120: CrossEntropyLoss=2.3509 | MulticlassF1Score=0.6943
# Batch-135: CrossEntropyLoss=2.3399 | MulticlassF1Score=0.6969
# Batch-150: CrossEntropyLoss=2.3272 | MulticlassF1Score=0.7019
# Batch-165: CrossEntropyLoss=2.3289 | MulticlassF1Score=0.7081
# Batch-180: CrossEntropyLoss=2.3082 | MulticlassF1Score=0.7149
# Batch-195: CrossEntropyLoss=2.3188 | MulticlassF1Score=0.7204
# Batch-210: CrossEntropyLoss=2.3072 | MulticlassF1Score=0.7247
# Batch-225: CrossEntropyLoss=2.3223 | MulticlassF1Score=0.7286
# Batch-226: CrossEntropyLoss=2.3038 | MulticlassF1Score=0.7289
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2979 | MulticlassF1Score=0.7860
# Batch-30 : CrossEntropyLoss=2.3228 | MulticlassF1Score=0.7906
# Batch-45 : CrossEntropyLoss=2.3086 | MulticlassF1Score=0.7915
# Batch-60 : CrossEntropyLoss=2.3104 | MulticlassF1Score=0.7900
# Batch-63 : CrossEntropyLoss=2.3298 | MulticlassF1Score=0.7906
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3328 | Mean MulticlassF1Score = 0.6962
# Validation : Mean CrossEntropyLoss = 2.3132 | Mean MulticlassF1Score = 0.7888
# ================================================================================
#
# EPOCH-3
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3190 | MulticlassF1Score=0.7854
# Batch-30 : CrossEntropyLoss=2.3208 | MulticlassF1Score=0.7858
# Batch-45 : CrossEntropyLoss=2.3129 | MulticlassF1Score=0.7881
# Batch-60 : CrossEntropyLoss=2.3025 | MulticlassF1Score=0.7899
# Batch-75 : CrossEntropyLoss=2.3167 | MulticlassF1Score=0.7917
# Batch-90 : CrossEntropyLoss=2.3119 | MulticlassF1Score=0.7926
# Batch-105: CrossEntropyLoss=2.3105 | MulticlassF1Score=0.7925
# Batch-120: CrossEntropyLoss=2.3109 | MulticlassF1Score=0.7921
# Batch-135: CrossEntropyLoss=2.3093 | MulticlassF1Score=0.7932
# Batch-150: CrossEntropyLoss=2.3116 | MulticlassF1Score=0.7934
# Batch-165: CrossEntropyLoss=2.3084 | MulticlassF1Score=0.7949
# Batch-180: CrossEntropyLoss=2.3042 | MulticlassF1Score=0.7960
# Batch-195: CrossEntropyLoss=2.3149 | MulticlassF1Score=0.7978
# Batch-210: CrossEntropyLoss=2.3084 | MulticlassF1Score=0.7987
# Batch-225: CrossEntropyLoss=2.3125 | MulticlassF1Score=0.7998
# Batch-226: CrossEntropyLoss=2.3038 | MulticlassF1Score=0.7998
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3114 | MulticlassF1Score=0.8150
# Batch-30 : CrossEntropyLoss=2.3046 | MulticlassF1Score=0.8157
# Batch-45 : CrossEntropyLoss=2.3103 | MulticlassF1Score=0.8149
# Batch-60 : CrossEntropyLoss=2.3016 | MulticlassF1Score=0.8152
# Batch-63 : CrossEntropyLoss=2.3011 | MulticlassF1Score=0.8154
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3101 | Mean MulticlassF1Score = 0.7928
# Validation : Mean CrossEntropyLoss = 2.3049 | Mean MulticlassF1Score = 0.8158
# ================================================================================
#
# EPOCH-4
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2919 | MulticlassF1Score=0.8288
# Batch-30 : CrossEntropyLoss=2.3086 | MulticlassF1Score=0.8290
# Batch-45 : CrossEntropyLoss=2.3055 | MulticlassF1Score=0.8277
# Batch-60 : CrossEntropyLoss=2.2914 | MulticlassF1Score=0.8271
# Batch-75 : CrossEntropyLoss=2.3027 | MulticlassF1Score=0.8267
# Batch-90 : CrossEntropyLoss=2.3059 | MulticlassF1Score=0.8263
# Batch-105: CrossEntropyLoss=2.3022 | MulticlassF1Score=0.8272
# Batch-120: CrossEntropyLoss=2.2988 | MulticlassF1Score=0.8279
# Batch-135: CrossEntropyLoss=2.3009 | MulticlassF1Score=0.8283
# Batch-150: CrossEntropyLoss=2.2959 | MulticlassF1Score=0.8278
# Batch-165: CrossEntropyLoss=2.3120 | MulticlassF1Score=0.8280
# Batch-180: CrossEntropyLoss=2.3027 | MulticlassF1Score=0.8278
# Batch-195: CrossEntropyLoss=2.3015 | MulticlassF1Score=0.8275
# Batch-210: CrossEntropyLoss=2.3073 | MulticlassF1Score=0.8272
# Batch-225: CrossEntropyLoss=2.2943 | MulticlassF1Score=0.8279
# Batch-226: CrossEntropyLoss=2.2949 | MulticlassF1Score=0.8279
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2956 | MulticlassF1Score=0.8294
# Batch-30 : CrossEntropyLoss=2.2936 | MulticlassF1Score=0.8335
# Batch-45 : CrossEntropyLoss=2.3119 | MulticlassF1Score=0.8319
# Batch-60 : CrossEntropyLoss=2.3023 | MulticlassF1Score=0.8346
# Batch-63 : CrossEntropyLoss=2.3073 | MulticlassF1Score=0.8346
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3013 | Mean MulticlassF1Score = 0.8275
# Validation : Mean CrossEntropyLoss = 2.2993 | Mean MulticlassF1Score = 0.8329
# ================================================================================
#
# EPOCH-5
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2936 | MulticlassF1Score=0.8381
# Batch-30 : CrossEntropyLoss=2.2944 | MulticlassF1Score=0.8385
# Batch-45 : CrossEntropyLoss=2.3044 | MulticlassF1Score=0.8390
# Batch-60 : CrossEntropyLoss=2.2844 | MulticlassF1Score=0.8379
# Batch-75 : CrossEntropyLoss=2.3006 | MulticlassF1Score=0.8384
# Batch-90 : CrossEntropyLoss=2.2993 | MulticlassF1Score=0.8379
# Batch-105: CrossEntropyLoss=2.2881 | MulticlassF1Score=0.8382
# Batch-120: CrossEntropyLoss=2.2964 | MulticlassF1Score=0.8380
# Batch-135: CrossEntropyLoss=2.2970 | MulticlassF1Score=0.8377
# Batch-150: CrossEntropyLoss=2.2950 | MulticlassF1Score=0.8370
# Batch-165: CrossEntropyLoss=2.3009 | MulticlassF1Score=0.8373
# Batch-180: CrossEntropyLoss=2.2939 | MulticlassF1Score=0.8377
# Batch-195: CrossEntropyLoss=2.2978 | MulticlassF1Score=0.8378
# Batch-210: CrossEntropyLoss=2.2849 | MulticlassF1Score=0.8379
# Batch-225: CrossEntropyLoss=2.2879 | MulticlassF1Score=0.8382
# Batch-226: CrossEntropyLoss=2.2910 | MulticlassF1Score=0.8383
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2931 | MulticlassF1Score=0.8365
# Batch-30 : CrossEntropyLoss=2.2967 | MulticlassF1Score=0.8335
# Batch-45 : CrossEntropyLoss=2.2922 | MulticlassF1Score=0.8351
# Batch-60 : CrossEntropyLoss=2.2954 | MulticlassF1Score=0.8357
# Batch-63 : CrossEntropyLoss=2.3076 | MulticlassF1Score=0.8358
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2978 | Mean MulticlassF1Score = 0.8382
# Validation : Mean CrossEntropyLoss = 2.2987 | Mean MulticlassF1Score = 0.8350
# ================================================================================
#
# EPOCH-6
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2976 | MulticlassF1Score=0.8385
# Batch-30 : CrossEntropyLoss=2.2980 | MulticlassF1Score=0.8405
# Batch-45 : CrossEntropyLoss=2.2985 | MulticlassF1Score=0.8414
# Batch-60 : CrossEntropyLoss=2.2955 | MulticlassF1Score=0.8414
# Batch-75 : CrossEntropyLoss=2.2922 | MulticlassF1Score=0.8410
# Batch-90 : CrossEntropyLoss=2.2968 | MulticlassF1Score=0.8419
# Batch-105: CrossEntropyLoss=2.2884 | MulticlassF1Score=0.8414
# Batch-120: CrossEntropyLoss=2.2976 | MulticlassF1Score=0.8407
# Batch-135: CrossEntropyLoss=2.3013 | MulticlassF1Score=0.8402
# Batch-150: CrossEntropyLoss=2.2996 | MulticlassF1Score=0.8408
# Batch-165: CrossEntropyLoss=2.3011 | MulticlassF1Score=0.8409
# Batch-180: CrossEntropyLoss=2.3019 | MulticlassF1Score=0.8414
# Batch-195: CrossEntropyLoss=2.2901 | MulticlassF1Score=0.8422
# Batch-210: CrossEntropyLoss=2.2933 | MulticlassF1Score=0.8436
# Batch-225: CrossEntropyLoss=2.2969 | MulticlassF1Score=0.8440
# Batch-226: CrossEntropyLoss=2.2975 | MulticlassF1Score=0.8440
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2894 | MulticlassF1Score=0.8494
# Batch-30 : CrossEntropyLoss=2.2911 | MulticlassF1Score=0.8518
# Batch-45 : CrossEntropyLoss=2.2887 | MulticlassF1Score=0.8533
# Batch-60 : CrossEntropyLoss=2.3023 | MulticlassF1Score=0.8522
# Batch-63 : CrossEntropyLoss=2.3045 | MulticlassF1Score=0.8515
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2961 | Mean MulticlassF1Score = 0.8412
# Validation : Mean CrossEntropyLoss = 2.2940 | Mean MulticlassF1Score = 0.8504
# ================================================================================
#
# EPOCH-7
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2858 | MulticlassF1Score=0.8551
# Batch-30 : CrossEntropyLoss=2.2940 | MulticlassF1Score=0.8547
# Batch-45 : CrossEntropyLoss=2.2962 | MulticlassF1Score=0.8574
# Batch-60 : CrossEntropyLoss=2.2943 | MulticlassF1Score=0.8577
# Batch-75 : CrossEntropyLoss=2.2852 | MulticlassF1Score=0.8586
# Batch-90 : CrossEntropyLoss=2.2861 | MulticlassF1Score=0.8578
# Batch-105: CrossEntropyLoss=2.2947 | MulticlassF1Score=0.8573
# Batch-120: CrossEntropyLoss=2.2969 | MulticlassF1Score=0.8576
# Batch-135: CrossEntropyLoss=2.2965 | MulticlassF1Score=0.8575
# Batch-150: CrossEntropyLoss=2.2934 | MulticlassF1Score=0.8579
# Batch-165: CrossEntropyLoss=2.2951 | MulticlassF1Score=0.8573
# Batch-180: CrossEntropyLoss=2.2852 | MulticlassF1Score=0.8574
# Batch-195: CrossEntropyLoss=2.2861 | MulticlassF1Score=0.8574
# Batch-210: CrossEntropyLoss=2.2851 | MulticlassF1Score=0.8577
# Batch-225: CrossEntropyLoss=2.2972 | MulticlassF1Score=0.8577
# Batch-226: CrossEntropyLoss=2.2964 | MulticlassF1Score=0.8577
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2962 | MulticlassF1Score=0.8538
# Batch-30 : CrossEntropyLoss=2.2935 | MulticlassF1Score=0.8550
# Batch-45 : CrossEntropyLoss=2.2943 | MulticlassF1Score=0.8544
# Batch-60 : CrossEntropyLoss=2.2864 | MulticlassF1Score=0.8536
# Batch-63 : CrossEntropyLoss=2.2883 | MulticlassF1Score=0.8540
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2920 | Mean MulticlassF1Score = 0.8571
# Validation : Mean CrossEntropyLoss = 2.2928 | Mean MulticlassF1Score = 0.8549
# ================================================================================
#
# EPOCH-8
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2941 | MulticlassF1Score=0.8583
# Batch-30 : CrossEntropyLoss=2.2912 | MulticlassF1Score=0.8565
# Batch-45 : CrossEntropyLoss=2.2922 | MulticlassF1Score=0.8587
# Batch-60 : CrossEntropyLoss=2.2885 | MulticlassF1Score=0.8593
# Batch-75 : CrossEntropyLoss=2.2919 | MulticlassF1Score=0.8588
# Batch-90 : CrossEntropyLoss=2.2995 | MulticlassF1Score=0.8589
# Batch-105: CrossEntropyLoss=2.2914 | MulticlassF1Score=0.8600
# Batch-120: CrossEntropyLoss=2.2892 | MulticlassF1Score=0.8599
# Batch-135: CrossEntropyLoss=2.2886 | MulticlassF1Score=0.8602
# Batch-150: CrossEntropyLoss=2.2848 | MulticlassF1Score=0.8602
# Batch-165: CrossEntropyLoss=2.2971 | MulticlassF1Score=0.8605
# Batch-180: CrossEntropyLoss=2.2857 | MulticlassF1Score=0.8607
# Batch-195: CrossEntropyLoss=2.2952 | MulticlassF1Score=0.8603
# Batch-210: CrossEntropyLoss=2.2983 | MulticlassF1Score=0.8606
# Batch-225: CrossEntropyLoss=2.2989 | MulticlassF1Score=0.8603
# Batch-226: CrossEntropyLoss=2.2964 | MulticlassF1Score=0.8602
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2917 | MulticlassF1Score=0.8594
# Batch-30 : CrossEntropyLoss=2.2908 | MulticlassF1Score=0.8566
# Batch-45 : CrossEntropyLoss=2.2864 | MulticlassF1Score=0.8558
# Batch-60 : CrossEntropyLoss=2.2971 | MulticlassF1Score=0.8546
# Batch-63 : CrossEntropyLoss=2.2863 | MulticlassF1Score=0.8547
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2911 | Mean MulticlassF1Score = 0.8597
# Validation : Mean CrossEntropyLoss = 2.2926 | Mean MulticlassF1Score = 0.8567
# ================================================================================
#
# EPOCH-9
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2844 | MulticlassF1Score=0.8618
# Batch-30 : CrossEntropyLoss=2.2890 | MulticlassF1Score=0.8650
# Batch-45 : CrossEntropyLoss=2.2848 | MulticlassF1Score=0.8655
# Batch-60 : CrossEntropyLoss=2.2911 | MulticlassF1Score=0.8664
# Batch-75 : CrossEntropyLoss=2.2975 | MulticlassF1Score=0.8653
# Batch-90 : CrossEntropyLoss=2.2867 | MulticlassF1Score=0.8652
# Batch-105: CrossEntropyLoss=2.2933 | MulticlassF1Score=0.8648
# Batch-120: CrossEntropyLoss=2.3036 | MulticlassF1Score=0.8639
# Batch-135: CrossEntropyLoss=2.2951 | MulticlassF1Score=0.8639
# Batch-150: CrossEntropyLoss=2.3098 | MulticlassF1Score=0.8637
# Batch-165: CrossEntropyLoss=2.2899 | MulticlassF1Score=0.8631
# Batch-180: CrossEntropyLoss=2.2855 | MulticlassF1Score=0.8630
# Batch-195: CrossEntropyLoss=2.2900 | MulticlassF1Score=0.8633
# Batch-210: CrossEntropyLoss=2.2896 | MulticlassF1Score=0.8647
# Batch-225: CrossEntropyLoss=2.2875 | MulticlassF1Score=0.8664
# Batch-226: CrossEntropyLoss=2.2872 | MulticlassF1Score=0.8665
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2786 | MulticlassF1Score=0.8776
# Batch-30 : CrossEntropyLoss=2.2844 | MulticlassF1Score=0.8788
# Batch-45 : CrossEntropyLoss=2.2872 | MulticlassF1Score=0.8782
# Batch-60 : CrossEntropyLoss=2.2795 | MulticlassF1Score=0.8780
# Batch-63 : CrossEntropyLoss=2.2778 | MulticlassF1Score=0.8785
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2891 | Mean MulticlassF1Score = 0.8642
# Validation : Mean CrossEntropyLoss = 2.2855 | Mean MulticlassF1Score = 0.8771
# ================================================================================
#
# EPOCH-10
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2834 | MulticlassF1Score=0.8910
# Batch-30 : CrossEntropyLoss=2.2904 | MulticlassF1Score=0.8887
# Batch-45 : CrossEntropyLoss=2.2819 | MulticlassF1Score=0.8883
# Batch-60 : CrossEntropyLoss=2.2784 | MulticlassF1Score=0.8903
# Batch-75 : CrossEntropyLoss=2.2888 | MulticlassF1Score=0.8901
# Batch-90 : CrossEntropyLoss=2.2876 | MulticlassF1Score=0.8894
# Batch-105: CrossEntropyLoss=2.2880 | MulticlassF1Score=0.8889
# Batch-120: CrossEntropyLoss=2.2760 | MulticlassF1Score=0.8888
# Batch-135: CrossEntropyLoss=2.2817 | MulticlassF1Score=0.8888
# Batch-150: CrossEntropyLoss=2.2807 | MulticlassF1Score=0.8891
# Batch-165: CrossEntropyLoss=2.2766 | MulticlassF1Score=0.8894
# Batch-180: CrossEntropyLoss=2.2765 | MulticlassF1Score=0.8895
# Batch-195: CrossEntropyLoss=2.2786 | MulticlassF1Score=0.8895
# Batch-210: CrossEntropyLoss=2.2828 | MulticlassF1Score=0.8895
# Batch-225: CrossEntropyLoss=2.2851 | MulticlassF1Score=0.8897
# Batch-226: CrossEntropyLoss=2.2835 | MulticlassF1Score=0.8897
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2809 | MulticlassF1Score=0.8809
# Batch-30 : CrossEntropyLoss=2.2814 | MulticlassF1Score=0.8824
# Batch-45 : CrossEntropyLoss=2.2879 | MulticlassF1Score=0.8826
# Batch-60 : CrossEntropyLoss=2.2861 | MulticlassF1Score=0.8830
# Batch-63 : CrossEntropyLoss=2.2803 | MulticlassF1Score=0.8832
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2820 | Mean MulticlassF1Score = 0.8894
# Validation : Mean CrossEntropyLoss = 2.2840 | Mean MulticlassF1Score = 0.8831
# ================================================================================
#
# EPOCH-11
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2780 | MulticlassF1Score=0.8961
# Batch-30 : CrossEntropyLoss=2.2716 | MulticlassF1Score=0.8982
# Batch-45 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.8975
# Batch-60 : CrossEntropyLoss=2.2803 | MulticlassF1Score=0.8966
# Batch-75 : CrossEntropyLoss=2.2770 | MulticlassF1Score=0.8962
# Batch-90 : CrossEntropyLoss=2.2742 | MulticlassF1Score=0.8960
# Batch-105: CrossEntropyLoss=2.2877 | MulticlassF1Score=0.8955
# Batch-120: CrossEntropyLoss=2.2768 | MulticlassF1Score=0.8952
# Batch-135: CrossEntropyLoss=2.2819 | MulticlassF1Score=0.8950
# Batch-150: CrossEntropyLoss=2.2874 | MulticlassF1Score=0.8947
# Batch-165: CrossEntropyLoss=2.2812 | MulticlassF1Score=0.8944
# Batch-180: CrossEntropyLoss=2.2836 | MulticlassF1Score=0.8943
# Batch-195: CrossEntropyLoss=2.2856 | MulticlassF1Score=0.8945
# Batch-210: CrossEntropyLoss=2.2990 | MulticlassF1Score=0.8936
# Batch-225: CrossEntropyLoss=2.2847 | MulticlassF1Score=0.8937
# Batch-226: CrossEntropyLoss=2.2780 | MulticlassF1Score=0.8937
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2930 | MulticlassF1Score=0.8827
# Batch-30 : CrossEntropyLoss=2.2922 | MulticlassF1Score=0.8829
# Batch-45 : CrossEntropyLoss=2.2919 | MulticlassF1Score=0.8843
# Batch-60 : CrossEntropyLoss=2.2781 | MulticlassF1Score=0.8836
# Batch-63 : CrossEntropyLoss=2.2848 | MulticlassF1Score=0.8841
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2808 | Mean MulticlassF1Score = 0.8957
# Validation : Mean CrossEntropyLoss = 2.2836 | Mean MulticlassF1Score = 0.8846
# ================================================================================
#
# EPOCH-12
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2794 | MulticlassF1Score=0.9025
# Batch-30 : CrossEntropyLoss=2.2758 | MulticlassF1Score=0.8995
# Batch-45 : CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9009
# Batch-60 : CrossEntropyLoss=2.2771 | MulticlassF1Score=0.9001
# Batch-75 : CrossEntropyLoss=2.2808 | MulticlassF1Score=0.8987
# Batch-90 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.8991
# Batch-105: CrossEntropyLoss=2.2872 | MulticlassF1Score=0.8982
# Batch-120: CrossEntropyLoss=2.2834 | MulticlassF1Score=0.8971
# Batch-135: CrossEntropyLoss=2.2816 | MulticlassF1Score=0.8967
# Batch-150: CrossEntropyLoss=2.2783 | MulticlassF1Score=0.8967
# Batch-165: CrossEntropyLoss=2.2772 | MulticlassF1Score=0.8964
# Batch-180: CrossEntropyLoss=2.2836 | MulticlassF1Score=0.8962
# Batch-195: CrossEntropyLoss=2.2779 | MulticlassF1Score=0.8962
# Batch-210: CrossEntropyLoss=2.2773 | MulticlassF1Score=0.8961
# Batch-225: CrossEntropyLoss=2.2834 | MulticlassF1Score=0.8960
# Batch-226: CrossEntropyLoss=2.2824 | MulticlassF1Score=0.8960
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2805 | MulticlassF1Score=0.8873
# Batch-30 : CrossEntropyLoss=2.2817 | MulticlassF1Score=0.8852
# Batch-45 : CrossEntropyLoss=2.2832 | MulticlassF1Score=0.8862
# Batch-60 : CrossEntropyLoss=2.2847 | MulticlassF1Score=0.8852
# Batch-63 : CrossEntropyLoss=2.2835 | MulticlassF1Score=0.8853
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2800 | Mean MulticlassF1Score = 0.8980
# Validation : Mean CrossEntropyLoss = 2.2832 | Mean MulticlassF1Score = 0.8856
# ================================================================================
#
# EPOCH-13
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2775 | MulticlassF1Score=0.8975
# Batch-30 : CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9023
# Batch-45 : CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9025
# Batch-60 : CrossEntropyLoss=2.2789 | MulticlassF1Score=0.9009
# Batch-75 : CrossEntropyLoss=2.2860 | MulticlassF1Score=0.8999
# Batch-90 : CrossEntropyLoss=2.2753 | MulticlassF1Score=0.8999
# Batch-105: CrossEntropyLoss=2.2838 | MulticlassF1Score=0.8989
# Batch-120: CrossEntropyLoss=2.2723 | MulticlassF1Score=0.8990
# Batch-135: CrossEntropyLoss=2.2760 | MulticlassF1Score=0.8988
# Batch-150: CrossEntropyLoss=2.2796 | MulticlassF1Score=0.8992
# Batch-165: CrossEntropyLoss=2.2820 | MulticlassF1Score=0.8988
# Batch-180: CrossEntropyLoss=2.2800 | MulticlassF1Score=0.8988
# Batch-195: CrossEntropyLoss=2.2778 | MulticlassF1Score=0.8983
# Batch-210: CrossEntropyLoss=2.2862 | MulticlassF1Score=0.8981
# Batch-225: CrossEntropyLoss=2.2812 | MulticlassF1Score=0.8978
# Batch-226: CrossEntropyLoss=2.2819 | MulticlassF1Score=0.8978
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2845 | MulticlassF1Score=0.8905
# Batch-30 : CrossEntropyLoss=2.2828 | MulticlassF1Score=0.8884
# Batch-45 : CrossEntropyLoss=2.2837 | MulticlassF1Score=0.8870
# Batch-60 : CrossEntropyLoss=2.2891 | MulticlassF1Score=0.8862
# Batch-63 : CrossEntropyLoss=2.2923 | MulticlassF1Score=0.8856
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2794 | Mean MulticlassF1Score = 0.8994
# Validation : Mean CrossEntropyLoss = 2.2831 | Mean MulticlassF1Score = 0.8895
# ================================================================================
#
# EPOCH-14
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9030
# Batch-30 : CrossEntropyLoss=2.2810 | MulticlassF1Score=0.9001
# Batch-45 : CrossEntropyLoss=2.2810 | MulticlassF1Score=0.9002
# Batch-60 : CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9003
# Batch-75 : CrossEntropyLoss=2.2830 | MulticlassF1Score=0.9003
# Batch-90 : CrossEntropyLoss=2.2773 | MulticlassF1Score=0.9002
# Batch-105: CrossEntropyLoss=2.2789 | MulticlassF1Score=0.8999
# Batch-120: CrossEntropyLoss=2.2812 | MulticlassF1Score=0.8997
# Batch-135: CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9000
# Batch-150: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9001
# Batch-165: CrossEntropyLoss=2.2851 | MulticlassF1Score=0.9000
# Batch-180: CrossEntropyLoss=2.2807 | MulticlassF1Score=0.8997
# Batch-195: CrossEntropyLoss=2.2808 | MulticlassF1Score=0.8994
# Batch-210: CrossEntropyLoss=2.2754 | MulticlassF1Score=0.8995
# Batch-225: CrossEntropyLoss=2.2782 | MulticlassF1Score=0.8994
# Batch-226: CrossEntropyLoss=2.2804 | MulticlassF1Score=0.8993
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2846 | MulticlassF1Score=0.8923
# Batch-30 : CrossEntropyLoss=2.2890 | MulticlassF1Score=0.8912
# Batch-45 : CrossEntropyLoss=2.2875 | MulticlassF1Score=0.8878
# Batch-60 : CrossEntropyLoss=2.2927 | MulticlassF1Score=0.8867
# Batch-63 : CrossEntropyLoss=2.2817 | MulticlassF1Score=0.8864
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2788 | Mean MulticlassF1Score = 0.9003
# Validation : Mean CrossEntropyLoss = 2.2827 | Mean MulticlassF1Score = 0.8899
# ================================================================================
#
# EPOCH-15
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2793 | MulticlassF1Score=0.8982
# Batch-30 : CrossEntropyLoss=2.2853 | MulticlassF1Score=0.8969
# Batch-45 : CrossEntropyLoss=2.2717 | MulticlassF1Score=0.8976
# Batch-60 : CrossEntropyLoss=2.2788 | MulticlassF1Score=0.8981
# Batch-75 : CrossEntropyLoss=2.2783 | MulticlassF1Score=0.8975
# Batch-90 : CrossEntropyLoss=2.2753 | MulticlassF1Score=0.8988
# Batch-105: CrossEntropyLoss=2.2777 | MulticlassF1Score=0.8992
# Batch-120: CrossEntropyLoss=2.2808 | MulticlassF1Score=0.8989
# Batch-135: CrossEntropyLoss=2.2766 | MulticlassF1Score=0.8998
# Batch-150: CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9000
# Batch-165: CrossEntropyLoss=2.2852 | MulticlassF1Score=0.8997
# Batch-180: CrossEntropyLoss=2.2817 | MulticlassF1Score=0.9000
# Batch-195: CrossEntropyLoss=2.2821 | MulticlassF1Score=0.9006
# Batch-210: CrossEntropyLoss=2.2792 | MulticlassF1Score=0.9007
# Batch-225: CrossEntropyLoss=2.2775 | MulticlassF1Score=0.9011
# Batch-226: CrossEntropyLoss=2.2770 | MulticlassF1Score=0.9011
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2795 | MulticlassF1Score=0.8952
# Batch-30 : CrossEntropyLoss=2.2845 | MulticlassF1Score=0.8903
# Batch-45 : CrossEntropyLoss=2.2781 | MulticlassF1Score=0.8900
# Batch-60 : CrossEntropyLoss=2.2786 | MulticlassF1Score=0.8873
# Batch-63 : CrossEntropyLoss=2.2815 | MulticlassF1Score=0.8875
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2782 | Mean MulticlassF1Score = 0.8988
# Validation : Mean CrossEntropyLoss = 2.2824 | Mean MulticlassF1Score = 0.8899
# ================================================================================
#
# EPOCH-16
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2747 | MulticlassF1Score=0.8978
# Batch-30 : CrossEntropyLoss=2.2811 | MulticlassF1Score=0.9025
# Batch-45 : CrossEntropyLoss=2.2795 | MulticlassF1Score=0.9017
# Batch-60 : CrossEntropyLoss=2.2774 | MulticlassF1Score=0.9021
# Batch-75 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9061
# Batch-90 : CrossEntropyLoss=2.2769 | MulticlassF1Score=0.9084
# Batch-105: CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9099
# Batch-120: CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9115
# Batch-135: CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9129
# Batch-150: CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9149
# Batch-165: CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9160
# Batch-180: CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9168
# Batch-195: CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9179
# Batch-210: CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9189
# Batch-225: CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9198
# Batch-226: CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9199
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2765 | MulticlassF1Score=0.9164
# Batch-30 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9221
# Batch-45 : CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9208
# Batch-60 : CrossEntropyLoss=2.2812 | MulticlassF1Score=0.9196
# Batch-63 : CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9192
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2726 | Mean MulticlassF1Score = 0.9096
# Validation : Mean CrossEntropyLoss = 2.2729 | Mean MulticlassF1Score = 0.9191
# ================================================================================
#
# EPOCH-17
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9369
# Batch-30 : CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9342
# Batch-45 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9342
# Batch-60 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9346
# Batch-75 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9345
# Batch-90 : CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9339
# Batch-105: CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9343
# Batch-120: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9341
# Batch-135: CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9343
# Batch-150: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9343
# Batch-165: CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9340
# Batch-180: CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9341
# Batch-195: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9339
# Batch-210: CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9338
# Batch-225: CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9339
# Batch-226: CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9340
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9211
# Batch-30 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9207
# Batch-45 : CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9208
# Batch-60 : CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9202
# Batch-63 : CrossEntropyLoss=2.2774 | MulticlassF1Score=0.9202
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2682 | Mean MulticlassF1Score = 0.9341
# Validation : Mean CrossEntropyLoss = 2.2725 | Mean MulticlassF1Score = 0.9202
# ================================================================================
#
# EPOCH-18
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9365
# Batch-30 : CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9355
# Batch-45 : CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9357
# Batch-60 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9357
# Batch-75 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9366
# Batch-90 : CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9367
# Batch-105: CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9370
# Batch-120: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9370
# Batch-135: CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9368
# Batch-150: CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9367
# Batch-165: CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9367
# Batch-180: CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9365
# Batch-195: CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9366
# Batch-210: CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9364
# Batch-225: CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9364
# Batch-226: CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9364
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9184
# Batch-30 : CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9192
# Batch-45 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9209
# Batch-60 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9217
# Batch-63 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9216
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2674 | Mean MulticlassF1Score = 0.9363
# Validation : Mean CrossEntropyLoss = 2.2719 | Mean MulticlassF1Score = 0.9209
# ================================================================================
#
# EPOCH-19
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9381
# Batch-30 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9384
# Batch-45 : CrossEntropyLoss=2.2612 | MulticlassF1Score=0.9394
# Batch-60 : CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9389
# Batch-75 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9388
# Batch-90 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9386
# Batch-105: CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9387
# Batch-120: CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9387
# Batch-135: CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9383
# Batch-150: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9386
# Batch-165: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9383
# Batch-180: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9384
# Batch-195: CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9384
# Batch-210: CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9382
# Batch-225: CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9382
# Batch-226: CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9382
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9245
# Batch-30 : CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9228
# Batch-45 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9217
# Batch-60 : CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9222
# Batch-63 : CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9227
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2668 | Mean MulticlassF1Score = 0.9387
# Validation : Mean CrossEntropyLoss = 2.2716 | Mean MulticlassF1Score = 0.9230
# ================================================================================
#
# EPOCH-20
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9454
# Batch-30 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9424
# Batch-45 : CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9414
# Batch-60 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9415
# Batch-75 : CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9416
# Batch-90 : CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9416
# Batch-105: CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9410
# Batch-120: CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9410
# Batch-135: CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9408
# Batch-150: CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9410
# Batch-165: CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9409
# Batch-180: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9410
# Batch-195: CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9411
# Batch-210: CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9408
# Batch-225: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9411
# Batch-226: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9411
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9207
# Batch-30 : CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9247
# Batch-45 : CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9233
# Batch-60 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9240
# Batch-63 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9242
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2658 | Mean MulticlassF1Score = 0.9417
# Validation : Mean CrossEntropyLoss = 2.2711 | Mean MulticlassF1Score = 0.9230
# ================================================================================
#
# EPOCH-21
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9369
# Batch-30 : CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9400
# Batch-45 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9413
# Batch-60 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9414
# Batch-75 : CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9412
# Batch-90 : CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9414
# Batch-105: CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9418
# Batch-120: CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9421
# Batch-135: CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9424
# Batch-150: CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9422
# Batch-165: CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9422
# Batch-180: CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9421
# Batch-195: CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9419
# Batch-210: CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9423
# Batch-225: CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9420
# Batch-226: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9421
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9264
# Batch-30 : CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9252
# Batch-45 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9244
# Batch-60 : CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9237
# Batch-63 : CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9239
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2655 | Mean MulticlassF1Score = 0.9413
# Validation : Mean CrossEntropyLoss = 2.2711 | Mean MulticlassF1Score = 0.9250
# ================================================================================
#
# EPOCH-22
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9438
# Batch-30 : CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9452
# Batch-45 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9461
# Batch-60 : CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9446
# Batch-75 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9447
# Batch-90 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9433
# Batch-105: CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9431
# Batch-120: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9432
# Batch-135: CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9430
# Batch-150: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9432
# Batch-165: CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9431
# Batch-180: CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9428
# Batch-195: CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9427
# Batch-210: CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9427
# Batch-225: CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9428
# Batch-226: CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9428
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9275
# Batch-30 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9258
# Batch-45 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9241
# Batch-60 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9234
# Batch-63 : CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9238
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2652 | Mean MulticlassF1Score = 0.9438
# Validation : Mean CrossEntropyLoss = 2.2712 | Mean MulticlassF1Score = 0.9269
# ================================================================================
#
# EPOCH-23
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9445
# Batch-30 : CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9428
# Batch-45 : CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9427
# Batch-60 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9429
# Batch-75 : CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9429
# Batch-90 : CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9434
# Batch-105: CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9432
# Batch-120: CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9434
# Batch-135: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9433
# Batch-150: CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9432
# Batch-165: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9432
# Batch-180: CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9433
# Batch-195: CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9435
# Batch-210: CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9434
# Batch-225: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9432
# Batch-226: CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9432
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9190
# Batch-30 : CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9244
# Batch-45 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9238
# Batch-60 : CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9243
# Batch-63 : CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9243
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2651 | Mean MulticlassF1Score = 0.9435
# Validation : Mean CrossEntropyLoss = 2.2710 | Mean MulticlassF1Score = 0.9224
# ================================================================================
#
# EPOCH-24
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9434
# Batch-30 : CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9446
# Batch-45 : CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9436
# Batch-60 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9433
# Batch-75 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9438
# Batch-90 : CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9439
# Batch-105: CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9438
# Batch-120: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9437
# Batch-135: CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9441
# Batch-150: CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9441
# Batch-165: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9440
# Batch-180: CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9440
# Batch-195: CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9439
# Batch-210: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9439
# Batch-225: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9439
# Batch-226: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9438
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2751 | MulticlassF1Score=0.9262
# Batch-30 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9227
# Batch-45 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9248
# Batch-60 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9248
# Batch-63 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9250
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2649 | Mean MulticlassF1Score = 0.9438
# Validation : Mean CrossEntropyLoss = 2.2708 | Mean MulticlassF1Score = 0.9259
# ================================================================================
#
# EPOCH-25
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9423
# Batch-30 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9464
# Batch-45 : CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9470
# Batch-60 : CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9463
# Batch-75 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9463
# Batch-90 : CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9460
# Batch-105: CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9457
# Batch-120: CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9456
# Batch-135: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9455
# Batch-150: CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9453
# Batch-165: CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9454
# Batch-180: CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9456
# Batch-195: CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9456
# Batch-210: CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9453
# Batch-225: CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9454
# Batch-226: CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9454
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2790 | MulticlassF1Score=0.9289
# Batch-30 : CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9293
# Batch-45 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9284
# Batch-60 : CrossEntropyLoss=2.2754 | MulticlassF1Score=0.9272
# Batch-63 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9270
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2644 | Mean MulticlassF1Score = 0.9454
# Validation : Mean CrossEntropyLoss = 2.2702 | Mean MulticlassF1Score = 0.9307
# ================================================================================
#
# EPOCH-26
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9500
# Batch-30 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9505
# Batch-45 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9492
# Batch-60 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9493
# Batch-75 : CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9484
# Batch-90 : CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9478
# Batch-105: CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9475
# Batch-120: CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9474
# Batch-135: CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9470
# Batch-150: CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9464
# Batch-165: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9462
# Batch-180: CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9464
# Batch-195: CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9465
# Batch-210: CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9463
# Batch-225: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9459
# Batch-226: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9459
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9281
# Batch-30 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9295
# Batch-45 : CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9284
# Batch-60 : CrossEntropyLoss=2.2825 | MulticlassF1Score=0.9271
# Batch-63 : CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9269
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2642 | Mean MulticlassF1Score = 0.9478
# Validation : Mean CrossEntropyLoss = 2.2702 | Mean MulticlassF1Score = 0.9284
# ================================================================================
#
# EPOCH-27
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9468
# Batch-30 : CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9472
# Batch-45 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9471
# Batch-60 : CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9472
# Batch-75 : CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9464
# Batch-90 : CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9463
# Batch-105: CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9466
# Batch-120: CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9468
# Batch-135: CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9467
# Batch-150: CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9463
# Batch-165: CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9466
# Batch-180: CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9466
# Batch-195: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9464
# Batch-210: CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9464
# Batch-225: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9465
# Batch-226: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9465
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9201
# Batch-30 : CrossEntropyLoss=2.2786 | MulticlassF1Score=0.9205
# Batch-45 : CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9204
# Batch-60 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9217
# Batch-63 : CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9217
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2643 | Mean MulticlassF1Score = 0.9466
# Validation : Mean CrossEntropyLoss = 2.2720 | Mean MulticlassF1Score = 0.9190
# Patience = 1/50❗
# ================================================================================
#
# EPOCH-28
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9430
# Batch-30 : CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9428
# Batch-45 : CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9428
# Batch-60 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9429
# Batch-75 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9438
# Batch-90 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9442
# Batch-105: CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9442
# Batch-120: CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9444
# Batch-135: CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9438
# Batch-150: CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9454
# Batch-165: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9469
# Batch-180: CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9483
# Batch-195: CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9493
# Batch-210: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9500
# Batch-225: CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9508
# Batch-226: CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9509
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9433
# Batch-30 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9454
# Batch-45 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9451
# Batch-60 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9453
# Batch-63 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9454
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2629 | Mean MulticlassF1Score = 0.9454
# Validation : Mean CrossEntropyLoss = 2.2646 | Mean MulticlassF1Score = 0.9450
# ================================================================================
#
# EPOCH-29
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9623
# Batch-30 : CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9650
# Batch-45 : CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9642
# Batch-60 : CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9650
# Batch-75 : CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9647
# Batch-90 : CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9650
# Batch-105: CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9649
# Batch-120: CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9649
# Batch-135: CrossEntropyLoss=2.2542 | MulticlassF1Score=0.9654
# Batch-150: CrossEntropyLoss=2.2589 | MulticlassF1Score=0.9654
# Batch-165: CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9654
# Batch-180: CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9654
# ...
# Batch-45 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9498
# Batch-60 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9495
# Batch-63 : CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9488
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2565 | Mean MulticlassF1Score = 0.9704
# Validation : Mean CrossEntropyLoss = 2.2633 | Mean MulticlassF1Score = 0.9496
# ================================================================================
#
# EPOCH-42
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2538 | MulticlassF1Score=0.9713
# Batch-30 : CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9711
# Batch-45 : CrossEntropyLoss=2.2530 | MulticlassF1Score=0.9724
# Batch-60 : CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9719
# Batch-75 : CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9709
# Batch-90 : CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9707
# Batch-105: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9707
# Batch-120: CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9708
# Batch-135: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9711
# Batch-150: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9709
# Batch-165: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9708
# Batch-180: CrossEntropyLoss=2.2538 | MulticlassF1Score=0.9708
# Batch-195: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9710
# Batch-210: CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9711
# Batch-225: CrossEntropyLoss=2.2533 | MulticlassF1Score=0.9710
# Batch-226: CrossEntropyLoss=2.2589 | MulticlassF1Score=0.9710
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9468
# Batch-30 : CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9492
# Batch-45 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9489
# Batch-60 : CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9492
# Batch-63 : CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9488
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2564 | Mean MulticlassF1Score = 0.9710
# Validation : Mean CrossEntropyLoss = 2.2633 | Mean MulticlassF1Score = 0.9478
# ================================================================================
#
# EPOCH-43
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9704
# Batch-30 : CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9706
# Batch-45 : CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9709
# Batch-60 : CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9713
# Batch-75 : CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9718
# Batch-90 : CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9718
# Batch-105: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9719
# Batch-120: CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9719
# Batch-135: CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9720
# Batch-150: CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9719
# Batch-165: CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9716
# Batch-180: CrossEntropyLoss=2.2541 | MulticlassF1Score=0.9713
# Batch-195: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9712
# Batch-210: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9713
# Batch-225: CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9710
# Batch-226: CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9710
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9491
# Batch-30 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9506
# Batch-45 : CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9484
# Batch-60 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9489
# Batch-63 : CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9487
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2564 | Mean MulticlassF1Score = 0.9715
# Validation : Mean CrossEntropyLoss = 2.2634 | Mean MulticlassF1Score = 0.9498
# ================================================================================
#
# EPOCH-44
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9722
# Batch-30 : CrossEntropyLoss=2.2543 | MulticlassF1Score=0.9721
# Batch-45 : CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9717
# Batch-60 : CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9716
# Batch-75 : CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9715
# Batch-90 : CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9717
# Batch-105: CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9712
# Batch-120: CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9713
# Batch-135: CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9716
# Batch-150: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9715
# Batch-165: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9715
# Batch-180: CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9714
# Batch-195: CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9714
# Batch-210: CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9715
# Batch-225: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9715
# Batch-226: CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9715
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9463
# Batch-30 : CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9475
# Batch-45 : CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9490
# Batch-60 : CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9491
# Batch-63 : CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9490
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2562 | Mean MulticlassF1Score = 0.9717
# Validation : Mean CrossEntropyLoss = 2.2633 | Mean MulticlassF1Score = 0.9484
# ================================================================================
#
# EPOCH-45
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9719
# Batch-30 : CrossEntropyLoss=2.2551 | MulticlassF1Score=0.9710
# Batch-45 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9714
# Batch-60 : CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9720
# Batch-75 : CrossEntropyLoss=2.2526 | MulticlassF1Score=0.9720
# Batch-90 : CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9724
# Batch-105: CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9725
# Batch-120: CrossEntropyLoss=2.2547 | MulticlassF1Score=0.9721
# Batch-135: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9719
# Batch-150: CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9721
# Batch-165: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9721
# Batch-180: CrossEntropyLoss=2.2547 | MulticlassF1Score=0.9719
# Batch-195: CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9718
# Batch-210: CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9718
# Batch-225: CrossEntropyLoss=2.2541 | MulticlassF1Score=0.9718
# Batch-226: CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9717
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9474
# Batch-30 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9474
# Batch-45 : CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9465
# Batch-60 : CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9489
# Batch-63 : CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9490
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2562 | Mean MulticlassF1Score = 0.9720
# Validation : Mean CrossEntropyLoss = 2.2632 | Mean MulticlassF1Score = 0.9467
# ================================================================================
#
# EPOCH-46
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9714
# Batch-30 : CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9716
# Batch-45 : CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9704
# Batch-60 : CrossEntropyLoss=2.2544 | MulticlassF1Score=0.9708
# Batch-75 : CrossEntropyLoss=2.2540 | MulticlassF1Score=0.9716
# Batch-90 : CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9718
# Batch-105: CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9717
# Batch-120: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9715
# Batch-135: CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9715
# Batch-150: CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9716
# Batch-165: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9716
# Batch-180: CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9716
# Batch-195: CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9716
# Batch-210: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9719
# Batch-225: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9721
# Batch-226: CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9721
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9516
# Batch-30 : CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9504
# Batch-45 : CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9493
# Batch-60 : CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9497
# Batch-63 : CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9496
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2560 | Mean MulticlassF1Score = 0.9714
# Validation : Mean CrossEntropyLoss = 2.2631 | Mean MulticlassF1Score = 0.9501
# ================================================================================
#
# EPOCH-47
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2526 | MulticlassF1Score=0.9743
# Batch-30 : CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9733
# Batch-45 : CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9731
# Batch-60 : CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9722
# Batch-75 : CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9724
# Batch-90 : CrossEntropyLoss=2.2531 | MulticlassF1Score=0.9717
# Batch-105: CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9718
# Batch-120: CrossEntropyLoss=2.2539 | MulticlassF1Score=0.9721
# Batch-135: CrossEntropyLoss=2.2551 | MulticlassF1Score=0.9723
# Batch-150: CrossEntropyLoss=2.2519 | MulticlassF1Score=0.9721
# Batch-165: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9721
# Batch-180: CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9721
# Batch-195: CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9721
# Batch-210: CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9719
# Batch-225: CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9719
# Batch-226: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9719
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9509
# Batch-30 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9498
# Batch-45 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9492
# Batch-60 : CrossEntropyLoss=2.2611 | MulticlassF1Score=0.9497
# Batch-63 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9490
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2561 | Mean MulticlassF1Score = 0.9724
# Validation : Mean CrossEntropyLoss = 2.2634 | Mean MulticlassF1Score = 0.9491
# Patience = 5/50❗
# ================================================================================
#
# EPOCH-48
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9741
# Batch-30 : CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9718
# Batch-45 : CrossEntropyLoss=2.2531 | MulticlassF1Score=0.9721
# Batch-60 : CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9722
# Batch-75 : CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9724
# Batch-90 : CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9723
# Batch-105: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9721
# Batch-120: CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9721
# Batch-135: CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9721
# Batch-150: CrossEntropyLoss=2.2543 | MulticlassF1Score=0.9722
# Batch-165: CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9721
# Batch-180: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9718
# Batch-195: CrossEntropyLoss=2.2551 | MulticlassF1Score=0.9718
# Batch-210: CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9718
# Batch-225: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9718
# Batch-226: CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9717
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9517
# Batch-30 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9500
# Batch-45 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9483
# Batch-60 : CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9484
# Batch-63 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9486
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2562 | Mean MulticlassF1Score = 0.9722
# Validation : Mean CrossEntropyLoss = 2.2634 | Mean MulticlassF1Score = 0.9504
# Patience = 6/50❗
# ================================================================================
#
# EPOCH-49
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9714
# Batch-30 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9725
# Batch-45 : CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9727
# Batch-60 : CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9726
# Batch-75 : CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9722
# Batch-90 : CrossEntropyLoss=2.2540 | MulticlassF1Score=0.9721
# Batch-105: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9719
# Batch-120: CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9718
# Batch-135: CrossEntropyLoss=2.2534 | MulticlassF1Score=0.9719
# Batch-150: CrossEntropyLoss=2.2543 | MulticlassF1Score=0.9719
# Batch-165: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9718
# Batch-180: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9718
# Batch-195: CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9717
# Batch-210: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9718
# Batch-225: CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9719
# Batch-226: CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9719
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9492
# Batch-30 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9481
# Batch-45 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9482
# Batch-60 : CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9491
# Batch-63 : CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9488
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2561 | Mean MulticlassF1Score = 0.9722
# Validation : Mean CrossEntropyLoss = 2.2633 | Mean MulticlassF1Score = 0.9490
# ================================================================================
#
# EPOCH-50
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9714
# Batch-30 : CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9711
# Batch-45 : CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9714
# Batch-60 : CrossEntropyLoss=2.2538 | MulticlassF1Score=0.9722
# Batch-75 : CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9726
# Batch-90 : CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9725
# Batch-105: CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9724
# Batch-120: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9722
# Batch-135: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9719
# Batch-150: CrossEntropyLoss=2.2542 | MulticlassF1Score=0.9719
# Batch-165: CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9721
# Batch-180: CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9721
# Batch-195: CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9721
# Batch-210: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9721
# Batch-225: CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9718
# Batch-226: CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9718
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9487
# Batch-30 : CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9484
# Batch-45 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9477
# Batch-60 : CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9482
# Batch-63 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9485
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2561 | Mean MulticlassF1Score = 0.9720
# Validation : Mean CrossEntropyLoss = 2.2634 | Mean MulticlassF1Score = 0.9485
# Patience = 7/50❗
# ================================================================================
#
# TRAINING SUMMARY
# Best CrossEntropyLoss training    : 2.2561
# Best CrossEntropyLoss training    : 2.2633
# Best MulticlassF1Score validation : 0.9722
# Best MulticlassF1Score validation : 0.9490
# Training duration                 : 4.7822 minutes.
# Training date                     : 2022-10-19 08:35:12.593765+08:00

# %% [markdown]
# ## End Training

# %% [markdown]
# # Evaluation

# %%
def evaluation(dataloader, model, criterion, metric):
    model.eval()
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)
            pred = rearrange(prob.argmax(dim=1).reshape(feature.shape[0], len(dataloader.dataset)), "s n -> n s")

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob.argmax(dim=1), actual_label.to(hyperparams.device))
            metric_score = metric.compute()

    return loss, metric_score, pred

train_dataloader = DataLoader(train_dataset, batch_size=len(train_dataset))
val_dataloader = DataLoader(val_dataset, batch_size=len(val_dataset))
test_dataloader = DataLoader(test_dataset, batch_size=len(test_dataset))

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
train_loss, train_f1_score, train_pred_label = evaluation(train_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_loss, val_f1_score, val_pred_label = evaluation(val_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
test_loss, test_f1_score, test_pred_label = evaluation(test_dataloader, model, criterion, metric)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9725, device='cuda:0'),
#  tensor(0.9485, device='cuda:0'),
#  tensor(0.9502, device='cuda:0'))

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9725, device='cuda:0'),
#  tensor(0.9485, device='cuda:0'),
#  tensor(0.9502, device='cuda:0'))

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns

def viz_evaluation(pred_label, actual_label, title):
    plt.figure(figsize=(15, 7), dpi=200)
    sns.heatmap(pred_label.detach().cpu() == actual_label, cbar=True, cmap="binary_r")
    plt.xlabel("Sentence Length")
    plt.ylabel("Sentence")
    plt.title(title)
    plt.savefig(f"{root_path}/heatmap_{title.lower()}.jpg", dpi=200)
    plt.show()

train_actual_label = train_dataloader.dataset.tensors[1]
val_actual_label = val_dataloader.dataset.tensors[1]
test_actual_label = test_dataloader.dataset.tensors[1]

viz_evaluation(train_pred_label, train_actual_label, f"Training (F1-Score: {(train_f1_score):.4f})")
viz_evaluation(val_pred_label, val_actual_label, f"Validation (F1-Score: {(val_f1_score):.4f})")
viz_evaluation(test_pred_label, test_actual_label, f"Test (F1-Score: {(test_f1_score):.4f})")

# %% [markdown]
# ## Confusion Matrix

# %%
def confusion_matrix(pred_class, actual_class, title, normalize=None):
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize=normalize)
    plt.figure(figsize=(20, 10), dpi=200)
    sns.heatmap(conf_mat(pred_class.detach().cpu(), actual_class), annot=True, fmt=".2g", xticklabels=list(label_to_idx.keys()), yticklabels=list(label_to_idx.keys()));
    plt.yticks(rotation=0)
    plt.title(title)
    plt.xlabel("Actual Class")
    plt.ylabel("Predict Class")
    plt.savefig(f"{root_path}/conf_matrix_{title.lower()}.jpg", dpi=200)

confusion_matrix(train_pred_label, train_actual_label, "Training", "pred")
confusion_matrix(val_pred_label,val_actual_label, "Validation", "pred")
confusion_matrix(test_pred_label, test_actual_label, "Test", "pred")
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 96 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 120 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)

# %% [markdown]
# ## Prediction Table

# %%
def number_wrong_pred_each_class(pred_class, actual_class):
    classes, count_class = actual_class.flatten().unique(return_counts=True)
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize="none")
    correct_pred_count_class = conf_mat(pred_class.detach().cpu(), actual_class).diag()
    
    correct_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (correct_pred_count_class))}
    wrong_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (count_class - correct_pred_count_class))}
    
    return correct_pred, wrong_pred

correct_pred, wrong_pred = number_wrong_pred_each_class(train_pred_label, train_actual_label)
print(f"| {'Number class'.ljust(14)} | {'Correct prediction'.ljust(12)} | {'Wrong prediction'.ljust(12)} |")
for (label_correct_pred, count_correct_pred), (label_wrong_pred, count_wrong_pred) in zip(correct_pred.items(), wrong_pred.items()):
    print(f"| {str(label_correct_pred).ljust(6)}: {str(count_correct_pred + count_wrong_pred).ljust(7)}| {label_correct_pred.ljust(6)}: {str(count_correct_pred).ljust(10)} | {label_wrong_pred.ljust(6)}: {str(count_wrong_pred).ljust(8)} |")
# Out:
# | Number class   | Correct prediction | Wrong prediction |
# | CC    : 5336   | CC    : 5229       | CC    : 107      |
# | CD    : 12904  | CD    : 12817      | CD    : 87       |
# | DT    : 263    | DT    : 0          | DT    : 263      |
# | FW    : 1697   | FW    : 1481       | FW    : 216      |
# | IN    : 15290  | IN    : 15158      | IN    : 132      |
# | JJ    : 7049   | JJ    : 6799       | JJ    : 250      |
# | MD    : 3783   | MD    : 3692       | MD    : 91       |
# | NEG   : 1126   | NEG   : 0          | NEG   : 1126     |
# | NN    : 44769  | NN    : 44251      | NN    : 518      |
# | NND   : 998    | NND   : 857        | NND   : 141      |
# | NNP   : 24884  | NNP   : 24418      | NNP   : 466      |
# | OD    : 550    | OD    : 406        | OD    : 144      |
# | PR    : 3878   | PR    : 3845       | PR    : 33       |
# | PRP   : 5355   | PRP   : 5282       | PRP   : 73       |
# | RB    : 3517   | RB    : 3342       | RB    : 175      |
# | RP    : 131    | RP    : 0          | RP    : 131      |
# | SC    : 9467   | SC    : 9229       | SC    : 238      |
# | SYM   : 1570   | SYM   : 1473       | SYM   : 97       |
# | UH    : 21     | UH    : 13         | UH    : 8        |
# | VB    : 22796  | VB    : 22465      | VB    : 331      |
# | WH    : 180    | WH    : 0          | WH    : 180      |
# | X     : 282    | X     : 12         | X     : 270      |
# | Z     : 18940  | Z     : 18940      | Z     : 0        |
# | <PAD> : 407418 | <PAD> : 407418     | <PAD> : 0        |

# %%
train_actual_label[308], train_pred_label[308]
# Out:
# (tensor([ 8, 19, 22, 10, 22, 19, 10,  6, 19,  4,  1,  8, 16, 19,  8, 19,  0,  8,
#           5, 16, 19, 19,  8,  8, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23]),
#  tensor([ 8, 19, 22, 10, 22, 19, 10,  6, 19,  4,  1,  8, 16, 19,  8, 19,  0,  8,
#           5, 16, 19, 19,  8,  8, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23], device='cuda:0'))

# %%
train_actual_label[308] == train_pred_label[308].detach().cpu()
# Out:
# tensor([True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True])

# %% [markdown]
# ## OOV prediction is correct

# %%
def oov_flag_token(sentences, max_seq_len=hyperparams.max_seq_len):
    sent_copy = deepcopy(sentences)
    sent = []
    oov_flag = []
    
    for sentence in tqdm(sent_copy):
        for token in sentence:
            sent.append(token[2])
        
        for _ in range(max_seq_len- len(sentence)):
            sent.append(False)
        
        oov_flag.append(sent)
        sent = []
        
    return np.array(oov_flag)

train_oov_flag = oov_flag_token(train_sentences, max_seq_len=hyperparams.max_seq_len)
val_oov_flag = oov_flag_token(val_sentences, max_seq_len=hyperparams.max_seq_len)
test_oov_flag = oov_flag_token(test_sentences, max_seq_len=hyperparams.max_seq_len)

def pencentage_oov_pred_correct(pred_oov_flag, oov_flag_tensor):
    oov_correct_counter = 0
    oov_wrong_counter = 0

    for pred, oov_label in tqdm(zip(pred_oov_flag, oov_flag_tensor)):
        if pred == True and oov_label == True:
            oov_correct_counter += 1
        elif pred == False and oov_label == True:
            oov_wrong_counter += 1
        else:
            continue
            
    return oov_correct_counter, oov_wrong_counter

train_pred_oov_flag = (train_actual_label == train_pred_label.detach().cpu()).flatten()
val_pred_oov_flag = (val_actual_label == val_pred_label.detach().cpu()).flatten()
test_pred_oov_flag = (test_actual_label == test_pred_label.detach().cpu()).flatten()
train_oov_flag_tensor = torch.tensor(train_oov_flag).flatten()
val_oov_flag_tensor = torch.tensor(val_oov_flag).flatten()
test_oov_flag_tensor = torch.tensor(test_oov_flag).flatten()

train_oov_correct_counter, train_oov_wrong_counter = pencentage_oov_pred_correct(train_pred_oov_flag, train_oov_flag_tensor)
val_oov_correct_counter, val_oov_wrong_counter = pencentage_oov_pred_correct(val_pred_oov_flag, val_oov_flag_tensor)
test_oov_correct_counter, test_oov_wrong_counter = pencentage_oov_pred_correct(test_pred_oov_flag, test_oov_flag_tensor)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
def print_percentage_pred_oov(title, oov_correct_counter, oov_wrong_counter):
    print(f"{title}")
    print(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}")
    print(f"Correct prediction          : {oov_correct_counter}")
    print(f"Wrong prediction            : {oov_wrong_counter}")
    print(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n")
    
    with open(f"{root_path}/oov_summary.txt", "a") as f:
        f.write(f"{title}\n")
        f.write(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}\n")
        f.write(f"Correct prediction          : {oov_correct_counter}\n")
        f.write(f"Wrong prediction            : {oov_wrong_counter}\n")
        f.write(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n\n")

# %%
print_percentage_pred_oov("Training", train_oov_correct_counter, train_oov_wrong_counter)
print_percentage_pred_oov("Validation", val_oov_correct_counter, val_oov_wrong_counter)
print_percentage_pred_oov("Test", test_oov_correct_counter, test_oov_wrong_counter)
# Out:
# Training
# Number OOV token            : 11934
# Correct prediction          : 11436
# Wrong prediction            : 498
# Percentage correct oov pred : 95.82704876822524
#
# Validation
# Number OOV token            : 3261
# Correct prediction          : 2954
# Wrong prediction            : 307
# Percentage correct oov pred : 90.58570990493713
#
# Test
# Number OOV token            : 1367
# Correct prediction          : 1253
# Wrong prediction            : 114
# Percentage correct oov pred : 91.6605705925384

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(train_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(val_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(test_oov_flag, cmap=plt.cm.binary_r);
