# %% [markdown]
# # Import modules

# %%
import csv
import os
import pickle
import pytz
import torch
import timeit
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from copy import deepcopy
from datetime import datetime
from einops import rearrange
from itertools import chain
from time import time
from torch import nn, optim
from torchmetrics.classification import MulticlassAccuracy, MulticlassF1Score, MulticlassConfusionMatrix
from torch.optim import lr_scheduler
from tqdm.notebook import tqdm
from torch.utils.data import TensorDataset, DataLoader
from polyglot.mapping import Embedding, CaseExpander, DigitExpander

# %% [markdown]
# # Hyperparameters

# %%
class Hyperparams:
     def __init__(
        self,
        context_size=55,
        fold=3,
        max_seq_len=82,
        input_size=64,
        batch_size=32,
        num_hidden_layer=1,
        hidden_size=128,
        dropout=0,
        bias=True,
        output_size=24,
        shuffle=True,
        lr=0.005,
        batch_first=False,
        bidirectional=True,
        init_wb_with_kaiming_normal=True,
        n_epoch=50,
        patience=50,
        device="cuda" if torch.cuda.is_available() else "cpu"
    ):
        self.context_size = context_size
        self.fold = fold
        self.input_size = input_size
        self.max_seq_len = max_seq_len
        self.batch_size = batch_size
        self.num_hidden_layer = num_hidden_layer
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.output_size = output_size
        self.shuffle = shuffle
        self.lr = lr
        self.batch_first = batch_first
        self.bidirectional = bidirectional
        self.init_wb_with_kaiming_normal = init_wb_with_kaiming_normal
        self.n_epoch = n_epoch
        self.patience = patience
        self.device = device

hyperparams = Hyperparams()

# %% [markdown]
# # Dataset

# %%
id_pos_tag = pd.read_csv("../../../datasets/raw/Indonesian_Manually_Tagged_Corpus.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False) 
train = pd.read_csv(f"../../../datasets/raw/cv/train/train.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
val = pd.read_csv(f"../../../datasets/raw/cv/val/val.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
test = pd.read_csv(f"../../../datasets/raw/cv/test/test.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)

# %% [markdown]
# # Pre-trained Word Embedding

# %%
embeddings = Embedding.load("../../../word_embeddings/polyglot/idn_embeddings.tar.bz2")
embeddings.apply_expansion(DigitExpander)
embeddings.apply_expansion(CaseExpander)

oov_embeddings = pickle.load(open(f"../../../logs/comick/{hyperparams.context_size}_contexts/10-11-2022_16-08-07/oov_embedding_dict.pkl", "rb"))

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Add OOV Flag

# %%
def add_oov_flag(tokens, embeddings):
    oov_flags = []
    
    for token in tqdm(tokens):
        try:
            if token not in embeddings:
                oov_flags.append(True)
            else:
                oov_flags.append(False)
        except:
            oov_flags.append(False)
        
    return pd.DataFrame(oov_flags, columns=["is_oov"])

id_pos_tag_oov_flags = add_oov_flag(id_pos_tag["token"].values, embeddings)
train_oov_flags = add_oov_flag(train["token"].values, embeddings)
val_oov_flags = add_oov_flag(val["token"].values, embeddings)
test_oov_flags = add_oov_flag(test["token"].values, embeddings)
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/192215 [00:00<?, ?it/s]
#   0%|          | 0/21143 [00:00<?, ?it/s]
#   0%|          | 0/53294 [00:00<?, ?it/s]

# %% [markdown]
# ## Concate OOV Flag

# %%
id_pos_tag_df = pd.concat([id_pos_tag, id_pos_tag_oov_flags], axis=1)
train_df = pd.concat([train, train_oov_flags], axis=1)
val_df = pd.concat([val, val_oov_flags], axis=1)
test_df = pd.concat([test, test_oov_flags], axis=1)

# %% [markdown]
# ## Lowercase OOV Token

# %%
id_pos_tag_df['token'] = np.where(id_pos_tag_df['is_oov'] == True, id_pos_tag_df['token'].str.lower(), id_pos_tag_df['token'])
train_df['token'] = np.where(train_df['is_oov'] == True, train_df['token'].str.lower(), train_df['token'])
val_df['token'] = np.where(val_df['is_oov'] == True, val_df['token'].str.lower(), val_df['token'])
test_df['token'] = np.where(test_df['is_oov'] == True, test_df['token'].str.lower(), test_df['token'])

# %% [markdown]
# ## Embedding Dict, Index to Token and Token to Index

# %%
tokens = list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None))

def embedding_dict(tokens, embeddings, oov_embeddings):
    embedding = {}
    
    for token in tokens:
        if token[0] is not np.nan:
            if token[2] == False or token[0] in embeddings:
                embedding[token[0]] = embeddings[token[0]]
            else:
                embedding[token[0]] = oov_embeddings[token[0].lower()]

    return embedding

embedding_dict = embedding_dict(tokens, embeddings, oov_embeddings)
embedding_dict["<PAD>"] = embeddings["<PAD>"]
word_embeddings = nn.Embedding.from_pretrained(torch.FloatTensor(np.array(list(embedding_dict.values()))), padding_idx=list(embedding_dict.keys()).index("<PAD>"), freeze=True)

idx_to_token = {idx: token for idx, token in enumerate(list(embedding_dict.keys()))}
token_to_idx = {token: idx for idx, token in enumerate(list(embedding_dict.keys()))}

# %% [markdown]
# ## Token to Sentence

# %%
def make_sentence(tokens, max_length_sentence=hyperparams.max_seq_len):
    sentence = []
    sentences = []

    for token in tqdm(tokens):
        if token[0] is not np.nan:
            sentence.append(token)
        else:
            sentences.append(sentence[:max_length_sentence])
            sentence = []

    return sentences

all_sentence = make_sentence(list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
train_sentences = make_sentence(list(train_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
val_sentences = make_sentence(list(test_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
test_sentences = make_sentence(list(val_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/192215 [00:00<?, ?it/s]
#   0%|          | 0/53294 [00:00<?, ?it/s]
#   0%|          | 0/21143 [00:00<?, ?it/s]

# %% [markdown]
# ## Word Token, Padding, and Word token to Index

# %%
def tokenize_docs(docs, idx_token):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token[idx_token])
        sentences.append(new_sentence)
        new_sentence = []

    return sentences

def padding(docs, max_seq_len=hyperparams.max_seq_len, mode="post", val_pad="<PAD>"):
    docs = deepcopy(docs)
    doc_with_pad = []
    docs_with_pad = []

    for doc in tqdm(docs):
        if mode == "pre":
            for _ in range(max_seq_len - len(doc)):
                doc.insert(0, val_pad)
        elif mode == "post":
            for _ in range(max_seq_len - len(doc)):
                doc.append(val_pad)
        else:
            return f"Mode {mode} is not available, use instead 'pre' or 'post'."
        
        docs_with_pad.append(doc)
        
    return np.array(docs_with_pad)

def sent_to_idx(docs, token_to_idx):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token_to_idx[token])
        sentences.append(new_sentence)
        new_sentence = []

    return np.array(sentences)

def convert_feature_to_idx(docs, idx_token, token_to_idx, max_seq_len):
    sentences = tokenize_docs(docs, idx_token)
    sentences_with_pad = padding(sentences, max_seq_len=max_seq_len, mode="post", val_pad="<PAD>")
    sentences_to_idx = sent_to_idx(sentences_with_pad, token_to_idx)
    
    return sentences_to_idx

train_sentence_idxs = convert_feature_to_idx(train_sentences, 0, token_to_idx, hyperparams.max_seq_len)
val_sentence_idxs = convert_feature_to_idx(val_sentences, 0, token_to_idx, hyperparams.max_seq_len)
test_sentence_idxs = convert_feature_to_idx(test_sentences, 0, token_to_idx, hyperparams.max_seq_len)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]

# %% [markdown]
# ## Encode Class

# %%
classes = sorted(np.delete(id_pos_tag_df["tag"].unique(), 3))
idx_to_label = {idx: label for idx, label in enumerate(classes + ["<PAD>"])}
label_to_idx = {label: idx for idx, label in enumerate(classes + ["<PAD>"])}

def encode_class(docs, label_to_idx, seq_len=hyperparams.max_seq_len):
    class_idxs = []
    classes = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            class_idxs.append(label_to_idx[token[1]])
            
        for _ in range(seq_len - len(sentence)):
            class_idxs.append(label_to_idx["<PAD>"])
                
        classes.append(class_idxs)
        class_idxs = []

    return np.array(classes)
        
train_class_idxs = encode_class(train_sentences, label_to_idx)
val_class_idxs = encode_class(val_sentences, label_to_idx)
test_class_idxs = encode_class(test_sentences, label_to_idx)

print(f"Training shape   : {train_sentence_idxs.shape, train_class_idxs.shape}")
print(f"validation shape : {val_class_idxs.shape, val_class_idxs.shape}")
print(f"Test shape       : {test_sentence_idxs.shape, test_class_idxs.shape}")
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# Training shape   : ((7222, 82), (7222, 82))
# validation shape : ((2006, 82), (2006, 82))
# Test shape       : ((802, 82), (802, 82))

# %% [markdown]
# ## Note
#
# - Number of sentences = 10030
# - Train : 72% (7222)
# - Val   : 8% (802)
# - Test  : 20% (2006)

# %% [markdown]
# # Build Model

# %% [markdown]
# ## Feature and Actual Class

# %%
train_feature = torch.LongTensor(train_sentence_idxs)
val_feature = torch.LongTensor(val_sentence_idxs)
test_feature = torch.LongTensor(test_sentence_idxs)

train_class = torch.LongTensor(train_class_idxs)
val_class = torch.LongTensor(val_class_idxs)
test_class = torch.LongTensor(test_class_idxs)

# %%
train_feature.shape, val_feature.shape, test_feature.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %%
train_class.shape, val_class.shape, test_class.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %% [markdown]
# ## Tensor Dataset

# %%
train_dataset = TensorDataset(train_feature, train_class)
val_dataset = TensorDataset(val_feature, val_class)
test_dataset = TensorDataset(test_feature, test_class)

# %% [markdown]
# ## Dataloader

# %%
train_dataloader = DataLoader(train_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
val_dataloader = DataLoader(val_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
test_dataloader = DataLoader(test_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)

# %% [markdown]
# ## Model

# %%
class POSTagger(nn.Module):
    def __init__(
        self,
        input_size=hyperparams.input_size,
        hidden_size=hyperparams.hidden_size,
        dropout=hyperparams.dropout,
        bias=hyperparams.bias,
        num_layers=hyperparams.num_hidden_layer,
        output_size=hyperparams.output_size,
        batch_first=hyperparams.batch_first,
        bidirectional=hyperparams.bidirectional,
        init_wb_with_kaiming_normal=hyperparams.init_wb_with_kaiming_normal
    ):
        super(POSTagger, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.num_layers = num_layers
        self.output_size = output_size
        self.batch_first = batch_first
        self.bidirectional = bidirectional
                
        self.feature = nn.LSTM(
            input_size = self.input_size,
            hidden_size = self.hidden_size,
            bias = self.bias,
            dropout = self.dropout,
            num_layers = self.num_layers,
            batch_first = self.batch_first,
            bidirectional = self.bidirectional
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(in_features=2 * self.hidden_size if hyperparams.bidirectional else self.hidden_size, out_features=self.output_size, bias=self.bias),
            nn.Softmax(dim=-1)
        )
        
        if init_wb_with_kaiming_normal:
            self.init_wb()

    def init_wb(self):
        for module in self.modules():
            if isinstance(module, (nn.Linear, nn.LSTM)):
                for name, param in module.named_parameters():
                    if "weight" in name:
                        nn.init.kaiming_normal_(param)
                    else:
                        nn.init.kaiming_normal_(param.reshape(1, -1))
        
    def forward(self, feature, hidden=None):
        output, (hidden, memory) = self.feature(feature, None)
        prob = self.classifier(output)

        return prob
    
model = POSTagger().to(hyperparams.device)
model
# Out:
# POSTagger(
#   (feature): LSTM(64, 128, bidirectional=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=24, bias=True)
#     (1): Softmax(dim=-1)
#   )
# )

# %% [markdown]
# ## Optimizer, Criterion, and Metric

# %%
optimizer = optim.Adam(model.parameters(), lr=hyperparams.lr)
criterion = nn.CrossEntropyLoss().to(hyperparams.device)
train_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", verbose=True, factor=0.5)

# %%
sum(param.numel() for param in model.parameters() if param.requires_grad)
# Out:
# 204824

# %% [markdown]
# ## Training Step

# %%
def training_step(dataloader, model, optimizer, criterion, metric, scheduler=None):
    model.train()
    
    batch_losses = []
    batch_metric_scores = []
    
    for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
        # Forward Propagation
        feature = rearrange(feature, "n s -> s n")
        actual_label = rearrange(actual_label, "n s -> s n")
        embedding = word_embeddings(feature)
        
        prob = model(
            embedding.to(hyperparams.device),
            actual_label.to(hyperparams.device)
        )
        
        prob = prob.reshape(-1, prob.shape[-1])
        actual_label = actual_label.reshape(-1)

        loss = criterion(prob, actual_label.to(hyperparams.device))
        metric_score = metric(prob, actual_label.to(hyperparams.device))
        metric_score = metric.compute()
                
        if scheduler is not None:
            scheduler.step(loss)
        
        batch_losses.append(loss.item())
        batch_metric_scores.append(metric_score)
        
        if len(dataloader) < 10:
            if batch % 1 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
        else:
            if batch % 15 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            
        # Backward Propagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Validation Step

# %%
def validation_step(dataloader, model, criterion, metric):
    model.eval()
    
    batch_losses = []
    batch_metric_scores = []
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob, actual_label.to(hyperparams.device))
            metric_score = metric.compute()

            batch_losses.append(loss.item())
            batch_metric_scores.append(metric_score)
            
            if len(dataloader) < 10 and (batch % 1 == 0 or batch == len(dataloader)):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            else:
                if batch % 15 == 0 or batch == len(dataloader):
                    batch_name = "Batch-" + str(batch)
                    print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                    with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                        f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Looping Step

# %%
now = datetime.now(pytz.timezone("Asia/Ujung_Pandang"))
path_name = now.strftime("%m-%d-%Y_%H-%M-%S")
root_path = f"../../../logs/classifier/{hyperparams.context_size}_contexts/fold_0{hyperparams.fold}/{path_name}"
os.makedirs(root_path)

def looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric, n_epoch=hyperparams.n_epoch, patience=hyperparams.patience, monitor="loss"):    
    start_time = time()
    
    epoch_training_losses = []
    epoch_training_metric_scores = []
    epoch_val_losses = []
    epoch_val_metric_scores = []
    patience_counter = 0
    
    # Hyperparameters
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write(f"HYPERPARAMETERS\n")
        f.write(f"{'-' * 80}\n")
        for name, value in vars(hyperparams).items():
            f.write(f"{name}: {value}\n")
        
        f.write("\n\nTRAINING PROGRESS\n")
        f.write(f"{'-' * 80}\n")
    
    # Training Progress
    for epoch in range(1, n_epoch + 1):
        print(f"EPOCH-{epoch}")
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"EPOCH-{epoch}\n")
            f.write(f"Training Step\n")
            
        # Training Step
        print("Training Step")
        batch_training_losses, batch_training_metric_scores = training_step(train_dataloader, model, optimizer, criterion, train_metric, scheduler=None)
        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))

        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))
        epoch_training_losses.append(epoch_training_loss.item())

        epoch_training_metric_score = torch.mean(torch.FloatTensor(batch_training_metric_scores))
        epoch_training_metric_scores.append(epoch_training_metric_score.item())
        
        # Validation Step
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"\nValidation Step\n")
            
        print("\nValidation Step")
        batch_val_losses, batch_val_metric_scores = validation_step(val_dataloader, model, criterion, val_metric)
        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))

        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))
        epoch_val_losses.append(epoch_val_loss.item())

        epoch_val_metric_score = torch.mean(torch.FloatTensor(batch_val_metric_scores))
        epoch_val_metric_scores.append(epoch_val_metric_score.item())
        
        with open(f"{root_path}/training_history.txt", "a") as f:
            if monitor == "loss":
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_losses[-1] < epoch_training_losses[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
            else:
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_metric_scores[-1] > epoch_training_metric_scores[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗\n")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
                    
            print("=" * 80, end="\n\n")
            
            f.write(f"{'=' * 80}\n\n")
            
            if patience_counter == patience:
                print(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                
                f.write(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                break
        
        train_metric.reset()
        val_metric.reset()
        
    finish_time = time()
    
    # Training plot 
    fig, (ax_loss, ax_metric_score) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    fig.suptitle(f"Training with context size = {hyperparams.context_size}")

    ax_loss.set_title("Loss")
    ax_loss.set_xlabel("Epoch")
    ax_loss.set_ylabel("Score")
    ax_loss.plot(epoch_training_losses, "green", label="Training")
    ax_loss.plot(epoch_val_losses, "orange", label="Validation")
    ax_loss.legend()
    ax_loss.grid()

    ax_metric_score.set_title("F1 Score")
    ax_metric_score.set_xlabel("Epoch")
    ax_metric_score.set_ylabel("Score")
    ax_metric_score.plot(epoch_training_metric_scores, "green", label="Training")
    ax_metric_score.plot(epoch_val_metric_scores, "orange", label="Validation")
    ax_metric_score.legend()
    ax_metric_score.grid()

    plt.savefig(f"{root_path}/training_plot.jpg", dpi=200)                        
    
    print("TRAINING SUMMARY")
    name_best_training_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_training_metric = f"Best {str(train_metric).split('(')[0]} validation".ljust(34)
    name_best_validation_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_validation_metric = f"Best {str(val_metric).split('(')[0]} validation".ljust(34)
    name_training_time = f"Training duration".ljust(34)
    name_training_date = f"Training date".ljust(34)
    
    print(f"{name_best_training_loss}: {best_training_loss:.4f}")
    print(f"{name_best_validation_loss}: {best_val_loss:.4f}")
    print(f"{name_best_training_metric}: {best_training_metric:.4f}")
    print(f"{name_best_validation_metric}: {best_val_metric:.4f}")
    print(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.")
    print(f"{name_training_date}: {now}")
    
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write("\nTRAINING SUMMARY\n")
        f.write(f"{'-' * 80}\n")
        f.write(f"{name_best_training_loss}: {best_training_loss:.4f}\n")
        f.write(f"{name_best_validation_loss}: {best_val_loss:.4f}\n")
        f.write(f"{name_best_training_metric}: {best_training_metric:.4f}\n")
        f.write(f"{name_best_validation_metric}: {best_val_metric:.4f}\n")
        f.write(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.\n")
        f.write(f"{name_training_date}: {now}\n")
    
    # Save epoch losses, epoch metric scores, model, state dict, and oov embedding dict
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_training_losses
    }).to_csv(f"{root_path}/training_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_training_metric_scores
    }).to_csv(f"{root_path}/training_metric_scores.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_val_losses
    }).to_csv(f"{root_path}/val_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_val_metric_scores
    }).to_csv(f"{root_path}/val_metric_scores.csv", index=False)    
    
    filename_model_params = f"{root_path}/model_params.pth"
    torch.save(best_state_dict, filename_model_params)
    
    return epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores

epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores = looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric)
# Out:
# EPOCH-1
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.4872 | MulticlassF1Score=0.1328
# Batch-30 : CrossEntropyLoss=2.4810 | MulticlassF1Score=0.1941
# Batch-45 : CrossEntropyLoss=2.4675 | MulticlassF1Score=0.2398
# Batch-60 : CrossEntropyLoss=2.4504 | MulticlassF1Score=0.2725
# Batch-75 : CrossEntropyLoss=2.4344 | MulticlassF1Score=0.2929
# Batch-90 : CrossEntropyLoss=2.4190 | MulticlassF1Score=0.3180
# Batch-105: CrossEntropyLoss=2.4115 | MulticlassF1Score=0.3411
# Batch-120: CrossEntropyLoss=2.4061 | MulticlassF1Score=0.3598
# Batch-135: CrossEntropyLoss=2.4005 | MulticlassF1Score=0.3736
# Batch-150: CrossEntropyLoss=2.3808 | MulticlassF1Score=0.3899
# Batch-165: CrossEntropyLoss=2.3840 | MulticlassF1Score=0.4073
# Batch-180: CrossEntropyLoss=2.3464 | MulticlassF1Score=0.4251
# Batch-195: CrossEntropyLoss=2.3612 | MulticlassF1Score=0.4441
# Batch-210: CrossEntropyLoss=2.3432 | MulticlassF1Score=0.4596
# Batch-225: CrossEntropyLoss=2.3520 | MulticlassF1Score=0.4737
# Batch-226: CrossEntropyLoss=2.3525 | MulticlassF1Score=0.4745
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3443 | MulticlassF1Score=0.6673
# Batch-30 : CrossEntropyLoss=2.3273 | MulticlassF1Score=0.6720
# Batch-45 : CrossEntropyLoss=2.3507 | MulticlassF1Score=0.6766
# Batch-60 : CrossEntropyLoss=2.3410 | MulticlassF1Score=0.6749
# Batch-63 : CrossEntropyLoss=2.3464 | MulticlassF1Score=0.6764
#
# Training   : Mean CrossEntropyLoss = 2.4216 | Mean MulticlassF1Score = 0.3297
# Validation : Mean CrossEntropyLoss = 2.3489 | Mean MulticlassF1Score = 0.6730
# ================================================================================
#
# EPOCH-2
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3638 | MulticlassF1Score=0.6839
# Batch-30 : CrossEntropyLoss=2.3499 | MulticlassF1Score=0.6792
# Batch-45 : CrossEntropyLoss=2.3491 | MulticlassF1Score=0.6748
# Batch-60 : CrossEntropyLoss=2.3787 | MulticlassF1Score=0.6758
# Batch-75 : CrossEntropyLoss=2.3303 | MulticlassF1Score=0.6793
# Batch-90 : CrossEntropyLoss=2.3476 | MulticlassF1Score=0.6782
# Batch-105: CrossEntropyLoss=2.3515 | MulticlassF1Score=0.6786
# Batch-120: CrossEntropyLoss=2.3411 | MulticlassF1Score=0.6799
# Batch-135: CrossEntropyLoss=2.3219 | MulticlassF1Score=0.6831
# Batch-150: CrossEntropyLoss=2.3387 | MulticlassF1Score=0.6871
# Batch-165: CrossEntropyLoss=2.3458 | MulticlassF1Score=0.6895
# Batch-180: CrossEntropyLoss=2.3481 | MulticlassF1Score=0.6924
# Batch-195: CrossEntropyLoss=2.3519 | MulticlassF1Score=0.6939
# Batch-210: CrossEntropyLoss=2.3301 | MulticlassF1Score=0.6958
# Batch-225: CrossEntropyLoss=2.3564 | MulticlassF1Score=0.6971
# Batch-226: CrossEntropyLoss=2.3442 | MulticlassF1Score=0.6971
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3142 | MulticlassF1Score=0.7296
# Batch-30 : CrossEntropyLoss=2.3326 | MulticlassF1Score=0.7324
# Batch-45 : CrossEntropyLoss=2.3454 | MulticlassF1Score=0.7303
# Batch-60 : CrossEntropyLoss=2.3370 | MulticlassF1Score=0.7254
# Batch-63 : CrossEntropyLoss=2.3349 | MulticlassF1Score=0.7252
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3424 | Mean MulticlassF1Score = 0.6841
# Validation : Mean CrossEntropyLoss = 2.3335 | Mean MulticlassF1Score = 0.7303
# ================================================================================
#
# EPOCH-3
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3443 | MulticlassF1Score=0.7253
# Batch-30 : CrossEntropyLoss=2.3290 | MulticlassF1Score=0.7302
# Batch-45 : CrossEntropyLoss=2.3274 | MulticlassF1Score=0.7284
# Batch-60 : CrossEntropyLoss=2.3122 | MulticlassF1Score=0.7286
# Batch-75 : CrossEntropyLoss=2.3376 | MulticlassF1Score=0.7271
# Batch-90 : CrossEntropyLoss=2.3376 | MulticlassF1Score=0.7260
# Batch-105: CrossEntropyLoss=2.3360 | MulticlassF1Score=0.7263
# Batch-120: CrossEntropyLoss=2.3231 | MulticlassF1Score=0.7325
# Batch-135: CrossEntropyLoss=2.3117 | MulticlassF1Score=0.7390
# Batch-150: CrossEntropyLoss=2.3028 | MulticlassF1Score=0.7445
# Batch-165: CrossEntropyLoss=2.3126 | MulticlassF1Score=0.7490
# Batch-180: CrossEntropyLoss=2.3124 | MulticlassF1Score=0.7529
# Batch-195: CrossEntropyLoss=2.3291 | MulticlassF1Score=0.7558
# Batch-210: CrossEntropyLoss=2.3080 | MulticlassF1Score=0.7584
# Batch-225: CrossEntropyLoss=2.3033 | MulticlassF1Score=0.7611
# Batch-226: CrossEntropyLoss=2.3209 | MulticlassF1Score=0.7612
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3079 | MulticlassF1Score=0.7933
# Batch-30 : CrossEntropyLoss=2.3059 | MulticlassF1Score=0.7959
# Batch-45 : CrossEntropyLoss=2.3048 | MulticlassF1Score=0.7927
# Batch-60 : CrossEntropyLoss=2.3109 | MulticlassF1Score=0.7936
# Batch-63 : CrossEntropyLoss=2.3045 | MulticlassF1Score=0.7931
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3225 | Mean MulticlassF1Score = 0.7381
# Validation : Mean CrossEntropyLoss = 2.3120 | Mean MulticlassF1Score = 0.7935
# ================================================================================
#
# EPOCH-4
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3183 | MulticlassF1Score=0.7899
# Batch-30 : CrossEntropyLoss=2.3158 | MulticlassF1Score=0.7920
# Batch-45 : CrossEntropyLoss=2.3005 | MulticlassF1Score=0.7956
# Batch-60 : CrossEntropyLoss=2.3097 | MulticlassF1Score=0.7961
# Batch-75 : CrossEntropyLoss=2.3134 | MulticlassF1Score=0.7968
# Batch-90 : CrossEntropyLoss=2.3024 | MulticlassF1Score=0.7977
# Batch-105: CrossEntropyLoss=2.3078 | MulticlassF1Score=0.7972
# Batch-120: CrossEntropyLoss=2.3149 | MulticlassF1Score=0.7968
# Batch-135: CrossEntropyLoss=2.3017 | MulticlassF1Score=0.7967
# Batch-150: CrossEntropyLoss=2.3027 | MulticlassF1Score=0.7976
# Batch-165: CrossEntropyLoss=2.3123 | MulticlassF1Score=0.7990
# Batch-180: CrossEntropyLoss=2.3040 | MulticlassF1Score=0.7992
# Batch-195: CrossEntropyLoss=2.3030 | MulticlassF1Score=0.8000
# Batch-210: CrossEntropyLoss=2.3045 | MulticlassF1Score=0.8004
# Batch-225: CrossEntropyLoss=2.3098 | MulticlassF1Score=0.8006
# Batch-226: CrossEntropyLoss=2.3189 | MulticlassF1Score=0.8006
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3132 | MulticlassF1Score=0.8092
# Batch-30 : CrossEntropyLoss=2.3019 | MulticlassF1Score=0.8058
# Batch-45 : CrossEntropyLoss=2.3003 | MulticlassF1Score=0.8069
# Batch-60 : CrossEntropyLoss=2.3002 | MulticlassF1Score=0.8078
# Batch-63 : CrossEntropyLoss=2.3101 | MulticlassF1Score=0.8067
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3098 | Mean MulticlassF1Score = 0.7966
# Validation : Mean CrossEntropyLoss = 2.3077 | Mean MulticlassF1Score = 0.8072
# ================================================================================
#
# EPOCH-5
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3211 | MulticlassF1Score=0.8136
# Batch-30 : CrossEntropyLoss=2.3128 | MulticlassF1Score=0.8092
# Batch-45 : CrossEntropyLoss=2.2943 | MulticlassF1Score=0.8092
# Batch-60 : CrossEntropyLoss=2.3007 | MulticlassF1Score=0.8101
# Batch-75 : CrossEntropyLoss=2.3051 | MulticlassF1Score=0.8152
# Batch-90 : CrossEntropyLoss=2.3083 | MulticlassF1Score=0.8179
# Batch-105: CrossEntropyLoss=2.2968 | MulticlassF1Score=0.8197
# Batch-120: CrossEntropyLoss=2.3058 | MulticlassF1Score=0.8210
# Batch-135: CrossEntropyLoss=2.2985 | MulticlassF1Score=0.8216
# Batch-150: CrossEntropyLoss=2.2990 | MulticlassF1Score=0.8221
# Batch-165: CrossEntropyLoss=2.2923 | MulticlassF1Score=0.8222
# Batch-180: CrossEntropyLoss=2.3006 | MulticlassF1Score=0.8228
# Batch-195: CrossEntropyLoss=2.3007 | MulticlassF1Score=0.8234
# Batch-210: CrossEntropyLoss=2.3017 | MulticlassF1Score=0.8238
# Batch-225: CrossEntropyLoss=2.2987 | MulticlassF1Score=0.8241
# Batch-226: CrossEntropyLoss=2.3006 | MulticlassF1Score=0.8241
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3030 | MulticlassF1Score=0.8264
# Batch-30 : CrossEntropyLoss=2.3060 | MulticlassF1Score=0.8296
# Batch-45 : CrossEntropyLoss=2.2960 | MulticlassF1Score=0.8272
# Batch-60 : CrossEntropyLoss=2.3129 | MulticlassF1Score=0.8261
# Batch-63 : CrossEntropyLoss=2.2973 | MulticlassF1Score=0.8263
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3024 | Mean MulticlassF1Score = 0.8184
# Validation : Mean CrossEntropyLoss = 2.3016 | Mean MulticlassF1Score = 0.8269
# ================================================================================
#
# EPOCH-6
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2986 | MulticlassF1Score=0.8294
# Batch-30 : CrossEntropyLoss=2.2930 | MulticlassF1Score=0.8329
# Batch-45 : CrossEntropyLoss=2.2973 | MulticlassF1Score=0.8285
# Batch-60 : CrossEntropyLoss=2.3058 | MulticlassF1Score=0.8277
# Batch-75 : CrossEntropyLoss=2.2991 | MulticlassF1Score=0.8289
# Batch-90 : CrossEntropyLoss=2.2913 | MulticlassF1Score=0.8301
# Batch-105: CrossEntropyLoss=2.3002 | MulticlassF1Score=0.8309
# Batch-120: CrossEntropyLoss=2.3023 | MulticlassF1Score=0.8311
# Batch-135: CrossEntropyLoss=2.3002 | MulticlassF1Score=0.8309
# Batch-150: CrossEntropyLoss=2.3031 | MulticlassF1Score=0.8311
# Batch-165: CrossEntropyLoss=2.2926 | MulticlassF1Score=0.8319
# Batch-180: CrossEntropyLoss=2.3040 | MulticlassF1Score=0.8318
# Batch-195: CrossEntropyLoss=2.3120 | MulticlassF1Score=0.8312
# Batch-210: CrossEntropyLoss=2.2953 | MulticlassF1Score=0.8314
# Batch-225: CrossEntropyLoss=2.3029 | MulticlassF1Score=0.8315
# Batch-226: CrossEntropyLoss=2.3038 | MulticlassF1Score=0.8315
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2985 | MulticlassF1Score=0.8315
# Batch-30 : CrossEntropyLoss=2.2915 | MulticlassF1Score=0.8297
# Batch-45 : CrossEntropyLoss=2.3053 | MulticlassF1Score=0.8293
# Batch-60 : CrossEntropyLoss=2.3030 | MulticlassF1Score=0.8290
# Batch-63 : CrossEntropyLoss=2.3106 | MulticlassF1Score=0.8289
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3000 | Mean MulticlassF1Score = 0.8306
# Validation : Mean CrossEntropyLoss = 2.3007 | Mean MulticlassF1Score = 0.8308
# ================================================================================
#
# EPOCH-7
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2934 | MulticlassF1Score=0.8349
# Batch-30 : CrossEntropyLoss=2.2923 | MulticlassF1Score=0.8374
# Batch-45 : CrossEntropyLoss=2.3005 | MulticlassF1Score=0.8341
# Batch-60 : CrossEntropyLoss=2.3046 | MulticlassF1Score=0.8343
# Batch-75 : CrossEntropyLoss=2.3013 | MulticlassF1Score=0.8336
# Batch-90 : CrossEntropyLoss=2.2943 | MulticlassF1Score=0.8342
# Batch-105: CrossEntropyLoss=2.2997 | MulticlassF1Score=0.8329
# Batch-120: CrossEntropyLoss=2.2956 | MulticlassF1Score=0.8336
# Batch-135: CrossEntropyLoss=2.2966 | MulticlassF1Score=0.8340
# Batch-150: CrossEntropyLoss=2.3033 | MulticlassF1Score=0.8344
# Batch-165: CrossEntropyLoss=2.2911 | MulticlassF1Score=0.8352
# Batch-180: CrossEntropyLoss=2.2910 | MulticlassF1Score=0.8359
# Batch-195: CrossEntropyLoss=2.3090 | MulticlassF1Score=0.8361
# Batch-210: CrossEntropyLoss=2.3023 | MulticlassF1Score=0.8368
# Batch-225: CrossEntropyLoss=2.2849 | MulticlassF1Score=0.8386
# Batch-226: CrossEntropyLoss=2.2856 | MulticlassF1Score=0.8388
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2968 | MulticlassF1Score=0.8574
# Batch-30 : CrossEntropyLoss=2.2942 | MulticlassF1Score=0.8589
# Batch-45 : CrossEntropyLoss=2.2926 | MulticlassF1Score=0.8595
# Batch-60 : CrossEntropyLoss=2.2892 | MulticlassF1Score=0.8596
# Batch-63 : CrossEntropyLoss=2.2911 | MulticlassF1Score=0.8600
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2977 | Mean MulticlassF1Score = 0.8345
# Validation : Mean CrossEntropyLoss = 2.2914 | Mean MulticlassF1Score = 0.8600
# ================================================================================
#
# EPOCH-8
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2878 | MulticlassF1Score=0.8681
# Batch-30 : CrossEntropyLoss=2.2826 | MulticlassF1Score=0.8686
# Batch-45 : CrossEntropyLoss=2.2897 | MulticlassF1Score=0.8704
# Batch-60 : CrossEntropyLoss=2.2840 | MulticlassF1Score=0.8693
# Batch-75 : CrossEntropyLoss=2.2912 | MulticlassF1Score=0.8693
# Batch-90 : CrossEntropyLoss=2.2897 | MulticlassF1Score=0.8693
# Batch-105: CrossEntropyLoss=2.2862 | MulticlassF1Score=0.8696
# Batch-120: CrossEntropyLoss=2.2884 | MulticlassF1Score=0.8695
# Batch-135: CrossEntropyLoss=2.2860 | MulticlassF1Score=0.8686
# Batch-150: CrossEntropyLoss=2.2838 | MulticlassF1Score=0.8690
# Batch-165: CrossEntropyLoss=2.2852 | MulticlassF1Score=0.8690
# Batch-180: CrossEntropyLoss=2.2861 | MulticlassF1Score=0.8688
# Batch-195: CrossEntropyLoss=2.2853 | MulticlassF1Score=0.8682
# Batch-210: CrossEntropyLoss=2.2865 | MulticlassF1Score=0.8682
# Batch-225: CrossEntropyLoss=2.3032 | MulticlassF1Score=0.8680
# Batch-226: CrossEntropyLoss=2.2827 | MulticlassF1Score=0.8681
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2941 | MulticlassF1Score=0.8699
# Batch-30 : CrossEntropyLoss=2.2921 | MulticlassF1Score=0.8684
# Batch-45 : CrossEntropyLoss=2.2851 | MulticlassF1Score=0.8665
# Batch-60 : CrossEntropyLoss=2.2891 | MulticlassF1Score=0.8657
# Batch-63 : CrossEntropyLoss=2.2800 | MulticlassF1Score=0.8658
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2888 | Mean MulticlassF1Score = 0.8688
# Validation : Mean CrossEntropyLoss = 2.2893 | Mean MulticlassF1Score = 0.8683
# ================================================================================
#
# EPOCH-9
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2915 | MulticlassF1Score=0.8739
# Batch-30 : CrossEntropyLoss=2.2889 | MulticlassF1Score=0.8715
# Batch-45 : CrossEntropyLoss=2.2910 | MulticlassF1Score=0.8720
# Batch-60 : CrossEntropyLoss=2.2843 | MulticlassF1Score=0.8706
# Batch-75 : CrossEntropyLoss=2.2868 | MulticlassF1Score=0.8705
# Batch-90 : CrossEntropyLoss=2.2831 | MulticlassF1Score=0.8717
# Batch-105: CrossEntropyLoss=2.2858 | MulticlassF1Score=0.8720
# Batch-120: CrossEntropyLoss=2.2820 | MulticlassF1Score=0.8721
# Batch-135: CrossEntropyLoss=2.2936 | MulticlassF1Score=0.8720
# Batch-150: CrossEntropyLoss=2.2853 | MulticlassF1Score=0.8719
# Batch-165: CrossEntropyLoss=2.2807 | MulticlassF1Score=0.8734
# Batch-180: CrossEntropyLoss=2.2837 | MulticlassF1Score=0.8745
# Batch-195: CrossEntropyLoss=2.2810 | MulticlassF1Score=0.8754
# Batch-210: CrossEntropyLoss=2.2793 | MulticlassF1Score=0.8762
# Batch-225: CrossEntropyLoss=2.2768 | MulticlassF1Score=0.8777
# Batch-226: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.8778
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2808 | MulticlassF1Score=0.9016
# Batch-30 : CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9036
# Batch-45 : CrossEntropyLoss=2.2774 | MulticlassF1Score=0.9033
# Batch-60 : CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9032
# Batch-63 : CrossEntropyLoss=2.2815 | MulticlassF1Score=0.9032
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2859 | Mean MulticlassF1Score = 0.8730
# Validation : Mean CrossEntropyLoss = 2.2786 | Mean MulticlassF1Score = 0.9022
# ================================================================================
#
# EPOCH-10
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9145
# Batch-30 : CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9102
# Batch-45 : CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9122
# Batch-60 : CrossEntropyLoss=2.2764 | MulticlassF1Score=0.9126
# Batch-75 : CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9131
# Batch-90 : CrossEntropyLoss=2.2783 | MulticlassF1Score=0.9134
# Batch-105: CrossEntropyLoss=2.2780 | MulticlassF1Score=0.9144
# Batch-120: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9153
# Batch-135: CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9155
# Batch-150: CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9156
# Batch-165: CrossEntropyLoss=2.2767 | MulticlassF1Score=0.9159
# Batch-180: CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9162
# Batch-195: CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9164
# Batch-210: CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9158
# Batch-225: CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9159
# Batch-226: CrossEntropyLoss=2.2771 | MulticlassF1Score=0.9160
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2751 | MulticlassF1Score=0.9122
# Batch-30 : CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9109
# Batch-45 : CrossEntropyLoss=2.2788 | MulticlassF1Score=0.9117
# Batch-60 : CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9122
# Batch-63 : CrossEntropyLoss=2.2844 | MulticlassF1Score=0.9118
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2743 | Mean MulticlassF1Score = 0.9143
# Validation : Mean CrossEntropyLoss = 2.2755 | Mean MulticlassF1Score = 0.9126
# ================================================================================
#
# EPOCH-11
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9200
# Batch-30 : CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9207
# Batch-45 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9209
# Batch-60 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9198
# Batch-75 : CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9198
# Batch-90 : CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9188
# Batch-105: CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9195
# Batch-120: CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9206
# Batch-135: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9201
# Batch-150: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9199
# Batch-165: CrossEntropyLoss=2.2789 | MulticlassF1Score=0.9195
# Batch-180: CrossEntropyLoss=2.2770 | MulticlassF1Score=0.9195
# Batch-195: CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9198
# Batch-210: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9200
# Batch-225: CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9202
# Batch-226: CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9203
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9097
# Batch-30 : CrossEntropyLoss=2.2751 | MulticlassF1Score=0.9112
# Batch-45 : CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9126
# Batch-60 : CrossEntropyLoss=2.2759 | MulticlassF1Score=0.9133
# Batch-63 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9136
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2727 | Mean MulticlassF1Score = 0.9196
# Validation : Mean CrossEntropyLoss = 2.2746 | Mean MulticlassF1Score = 0.9108
# ================================================================================
#
# EPOCH-12
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9187
# Batch-30 : CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9223
# Batch-45 : CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9211
# Batch-60 : CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9204
# Batch-75 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9206
# Batch-90 : CrossEntropyLoss=2.2801 | MulticlassF1Score=0.9213
# Batch-105: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9222
# Batch-120: CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9221
# Batch-135: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9226
# Batch-150: CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9222
# Batch-165: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9218
# Batch-180: CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9222
# Batch-195: CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9223
# Batch-210: CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9228
# Batch-225: CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9223
# Batch-226: CrossEntropyLoss=2.2762 | MulticlassF1Score=0.9222
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9131
# Batch-30 : CrossEntropyLoss=2.2776 | MulticlassF1Score=0.9124
# Batch-45 : CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9124
# Batch-60 : CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9137
# Batch-63 : CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9138
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2720 | Mean MulticlassF1Score = 0.9218
# Validation : Mean CrossEntropyLoss = 2.2745 | Mean MulticlassF1Score = 0.9139
# ================================================================================
#
# EPOCH-13
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9274
# Batch-30 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9270
# Batch-45 : CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9250
# Batch-60 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9251
# Batch-75 : CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9252
# Batch-90 : CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9247
# Batch-105: CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9250
# Batch-120: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9246
# Batch-135: CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9243
# Batch-150: CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9242
# Batch-165: CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9244
# Batch-180: CrossEntropyLoss=2.2754 | MulticlassF1Score=0.9240
# Batch-195: CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9238
# Batch-210: CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9238
# Batch-225: CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9236
# Batch-226: CrossEntropyLoss=2.2774 | MulticlassF1Score=0.9236
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9173
# Batch-30 : CrossEntropyLoss=2.2784 | MulticlassF1Score=0.9153
# Batch-45 : CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9140
# Batch-60 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9142
# Batch-63 : CrossEntropyLoss=2.2774 | MulticlassF1Score=0.9148
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2715 | Mean MulticlassF1Score = 0.9249
# Validation : Mean CrossEntropyLoss = 2.2741 | Mean MulticlassF1Score = 0.9169
# ================================================================================
#
# EPOCH-14
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9242
# Batch-30 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9250
# Batch-45 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9248
# Batch-60 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9263
# Batch-75 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9261
# Batch-90 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9256
# Batch-105: CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9261
# Batch-120: CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9257
# Batch-135: CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9254
# Batch-150: CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9255
# Batch-165: CrossEntropyLoss=2.2758 | MulticlassF1Score=0.9252
# Batch-180: CrossEntropyLoss=2.2778 | MulticlassF1Score=0.9249
# Batch-195: CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9252
# Batch-210: CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9253
# Batch-225: CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9253
# Batch-226: CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9253
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2756 | MulticlassF1Score=0.9151
# Batch-30 : CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9144
# Batch-45 : CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9145
# Batch-60 : CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9157
# Batch-63 : CrossEntropyLoss=2.2764 | MulticlassF1Score=0.9154
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2709 | Mean MulticlassF1Score = 0.9253
# Validation : Mean CrossEntropyLoss = 2.2740 | Mean MulticlassF1Score = 0.9148
# ================================================================================
#
# EPOCH-15
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9273
# Batch-30 : CrossEntropyLoss=2.2756 | MulticlassF1Score=0.9244
# Batch-45 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9265
# Batch-60 : CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9271
# Batch-75 : CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9266
# Batch-90 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9266
# Batch-105: CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9261
# Batch-120: CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9258
# Batch-135: CrossEntropyLoss=2.2759 | MulticlassF1Score=0.9257
# Batch-150: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9260
# Batch-165: CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9262
# Batch-180: CrossEntropyLoss=2.2793 | MulticlassF1Score=0.9261
# Batch-195: CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9261
# Batch-210: CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9263
# Batch-225: CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9263
# Batch-226: CrossEntropyLoss=2.2776 | MulticlassF1Score=0.9262
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9165
# Batch-30 : CrossEntropyLoss=2.2762 | MulticlassF1Score=0.9151
# Batch-45 : CrossEntropyLoss=2.2776 | MulticlassF1Score=0.9156
# Batch-60 : CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9151
# Batch-63 : CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9146
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2706 | Mean MulticlassF1Score = 0.9262
# Validation : Mean CrossEntropyLoss = 2.2742 | Mean MulticlassF1Score = 0.9156
# ================================================================================
#
# EPOCH-16
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9241
# Batch-30 : CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9254
# Batch-45 : CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9260
# Batch-60 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9268
# Batch-75 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9265
# Batch-90 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9280
# Batch-105: CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9285
# Batch-120: CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9286
# Batch-135: CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9289
# Batch-150: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9293
# Batch-165: CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9294
# Batch-180: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9297
# Batch-195: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9298
# Batch-210: CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9297
# Batch-225: CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9298
# Batch-226: CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9298
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2751 | MulticlassF1Score=0.9113
# Batch-30 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9165
# Batch-45 : CrossEntropyLoss=2.2759 | MulticlassF1Score=0.9190
# Batch-60 : CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9185
# Batch-63 : CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9191
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2695 | Mean MulticlassF1Score = 0.9276
# Validation : Mean CrossEntropyLoss = 2.2729 | Mean MulticlassF1Score = 0.9150
# ================================================================================
#
# EPOCH-17
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9322
# Batch-30 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9321
# Batch-45 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9334
# Batch-60 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9338
# Batch-75 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9339
# Batch-90 : CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9336
# Batch-105: CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9328
# Batch-120: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9331
# Batch-135: CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9331
# Batch-150: CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9333
# Batch-165: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9332
# Batch-180: CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9329
# Batch-195: CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9330
# Batch-210: CrossEntropyLoss=2.2612 | MulticlassF1Score=0.9330
# Batch-225: CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9327
# Batch-226: CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9327
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9194
# Batch-30 : CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9189
# Batch-45 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9201
# Batch-60 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9197
# Batch-63 : CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9197
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2686 | Mean MulticlassF1Score = 0.9330
# Validation : Mean CrossEntropyLoss = 2.2726 | Mean MulticlassF1Score = 0.9190
# ================================================================================
#
# EPOCH-18
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9336
# Batch-30 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9330
# Batch-45 : CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9349
# Batch-60 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9349
# Batch-75 : CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9348
# Batch-90 : CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9338
# Batch-105: CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9343
# Batch-120: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9348
# Batch-135: CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9347
# Batch-150: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9346
# Batch-165: CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9348
# Batch-180: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9347
# Batch-195: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9345
# Batch-210: CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9344
# Batch-225: CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9343
# Batch-226: CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9343
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9226
# Batch-30 : CrossEntropyLoss=2.2759 | MulticlassF1Score=0.9197
# Batch-45 : CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9194
# Batch-60 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9194
# Batch-63 : CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9196
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2680 | Mean MulticlassF1Score = 0.9341
# Validation : Mean CrossEntropyLoss = 2.2725 | Mean MulticlassF1Score = 0.9203
# ================================================================================
#
# EPOCH-19
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9335
# Batch-30 : CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9355
# Batch-45 : CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9375
# Batch-60 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9379
# Batch-75 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9369
# Batch-90 : CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9369
# Batch-105: CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9367
# Batch-120: CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9359
# Batch-135: CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9356
# Batch-150: CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9353
# Batch-165: CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9355
# Batch-180: CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9352
# Batch-195: CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9354
# Batch-210: CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9353
# Batch-225: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9352
# Batch-226: CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9352
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9224
# Batch-30 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9205
# Batch-45 : CrossEntropyLoss=2.2782 | MulticlassF1Score=0.9205
# Batch-60 : CrossEntropyLoss=2.2772 | MulticlassF1Score=0.9203
# Batch-63 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9202
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2677 | Mean MulticlassF1Score = 0.9359
# Validation : Mean CrossEntropyLoss = 2.2724 | Mean MulticlassF1Score = 0.9212
# ================================================================================
#
# EPOCH-20
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9369
# Batch-30 : CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9382
# Batch-45 : CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9381
# Batch-60 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9390
# Batch-75 : CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9374
# Batch-90 : CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9372
# Batch-105: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9369
# Batch-120: CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9372
# Batch-135: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9373
# Batch-150: CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9367
# Batch-165: CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9364
# Batch-180: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9363
# Batch-195: CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9366
# Batch-210: CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9362
# Batch-225: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9362
# Batch-226: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9361
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9179
# Batch-30 : CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9194
# Batch-45 : CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9204
# Batch-60 : CrossEntropyLoss=2.2775 | MulticlassF1Score=0.9208
# Batch-63 : CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9211
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2674 | Mean MulticlassF1Score = 0.9370
# Validation : Mean CrossEntropyLoss = 2.2721 | Mean MulticlassF1Score = 0.9196
# ================================================================================
#
# EPOCH-21
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9352
# Batch-30 : CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9357
# Batch-45 : CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9373
# Batch-60 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9366
# Batch-75 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9380
# Batch-90 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9377
# Batch-105: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9372
# Batch-120: CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9375
# Batch-135: CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9371
# Batch-150: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9373
# Batch-165: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9371
# Batch-180: CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9370
# Batch-195: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9368
# Batch-210: CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9367
# Batch-225: CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9367
# Batch-226: CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9367
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9180
# Batch-30 : CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9186
# Batch-45 : CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9197
# Batch-60 : CrossEntropyLoss=2.2784 | MulticlassF1Score=0.9200
# Batch-63 : CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9200
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2671 | Mean MulticlassF1Score = 0.9368
# Validation : Mean CrossEntropyLoss = 2.2724 | Mean MulticlassF1Score = 0.9180
# ================================================================================
#
# EPOCH-22
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2611 | MulticlassF1Score=0.9376
# Batch-30 : CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9370
# Batch-45 : CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9371
# Batch-60 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9367
# Batch-75 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9367
# Batch-90 : CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9362
# Batch-105: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9363
# Batch-120: CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9368
# Batch-135: CrossEntropyLoss=2.2612 | MulticlassF1Score=0.9374
# Batch-150: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9372
# Batch-165: CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9369
# Batch-180: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9371
# Batch-195: CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9368
# Batch-210: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9368
# Batch-225: CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9370
# Batch-226: CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9370
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9241
# Batch-30 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9227
# Batch-45 : CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9208
# Batch-60 : CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9207
# Batch-63 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9209
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2670 | Mean MulticlassF1Score = 0.9368
# Validation : Mean CrossEntropyLoss = 2.2721 | Mean MulticlassF1Score = 0.9230
# ================================================================================
#
# EPOCH-23
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9358
# Batch-30 : CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9380
# Batch-45 : CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9375
# Batch-60 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9376
# Batch-75 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9376
# Batch-90 : CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9374
# Batch-105: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9381
# Batch-120: CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9377
# Batch-135: CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9378
# Batch-150: CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9381
# Batch-165: CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9380
# Batch-180: CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9377
# Batch-195: CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9374
# Batch-210: CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9374
# Batch-225: CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9376
# Batch-226: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9376
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9178
# Batch-30 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9196
# Batch-45 : CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9197
# Batch-60 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9205
# Batch-63 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9208
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2668 | Mean MulticlassF1Score = 0.9377
# Validation : Mean CrossEntropyLoss = 2.2720 | Mean MulticlassF1Score = 0.9196
# ================================================================================
#
# EPOCH-24
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9386
# Batch-30 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9356
# Batch-45 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9353
# Batch-60 : CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9360
# Batch-75 : CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9372
# Batch-90 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9377
# Batch-105: CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9379
# Batch-120: CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9388
# Batch-135: CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9385
# Batch-150: CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9384
# Batch-165: CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9381
# Batch-180: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9379
# Batch-195: CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9378
# Batch-210: CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9379
# Batch-225: CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9376
# Batch-226: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9377
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9215
# Batch-30 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9229
# Batch-45 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9207
# Batch-60 : CrossEntropyLoss=2.2866 | MulticlassF1Score=0.9202
# Batch-63 : CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9201
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2668 | Mean MulticlassF1Score = 0.9375
# Validation : Mean CrossEntropyLoss = 2.2723 | Mean MulticlassF1Score = 0.9218
# ================================================================================
#
# EPOCH-25
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9367
# Batch-30 : CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9399
# Batch-45 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9397
# Batch-60 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9379
# Batch-75 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9381
# Batch-90 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9385
# Batch-105: CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9389
# Batch-120: CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9386
# Batch-135: CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9383
# Batch-150: CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9384
# Batch-165: CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9383
# Batch-180: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9382
# Batch-195: CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9381
# Batch-210: CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9377
# Batch-225: CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9378
# Batch-226: CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9378
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9203
# Batch-30 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9194
# Batch-45 : CrossEntropyLoss=2.2777 | MulticlassF1Score=0.9205
# Batch-60 : CrossEntropyLoss=2.2766 | MulticlassF1Score=0.9207
# Batch-63 : CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9212
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2668 | Mean MulticlassF1Score = 0.9385
# Validation : Mean CrossEntropyLoss = 2.2719 | Mean MulticlassF1Score = 0.9195
# Patience = 1/50❗
# ================================================================================
#
# EPOCH-26
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9385
# Batch-30 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9388
# Batch-45 : CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9384
# Batch-60 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9386
# Batch-75 : CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9387
# Batch-90 : CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9386
# Batch-105: CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9390
# Batch-120: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9392
# Batch-135: CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9388
# Batch-150: CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9389
# Batch-165: CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9385
# Batch-180: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9384
# Batch-195: CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9387
# Batch-210: CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9387
# Batch-225: CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9388
# Batch-226: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9387
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9200
# Batch-30 : CrossEntropyLoss=2.2756 | MulticlassF1Score=0.9208
# Batch-45 : CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9212
# Batch-60 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9212
# Batch-63 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9218
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2665 | Mean MulticlassF1Score = 0.9387
# Validation : Mean CrossEntropyLoss = 2.2718 | Mean MulticlassF1Score = 0.9221
# ================================================================================
#
# EPOCH-27
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9427
# Batch-30 : CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9405
# Batch-45 : CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9399
# Batch-60 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9396
# Batch-75 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9395
# Batch-90 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9397
# Batch-105: CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9395
# Batch-120: CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9394
# Batch-135: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9397
# Batch-150: CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9400
# Batch-165: CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9398
# Batch-180: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9401
# Batch-195: CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9400
# Batch-210: CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9399
# Batch-225: CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9396
# Batch-226: CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9396
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9225
# Batch-30 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9215
# Batch-45 : CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9226
# Batch-60 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9227
# Batch-63 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9225
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2662 | Mean MulticlassF1Score = 0.9401
# Validation : Mean CrossEntropyLoss = 2.2716 | Mean MulticlassF1Score = 0.9225
# ================================================================================
#
# EPOCH-28
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9425
# Batch-30 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9403
# Batch-45 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9399
# Batch-60 : CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9396
# Batch-75 : CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9395
# Batch-90 : CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9393
# Batch-105: CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9396
# Batch-120: CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9398
# Batch-135: CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9402
# Batch-150: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9401
# Batch-165: CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9404
# Batch-180: CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9404
# Batch-195: CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9400
# Batch-210: CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9400
# Batch-225: CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9399
# Batch-226: CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9399
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9224
# Batch-30 : CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9239
# Batch-45 : CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9220
# Batch-60 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9219
# Batch-63 : CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9218
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2660 | Mean MulticlassF1Score = 0.9400
# Validation : Mean CrossEntropyLoss = 2.2717 | Mean MulticlassF1Score = 0.9227
# ================================================================================
#
# EPOCH-29
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9384
# Batch-30 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9406
# Batch-45 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9413
# Batch-60 : CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9423
# Batch-75 : CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9421
# Batch-90 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9424
# Batch-105: CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9423
# Batch-120: CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9419
# Batch-135: CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9412
# Batch-150: CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9410
# Batch-165: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9409
# Batch-180: CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9410
# ...
# Batch-45 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9257
# Batch-60 : CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9270
# Batch-63 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9273
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2640 | Mean MulticlassF1Score = 0.9468
# Validation : Mean CrossEntropyLoss = 2.2699 | Mean MulticlassF1Score = 0.9240
# ================================================================================
#
# EPOCH-42
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9458
# Batch-30 : CrossEntropyLoss=2.2622 | MulticlassF1Score=0.9450
# Batch-45 : CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9510
# Batch-60 : CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9568
# Batch-75 : CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9595
# Batch-90 : CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9616
# Batch-105: CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9634
# Batch-120: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9643
# Batch-135: CrossEntropyLoss=2.2534 | MulticlassF1Score=0.9651
# Batch-150: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9656
# Batch-165: CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9659
# Batch-180: CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9665
# Batch-195: CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9668
# Batch-210: CrossEntropyLoss=2.2544 | MulticlassF1Score=0.9672
# Batch-225: CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9674
# Batch-226: CrossEntropyLoss=2.2530 | MulticlassF1Score=0.9675
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9503
# Batch-30 : CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9494
# Batch-45 : CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9503
# Batch-60 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9520
# Batch-63 : CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9523
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2576 | Mean MulticlassF1Score = 0.9599
# Validation : Mean CrossEntropyLoss = 2.2624 | Mean MulticlassF1Score = 0.9504
# ================================================================================
#
# EPOCH-43
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9730
# Batch-30 : CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9742
# Batch-45 : CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9730
# Batch-60 : CrossEntropyLoss=2.2547 | MulticlassF1Score=0.9725
# Batch-75 : CrossEntropyLoss=2.2551 | MulticlassF1Score=0.9724
# Batch-90 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9718
# Batch-105: CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9720
# Batch-120: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9724
# Batch-135: CrossEntropyLoss=2.2542 | MulticlassF1Score=0.9723
# Batch-150: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9724
# Batch-165: CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9725
# Batch-180: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9723
# Batch-195: CrossEntropyLoss=2.2540 | MulticlassF1Score=0.9721
# Batch-210: CrossEntropyLoss=2.2530 | MulticlassF1Score=0.9719
# Batch-225: CrossEntropyLoss=2.2536 | MulticlassF1Score=0.9718
# Batch-226: CrossEntropyLoss=2.2543 | MulticlassF1Score=0.9718
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9483
# Batch-30 : CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9523
# Batch-45 : CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9522
# Batch-60 : CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9519
# Batch-63 : CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9519
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2562 | Mean MulticlassF1Score = 0.9725
# Validation : Mean CrossEntropyLoss = 2.2625 | Mean MulticlassF1Score = 0.9517
# ================================================================================
#
# EPOCH-44
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9725
# Batch-30 : CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9741
# Batch-45 : CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9727
# Batch-60 : CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9729
# Batch-75 : CrossEntropyLoss=2.2530 | MulticlassF1Score=0.9729
# Batch-90 : CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9726
# Batch-105: CrossEntropyLoss=2.2521 | MulticlassF1Score=0.9727
# Batch-120: CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9725
# Batch-135: CrossEntropyLoss=2.2536 | MulticlassF1Score=0.9729
# Batch-150: CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9729
# Batch-165: CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9727
# Batch-180: CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9725
# Batch-195: CrossEntropyLoss=2.2535 | MulticlassF1Score=0.9727
# Batch-210: CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9726
# Batch-225: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9725
# Batch-226: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9725
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9501
# Batch-30 : CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9511
# Batch-45 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9505
# Batch-60 : CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9517
# Batch-63 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9519
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2560 | Mean MulticlassF1Score = 0.9728
# Validation : Mean CrossEntropyLoss = 2.2625 | Mean MulticlassF1Score = 0.9517
# ================================================================================
#
# EPOCH-45
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9739
# Batch-30 : CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9721
# Batch-45 : CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9728
# Batch-60 : CrossEntropyLoss=2.2547 | MulticlassF1Score=0.9726
# Batch-75 : CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9729
# Batch-90 : CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9731
# Batch-105: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9730
# Batch-120: CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9726
# Batch-135: CrossEntropyLoss=2.2526 | MulticlassF1Score=0.9727
# Batch-150: CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9726
# Batch-165: CrossEntropyLoss=2.2538 | MulticlassF1Score=0.9726
# Batch-180: CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9727
# Batch-195: CrossEntropyLoss=2.2534 | MulticlassF1Score=0.9727
# Batch-210: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9728
# Batch-225: CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9727
# Batch-226: CrossEntropyLoss=2.2551 | MulticlassF1Score=0.9727
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9543
# Batch-30 : CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9546
# Batch-45 : CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9532
# Batch-60 : CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9526
# Batch-63 : CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9531
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2559 | Mean MulticlassF1Score = 0.9729
# Validation : Mean CrossEntropyLoss = 2.2622 | Mean MulticlassF1Score = 0.9532
# ================================================================================
#
# EPOCH-46
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2538 | MulticlassF1Score=0.9717
# Batch-30 : CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9716
# Batch-45 : CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9718
# Batch-60 : CrossEntropyLoss=2.2551 | MulticlassF1Score=0.9719
# Batch-75 : CrossEntropyLoss=2.2535 | MulticlassF1Score=0.9722
# Batch-90 : CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9722
# Batch-105: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9725
# Batch-120: CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9726
# Batch-135: CrossEntropyLoss=2.2535 | MulticlassF1Score=0.9728
# Batch-150: CrossEntropyLoss=2.2547 | MulticlassF1Score=0.9728
# Batch-165: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9728
# Batch-180: CrossEntropyLoss=2.2541 | MulticlassF1Score=0.9729
# Batch-195: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9730
# Batch-210: CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9730
# Batch-225: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9730
# Batch-226: CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9730
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9529
# Batch-30 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9513
# Batch-45 : CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9519
# Batch-60 : CrossEntropyLoss=2.2589 | MulticlassF1Score=0.9514
# Batch-63 : CrossEntropyLoss=2.2622 | MulticlassF1Score=0.9516
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2558 | Mean MulticlassF1Score = 0.9724
# Validation : Mean CrossEntropyLoss = 2.2625 | Mean MulticlassF1Score = 0.9512
# ================================================================================
#
# EPOCH-47
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2544 | MulticlassF1Score=0.9760
# Batch-30 : CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9741
# Batch-45 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9731
# Batch-60 : CrossEntropyLoss=2.2543 | MulticlassF1Score=0.9733
# Batch-75 : CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9729
# Batch-90 : CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9729
# Batch-105: CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9734
# Batch-120: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9737
# Batch-135: CrossEntropyLoss=2.2527 | MulticlassF1Score=0.9736
# Batch-150: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9738
# Batch-165: CrossEntropyLoss=2.2539 | MulticlassF1Score=0.9739
# Batch-180: CrossEntropyLoss=2.2544 | MulticlassF1Score=0.9739
# Batch-195: CrossEntropyLoss=2.2530 | MulticlassF1Score=0.9736
# Batch-210: CrossEntropyLoss=2.2538 | MulticlassF1Score=0.9736
# Batch-225: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9733
# Batch-226: CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9733
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9503
# Batch-30 : CrossEntropyLoss=2.2611 | MulticlassF1Score=0.9506
# Batch-45 : CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9517
# Batch-60 : CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9515
# Batch-63 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9514
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2557 | Mean MulticlassF1Score = 0.9737
# Validation : Mean CrossEntropyLoss = 2.2626 | Mean MulticlassF1Score = 0.9508
# ================================================================================
#
# EPOCH-48
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2534 | MulticlassF1Score=0.9726
# Batch-30 : CrossEntropyLoss=2.2514 | MulticlassF1Score=0.9740
# Batch-45 : CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9737
# Batch-60 : CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9735
# Batch-75 : CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9733
# Batch-90 : CrossEntropyLoss=2.2539 | MulticlassF1Score=0.9732
# Batch-105: CrossEntropyLoss=2.2551 | MulticlassF1Score=0.9734
# Batch-120: CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9736
# Batch-135: CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9734
# Batch-150: CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9735
# Batch-165: CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9733
# Batch-180: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9733
# Batch-195: CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9733
# Batch-210: CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9732
# Batch-225: CrossEntropyLoss=2.2530 | MulticlassF1Score=0.9733
# Batch-226: CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9733
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9540
# Batch-30 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9524
# Batch-45 : CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9527
# Batch-60 : CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9527
# Batch-63 : CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9528
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2557 | Mean MulticlassF1Score = 0.9734
# Validation : Mean CrossEntropyLoss = 2.2622 | Mean MulticlassF1Score = 0.9533
# ================================================================================
#
# EPOCH-49
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9742
# Batch-30 : CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9743
# Batch-45 : CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9733
# Batch-60 : CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9727
# Batch-75 : CrossEntropyLoss=2.2541 | MulticlassF1Score=0.9726
# Batch-90 : CrossEntropyLoss=2.2529 | MulticlassF1Score=0.9728
# Batch-105: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9733
# Batch-120: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9732
# Batch-135: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9733
# Batch-150: CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9732
# Batch-165: CrossEntropyLoss=2.2528 | MulticlassF1Score=0.9732
# Batch-180: CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9731
# Batch-195: CrossEntropyLoss=2.2516 | MulticlassF1Score=0.9731
# Batch-210: CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9733
# Batch-225: CrossEntropyLoss=2.2518 | MulticlassF1Score=0.9732
# Batch-226: CrossEntropyLoss=2.2530 | MulticlassF1Score=0.9732
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9509
# Batch-30 : CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9520
# Batch-45 : CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9531
# Batch-60 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9529
# Batch-63 : CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9530
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2557 | Mean MulticlassF1Score = 0.9732
# Validation : Mean CrossEntropyLoss = 2.2620 | Mean MulticlassF1Score = 0.9524
# Patience = 5/50❗
# ================================================================================
#
# EPOCH-50
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2551 | MulticlassF1Score=0.9777
# Batch-30 : CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9757
# Batch-45 : CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9753
# Batch-60 : CrossEntropyLoss=2.2535 | MulticlassF1Score=0.9745
# Batch-75 : CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9744
# Batch-90 : CrossEntropyLoss=2.2507 | MulticlassF1Score=0.9743
# Batch-105: CrossEntropyLoss=2.2534 | MulticlassF1Score=0.9742
# Batch-120: CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9740
# Batch-135: CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9734
# Batch-150: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9733
# Batch-165: CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9734
# Batch-180: CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9734
# Batch-195: CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9736
# Batch-210: CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9734
# Batch-225: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9733
# Batch-226: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9733
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9535
# Batch-30 : CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9532
# Batch-45 : CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9532
# Batch-60 : CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9531
# Batch-63 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9531
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2557 | Mean MulticlassF1Score = 0.9744
# Validation : Mean CrossEntropyLoss = 2.2621 | Mean MulticlassF1Score = 0.9529
# ================================================================================
#
# TRAINING SUMMARY
# Best CrossEntropyLoss training    : 2.2557
# Best CrossEntropyLoss training    : 2.2621
# Best MulticlassF1Score validation : 0.9744
# Best MulticlassF1Score validation : 0.9529
# Training duration                 : 2.5550 minutes.
# Training date                     : 2022-10-19 11:05:47.870510+08:00

# %% [markdown]
# ## End Training

# %% [markdown]
# # Evaluation

# %%
def evaluation(dataloader, model, criterion, metric):
    model.eval()
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)
            pred = rearrange(prob.argmax(dim=1).reshape(feature.shape[0], len(dataloader.dataset)), "s n -> n s")

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob.argmax(dim=1), actual_label.to(hyperparams.device))
            metric_score = metric.compute()

    return loss, metric_score, pred

train_dataloader = DataLoader(train_dataset, batch_size=len(train_dataset))
val_dataloader = DataLoader(val_dataset, batch_size=len(val_dataset))
test_dataloader = DataLoader(test_dataset, batch_size=len(test_dataset))

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
train_loss, train_f1_score, train_pred_label = evaluation(train_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_loss, val_f1_score, val_pred_label = evaluation(val_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
test_loss, test_f1_score, test_pred_label = evaluation(test_dataloader, model, criterion, metric)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9740, device='cuda:0'),
#  tensor(0.9531, device='cuda:0'),
#  tensor(0.9495, device='cuda:0'))

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9740, device='cuda:0'),
#  tensor(0.9531, device='cuda:0'),
#  tensor(0.9495, device='cuda:0'))

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns

def viz_evaluation(pred_label, actual_label, title):
    plt.figure(figsize=(15, 7), dpi=200)
    sns.heatmap(pred_label.detach().cpu() == actual_label, cbar=True, cmap="binary_r")
    plt.xlabel("Sentence Length")
    plt.ylabel("Sentence")
    plt.title(title)
    plt.savefig(f"{root_path}/heatmap_{title.lower()}.jpg", dpi=200)
    plt.show()

train_actual_label = train_dataloader.dataset.tensors[1]
val_actual_label = val_dataloader.dataset.tensors[1]
test_actual_label = test_dataloader.dataset.tensors[1]

viz_evaluation(train_pred_label, train_actual_label, f"Training (F1-Score: {(train_f1_score):.4f})")
viz_evaluation(val_pred_label, val_actual_label, f"Validation (F1-Score: {(val_f1_score):.4f})")
viz_evaluation(test_pred_label, test_actual_label, f"Test (F1-Score: {(test_f1_score):.4f})")

# %% [markdown]
# ## Confusion Matrix

# %%
def confusion_matrix(pred_class, actual_class, title, normalize=None):
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize=normalize)
    plt.figure(figsize=(20, 10), dpi=200)
    sns.heatmap(conf_mat(pred_class.detach().cpu(), actual_class), annot=True, fmt=".2g", xticklabels=list(label_to_idx.keys()), yticklabels=list(label_to_idx.keys()));
    plt.yticks(rotation=0)
    plt.title(title)
    plt.xlabel("Actual Class")
    plt.ylabel("Predict Class")
    plt.savefig(f"{root_path}/conf_matrix_{title.lower()}.jpg", dpi=200)

confusion_matrix(train_pred_label, train_actual_label, "Training", "pred")
confusion_matrix(val_pred_label,val_actual_label, "Validation", "pred")
confusion_matrix(test_pred_label, test_actual_label, "Test", "pred")
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 144 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)

# %% [markdown]
# ## Prediction Table

# %%
def number_wrong_pred_each_class(pred_class, actual_class):
    classes, count_class = actual_class.flatten().unique(return_counts=True)
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize="none")
    correct_pred_count_class = conf_mat(pred_class.detach().cpu(), actual_class).diag()
    
    correct_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (correct_pred_count_class))}
    wrong_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (count_class - correct_pred_count_class))}
    
    return correct_pred, wrong_pred

correct_pred, wrong_pred = number_wrong_pred_each_class(train_pred_label, train_actual_label)
print(f"| {'Number class'.ljust(14)} | {'Correct prediction'.ljust(12)} | {'Wrong prediction'.ljust(12)} |")
for (label_correct_pred, count_correct_pred), (label_wrong_pred, count_wrong_pred) in zip(correct_pred.items(), wrong_pred.items()):
    print(f"| {str(label_correct_pred).ljust(6)}: {str(count_correct_pred + count_wrong_pred).ljust(7)}| {label_correct_pred.ljust(6)}: {str(count_correct_pred).ljust(10)} | {label_wrong_pred.ljust(6)}: {str(count_wrong_pred).ljust(8)} |")
# Out:
# | Number class   | Correct prediction | Wrong prediction |
# | CC    : 5391   | CC    : 5249       | CC    : 142      |
# | CD    : 12882  | CD    : 12805      | CD    : 77       |
# | DT    : 273    | DT    : 0          | DT    : 273      |
# | FW    : 1690   | FW    : 1470       | FW    : 220      |
# | IN    : 15403  | IN    : 15268      | IN    : 135      |
# | JJ    : 7018   | JJ    : 6644       | JJ    : 374      |
# | MD    : 3810   | MD    : 3692       | MD    : 118      |
# | NEG   : 1082   | NEG   : 980        | NEG   : 102      |
# | NN    : 44728  | NN    : 44239      | NN    : 489      |
# | NND   : 1019   | NND   : 897        | NND   : 122      |
# | NNP   : 24885  | NNP   : 24475      | NNP   : 410      |
# | OD    : 534    | OD    : 0          | OD    : 534      |
# | PR    : 3842   | PR    : 3657       | PR    : 185      |
# | PRP   : 5405   | PRP   : 5361       | PRP   : 44       |
# | RB    : 3553   | RB    : 3317       | RB    : 236      |
# | RP    : 144    | RP    : 0          | RP    : 144      |
# | SC    : 9487   | SC    : 9242       | SC    : 245      |
# | SYM   : 1550   | SYM   : 1490       | SYM   : 60       |
# | UH    : 26     | UH    : 0          | UH    : 26       |
# | VB    : 22846  | VB    : 22443      | VB    : 403      |
# | WH    : 188    | WH    : 0          | WH    : 188      |
# | X     : 279    | X     : 0          | X     : 279      |
# | Z     : 18958  | Z     : 18954      | Z     : 4        |
# | <PAD> : 407211 | <PAD> : 407211     | <PAD> : 0        |

# %%
train_actual_label[308], train_pred_label[308]
# Out:
# (tensor([ 8, 19, 22, 10, 22, 19, 10,  6, 19,  4,  1,  8, 16, 19,  8, 19,  0,  8,
#           5, 16, 19, 19,  8,  8, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23]),
#  tensor([ 8, 19, 22, 10, 22, 19, 10,  6, 19,  4,  1,  8, 16, 19,  8,  5,  0,  8,
#           5, 16, 19, 19,  8,  8, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23], device='cuda:0'))

# %%
train_actual_label[308] == train_pred_label[308].detach().cpu()
# Out:
# tensor([ True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True, False,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True])

# %% [markdown]
# ## OOV prediction is correct

# %%
def oov_flag_token(sentences, max_seq_len=hyperparams.max_seq_len):
    sent_copy = deepcopy(sentences)
    sent = []
    oov_flag = []
    
    for sentence in tqdm(sent_copy):
        for token in sentence:
            sent.append(token[2])
        
        for _ in range(max_seq_len- len(sentence)):
            sent.append(False)
        
        oov_flag.append(sent)
        sent = []
        
    return np.array(oov_flag)

train_oov_flag = oov_flag_token(train_sentences, max_seq_len=hyperparams.max_seq_len)
val_oov_flag = oov_flag_token(val_sentences, max_seq_len=hyperparams.max_seq_len)
test_oov_flag = oov_flag_token(test_sentences, max_seq_len=hyperparams.max_seq_len)

def pencentage_oov_pred_correct(pred_oov_flag, oov_flag_tensor):
    oov_correct_counter = 0
    oov_wrong_counter = 0

    for pred, oov_label in tqdm(zip(pred_oov_flag, oov_flag_tensor)):
        if pred == True and oov_label == True:
            oov_correct_counter += 1
        elif pred == False and oov_label == True:
            oov_wrong_counter += 1
        else:
            continue
            
    return oov_correct_counter, oov_wrong_counter

train_pred_oov_flag = (train_actual_label == train_pred_label.detach().cpu()).flatten()
val_pred_oov_flag = (val_actual_label == val_pred_label.detach().cpu()).flatten()
test_pred_oov_flag = (test_actual_label == test_pred_label.detach().cpu()).flatten()
train_oov_flag_tensor = torch.tensor(train_oov_flag).flatten()
val_oov_flag_tensor = torch.tensor(val_oov_flag).flatten()
test_oov_flag_tensor = torch.tensor(test_oov_flag).flatten()

train_oov_correct_counter, train_oov_wrong_counter = pencentage_oov_pred_correct(train_pred_oov_flag, train_oov_flag_tensor)
val_oov_correct_counter, val_oov_wrong_counter = pencentage_oov_pred_correct(val_pred_oov_flag, val_oov_flag_tensor)
test_oov_correct_counter, test_oov_wrong_counter = pencentage_oov_pred_correct(test_pred_oov_flag, test_oov_flag_tensor)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
def print_percentage_pred_oov(title, oov_correct_counter, oov_wrong_counter):
    print(f"{title}")
    print(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}")
    print(f"Correct prediction          : {oov_correct_counter}")
    print(f"Wrong prediction            : {oov_wrong_counter}")
    print(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n")
    
    with open(f"{root_path}/oov_summary.txt", "a") as f:
        f.write(f"{title}\n")
        f.write(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}\n")
        f.write(f"Correct prediction          : {oov_correct_counter}\n")
        f.write(f"Wrong prediction            : {oov_wrong_counter}\n")
        f.write(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n\n")

# %%
print_percentage_pred_oov("Training", train_oov_correct_counter, train_oov_wrong_counter)
print_percentage_pred_oov("Validation", val_oov_correct_counter, val_oov_wrong_counter)
print_percentage_pred_oov("Test", test_oov_correct_counter, test_oov_wrong_counter)
# Out:
# Training
# Number OOV token            : 11808
# Correct prediction          : 11125
# Wrong prediction            : 683
# Percentage correct oov pred : 94.21578590785907
#
# Validation
# Number OOV token            : 3395
# Correct prediction          : 3020
# Wrong prediction            : 375
# Percentage correct oov pred : 88.95434462444771
#
# Test
# Number OOV token            : 1359
# Correct prediction          : 1221
# Wrong prediction            : 138
# Percentage correct oov pred : 89.84547461368653

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(train_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(val_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(test_oov_flag, cmap=plt.cm.binary_r);
