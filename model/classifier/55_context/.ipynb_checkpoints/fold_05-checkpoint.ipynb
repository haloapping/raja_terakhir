# %% [markdown]
# # Import modules

# %%
import csv
import os
import pickle
import pytz
import torch
import timeit
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from copy import deepcopy
from datetime import datetime
from einops import rearrange
from itertools import chain
from time import time
from torch import nn, optim
from torchmetrics.classification import MulticlassAccuracy, MulticlassF1Score, MulticlassConfusionMatrix
from torch.optim import lr_scheduler
from tqdm.notebook import tqdm
from torch.utils.data import TensorDataset, DataLoader
from polyglot.mapping import Embedding, CaseExpander, DigitExpander

# %% [markdown]
# # Hyperparameters

# %%
class Hyperparams:
     def __init__(
        self,
        context_size=55,
        fold=5,
        max_seq_len=82,
        input_size=64,
        batch_size=32,
        num_hidden_layer=1,
        hidden_size=128,
        dropout=0,
        bias=True,
        output_size=24,
        shuffle=True,
        lr=0.005,
        batch_first=False,
        bidirectional=True,
        init_wb_with_kaiming_normal=True,
        n_epoch=50,
        patience=50,
        device="cuda" if torch.cuda.is_available() else "cpu"
    ):
        self.context_size = context_size
        self.fold = fold
        self.input_size = input_size
        self.max_seq_len = max_seq_len
        self.batch_size = batch_size
        self.num_hidden_layer = num_hidden_layer
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.output_size = output_size
        self.shuffle = shuffle
        self.lr = lr
        self.batch_first = batch_first
        self.bidirectional = bidirectional
        self.init_wb_with_kaiming_normal = init_wb_with_kaiming_normal
        self.n_epoch = n_epoch
        self.patience = patience
        self.device = device

hyperparams = Hyperparams()

# %% [markdown]
# # Dataset

# %%
id_pos_tag = pd.read_csv("../../../datasets/raw/Indonesian_Manually_Tagged_Corpus.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False) 
train = pd.read_csv(f"../../../datasets/raw/cv/train/train.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
val = pd.read_csv(f"../../../datasets/raw/cv/val/val.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
test = pd.read_csv(f"../../../datasets/raw/cv/test/test.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)

# %% [markdown]
# # Pre-trained Word Embedding

# %%
embeddings = Embedding.load("../../../word_embeddings/polyglot/idn_embeddings.tar.bz2")
embeddings.apply_expansion(DigitExpander)
embeddings.apply_expansion(CaseExpander)

oov_embeddings = pickle.load(open(f"../../../logs/comick/{hyperparams.context_size}_contexts/10-11-2022_16-08-07/oov_embedding_dict.pkl", "rb"))

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Add OOV Flag

# %%
def add_oov_flag(tokens, embeddings):
    oov_flags = []
    
    for token in tqdm(tokens):
        try:
            if token not in embeddings:
                oov_flags.append(True)
            else:
                oov_flags.append(False)
        except:
            oov_flags.append(False)
        
    return pd.DataFrame(oov_flags, columns=["is_oov"])

id_pos_tag_oov_flags = add_oov_flag(id_pos_tag["token"].values, embeddings)
train_oov_flags = add_oov_flag(train["token"].values, embeddings)
val_oov_flags = add_oov_flag(val["token"].values, embeddings)
test_oov_flags = add_oov_flag(test["token"].values, embeddings)
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/191905 [00:00<?, ?it/s]
#   0%|          | 0/21691 [00:00<?, ?it/s]
#   0%|          | 0/53056 [00:00<?, ?it/s]

# %% [markdown]
# ## Concate OOV Flag

# %%
id_pos_tag_df = pd.concat([id_pos_tag, id_pos_tag_oov_flags], axis=1)
train_df = pd.concat([train, train_oov_flags], axis=1)
val_df = pd.concat([val, val_oov_flags], axis=1)
test_df = pd.concat([test, test_oov_flags], axis=1)

# %% [markdown]
# ## Lowercase OOV Token

# %%
id_pos_tag_df['token'] = np.where(id_pos_tag_df['is_oov'] == True, id_pos_tag_df['token'].str.lower(), id_pos_tag_df['token'])
train_df['token'] = np.where(train_df['is_oov'] == True, train_df['token'].str.lower(), train_df['token'])
val_df['token'] = np.where(val_df['is_oov'] == True, val_df['token'].str.lower(), val_df['token'])
test_df['token'] = np.where(test_df['is_oov'] == True, test_df['token'].str.lower(), test_df['token'])

# %% [markdown]
# ## Embedding Dict, Index to Token and Token to Index

# %%
tokens = list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None))

def embedding_dict(tokens, embeddings, oov_embeddings):
    embedding = {}
    
    for token in tokens:
        if token[0] is not np.nan:
            if token[2] == False or token[0] in embeddings:
                embedding[token[0]] = embeddings[token[0]]
            else:
                embedding[token[0]] = oov_embeddings[token[0].lower()]

    return embedding

embedding_dict = embedding_dict(tokens, embeddings, oov_embeddings)
embedding_dict["<PAD>"] = embeddings["<PAD>"]
word_embeddings = nn.Embedding.from_pretrained(torch.FloatTensor(np.array(list(embedding_dict.values()))), padding_idx=list(embedding_dict.keys()).index("<PAD>"), freeze=True)

idx_to_token = {idx: token for idx, token in enumerate(list(embedding_dict.keys()))}
token_to_idx = {token: idx for idx, token in enumerate(list(embedding_dict.keys()))}

# %% [markdown]
# ## Token to Sentence

# %%
def make_sentence(tokens, max_length_sentence=hyperparams.max_seq_len):
    sentence = []
    sentences = []

    for token in tqdm(tokens):
        if token[0] is not np.nan:
            sentence.append(token)
        else:
            sentences.append(sentence[:max_length_sentence])
            sentence = []

    return sentences

all_sentence = make_sentence(list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
train_sentences = make_sentence(list(train_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
val_sentences = make_sentence(list(test_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
test_sentences = make_sentence(list(val_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/191905 [00:00<?, ?it/s]
#   0%|          | 0/53056 [00:00<?, ?it/s]
#   0%|          | 0/21691 [00:00<?, ?it/s]

# %% [markdown]
# ## Word Token, Padding, and Word token to Index

# %%
def tokenize_docs(docs, idx_token):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token[idx_token])
        sentences.append(new_sentence)
        new_sentence = []

    return sentences

def padding(docs, max_seq_len=hyperparams.max_seq_len, mode="post", val_pad="<PAD>"):
    docs = deepcopy(docs)
    doc_with_pad = []
    docs_with_pad = []

    for doc in tqdm(docs):
        if mode == "pre":
            for _ in range(max_seq_len - len(doc)):
                doc.insert(0, val_pad)
        elif mode == "post":
            for _ in range(max_seq_len - len(doc)):
                doc.append(val_pad)
        else:
            return f"Mode {mode} is not available, use instead 'pre' or 'post'."
        
        docs_with_pad.append(doc)
        
    return np.array(docs_with_pad)

def sent_to_idx(docs, token_to_idx):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token_to_idx[token])
        sentences.append(new_sentence)
        new_sentence = []

    return np.array(sentences)

def convert_feature_to_idx(docs, idx_token, token_to_idx, max_seq_len):
    sentences = tokenize_docs(docs, idx_token)
    sentences_with_pad = padding(sentences, max_seq_len=max_seq_len, mode="post", val_pad="<PAD>")
    sentences_to_idx = sent_to_idx(sentences_with_pad, token_to_idx)
    
    return sentences_to_idx

train_sentence_idxs = convert_feature_to_idx(train_sentences, 0, token_to_idx, hyperparams.max_seq_len)
val_sentence_idxs = convert_feature_to_idx(val_sentences, 0, token_to_idx, hyperparams.max_seq_len)
test_sentence_idxs = convert_feature_to_idx(test_sentences, 0, token_to_idx, hyperparams.max_seq_len)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]

# %% [markdown]
# ## Encode Class

# %%
classes = sorted(np.delete(id_pos_tag_df["tag"].unique(), 3))
idx_to_label = {idx: label for idx, label in enumerate(classes + ["<PAD>"])}
label_to_idx = {label: idx for idx, label in enumerate(classes + ["<PAD>"])}

def encode_class(docs, label_to_idx, seq_len=hyperparams.max_seq_len):
    class_idxs = []
    classes = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            class_idxs.append(label_to_idx[token[1]])
            
        for _ in range(seq_len - len(sentence)):
            class_idxs.append(label_to_idx["<PAD>"])
                
        classes.append(class_idxs)
        class_idxs = []

    return np.array(classes)
        
train_class_idxs = encode_class(train_sentences, label_to_idx)
val_class_idxs = encode_class(val_sentences, label_to_idx)
test_class_idxs = encode_class(test_sentences, label_to_idx)

print(f"Training shape   : {train_sentence_idxs.shape, train_class_idxs.shape}")
print(f"validation shape : {val_class_idxs.shape, val_class_idxs.shape}")
print(f"Test shape       : {test_sentence_idxs.shape, test_class_idxs.shape}")
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# Training shape   : ((7222, 82), (7222, 82))
# validation shape : ((2006, 82), (2006, 82))
# Test shape       : ((802, 82), (802, 82))

# %% [markdown]
# ## Note
#
# - Number of sentences = 10030
# - Train : 72% (7222)
# - Val   : 8% (802)
# - Test  : 20% (2006)

# %% [markdown]
# # Build Model

# %% [markdown]
# ## Feature and Actual Class

# %%
train_feature = torch.LongTensor(train_sentence_idxs)
val_feature = torch.LongTensor(val_sentence_idxs)
test_feature = torch.LongTensor(test_sentence_idxs)

train_class = torch.LongTensor(train_class_idxs)
val_class = torch.LongTensor(val_class_idxs)
test_class = torch.LongTensor(test_class_idxs)

# %%
train_feature.shape, val_feature.shape, test_feature.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %%
train_class.shape, val_class.shape, test_class.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %% [markdown]
# ## Tensor Dataset

# %%
train_dataset = TensorDataset(train_feature, train_class)
val_dataset = TensorDataset(val_feature, val_class)
test_dataset = TensorDataset(test_feature, test_class)

# %% [markdown]
# ## Dataloader

# %%
train_dataloader = DataLoader(train_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
val_dataloader = DataLoader(val_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
test_dataloader = DataLoader(test_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)

# %% [markdown]
# ## Model

# %%
class POSTagger(nn.Module):
    def __init__(
        self,
        input_size=hyperparams.input_size,
        hidden_size=hyperparams.hidden_size,
        dropout=hyperparams.dropout,
        bias=hyperparams.bias,
        num_layers=hyperparams.num_hidden_layer,
        output_size=hyperparams.output_size,
        batch_first=hyperparams.batch_first,
        bidirectional=hyperparams.bidirectional,
        init_wb_with_kaiming_normal=hyperparams.init_wb_with_kaiming_normal
    ):
        super(POSTagger, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.num_layers = num_layers
        self.output_size = output_size
        self.batch_first = batch_first
        self.bidirectional = bidirectional
                
        self.feature = nn.LSTM(
            input_size = self.input_size,
            hidden_size = self.hidden_size,
            bias = self.bias,
            dropout = self.dropout,
            num_layers = self.num_layers,
            batch_first = self.batch_first,
            bidirectional = self.bidirectional
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(in_features=2 * self.hidden_size if hyperparams.bidirectional else self.hidden_size, out_features=self.output_size, bias=self.bias),
            nn.Softmax(dim=-1)
        )
        
        if init_wb_with_kaiming_normal:
            self.init_wb()

    def init_wb(self):
        for module in self.modules():
            if isinstance(module, (nn.Linear, nn.LSTM)):
                for name, param in module.named_parameters():
                    if "weight" in name:
                        nn.init.kaiming_normal_(param)
                    else:
                        nn.init.kaiming_normal_(param.reshape(1, -1))
        
    def forward(self, feature, hidden=None):
        output, (hidden, memory) = self.feature(feature, None)
        prob = self.classifier(output)

        return prob
    
model = POSTagger().to(hyperparams.device)
model
# Out:
# POSTagger(
#   (feature): LSTM(64, 128, bidirectional=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=24, bias=True)
#     (1): Softmax(dim=-1)
#   )
# )

# %% [markdown]
# ## Optimizer, Criterion, and Metric

# %%
optimizer = optim.Adam(model.parameters(), lr=hyperparams.lr)
criterion = nn.CrossEntropyLoss().to(hyperparams.device)
train_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", verbose=True, factor=0.5)

# %%
sum(param.numel() for param in model.parameters() if param.requires_grad)
# Out:
# 204824

# %% [markdown]
# ## Training Step

# %%
def training_step(dataloader, model, optimizer, criterion, metric, scheduler=None):
    model.train()
    
    batch_losses = []
    batch_metric_scores = []
    
    for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
        # Forward Propagation
        feature = rearrange(feature, "n s -> s n")
        actual_label = rearrange(actual_label, "n s -> s n")
        embedding = word_embeddings(feature)
        
        prob = model(
            embedding.to(hyperparams.device),
            actual_label.to(hyperparams.device)
        )
        
        prob = prob.reshape(-1, prob.shape[-1])
        actual_label = actual_label.reshape(-1)

        loss = criterion(prob, actual_label.to(hyperparams.device))
        metric_score = metric(prob, actual_label.to(hyperparams.device))
        metric_score = metric.compute()
                
        if scheduler is not None:
            scheduler.step(loss)
        
        batch_losses.append(loss.item())
        batch_metric_scores.append(metric_score)
        
        if len(dataloader) < 10:
            if batch % 1 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
        else:
            if batch % 15 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            
        # Backward Propagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Validation Step

# %%
def validation_step(dataloader, model, criterion, metric):
    model.eval()
    
    batch_losses = []
    batch_metric_scores = []
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob, actual_label.to(hyperparams.device))
            metric_score = metric.compute()

            batch_losses.append(loss.item())
            batch_metric_scores.append(metric_score)
            
            if len(dataloader) < 10 and (batch % 1 == 0 or batch == len(dataloader)):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            else:
                if batch % 15 == 0 or batch == len(dataloader):
                    batch_name = "Batch-" + str(batch)
                    print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                    with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                        f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Looping Step

# %%
now = datetime.now(pytz.timezone("Asia/Ujung_Pandang"))
path_name = now.strftime("%m-%d-%Y_%H-%M-%S")
root_path = f"../../../logs/classifier/{hyperparams.context_size}_contexts/fold_0{hyperparams.fold}/{path_name}"
os.makedirs(root_path)

def looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric, n_epoch=hyperparams.n_epoch, patience=hyperparams.patience, monitor="loss"):    
    start_time = time()
    
    epoch_training_losses = []
    epoch_training_metric_scores = []
    epoch_val_losses = []
    epoch_val_metric_scores = []
    patience_counter = 0
    
    # Hyperparameters
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write(f"HYPERPARAMETERS\n")
        f.write(f"{'-' * 80}\n")
        for name, value in vars(hyperparams).items():
            f.write(f"{name}: {value}\n")
        
        f.write("\n\nTRAINING PROGRESS\n")
        f.write(f"{'-' * 80}\n")
    
    # Training Progress
    for epoch in range(1, n_epoch + 1):
        print(f"EPOCH-{epoch}")
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"EPOCH-{epoch}\n")
            f.write(f"Training Step\n")
            
        # Training Step
        print("Training Step")
        batch_training_losses, batch_training_metric_scores = training_step(train_dataloader, model, optimizer, criterion, train_metric, scheduler=None)
        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))

        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))
        epoch_training_losses.append(epoch_training_loss.item())

        epoch_training_metric_score = torch.mean(torch.FloatTensor(batch_training_metric_scores))
        epoch_training_metric_scores.append(epoch_training_metric_score.item())
        
        # Validation Step
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"\nValidation Step\n")
            
        print("\nValidation Step")
        batch_val_losses, batch_val_metric_scores = validation_step(val_dataloader, model, criterion, val_metric)
        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))

        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))
        epoch_val_losses.append(epoch_val_loss.item())

        epoch_val_metric_score = torch.mean(torch.FloatTensor(batch_val_metric_scores))
        epoch_val_metric_scores.append(epoch_val_metric_score.item())
        
        with open(f"{root_path}/training_history.txt", "a") as f:
            if monitor == "loss":
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_losses[-1] < epoch_training_losses[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
            else:
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_metric_scores[-1] > epoch_training_metric_scores[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗\n")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
                    
            print("=" * 80, end="\n\n")
            
            f.write(f"{'=' * 80}\n\n")
            
            if patience_counter == patience:
                print(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                
                f.write(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                break
        
        train_metric.reset()
        val_metric.reset()
        
    finish_time = time()
    
    # Training plot 
    fig, (ax_loss, ax_metric_score) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    fig.suptitle(f"Training with context size = {hyperparams.context_size}")

    ax_loss.set_title("Loss")
    ax_loss.set_xlabel("Epoch")
    ax_loss.set_ylabel("Score")
    ax_loss.plot(epoch_training_losses, "green", label="Training")
    ax_loss.plot(epoch_val_losses, "orange", label="Validation")
    ax_loss.legend()
    ax_loss.grid()

    ax_metric_score.set_title("F1 Score")
    ax_metric_score.set_xlabel("Epoch")
    ax_metric_score.set_ylabel("Score")
    ax_metric_score.plot(epoch_training_metric_scores, "green", label="Training")
    ax_metric_score.plot(epoch_val_metric_scores, "orange", label="Validation")
    ax_metric_score.legend()
    ax_metric_score.grid()

    plt.savefig(f"{root_path}/training_plot.jpg", dpi=200)                        
    
    print("TRAINING SUMMARY")
    name_best_training_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_training_metric = f"Best {str(train_metric).split('(')[0]} validation".ljust(34)
    name_best_validation_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_validation_metric = f"Best {str(val_metric).split('(')[0]} validation".ljust(34)
    name_training_time = f"Training duration".ljust(34)
    name_training_date = f"Training date".ljust(34)
    
    print(f"{name_best_training_loss}: {best_training_loss:.4f}")
    print(f"{name_best_validation_loss}: {best_val_loss:.4f}")
    print(f"{name_best_training_metric}: {best_training_metric:.4f}")
    print(f"{name_best_validation_metric}: {best_val_metric:.4f}")
    print(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.")
    print(f"{name_training_date}: {now}")
    
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write("\nTRAINING SUMMARY\n")
        f.write(f"{'-' * 80}\n")
        f.write(f"{name_best_training_loss}: {best_training_loss:.4f}\n")
        f.write(f"{name_best_validation_loss}: {best_val_loss:.4f}\n")
        f.write(f"{name_best_training_metric}: {best_training_metric:.4f}\n")
        f.write(f"{name_best_validation_metric}: {best_val_metric:.4f}\n")
        f.write(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.\n")
        f.write(f"{name_training_date}: {now}\n")
    
    # Save epoch losses, epoch metric scores, model, state dict, and oov embedding dict
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_training_losses
    }).to_csv(f"{root_path}/training_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_training_metric_scores
    }).to_csv(f"{root_path}/training_metric_scores.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_val_losses
    }).to_csv(f"{root_path}/val_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_val_metric_scores
    }).to_csv(f"{root_path}/val_metric_scores.csv", index=False)    
    
    filename_model_params = f"{root_path}/model_params.pth"
    torch.save(best_state_dict, filename_model_params)
    
    return epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores

epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores = looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric)
# Out:
# EPOCH-1
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.4928 | MulticlassF1Score=0.1133
# Batch-30 : CrossEntropyLoss=2.4775 | MulticlassF1Score=0.1851
# Batch-45 : CrossEntropyLoss=2.4967 | MulticlassF1Score=0.2099
# Batch-60 : CrossEntropyLoss=2.4708 | MulticlassF1Score=0.2304
# Batch-75 : CrossEntropyLoss=2.4215 | MulticlassF1Score=0.2513
# Batch-90 : CrossEntropyLoss=2.3998 | MulticlassF1Score=0.2890
# Batch-105: CrossEntropyLoss=2.3895 | MulticlassF1Score=0.3235
# Batch-120: CrossEntropyLoss=2.3565 | MulticlassF1Score=0.3568
# Batch-135: CrossEntropyLoss=2.3614 | MulticlassF1Score=0.3823
# Batch-150: CrossEntropyLoss=2.3591 | MulticlassF1Score=0.4030
# Batch-165: CrossEntropyLoss=2.3745 | MulticlassF1Score=0.4192
# Batch-180: CrossEntropyLoss=2.3561 | MulticlassF1Score=0.4368
# Batch-195: CrossEntropyLoss=2.3531 | MulticlassF1Score=0.4550
# Batch-210: CrossEntropyLoss=2.3671 | MulticlassF1Score=0.4703
# Batch-225: CrossEntropyLoss=2.3507 | MulticlassF1Score=0.4845
# Batch-226: CrossEntropyLoss=2.3598 | MulticlassF1Score=0.4851
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3589 | MulticlassF1Score=0.7036
# Batch-30 : CrossEntropyLoss=2.3351 | MulticlassF1Score=0.7073
# Batch-45 : CrossEntropyLoss=2.3451 | MulticlassF1Score=0.7066
# Batch-60 : CrossEntropyLoss=2.3410 | MulticlassF1Score=0.7054
# Batch-63 : CrossEntropyLoss=2.3474 | MulticlassF1Score=0.7057
#
# Training   : Mean CrossEntropyLoss = 2.4189 | Mean MulticlassF1Score = 0.3206
# Validation : Mean CrossEntropyLoss = 2.3427 | Mean MulticlassF1Score = 0.7064
# ================================================================================
#
# EPOCH-2
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3386 | MulticlassF1Score=0.7152
# Batch-30 : CrossEntropyLoss=2.3489 | MulticlassF1Score=0.7171
# Batch-45 : CrossEntropyLoss=2.3326 | MulticlassF1Score=0.7201
# Batch-60 : CrossEntropyLoss=2.3386 | MulticlassF1Score=0.7243
# Batch-75 : CrossEntropyLoss=2.3327 | MulticlassF1Score=0.7309
# Batch-90 : CrossEntropyLoss=2.3343 | MulticlassF1Score=0.7335
# Batch-105: CrossEntropyLoss=2.3297 | MulticlassF1Score=0.7332
# Batch-120: CrossEntropyLoss=2.3496 | MulticlassF1Score=0.7336
# Batch-135: CrossEntropyLoss=2.3156 | MulticlassF1Score=0.7355
# Batch-150: CrossEntropyLoss=2.3124 | MulticlassF1Score=0.7400
# Batch-165: CrossEntropyLoss=2.3165 | MulticlassF1Score=0.7440
# Batch-180: CrossEntropyLoss=2.3172 | MulticlassF1Score=0.7478
# Batch-195: CrossEntropyLoss=2.3076 | MulticlassF1Score=0.7511
# Batch-210: CrossEntropyLoss=2.3090 | MulticlassF1Score=0.7542
# Batch-225: CrossEntropyLoss=2.3187 | MulticlassF1Score=0.7564
# Batch-226: CrossEntropyLoss=2.3148 | MulticlassF1Score=0.7566
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3103 | MulticlassF1Score=0.7885
# Batch-30 : CrossEntropyLoss=2.3107 | MulticlassF1Score=0.7849
# Batch-45 : CrossEntropyLoss=2.3096 | MulticlassF1Score=0.7855
# Batch-60 : CrossEntropyLoss=2.3109 | MulticlassF1Score=0.7872
# Batch-63 : CrossEntropyLoss=2.3058 | MulticlassF1Score=0.7874
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3244 | Mean MulticlassF1Score = 0.7349
# Validation : Mean CrossEntropyLoss = 2.3141 | Mean MulticlassF1Score = 0.7871
# ================================================================================
#
# EPOCH-3
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3117 | MulticlassF1Score=0.7907
# Batch-30 : CrossEntropyLoss=2.3165 | MulticlassF1Score=0.7891
# Batch-45 : CrossEntropyLoss=2.3092 | MulticlassF1Score=0.7900
# Batch-60 : CrossEntropyLoss=2.3150 | MulticlassF1Score=0.7891
# Batch-75 : CrossEntropyLoss=2.3055 | MulticlassF1Score=0.7911
# Batch-90 : CrossEntropyLoss=2.3126 | MulticlassF1Score=0.7926
# Batch-105: CrossEntropyLoss=2.3139 | MulticlassF1Score=0.7927
# Batch-120: CrossEntropyLoss=2.3140 | MulticlassF1Score=0.7924
# Batch-135: CrossEntropyLoss=2.3049 | MulticlassF1Score=0.7938
# Batch-150: CrossEntropyLoss=2.3066 | MulticlassF1Score=0.7952
# Batch-165: CrossEntropyLoss=2.3246 | MulticlassF1Score=0.7949
# Batch-180: CrossEntropyLoss=2.3206 | MulticlassF1Score=0.7950
# Batch-195: CrossEntropyLoss=2.3145 | MulticlassF1Score=0.7945
# Batch-210: CrossEntropyLoss=2.3119 | MulticlassF1Score=0.7946
# Batch-225: CrossEntropyLoss=2.3125 | MulticlassF1Score=0.7948
# Batch-226: CrossEntropyLoss=2.3105 | MulticlassF1Score=0.7947
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3130 | MulticlassF1Score=0.7923
# Batch-30 : CrossEntropyLoss=2.3101 | MulticlassF1Score=0.7906
# Batch-45 : CrossEntropyLoss=2.3050 | MulticlassF1Score=0.7887
# Batch-60 : CrossEntropyLoss=2.3125 | MulticlassF1Score=0.7902
# Batch-63 : CrossEntropyLoss=2.3076 | MulticlassF1Score=0.7908
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3118 | Mean MulticlassF1Score = 0.7929
# Validation : Mean CrossEntropyLoss = 2.3121 | Mean MulticlassF1Score = 0.7887
# ================================================================================
#
# EPOCH-4
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3097 | MulticlassF1Score=0.8065
# Batch-30 : CrossEntropyLoss=2.3010 | MulticlassF1Score=0.8092
# Batch-45 : CrossEntropyLoss=2.3186 | MulticlassF1Score=0.8069
# Batch-60 : CrossEntropyLoss=2.3066 | MulticlassF1Score=0.8072
# Batch-75 : CrossEntropyLoss=2.3089 | MulticlassF1Score=0.8090
# Batch-90 : CrossEntropyLoss=2.3082 | MulticlassF1Score=0.8080
# Batch-105: CrossEntropyLoss=2.3155 | MulticlassF1Score=0.8071
# Batch-120: CrossEntropyLoss=2.3063 | MulticlassF1Score=0.8077
# Batch-135: CrossEntropyLoss=2.3001 | MulticlassF1Score=0.8085
# Batch-150: CrossEntropyLoss=2.3058 | MulticlassF1Score=0.8078
# Batch-165: CrossEntropyLoss=2.3107 | MulticlassF1Score=0.8073
# Batch-180: CrossEntropyLoss=2.2981 | MulticlassF1Score=0.8074
# Batch-195: CrossEntropyLoss=2.3043 | MulticlassF1Score=0.8077
# Batch-210: CrossEntropyLoss=2.3018 | MulticlassF1Score=0.8078
# Batch-225: CrossEntropyLoss=2.3075 | MulticlassF1Score=0.8083
# Batch-226: CrossEntropyLoss=2.3106 | MulticlassF1Score=0.8083
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3162 | MulticlassF1Score=0.8148
# Batch-30 : CrossEntropyLoss=2.3220 | MulticlassF1Score=0.8081
# Batch-45 : CrossEntropyLoss=2.3030 | MulticlassF1Score=0.8055
# Batch-60 : CrossEntropyLoss=2.3082 | MulticlassF1Score=0.8035
# Batch-63 : CrossEntropyLoss=2.3274 | MulticlassF1Score=0.8034
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3073 | Mean MulticlassF1Score = 0.8071
# Validation : Mean CrossEntropyLoss = 2.3085 | Mean MulticlassF1Score = 0.8085
# ================================================================================
#
# EPOCH-5
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3069 | MulticlassF1Score=0.8091
# Batch-30 : CrossEntropyLoss=2.2929 | MulticlassF1Score=0.8096
# Batch-45 : CrossEntropyLoss=2.2970 | MulticlassF1Score=0.8155
# Batch-60 : CrossEntropyLoss=2.3108 | MulticlassF1Score=0.8195
# Batch-75 : CrossEntropyLoss=2.2955 | MulticlassF1Score=0.8243
# Batch-90 : CrossEntropyLoss=2.2918 | MulticlassF1Score=0.8254
# Batch-105: CrossEntropyLoss=2.2996 | MulticlassF1Score=0.8276
# Batch-120: CrossEntropyLoss=2.2958 | MulticlassF1Score=0.8299
# Batch-135: CrossEntropyLoss=2.3016 | MulticlassF1Score=0.8309
# Batch-150: CrossEntropyLoss=2.2953 | MulticlassF1Score=0.8313
# Batch-165: CrossEntropyLoss=2.2949 | MulticlassF1Score=0.8316
# Batch-180: CrossEntropyLoss=2.2998 | MulticlassF1Score=0.8329
# Batch-195: CrossEntropyLoss=2.2922 | MulticlassF1Score=0.8333
# Batch-210: CrossEntropyLoss=2.3041 | MulticlassF1Score=0.8333
# Batch-225: CrossEntropyLoss=2.3003 | MulticlassF1Score=0.8331
# Batch-226: CrossEntropyLoss=2.2825 | MulticlassF1Score=0.8333
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2999 | MulticlassF1Score=0.8324
# Batch-30 : CrossEntropyLoss=2.2920 | MulticlassF1Score=0.8325
# Batch-45 : CrossEntropyLoss=2.3044 | MulticlassF1Score=0.8331
# Batch-60 : CrossEntropyLoss=2.2980 | MulticlassF1Score=0.8314
# Batch-63 : CrossEntropyLoss=2.3130 | MulticlassF1Score=0.8313
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2995 | Mean MulticlassF1Score = 0.8251
# Validation : Mean CrossEntropyLoss = 2.2998 | Mean MulticlassF1Score = 0.8331
# ================================================================================
#
# EPOCH-6
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2986 | MulticlassF1Score=0.8400
# Batch-30 : CrossEntropyLoss=2.2949 | MulticlassF1Score=0.8384
# Batch-45 : CrossEntropyLoss=2.3050 | MulticlassF1Score=0.8398
# Batch-60 : CrossEntropyLoss=2.2890 | MulticlassF1Score=0.8401
# Batch-75 : CrossEntropyLoss=2.2871 | MulticlassF1Score=0.8403
# Batch-90 : CrossEntropyLoss=2.2892 | MulticlassF1Score=0.8401
# Batch-105: CrossEntropyLoss=2.2977 | MulticlassF1Score=0.8398
# Batch-120: CrossEntropyLoss=2.2858 | MulticlassF1Score=0.8401
# Batch-135: CrossEntropyLoss=2.2953 | MulticlassF1Score=0.8397
# Batch-150: CrossEntropyLoss=2.3038 | MulticlassF1Score=0.8399
# Batch-165: CrossEntropyLoss=2.3013 | MulticlassF1Score=0.8401
# Batch-180: CrossEntropyLoss=2.2928 | MulticlassF1Score=0.8399
# Batch-195: CrossEntropyLoss=2.2924 | MulticlassF1Score=0.8397
# Batch-210: CrossEntropyLoss=2.2916 | MulticlassF1Score=0.8400
# Batch-225: CrossEntropyLoss=2.2995 | MulticlassF1Score=0.8399
# Batch-226: CrossEntropyLoss=2.2898 | MulticlassF1Score=0.8400
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2976 | MulticlassF1Score=0.8308
# Batch-30 : CrossEntropyLoss=2.2910 | MulticlassF1Score=0.8340
# Batch-45 : CrossEntropyLoss=2.3033 | MulticlassF1Score=0.8315
# Batch-60 : CrossEntropyLoss=2.3057 | MulticlassF1Score=0.8321
# Batch-63 : CrossEntropyLoss=2.2830 | MulticlassF1Score=0.8325
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2972 | Mean MulticlassF1Score = 0.8399
# Validation : Mean CrossEntropyLoss = 2.2992 | Mean MulticlassF1Score = 0.8324
# ================================================================================
#
# EPOCH-7
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2946 | MulticlassF1Score=0.8439
# Batch-30 : CrossEntropyLoss=2.3027 | MulticlassF1Score=0.8414
# Batch-45 : CrossEntropyLoss=2.3026 | MulticlassF1Score=0.8409
# Batch-60 : CrossEntropyLoss=2.2914 | MulticlassF1Score=0.8426
# Batch-75 : CrossEntropyLoss=2.2975 | MulticlassF1Score=0.8421
# Batch-90 : CrossEntropyLoss=2.3011 | MulticlassF1Score=0.8427
# Batch-105: CrossEntropyLoss=2.2879 | MulticlassF1Score=0.8429
# Batch-120: CrossEntropyLoss=2.2892 | MulticlassF1Score=0.8420
# Batch-135: CrossEntropyLoss=2.2955 | MulticlassF1Score=0.8415
# Batch-150: CrossEntropyLoss=2.2929 | MulticlassF1Score=0.8423
# Batch-165: CrossEntropyLoss=2.2918 | MulticlassF1Score=0.8426
# Batch-180: CrossEntropyLoss=2.3033 | MulticlassF1Score=0.8425
# Batch-195: CrossEntropyLoss=2.2925 | MulticlassF1Score=0.8425
# Batch-210: CrossEntropyLoss=2.2889 | MulticlassF1Score=0.8424
# Batch-225: CrossEntropyLoss=2.3052 | MulticlassF1Score=0.8419
# Batch-226: CrossEntropyLoss=2.3022 | MulticlassF1Score=0.8419
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3031 | MulticlassF1Score=0.8343
# Batch-30 : CrossEntropyLoss=2.3087 | MulticlassF1Score=0.8314
# Batch-45 : CrossEntropyLoss=2.2883 | MulticlassF1Score=0.8337
# Batch-60 : CrossEntropyLoss=2.2837 | MulticlassF1Score=0.8335
# Batch-63 : CrossEntropyLoss=2.2895 | MulticlassF1Score=0.8338
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2966 | Mean MulticlassF1Score = 0.8422
# Validation : Mean CrossEntropyLoss = 2.2988 | Mean MulticlassF1Score = 0.8345
# ================================================================================
#
# EPOCH-8
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2962 | MulticlassF1Score=0.8384
# Batch-30 : CrossEntropyLoss=2.2955 | MulticlassF1Score=0.8429
# Batch-45 : CrossEntropyLoss=2.2983 | MulticlassF1Score=0.8451
# Batch-60 : CrossEntropyLoss=2.2837 | MulticlassF1Score=0.8473
# Batch-75 : CrossEntropyLoss=2.2944 | MulticlassF1Score=0.8487
# Batch-90 : CrossEntropyLoss=2.2918 | MulticlassF1Score=0.8508
# Batch-105: CrossEntropyLoss=2.2881 | MulticlassF1Score=0.8518
# Batch-120: CrossEntropyLoss=2.2852 | MulticlassF1Score=0.8524
# Batch-135: CrossEntropyLoss=2.2899 | MulticlassF1Score=0.8534
# Batch-150: CrossEntropyLoss=2.2980 | MulticlassF1Score=0.8534
# Batch-165: CrossEntropyLoss=2.2916 | MulticlassF1Score=0.8538
# Batch-180: CrossEntropyLoss=2.2863 | MulticlassF1Score=0.8542
# Batch-195: CrossEntropyLoss=2.2836 | MulticlassF1Score=0.8546
# Batch-210: CrossEntropyLoss=2.2933 | MulticlassF1Score=0.8550
# Batch-225: CrossEntropyLoss=2.2880 | MulticlassF1Score=0.8549
# Batch-226: CrossEntropyLoss=2.2831 | MulticlassF1Score=0.8550
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2877 | MulticlassF1Score=0.8550
# Batch-30 : CrossEntropyLoss=2.2972 | MulticlassF1Score=0.8542
# Batch-45 : CrossEntropyLoss=2.2882 | MulticlassF1Score=0.8505
# Batch-60 : CrossEntropyLoss=2.2986 | MulticlassF1Score=0.8511
# Batch-63 : CrossEntropyLoss=2.2942 | MulticlassF1Score=0.8507
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2928 | Mean MulticlassF1Score = 0.8499
# Validation : Mean CrossEntropyLoss = 2.2938 | Mean MulticlassF1Score = 0.8532
# ================================================================================
#
# EPOCH-9
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2864 | MulticlassF1Score=0.8571
# Batch-30 : CrossEntropyLoss=2.2882 | MulticlassF1Score=0.8583
# Batch-45 : CrossEntropyLoss=2.2904 | MulticlassF1Score=0.8577
# Batch-60 : CrossEntropyLoss=2.2887 | MulticlassF1Score=0.8581
# Batch-75 : CrossEntropyLoss=2.2827 | MulticlassF1Score=0.8583
# Batch-90 : CrossEntropyLoss=2.2888 | MulticlassF1Score=0.8608
# Batch-105: CrossEntropyLoss=2.2826 | MulticlassF1Score=0.8636
# Batch-120: CrossEntropyLoss=2.2794 | MulticlassF1Score=0.8660
# Batch-135: CrossEntropyLoss=2.2864 | MulticlassF1Score=0.8679
# Batch-150: CrossEntropyLoss=2.2835 | MulticlassF1Score=0.8696
# Batch-165: CrossEntropyLoss=2.2884 | MulticlassF1Score=0.8713
# Batch-180: CrossEntropyLoss=2.2815 | MulticlassF1Score=0.8730
# Batch-195: CrossEntropyLoss=2.2934 | MulticlassF1Score=0.8739
# Batch-210: CrossEntropyLoss=2.2740 | MulticlassF1Score=0.8752
# Batch-225: CrossEntropyLoss=2.2795 | MulticlassF1Score=0.8758
# Batch-226: CrossEntropyLoss=2.2823 | MulticlassF1Score=0.8758
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2760 | MulticlassF1Score=0.8779
# Batch-30 : CrossEntropyLoss=2.2855 | MulticlassF1Score=0.8794
# Batch-45 : CrossEntropyLoss=2.2886 | MulticlassF1Score=0.8788
# Batch-60 : CrossEntropyLoss=2.2884 | MulticlassF1Score=0.8785
# Batch-63 : CrossEntropyLoss=2.2804 | MulticlassF1Score=0.8786
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2865 | Mean MulticlassF1Score = 0.8650
# Validation : Mean CrossEntropyLoss = 2.2854 | Mean MulticlassF1Score = 0.8792
# ================================================================================
#
# EPOCH-10
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2840 | MulticlassF1Score=0.8847
# Batch-30 : CrossEntropyLoss=2.2898 | MulticlassF1Score=0.8862
# Batch-45 : CrossEntropyLoss=2.2782 | MulticlassF1Score=0.8863
# Batch-60 : CrossEntropyLoss=2.2827 | MulticlassF1Score=0.8875
# Batch-75 : CrossEntropyLoss=2.2811 | MulticlassF1Score=0.8875
# Batch-90 : CrossEntropyLoss=2.2772 | MulticlassF1Score=0.8885
# Batch-105: CrossEntropyLoss=2.2820 | MulticlassF1Score=0.8886
# Batch-120: CrossEntropyLoss=2.2846 | MulticlassF1Score=0.8887
# Batch-135: CrossEntropyLoss=2.2779 | MulticlassF1Score=0.8893
# Batch-150: CrossEntropyLoss=2.2771 | MulticlassF1Score=0.8900
# Batch-165: CrossEntropyLoss=2.2877 | MulticlassF1Score=0.8903
# Batch-180: CrossEntropyLoss=2.2894 | MulticlassF1Score=0.8900
# Batch-195: CrossEntropyLoss=2.2900 | MulticlassF1Score=0.8900
# Batch-210: CrossEntropyLoss=2.2752 | MulticlassF1Score=0.8901
# Batch-225: CrossEntropyLoss=2.2837 | MulticlassF1Score=0.8899
# Batch-226: CrossEntropyLoss=2.2872 | MulticlassF1Score=0.8899
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2925 | MulticlassF1Score=0.8778
# Batch-30 : CrossEntropyLoss=2.2820 | MulticlassF1Score=0.8791
# Batch-45 : CrossEntropyLoss=2.2816 | MulticlassF1Score=0.8795
# Batch-60 : CrossEntropyLoss=2.2779 | MulticlassF1Score=0.8813
# Batch-63 : CrossEntropyLoss=2.2835 | MulticlassF1Score=0.8814
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2821 | Mean MulticlassF1Score = 0.8881
# Validation : Mean CrossEntropyLoss = 2.2845 | Mean MulticlassF1Score = 0.8789
# ================================================================================
#
# EPOCH-11
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2747 | MulticlassF1Score=0.8922
# Batch-30 : CrossEntropyLoss=2.2838 | MulticlassF1Score=0.8939
# Batch-45 : CrossEntropyLoss=2.2812 | MulticlassF1Score=0.8939
# Batch-60 : CrossEntropyLoss=2.2844 | MulticlassF1Score=0.8932
# Batch-75 : CrossEntropyLoss=2.2913 | MulticlassF1Score=0.8924
# Batch-90 : CrossEntropyLoss=2.2860 | MulticlassF1Score=0.8919
# Batch-105: CrossEntropyLoss=2.2757 | MulticlassF1Score=0.8914
# Batch-120: CrossEntropyLoss=2.2713 | MulticlassF1Score=0.8922
# Batch-135: CrossEntropyLoss=2.2772 | MulticlassF1Score=0.8924
# Batch-150: CrossEntropyLoss=2.2754 | MulticlassF1Score=0.8924
# Batch-165: CrossEntropyLoss=2.2847 | MulticlassF1Score=0.8921
# Batch-180: CrossEntropyLoss=2.2746 | MulticlassF1Score=0.8923
# Batch-195: CrossEntropyLoss=2.2857 | MulticlassF1Score=0.8924
# Batch-210: CrossEntropyLoss=2.2769 | MulticlassF1Score=0.8925
# Batch-225: CrossEntropyLoss=2.2755 | MulticlassF1Score=0.8926
# Batch-226: CrossEntropyLoss=2.2769 | MulticlassF1Score=0.8926
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2869 | MulticlassF1Score=0.8773
# Batch-30 : CrossEntropyLoss=2.2789 | MulticlassF1Score=0.8794
# Batch-45 : CrossEntropyLoss=2.2815 | MulticlassF1Score=0.8804
# Batch-60 : CrossEntropyLoss=2.2824 | MulticlassF1Score=0.8820
# Batch-63 : CrossEntropyLoss=2.2886 | MulticlassF1Score=0.8817
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2811 | Mean MulticlassF1Score = 0.8924
# Validation : Mean CrossEntropyLoss = 2.2843 | Mean MulticlassF1Score = 0.8796
# ================================================================================
#
# EPOCH-12
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2801 | MulticlassF1Score=0.8957
# Batch-30 : CrossEntropyLoss=2.2763 | MulticlassF1Score=0.8967
# Batch-45 : CrossEntropyLoss=2.2782 | MulticlassF1Score=0.8957
# Batch-60 : CrossEntropyLoss=2.2831 | MulticlassF1Score=0.8940
# Batch-75 : CrossEntropyLoss=2.2837 | MulticlassF1Score=0.8950
# Batch-90 : CrossEntropyLoss=2.2767 | MulticlassF1Score=0.8952
# Batch-105: CrossEntropyLoss=2.2791 | MulticlassF1Score=0.8958
# Batch-120: CrossEntropyLoss=2.2749 | MulticlassF1Score=0.8952
# Batch-135: CrossEntropyLoss=2.2846 | MulticlassF1Score=0.8956
# Batch-150: CrossEntropyLoss=2.2869 | MulticlassF1Score=0.8958
# Batch-165: CrossEntropyLoss=2.2722 | MulticlassF1Score=0.8956
# Batch-180: CrossEntropyLoss=2.2879 | MulticlassF1Score=0.8955
# Batch-195: CrossEntropyLoss=2.2833 | MulticlassF1Score=0.8954
# Batch-210: CrossEntropyLoss=2.2802 | MulticlassF1Score=0.8952
# Batch-225: CrossEntropyLoss=2.2796 | MulticlassF1Score=0.8952
# Batch-226: CrossEntropyLoss=2.2778 | MulticlassF1Score=0.8952
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2777 | MulticlassF1Score=0.8829
# Batch-30 : CrossEntropyLoss=2.2832 | MulticlassF1Score=0.8839
# Batch-45 : CrossEntropyLoss=2.2891 | MulticlassF1Score=0.8843
# Batch-60 : CrossEntropyLoss=2.2806 | MulticlassF1Score=0.8833
# Batch-63 : CrossEntropyLoss=2.2754 | MulticlassF1Score=0.8835
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2803 | Mean MulticlassF1Score = 0.8953
# Validation : Mean CrossEntropyLoss = 2.2837 | Mean MulticlassF1Score = 0.8810
# ================================================================================
#
# EPOCH-13
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2758 | MulticlassF1Score=0.8945
# Batch-30 : CrossEntropyLoss=2.2795 | MulticlassF1Score=0.8938
# Batch-45 : CrossEntropyLoss=2.2769 | MulticlassF1Score=0.8964
# Batch-60 : CrossEntropyLoss=2.2784 | MulticlassF1Score=0.8962
# Batch-75 : CrossEntropyLoss=2.2750 | MulticlassF1Score=0.8968
# Batch-90 : CrossEntropyLoss=2.2811 | MulticlassF1Score=0.8970
# Batch-105: CrossEntropyLoss=2.2759 | MulticlassF1Score=0.8973
# Batch-120: CrossEntropyLoss=2.2841 | MulticlassF1Score=0.8971
# Batch-135: CrossEntropyLoss=2.2729 | MulticlassF1Score=0.8975
# Batch-150: CrossEntropyLoss=2.2776 | MulticlassF1Score=0.8974
# Batch-165: CrossEntropyLoss=2.2847 | MulticlassF1Score=0.8972
# Batch-180: CrossEntropyLoss=2.2778 | MulticlassF1Score=0.8971
# Batch-195: CrossEntropyLoss=2.2821 | MulticlassF1Score=0.8968
# Batch-210: CrossEntropyLoss=2.2788 | MulticlassF1Score=0.8967
# Batch-225: CrossEntropyLoss=2.2741 | MulticlassF1Score=0.8969
# Batch-226: CrossEntropyLoss=2.2732 | MulticlassF1Score=0.8969
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2790 | MulticlassF1Score=0.8907
# Batch-30 : CrossEntropyLoss=2.2862 | MulticlassF1Score=0.8870
# Batch-45 : CrossEntropyLoss=2.2823 | MulticlassF1Score=0.8859
# Batch-60 : CrossEntropyLoss=2.2799 | MulticlassF1Score=0.8854
# Batch-63 : CrossEntropyLoss=2.2875 | MulticlassF1Score=0.8852
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2796 | Mean MulticlassF1Score = 0.8964
# Validation : Mean CrossEntropyLoss = 2.2831 | Mean MulticlassF1Score = 0.8885
# ================================================================================
#
# EPOCH-14
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2809 | MulticlassF1Score=0.9022
# Batch-30 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.8992
# Batch-45 : CrossEntropyLoss=2.2753 | MulticlassF1Score=0.8985
# Batch-60 : CrossEntropyLoss=2.2799 | MulticlassF1Score=0.8992
# Batch-75 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9003
# Batch-90 : CrossEntropyLoss=2.2785 | MulticlassF1Score=0.8995
# Batch-105: CrossEntropyLoss=2.2860 | MulticlassF1Score=0.8988
# Batch-120: CrossEntropyLoss=2.2818 | MulticlassF1Score=0.8987
# Batch-135: CrossEntropyLoss=2.2780 | MulticlassF1Score=0.8986
# Batch-150: CrossEntropyLoss=2.2861 | MulticlassF1Score=0.8983
# Batch-165: CrossEntropyLoss=2.2827 | MulticlassF1Score=0.8980
# Batch-180: CrossEntropyLoss=2.2752 | MulticlassF1Score=0.8985
# Batch-195: CrossEntropyLoss=2.2844 | MulticlassF1Score=0.8984
# Batch-210: CrossEntropyLoss=2.2770 | MulticlassF1Score=0.8983
# Batch-225: CrossEntropyLoss=2.2747 | MulticlassF1Score=0.8984
# Batch-226: CrossEntropyLoss=2.2825 | MulticlassF1Score=0.8984
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2861 | MulticlassF1Score=0.8875
# Batch-30 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.8838
# Batch-45 : CrossEntropyLoss=2.2773 | MulticlassF1Score=0.8848
# Batch-60 : CrossEntropyLoss=2.2853 | MulticlassF1Score=0.8849
# Batch-63 : CrossEntropyLoss=2.2905 | MulticlassF1Score=0.8848
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2791 | Mean MulticlassF1Score = 0.8990
# Validation : Mean CrossEntropyLoss = 2.2832 | Mean MulticlassF1Score = 0.8847
# ================================================================================
#
# EPOCH-15
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2872 | MulticlassF1Score=0.8994
# Batch-30 : CrossEntropyLoss=2.2808 | MulticlassF1Score=0.8992
# Batch-45 : CrossEntropyLoss=2.2813 | MulticlassF1Score=0.8985
# Batch-60 : CrossEntropyLoss=2.2747 | MulticlassF1Score=0.8987
# Batch-75 : CrossEntropyLoss=2.2710 | MulticlassF1Score=0.8991
# Batch-90 : CrossEntropyLoss=2.2778 | MulticlassF1Score=0.8987
# Batch-105: CrossEntropyLoss=2.2829 | MulticlassF1Score=0.8995
# Batch-120: CrossEntropyLoss=2.2799 | MulticlassF1Score=0.8997
# Batch-135: CrossEntropyLoss=2.2771 | MulticlassF1Score=0.8998
# Batch-150: CrossEntropyLoss=2.2806 | MulticlassF1Score=0.8996
# Batch-165: CrossEntropyLoss=2.2799 | MulticlassF1Score=0.8994
# Batch-180: CrossEntropyLoss=2.2753 | MulticlassF1Score=0.8995
# Batch-195: CrossEntropyLoss=2.2793 | MulticlassF1Score=0.8998
# Batch-210: CrossEntropyLoss=2.2746 | MulticlassF1Score=0.8999
# Batch-225: CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9001
# Batch-226: CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9001
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2776 | MulticlassF1Score=0.8873
# Batch-30 : CrossEntropyLoss=2.2819 | MulticlassF1Score=0.8884
# Batch-45 : CrossEntropyLoss=2.2821 | MulticlassF1Score=0.8894
# Batch-60 : CrossEntropyLoss=2.2795 | MulticlassF1Score=0.8892
# Batch-63 : CrossEntropyLoss=2.2898 | MulticlassF1Score=0.8889
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2785 | Mean MulticlassF1Score = 0.8994
# Validation : Mean CrossEntropyLoss = 2.2819 | Mean MulticlassF1Score = 0.8887
# ================================================================================
#
# EPOCH-16
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9015
# Batch-30 : CrossEntropyLoss=2.2759 | MulticlassF1Score=0.9040
# Batch-45 : CrossEntropyLoss=2.2807 | MulticlassF1Score=0.9026
# Batch-60 : CrossEntropyLoss=2.2753 | MulticlassF1Score=0.9024
# Batch-75 : CrossEntropyLoss=2.2758 | MulticlassF1Score=0.9032
# Batch-90 : CrossEntropyLoss=2.2753 | MulticlassF1Score=0.9029
# Batch-105: CrossEntropyLoss=2.2827 | MulticlassF1Score=0.9030
# Batch-120: CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9032
# Batch-135: CrossEntropyLoss=2.2819 | MulticlassF1Score=0.9032
# Batch-150: CrossEntropyLoss=2.2772 | MulticlassF1Score=0.9034
# Batch-165: CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9038
# Batch-180: CrossEntropyLoss=2.2766 | MulticlassF1Score=0.9043
# Batch-195: CrossEntropyLoss=2.2784 | MulticlassF1Score=0.9042
# Batch-210: CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9045
# Batch-225: CrossEntropyLoss=2.2799 | MulticlassF1Score=0.9046
# Batch-226: CrossEntropyLoss=2.2766 | MulticlassF1Score=0.9046
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2780 | MulticlassF1Score=0.8899
# Batch-30 : CrossEntropyLoss=2.2730 | MulticlassF1Score=0.8902
# Batch-45 : CrossEntropyLoss=2.2787 | MulticlassF1Score=0.8911
# Batch-60 : CrossEntropyLoss=2.2755 | MulticlassF1Score=0.8918
# Batch-63 : CrossEntropyLoss=2.2788 | MulticlassF1Score=0.8918
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2772 | Mean MulticlassF1Score = 0.9033
# Validation : Mean CrossEntropyLoss = 2.2811 | Mean MulticlassF1Score = 0.8913
# ================================================================================
#
# EPOCH-17
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9118
# Batch-30 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9098
# Batch-45 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9079
# Batch-60 : CrossEntropyLoss=2.2824 | MulticlassF1Score=0.9082
# Batch-75 : CrossEntropyLoss=2.2747 | MulticlassF1Score=0.9073
# Batch-90 : CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9066
# Batch-105: CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9064
# Batch-120: CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9064
# Batch-135: CrossEntropyLoss=2.2827 | MulticlassF1Score=0.9065
# Batch-150: CrossEntropyLoss=2.2822 | MulticlassF1Score=0.9064
# Batch-165: CrossEntropyLoss=2.2776 | MulticlassF1Score=0.9065
# Batch-180: CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9067
# Batch-195: CrossEntropyLoss=2.2814 | MulticlassF1Score=0.9068
# Batch-210: CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9070
# Batch-225: CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9068
# Batch-226: CrossEntropyLoss=2.2767 | MulticlassF1Score=0.9068
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2773 | MulticlassF1Score=0.8917
# Batch-30 : CrossEntropyLoss=2.2810 | MulticlassF1Score=0.8893
# Batch-45 : CrossEntropyLoss=2.2763 | MulticlassF1Score=0.8937
# Batch-60 : CrossEntropyLoss=2.2734 | MulticlassF1Score=0.8926
# Batch-63 : CrossEntropyLoss=2.2769 | MulticlassF1Score=0.8922
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2765 | Mean MulticlassF1Score = 0.9076
# Validation : Mean CrossEntropyLoss = 2.2808 | Mean MulticlassF1Score = 0.8916
# ================================================================================
#
# EPOCH-18
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2751 | MulticlassF1Score=0.9120
# Batch-30 : CrossEntropyLoss=2.2840 | MulticlassF1Score=0.9062
# Batch-45 : CrossEntropyLoss=2.2819 | MulticlassF1Score=0.9086
# Batch-60 : CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9083
# Batch-75 : CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9087
# Batch-90 : CrossEntropyLoss=2.2836 | MulticlassF1Score=0.9081
# Batch-105: CrossEntropyLoss=2.2765 | MulticlassF1Score=0.9081
# Batch-120: CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9083
# Batch-135: CrossEntropyLoss=2.2751 | MulticlassF1Score=0.9077
# Batch-150: CrossEntropyLoss=2.2779 | MulticlassF1Score=0.9083
# Batch-165: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9088
# Batch-180: CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9090
# Batch-195: CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9088
# Batch-210: CrossEntropyLoss=2.2770 | MulticlassF1Score=0.9090
# Batch-225: CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9090
# Batch-226: CrossEntropyLoss=2.2848 | MulticlassF1Score=0.9090
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2842 | MulticlassF1Score=0.8952
# Batch-30 : CrossEntropyLoss=2.2778 | MulticlassF1Score=0.8963
# Batch-45 : CrossEntropyLoss=2.2812 | MulticlassF1Score=0.8942
# Batch-60 : CrossEntropyLoss=2.2873 | MulticlassF1Score=0.8941
# Batch-63 : CrossEntropyLoss=2.2792 | MulticlassF1Score=0.8941
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2758 | Mean MulticlassF1Score = 0.9088
# Validation : Mean CrossEntropyLoss = 2.2802 | Mean MulticlassF1Score = 0.8954
# ================================================================================
#
# EPOCH-19
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9094
# Batch-30 : CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9122
# Batch-45 : CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9117
# Batch-60 : CrossEntropyLoss=2.2770 | MulticlassF1Score=0.9108
# Batch-75 : CrossEntropyLoss=2.2853 | MulticlassF1Score=0.9097
# Batch-90 : CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9102
# Batch-105: CrossEntropyLoss=2.2765 | MulticlassF1Score=0.9108
# Batch-120: CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9109
# Batch-135: CrossEntropyLoss=2.2801 | MulticlassF1Score=0.9106
# Batch-150: CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9104
# Batch-165: CrossEntropyLoss=2.2798 | MulticlassF1Score=0.9104
# Batch-180: CrossEntropyLoss=2.2813 | MulticlassF1Score=0.9107
# Batch-195: CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9106
# Batch-210: CrossEntropyLoss=2.2758 | MulticlassF1Score=0.9108
# Batch-225: CrossEntropyLoss=2.2826 | MulticlassF1Score=0.9105
# Batch-226: CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9105
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2808 | MulticlassF1Score=0.8884
# Batch-30 : CrossEntropyLoss=2.2820 | MulticlassF1Score=0.8921
# Batch-45 : CrossEntropyLoss=2.2869 | MulticlassF1Score=0.8940
# Batch-60 : CrossEntropyLoss=2.2749 | MulticlassF1Score=0.8942
# Batch-63 : CrossEntropyLoss=2.2859 | MulticlassF1Score=0.8944
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2752 | Mean MulticlassF1Score = 0.9105
# Validation : Mean CrossEntropyLoss = 2.2801 | Mean MulticlassF1Score = 0.8905
# ================================================================================
#
# EPOCH-20
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9123
# Batch-30 : CrossEntropyLoss=2.2787 | MulticlassF1Score=0.9102
# Batch-45 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9109
# Batch-60 : CrossEntropyLoss=2.2808 | MulticlassF1Score=0.9100
# Batch-75 : CrossEntropyLoss=2.2772 | MulticlassF1Score=0.9111
# Batch-90 : CrossEntropyLoss=2.2769 | MulticlassF1Score=0.9110
# Batch-105: CrossEntropyLoss=2.2779 | MulticlassF1Score=0.9108
# Batch-120: CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9108
# Batch-135: CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9111
# Batch-150: CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9116
# Batch-165: CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9116
# Batch-180: CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9125
# Batch-195: CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9141
# Batch-210: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9154
# Batch-225: CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9164
# Batch-226: CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9166
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2792 | MulticlassF1Score=0.9185
# Batch-30 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9184
# Batch-45 : CrossEntropyLoss=2.2758 | MulticlassF1Score=0.9170
# Batch-60 : CrossEntropyLoss=2.2810 | MulticlassF1Score=0.9161
# Batch-63 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9165
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2734 | Mean MulticlassF1Score = 0.9122
# Validation : Mean CrossEntropyLoss = 2.2734 | Mean MulticlassF1Score = 0.9176
# ================================================================================
#
# EPOCH-21
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9387
# Batch-30 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9374
# Batch-45 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9369
# Batch-60 : CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9378
# Batch-75 : CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9375
# Batch-90 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9368
# Batch-105: CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9368
# Batch-120: CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9362
# Batch-135: CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9360
# Batch-150: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9363
# Batch-165: CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9365
# Batch-180: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9370
# Batch-195: CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9369
# Batch-210: CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9372
# Batch-225: CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9374
# Batch-226: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9374
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2747 | MulticlassF1Score=0.9225
# Batch-30 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9209
# Batch-45 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9220
# Batch-60 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9225
# Batch-63 : CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9226
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2671 | Mean MulticlassF1Score = 0.9374
# Validation : Mean CrossEntropyLoss = 2.2717 | Mean MulticlassF1Score = 0.9228
# ================================================================================
#
# EPOCH-22
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9410
# Batch-30 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9411
# Batch-45 : CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9412
# Batch-60 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9411
# Batch-75 : CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9411
# Batch-90 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9410
# Batch-105: CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9409
# Batch-120: CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9410
# Batch-135: CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9411
# Batch-150: CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9408
# Batch-165: CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9407
# Batch-180: CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9409
# Batch-195: CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9407
# Batch-210: CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9409
# Batch-225: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9408
# Batch-226: CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9408
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9231
# Batch-30 : CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9216
# Batch-45 : CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9236
# Batch-60 : CrossEntropyLoss=2.2769 | MulticlassF1Score=0.9234
# Batch-63 : CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9236
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2660 | Mean MulticlassF1Score = 0.9409
# Validation : Mean CrossEntropyLoss = 2.2712 | Mean MulticlassF1Score = 0.9235
# ================================================================================
#
# EPOCH-23
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9414
# Batch-30 : CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9429
# Batch-45 : CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9423
# Batch-60 : CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9427
# Batch-75 : CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9427
# Batch-90 : CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9431
# Batch-105: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9431
# Batch-120: CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9433
# Batch-135: CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9427
# Batch-150: CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9429
# Batch-165: CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9427
# Batch-180: CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9427
# Batch-195: CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9425
# Batch-210: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9424
# Batch-225: CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9423
# Batch-226: CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9423
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9276
# Batch-30 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9247
# Batch-45 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9247
# Batch-60 : CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9248
# Batch-63 : CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9249
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2654 | Mean MulticlassF1Score = 0.9426
# Validation : Mean CrossEntropyLoss = 2.2708 | Mean MulticlassF1Score = 0.9256
# ================================================================================
#
# EPOCH-24
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9426
# Batch-30 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9428
# Batch-45 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9412
# Batch-60 : CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9429
# Batch-75 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9431
# Batch-90 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9431
# Batch-105: CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9430
# Batch-120: CrossEntropyLoss=2.2622 | MulticlassF1Score=0.9429
# Batch-135: CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9431
# Batch-150: CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9428
# Batch-165: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9430
# Batch-180: CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9430
# Batch-195: CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9430
# Batch-210: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9430
# Batch-225: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9430
# Batch-226: CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9430
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9244
# Batch-30 : CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9232
# Batch-45 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9237
# Batch-60 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9239
# Batch-63 : CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9240
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2652 | Mean MulticlassF1Score = 0.9428
# Validation : Mean CrossEntropyLoss = 2.2710 | Mean MulticlassF1Score = 0.9228
# ================================================================================
#
# EPOCH-25
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9422
# Batch-30 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9413
# Batch-45 : CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9414
# Batch-60 : CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9427
# Batch-75 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9429
# Batch-90 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9436
# Batch-105: CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9439
# Batch-120: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9442
# Batch-135: CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9437
# Batch-150: CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9437
# Batch-165: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9437
# Batch-180: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9436
# Batch-195: CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9436
# Batch-210: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9437
# Batch-225: CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9438
# Batch-226: CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9438
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9245
# Batch-30 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9255
# Batch-45 : CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9251
# Batch-60 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9252
# Batch-63 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9249
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2649 | Mean MulticlassF1Score = 0.9431
# Validation : Mean CrossEntropyLoss = 2.2708 | Mean MulticlassF1Score = 0.9261
# ================================================================================
#
# EPOCH-26
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9430
# Batch-30 : CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9448
# Batch-45 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9449
# Batch-60 : CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9456
# Batch-75 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9454
# Batch-90 : CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9446
# Batch-105: CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9446
# Batch-120: CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9444
# Batch-135: CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9443
# Batch-150: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9445
# Batch-165: CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9441
# Batch-180: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9442
# Batch-195: CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9440
# Batch-210: CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9440
# Batch-225: CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9443
# Batch-226: CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9443
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9269
# Batch-30 : CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9238
# Batch-45 : CrossEntropyLoss=2.2784 | MulticlassF1Score=0.9234
# Batch-60 : CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9242
# Batch-63 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9245
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2647 | Mean MulticlassF1Score = 0.9444
# Validation : Mean CrossEntropyLoss = 2.2709 | Mean MulticlassF1Score = 0.9255
# ================================================================================
#
# EPOCH-27
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9453
# Batch-30 : CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9422
# Batch-45 : CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9417
# Batch-60 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9430
# Batch-75 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9436
# Batch-90 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9443
# Batch-105: CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9444
# Batch-120: CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9443
# Batch-135: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9446
# Batch-150: CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9446
# Batch-165: CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9447
# Batch-180: CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9446
# Batch-195: CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9448
# Batch-210: CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9445
# Batch-225: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9444
# Batch-226: CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9444
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9235
# Batch-30 : CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9246
# Batch-45 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9251
# Batch-60 : CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9256
# Batch-63 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9255
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2646 | Mean MulticlassF1Score = 0.9437
# Validation : Mean CrossEntropyLoss = 2.2705 | Mean MulticlassF1Score = 0.9234
# ================================================================================
#
# EPOCH-28
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9444
# Batch-30 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9449
# Batch-45 : CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9453
# Batch-60 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9458
# Batch-75 : CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9455
# Batch-90 : CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9455
# Batch-105: CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9453
# Batch-120: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9450
# Batch-135: CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9452
# Batch-150: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9451
# Batch-165: CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9449
# Batch-180: CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9446
# Batch-195: CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9447
# Batch-210: CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9448
# Batch-225: CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9449
# Batch-226: CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9449
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9247
# Batch-30 : CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9241
# Batch-45 : CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9234
# Batch-60 : CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9239
# Batch-63 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9247
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2645 | Mean MulticlassF1Score = 0.9450
# Validation : Mean CrossEntropyLoss = 2.2708 | Mean MulticlassF1Score = 0.9247
# ================================================================================
#
# EPOCH-29
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9454
# Batch-30 : CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9465
# Batch-45 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9453
# Batch-60 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9447
# Batch-75 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9449
# Batch-90 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9446
# Batch-105: CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9453
# Batch-120: CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9456
# Batch-135: CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9455
# Batch-150: CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9452
# Batch-165: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9454
# Batch-180: CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9453
# ...
# Batch-45 : CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9449
# Batch-60 : CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9443
# Batch-63 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9439
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2583 | Mean MulticlassF1Score = 0.9672
# Validation : Mean CrossEntropyLoss = 2.2648 | Mean MulticlassF1Score = 0.9450
# Patience = 4/50❗
# ================================================================================
#
# EPOCH-42
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9679
# Batch-30 : CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9676
# Batch-45 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9675
# Batch-60 : CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9672
# Batch-75 : CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9663
# Batch-90 : CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9660
# Batch-105: CrossEntropyLoss=2.2543 | MulticlassF1Score=0.9661
# Batch-120: CrossEntropyLoss=2.2539 | MulticlassF1Score=0.9665
# Batch-135: CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9660
# Batch-150: CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9659
# Batch-165: CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9660
# Batch-180: CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9659
# Batch-195: CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9659
# Batch-210: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9659
# Batch-225: CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9658
# Batch-226: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9658
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9482
# Batch-30 : CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9491
# Batch-45 : CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9480
# Batch-60 : CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9466
# Batch-63 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9467
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2581 | Mean MulticlassF1Score = 0.9665
# Validation : Mean CrossEntropyLoss = 2.2641 | Mean MulticlassF1Score = 0.9477
# ================================================================================
#
# EPOCH-43
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9699
# Batch-30 : CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9684
# Batch-45 : CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9683
# Batch-60 : CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9687
# Batch-75 : CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9685
# Batch-90 : CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9686
# Batch-105: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9682
# Batch-120: CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9684
# Batch-135: CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9682
# Batch-150: CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9685
# Batch-165: CrossEntropyLoss=2.2603 | MulticlassF1Score=0.9681
# Batch-180: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9681
# Batch-195: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9681
# Batch-210: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9683
# Batch-225: CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9683
# Batch-226: CrossEntropyLoss=2.2544 | MulticlassF1Score=0.9683
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9454
# Batch-30 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9472
# Batch-45 : CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9457
# Batch-60 : CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9460
# Batch-63 : CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9462
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2572 | Mean MulticlassF1Score = 0.9685
# Validation : Mean CrossEntropyLoss = 2.2641 | Mean MulticlassF1Score = 0.9454
# ================================================================================
#
# EPOCH-44
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9669
# Batch-30 : CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9684
# Batch-45 : CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9681
# Batch-60 : CrossEntropyLoss=2.2528 | MulticlassF1Score=0.9685
# Batch-75 : CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9692
# Batch-90 : CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9692
# Batch-105: CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9689
# Batch-120: CrossEntropyLoss=2.2541 | MulticlassF1Score=0.9692
# Batch-135: CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9693
# Batch-150: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9690
# Batch-165: CrossEntropyLoss=2.2611 | MulticlassF1Score=0.9688
# Batch-180: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9691
# Batch-195: CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9691
# Batch-210: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9692
# Batch-225: CrossEntropyLoss=2.2542 | MulticlassF1Score=0.9692
# Batch-226: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9692
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9428
# Batch-30 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9463
# Batch-45 : CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9478
# Batch-60 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9460
# Batch-63 : CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9462
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2569 | Mean MulticlassF1Score = 0.9685
# Validation : Mean CrossEntropyLoss = 2.2641 | Mean MulticlassF1Score = 0.9464
# ================================================================================
#
# EPOCH-45
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9692
# Batch-30 : CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9680
# Batch-45 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9682
# Batch-60 : CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9691
# Batch-75 : CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9693
# Batch-90 : CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9692
# Batch-105: CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9691
# Batch-120: CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9693
# Batch-135: CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9694
# Batch-150: CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9695
# Batch-165: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9697
# Batch-180: CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9697
# Batch-195: CrossEntropyLoss=2.2538 | MulticlassF1Score=0.9697
# Batch-210: CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9697
# Batch-225: CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9697
# Batch-226: CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9697
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9452
# Batch-30 : CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9438
# Batch-45 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9454
# Batch-60 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9458
# Batch-63 : CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9460
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2567 | Mean MulticlassF1Score = 0.9690
# Validation : Mean CrossEntropyLoss = 2.2641 | Mean MulticlassF1Score = 0.9447
# ================================================================================
#
# EPOCH-46
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2534 | MulticlassF1Score=0.9714
# Batch-30 : CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9703
# Batch-45 : CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9696
# Batch-60 : CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9695
# Batch-75 : CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9689
# Batch-90 : CrossEntropyLoss=2.2516 | MulticlassF1Score=0.9689
# Batch-105: CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9693
# Batch-120: CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9692
# Batch-135: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9693
# Batch-150: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9695
# Batch-165: CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9696
# Batch-180: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9696
# Batch-195: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9695
# Batch-210: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9696
# Batch-225: CrossEntropyLoss=2.2522 | MulticlassF1Score=0.9698
# Batch-226: CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9698
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9413
# Batch-30 : CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9437
# Batch-45 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9462
# Batch-60 : CrossEntropyLoss=2.2611 | MulticlassF1Score=0.9464
# Batch-63 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9464
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2566 | Mean MulticlassF1Score = 0.9697
# Validation : Mean CrossEntropyLoss = 2.2640 | Mean MulticlassF1Score = 0.9447
# ================================================================================
#
# EPOCH-47
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9704
# Batch-30 : CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9709
# Batch-45 : CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9703
# Batch-60 : CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9705
# Batch-75 : CrossEntropyLoss=2.2541 | MulticlassF1Score=0.9711
# Batch-90 : CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9708
# Batch-105: CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9703
# Batch-120: CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9702
# Batch-135: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9703
# Batch-150: CrossEntropyLoss=2.2542 | MulticlassF1Score=0.9703
# Batch-165: CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9702
# Batch-180: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9702
# Batch-195: CrossEntropyLoss=2.2597 | MulticlassF1Score=0.9702
# Batch-210: CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9701
# Batch-225: CrossEntropyLoss=2.2538 | MulticlassF1Score=0.9700
# Batch-226: CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9700
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9445
# Batch-30 : CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9436
# Batch-45 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9443
# Batch-60 : CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9457
# Batch-63 : CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9461
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2566 | Mean MulticlassF1Score = 0.9702
# Validation : Mean CrossEntropyLoss = 2.2640 | Mean MulticlassF1Score = 0.9448
# ================================================================================
#
# EPOCH-48
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2526 | MulticlassF1Score=0.9703
# Batch-30 : CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9706
# Batch-45 : CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9714
# Batch-60 : CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9718
# Batch-75 : CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9712
# Batch-90 : CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9708
# Batch-105: CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9704
# Batch-120: CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9702
# Batch-135: CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9704
# Batch-150: CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9704
# Batch-165: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9702
# Batch-180: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9701
# Batch-195: CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9703
# Batch-210: CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9701
# Batch-225: CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9703
# Batch-226: CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9702
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9475
# Batch-30 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9472
# Batch-45 : CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9453
# Batch-60 : CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9464
# Batch-63 : CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9465
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2565 | Mean MulticlassF1Score = 0.9707
# Validation : Mean CrossEntropyLoss = 2.2639 | Mean MulticlassF1Score = 0.9468
# ================================================================================
#
# EPOCH-49
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9693
# Batch-30 : CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9703
# Batch-45 : CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9693
# Batch-60 : CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9696
# Batch-75 : CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9700
# Batch-90 : CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9697
# Batch-105: CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9699
# Batch-120: CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9700
# Batch-135: CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9701
# Batch-150: CrossEntropyLoss=2.2589 | MulticlassF1Score=0.9700
# Batch-165: CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9702
# Batch-180: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9702
# Batch-195: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9704
# Batch-210: CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9703
# Batch-225: CrossEntropyLoss=2.2533 | MulticlassF1Score=0.9704
# Batch-226: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9704
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9455
# Batch-30 : CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9485
# Batch-45 : CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9471
# Batch-60 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9465
# Batch-63 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9467
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2564 | Mean MulticlassF1Score = 0.9701
# Validation : Mean CrossEntropyLoss = 2.2639 | Mean MulticlassF1Score = 0.9467
# ================================================================================
#
# EPOCH-50
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2522 | MulticlassF1Score=0.9731
# Batch-30 : CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9703
# Batch-45 : CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9706
# Batch-60 : CrossEntropyLoss=2.2532 | MulticlassF1Score=0.9704
# Batch-75 : CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9701
# Batch-90 : CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9701
# Batch-105: CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9705
# Batch-120: CrossEntropyLoss=2.2529 | MulticlassF1Score=0.9706
# Batch-135: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9707
# Batch-150: CrossEntropyLoss=2.2533 | MulticlassF1Score=0.9704
# Batch-165: CrossEntropyLoss=2.2541 | MulticlassF1Score=0.9706
# Batch-180: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9704
# Batch-195: CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9704
# Batch-210: CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9703
# Batch-225: CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9705
# Batch-226: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9705
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9491
# Batch-30 : CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9474
# Batch-45 : CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9474
# Batch-60 : CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9464
# Batch-63 : CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9466
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2564 | Mean MulticlassF1Score = 0.9706
# Validation : Mean CrossEntropyLoss = 2.2639 | Mean MulticlassF1Score = 0.9475
# ================================================================================
#
# TRAINING SUMMARY
# Best CrossEntropyLoss training    : 2.2564
# Best CrossEntropyLoss training    : 2.2639
# Best MulticlassF1Score validation : 0.9706
# Best MulticlassF1Score validation : 0.9475
# Training duration                 : 2.5922 minutes.
# Training date                     : 2022-10-19 11:09:37.709109+08:00

# %% [markdown]
# ## End Training

# %% [markdown]
# # Evaluation

# %%
def evaluation(dataloader, model, criterion, metric):
    model.eval()
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)
            pred = rearrange(prob.argmax(dim=1).reshape(feature.shape[0], len(dataloader.dataset)), "s n -> n s")

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob.argmax(dim=1), actual_label.to(hyperparams.device))
            metric_score = metric.compute()

    return loss, metric_score, pred

train_dataloader = DataLoader(train_dataset, batch_size=len(train_dataset))
val_dataloader = DataLoader(val_dataset, batch_size=len(val_dataset))
test_dataloader = DataLoader(test_dataset, batch_size=len(test_dataset))

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
train_loss, train_f1_score, train_pred_label = evaluation(train_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_loss, val_f1_score, val_pred_label = evaluation(val_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
test_loss, test_f1_score, test_pred_label = evaluation(test_dataloader, model, criterion, metric)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9706, device='cuda:0'),
#  tensor(0.9466, device='cuda:0'),
#  tensor(0.9479, device='cuda:0'))

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9706, device='cuda:0'),
#  tensor(0.9466, device='cuda:0'),
#  tensor(0.9479, device='cuda:0'))

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns

def viz_evaluation(pred_label, actual_label, title):
    plt.figure(figsize=(15, 7), dpi=200)
    sns.heatmap(pred_label.detach().cpu() == actual_label, cbar=True, cmap="binary_r")
    plt.xlabel("Sentence Length")
    plt.ylabel("Sentence")
    plt.title(title)
    plt.savefig(f"{root_path}/heatmap_{title.lower()}.jpg", dpi=200)
    plt.show()

train_actual_label = train_dataloader.dataset.tensors[1]
val_actual_label = val_dataloader.dataset.tensors[1]
test_actual_label = test_dataloader.dataset.tensors[1]

viz_evaluation(train_pred_label, train_actual_label, f"Training (F1-Score: {(train_f1_score):.4f})")
viz_evaluation(val_pred_label, val_actual_label, f"Validation (F1-Score: {(val_f1_score):.4f})")
viz_evaluation(test_pred_label, test_actual_label, f"Test (F1-Score: {(test_f1_score):.4f})")

# %% [markdown]
# ## Confusion Matrix

# %%
def confusion_matrix(pred_class, actual_class, title, normalize=None):
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize=normalize)
    plt.figure(figsize=(20, 10), dpi=200)
    sns.heatmap(conf_mat(pred_class.detach().cpu(), actual_class), annot=True, fmt=".2g", xticklabels=list(label_to_idx.keys()), yticklabels=list(label_to_idx.keys()));
    plt.yticks(rotation=0)
    plt.title(title)
    plt.xlabel("Actual Class")
    plt.ylabel("Predict Class")
    plt.savefig(f"{root_path}/conf_matrix_{title.lower()}.jpg", dpi=200)

confusion_matrix(train_pred_label, train_actual_label, "Training", "pred")
confusion_matrix(val_pred_label,val_actual_label, "Validation", "pred")
confusion_matrix(test_pred_label, test_actual_label, "Test", "pred")
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 144 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)

# %% [markdown]
# ## Prediction Table

# %%
def number_wrong_pred_each_class(pred_class, actual_class):
    classes, count_class = actual_class.flatten().unique(return_counts=True)
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize="none")
    correct_pred_count_class = conf_mat(pred_class.detach().cpu(), actual_class).diag()
    
    correct_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (correct_pred_count_class))}
    wrong_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (count_class - correct_pred_count_class))}
    
    return correct_pred, wrong_pred

correct_pred, wrong_pred = number_wrong_pred_each_class(train_pred_label, train_actual_label)
print(f"| {'Number class'.ljust(14)} | {'Correct prediction'.ljust(12)} | {'Wrong prediction'.ljust(12)} |")
for (label_correct_pred, count_correct_pred), (label_wrong_pred, count_wrong_pred) in zip(correct_pred.items(), wrong_pred.items()):
    print(f"| {str(label_correct_pred).ljust(6)}: {str(count_correct_pred + count_wrong_pred).ljust(7)}| {label_correct_pred.ljust(6)}: {str(count_correct_pred).ljust(10)} | {label_wrong_pred.ljust(6)}: {str(count_wrong_pred).ljust(8)} |")
# Out:
# | Number class   | Correct prediction | Wrong prediction |
# | CC    : 5346   | CC    : 5201       | CC    : 145      |
# | CD    : 12730  | CD    : 12645      | CD    : 85       |
# | DT    : 269    | DT    : 0          | DT    : 269      |
# | FW    : 1614   | FW    : 1436       | FW    : 178      |
# | IN    : 15342  | IN    : 15239      | IN    : 103      |
# | JJ    : 6981   | JJ    : 6601       | JJ    : 380      |
# | MD    : 3799   | MD    : 3693       | MD    : 106      |
# | NEG   : 1118   | NEG   : 0          | NEG   : 1118     |
# | NN    : 44369  | NN    : 43984      | NN    : 385      |
# | NND   : 1047   | NND   : 878        | NND   : 169      |
# | NNP   : 25175  | NNP   : 24759      | NNP   : 416      |
# | OD    : 524    | OD    : 0          | OD    : 524      |
# | PR    : 3880   | PR    : 3821       | PR    : 59       |
# | PRP   : 5471   | PRP   : 5396       | PRP   : 75       |
# | RB    : 3477   | RB    : 3255       | RB    : 222      |
# | RP    : 141    | RP    : 0          | RP    : 141      |
# | SC    : 9455   | SC    : 9243       | SC    : 212      |
# | SYM   : 1551   | SYM   : 1503       | SYM   : 48       |
# | UH    : 21     | UH    : 12         | UH    : 9        |
# | VB    : 22950  | VB    : 22632      | VB    : 318      |
# | WH    : 184    | WH    : 0          | WH    : 184      |
# | X     : 279    | X     : 0          | X     : 279      |
# | Z     : 18960  | Z     : 18958      | Z     : 2        |
# | <PAD> : 407521 | <PAD> : 407521     | <PAD> : 0        |

# %%
train_actual_label[308], train_pred_label[308]
# Out:
# (tensor([ 8,  3, 12, 19,  8,  8,  8, 16, 19,  4, 10,  8, 10,  0,  4,  1,  8,  8,
#           8,  5,  4,  8, 10,  0, 10, 10, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23]),
#  tensor([ 8,  8, 12, 19,  8,  8,  5, 16, 19,  4, 10,  8, 10,  0,  4,  1,  8,  8,
#           8,  5,  4,  8, 10,  0, 10, 10, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23], device='cuda:0'))

# %%
train_actual_label[308] == train_pred_label[308].detach().cpu()
# Out:
# tensor([ True, False,  True,  True,  True,  True, False,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True])

# %% [markdown]
# ## OOV prediction is correct

# %%
def oov_flag_token(sentences, max_seq_len=hyperparams.max_seq_len):
    sent_copy = deepcopy(sentences)
    sent = []
    oov_flag = []
    
    for sentence in tqdm(sent_copy):
        for token in sentence:
            sent.append(token[2])
        
        for _ in range(max_seq_len- len(sentence)):
            sent.append(False)
        
        oov_flag.append(sent)
        sent = []
        
    return np.array(oov_flag)

train_oov_flag = oov_flag_token(train_sentences, max_seq_len=hyperparams.max_seq_len)
val_oov_flag = oov_flag_token(val_sentences, max_seq_len=hyperparams.max_seq_len)
test_oov_flag = oov_flag_token(test_sentences, max_seq_len=hyperparams.max_seq_len)

def pencentage_oov_pred_correct(pred_oov_flag, oov_flag_tensor):
    oov_correct_counter = 0
    oov_wrong_counter = 0

    for pred, oov_label in tqdm(zip(pred_oov_flag, oov_flag_tensor)):
        if pred == True and oov_label == True:
            oov_correct_counter += 1
        elif pred == False and oov_label == True:
            oov_wrong_counter += 1
        else:
            continue
            
    return oov_correct_counter, oov_wrong_counter

train_pred_oov_flag = (train_actual_label == train_pred_label.detach().cpu()).flatten()
val_pred_oov_flag = (val_actual_label == val_pred_label.detach().cpu()).flatten()
test_pred_oov_flag = (test_actual_label == test_pred_label.detach().cpu()).flatten()
train_oov_flag_tensor = torch.tensor(train_oov_flag).flatten()
val_oov_flag_tensor = torch.tensor(val_oov_flag).flatten()
test_oov_flag_tensor = torch.tensor(test_oov_flag).flatten()

train_oov_correct_counter, train_oov_wrong_counter = pencentage_oov_pred_correct(train_pred_oov_flag, train_oov_flag_tensor)
val_oov_correct_counter, val_oov_wrong_counter = pencentage_oov_pred_correct(val_pred_oov_flag, val_oov_flag_tensor)
test_oov_correct_counter, test_oov_wrong_counter = pencentage_oov_pred_correct(test_pred_oov_flag, test_oov_flag_tensor)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
def print_percentage_pred_oov(title, oov_correct_counter, oov_wrong_counter):
    print(f"{title}")
    print(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}")
    print(f"Correct prediction          : {oov_correct_counter}")
    print(f"Wrong prediction            : {oov_wrong_counter}")
    print(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n")
    
    with open(f"{root_path}/oov_summary.txt", "a") as f:
        f.write(f"{title}\n")
        f.write(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}\n")
        f.write(f"Correct prediction          : {oov_correct_counter}\n")
        f.write(f"Wrong prediction            : {oov_wrong_counter}\n")
        f.write(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n\n")

# %%
print_percentage_pred_oov("Training", train_oov_correct_counter, train_oov_wrong_counter)
print_percentage_pred_oov("Validation", val_oov_correct_counter, val_oov_wrong_counter)
print_percentage_pred_oov("Test", test_oov_correct_counter, test_oov_wrong_counter)
# Out:
# Training
# Number OOV token            : 11806
# Correct prediction          : 11101
# Wrong prediction            : 705
# Percentage correct oov pred : 94.02846010503134
#
# Validation
# Number OOV token            : 3366
# Correct prediction          : 2962
# Wrong prediction            : 404
# Percentage correct oov pred : 87.99762329174094
#
# Test
# Number OOV token            : 1390
# Correct prediction          : 1240
# Wrong prediction            : 150
# Percentage correct oov pred : 89.20863309352518

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(train_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(val_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(test_oov_flag, cmap=plt.cm.binary_r);
