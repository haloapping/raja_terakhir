# %% [markdown]
# # Import modules

# %%
import csv
import os
import pickle
import pytz
import torch
import timeit
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from copy import deepcopy
from datetime import datetime
from einops import rearrange
from itertools import chain
from time import time
from torch import nn, optim
from torchmetrics.classification import MulticlassAccuracy, MulticlassF1Score, MulticlassConfusionMatrix
from torch.optim import lr_scheduler
from tqdm.notebook import tqdm
from torch.utils.data import TensorDataset, DataLoader
from polyglot.mapping import Embedding, CaseExpander, DigitExpander

# %% [markdown]
# # Hyperparameters

# %%
class Hyperparams:
     def __init__(
        self,
        context_size=1,
        fold=5,
        max_seq_len=82,
        input_size=64,
        batch_size=32,
        num_hidden_layer=1,
        hidden_size=128,
        dropout=0,
        bias=True,
        output_size=24,
        shuffle=True,
        lr=0.005,
        batch_first=False,
        bidirectional=True,
        init_wb_with_kaiming_normal=True,
        n_epoch=50,
        patience=50,
        device="cuda" if torch.cuda.is_available() else "cpu"
    ):
        self.context_size = context_size
        self.fold = fold
        self.input_size = input_size
        self.max_seq_len = max_seq_len
        self.batch_size = batch_size
        self.num_hidden_layer = num_hidden_layer
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.output_size = output_size
        self.shuffle = shuffle
        self.lr = lr
        self.batch_first = batch_first
        self.bidirectional = bidirectional
        self.init_wb_with_kaiming_normal = init_wb_with_kaiming_normal
        self.n_epoch = n_epoch
        self.patience = patience
        self.device = device

hyperparams = Hyperparams()

# %% [markdown]
# # Dataset

# %%
id_pos_tag = pd.read_csv("../../../datasets/raw/Indonesian_Manually_Tagged_Corpus.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False) 
train = pd.read_csv(f"../../../datasets/raw/cv/train/train.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
val = pd.read_csv(f"../../../datasets/raw/cv/val/val.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
test = pd.read_csv(f"../../../datasets/raw/cv/test/test.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)

# %% [markdown]
# # Pre-trained Word Embedding

# %%
embeddings = Embedding.load("../../../word_embeddings/polyglot/idn_embeddings.tar.bz2")
embeddings.apply_expansion(DigitExpander)
embeddings.apply_expansion(CaseExpander)

oov_embeddings = pickle.load(open(f"../../../logs/comick/{hyperparams.context_size}_contexts/10-11-2022_10-29-38/oov_embedding_dict.pkl", "rb"))

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Add OOV Flag

# %%
def add_oov_flag(tokens, embeddings):
    oov_flags = []
    
    for token in tqdm(tokens):
        try:
            if token not in embeddings:
                oov_flags.append(True)
            else:
                oov_flags.append(False)
        except:
            oov_flags.append(False)
        
    return pd.DataFrame(oov_flags, columns=["is_oov"])

id_pos_tag_oov_flags = add_oov_flag(id_pos_tag["token"].values, embeddings)
train_oov_flags = add_oov_flag(train["token"].values, embeddings)
val_oov_flags = add_oov_flag(val["token"].values, embeddings)
test_oov_flags = add_oov_flag(test["token"].values, embeddings)
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/191905 [00:00<?, ?it/s]
#   0%|          | 0/21691 [00:00<?, ?it/s]
#   0%|          | 0/53056 [00:00<?, ?it/s]

# %% [markdown]
# ## Concate OOV Flag

# %%
id_pos_tag_df = pd.concat([id_pos_tag, id_pos_tag_oov_flags], axis=1)
train_df = pd.concat([train, train_oov_flags], axis=1)
val_df = pd.concat([val, val_oov_flags], axis=1)
test_df = pd.concat([test, test_oov_flags], axis=1)

# %% [markdown]
# ## Lowercase OOV Token

# %%
id_pos_tag_df['token'] = np.where(id_pos_tag_df['is_oov'] == True, id_pos_tag_df['token'].str.lower(), id_pos_tag_df['token'])
train_df['token'] = np.where(train_df['is_oov'] == True, train_df['token'].str.lower(), train_df['token'])
val_df['token'] = np.where(val_df['is_oov'] == True, val_df['token'].str.lower(), val_df['token'])
test_df['token'] = np.where(test_df['is_oov'] == True, test_df['token'].str.lower(), test_df['token'])

# %% [markdown]
# ## Embedding Dict, Index to Token and Token to Index

# %%
tokens = list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None))

def embedding_dict(tokens, embeddings, oov_embeddings):
    embedding = {}
    
    for token in tokens:
        if token[0] is not np.nan:
            if token[2] == False or token[0] in embeddings:
                embedding[token[0]] = embeddings[token[0]]
            else:
                embedding[token[0]] = oov_embeddings[token[0].lower()]

    return embedding

embedding_dict = embedding_dict(tokens, embeddings, oov_embeddings)
embedding_dict["<PAD>"] = embeddings["<PAD>"]
word_embeddings = nn.Embedding.from_pretrained(torch.FloatTensor(np.array(list(embedding_dict.values()))), padding_idx=list(embedding_dict.keys()).index("<PAD>"), freeze=True)

idx_to_token = {idx: token for idx, token in enumerate(list(embedding_dict.keys()))}
token_to_idx = {token: idx for idx, token in enumerate(list(embedding_dict.keys()))}

# %% [markdown]
# ## Token to Sentence

# %%
def make_sentence(tokens, max_length_sentence=hyperparams.max_seq_len):
    sentence = []
    sentences = []

    for token in tqdm(tokens):
        if token[0] is not np.nan:
            sentence.append(token)
        else:
            sentences.append(sentence[:max_length_sentence])
            sentence = []

    return sentences

all_sentence = make_sentence(list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
train_sentences = make_sentence(list(train_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
val_sentences = make_sentence(list(test_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
test_sentences = make_sentence(list(val_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/191905 [00:00<?, ?it/s]
#   0%|          | 0/53056 [00:00<?, ?it/s]
#   0%|          | 0/21691 [00:00<?, ?it/s]

# %% [markdown]
# ## Word Token, Padding, and Word token to Index

# %%
def tokenize_docs(docs, idx_token):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token[idx_token])
        sentences.append(new_sentence)
        new_sentence = []

    return sentences

def padding(docs, max_seq_len=hyperparams.max_seq_len, mode="post", val_pad="<PAD>"):
    docs = deepcopy(docs)
    doc_with_pad = []
    docs_with_pad = []

    for doc in tqdm(docs):
        if mode == "pre":
            for _ in range(max_seq_len - len(doc)):
                doc.insert(0, val_pad)
        elif mode == "post":
            for _ in range(max_seq_len - len(doc)):
                doc.append(val_pad)
        else:
            return f"Mode {mode} is not available, use instead 'pre' or 'post'."
        
        docs_with_pad.append(doc)
        
    return np.array(docs_with_pad)

def sent_to_idx(docs, token_to_idx):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token_to_idx[token])
        sentences.append(new_sentence)
        new_sentence = []

    return np.array(sentences)

def convert_feature_to_idx(docs, idx_token, token_to_idx, max_seq_len):
    sentences = tokenize_docs(docs, idx_token)
    sentences_with_pad = padding(sentences, max_seq_len=max_seq_len, mode="post", val_pad="<PAD>")
    sentences_to_idx = sent_to_idx(sentences_with_pad, token_to_idx)
    
    return sentences_to_idx

train_sentence_idxs = convert_feature_to_idx(train_sentences, 0, token_to_idx, hyperparams.max_seq_len)
val_sentence_idxs = convert_feature_to_idx(val_sentences, 0, token_to_idx, hyperparams.max_seq_len)
test_sentence_idxs = convert_feature_to_idx(test_sentences, 0, token_to_idx, hyperparams.max_seq_len)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]

# %% [markdown]
# ## Encode Class

# %%
classes = sorted(np.delete(id_pos_tag_df["tag"].unique(), 3))
idx_to_label = {idx: label for idx, label in enumerate(classes + ["<PAD>"])}
label_to_idx = {label: idx for idx, label in enumerate(classes + ["<PAD>"])}

def encode_class(docs, label_to_idx, seq_len=hyperparams.max_seq_len):
    class_idxs = []
    classes = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            class_idxs.append(label_to_idx[token[1]])
            
        for _ in range(seq_len - len(sentence)):
            class_idxs.append(label_to_idx["<PAD>"])
                
        classes.append(class_idxs)
        class_idxs = []

    return np.array(classes)
        
train_class_idxs = encode_class(train_sentences, label_to_idx)
val_class_idxs = encode_class(val_sentences, label_to_idx)
test_class_idxs = encode_class(test_sentences, label_to_idx)

print(f"Training shape   : {train_sentence_idxs.shape, train_class_idxs.shape}")
print(f"validation shape : {val_class_idxs.shape, val_class_idxs.shape}")
print(f"Test shape       : {test_sentence_idxs.shape, test_class_idxs.shape}")
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# Training shape   : ((7222, 82), (7222, 82))
# validation shape : ((2006, 82), (2006, 82))
# Test shape       : ((802, 82), (802, 82))

# %% [markdown]
# ## Note
#
# - Number of sentences = 10030
# - Train : 72% (7222)
# - Val   : 8% (802)
# - Test  : 20% (2006)

# %% [markdown]
# # Build Model

# %% [markdown]
# ## Feature and Actual Class

# %%
train_feature = torch.LongTensor(train_sentence_idxs)
val_feature = torch.LongTensor(val_sentence_idxs)
test_feature = torch.LongTensor(test_sentence_idxs)

train_class = torch.LongTensor(train_class_idxs)
val_class = torch.LongTensor(val_class_idxs)
test_class = torch.LongTensor(test_class_idxs)

# %%
train_feature.shape, val_feature.shape, test_feature.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %%
train_class.shape, val_class.shape, test_class.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %% [markdown]
# ## Tensor Dataset

# %%
train_dataset = TensorDataset(train_feature, train_class)
val_dataset = TensorDataset(val_feature, val_class)
test_dataset = TensorDataset(test_feature, test_class)

# %% [markdown]
# ## Dataloader

# %%
train_dataloader = DataLoader(train_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
val_dataloader = DataLoader(val_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
test_dataloader = DataLoader(test_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)

# %% [markdown]
# ## Model

# %%
class POSTagger(nn.Module):
    def __init__(
        self,
        input_size=hyperparams.input_size,
        hidden_size=hyperparams.hidden_size,
        dropout=hyperparams.dropout,
        bias=hyperparams.bias,
        num_layers=hyperparams.num_hidden_layer,
        output_size=hyperparams.output_size,
        batch_first=hyperparams.batch_first,
        bidirectional=hyperparams.bidirectional,
        init_wb_with_kaiming_normal=hyperparams.init_wb_with_kaiming_normal
    ):
        super(POSTagger, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.num_layers = num_layers
        self.output_size = output_size
        self.batch_first = batch_first
        self.bidirectional = bidirectional
                
        self.feature = nn.LSTM(
            input_size = self.input_size,
            hidden_size = self.hidden_size,
            bias = self.bias,
            dropout = self.dropout,
            num_layers = self.num_layers,
            batch_first = self.batch_first,
            bidirectional = self.bidirectional
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(in_features=2 * self.hidden_size if hyperparams.bidirectional else self.hidden_size, out_features=self.output_size, bias=self.bias),
            nn.Softmax(dim=-1)
        )
        
        if init_wb_with_kaiming_normal:
            self.init_wb()

    def init_wb(self):
        for module in self.modules():
            if isinstance(module, (nn.Linear, nn.LSTM)):
                for name, param in module.named_parameters():
                    if "weight" in name:
                        nn.init.kaiming_normal_(param)
                    else:
                        nn.init.kaiming_normal_(param.reshape(1, -1))
        
    def forward(self, feature, hidden=None):
        output, (hidden, memory) = self.feature(feature, None)
        prob = self.classifier(output)

        return prob
    
model = POSTagger().to(hyperparams.device)
model
# Out:
# POSTagger(
#   (feature): LSTM(64, 128, bidirectional=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=24, bias=True)
#     (1): Softmax(dim=-1)
#   )
# )

# %% [markdown]
# ## Optimizer, Criterion, and Metric

# %%
optimizer = optim.Adam(model.parameters(), lr=hyperparams.lr)
criterion = nn.CrossEntropyLoss().to(hyperparams.device)
train_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", verbose=True, factor=0.5)

# %%
sum(param.numel() for param in model.parameters() if param.requires_grad)
# Out:
# 204824

# %% [markdown]
# ## Training Step

# %%
def training_step(dataloader, model, optimizer, criterion, metric, scheduler=None):
    model.train()
    
    batch_losses = []
    batch_metric_scores = []
    
    for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
        # Forward Propagation
        feature = rearrange(feature, "n s -> s n")
        actual_label = rearrange(actual_label, "n s -> s n")
        embedding = word_embeddings(feature)
        
        prob = model(
            embedding.to(hyperparams.device),
            actual_label.to(hyperparams.device)
        )
        
        prob = prob.reshape(-1, prob.shape[-1])
        actual_label = actual_label.reshape(-1)

        loss = criterion(prob, actual_label.to(hyperparams.device))
        metric_score = metric(prob, actual_label.to(hyperparams.device))
        metric_score = metric.compute()
                
        if scheduler is not None:
            scheduler.step(loss)
        
        batch_losses.append(loss.item())
        batch_metric_scores.append(metric_score)
        
        if len(dataloader) < 10:
            if batch % 1 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
        else:
            if batch % 15 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            
        # Backward Propagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Validation Step

# %%
def validation_step(dataloader, model, criterion, metric):
    model.eval()
    
    batch_losses = []
    batch_metric_scores = []
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob, actual_label.to(hyperparams.device))
            metric_score = metric.compute()

            batch_losses.append(loss.item())
            batch_metric_scores.append(metric_score)
            
            if len(dataloader) < 10 and (batch % 1 == 0 or batch == len(dataloader)):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            else:
                if batch % 15 == 0 or batch == len(dataloader):
                    batch_name = "Batch-" + str(batch)
                    print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                    with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                        f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Looping Step

# %%
now = datetime.now(pytz.timezone("Asia/Ujung_Pandang"))
path_name = now.strftime("%m-%d-%Y_%H-%M-%S")
root_path = f"../../../logs/classifier/{hyperparams.context_size}_contexts/fold_0{hyperparams.fold}/{path_name}"
os.makedirs(root_path)

def looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric, n_epoch=hyperparams.n_epoch, patience=hyperparams.patience, monitor="loss"):    
    start_time = time()
    
    epoch_training_losses = []
    epoch_training_metric_scores = []
    epoch_val_losses = []
    epoch_val_metric_scores = []
    patience_counter = 0
    
    # Hyperparameters
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write(f"HYPERPARAMETERS\n")
        f.write(f"{'-' * 80}\n")
        for name, value in vars(hyperparams).items():
            f.write(f"{name}: {value}\n")
        
        f.write("\n\nTRAINING PROGRESS\n")
        f.write(f"{'-' * 80}\n")
    
    # Training Progress
    for epoch in range(1, n_epoch + 1):
        print(f"EPOCH-{epoch}")
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"EPOCH-{epoch}\n")
            f.write(f"Training Step\n")
            
        # Training Step
        print("Training Step")
        batch_training_losses, batch_training_metric_scores = training_step(train_dataloader, model, optimizer, criterion, train_metric, scheduler=None)
        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))

        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))
        epoch_training_losses.append(epoch_training_loss.item())

        epoch_training_metric_score = torch.mean(torch.FloatTensor(batch_training_metric_scores))
        epoch_training_metric_scores.append(epoch_training_metric_score.item())
        
        # Validation Step
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"\nValidation Step\n")
            
        print("\nValidation Step")
        batch_val_losses, batch_val_metric_scores = validation_step(val_dataloader, model, criterion, val_metric)
        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))

        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))
        epoch_val_losses.append(epoch_val_loss.item())

        epoch_val_metric_score = torch.mean(torch.FloatTensor(batch_val_metric_scores))
        epoch_val_metric_scores.append(epoch_val_metric_score.item())
        
        with open(f"{root_path}/training_history.txt", "a") as f:
            if monitor == "loss":
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_losses[-1] < epoch_training_losses[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
            else:
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_metric_scores[-1] > epoch_training_metric_scores[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗\n")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
                    
            print("=" * 80, end="\n\n")
            
            f.write(f"{'=' * 80}\n\n")
            
            if patience_counter == patience:
                print(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                
                f.write(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                break
        
        train_metric.reset()
        val_metric.reset()
        
    finish_time = time()
    
    # Training plot 
    fig, (ax_loss, ax_metric_score) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    fig.suptitle(f"Training with context size = {hyperparams.context_size}")

    ax_loss.set_title("Loss")
    ax_loss.set_xlabel("Epoch")
    ax_loss.set_ylabel("Score")
    ax_loss.plot(epoch_training_losses, "green", label="Training")
    ax_loss.plot(epoch_val_losses, "orange", label="Validation")
    ax_loss.legend()
    ax_loss.grid()

    ax_metric_score.set_title("F1 Score")
    ax_metric_score.set_xlabel("Epoch")
    ax_metric_score.set_ylabel("Score")
    ax_metric_score.plot(epoch_training_metric_scores, "green", label="Training")
    ax_metric_score.plot(epoch_val_metric_scores, "orange", label="Validation")
    ax_metric_score.legend()
    ax_metric_score.grid()

    plt.savefig(f"{root_path}/training_plot.jpg", dpi=200)                        
    
    print("TRAINING SUMMARY")
    name_best_training_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_training_metric = f"Best {str(train_metric).split('(')[0]} validation".ljust(34)
    name_best_validation_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_validation_metric = f"Best {str(val_metric).split('(')[0]} validation".ljust(34)
    name_training_time = f"Training duration".ljust(34)
    name_training_date = f"Training date".ljust(34)
    
    print(f"{name_best_training_loss}: {best_training_loss:.4f}")
    print(f"{name_best_validation_loss}: {best_val_loss:.4f}")
    print(f"{name_best_training_metric}: {best_training_metric:.4f}")
    print(f"{name_best_validation_metric}: {best_val_metric:.4f}")
    print(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.")
    print(f"{name_training_date}: {now}")
    
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write("\nTRAINING SUMMARY\n")
        f.write(f"{'-' * 80}\n")
        f.write(f"{name_best_training_loss}: {best_training_loss:.4f}\n")
        f.write(f"{name_best_validation_loss}: {best_val_loss:.4f}\n")
        f.write(f"{name_best_training_metric}: {best_training_metric:.4f}\n")
        f.write(f"{name_best_validation_metric}: {best_val_metric:.4f}\n")
        f.write(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.\n")
        f.write(f"{name_training_date}: {now}\n")
    
    # Save epoch losses, epoch metric scores, model, state dict, and oov embedding dict
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_training_losses
    }).to_csv(f"{root_path}/training_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_training_metric_scores
    }).to_csv(f"{root_path}/training_metric_scores.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_val_losses
    }).to_csv(f"{root_path}/val_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_val_metric_scores
    }).to_csv(f"{root_path}/val_metric_scores.csv", index=False)    
    
    filename_model_params = f"{root_path}/model_params.pth"
    torch.save(best_state_dict, filename_model_params)
    
    return epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores

epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores = looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric)
# Out:
# EPOCH-1
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.4841 | MulticlassF1Score=0.1463
# Batch-30 : CrossEntropyLoss=2.5028 | MulticlassF1Score=0.2017
# Batch-45 : CrossEntropyLoss=2.5030 | MulticlassF1Score=0.2192
# Batch-60 : CrossEntropyLoss=2.4852 | MulticlassF1Score=0.2346
# Batch-75 : CrossEntropyLoss=2.4234 | MulticlassF1Score=0.2735
# Batch-90 : CrossEntropyLoss=2.3936 | MulticlassF1Score=0.3109
# Batch-105: CrossEntropyLoss=2.3845 | MulticlassF1Score=0.3454
# Batch-120: CrossEntropyLoss=2.3712 | MulticlassF1Score=0.3764
# Batch-135: CrossEntropyLoss=2.3453 | MulticlassF1Score=0.4009
# Batch-150: CrossEntropyLoss=2.3664 | MulticlassF1Score=0.4264
# Batch-165: CrossEntropyLoss=2.3540 | MulticlassF1Score=0.4475
# Batch-180: CrossEntropyLoss=2.3457 | MulticlassF1Score=0.4667
# Batch-195: CrossEntropyLoss=2.3428 | MulticlassF1Score=0.4830
# Batch-210: CrossEntropyLoss=2.3511 | MulticlassF1Score=0.4967
# Batch-225: CrossEntropyLoss=2.3544 | MulticlassF1Score=0.5088
# Batch-226: CrossEntropyLoss=2.3511 | MulticlassF1Score=0.5093
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3263 | MulticlassF1Score=0.6777
# Batch-30 : CrossEntropyLoss=2.3614 | MulticlassF1Score=0.6722
# Batch-45 : CrossEntropyLoss=2.3504 | MulticlassF1Score=0.6715
# Batch-60 : CrossEntropyLoss=2.3298 | MulticlassF1Score=0.6716
# Batch-63 : CrossEntropyLoss=2.3550 | MulticlassF1Score=0.6716
#
# Training   : Mean CrossEntropyLoss = 2.4118 | Mean MulticlassF1Score = 0.3435
# Validation : Mean CrossEntropyLoss = 2.3498 | Mean MulticlassF1Score = 0.6711
# ================================================================================
#
# EPOCH-2
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3318 | MulticlassF1Score=0.6757
# Batch-30 : CrossEntropyLoss=2.3501 | MulticlassF1Score=0.6752
# Batch-45 : CrossEntropyLoss=2.3373 | MulticlassF1Score=0.6855
# Batch-60 : CrossEntropyLoss=2.3240 | MulticlassF1Score=0.6970
# Batch-75 : CrossEntropyLoss=2.3211 | MulticlassF1Score=0.7092
# Batch-90 : CrossEntropyLoss=2.3190 | MulticlassF1Score=0.7167
# Batch-105: CrossEntropyLoss=2.3223 | MulticlassF1Score=0.7263
# Batch-120: CrossEntropyLoss=2.3189 | MulticlassF1Score=0.7342
# Batch-135: CrossEntropyLoss=2.3138 | MulticlassF1Score=0.7404
# Batch-150: CrossEntropyLoss=2.3112 | MulticlassF1Score=0.7445
# Batch-165: CrossEntropyLoss=2.3055 | MulticlassF1Score=0.7487
# Batch-180: CrossEntropyLoss=2.3128 | MulticlassF1Score=0.7528
# Batch-195: CrossEntropyLoss=2.3042 | MulticlassF1Score=0.7558
# Batch-210: CrossEntropyLoss=2.3033 | MulticlassF1Score=0.7583
# Batch-225: CrossEntropyLoss=2.3080 | MulticlassF1Score=0.7607
# Batch-226: CrossEntropyLoss=2.3063 | MulticlassF1Score=0.7609
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3101 | MulticlassF1Score=0.7914
# Batch-30 : CrossEntropyLoss=2.3108 | MulticlassF1Score=0.7923
# Batch-45 : CrossEntropyLoss=2.3094 | MulticlassF1Score=0.7905
# Batch-60 : CrossEntropyLoss=2.3164 | MulticlassF1Score=0.7897
# Batch-63 : CrossEntropyLoss=2.3239 | MulticlassF1Score=0.7893
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3229 | Mean MulticlassF1Score = 0.7228
# Validation : Mean CrossEntropyLoss = 2.3133 | Mean MulticlassF1Score = 0.7887
# ================================================================================
#
# EPOCH-3
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3100 | MulticlassF1Score=0.7895
# Batch-30 : CrossEntropyLoss=2.2991 | MulticlassF1Score=0.7948
# Batch-45 : CrossEntropyLoss=2.3126 | MulticlassF1Score=0.7960
# Batch-60 : CrossEntropyLoss=2.3110 | MulticlassF1Score=0.7969
# Batch-75 : CrossEntropyLoss=2.3103 | MulticlassF1Score=0.7965
# Batch-90 : CrossEntropyLoss=2.3162 | MulticlassF1Score=0.7968
# Batch-105: CrossEntropyLoss=2.3226 | MulticlassF1Score=0.7973
# Batch-120: CrossEntropyLoss=2.3114 | MulticlassF1Score=0.7968
# Batch-135: CrossEntropyLoss=2.3008 | MulticlassF1Score=0.7962
# Batch-150: CrossEntropyLoss=2.3172 | MulticlassF1Score=0.7977
# Batch-165: CrossEntropyLoss=2.3119 | MulticlassF1Score=0.7987
# Batch-180: CrossEntropyLoss=2.3198 | MulticlassF1Score=0.7994
# Batch-195: CrossEntropyLoss=2.3154 | MulticlassF1Score=0.7998
# Batch-210: CrossEntropyLoss=2.3073 | MulticlassF1Score=0.8002
# Batch-225: CrossEntropyLoss=2.3004 | MulticlassF1Score=0.8003
# Batch-226: CrossEntropyLoss=2.3136 | MulticlassF1Score=0.8002
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3086 | MulticlassF1Score=0.8052
# Batch-30 : CrossEntropyLoss=2.3081 | MulticlassF1Score=0.8042
# Batch-45 : CrossEntropyLoss=2.3025 | MulticlassF1Score=0.8024
# Batch-60 : CrossEntropyLoss=2.3100 | MulticlassF1Score=0.8038
# Batch-63 : CrossEntropyLoss=2.3375 | MulticlassF1Score=0.8030
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3100 | Mean MulticlassF1Score = 0.7970
# Validation : Mean CrossEntropyLoss = 2.3088 | Mean MulticlassF1Score = 0.8037
# ================================================================================
#
# EPOCH-4
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3035 | MulticlassF1Score=0.8055
# Batch-30 : CrossEntropyLoss=2.3151 | MulticlassF1Score=0.8069
# Batch-45 : CrossEntropyLoss=2.3139 | MulticlassF1Score=0.8057
# Batch-60 : CrossEntropyLoss=2.3145 | MulticlassF1Score=0.8058
# Batch-75 : CrossEntropyLoss=2.3072 | MulticlassF1Score=0.8074
# Batch-90 : CrossEntropyLoss=2.3092 | MulticlassF1Score=0.8080
# Batch-105: CrossEntropyLoss=2.3020 | MulticlassF1Score=0.8103
# Batch-120: CrossEntropyLoss=2.3026 | MulticlassF1Score=0.8115
# Batch-135: CrossEntropyLoss=2.3084 | MulticlassF1Score=0.8124
# Batch-150: CrossEntropyLoss=2.3003 | MulticlassF1Score=0.8133
# Batch-165: CrossEntropyLoss=2.3015 | MulticlassF1Score=0.8140
# Batch-180: CrossEntropyLoss=2.3037 | MulticlassF1Score=0.8141
# Batch-195: CrossEntropyLoss=2.2980 | MulticlassF1Score=0.8138
# Batch-210: CrossEntropyLoss=2.3137 | MulticlassF1Score=0.8144
# Batch-225: CrossEntropyLoss=2.3135 | MulticlassF1Score=0.8149
# Batch-226: CrossEntropyLoss=2.3068 | MulticlassF1Score=0.8150
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3112 | MulticlassF1Score=0.8148
# Batch-30 : CrossEntropyLoss=2.3106 | MulticlassF1Score=0.8111
# Batch-45 : CrossEntropyLoss=2.2913 | MulticlassF1Score=0.8130
# Batch-60 : CrossEntropyLoss=2.3133 | MulticlassF1Score=0.8118
# Batch-63 : CrossEntropyLoss=2.3123 | MulticlassF1Score=0.8115
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3052 | Mean MulticlassF1Score = 0.8104
# Validation : Mean CrossEntropyLoss = 2.3060 | Mean MulticlassF1Score = 0.8143
# ================================================================================
#
# EPOCH-5
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3131 | MulticlassF1Score=0.8242
# Batch-30 : CrossEntropyLoss=2.3094 | MulticlassF1Score=0.8237
# Batch-45 : CrossEntropyLoss=2.3021 | MulticlassF1Score=0.8226
# Batch-60 : CrossEntropyLoss=2.3083 | MulticlassF1Score=0.8221
# Batch-75 : CrossEntropyLoss=2.3087 | MulticlassF1Score=0.8212
# Batch-90 : CrossEntropyLoss=2.3086 | MulticlassF1Score=0.8209
# Batch-105: CrossEntropyLoss=2.3096 | MulticlassF1Score=0.8208
# Batch-120: CrossEntropyLoss=2.3053 | MulticlassF1Score=0.8197
# Batch-135: CrossEntropyLoss=2.2924 | MulticlassF1Score=0.8197
# Batch-150: CrossEntropyLoss=2.2993 | MulticlassF1Score=0.8200
# Batch-165: CrossEntropyLoss=2.3044 | MulticlassF1Score=0.8198
# Batch-180: CrossEntropyLoss=2.2983 | MulticlassF1Score=0.8198
# Batch-195: CrossEntropyLoss=2.3099 | MulticlassF1Score=0.8195
# Batch-210: CrossEntropyLoss=2.2956 | MulticlassF1Score=0.8196
# Batch-225: CrossEntropyLoss=2.3009 | MulticlassF1Score=0.8197
# Batch-226: CrossEntropyLoss=2.3049 | MulticlassF1Score=0.8197
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3016 | MulticlassF1Score=0.8125
# Batch-30 : CrossEntropyLoss=2.3202 | MulticlassF1Score=0.8139
# Batch-45 : CrossEntropyLoss=2.3019 | MulticlassF1Score=0.8132
# Batch-60 : CrossEntropyLoss=2.3100 | MulticlassF1Score=0.8129
# Batch-63 : CrossEntropyLoss=2.3029 | MulticlassF1Score=0.8130
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3036 | Mean MulticlassF1Score = 0.8210
# Validation : Mean CrossEntropyLoss = 2.3052 | Mean MulticlassF1Score = 0.8141
# ================================================================================
#
# EPOCH-6
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3057 | MulticlassF1Score=0.8184
# Batch-30 : CrossEntropyLoss=2.3069 | MulticlassF1Score=0.8185
# Batch-45 : CrossEntropyLoss=2.3014 | MulticlassF1Score=0.8184
# Batch-60 : CrossEntropyLoss=2.3077 | MulticlassF1Score=0.8193
# Batch-75 : CrossEntropyLoss=2.2964 | MulticlassF1Score=0.8205
# Batch-90 : CrossEntropyLoss=2.3004 | MulticlassF1Score=0.8206
# Batch-105: CrossEntropyLoss=2.3002 | MulticlassF1Score=0.8218
# Batch-120: CrossEntropyLoss=2.3041 | MulticlassF1Score=0.8217
# Batch-135: CrossEntropyLoss=2.2989 | MulticlassF1Score=0.8216
# Batch-150: CrossEntropyLoss=2.3008 | MulticlassF1Score=0.8224
# Batch-165: CrossEntropyLoss=2.2900 | MulticlassF1Score=0.8238
# Batch-180: CrossEntropyLoss=2.2889 | MulticlassF1Score=0.8256
# Batch-195: CrossEntropyLoss=2.2971 | MulticlassF1Score=0.8272
# Batch-210: CrossEntropyLoss=2.2956 | MulticlassF1Score=0.8282
# Batch-225: CrossEntropyLoss=2.3070 | MulticlassF1Score=0.8288
# Batch-226: CrossEntropyLoss=2.2991 | MulticlassF1Score=0.8288
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2921 | MulticlassF1Score=0.8381
# Batch-30 : CrossEntropyLoss=2.2924 | MulticlassF1Score=0.8338
# Batch-45 : CrossEntropyLoss=2.3078 | MulticlassF1Score=0.8343
# Batch-60 : CrossEntropyLoss=2.2998 | MulticlassF1Score=0.8345
# Batch-63 : CrossEntropyLoss=2.2951 | MulticlassF1Score=0.8338
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3007 | Mean MulticlassF1Score = 0.8220
# Validation : Mean CrossEntropyLoss = 2.2989 | Mean MulticlassF1Score = 0.8359
# ================================================================================
#
# EPOCH-7
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2931 | MulticlassF1Score=0.8473
# Batch-30 : CrossEntropyLoss=2.3044 | MulticlassF1Score=0.8455
# Batch-45 : CrossEntropyLoss=2.2900 | MulticlassF1Score=0.8472
# Batch-60 : CrossEntropyLoss=2.2894 | MulticlassF1Score=0.8453
# Batch-75 : CrossEntropyLoss=2.2916 | MulticlassF1Score=0.8455
# Batch-90 : CrossEntropyLoss=2.2948 | MulticlassF1Score=0.8446
# Batch-105: CrossEntropyLoss=2.2929 | MulticlassF1Score=0.8443
# Batch-120: CrossEntropyLoss=2.3009 | MulticlassF1Score=0.8440
# Batch-135: CrossEntropyLoss=2.3028 | MulticlassF1Score=0.8431
# Batch-150: CrossEntropyLoss=2.3025 | MulticlassF1Score=0.8429
# Batch-165: CrossEntropyLoss=2.2996 | MulticlassF1Score=0.8428
# Batch-180: CrossEntropyLoss=2.2983 | MulticlassF1Score=0.8427
# Batch-195: CrossEntropyLoss=2.2955 | MulticlassF1Score=0.8425
# Batch-210: CrossEntropyLoss=2.2978 | MulticlassF1Score=0.8430
# Batch-225: CrossEntropyLoss=2.2961 | MulticlassF1Score=0.8428
# Batch-226: CrossEntropyLoss=2.3015 | MulticlassF1Score=0.8428
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2954 | MulticlassF1Score=0.8463
# Batch-30 : CrossEntropyLoss=2.2919 | MulticlassF1Score=0.8434
# Batch-45 : CrossEntropyLoss=2.3032 | MulticlassF1Score=0.8438
# Batch-60 : CrossEntropyLoss=2.3013 | MulticlassF1Score=0.8444
# Batch-63 : CrossEntropyLoss=2.2941 | MulticlassF1Score=0.8436
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2963 | Mean MulticlassF1Score = 0.8443
# Validation : Mean CrossEntropyLoss = 2.2961 | Mean MulticlassF1Score = 0.8444
# ================================================================================
#
# EPOCH-8
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2851 | MulticlassF1Score=0.8645
# Batch-30 : CrossEntropyLoss=2.2874 | MulticlassF1Score=0.8623
# Batch-45 : CrossEntropyLoss=2.2951 | MulticlassF1Score=0.8588
# Batch-60 : CrossEntropyLoss=2.2943 | MulticlassF1Score=0.8592
# Batch-75 : CrossEntropyLoss=2.3000 | MulticlassF1Score=0.8599
# Batch-90 : CrossEntropyLoss=2.2947 | MulticlassF1Score=0.8590
# Batch-105: CrossEntropyLoss=2.2988 | MulticlassF1Score=0.8586
# Batch-120: CrossEntropyLoss=2.2947 | MulticlassF1Score=0.8588
# Batch-135: CrossEntropyLoss=2.2906 | MulticlassF1Score=0.8590
# Batch-150: CrossEntropyLoss=2.2906 | MulticlassF1Score=0.8590
# Batch-165: CrossEntropyLoss=2.2920 | MulticlassF1Score=0.8593
# Batch-180: CrossEntropyLoss=2.2963 | MulticlassF1Score=0.8592
# Batch-195: CrossEntropyLoss=2.2898 | MulticlassF1Score=0.8595
# Batch-210: CrossEntropyLoss=2.2843 | MulticlassF1Score=0.8594
# Batch-225: CrossEntropyLoss=2.2881 | MulticlassF1Score=0.8592
# Batch-226: CrossEntropyLoss=2.2898 | MulticlassF1Score=0.8593
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2994 | MulticlassF1Score=0.8532
# Batch-30 : CrossEntropyLoss=2.2944 | MulticlassF1Score=0.8527
# Batch-45 : CrossEntropyLoss=2.2974 | MulticlassF1Score=0.8534
# Batch-60 : CrossEntropyLoss=2.2925 | MulticlassF1Score=0.8515
# Batch-63 : CrossEntropyLoss=2.2884 | MulticlassF1Score=0.8518
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2915 | Mean MulticlassF1Score = 0.8599
# Validation : Mean CrossEntropyLoss = 2.2934 | Mean MulticlassF1Score = 0.8518
# ================================================================================
#
# EPOCH-9
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2967 | MulticlassF1Score=0.8641
# Batch-30 : CrossEntropyLoss=2.2936 | MulticlassF1Score=0.8609
# Batch-45 : CrossEntropyLoss=2.2925 | MulticlassF1Score=0.8606
# Batch-60 : CrossEntropyLoss=2.2932 | MulticlassF1Score=0.8615
# Batch-75 : CrossEntropyLoss=2.2909 | MulticlassF1Score=0.8618
# Batch-90 : CrossEntropyLoss=2.2983 | MulticlassF1Score=0.8609
# Batch-105: CrossEntropyLoss=2.2952 | MulticlassF1Score=0.8604
# Batch-120: CrossEntropyLoss=2.2878 | MulticlassF1Score=0.8608
# Batch-135: CrossEntropyLoss=2.2901 | MulticlassF1Score=0.8607
# Batch-150: CrossEntropyLoss=2.2920 | MulticlassF1Score=0.8607
# Batch-165: CrossEntropyLoss=2.2924 | MulticlassF1Score=0.8612
# Batch-180: CrossEntropyLoss=2.2969 | MulticlassF1Score=0.8613
# Batch-195: CrossEntropyLoss=2.2886 | MulticlassF1Score=0.8608
# Batch-210: CrossEntropyLoss=2.2888 | MulticlassF1Score=0.8614
# Batch-225: CrossEntropyLoss=2.2973 | MulticlassF1Score=0.8613
# Batch-226: CrossEntropyLoss=2.2872 | MulticlassF1Score=0.8614
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2904 | MulticlassF1Score=0.8518
# Batch-30 : CrossEntropyLoss=2.2977 | MulticlassF1Score=0.8538
# Batch-45 : CrossEntropyLoss=2.2938 | MulticlassF1Score=0.8511
# Batch-60 : CrossEntropyLoss=2.2905 | MulticlassF1Score=0.8523
# Batch-63 : CrossEntropyLoss=2.2945 | MulticlassF1Score=0.8525
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2906 | Mean MulticlassF1Score = 0.8617
# Validation : Mean CrossEntropyLoss = 2.2931 | Mean MulticlassF1Score = 0.8520
# ================================================================================
#
# EPOCH-10
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2922 | MulticlassF1Score=0.8637
# Batch-30 : CrossEntropyLoss=2.2924 | MulticlassF1Score=0.8645
# Batch-45 : CrossEntropyLoss=2.2877 | MulticlassF1Score=0.8645
# Batch-60 : CrossEntropyLoss=2.2928 | MulticlassF1Score=0.8635
# Batch-75 : CrossEntropyLoss=2.2935 | MulticlassF1Score=0.8634
# Batch-90 : CrossEntropyLoss=2.2882 | MulticlassF1Score=0.8654
# Batch-105: CrossEntropyLoss=2.2825 | MulticlassF1Score=0.8676
# Batch-120: CrossEntropyLoss=2.2808 | MulticlassF1Score=0.8700
# Batch-135: CrossEntropyLoss=2.2771 | MulticlassF1Score=0.8721
# Batch-150: CrossEntropyLoss=2.2891 | MulticlassF1Score=0.8740
# Batch-165: CrossEntropyLoss=2.2785 | MulticlassF1Score=0.8749
# Batch-180: CrossEntropyLoss=2.2808 | MulticlassF1Score=0.8760
# Batch-195: CrossEntropyLoss=2.2797 | MulticlassF1Score=0.8764
# Batch-210: CrossEntropyLoss=2.2854 | MulticlassF1Score=0.8776
# Batch-225: CrossEntropyLoss=2.2928 | MulticlassF1Score=0.8784
# Batch-226: CrossEntropyLoss=2.2907 | MulticlassF1Score=0.8784
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2915 | MulticlassF1Score=0.8805
# Batch-30 : CrossEntropyLoss=2.2801 | MulticlassF1Score=0.8807
# Batch-45 : CrossEntropyLoss=2.2842 | MulticlassF1Score=0.8789
# Batch-60 : CrossEntropyLoss=2.2714 | MulticlassF1Score=0.8806
# Batch-63 : CrossEntropyLoss=2.2798 | MulticlassF1Score=0.8808
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2855 | Mean MulticlassF1Score = 0.8694
# Validation : Mean CrossEntropyLoss = 2.2847 | Mean MulticlassF1Score = 0.8798
# ================================================================================
#
# EPOCH-11
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2832 | MulticlassF1Score=0.8921
# Batch-30 : CrossEntropyLoss=2.2849 | MulticlassF1Score=0.8892
# Batch-45 : CrossEntropyLoss=2.2795 | MulticlassF1Score=0.8909
# Batch-60 : CrossEntropyLoss=2.2776 | MulticlassF1Score=0.8913
# Batch-75 : CrossEntropyLoss=2.2788 | MulticlassF1Score=0.8918
# Batch-90 : CrossEntropyLoss=2.2819 | MulticlassF1Score=0.8917
# Batch-105: CrossEntropyLoss=2.2822 | MulticlassF1Score=0.8910
# Batch-120: CrossEntropyLoss=2.2786 | MulticlassF1Score=0.8908
# Batch-135: CrossEntropyLoss=2.2785 | MulticlassF1Score=0.8908
# Batch-150: CrossEntropyLoss=2.2873 | MulticlassF1Score=0.8907
# Batch-165: CrossEntropyLoss=2.2875 | MulticlassF1Score=0.8907
# Batch-180: CrossEntropyLoss=2.2889 | MulticlassF1Score=0.8904
# Batch-195: CrossEntropyLoss=2.2816 | MulticlassF1Score=0.8907
# Batch-210: CrossEntropyLoss=2.2813 | MulticlassF1Score=0.8909
# Batch-225: CrossEntropyLoss=2.2752 | MulticlassF1Score=0.8911
# Batch-226: CrossEntropyLoss=2.2918 | MulticlassF1Score=0.8910
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2876 | MulticlassF1Score=0.8790
# Batch-30 : CrossEntropyLoss=2.2868 | MulticlassF1Score=0.8808
# Batch-45 : CrossEntropyLoss=2.2880 | MulticlassF1Score=0.8822
# Batch-60 : CrossEntropyLoss=2.2786 | MulticlassF1Score=0.8827
# Batch-63 : CrossEntropyLoss=2.2771 | MulticlassF1Score=0.8828
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2815 | Mean MulticlassF1Score = 0.8910
# Validation : Mean CrossEntropyLoss = 2.2839 | Mean MulticlassF1Score = 0.8815
# ================================================================================
#
# EPOCH-12
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2874 | MulticlassF1Score=0.8921
# Batch-30 : CrossEntropyLoss=2.2753 | MulticlassF1Score=0.8961
# Batch-45 : CrossEntropyLoss=2.2748 | MulticlassF1Score=0.8960
# Batch-60 : CrossEntropyLoss=2.2759 | MulticlassF1Score=0.8947
# Batch-75 : CrossEntropyLoss=2.2791 | MulticlassF1Score=0.8949
# Batch-90 : CrossEntropyLoss=2.2856 | MulticlassF1Score=0.8947
# Batch-105: CrossEntropyLoss=2.2787 | MulticlassF1Score=0.8943
# Batch-120: CrossEntropyLoss=2.2851 | MulticlassF1Score=0.8944
# Batch-135: CrossEntropyLoss=2.2784 | MulticlassF1Score=0.8945
# Batch-150: CrossEntropyLoss=2.2783 | MulticlassF1Score=0.8946
# Batch-165: CrossEntropyLoss=2.2875 | MulticlassF1Score=0.8939
# Batch-180: CrossEntropyLoss=2.2760 | MulticlassF1Score=0.8943
# Batch-195: CrossEntropyLoss=2.2792 | MulticlassF1Score=0.8940
# Batch-210: CrossEntropyLoss=2.2707 | MulticlassF1Score=0.8943
# Batch-225: CrossEntropyLoss=2.2906 | MulticlassF1Score=0.8939
# Batch-226: CrossEntropyLoss=2.2812 | MulticlassF1Score=0.8939
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2842 | MulticlassF1Score=0.8832
# Batch-30 : CrossEntropyLoss=2.2810 | MulticlassF1Score=0.8840
# Batch-45 : CrossEntropyLoss=2.2840 | MulticlassF1Score=0.8827
# Batch-60 : CrossEntropyLoss=2.2780 | MulticlassF1Score=0.8828
# Batch-63 : CrossEntropyLoss=2.2918 | MulticlassF1Score=0.8827
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2806 | Mean MulticlassF1Score = 0.8943
# Validation : Mean CrossEntropyLoss = 2.2840 | Mean MulticlassF1Score = 0.8832
# ================================================================================
#
# EPOCH-13
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2803 | MulticlassF1Score=0.8870
# Batch-30 : CrossEntropyLoss=2.2792 | MulticlassF1Score=0.8908
# Batch-45 : CrossEntropyLoss=2.2863 | MulticlassF1Score=0.8927
# Batch-60 : CrossEntropyLoss=2.2727 | MulticlassF1Score=0.8931
# Batch-75 : CrossEntropyLoss=2.2799 | MulticlassF1Score=0.8942
# Batch-90 : CrossEntropyLoss=2.2728 | MulticlassF1Score=0.8949
# Batch-105: CrossEntropyLoss=2.2840 | MulticlassF1Score=0.8950
# Batch-120: CrossEntropyLoss=2.2849 | MulticlassF1Score=0.8947
# Batch-135: CrossEntropyLoss=2.2826 | MulticlassF1Score=0.8946
# Batch-150: CrossEntropyLoss=2.2803 | MulticlassF1Score=0.8953
# Batch-165: CrossEntropyLoss=2.2830 | MulticlassF1Score=0.8954
# Batch-180: CrossEntropyLoss=2.2772 | MulticlassF1Score=0.8949
# Batch-195: CrossEntropyLoss=2.2797 | MulticlassF1Score=0.8947
# Batch-210: CrossEntropyLoss=2.2741 | MulticlassF1Score=0.8949
# Batch-225: CrossEntropyLoss=2.2743 | MulticlassF1Score=0.8953
# Batch-226: CrossEntropyLoss=2.2793 | MulticlassF1Score=0.8952
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2852 | MulticlassF1Score=0.8799
# Batch-30 : CrossEntropyLoss=2.2851 | MulticlassF1Score=0.8818
# Batch-45 : CrossEntropyLoss=2.2824 | MulticlassF1Score=0.8838
# Batch-60 : CrossEntropyLoss=2.2793 | MulticlassF1Score=0.8845
# Batch-63 : CrossEntropyLoss=2.2864 | MulticlassF1Score=0.8846
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2801 | Mean MulticlassF1Score = 0.8936
# Validation : Mean CrossEntropyLoss = 2.2832 | Mean MulticlassF1Score = 0.8820
# ================================================================================
#
# EPOCH-14
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2831 | MulticlassF1Score=0.8934
# Batch-30 : CrossEntropyLoss=2.2812 | MulticlassF1Score=0.8940
# Batch-45 : CrossEntropyLoss=2.2821 | MulticlassF1Score=0.8974
# Batch-60 : CrossEntropyLoss=2.2846 | MulticlassF1Score=0.8975
# Batch-75 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.8984
# Batch-90 : CrossEntropyLoss=2.2832 | MulticlassF1Score=0.8973
# Batch-105: CrossEntropyLoss=2.2841 | MulticlassF1Score=0.8966
# Batch-120: CrossEntropyLoss=2.2813 | MulticlassF1Score=0.8968
# Batch-135: CrossEntropyLoss=2.2752 | MulticlassF1Score=0.8972
# Batch-150: CrossEntropyLoss=2.2823 | MulticlassF1Score=0.8974
# Batch-165: CrossEntropyLoss=2.2856 | MulticlassF1Score=0.8973
# Batch-180: CrossEntropyLoss=2.2822 | MulticlassF1Score=0.8971
# Batch-195: CrossEntropyLoss=2.2732 | MulticlassF1Score=0.8973
# Batch-210: CrossEntropyLoss=2.2829 | MulticlassF1Score=0.8969
# Batch-225: CrossEntropyLoss=2.2791 | MulticlassF1Score=0.8970
# Batch-226: CrossEntropyLoss=2.2800 | MulticlassF1Score=0.8970
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2800 | MulticlassF1Score=0.8872
# Batch-30 : CrossEntropyLoss=2.2803 | MulticlassF1Score=0.8870
# Batch-45 : CrossEntropyLoss=2.2803 | MulticlassF1Score=0.8857
# Batch-60 : CrossEntropyLoss=2.2883 | MulticlassF1Score=0.8850
# Batch-63 : CrossEntropyLoss=2.2961 | MulticlassF1Score=0.8850
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2795 | Mean MulticlassF1Score = 0.8968
# Validation : Mean CrossEntropyLoss = 2.2832 | Mean MulticlassF1Score = 0.8858
# ================================================================================
#
# EPOCH-15
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2810 | MulticlassF1Score=0.8979
# Batch-30 : CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9000
# Batch-45 : CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9023
# Batch-60 : CrossEntropyLoss=2.2815 | MulticlassF1Score=0.9017
# Batch-75 : CrossEntropyLoss=2.2762 | MulticlassF1Score=0.9015
# Batch-90 : CrossEntropyLoss=2.2827 | MulticlassF1Score=0.9011
# Batch-105: CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9004
# Batch-120: CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9001
# Batch-135: CrossEntropyLoss=2.2809 | MulticlassF1Score=0.8997
# Batch-150: CrossEntropyLoss=2.2851 | MulticlassF1Score=0.8997
# Batch-165: CrossEntropyLoss=2.2765 | MulticlassF1Score=0.8995
# Batch-180: CrossEntropyLoss=2.2784 | MulticlassF1Score=0.8991
# Batch-195: CrossEntropyLoss=2.2705 | MulticlassF1Score=0.8989
# Batch-210: CrossEntropyLoss=2.2783 | MulticlassF1Score=0.8987
# Batch-225: CrossEntropyLoss=2.2818 | MulticlassF1Score=0.8986
# Batch-226: CrossEntropyLoss=2.2808 | MulticlassF1Score=0.8986
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2852 | MulticlassF1Score=0.8852
# Batch-30 : CrossEntropyLoss=2.2822 | MulticlassF1Score=0.8857
# Batch-45 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.8858
# Batch-60 : CrossEntropyLoss=2.2783 | MulticlassF1Score=0.8861
# Batch-63 : CrossEntropyLoss=2.2862 | MulticlassF1Score=0.8867
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2790 | Mean MulticlassF1Score = 0.9001
# Validation : Mean CrossEntropyLoss = 2.2826 | Mean MulticlassF1Score = 0.8857
# ================================================================================
#
# EPOCH-16
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2811 | MulticlassF1Score=0.9031
# Batch-30 : CrossEntropyLoss=2.2865 | MulticlassF1Score=0.9023
# Batch-45 : CrossEntropyLoss=2.2796 | MulticlassF1Score=0.9009
# Batch-60 : CrossEntropyLoss=2.2767 | MulticlassF1Score=0.9003
# Batch-75 : CrossEntropyLoss=2.2846 | MulticlassF1Score=0.9008
# Batch-90 : CrossEntropyLoss=2.2814 | MulticlassF1Score=0.9005
# Batch-105: CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9001
# Batch-120: CrossEntropyLoss=2.2783 | MulticlassF1Score=0.9001
# Batch-135: CrossEntropyLoss=2.2788 | MulticlassF1Score=0.8990
# Batch-150: CrossEntropyLoss=2.2846 | MulticlassF1Score=0.8991
# Batch-165: CrossEntropyLoss=2.2771 | MulticlassF1Score=0.8991
# Batch-180: CrossEntropyLoss=2.2786 | MulticlassF1Score=0.8993
# Batch-195: CrossEntropyLoss=2.2848 | MulticlassF1Score=0.8993
# Batch-210: CrossEntropyLoss=2.2726 | MulticlassF1Score=0.8995
# Batch-225: CrossEntropyLoss=2.2791 | MulticlassF1Score=0.8994
# Batch-226: CrossEntropyLoss=2.2790 | MulticlassF1Score=0.8994
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2808 | MulticlassF1Score=0.8846
# Batch-30 : CrossEntropyLoss=2.2803 | MulticlassF1Score=0.8888
# Batch-45 : CrossEntropyLoss=2.2903 | MulticlassF1Score=0.8873
# Batch-60 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.8865
# Batch-63 : CrossEntropyLoss=2.2849 | MulticlassF1Score=0.8862
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2787 | Mean MulticlassF1Score = 0.9002
# Validation : Mean CrossEntropyLoss = 2.2827 | Mean MulticlassF1Score = 0.8872
# ================================================================================
#
# EPOCH-17
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2790 | MulticlassF1Score=0.8974
# Batch-30 : CrossEntropyLoss=2.2756 | MulticlassF1Score=0.8991
# Batch-45 : CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9003
# Batch-60 : CrossEntropyLoss=2.2865 | MulticlassF1Score=0.8992
# Batch-75 : CrossEntropyLoss=2.2796 | MulticlassF1Score=0.8996
# Batch-90 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.8995
# Batch-105: CrossEntropyLoss=2.2788 | MulticlassF1Score=0.8996
# Batch-120: CrossEntropyLoss=2.2770 | MulticlassF1Score=0.8999
# Batch-135: CrossEntropyLoss=2.2745 | MulticlassF1Score=0.8998
# Batch-150: CrossEntropyLoss=2.2813 | MulticlassF1Score=0.9002
# Batch-165: CrossEntropyLoss=2.2795 | MulticlassF1Score=0.8996
# Batch-180: CrossEntropyLoss=2.2830 | MulticlassF1Score=0.8994
# Batch-195: CrossEntropyLoss=2.2787 | MulticlassF1Score=0.8998
# Batch-210: CrossEntropyLoss=2.2823 | MulticlassF1Score=0.9001
# Batch-225: CrossEntropyLoss=2.2756 | MulticlassF1Score=0.8998
# Batch-226: CrossEntropyLoss=2.2764 | MulticlassF1Score=0.8998
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2782 | MulticlassF1Score=0.8874
# Batch-30 : CrossEntropyLoss=2.2784 | MulticlassF1Score=0.8872
# Batch-45 : CrossEntropyLoss=2.2842 | MulticlassF1Score=0.8862
# Batch-60 : CrossEntropyLoss=2.2807 | MulticlassF1Score=0.8860
# Batch-63 : CrossEntropyLoss=2.2818 | MulticlassF1Score=0.8860
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2785 | Mean MulticlassF1Score = 0.8996
# Validation : Mean CrossEntropyLoss = 2.2827 | Mean MulticlassF1Score = 0.8856
# ================================================================================
#
# EPOCH-18
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2836 | MulticlassF1Score=0.9032
# Batch-30 : CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9014
# Batch-45 : CrossEntropyLoss=2.2765 | MulticlassF1Score=0.9014
# Batch-60 : CrossEntropyLoss=2.2784 | MulticlassF1Score=0.9008
# Batch-75 : CrossEntropyLoss=2.2785 | MulticlassF1Score=0.9013
# Batch-90 : CrossEntropyLoss=2.2762 | MulticlassF1Score=0.9009
# Batch-105: CrossEntropyLoss=2.2829 | MulticlassF1Score=0.9006
# Batch-120: CrossEntropyLoss=2.2788 | MulticlassF1Score=0.9005
# Batch-135: CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9001
# Batch-150: CrossEntropyLoss=2.2775 | MulticlassF1Score=0.8999
# Batch-165: CrossEntropyLoss=2.2766 | MulticlassF1Score=0.9001
# Batch-180: CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9003
# Batch-195: CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9000
# Batch-210: CrossEntropyLoss=2.2776 | MulticlassF1Score=0.9005
# Batch-225: CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9008
# Batch-226: CrossEntropyLoss=2.2776 | MulticlassF1Score=0.9008
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2839 | MulticlassF1Score=0.8906
# Batch-30 : CrossEntropyLoss=2.2920 | MulticlassF1Score=0.8862
# Batch-45 : CrossEntropyLoss=2.2827 | MulticlassF1Score=0.8850
# Batch-60 : CrossEntropyLoss=2.2788 | MulticlassF1Score=0.8855
# Batch-63 : CrossEntropyLoss=2.2847 | MulticlassF1Score=0.8863
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2782 | Mean MulticlassF1Score = 0.9013
# Validation : Mean CrossEntropyLoss = 2.2825 | Mean MulticlassF1Score = 0.8876
# ================================================================================
#
# EPOCH-19
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9017
# Batch-30 : CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9022
# Batch-45 : CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9031
# Batch-60 : CrossEntropyLoss=2.2775 | MulticlassF1Score=0.9023
# Batch-75 : CrossEntropyLoss=2.2840 | MulticlassF1Score=0.9019
# Batch-90 : CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9008
# Batch-105: CrossEntropyLoss=2.2820 | MulticlassF1Score=0.9001
# Batch-120: CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9011
# Batch-135: CrossEntropyLoss=2.2796 | MulticlassF1Score=0.9009
# Batch-150: CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9009
# Batch-165: CrossEntropyLoss=2.2775 | MulticlassF1Score=0.9009
# Batch-180: CrossEntropyLoss=2.2868 | MulticlassF1Score=0.9012
# Batch-195: CrossEntropyLoss=2.2768 | MulticlassF1Score=0.9011
# Batch-210: CrossEntropyLoss=2.2818 | MulticlassF1Score=0.9012
# Batch-225: CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9011
# Batch-226: CrossEntropyLoss=2.2788 | MulticlassF1Score=0.9011
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2750 | MulticlassF1Score=0.8892
# Batch-30 : CrossEntropyLoss=2.2908 | MulticlassF1Score=0.8871
# Batch-45 : CrossEntropyLoss=2.2874 | MulticlassF1Score=0.8867
# Batch-60 : CrossEntropyLoss=2.2776 | MulticlassF1Score=0.8857
# Batch-63 : CrossEntropyLoss=2.2870 | MulticlassF1Score=0.8861
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2781 | Mean MulticlassF1Score = 0.9013
# Validation : Mean CrossEntropyLoss = 2.2826 | Mean MulticlassF1Score = 0.8873
# ================================================================================
#
# EPOCH-20
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9030
# Batch-30 : CrossEntropyLoss=2.2771 | MulticlassF1Score=0.9030
# Batch-45 : CrossEntropyLoss=2.2778 | MulticlassF1Score=0.9025
# Batch-60 : CrossEntropyLoss=2.2782 | MulticlassF1Score=0.9018
# Batch-75 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9019
# Batch-90 : CrossEntropyLoss=2.2787 | MulticlassF1Score=0.9020
# Batch-105: CrossEntropyLoss=2.2780 | MulticlassF1Score=0.9015
# Batch-120: CrossEntropyLoss=2.2821 | MulticlassF1Score=0.9012
# Batch-135: CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9033
# Batch-150: CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9050
# Batch-165: CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9065
# Batch-180: CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9078
# Batch-195: CrossEntropyLoss=2.2747 | MulticlassF1Score=0.9089
# Batch-210: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9102
# Batch-225: CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9114
# Batch-226: CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9114
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9124
# Batch-30 : CrossEntropyLoss=2.2824 | MulticlassF1Score=0.9104
# Batch-45 : CrossEntropyLoss=2.2782 | MulticlassF1Score=0.9106
# Batch-60 : CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9109
# Batch-63 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9112
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2750 | Mean MulticlassF1Score = 0.9043
# Validation : Mean CrossEntropyLoss = 2.2750 | Mean MulticlassF1Score = 0.9108
# ================================================================================
#
# EPOCH-21
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2747 | MulticlassF1Score=0.9308
# Batch-30 : CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9296
# Batch-45 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9299
# Batch-60 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9302
# Batch-75 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9298
# Batch-90 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9302
# Batch-105: CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9300
# Batch-120: CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9293
# Batch-135: CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9293
# Batch-150: CrossEntropyLoss=2.2774 | MulticlassF1Score=0.9288
# Batch-165: CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9290
# Batch-180: CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9291
# Batch-195: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9291
# Batch-210: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9287
# Batch-225: CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9284
# Batch-226: CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9284
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2839 | MulticlassF1Score=0.9078
# Batch-30 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9114
# Batch-45 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9137
# Batch-60 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9149
# Batch-63 : CrossEntropyLoss=2.2776 | MulticlassF1Score=0.9149
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2698 | Mean MulticlassF1Score = 0.9295
# Validation : Mean CrossEntropyLoss = 2.2740 | Mean MulticlassF1Score = 0.9107
# ================================================================================
#
# EPOCH-22
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9306
# Batch-30 : CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9305
# Batch-45 : CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9293
# Batch-60 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9300
# Batch-75 : CrossEntropyLoss=2.2751 | MulticlassF1Score=0.9301
# Batch-90 : CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9298
# Batch-105: CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9300
# Batch-120: CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9305
# Batch-135: CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9306
# Batch-150: CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9303
# Batch-165: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9299
# Batch-180: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9300
# Batch-195: CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9303
# Batch-210: CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9302
# Batch-225: CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9303
# Batch-226: CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9303
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2787 | MulticlassF1Score=0.9135
# Batch-30 : CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9112
# Batch-45 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9138
# Batch-60 : CrossEntropyLoss=2.2801 | MulticlassF1Score=0.9153
# Batch-63 : CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9157
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2692 | Mean MulticlassF1Score = 0.9303
# Validation : Mean CrossEntropyLoss = 2.2736 | Mean MulticlassF1Score = 0.9138
# ================================================================================
#
# EPOCH-23
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9335
# Batch-30 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9322
# Batch-45 : CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9326
# Batch-60 : CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9318
# Batch-75 : CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9320
# Batch-90 : CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9314
# Batch-105: CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9309
# Batch-120: CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9307
# Batch-135: CrossEntropyLoss=2.2772 | MulticlassF1Score=0.9306
# Batch-150: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9308
# Batch-165: CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9306
# Batch-180: CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9309
# Batch-195: CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9310
# Batch-210: CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9309
# Batch-225: CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9312
# Batch-226: CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9312
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2886 | MulticlassF1Score=0.9132
# Batch-30 : CrossEntropyLoss=2.2754 | MulticlassF1Score=0.9145
# Batch-45 : CrossEntropyLoss=2.2817 | MulticlassF1Score=0.9155
# Batch-60 : CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9163
# Batch-63 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9170
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2688 | Mean MulticlassF1Score = 0.9316
# Validation : Mean CrossEntropyLoss = 2.2732 | Mean MulticlassF1Score = 0.9153
# ================================================================================
#
# EPOCH-24
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9275
# Batch-30 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9300
# Batch-45 : CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9301
# Batch-60 : CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9291
# Batch-75 : CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9301
# Batch-90 : CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9310
# Batch-105: CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9317
# Batch-120: CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9317
# Batch-135: CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9315
# Batch-150: CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9322
# Batch-165: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9321
# Batch-180: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9319
# Batch-195: CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9321
# Batch-210: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9323
# Batch-225: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9323
# Batch-226: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9323
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2790 | MulticlassF1Score=0.9156
# Batch-30 : CrossEntropyLoss=2.2765 | MulticlassF1Score=0.9170
# Batch-45 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9169
# Batch-60 : CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9162
# Batch-63 : CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9163
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2684 | Mean MulticlassF1Score = 0.9307
# Validation : Mean CrossEntropyLoss = 2.2733 | Mean MulticlassF1Score = 0.9166
# ================================================================================
#
# EPOCH-25
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9288
# Batch-30 : CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9331
# Batch-45 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9319
# Batch-60 : CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9306
# Batch-75 : CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9301
# Batch-90 : CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9309
# Batch-105: CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9311
# Batch-120: CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9315
# Batch-135: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9319
# Batch-150: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9322
# Batch-165: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9323
# Batch-180: CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9327
# Batch-195: CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9329
# Batch-210: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9330
# Batch-225: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9328
# Batch-226: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9328
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9094
# Batch-30 : CrossEntropyLoss=2.2796 | MulticlassF1Score=0.9151
# Batch-45 : CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9160
# Batch-60 : CrossEntropyLoss=2.2785 | MulticlassF1Score=0.9162
# Batch-63 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9167
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2682 | Mean MulticlassF1Score = 0.9316
# Validation : Mean CrossEntropyLoss = 2.2732 | Mean MulticlassF1Score = 0.9139
# ================================================================================
#
# EPOCH-26
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9348
# Batch-30 : CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9340
# Batch-45 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9336
# Batch-60 : CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9335
# Batch-75 : CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9335
# Batch-90 : CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9327
# Batch-105: CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9328
# Batch-120: CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9326
# Batch-135: CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9331
# Batch-150: CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9333
# Batch-165: CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9334
# Batch-180: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9329
# Batch-195: CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9329
# Batch-210: CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9331
# Batch-225: CrossEntropyLoss=2.2785 | MulticlassF1Score=0.9331
# Batch-226: CrossEntropyLoss=2.2777 | MulticlassF1Score=0.9330
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2751 | MulticlassF1Score=0.9139
# Batch-30 : CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9174
# Batch-45 : CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9184
# Batch-60 : CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9166
# Batch-63 : CrossEntropyLoss=2.2803 | MulticlassF1Score=0.9163
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2682 | Mean MulticlassF1Score = 0.9335
# Validation : Mean CrossEntropyLoss = 2.2734 | Mean MulticlassF1Score = 0.9160
# ================================================================================
#
# EPOCH-27
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9299
# Batch-30 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9322
# Batch-45 : CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9322
# Batch-60 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9332
# Batch-75 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9332
# Batch-90 : CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9334
# Batch-105: CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9335
# Batch-120: CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9336
# Batch-135: CrossEntropyLoss=2.2762 | MulticlassF1Score=0.9335
# Batch-150: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9339
# Batch-165: CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9336
# Batch-180: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9336
# Batch-195: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9332
# Batch-210: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9333
# Batch-225: CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9332
# Batch-226: CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9332
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9177
# Batch-30 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9173
# Batch-45 : CrossEntropyLoss=2.2796 | MulticlassF1Score=0.9155
# Batch-60 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9162
# Batch-63 : CrossEntropyLoss=2.2770 | MulticlassF1Score=0.9164
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2681 | Mean MulticlassF1Score = 0.9331
# Validation : Mean CrossEntropyLoss = 2.2733 | Mean MulticlassF1Score = 0.9166
# ================================================================================
#
# EPOCH-28
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9361
# Batch-30 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9331
# Batch-45 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9332
# Batch-60 : CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9332
# Batch-75 : CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9326
# Batch-90 : CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9326
# Batch-105: CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9326
# Batch-120: CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9333
# Batch-135: CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9337
# Batch-150: CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9338
# Batch-165: CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9339
# Batch-180: CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9337
# Batch-195: CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9337
# Batch-210: CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9334
# Batch-225: CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9333
# Batch-226: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9333
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9144
# Batch-30 : CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9170
# Batch-45 : CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9176
# Batch-60 : CrossEntropyLoss=2.2789 | MulticlassF1Score=0.9163
# Batch-63 : CrossEntropyLoss=2.2781 | MulticlassF1Score=0.9165
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2680 | Mean MulticlassF1Score = 0.9331
# Validation : Mean CrossEntropyLoss = 2.2733 | Mean MulticlassF1Score = 0.9175
# ================================================================================
#
# EPOCH-29
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9348
# Batch-30 : CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9343
# Batch-45 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9343
# Batch-60 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9338
# Batch-75 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9343
# Batch-90 : CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9354
# Batch-105: CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9362
# Batch-120: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9367
# Batch-135: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9367
# Batch-150: CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9370
# Batch-165: CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9370
# Batch-180: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9372
# ...
# Batch-45 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9476
# Batch-60 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9480
# Batch-63 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9482
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2570 | Mean MulticlassF1Score = 0.9694
# Validation : Mean CrossEntropyLoss = 2.2636 | Mean MulticlassF1Score = 0.9464
# Patience = 1/50❗
# ================================================================================
#
# EPOCH-42
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2544 | MulticlassF1Score=0.9688
# Batch-30 : CrossEntropyLoss=2.2611 | MulticlassF1Score=0.9696
# Batch-45 : CrossEntropyLoss=2.2526 | MulticlassF1Score=0.9708
# Batch-60 : CrossEntropyLoss=2.2539 | MulticlassF1Score=0.9707
# Batch-75 : CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9701
# Batch-90 : CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9699
# Batch-105: CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9697
# Batch-120: CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9693
# Batch-135: CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9692
# Batch-150: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9692
# Batch-165: CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9693
# Batch-180: CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9692
# Batch-195: CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9690
# Batch-210: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9689
# Batch-225: CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9685
# Batch-226: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9685
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9419
# Batch-30 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9389
# Batch-45 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9396
# Batch-60 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9397
# Batch-63 : CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9399
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2573 | Mean MulticlassF1Score = 0.9693
# Validation : Mean CrossEntropyLoss = 2.2664 | Mean MulticlassF1Score = 0.9397
# Patience = 2/50❗
# ================================================================================
#
# EPOCH-43
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9615
# Batch-30 : CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9604
# Batch-45 : CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9618
# Batch-60 : CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9620
# Batch-75 : CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9621
# Batch-90 : CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9620
# Batch-105: CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9621
# Batch-120: CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9620
# Batch-135: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9622
# Batch-150: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9621
# Batch-165: CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9622
# Batch-180: CrossEntropyLoss=2.2611 | MulticlassF1Score=0.9624
# Batch-195: CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9625
# Batch-210: CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9628
# Batch-225: CrossEntropyLoss=2.2533 | MulticlassF1Score=0.9631
# Batch-226: CrossEntropyLoss=2.2542 | MulticlassF1Score=0.9631
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9438
# Batch-30 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9453
# Batch-45 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9462
# Batch-60 : CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9478
# Batch-63 : CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9481
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2591 | Mean MulticlassF1Score = 0.9619
# Validation : Mean CrossEntropyLoss = 2.2636 | Mean MulticlassF1Score = 0.9444
# Patience = 3/50❗
# ================================================================================
#
# EPOCH-44
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9697
# Batch-30 : CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9658
# Batch-45 : CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9666
# Batch-60 : CrossEntropyLoss=2.2597 | MulticlassF1Score=0.9663
# Batch-75 : CrossEntropyLoss=2.2534 | MulticlassF1Score=0.9675
# Batch-90 : CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9678
# Batch-105: CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9681
# Batch-120: CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9678
# Batch-135: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9679
# Batch-150: CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9683
# Batch-165: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9681
# Batch-180: CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9679
# Batch-195: CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9678
# Batch-210: CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9679
# Batch-225: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9679
# Batch-226: CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9679
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9505
# Batch-30 : CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9501
# Batch-45 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9489
# Batch-60 : CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9486
# Batch-63 : CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9483
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2575 | Mean MulticlassF1Score = 0.9676
# Validation : Mean CrossEntropyLoss = 2.2634 | Mean MulticlassF1Score = 0.9494
# ================================================================================
#
# EPOCH-45
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9699
# Batch-30 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9701
# Batch-45 : CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9703
# Batch-60 : CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9702
# Batch-75 : CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9701
# Batch-90 : CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9696
# Batch-105: CrossEntropyLoss=2.2603 | MulticlassF1Score=0.9691
# Batch-120: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9693
# Batch-135: CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9693
# Batch-150: CrossEntropyLoss=2.2547 | MulticlassF1Score=0.9695
# Batch-165: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9694
# Batch-180: CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9693
# Batch-195: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9694
# Batch-210: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9695
# Batch-225: CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9696
# Batch-226: CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9696
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9529
# Batch-30 : CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9475
# Batch-45 : CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9484
# Batch-60 : CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9488
# Batch-63 : CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9489
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2569 | Mean MulticlassF1Score = 0.9696
# Validation : Mean CrossEntropyLoss = 2.2632 | Mean MulticlassF1Score = 0.9492
# ================================================================================
#
# EPOCH-46
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2531 | MulticlassF1Score=0.9713
# Batch-30 : CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9717
# Batch-45 : CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9722
# Batch-60 : CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9718
# Batch-75 : CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9718
# Batch-90 : CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9713
# Batch-105: CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9711
# Batch-120: CrossEntropyLoss=2.2541 | MulticlassF1Score=0.9714
# Batch-135: CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9712
# Batch-150: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9710
# Batch-165: CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9710
# Batch-180: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9708
# Batch-195: CrossEntropyLoss=2.2539 | MulticlassF1Score=0.9706
# Batch-210: CrossEntropyLoss=2.2540 | MulticlassF1Score=0.9707
# Batch-225: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9708
# Batch-226: CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9707
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9491
# Batch-30 : CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9489
# Batch-45 : CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9481
# Batch-60 : CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9492
# Batch-63 : CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9489
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2565 | Mean MulticlassF1Score = 0.9711
# Validation : Mean CrossEntropyLoss = 2.2633 | Mean MulticlassF1Score = 0.9488
# ================================================================================
#
# EPOCH-47
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9709
# Batch-30 : CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9704
# Batch-45 : CrossEntropyLoss=2.2530 | MulticlassF1Score=0.9712
# Batch-60 : CrossEntropyLoss=2.2534 | MulticlassF1Score=0.9719
# Batch-75 : CrossEntropyLoss=2.2515 | MulticlassF1Score=0.9724
# Batch-90 : CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9721
# Batch-105: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9720
# Batch-120: CrossEntropyLoss=2.2551 | MulticlassF1Score=0.9714
# Batch-135: CrossEntropyLoss=2.2532 | MulticlassF1Score=0.9718
# Batch-150: CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9717
# Batch-165: CrossEntropyLoss=2.2523 | MulticlassF1Score=0.9717
# Batch-180: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9717
# Batch-195: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9714
# Batch-210: CrossEntropyLoss=2.2522 | MulticlassF1Score=0.9713
# Batch-225: CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9711
# Batch-226: CrossEntropyLoss=2.2539 | MulticlassF1Score=0.9712
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9479
# Batch-30 : CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9474
# Batch-45 : CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9485
# Batch-60 : CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9496
# Batch-63 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9490
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2563 | Mean MulticlassF1Score = 0.9714
# Validation : Mean CrossEntropyLoss = 2.2632 | Mean MulticlassF1Score = 0.9486
# ================================================================================
#
# EPOCH-48
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9732
# Batch-30 : CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9715
# Batch-45 : CrossEntropyLoss=2.2551 | MulticlassF1Score=0.9715
# Batch-60 : CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9715
# Batch-75 : CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9714
# Batch-90 : CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9714
# Batch-105: CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9715
# Batch-120: CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9714
# Batch-135: CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9712
# Batch-150: CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9713
# Batch-165: CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9713
# Batch-180: CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9715
# Batch-195: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9715
# Batch-210: CrossEntropyLoss=2.2544 | MulticlassF1Score=0.9714
# Batch-225: CrossEntropyLoss=2.2543 | MulticlassF1Score=0.9715
# Batch-226: CrossEntropyLoss=2.2539 | MulticlassF1Score=0.9715
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9503
# Batch-30 : CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9495
# Batch-45 : CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9496
# Batch-60 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9497
# Batch-63 : CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9499
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2562 | Mean MulticlassF1Score = 0.9716
# Validation : Mean CrossEntropyLoss = 2.2629 | Mean MulticlassF1Score = 0.9490
# ================================================================================
#
# EPOCH-49
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9728
# Batch-30 : CrossEntropyLoss=2.2541 | MulticlassF1Score=0.9712
# Batch-45 : CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9715
# Batch-60 : CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9718
# Batch-75 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9719
# Batch-90 : CrossEntropyLoss=2.2530 | MulticlassF1Score=0.9723
# Batch-105: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9721
# Batch-120: CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9717
# Batch-135: CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9717
# Batch-150: CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9712
# Batch-165: CrossEntropyLoss=2.2542 | MulticlassF1Score=0.9712
# Batch-180: CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9712
# Batch-195: CrossEntropyLoss=2.2535 | MulticlassF1Score=0.9714
# Batch-210: CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9717
# Batch-225: CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9718
# Batch-226: CrossEntropyLoss=2.2551 | MulticlassF1Score=0.9718
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9481
# Batch-30 : CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9499
# Batch-45 : CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9506
# Batch-60 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9496
# Batch-63 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9499
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2560 | Mean MulticlassF1Score = 0.9717
# Validation : Mean CrossEntropyLoss = 2.2630 | Mean MulticlassF1Score = 0.9497
# ================================================================================
#
# EPOCH-50
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9704
# Batch-30 : CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9708
# Batch-45 : CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9710
# Batch-60 : CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9717
# Batch-75 : CrossEntropyLoss=2.2535 | MulticlassF1Score=0.9721
# Batch-90 : CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9723
# Batch-105: CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9722
# Batch-120: CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9722
# Batch-135: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9720
# Batch-150: CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9721
# Batch-165: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9719
# Batch-180: CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9721
# Batch-195: CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9721
# Batch-210: CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9719
# Batch-225: CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9719
# Batch-226: CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9719
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9500
# Batch-30 : CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9504
# Batch-45 : CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9508
# Batch-60 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9496
# Batch-63 : CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9499
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2560 | Mean MulticlassF1Score = 0.9717
# Validation : Mean CrossEntropyLoss = 2.2630 | Mean MulticlassF1Score = 0.9498
# ================================================================================
#
# TRAINING SUMMARY
# Best CrossEntropyLoss training    : 2.2560
# Best CrossEntropyLoss training    : 2.2630
# Best MulticlassF1Score validation : 0.9717
# Best MulticlassF1Score validation : 0.9498
# Training duration                 : 2.6404 minutes.
# Training date                     : 2022-10-19 13:23:16.972584+08:00

# %% [markdown]
# ## End Training

# %% [markdown]
# # Evaluation

# %%
def evaluation(dataloader, model, criterion, metric):
    model.eval()
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)
            pred = rearrange(prob.argmax(dim=1).reshape(feature.shape[0], len(dataloader.dataset)), "s n -> n s")

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob.argmax(dim=1), actual_label.to(hyperparams.device))
            metric_score = metric.compute()

    return loss, metric_score, pred

train_dataloader = DataLoader(train_dataset, batch_size=len(train_dataset))
val_dataloader = DataLoader(val_dataset, batch_size=len(val_dataset))
test_dataloader = DataLoader(test_dataset, batch_size=len(test_dataset))

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
train_loss, train_f1_score, train_pred_label = evaluation(train_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_loss, val_f1_score, val_pred_label = evaluation(val_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
test_loss, test_f1_score, test_pred_label = evaluation(test_dataloader, model, criterion, metric)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9721, device='cuda:0'),
#  tensor(0.9499, device='cuda:0'),
#  tensor(0.9489, device='cuda:0'))

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9721, device='cuda:0'),
#  tensor(0.9499, device='cuda:0'),
#  tensor(0.9489, device='cuda:0'))

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns

def viz_evaluation(pred_label, actual_label, title):
    plt.figure(figsize=(15, 7), dpi=200)
    sns.heatmap(pred_label.detach().cpu() == actual_label, cbar=True, cmap="binary_r")
    plt.xlabel("Sentence Length")
    plt.ylabel("Sentence")
    plt.title(title)
    plt.savefig(f"{root_path}/heatmap_{title.lower()}.jpg", dpi=200)
    plt.show()

train_actual_label = train_dataloader.dataset.tensors[1]
val_actual_label = val_dataloader.dataset.tensors[1]
test_actual_label = test_dataloader.dataset.tensors[1]

viz_evaluation(train_pred_label, train_actual_label, f"Training (F1-Score: {(train_f1_score):.4f})")
viz_evaluation(val_pred_label, val_actual_label, f"Validation (F1-Score: {(val_f1_score):.4f})")
viz_evaluation(test_pred_label, test_actual_label, f"Test (F1-Score: {(test_f1_score):.4f})")

# %% [markdown]
# ## Confusion Matrix

# %%
def confusion_matrix(pred_class, actual_class, title, normalize=None):
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize=normalize)
    plt.figure(figsize=(20, 10), dpi=200)
    sns.heatmap(conf_mat(pred_class.detach().cpu(), actual_class), annot=True, fmt=".2g", xticklabels=list(label_to_idx.keys()), yticklabels=list(label_to_idx.keys()));
    plt.yticks(rotation=0)
    plt.title(title)
    plt.xlabel("Actual Class")
    plt.ylabel("Predict Class")
    plt.savefig(f"{root_path}/conf_matrix_{title.lower()}.jpg", dpi=200)

confusion_matrix(train_pred_label, train_actual_label, "Training", "pred")
confusion_matrix(val_pred_label,val_actual_label, "Validation", "pred")
confusion_matrix(test_pred_label, test_actual_label, "Test", "pred")
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 120 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 144 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)

# %% [markdown]
# ## Prediction Table

# %%
def number_wrong_pred_each_class(pred_class, actual_class):
    classes, count_class = actual_class.flatten().unique(return_counts=True)
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize="none")
    correct_pred_count_class = conf_mat(pred_class.detach().cpu(), actual_class).diag()
    
    correct_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (correct_pred_count_class))}
    wrong_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (count_class - correct_pred_count_class))}
    
    return correct_pred, wrong_pred

correct_pred, wrong_pred = number_wrong_pred_each_class(train_pred_label, train_actual_label)
print(f"| {'Number class'.ljust(14)} | {'Correct prediction'.ljust(12)} | {'Wrong prediction'.ljust(12)} |")
for (label_correct_pred, count_correct_pred), (label_wrong_pred, count_wrong_pred) in zip(correct_pred.items(), wrong_pred.items()):
    print(f"| {str(label_correct_pred).ljust(6)}: {str(count_correct_pred + count_wrong_pred).ljust(7)}| {label_correct_pred.ljust(6)}: {str(count_correct_pred).ljust(10)} | {label_wrong_pred.ljust(6)}: {str(count_wrong_pred).ljust(8)} |")
# Out:
# | Number class   | Correct prediction | Wrong prediction |
# | CC    : 5346   | CC    : 5240       | CC    : 106      |
# | CD    : 12730  | CD    : 12657      | CD    : 73       |
# | DT    : 269    | DT    : 0          | DT    : 269      |
# | FW    : 1614   | FW    : 1317       | FW    : 297      |
# | IN    : 15342  | IN    : 15224      | IN    : 118      |
# | JJ    : 6981   | JJ    : 6657       | JJ    : 324      |
# | MD    : 3799   | MD    : 3740       | MD    : 59       |
# | NEG   : 1118   | NEG   : 0          | NEG   : 1118     |
# | NN    : 44369  | NN    : 43888      | NN    : 481      |
# | NND   : 1047   | NND   : 877        | NND   : 170      |
# | NNP   : 25175  | NNP   : 24747      | NNP   : 428      |
# | OD    : 524    | OD    : 505        | OD    : 19       |
# | PR    : 3880   | PR    : 3726       | PR    : 154      |
# | PRP   : 5471   | PRP   : 5434       | PRP   : 37       |
# | RB    : 3477   | RB    : 3300       | RB    : 177      |
# | RP    : 141    | RP    : 0          | RP    : 141      |
# | SC    : 9455   | SC    : 9175       | SC    : 280      |
# | SYM   : 1551   | SYM   : 1486       | SYM   : 65       |
# | UH    : 21     | UH    : 8          | UH    : 13       |
# | VB    : 22950  | VB    : 22622      | VB    : 328      |
# | WH    : 184    | WH    : 0          | WH    : 184      |
# | X     : 279    | X     : 0          | X     : 279      |
# | Z     : 18960  | Z     : 18922      | Z     : 38       |
# | <PAD> : 407521 | <PAD> : 407521     | <PAD> : 0        |

# %%
train_actual_label[308], train_pred_label[308]
# Out:
# (tensor([ 8,  3, 12, 19,  8,  8,  8, 16, 19,  4, 10,  8, 10,  0,  4,  1,  8,  8,
#           8,  5,  4,  8, 10,  0, 10, 10, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23]),
#  tensor([ 8,  8, 12, 19,  8,  8, 19, 16, 19,  4, 10,  8, 10,  0,  4,  1,  8,  8,
#           8,  5,  4,  8, 10,  0, 10, 10, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23], device='cuda:0'))

# %%
train_actual_label[308] == train_pred_label[308].detach().cpu()
# Out:
# tensor([ True, False,  True,  True,  True,  True, False,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True])

# %% [markdown]
# ## OOV prediction is correct

# %%
def oov_flag_token(sentences, max_seq_len=hyperparams.max_seq_len):
    sent_copy = deepcopy(sentences)
    sent = []
    oov_flag = []
    
    for sentence in tqdm(sent_copy):
        for token in sentence:
            sent.append(token[2])
        
        for _ in range(max_seq_len- len(sentence)):
            sent.append(False)
        
        oov_flag.append(sent)
        sent = []
        
    return np.array(oov_flag)

train_oov_flag = oov_flag_token(train_sentences, max_seq_len=hyperparams.max_seq_len)
val_oov_flag = oov_flag_token(val_sentences, max_seq_len=hyperparams.max_seq_len)
test_oov_flag = oov_flag_token(test_sentences, max_seq_len=hyperparams.max_seq_len)

def pencentage_oov_pred_correct(pred_oov_flag, oov_flag_tensor):
    oov_correct_counter = 0
    oov_wrong_counter = 0

    for pred, oov_label in tqdm(zip(pred_oov_flag, oov_flag_tensor)):
        if pred == True and oov_label == True:
            oov_correct_counter += 1
        elif pred == False and oov_label == True:
            oov_wrong_counter += 1
        else:
            continue
            
    return oov_correct_counter, oov_wrong_counter

train_pred_oov_flag = (train_actual_label == train_pred_label.detach().cpu()).flatten()
val_pred_oov_flag = (val_actual_label == val_pred_label.detach().cpu()).flatten()
test_pred_oov_flag = (test_actual_label == test_pred_label.detach().cpu()).flatten()
train_oov_flag_tensor = torch.tensor(train_oov_flag).flatten()
val_oov_flag_tensor = torch.tensor(val_oov_flag).flatten()
test_oov_flag_tensor = torch.tensor(test_oov_flag).flatten()

train_oov_correct_counter, train_oov_wrong_counter = pencentage_oov_pred_correct(train_pred_oov_flag, train_oov_flag_tensor)
val_oov_correct_counter, val_oov_wrong_counter = pencentage_oov_pred_correct(val_pred_oov_flag, val_oov_flag_tensor)
test_oov_correct_counter, test_oov_wrong_counter = pencentage_oov_pred_correct(test_pred_oov_flag, test_oov_flag_tensor)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
def print_percentage_pred_oov(title, oov_correct_counter, oov_wrong_counter):
    print(f"{title}")
    print(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}")
    print(f"Correct prediction          : {oov_correct_counter}")
    print(f"Wrong prediction            : {oov_wrong_counter}")
    print(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n")
    
    with open(f"{root_path}/oov_summary.txt", "a") as f:
        f.write(f"{title}\n")
        f.write(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}\n")
        f.write(f"Correct prediction          : {oov_correct_counter}\n")
        f.write(f"Wrong prediction            : {oov_wrong_counter}\n")
        f.write(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n\n")

# %%
print_percentage_pred_oov("Training", train_oov_correct_counter, train_oov_wrong_counter)
print_percentage_pred_oov("Validation", val_oov_correct_counter, val_oov_wrong_counter)
print_percentage_pred_oov("Test", test_oov_correct_counter, test_oov_wrong_counter)
# Out:
# Training
# Number OOV token            : 11806
# Correct prediction          : 11174
# Wrong prediction            : 632
# Percentage correct oov pred : 94.64678976791461
#
# Validation
# Number OOV token            : 3366
# Correct prediction          : 3033
# Wrong prediction            : 333
# Percentage correct oov pred : 90.10695187165776
#
# Test
# Number OOV token            : 1390
# Correct prediction          : 1264
# Wrong prediction            : 126
# Percentage correct oov pred : 90.93525179856115

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(train_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(val_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(test_oov_flag, cmap=plt.cm.binary_r);
