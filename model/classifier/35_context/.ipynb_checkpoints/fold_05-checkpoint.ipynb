# %% [markdown]
# # Import modules

# %%
import csv
import os
import pickle
import pytz
import torch
import timeit
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from copy import deepcopy
from datetime import datetime
from einops import rearrange
from itertools import chain
from time import time
from torch import nn, optim
from torchmetrics.classification import MulticlassAccuracy, MulticlassF1Score, MulticlassConfusionMatrix
from torch.optim import lr_scheduler
from tqdm.notebook import tqdm
from torch.utils.data import TensorDataset, DataLoader
from polyglot.mapping import Embedding, CaseExpander, DigitExpander

# %% [markdown]
# # Hyperparameters

# %%
class Hyperparams:
     def __init__(
        self,
        context_size=35,
        fold=5,
        max_seq_len=82,
        input_size=64,
        batch_size=32,
        num_hidden_layer=1,
        hidden_size=128,
        dropout=0,
        bias=True,
        output_size=24,
        shuffle=True,
        lr=0.005,
        batch_first=False,
        bidirectional=True,
        init_wb_with_kaiming_normal=True,
        n_epoch=50,
        patience=50,
        device="cuda" if torch.cuda.is_available() else "cpu"
    ):
        self.context_size = context_size
        self.fold = fold
        self.input_size = input_size
        self.max_seq_len = max_seq_len
        self.batch_size = batch_size
        self.num_hidden_layer = num_hidden_layer
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.output_size = output_size
        self.shuffle = shuffle
        self.lr = lr
        self.batch_first = batch_first
        self.bidirectional = bidirectional
        self.init_wb_with_kaiming_normal = init_wb_with_kaiming_normal
        self.n_epoch = n_epoch
        self.patience = patience
        self.device = device

hyperparams = Hyperparams()

# %% [markdown]
# # Dataset

# %%
id_pos_tag = pd.read_csv("../../../datasets/raw/Indonesian_Manually_Tagged_Corpus.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False) 
train = pd.read_csv(f"../../../datasets/raw/cv/train/train.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
val = pd.read_csv(f"../../../datasets/raw/cv/val/val.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
test = pd.read_csv(f"../../../datasets/raw/cv/test/test.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)

# %% [markdown]
# # Pre-trained Word Embedding

# %%
embeddings = Embedding.load("../../../word_embeddings/polyglot/idn_embeddings.tar.bz2")
embeddings.apply_expansion(DigitExpander)
embeddings.apply_expansion(CaseExpander)

oov_embeddings = pickle.load(open(f"../../../logs/comick/{hyperparams.context_size}_contexts/10-11-2022_13-22-21/oov_embedding_dict.pkl", "rb"))

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Add OOV Flag

# %%
def add_oov_flag(tokens, embeddings):
    oov_flags = []
    
    for token in tqdm(tokens):
        try:
            if token not in embeddings:
                oov_flags.append(True)
            else:
                oov_flags.append(False)
        except:
            oov_flags.append(False)
        
    return pd.DataFrame(oov_flags, columns=["is_oov"])

id_pos_tag_oov_flags = add_oov_flag(id_pos_tag["token"].values, embeddings)
train_oov_flags = add_oov_flag(train["token"].values, embeddings)
val_oov_flags = add_oov_flag(val["token"].values, embeddings)
test_oov_flags = add_oov_flag(test["token"].values, embeddings)
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/191905 [00:00<?, ?it/s]
#   0%|          | 0/21691 [00:00<?, ?it/s]
#   0%|          | 0/53056 [00:00<?, ?it/s]

# %% [markdown]
# ## Concate OOV Flag

# %%
id_pos_tag_df = pd.concat([id_pos_tag, id_pos_tag_oov_flags], axis=1)
train_df = pd.concat([train, train_oov_flags], axis=1)
val_df = pd.concat([val, val_oov_flags], axis=1)
test_df = pd.concat([test, test_oov_flags], axis=1)

# %% [markdown]
# ## Lowercase OOV Token

# %%
id_pos_tag_df['token'] = np.where(id_pos_tag_df['is_oov'] == True, id_pos_tag_df['token'].str.lower(), id_pos_tag_df['token'])
train_df['token'] = np.where(train_df['is_oov'] == True, train_df['token'].str.lower(), train_df['token'])
val_df['token'] = np.where(val_df['is_oov'] == True, val_df['token'].str.lower(), val_df['token'])
test_df['token'] = np.where(test_df['is_oov'] == True, test_df['token'].str.lower(), test_df['token'])

# %% [markdown]
# ## Embedding Dict, Index to Token and Token to Index

# %%
tokens = list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None))

def embedding_dict(tokens, embeddings, oov_embeddings):
    embedding = {}
    
    for token in tokens:
        if token[0] is not np.nan:
            if token[2] == False or token[0] in embeddings:
                embedding[token[0]] = embeddings[token[0]]
            else:
                embedding[token[0]] = oov_embeddings[token[0].lower()]

    return embedding

embedding_dict = embedding_dict(tokens, embeddings, oov_embeddings)
embedding_dict["<PAD>"] = embeddings["<PAD>"]
word_embeddings = nn.Embedding.from_pretrained(torch.FloatTensor(np.array(list(embedding_dict.values()))), padding_idx=list(embedding_dict.keys()).index("<PAD>"), freeze=True)

idx_to_token = {idx: token for idx, token in enumerate(list(embedding_dict.keys()))}
token_to_idx = {token: idx for idx, token in enumerate(list(embedding_dict.keys()))}

# %% [markdown]
# ## Token to Sentence

# %%
def make_sentence(tokens, max_length_sentence=hyperparams.max_seq_len):
    sentence = []
    sentences = []

    for token in tqdm(tokens):
        if token[0] is not np.nan:
            sentence.append(token)
        else:
            sentences.append(sentence[:max_length_sentence])
            sentence = []

    return sentences

all_sentence = make_sentence(list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
train_sentences = make_sentence(list(train_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
val_sentences = make_sentence(list(test_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
test_sentences = make_sentence(list(val_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/191905 [00:00<?, ?it/s]
#   0%|          | 0/53056 [00:00<?, ?it/s]
#   0%|          | 0/21691 [00:00<?, ?it/s]

# %% [markdown]
# ## Word Token, Padding, and Word token to Index

# %%
def tokenize_docs(docs, idx_token):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token[idx_token])
        sentences.append(new_sentence)
        new_sentence = []

    return sentences

def padding(docs, max_seq_len=hyperparams.max_seq_len, mode="post", val_pad="<PAD>"):
    docs = deepcopy(docs)
    doc_with_pad = []
    docs_with_pad = []

    for doc in tqdm(docs):
        if mode == "pre":
            for _ in range(max_seq_len - len(doc)):
                doc.insert(0, val_pad)
        elif mode == "post":
            for _ in range(max_seq_len - len(doc)):
                doc.append(val_pad)
        else:
            return f"Mode {mode} is not available, use instead 'pre' or 'post'."
        
        docs_with_pad.append(doc)
        
    return np.array(docs_with_pad)

def sent_to_idx(docs, token_to_idx):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token_to_idx[token])
        sentences.append(new_sentence)
        new_sentence = []

    return np.array(sentences)

def convert_feature_to_idx(docs, idx_token, token_to_idx, max_seq_len):
    sentences = tokenize_docs(docs, idx_token)
    sentences_with_pad = padding(sentences, max_seq_len=max_seq_len, mode="post", val_pad="<PAD>")
    sentences_to_idx = sent_to_idx(sentences_with_pad, token_to_idx)
    
    return sentences_to_idx

train_sentence_idxs = convert_feature_to_idx(train_sentences, 0, token_to_idx, hyperparams.max_seq_len)
val_sentence_idxs = convert_feature_to_idx(val_sentences, 0, token_to_idx, hyperparams.max_seq_len)
test_sentence_idxs = convert_feature_to_idx(test_sentences, 0, token_to_idx, hyperparams.max_seq_len)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]

# %% [markdown]
# ## Encode Class

# %%
classes = sorted(np.delete(id_pos_tag_df["tag"].unique(), 3))
idx_to_label = {idx: label for idx, label in enumerate(classes + ["<PAD>"])}
label_to_idx = {label: idx for idx, label in enumerate(classes + ["<PAD>"])}

def encode_class(docs, label_to_idx, seq_len=hyperparams.max_seq_len):
    class_idxs = []
    classes = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            class_idxs.append(label_to_idx[token[1]])
            
        for _ in range(seq_len - len(sentence)):
            class_idxs.append(label_to_idx["<PAD>"])
                
        classes.append(class_idxs)
        class_idxs = []

    return np.array(classes)
        
train_class_idxs = encode_class(train_sentences, label_to_idx)
val_class_idxs = encode_class(val_sentences, label_to_idx)
test_class_idxs = encode_class(test_sentences, label_to_idx)

print(f"Training shape   : {train_sentence_idxs.shape, train_class_idxs.shape}")
print(f"validation shape : {val_class_idxs.shape, val_class_idxs.shape}")
print(f"Test shape       : {test_sentence_idxs.shape, test_class_idxs.shape}")
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# Training shape   : ((7222, 82), (7222, 82))
# validation shape : ((2006, 82), (2006, 82))
# Test shape       : ((802, 82), (802, 82))

# %% [markdown]
# ## Note
#
# - Number of sentences = 10030
# - Train : 72% (7222)
# - Val   : 8% (802)
# - Test  : 20% (2006)

# %% [markdown]
# # Build Model

# %% [markdown]
# ## Feature and Actual Class

# %%
train_feature = torch.LongTensor(train_sentence_idxs)
val_feature = torch.LongTensor(val_sentence_idxs)
test_feature = torch.LongTensor(test_sentence_idxs)

train_class = torch.LongTensor(train_class_idxs)
val_class = torch.LongTensor(val_class_idxs)
test_class = torch.LongTensor(test_class_idxs)

# %%
train_feature.shape, val_feature.shape, test_feature.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %%
train_class.shape, val_class.shape, test_class.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %% [markdown]
# ## Tensor Dataset

# %%
train_dataset = TensorDataset(train_feature, train_class)
val_dataset = TensorDataset(val_feature, val_class)
test_dataset = TensorDataset(test_feature, test_class)

# %% [markdown]
# ## Dataloader

# %%
train_dataloader = DataLoader(train_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
val_dataloader = DataLoader(val_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
test_dataloader = DataLoader(test_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)

# %% [markdown]
# ## Model

# %%
class POSTagger(nn.Module):
    def __init__(
        self,
        input_size=hyperparams.input_size,
        hidden_size=hyperparams.hidden_size,
        dropout=hyperparams.dropout,
        bias=hyperparams.bias,
        num_layers=hyperparams.num_hidden_layer,
        output_size=hyperparams.output_size,
        batch_first=hyperparams.batch_first,
        bidirectional=hyperparams.bidirectional,
        init_wb_with_kaiming_normal=hyperparams.init_wb_with_kaiming_normal
    ):
        super(POSTagger, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.num_layers = num_layers
        self.output_size = output_size
        self.batch_first = batch_first
        self.bidirectional = bidirectional
                
        self.feature = nn.LSTM(
            input_size = self.input_size,
            hidden_size = self.hidden_size,
            bias = self.bias,
            dropout = self.dropout,
            num_layers = self.num_layers,
            batch_first = self.batch_first,
            bidirectional = self.bidirectional
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(in_features=2 * self.hidden_size if hyperparams.bidirectional else self.hidden_size, out_features=self.output_size, bias=self.bias),
            nn.Softmax(dim=-1)
        )
        
        if init_wb_with_kaiming_normal:
            self.init_wb()

    def init_wb(self):
        for module in self.modules():
            if isinstance(module, (nn.Linear, nn.LSTM)):
                for name, param in module.named_parameters():
                    if "weight" in name:
                        nn.init.kaiming_normal_(param)
                    else:
                        nn.init.kaiming_normal_(param.reshape(1, -1))
        
    def forward(self, feature, hidden=None):
        output, (hidden, memory) = self.feature(feature, None)
        prob = self.classifier(output)

        return prob
    
model = POSTagger().to(hyperparams.device)
model
# Out:
# POSTagger(
#   (feature): LSTM(64, 128, bidirectional=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=24, bias=True)
#     (1): Softmax(dim=-1)
#   )
# )

# %% [markdown]
# ## Optimizer, Criterion, and Metric

# %%
optimizer = optim.Adam(model.parameters(), lr=hyperparams.lr)
criterion = nn.CrossEntropyLoss().to(hyperparams.device)
train_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", verbose=True, factor=0.5)

# %%
sum(param.numel() for param in model.parameters() if param.requires_grad)
# Out:
# 204824

# %% [markdown]
# ## Training Step

# %%
def training_step(dataloader, model, optimizer, criterion, metric, scheduler=None):
    model.train()
    
    batch_losses = []
    batch_metric_scores = []
    
    for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
        # Forward Propagation
        feature = rearrange(feature, "n s -> s n")
        actual_label = rearrange(actual_label, "n s -> s n")
        embedding = word_embeddings(feature)
        
        prob = model(
            embedding.to(hyperparams.device),
            actual_label.to(hyperparams.device)
        )
        
        prob = prob.reshape(-1, prob.shape[-1])
        actual_label = actual_label.reshape(-1)

        loss = criterion(prob, actual_label.to(hyperparams.device))
        metric_score = metric(prob, actual_label.to(hyperparams.device))
        metric_score = metric.compute()
                
        if scheduler is not None:
            scheduler.step(loss)
        
        batch_losses.append(loss.item())
        batch_metric_scores.append(metric_score)
        
        if len(dataloader) < 10:
            if batch % 1 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
        else:
            if batch % 15 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            
        # Backward Propagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Validation Step

# %%
def validation_step(dataloader, model, criterion, metric):
    model.eval()
    
    batch_losses = []
    batch_metric_scores = []
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob, actual_label.to(hyperparams.device))
            metric_score = metric.compute()

            batch_losses.append(loss.item())
            batch_metric_scores.append(metric_score)
            
            if len(dataloader) < 10 and (batch % 1 == 0 or batch == len(dataloader)):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            else:
                if batch % 15 == 0 or batch == len(dataloader):
                    batch_name = "Batch-" + str(batch)
                    print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                    with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                        f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Looping Step

# %%
now = datetime.now(pytz.timezone("Asia/Ujung_Pandang"))
path_name = now.strftime("%m-%d-%Y_%H-%M-%S")
root_path = f"../../../logs/classifier/{hyperparams.context_size}_contexts/fold_0{hyperparams.fold}/{path_name}"
os.makedirs(root_path)

def looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric, n_epoch=hyperparams.n_epoch, patience=hyperparams.patience, monitor="loss"):    
    start_time = time()
    
    epoch_training_losses = []
    epoch_training_metric_scores = []
    epoch_val_losses = []
    epoch_val_metric_scores = []
    patience_counter = 0
    
    # Hyperparameters
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write(f"HYPERPARAMETERS\n")
        f.write(f"{'-' * 80}\n")
        for name, value in vars(hyperparams).items():
            f.write(f"{name}: {value}\n")
        
        f.write("\n\nTRAINING PROGRESS\n")
        f.write(f"{'-' * 80}\n")
    
    # Training Progress
    for epoch in range(1, n_epoch + 1):
        print(f"EPOCH-{epoch}")
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"EPOCH-{epoch}\n")
            f.write(f"Training Step\n")
            
        # Training Step
        print("Training Step")
        batch_training_losses, batch_training_metric_scores = training_step(train_dataloader, model, optimizer, criterion, train_metric, scheduler=None)
        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))

        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))
        epoch_training_losses.append(epoch_training_loss.item())

        epoch_training_metric_score = torch.mean(torch.FloatTensor(batch_training_metric_scores))
        epoch_training_metric_scores.append(epoch_training_metric_score.item())
        
        # Validation Step
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"\nValidation Step\n")
            
        print("\nValidation Step")
        batch_val_losses, batch_val_metric_scores = validation_step(val_dataloader, model, criterion, val_metric)
        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))

        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))
        epoch_val_losses.append(epoch_val_loss.item())

        epoch_val_metric_score = torch.mean(torch.FloatTensor(batch_val_metric_scores))
        epoch_val_metric_scores.append(epoch_val_metric_score.item())
        
        with open(f"{root_path}/training_history.txt", "a") as f:
            if monitor == "loss":
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_losses[-1] < epoch_training_losses[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
            else:
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_metric_scores[-1] > epoch_training_metric_scores[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗\n")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
                    
            print("=" * 80, end="\n\n")
            
            f.write(f"{'=' * 80}\n\n")
            
            if patience_counter == patience:
                print(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                
                f.write(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                break
        
        train_metric.reset()
        val_metric.reset()
        
    finish_time = time()
    
    # Training plot 
    fig, (ax_loss, ax_metric_score) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    fig.suptitle(f"Training with context size = {hyperparams.context_size}")

    ax_loss.set_title("Loss")
    ax_loss.set_xlabel("Epoch")
    ax_loss.set_ylabel("Score")
    ax_loss.plot(epoch_training_losses, "green", label="Training")
    ax_loss.plot(epoch_val_losses, "orange", label="Validation")
    ax_loss.legend()
    ax_loss.grid()

    ax_metric_score.set_title("F1 Score")
    ax_metric_score.set_xlabel("Epoch")
    ax_metric_score.set_ylabel("Score")
    ax_metric_score.plot(epoch_training_metric_scores, "green", label="Training")
    ax_metric_score.plot(epoch_val_metric_scores, "orange", label="Validation")
    ax_metric_score.legend()
    ax_metric_score.grid()

    plt.savefig(f"{root_path}/training_plot.jpg", dpi=200)                        
    
    print("TRAINING SUMMARY")
    name_best_training_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_training_metric = f"Best {str(train_metric).split('(')[0]} validation".ljust(34)
    name_best_validation_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_validation_metric = f"Best {str(val_metric).split('(')[0]} validation".ljust(34)
    name_training_time = f"Training duration".ljust(34)
    name_training_date = f"Training date".ljust(34)
    
    print(f"{name_best_training_loss}: {best_training_loss:.4f}")
    print(f"{name_best_validation_loss}: {best_val_loss:.4f}")
    print(f"{name_best_training_metric}: {best_training_metric:.4f}")
    print(f"{name_best_validation_metric}: {best_val_metric:.4f}")
    print(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.")
    print(f"{name_training_date}: {now}")
    
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write("\nTRAINING SUMMARY\n")
        f.write(f"{'-' * 80}\n")
        f.write(f"{name_best_training_loss}: {best_training_loss:.4f}\n")
        f.write(f"{name_best_validation_loss}: {best_val_loss:.4f}\n")
        f.write(f"{name_best_training_metric}: {best_training_metric:.4f}\n")
        f.write(f"{name_best_validation_metric}: {best_val_metric:.4f}\n")
        f.write(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.\n")
        f.write(f"{name_training_date}: {now}\n")
    
    # Save epoch losses, epoch metric scores, model, state dict, and oov embedding dict
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_training_losses
    }).to_csv(f"{root_path}/training_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_training_metric_scores
    }).to_csv(f"{root_path}/training_metric_scores.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_val_losses
    }).to_csv(f"{root_path}/val_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_val_metric_scores
    }).to_csv(f"{root_path}/val_metric_scores.csv", index=False)    
    
    filename_model_params = f"{root_path}/model_params.pth"
    torch.save(best_state_dict, filename_model_params)
    
    return epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores

epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores = looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric)
# Out:
# EPOCH-1
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.4523 | MulticlassF1Score=0.1127
# Batch-30 : CrossEntropyLoss=2.4887 | MulticlassF1Score=0.1846
# Batch-45 : CrossEntropyLoss=2.4773 | MulticlassF1Score=0.2294
# Batch-60 : CrossEntropyLoss=2.4372 | MulticlassF1Score=0.2757
# Batch-75 : CrossEntropyLoss=2.3934 | MulticlassF1Score=0.3270
# Batch-90 : CrossEntropyLoss=2.3744 | MulticlassF1Score=0.3652
# Batch-105: CrossEntropyLoss=2.3835 | MulticlassF1Score=0.3941
# Batch-120: CrossEntropyLoss=2.3802 | MulticlassF1Score=0.4197
# Batch-135: CrossEntropyLoss=2.3453 | MulticlassF1Score=0.4415
# Batch-150: CrossEntropyLoss=2.3648 | MulticlassF1Score=0.4643
# Batch-165: CrossEntropyLoss=2.3507 | MulticlassF1Score=0.4823
# Batch-180: CrossEntropyLoss=2.3504 | MulticlassF1Score=0.4970
# Batch-195: CrossEntropyLoss=2.3592 | MulticlassF1Score=0.5098
# Batch-210: CrossEntropyLoss=2.3537 | MulticlassF1Score=0.5218
# Batch-225: CrossEntropyLoss=2.3549 | MulticlassF1Score=0.5325
# Batch-226: CrossEntropyLoss=2.3582 | MulticlassF1Score=0.5330
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3494 | MulticlassF1Score=0.6724
# Batch-30 : CrossEntropyLoss=2.3604 | MulticlassF1Score=0.6673
# Batch-45 : CrossEntropyLoss=2.3446 | MulticlassF1Score=0.6692
# Batch-60 : CrossEntropyLoss=2.3437 | MulticlassF1Score=0.6699
# Batch-63 : CrossEntropyLoss=2.3604 | MulticlassF1Score=0.6700
#
# Training   : Mean CrossEntropyLoss = 2.4040 | Mean MulticlassF1Score = 0.3715
# Validation : Mean CrossEntropyLoss = 2.3504 | Mean MulticlassF1Score = 0.6701
# ================================================================================
#
# EPOCH-2
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3557 | MulticlassF1Score=0.6732
# Batch-30 : CrossEntropyLoss=2.3284 | MulticlassF1Score=0.6758
# Batch-45 : CrossEntropyLoss=2.3489 | MulticlassF1Score=0.6757
# Batch-60 : CrossEntropyLoss=2.3294 | MulticlassF1Score=0.6799
# Batch-75 : CrossEntropyLoss=2.3238 | MulticlassF1Score=0.6874
# Batch-90 : CrossEntropyLoss=2.3275 | MulticlassF1Score=0.6910
# Batch-105: CrossEntropyLoss=2.3298 | MulticlassF1Score=0.6949
# Batch-120: CrossEntropyLoss=2.3365 | MulticlassF1Score=0.6989
# Batch-135: CrossEntropyLoss=2.3353 | MulticlassF1Score=0.7018
# Batch-150: CrossEntropyLoss=2.3272 | MulticlassF1Score=0.7035
# Batch-165: CrossEntropyLoss=2.3268 | MulticlassF1Score=0.7053
# Batch-180: CrossEntropyLoss=2.3540 | MulticlassF1Score=0.7065
# Batch-195: CrossEntropyLoss=2.3242 | MulticlassF1Score=0.7078
# Batch-210: CrossEntropyLoss=2.3394 | MulticlassF1Score=0.7091
# Batch-225: CrossEntropyLoss=2.3423 | MulticlassF1Score=0.7102
# Batch-226: CrossEntropyLoss=2.3354 | MulticlassF1Score=0.7101
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3401 | MulticlassF1Score=0.7208
# Batch-30 : CrossEntropyLoss=2.3273 | MulticlassF1Score=0.7231
# Batch-45 : CrossEntropyLoss=2.3477 | MulticlassF1Score=0.7192
# Batch-60 : CrossEntropyLoss=2.3349 | MulticlassF1Score=0.7169
# Batch-63 : CrossEntropyLoss=2.3281 | MulticlassF1Score=0.7175
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3383 | Mean MulticlassF1Score = 0.6935
# Validation : Mean CrossEntropyLoss = 2.3355 | Mean MulticlassF1Score = 0.7212
# ================================================================================
#
# EPOCH-3
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3347 | MulticlassF1Score=0.7294
# Batch-30 : CrossEntropyLoss=2.3347 | MulticlassF1Score=0.7282
# Batch-45 : CrossEntropyLoss=2.3308 | MulticlassF1Score=0.7268
# Batch-60 : CrossEntropyLoss=2.3204 | MulticlassF1Score=0.7263
# Batch-75 : CrossEntropyLoss=2.3298 | MulticlassF1Score=0.7265
# Batch-90 : CrossEntropyLoss=2.3232 | MulticlassF1Score=0.7310
# Batch-105: CrossEntropyLoss=2.3175 | MulticlassF1Score=0.7362
# Batch-120: CrossEntropyLoss=2.3131 | MulticlassF1Score=0.7407
# Batch-135: CrossEntropyLoss=2.3207 | MulticlassF1Score=0.7446
# Batch-150: CrossEntropyLoss=2.3125 | MulticlassF1Score=0.7484
# Batch-165: CrossEntropyLoss=2.3117 | MulticlassF1Score=0.7519
# Batch-180: CrossEntropyLoss=2.3009 | MulticlassF1Score=0.7555
# Batch-195: CrossEntropyLoss=2.3010 | MulticlassF1Score=0.7588
# Batch-210: CrossEntropyLoss=2.3038 | MulticlassF1Score=0.7616
# Batch-225: CrossEntropyLoss=2.3165 | MulticlassF1Score=0.7640
# Batch-226: CrossEntropyLoss=2.3077 | MulticlassF1Score=0.7641
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3154 | MulticlassF1Score=0.7836
# Batch-30 : CrossEntropyLoss=2.3161 | MulticlassF1Score=0.7874
# Batch-45 : CrossEntropyLoss=2.3160 | MulticlassF1Score=0.7884
# Batch-60 : CrossEntropyLoss=2.3202 | MulticlassF1Score=0.7903
# Batch-63 : CrossEntropyLoss=2.3175 | MulticlassF1Score=0.7900
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3214 | Mean MulticlassF1Score = 0.7411
# Validation : Mean CrossEntropyLoss = 2.3128 | Mean MulticlassF1Score = 0.7859
# ================================================================================
#
# EPOCH-4
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3217 | MulticlassF1Score=0.7900
# Batch-30 : CrossEntropyLoss=2.3035 | MulticlassF1Score=0.7939
# Batch-45 : CrossEntropyLoss=2.3226 | MulticlassF1Score=0.7923
# Batch-60 : CrossEntropyLoss=2.3062 | MulticlassF1Score=0.7946
# Batch-75 : CrossEntropyLoss=2.3151 | MulticlassF1Score=0.7950
# Batch-90 : CrossEntropyLoss=2.3043 | MulticlassF1Score=0.7938
# Batch-105: CrossEntropyLoss=2.3195 | MulticlassF1Score=0.7947
# Batch-120: CrossEntropyLoss=2.3159 | MulticlassF1Score=0.7957
# Batch-135: CrossEntropyLoss=2.3045 | MulticlassF1Score=0.7963
# Batch-150: CrossEntropyLoss=2.3278 | MulticlassF1Score=0.7968
# Batch-165: CrossEntropyLoss=2.3045 | MulticlassF1Score=0.7971
# Batch-180: CrossEntropyLoss=2.3057 | MulticlassF1Score=0.7972
# Batch-195: CrossEntropyLoss=2.3132 | MulticlassF1Score=0.7982
# Batch-210: CrossEntropyLoss=2.3079 | MulticlassF1Score=0.7993
# Batch-225: CrossEntropyLoss=2.3022 | MulticlassF1Score=0.8004
# Batch-226: CrossEntropyLoss=2.3037 | MulticlassF1Score=0.8004
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3132 | MulticlassF1Score=0.8158
# Batch-30 : CrossEntropyLoss=2.2996 | MulticlassF1Score=0.8119
# Batch-45 : CrossEntropyLoss=2.3085 | MulticlassF1Score=0.8127
# Batch-60 : CrossEntropyLoss=2.3049 | MulticlassF1Score=0.8112
# Batch-63 : CrossEntropyLoss=2.3017 | MulticlassF1Score=0.8105
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3097 | Mean MulticlassF1Score = 0.7957
# Validation : Mean CrossEntropyLoss = 2.3061 | Mean MulticlassF1Score = 0.8138
# ================================================================================
#
# EPOCH-5
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2989 | MulticlassF1Score=0.8271
# Batch-30 : CrossEntropyLoss=2.3063 | MulticlassF1Score=0.8231
# Batch-45 : CrossEntropyLoss=2.3183 | MulticlassF1Score=0.8193
# Batch-60 : CrossEntropyLoss=2.3067 | MulticlassF1Score=0.8195
# Batch-75 : CrossEntropyLoss=2.2961 | MulticlassF1Score=0.8203
# Batch-90 : CrossEntropyLoss=2.2972 | MulticlassF1Score=0.8221
# Batch-105: CrossEntropyLoss=2.3020 | MulticlassF1Score=0.8221
# Batch-120: CrossEntropyLoss=2.3051 | MulticlassF1Score=0.8230
# Batch-135: CrossEntropyLoss=2.2986 | MulticlassF1Score=0.8241
# Batch-150: CrossEntropyLoss=2.2955 | MulticlassF1Score=0.8245
# Batch-165: CrossEntropyLoss=2.2993 | MulticlassF1Score=0.8249
# Batch-180: CrossEntropyLoss=2.2974 | MulticlassF1Score=0.8251
# Batch-195: CrossEntropyLoss=2.3097 | MulticlassF1Score=0.8255
# Batch-210: CrossEntropyLoss=2.3082 | MulticlassF1Score=0.8256
# Batch-225: CrossEntropyLoss=2.3076 | MulticlassF1Score=0.8259
# Batch-226: CrossEntropyLoss=2.3117 | MulticlassF1Score=0.8259
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2866 | MulticlassF1Score=0.8232
# Batch-30 : CrossEntropyLoss=2.3120 | MulticlassF1Score=0.8241
# Batch-45 : CrossEntropyLoss=2.3099 | MulticlassF1Score=0.8240
# Batch-60 : CrossEntropyLoss=2.2963 | MulticlassF1Score=0.8241
# Batch-63 : CrossEntropyLoss=2.3134 | MulticlassF1Score=0.8240
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3018 | Mean MulticlassF1Score = 0.8236
# Validation : Mean CrossEntropyLoss = 2.3021 | Mean MulticlassF1Score = 0.8242
# ================================================================================
#
# EPOCH-6
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3046 | MulticlassF1Score=0.8363
# Batch-30 : CrossEntropyLoss=2.3100 | MulticlassF1Score=0.8308
# Batch-45 : CrossEntropyLoss=2.3008 | MulticlassF1Score=0.8302
# Batch-60 : CrossEntropyLoss=2.3068 | MulticlassF1Score=0.8303
# Batch-75 : CrossEntropyLoss=2.2985 | MulticlassF1Score=0.8314
# Batch-90 : CrossEntropyLoss=2.3041 | MulticlassF1Score=0.8322
# Batch-105: CrossEntropyLoss=2.3077 | MulticlassF1Score=0.8324
# Batch-120: CrossEntropyLoss=2.2976 | MulticlassF1Score=0.8322
# Batch-135: CrossEntropyLoss=2.2933 | MulticlassF1Score=0.8323
# Batch-150: CrossEntropyLoss=2.2993 | MulticlassF1Score=0.8319
# Batch-165: CrossEntropyLoss=2.3053 | MulticlassF1Score=0.8313
# Batch-180: CrossEntropyLoss=2.3043 | MulticlassF1Score=0.8312
# Batch-195: CrossEntropyLoss=2.2958 | MulticlassF1Score=0.8315
# Batch-210: CrossEntropyLoss=2.2904 | MulticlassF1Score=0.8319
# Batch-225: CrossEntropyLoss=2.3084 | MulticlassF1Score=0.8318
# Batch-226: CrossEntropyLoss=2.3060 | MulticlassF1Score=0.8318
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3045 | MulticlassF1Score=0.8283
# Batch-30 : CrossEntropyLoss=2.2949 | MulticlassF1Score=0.8264
# Batch-45 : CrossEntropyLoss=2.2970 | MulticlassF1Score=0.8250
# Batch-60 : CrossEntropyLoss=2.3153 | MulticlassF1Score=0.8246
# Batch-63 : CrossEntropyLoss=2.2991 | MulticlassF1Score=0.8248
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2998 | Mean MulticlassF1Score = 0.8323
# Validation : Mean CrossEntropyLoss = 2.3017 | Mean MulticlassF1Score = 0.8262
# ================================================================================
#
# EPOCH-7
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2990 | MulticlassF1Score=0.8339
# Batch-30 : CrossEntropyLoss=2.2997 | MulticlassF1Score=0.8335
# Batch-45 : CrossEntropyLoss=2.3000 | MulticlassF1Score=0.8341
# Batch-60 : CrossEntropyLoss=2.2916 | MulticlassF1Score=0.8330
# Batch-75 : CrossEntropyLoss=2.2938 | MulticlassF1Score=0.8332
# Batch-90 : CrossEntropyLoss=2.2957 | MulticlassF1Score=0.8344
# Batch-105: CrossEntropyLoss=2.3030 | MulticlassF1Score=0.8340
# Batch-120: CrossEntropyLoss=2.2986 | MulticlassF1Score=0.8331
# Batch-135: CrossEntropyLoss=2.2887 | MulticlassF1Score=0.8335
# Batch-150: CrossEntropyLoss=2.3021 | MulticlassF1Score=0.8339
# Batch-165: CrossEntropyLoss=2.3018 | MulticlassF1Score=0.8334
# Batch-180: CrossEntropyLoss=2.3030 | MulticlassF1Score=0.8330
# Batch-195: CrossEntropyLoss=2.2999 | MulticlassF1Score=0.8327
# Batch-210: CrossEntropyLoss=2.2980 | MulticlassF1Score=0.8324
# Batch-225: CrossEntropyLoss=2.2956 | MulticlassF1Score=0.8329
# Batch-226: CrossEntropyLoss=2.2979 | MulticlassF1Score=0.8330
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2994 | MulticlassF1Score=0.8273
# Batch-30 : CrossEntropyLoss=2.3085 | MulticlassF1Score=0.8234
# Batch-45 : CrossEntropyLoss=2.3076 | MulticlassF1Score=0.8247
# Batch-60 : CrossEntropyLoss=2.2961 | MulticlassF1Score=0.8254
# Batch-63 : CrossEntropyLoss=2.2975 | MulticlassF1Score=0.8257
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2993 | Mean MulticlassF1Score = 0.8339
# Validation : Mean CrossEntropyLoss = 2.3013 | Mean MulticlassF1Score = 0.8249
# ================================================================================
#
# EPOCH-8
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3051 | MulticlassF1Score=0.8383
# Batch-30 : CrossEntropyLoss=2.3022 | MulticlassF1Score=0.8342
# Batch-45 : CrossEntropyLoss=2.2924 | MulticlassF1Score=0.8332
# Batch-60 : CrossEntropyLoss=2.2969 | MulticlassF1Score=0.8334
# Batch-75 : CrossEntropyLoss=2.2980 | MulticlassF1Score=0.8341
# Batch-90 : CrossEntropyLoss=2.3030 | MulticlassF1Score=0.8355
# Batch-105: CrossEntropyLoss=2.2915 | MulticlassF1Score=0.8361
# Batch-120: CrossEntropyLoss=2.3141 | MulticlassF1Score=0.8348
# Batch-135: CrossEntropyLoss=2.2878 | MulticlassF1Score=0.8350
# Batch-150: CrossEntropyLoss=2.2907 | MulticlassF1Score=0.8354
# Batch-165: CrossEntropyLoss=2.2954 | MulticlassF1Score=0.8353
# Batch-180: CrossEntropyLoss=2.2949 | MulticlassF1Score=0.8349
# Batch-195: CrossEntropyLoss=2.2939 | MulticlassF1Score=0.8346
# Batch-210: CrossEntropyLoss=2.3029 | MulticlassF1Score=0.8349
# Batch-225: CrossEntropyLoss=2.3088 | MulticlassF1Score=0.8345
# Batch-226: CrossEntropyLoss=2.2975 | MulticlassF1Score=0.8346
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3015 | MulticlassF1Score=0.8235
# Batch-30 : CrossEntropyLoss=2.3070 | MulticlassF1Score=0.8261
# Batch-45 : CrossEntropyLoss=2.2993 | MulticlassF1Score=0.8270
# Batch-60 : CrossEntropyLoss=2.2941 | MulticlassF1Score=0.8264
# Batch-63 : CrossEntropyLoss=2.2945 | MulticlassF1Score=0.8261
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2988 | Mean MulticlassF1Score = 0.8351
# Validation : Mean CrossEntropyLoss = 2.3013 | Mean MulticlassF1Score = 0.8260
# ================================================================================
#
# EPOCH-9
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2977 | MulticlassF1Score=0.8359
# Batch-30 : CrossEntropyLoss=2.3033 | MulticlassF1Score=0.8369
# Batch-45 : CrossEntropyLoss=2.2966 | MulticlassF1Score=0.8342
# Batch-60 : CrossEntropyLoss=2.2969 | MulticlassF1Score=0.8340
# Batch-75 : CrossEntropyLoss=2.2967 | MulticlassF1Score=0.8358
# Batch-90 : CrossEntropyLoss=2.2999 | MulticlassF1Score=0.8361
# Batch-105: CrossEntropyLoss=2.3056 | MulticlassF1Score=0.8350
# Batch-120: CrossEntropyLoss=2.2953 | MulticlassF1Score=0.8358
# Batch-135: CrossEntropyLoss=2.2979 | MulticlassF1Score=0.8360
# Batch-150: CrossEntropyLoss=2.2956 | MulticlassF1Score=0.8359
# Batch-165: CrossEntropyLoss=2.2988 | MulticlassF1Score=0.8356
# Batch-180: CrossEntropyLoss=2.2935 | MulticlassF1Score=0.8360
# Batch-195: CrossEntropyLoss=2.3001 | MulticlassF1Score=0.8358
# Batch-210: CrossEntropyLoss=2.3036 | MulticlassF1Score=0.8358
# Batch-225: CrossEntropyLoss=2.3023 | MulticlassF1Score=0.8360
# Batch-226: CrossEntropyLoss=2.3026 | MulticlassF1Score=0.8360
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3037 | MulticlassF1Score=0.8250
# Batch-30 : CrossEntropyLoss=2.3034 | MulticlassF1Score=0.8250
# Batch-45 : CrossEntropyLoss=2.2908 | MulticlassF1Score=0.8258
# Batch-60 : CrossEntropyLoss=2.3020 | MulticlassF1Score=0.8273
# Batch-63 : CrossEntropyLoss=2.2994 | MulticlassF1Score=0.8268
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2983 | Mean MulticlassF1Score = 0.8356
# Validation : Mean CrossEntropyLoss = 2.3009 | Mean MulticlassF1Score = 0.8248
# ================================================================================
#
# EPOCH-10
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2938 | MulticlassF1Score=0.8425
# Batch-30 : CrossEntropyLoss=2.2902 | MulticlassF1Score=0.8416
# Batch-45 : CrossEntropyLoss=2.3073 | MulticlassF1Score=0.8397
# Batch-60 : CrossEntropyLoss=2.2947 | MulticlassF1Score=0.8390
# Batch-75 : CrossEntropyLoss=2.2944 | MulticlassF1Score=0.8407
# Batch-90 : CrossEntropyLoss=2.3041 | MulticlassF1Score=0.8412
# Batch-105: CrossEntropyLoss=2.2899 | MulticlassF1Score=0.8415
# Batch-120: CrossEntropyLoss=2.2988 | MulticlassF1Score=0.8418
# Batch-135: CrossEntropyLoss=2.3077 | MulticlassF1Score=0.8416
# Batch-150: CrossEntropyLoss=2.2866 | MulticlassF1Score=0.8430
# Batch-165: CrossEntropyLoss=2.2993 | MulticlassF1Score=0.8444
# Batch-180: CrossEntropyLoss=2.2979 | MulticlassF1Score=0.8456
# Batch-195: CrossEntropyLoss=2.2918 | MulticlassF1Score=0.8466
# Batch-210: CrossEntropyLoss=2.2887 | MulticlassF1Score=0.8474
# Batch-225: CrossEntropyLoss=2.2910 | MulticlassF1Score=0.8483
# Batch-226: CrossEntropyLoss=2.2822 | MulticlassF1Score=0.8483
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2901 | MulticlassF1Score=0.8540
# Batch-30 : CrossEntropyLoss=2.2980 | MulticlassF1Score=0.8525
# Batch-45 : CrossEntropyLoss=2.2880 | MulticlassF1Score=0.8526
# Batch-60 : CrossEntropyLoss=2.2989 | MulticlassF1Score=0.8519
# Batch-63 : CrossEntropyLoss=2.2983 | MulticlassF1Score=0.8518
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2947 | Mean MulticlassF1Score = 0.8427
# Validation : Mean CrossEntropyLoss = 2.2936 | Mean MulticlassF1Score = 0.8523
# ================================================================================
#
# EPOCH-11
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2974 | MulticlassF1Score=0.8663
# Batch-30 : CrossEntropyLoss=2.2957 | MulticlassF1Score=0.8617
# Batch-45 : CrossEntropyLoss=2.2937 | MulticlassF1Score=0.8611
# Batch-60 : CrossEntropyLoss=2.2915 | MulticlassF1Score=0.8612
# Batch-75 : CrossEntropyLoss=2.2844 | MulticlassF1Score=0.8616
# Batch-90 : CrossEntropyLoss=2.2874 | MulticlassF1Score=0.8625
# Batch-105: CrossEntropyLoss=2.2895 | MulticlassF1Score=0.8629
# Batch-120: CrossEntropyLoss=2.2926 | MulticlassF1Score=0.8622
# Batch-135: CrossEntropyLoss=2.2850 | MulticlassF1Score=0.8621
# Batch-150: CrossEntropyLoss=2.2932 | MulticlassF1Score=0.8615
# Batch-165: CrossEntropyLoss=2.2919 | MulticlassF1Score=0.8616
# Batch-180: CrossEntropyLoss=2.2945 | MulticlassF1Score=0.8613
# Batch-195: CrossEntropyLoss=2.2928 | MulticlassF1Score=0.8612
# Batch-210: CrossEntropyLoss=2.2904 | MulticlassF1Score=0.8613
# Batch-225: CrossEntropyLoss=2.2810 | MulticlassF1Score=0.8610
# Batch-226: CrossEntropyLoss=2.2885 | MulticlassF1Score=0.8610
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2920 | MulticlassF1Score=0.8573
# Batch-30 : CrossEntropyLoss=2.2922 | MulticlassF1Score=0.8545
# Batch-45 : CrossEntropyLoss=2.2947 | MulticlassF1Score=0.8526
# Batch-60 : CrossEntropyLoss=2.2868 | MulticlassF1Score=0.8523
# Batch-63 : CrossEntropyLoss=2.2948 | MulticlassF1Score=0.8524
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2908 | Mean MulticlassF1Score = 0.8623
# Validation : Mean CrossEntropyLoss = 2.2932 | Mean MulticlassF1Score = 0.8541
# ================================================================================
#
# EPOCH-12
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2968 | MulticlassF1Score=0.8560
# Batch-30 : CrossEntropyLoss=2.2949 | MulticlassF1Score=0.8631
# Batch-45 : CrossEntropyLoss=2.2848 | MulticlassF1Score=0.8630
# Batch-60 : CrossEntropyLoss=2.2886 | MulticlassF1Score=0.8631
# Batch-75 : CrossEntropyLoss=2.2836 | MulticlassF1Score=0.8637
# Batch-90 : CrossEntropyLoss=2.2845 | MulticlassF1Score=0.8625
# Batch-105: CrossEntropyLoss=2.2903 | MulticlassF1Score=0.8624
# Batch-120: CrossEntropyLoss=2.2831 | MulticlassF1Score=0.8624
# Batch-135: CrossEntropyLoss=2.2842 | MulticlassF1Score=0.8624
# Batch-150: CrossEntropyLoss=2.2849 | MulticlassF1Score=0.8631
# Batch-165: CrossEntropyLoss=2.2866 | MulticlassF1Score=0.8643
# Batch-180: CrossEntropyLoss=2.2870 | MulticlassF1Score=0.8662
# Batch-195: CrossEntropyLoss=2.2869 | MulticlassF1Score=0.8674
# Batch-210: CrossEntropyLoss=2.2846 | MulticlassF1Score=0.8688
# Batch-225: CrossEntropyLoss=2.2833 | MulticlassF1Score=0.8701
# Batch-226: CrossEntropyLoss=2.2814 | MulticlassF1Score=0.8702
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2904 | MulticlassF1Score=0.8806
# Batch-30 : CrossEntropyLoss=2.2811 | MulticlassF1Score=0.8809
# Batch-45 : CrossEntropyLoss=2.2824 | MulticlassF1Score=0.8818
# Batch-60 : CrossEntropyLoss=2.2954 | MulticlassF1Score=0.8807
# Batch-63 : CrossEntropyLoss=2.2918 | MulticlassF1Score=0.8806
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2880 | Mean MulticlassF1Score = 0.8634
# Validation : Mean CrossEntropyLoss = 2.2850 | Mean MulticlassF1Score = 0.8805
# ================================================================================
#
# EPOCH-13
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2769 | MulticlassF1Score=0.8926
# Batch-30 : CrossEntropyLoss=2.2823 | MulticlassF1Score=0.8907
# Batch-45 : CrossEntropyLoss=2.2866 | MulticlassF1Score=0.8910
# Batch-60 : CrossEntropyLoss=2.2829 | MulticlassF1Score=0.8921
# Batch-75 : CrossEntropyLoss=2.2813 | MulticlassF1Score=0.8934
# Batch-90 : CrossEntropyLoss=2.2917 | MulticlassF1Score=0.8923
# Batch-105: CrossEntropyLoss=2.2770 | MulticlassF1Score=0.8916
# Batch-120: CrossEntropyLoss=2.2757 | MulticlassF1Score=0.8920
# Batch-135: CrossEntropyLoss=2.2791 | MulticlassF1Score=0.8918
# Batch-150: CrossEntropyLoss=2.2807 | MulticlassF1Score=0.8918
# Batch-165: CrossEntropyLoss=2.2763 | MulticlassF1Score=0.8916
# Batch-180: CrossEntropyLoss=2.2836 | MulticlassF1Score=0.8917
# Batch-195: CrossEntropyLoss=2.2912 | MulticlassF1Score=0.8920
# Batch-210: CrossEntropyLoss=2.2779 | MulticlassF1Score=0.8921
# Batch-225: CrossEntropyLoss=2.2821 | MulticlassF1Score=0.8921
# Batch-226: CrossEntropyLoss=2.2795 | MulticlassF1Score=0.8921
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2862 | MulticlassF1Score=0.8853
# Batch-30 : CrossEntropyLoss=2.2867 | MulticlassF1Score=0.8834
# Batch-45 : CrossEntropyLoss=2.2820 | MulticlassF1Score=0.8827
# Batch-60 : CrossEntropyLoss=2.2819 | MulticlassF1Score=0.8820
# Batch-63 : CrossEntropyLoss=2.2864 | MulticlassF1Score=0.8818
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2813 | Mean MulticlassF1Score = 0.8920
# Validation : Mean CrossEntropyLoss = 2.2843 | Mean MulticlassF1Score = 0.8833
# ================================================================================
#
# EPOCH-14
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2835 | MulticlassF1Score=0.8915
# Batch-30 : CrossEntropyLoss=2.2748 | MulticlassF1Score=0.8923
# Batch-45 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.8946
# Batch-60 : CrossEntropyLoss=2.2803 | MulticlassF1Score=0.8959
# Batch-75 : CrossEntropyLoss=2.2806 | MulticlassF1Score=0.8956
# Batch-90 : CrossEntropyLoss=2.2768 | MulticlassF1Score=0.8961
# Batch-105: CrossEntropyLoss=2.2773 | MulticlassF1Score=0.8958
# Batch-120: CrossEntropyLoss=2.2778 | MulticlassF1Score=0.8952
# Batch-135: CrossEntropyLoss=2.2783 | MulticlassF1Score=0.8946
# Batch-150: CrossEntropyLoss=2.2829 | MulticlassF1Score=0.8950
# Batch-165: CrossEntropyLoss=2.2804 | MulticlassF1Score=0.8954
# Batch-180: CrossEntropyLoss=2.2845 | MulticlassF1Score=0.8956
# Batch-195: CrossEntropyLoss=2.2804 | MulticlassF1Score=0.8955
# Batch-210: CrossEntropyLoss=2.2765 | MulticlassF1Score=0.8949
# Batch-225: CrossEntropyLoss=2.2824 | MulticlassF1Score=0.8948
# Batch-226: CrossEntropyLoss=2.2851 | MulticlassF1Score=0.8948
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2905 | MulticlassF1Score=0.8858
# Batch-30 : CrossEntropyLoss=2.2808 | MulticlassF1Score=0.8847
# Batch-45 : CrossEntropyLoss=2.2895 | MulticlassF1Score=0.8831
# Batch-60 : CrossEntropyLoss=2.2870 | MulticlassF1Score=0.8838
# Batch-63 : CrossEntropyLoss=2.2748 | MulticlassF1Score=0.8836
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2803 | Mean MulticlassF1Score = 0.8947
# Validation : Mean CrossEntropyLoss = 2.2836 | Mean MulticlassF1Score = 0.8853
# ================================================================================
#
# EPOCH-15
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2720 | MulticlassF1Score=0.8963
# Batch-30 : CrossEntropyLoss=2.2856 | MulticlassF1Score=0.8964
# Batch-45 : CrossEntropyLoss=2.2767 | MulticlassF1Score=0.8975
# Batch-60 : CrossEntropyLoss=2.2779 | MulticlassF1Score=0.8977
# Batch-75 : CrossEntropyLoss=2.2834 | MulticlassF1Score=0.8979
# Batch-90 : CrossEntropyLoss=2.2850 | MulticlassF1Score=0.8976
# Batch-105: CrossEntropyLoss=2.2791 | MulticlassF1Score=0.8983
# Batch-120: CrossEntropyLoss=2.2836 | MulticlassF1Score=0.8983
# Batch-135: CrossEntropyLoss=2.2715 | MulticlassF1Score=0.8988
# Batch-150: CrossEntropyLoss=2.2828 | MulticlassF1Score=0.8988
# Batch-165: CrossEntropyLoss=2.2852 | MulticlassF1Score=0.8988
# Batch-180: CrossEntropyLoss=2.2827 | MulticlassF1Score=0.8990
# Batch-195: CrossEntropyLoss=2.2841 | MulticlassF1Score=0.8990
# Batch-210: CrossEntropyLoss=2.2839 | MulticlassF1Score=0.8990
# Batch-225: CrossEntropyLoss=2.2754 | MulticlassF1Score=0.8990
# Batch-226: CrossEntropyLoss=2.2817 | MulticlassF1Score=0.8990
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.8914
# Batch-30 : CrossEntropyLoss=2.2873 | MulticlassF1Score=0.8889
# Batch-45 : CrossEntropyLoss=2.2766 | MulticlassF1Score=0.8885
# Batch-60 : CrossEntropyLoss=2.2819 | MulticlassF1Score=0.8894
# Batch-63 : CrossEntropyLoss=2.2891 | MulticlassF1Score=0.8889
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2790 | Mean MulticlassF1Score = 0.8979
# Validation : Mean CrossEntropyLoss = 2.2821 | Mean MulticlassF1Score = 0.8908
# ================================================================================
#
# EPOCH-16
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2790 | MulticlassF1Score=0.9021
# Batch-30 : CrossEntropyLoss=2.2785 | MulticlassF1Score=0.9013
# Batch-45 : CrossEntropyLoss=2.2808 | MulticlassF1Score=0.9016
# Batch-60 : CrossEntropyLoss=2.2785 | MulticlassF1Score=0.9016
# Batch-75 : CrossEntropyLoss=2.2776 | MulticlassF1Score=0.9013
# Batch-90 : CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9015
# Batch-105: CrossEntropyLoss=2.2787 | MulticlassF1Score=0.9020
# Batch-120: CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9026
# Batch-135: CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9023
# Batch-150: CrossEntropyLoss=2.2791 | MulticlassF1Score=0.9023
# Batch-165: CrossEntropyLoss=2.2784 | MulticlassF1Score=0.9025
# Batch-180: CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9026
# Batch-195: CrossEntropyLoss=2.2773 | MulticlassF1Score=0.9023
# Batch-210: CrossEntropyLoss=2.2828 | MulticlassF1Score=0.9019
# Batch-225: CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9022
# Batch-226: CrossEntropyLoss=2.2845 | MulticlassF1Score=0.9022
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2757 | MulticlassF1Score=0.8908
# Batch-30 : CrossEntropyLoss=2.2820 | MulticlassF1Score=0.8875
# Batch-45 : CrossEntropyLoss=2.2781 | MulticlassF1Score=0.8873
# Batch-60 : CrossEntropyLoss=2.2804 | MulticlassF1Score=0.8891
# Batch-63 : CrossEntropyLoss=2.2760 | MulticlassF1Score=0.8889
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2780 | Mean MulticlassF1Score = 0.9021
# Validation : Mean CrossEntropyLoss = 2.2820 | Mean MulticlassF1Score = 0.8892
# ================================================================================
#
# EPOCH-17
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2786 | MulticlassF1Score=0.9067
# Batch-30 : CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9049
# Batch-45 : CrossEntropyLoss=2.2776 | MulticlassF1Score=0.9044
# Batch-60 : CrossEntropyLoss=2.2840 | MulticlassF1Score=0.9043
# Batch-75 : CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9050
# Batch-90 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9054
# Batch-105: CrossEntropyLoss=2.2754 | MulticlassF1Score=0.9056
# Batch-120: CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9051
# Batch-135: CrossEntropyLoss=2.2793 | MulticlassF1Score=0.9041
# Batch-150: CrossEntropyLoss=2.2772 | MulticlassF1Score=0.9042
# Batch-165: CrossEntropyLoss=2.2805 | MulticlassF1Score=0.9042
# Batch-180: CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9044
# Batch-195: CrossEntropyLoss=2.2777 | MulticlassF1Score=0.9040
# Batch-210: CrossEntropyLoss=2.2803 | MulticlassF1Score=0.9039
# Batch-225: CrossEntropyLoss=2.2758 | MulticlassF1Score=0.9037
# Batch-226: CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9038
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2878 | MulticlassF1Score=0.8849
# Batch-30 : CrossEntropyLoss=2.2790 | MulticlassF1Score=0.8871
# Batch-45 : CrossEntropyLoss=2.2725 | MulticlassF1Score=0.8880
# Batch-60 : CrossEntropyLoss=2.2926 | MulticlassF1Score=0.8891
# Batch-63 : CrossEntropyLoss=2.2813 | MulticlassF1Score=0.8894
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2774 | Mean MulticlassF1Score = 0.9046
# Validation : Mean CrossEntropyLoss = 2.2817 | Mean MulticlassF1Score = 0.8864
# ================================================================================
#
# EPOCH-18
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2801 | MulticlassF1Score=0.9085
# Batch-30 : CrossEntropyLoss=2.2785 | MulticlassF1Score=0.9054
# Batch-45 : CrossEntropyLoss=2.2751 | MulticlassF1Score=0.9079
# Batch-60 : CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9076
# Batch-75 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9063
# Batch-90 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9066
# Batch-105: CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9063
# Batch-120: CrossEntropyLoss=2.2796 | MulticlassF1Score=0.9059
# Batch-135: CrossEntropyLoss=2.2766 | MulticlassF1Score=0.9057
# Batch-150: CrossEntropyLoss=2.2854 | MulticlassF1Score=0.9054
# Batch-165: CrossEntropyLoss=2.2821 | MulticlassF1Score=0.9056
# Batch-180: CrossEntropyLoss=2.2771 | MulticlassF1Score=0.9059
# Batch-195: CrossEntropyLoss=2.2845 | MulticlassF1Score=0.9059
# Batch-210: CrossEntropyLoss=2.2754 | MulticlassF1Score=0.9061
# Batch-225: CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9063
# Batch-226: CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9064
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2809 | MulticlassF1Score=0.8975
# Batch-30 : CrossEntropyLoss=2.2766 | MulticlassF1Score=0.8963
# Batch-45 : CrossEntropyLoss=2.2802 | MulticlassF1Score=0.8943
# Batch-60 : CrossEntropyLoss=2.2905 | MulticlassF1Score=0.8931
# Batch-63 : CrossEntropyLoss=2.2767 | MulticlassF1Score=0.8938
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2766 | Mean MulticlassF1Score = 0.9064
# Validation : Mean CrossEntropyLoss = 2.2804 | Mean MulticlassF1Score = 0.8947
# ================================================================================
#
# EPOCH-19
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2799 | MulticlassF1Score=0.9063
# Batch-30 : CrossEntropyLoss=2.2767 | MulticlassF1Score=0.9076
# Batch-45 : CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9080
# Batch-60 : CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9077
# Batch-75 : CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9075
# Batch-90 : CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9081
# Batch-105: CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9085
# Batch-120: CrossEntropyLoss=2.2804 | MulticlassF1Score=0.9084
# Batch-135: CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9088
# Batch-150: CrossEntropyLoss=2.2769 | MulticlassF1Score=0.9088
# Batch-165: CrossEntropyLoss=2.2808 | MulticlassF1Score=0.9087
# Batch-180: CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9087
# Batch-195: CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9089
# Batch-210: CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9091
# Batch-225: CrossEntropyLoss=2.2812 | MulticlassF1Score=0.9092
# Batch-226: CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9092
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2815 | MulticlassF1Score=0.8962
# Batch-30 : CrossEntropyLoss=2.2840 | MulticlassF1Score=0.8950
# Batch-45 : CrossEntropyLoss=2.2822 | MulticlassF1Score=0.8944
# Batch-60 : CrossEntropyLoss=2.2860 | MulticlassF1Score=0.8933
# Batch-63 : CrossEntropyLoss=2.2759 | MulticlassF1Score=0.8932
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2756 | Mean MulticlassF1Score = 0.9082
# Validation : Mean CrossEntropyLoss = 2.2805 | Mean MulticlassF1Score = 0.8944
# ================================================================================
#
# EPOCH-20
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2801 | MulticlassF1Score=0.9112
# Batch-30 : CrossEntropyLoss=2.2765 | MulticlassF1Score=0.9100
# Batch-45 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9090
# Batch-60 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9092
# Batch-75 : CrossEntropyLoss=2.2773 | MulticlassF1Score=0.9104
# Batch-90 : CrossEntropyLoss=2.2869 | MulticlassF1Score=0.9096
# Batch-105: CrossEntropyLoss=2.2816 | MulticlassF1Score=0.9096
# Batch-120: CrossEntropyLoss=2.2790 | MulticlassF1Score=0.9094
# Batch-135: CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9101
# Batch-150: CrossEntropyLoss=2.2782 | MulticlassF1Score=0.9098
# Batch-165: CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9099
# Batch-180: CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9100
# Batch-195: CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9102
# Batch-210: CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9104
# Batch-225: CrossEntropyLoss=2.2797 | MulticlassF1Score=0.9102
# Batch-226: CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9102
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2805 | MulticlassF1Score=0.8979
# Batch-30 : CrossEntropyLoss=2.2794 | MulticlassF1Score=0.8956
# Batch-45 : CrossEntropyLoss=2.2805 | MulticlassF1Score=0.8954
# Batch-60 : CrossEntropyLoss=2.2831 | MulticlassF1Score=0.8945
# Batch-63 : CrossEntropyLoss=2.2814 | MulticlassF1Score=0.8945
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2754 | Mean MulticlassF1Score = 0.9101
# Validation : Mean CrossEntropyLoss = 2.2802 | Mean MulticlassF1Score = 0.8955
# ================================================================================
#
# EPOCH-21
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9155
# Batch-30 : CrossEntropyLoss=2.2781 | MulticlassF1Score=0.9168
# Batch-45 : CrossEntropyLoss=2.2758 | MulticlassF1Score=0.9166
# Batch-60 : CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9143
# Batch-75 : CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9144
# Batch-90 : CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9138
# Batch-105: CrossEntropyLoss=2.2747 | MulticlassF1Score=0.9134
# Batch-120: CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9122
# Batch-135: CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9121
# Batch-150: CrossEntropyLoss=2.2816 | MulticlassF1Score=0.9122
# Batch-165: CrossEntropyLoss=2.2787 | MulticlassF1Score=0.9121
# Batch-180: CrossEntropyLoss=2.2754 | MulticlassF1Score=0.9124
# Batch-195: CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9117
# Batch-210: CrossEntropyLoss=2.2762 | MulticlassF1Score=0.9117
# Batch-225: CrossEntropyLoss=2.2783 | MulticlassF1Score=0.9112
# Batch-226: CrossEntropyLoss=2.2814 | MulticlassF1Score=0.9112
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2784 | MulticlassF1Score=0.8936
# Batch-30 : CrossEntropyLoss=2.2832 | MulticlassF1Score=0.8943
# Batch-45 : CrossEntropyLoss=2.2806 | MulticlassF1Score=0.8942
# Batch-60 : CrossEntropyLoss=2.2775 | MulticlassF1Score=0.8939
# Batch-63 : CrossEntropyLoss=2.2904 | MulticlassF1Score=0.8941
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2750 | Mean MulticlassF1Score = 0.9136
# Validation : Mean CrossEntropyLoss = 2.2802 | Mean MulticlassF1Score = 0.8943
# ================================================================================
#
# EPOCH-22
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9148
# Batch-30 : CrossEntropyLoss=2.2797 | MulticlassF1Score=0.9146
# Batch-45 : CrossEntropyLoss=2.2774 | MulticlassF1Score=0.9118
# Batch-60 : CrossEntropyLoss=2.2810 | MulticlassF1Score=0.9113
# Batch-75 : CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9112
# Batch-90 : CrossEntropyLoss=2.2762 | MulticlassF1Score=0.9108
# Batch-105: CrossEntropyLoss=2.2775 | MulticlassF1Score=0.9108
# Batch-120: CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9110
# Batch-135: CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9115
# Batch-150: CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9116
# Batch-165: CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9117
# Batch-180: CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9113
# Batch-195: CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9118
# Batch-210: CrossEntropyLoss=2.2770 | MulticlassF1Score=0.9117
# Batch-225: CrossEntropyLoss=2.2775 | MulticlassF1Score=0.9115
# Batch-226: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9115
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2823 | MulticlassF1Score=0.8936
# Batch-30 : CrossEntropyLoss=2.2844 | MulticlassF1Score=0.8939
# Batch-45 : CrossEntropyLoss=2.2858 | MulticlassF1Score=0.8943
# Batch-60 : CrossEntropyLoss=2.2983 | MulticlassF1Score=0.8936
# Batch-63 : CrossEntropyLoss=2.2736 | MulticlassF1Score=0.8941
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2749 | Mean MulticlassF1Score = 0.9122
# Validation : Mean CrossEntropyLoss = 2.2802 | Mean MulticlassF1Score = 0.8950
# ================================================================================
#
# EPOCH-23
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9135
# Batch-30 : CrossEntropyLoss=2.2775 | MulticlassF1Score=0.9111
# Batch-45 : CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9126
# Batch-60 : CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9138
# Batch-75 : CrossEntropyLoss=2.2759 | MulticlassF1Score=0.9133
# Batch-90 : CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9135
# Batch-105: CrossEntropyLoss=2.2756 | MulticlassF1Score=0.9135
# Batch-120: CrossEntropyLoss=2.2796 | MulticlassF1Score=0.9133
# Batch-135: CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9130
# Batch-150: CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9131
# Batch-165: CrossEntropyLoss=2.2846 | MulticlassF1Score=0.9125
# Batch-180: CrossEntropyLoss=2.2827 | MulticlassF1Score=0.9125
# Batch-195: CrossEntropyLoss=2.2775 | MulticlassF1Score=0.9124
# Batch-210: CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9123
# Batch-225: CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9123
# Batch-226: CrossEntropyLoss=2.2775 | MulticlassF1Score=0.9122
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2832 | MulticlassF1Score=0.8959
# Batch-30 : CrossEntropyLoss=2.2817 | MulticlassF1Score=0.8949
# Batch-45 : CrossEntropyLoss=2.2869 | MulticlassF1Score=0.8940
# Batch-60 : CrossEntropyLoss=2.2753 | MulticlassF1Score=0.8949
# Batch-63 : CrossEntropyLoss=2.2800 | MulticlassF1Score=0.8943
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2746 | Mean MulticlassF1Score = 0.9124
# Validation : Mean CrossEntropyLoss = 2.2802 | Mean MulticlassF1Score = 0.8947
# ================================================================================
#
# EPOCH-24
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2759 | MulticlassF1Score=0.9132
# Batch-30 : CrossEntropyLoss=2.2783 | MulticlassF1Score=0.9131
# Batch-45 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9126
# Batch-60 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9116
# Batch-75 : CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9112
# Batch-90 : CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9120
# Batch-105: CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9118
# Batch-120: CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9124
# Batch-135: CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9128
# Batch-150: CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9128
# Batch-165: CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9126
# Batch-180: CrossEntropyLoss=2.2769 | MulticlassF1Score=0.9125
# Batch-195: CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9122
# Batch-210: CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9126
# Batch-225: CrossEntropyLoss=2.2793 | MulticlassF1Score=0.9124
# Batch-226: CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9125
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2775 | MulticlassF1Score=0.8969
# Batch-30 : CrossEntropyLoss=2.2775 | MulticlassF1Score=0.8960
# Batch-45 : CrossEntropyLoss=2.2758 | MulticlassF1Score=0.8943
# Batch-60 : CrossEntropyLoss=2.2789 | MulticlassF1Score=0.8942
# Batch-63 : CrossEntropyLoss=2.2829 | MulticlassF1Score=0.8942
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2746 | Mean MulticlassF1Score = 0.9125
# Validation : Mean CrossEntropyLoss = 2.2801 | Mean MulticlassF1Score = 0.8957
# ================================================================================
#
# EPOCH-25
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9154
# Batch-30 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9149
# Batch-45 : CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9130
# Batch-60 : CrossEntropyLoss=2.2847 | MulticlassF1Score=0.9130
# Batch-75 : CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9144
# Batch-90 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9142
# Batch-105: CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9141
# Batch-120: CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9137
# Batch-135: CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9135
# Batch-150: CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9132
# Batch-165: CrossEntropyLoss=2.2762 | MulticlassF1Score=0.9127
# Batch-180: CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9130
# Batch-195: CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9130
# Batch-210: CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9130
# Batch-225: CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9128
# Batch-226: CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9129
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2764 | MulticlassF1Score=0.8935
# Batch-30 : CrossEntropyLoss=2.2749 | MulticlassF1Score=0.8945
# Batch-45 : CrossEntropyLoss=2.2772 | MulticlassF1Score=0.8939
# Batch-60 : CrossEntropyLoss=2.2782 | MulticlassF1Score=0.8943
# Batch-63 : CrossEntropyLoss=2.2829 | MulticlassF1Score=0.8945
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2744 | Mean MulticlassF1Score = 0.9134
# Validation : Mean CrossEntropyLoss = 2.2800 | Mean MulticlassF1Score = 0.8945
# ================================================================================
#
# EPOCH-26
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9139
# Batch-30 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9134
# Batch-45 : CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9140
# Batch-60 : CrossEntropyLoss=2.2766 | MulticlassF1Score=0.9139
# Batch-75 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9140
# Batch-90 : CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9143
# Batch-105: CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9146
# Batch-120: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9148
# Batch-135: CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9146
# Batch-150: CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9143
# Batch-165: CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9138
# Batch-180: CrossEntropyLoss=2.2758 | MulticlassF1Score=0.9136
# Batch-195: CrossEntropyLoss=2.2817 | MulticlassF1Score=0.9137
# Batch-210: CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9135
# Batch-225: CrossEntropyLoss=2.2765 | MulticlassF1Score=0.9132
# Batch-226: CrossEntropyLoss=2.2816 | MulticlassF1Score=0.9131
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2900 | MulticlassF1Score=0.8962
# Batch-30 : CrossEntropyLoss=2.2743 | MulticlassF1Score=0.8961
# Batch-45 : CrossEntropyLoss=2.2821 | MulticlassF1Score=0.8958
# Batch-60 : CrossEntropyLoss=2.2766 | MulticlassF1Score=0.8954
# Batch-63 : CrossEntropyLoss=2.2737 | MulticlassF1Score=0.8950
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2744 | Mean MulticlassF1Score = 0.9141
# Validation : Mean CrossEntropyLoss = 2.2799 | Mean MulticlassF1Score = 0.8963
# ================================================================================
#
# EPOCH-27
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9154
# Batch-30 : CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9145
# Batch-45 : CrossEntropyLoss=2.2845 | MulticlassF1Score=0.9132
# Batch-60 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9135
# Batch-75 : CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9134
# Batch-90 : CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9140
# Batch-105: CrossEntropyLoss=2.2761 | MulticlassF1Score=0.9144
# Batch-120: CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9147
# Batch-135: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9143
# Batch-150: CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9143
# Batch-165: CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9141
# Batch-180: CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9138
# Batch-195: CrossEntropyLoss=2.2773 | MulticlassF1Score=0.9136
# Batch-210: CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9136
# Batch-225: CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9137
# Batch-226: CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9137
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.8954
# Batch-30 : CrossEntropyLoss=2.2874 | MulticlassF1Score=0.8970
# Batch-45 : CrossEntropyLoss=2.2816 | MulticlassF1Score=0.8962
# Batch-60 : CrossEntropyLoss=2.2866 | MulticlassF1Score=0.8957
# Batch-63 : CrossEntropyLoss=2.2783 | MulticlassF1Score=0.8955
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2741 | Mean MulticlassF1Score = 0.9141
# Validation : Mean CrossEntropyLoss = 2.2797 | Mean MulticlassF1Score = 0.8969
# ================================================================================
#
# EPOCH-28
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2815 | MulticlassF1Score=0.9126
# Batch-30 : CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9148
# Batch-45 : CrossEntropyLoss=2.2774 | MulticlassF1Score=0.9141
# Batch-60 : CrossEntropyLoss=2.2769 | MulticlassF1Score=0.9141
# Batch-75 : CrossEntropyLoss=2.2802 | MulticlassF1Score=0.9133
# Batch-90 : CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9136
# Batch-105: CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9135
# Batch-120: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9152
# Batch-135: CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9175
# Batch-150: CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9192
# Batch-165: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9210
# Batch-180: CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9224
# Batch-195: CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9239
# Batch-210: CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9249
# Batch-225: CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9260
# Batch-226: CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9261
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9241
# Batch-30 : CrossEntropyLoss=2.2774 | MulticlassF1Score=0.9211
# Batch-45 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9218
# Batch-60 : CrossEntropyLoss=2.2781 | MulticlassF1Score=0.9231
# Batch-63 : CrossEntropyLoss=2.2826 | MulticlassF1Score=0.9228
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2704 | Mean MulticlassF1Score = 0.9174
# Validation : Mean CrossEntropyLoss = 2.2717 | Mean MulticlassF1Score = 0.9225
# ================================================================================
#
# EPOCH-29
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9410
# Batch-30 : CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9404
# Batch-45 : CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9417
# Batch-60 : CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9422
# Batch-75 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9421
# Batch-90 : CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9424
# Batch-105: CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9427
# Batch-120: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9432
# Batch-135: CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9429
# Batch-150: CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9425
# Batch-165: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9424
# Batch-180: CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9422
# ...
# Batch-45 : CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9471
# Batch-60 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9467
# Batch-63 : CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9469
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2570 | Mean MulticlassF1Score = 0.9705
# Validation : Mean CrossEntropyLoss = 2.2640 | Mean MulticlassF1Score = 0.9449
# ================================================================================
#
# EPOCH-42
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9696
# Batch-30 : CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9708
# Batch-45 : CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9697
# Batch-60 : CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9697
# Batch-75 : CrossEntropyLoss=2.2527 | MulticlassF1Score=0.9696
# Batch-90 : CrossEntropyLoss=2.2603 | MulticlassF1Score=0.9695
# Batch-105: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9695
# Batch-120: CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9695
# Batch-135: CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9695
# Batch-150: CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9694
# Batch-165: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9695
# Batch-180: CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9693
# Batch-195: CrossEntropyLoss=2.2532 | MulticlassF1Score=0.9695
# Batch-210: CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9693
# Batch-225: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9694
# Batch-226: CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9694
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9462
# Batch-30 : CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9479
# Batch-45 : CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9483
# Batch-60 : CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9477
# Batch-63 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9478
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2569 | Mean MulticlassF1Score = 0.9698
# Validation : Mean CrossEntropyLoss = 2.2637 | Mean MulticlassF1Score = 0.9479
# ================================================================================
#
# EPOCH-43
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2551 | MulticlassF1Score=0.9718
# Batch-30 : CrossEntropyLoss=2.2532 | MulticlassF1Score=0.9702
# Batch-45 : CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9706
# Batch-60 : CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9704
# Batch-75 : CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9705
# Batch-90 : CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9704
# Batch-105: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9702
# Batch-120: CrossEntropyLoss=2.2597 | MulticlassF1Score=0.9699
# Batch-135: CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9698
# Batch-150: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9696
# Batch-165: CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9695
# Batch-180: CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9692
# Batch-195: CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9691
# Batch-210: CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9690
# Batch-225: CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9689
# Batch-226: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9689
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9453
# Batch-30 : CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9459
# Batch-45 : CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9462
# Batch-60 : CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9463
# Batch-63 : CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9469
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2571 | Mean MulticlassF1Score = 0.9698
# Validation : Mean CrossEntropyLoss = 2.2639 | Mean MulticlassF1Score = 0.9459
# Patience = 2/50❗
# ================================================================================
#
# EPOCH-44
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2603 | MulticlassF1Score=0.9672
# Batch-30 : CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9683
# Batch-45 : CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9685
# Batch-60 : CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9686
# Batch-75 : CrossEntropyLoss=2.2542 | MulticlassF1Score=0.9687
# Batch-90 : CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9691
# Batch-105: CrossEntropyLoss=2.2589 | MulticlassF1Score=0.9687
# Batch-120: CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9689
# Batch-135: CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9692
# Batch-150: CrossEntropyLoss=2.2528 | MulticlassF1Score=0.9694
# Batch-165: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9692
# Batch-180: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9693
# Batch-195: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9695
# Batch-210: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9697
# Batch-225: CrossEntropyLoss=2.2534 | MulticlassF1Score=0.9696
# Batch-226: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9696
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9482
# Batch-30 : CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9491
# Batch-45 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9483
# Batch-60 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9476
# Batch-63 : CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9474
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2569 | Mean MulticlassF1Score = 0.9690
# Validation : Mean CrossEntropyLoss = 2.2638 | Mean MulticlassF1Score = 0.9484
# ================================================================================
#
# EPOCH-45
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9712
# Batch-30 : CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9706
# Batch-45 : CrossEntropyLoss=2.2519 | MulticlassF1Score=0.9712
# Batch-60 : CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9704
# Batch-75 : CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9710
# Batch-90 : CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9705
# Batch-105: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9702
# Batch-120: CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9703
# Batch-135: CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9703
# Batch-150: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9703
# Batch-165: CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9702
# Batch-180: CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9701
# Batch-195: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9702
# Batch-210: CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9701
# Batch-225: CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9702
# Batch-226: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9702
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9464
# Batch-30 : CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9498
# Batch-45 : CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9485
# Batch-60 : CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9479
# Batch-63 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9479
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2567 | Mean MulticlassF1Score = 0.9706
# Validation : Mean CrossEntropyLoss = 2.2636 | Mean MulticlassF1Score = 0.9479
# ================================================================================
#
# EPOCH-46
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9741
# Batch-30 : CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9715
# Batch-45 : CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9710
# Batch-60 : CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9707
# Batch-75 : CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9703
# Batch-90 : CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9704
# Batch-105: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9706
# Batch-120: CrossEntropyLoss=2.2544 | MulticlassF1Score=0.9708
# Batch-135: CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9709
# Batch-150: CrossEntropyLoss=2.2534 | MulticlassF1Score=0.9710
# Batch-165: CrossEntropyLoss=2.2551 | MulticlassF1Score=0.9708
# Batch-180: CrossEntropyLoss=2.2542 | MulticlassF1Score=0.9710
# Batch-195: CrossEntropyLoss=2.2547 | MulticlassF1Score=0.9708
# Batch-210: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9706
# Batch-225: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9707
# Batch-226: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9707
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9434
# Batch-30 : CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9458
# Batch-45 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9471
# Batch-60 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9485
# Batch-63 : CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9483
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2565 | Mean MulticlassF1Score = 0.9710
# Validation : Mean CrossEntropyLoss = 2.2634 | Mean MulticlassF1Score = 0.9456
# ================================================================================
#
# EPOCH-47
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9737
# Batch-30 : CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9733
# Batch-45 : CrossEntropyLoss=2.2534 | MulticlassF1Score=0.9728
# Batch-60 : CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9729
# Batch-75 : CrossEntropyLoss=2.2541 | MulticlassF1Score=0.9719
# Batch-90 : CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9716
# Batch-105: CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9712
# Batch-120: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9713
# Batch-135: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9712
# Batch-150: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9710
# Batch-165: CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9709
# Batch-180: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9708
# Batch-195: CrossEntropyLoss=2.2525 | MulticlassF1Score=0.9709
# Batch-210: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9711
# Batch-225: CrossEntropyLoss=2.2528 | MulticlassF1Score=0.9711
# Batch-226: CrossEntropyLoss=2.2527 | MulticlassF1Score=0.9712
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9474
# Batch-30 : CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9473
# Batch-45 : CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9490
# Batch-60 : CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9483
# Batch-63 : CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9484
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2563 | Mean MulticlassF1Score = 0.9719
# Validation : Mean CrossEntropyLoss = 2.2634 | Mean MulticlassF1Score = 0.9476
# ================================================================================
#
# EPOCH-48
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9702
# Batch-30 : CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9704
# Batch-45 : CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9701
# Batch-60 : CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9708
# Batch-75 : CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9708
# Batch-90 : CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9709
# Batch-105: CrossEntropyLoss=2.2532 | MulticlassF1Score=0.9710
# Batch-120: CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9713
# Batch-135: CrossEntropyLoss=2.2528 | MulticlassF1Score=0.9714
# Batch-150: CrossEntropyLoss=2.2526 | MulticlassF1Score=0.9713
# Batch-165: CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9709
# Batch-180: CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9709
# Batch-195: CrossEntropyLoss=2.2547 | MulticlassF1Score=0.9709
# Batch-210: CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9710
# Batch-225: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9712
# Batch-226: CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9712
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9445
# Batch-30 : CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9477
# Batch-45 : CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9467
# Batch-60 : CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9483
# Batch-63 : CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9482
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2563 | Mean MulticlassF1Score = 0.9709
# Validation : Mean CrossEntropyLoss = 2.2634 | Mean MulticlassF1Score = 0.9464
# Patience = 3/50❗
# ================================================================================
#
# EPOCH-49
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9741
# Batch-30 : CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9739
# Batch-45 : CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9726
# Batch-60 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9728
# Batch-75 : CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9718
# Batch-90 : CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9717
# Batch-105: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9715
# Batch-120: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9717
# Batch-135: CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9718
# Batch-150: CrossEntropyLoss=2.2532 | MulticlassF1Score=0.9716
# Batch-165: CrossEntropyLoss=2.2547 | MulticlassF1Score=0.9718
# Batch-180: CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9718
# Batch-195: CrossEntropyLoss=2.2547 | MulticlassF1Score=0.9716
# Batch-210: CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9713
# Batch-225: CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9712
# Batch-226: CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9712
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9486
# Batch-30 : CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9475
# Batch-45 : CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9482
# Batch-60 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9479
# Batch-63 : CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9477
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2563 | Mean MulticlassF1Score = 0.9722
# Validation : Mean CrossEntropyLoss = 2.2636 | Mean MulticlassF1Score = 0.9483
# ================================================================================
#
# EPOCH-50
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9715
# Batch-30 : CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9724
# Batch-45 : CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9722
# Batch-60 : CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9714
# Batch-75 : CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9711
# Batch-90 : CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9711
# Batch-105: CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9717
# Batch-120: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9718
# Batch-135: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9718
# Batch-150: CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9715
# Batch-165: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9716
# Batch-180: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9714
# Batch-195: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9713
# Batch-210: CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9712
# Batch-225: CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9714
# Batch-226: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9714
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9452
# Batch-30 : CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9474
# Batch-45 : CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9487
# Batch-60 : CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9487
# Batch-63 : CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9482
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2563 | Mean MulticlassF1Score = 0.9716
# Validation : Mean CrossEntropyLoss = 2.2635 | Mean MulticlassF1Score = 0.9477
# ================================================================================
#
# TRAINING SUMMARY
# Best CrossEntropyLoss training    : 2.2563
# Best CrossEntropyLoss training    : 2.2635
# Best MulticlassF1Score validation : 0.9716
# Best MulticlassF1Score validation : 0.9477
# Training duration                 : 4.2407 minutes.
# Training date                     : 2022-10-19 08:37:31.294822+08:00

# %% [markdown]
# ## End Training

# %% [markdown]
# # Evaluation

# %%
def evaluation(dataloader, model, criterion, metric):
    model.eval()
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)
            pred = rearrange(prob.argmax(dim=1).reshape(feature.shape[0], len(dataloader.dataset)), "s n -> n s")

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob.argmax(dim=1), actual_label.to(hyperparams.device))
            metric_score = metric.compute()

    return loss, metric_score, pred

train_dataloader = DataLoader(train_dataset, batch_size=len(train_dataset))
val_dataloader = DataLoader(val_dataset, batch_size=len(val_dataset))
test_dataloader = DataLoader(test_dataset, batch_size=len(test_dataset))

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
train_loss, train_f1_score, train_pred_label = evaluation(train_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_loss, val_f1_score, val_pred_label = evaluation(val_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
test_loss, test_f1_score, test_pred_label = evaluation(test_dataloader, model, criterion, metric)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9720, device='cuda:0'),
#  tensor(0.9482, device='cuda:0'),
#  tensor(0.9500, device='cuda:0'))

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9720, device='cuda:0'),
#  tensor(0.9482, device='cuda:0'),
#  tensor(0.9500, device='cuda:0'))

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns

def viz_evaluation(pred_label, actual_label, title):
    plt.figure(figsize=(15, 7), dpi=200)
    sns.heatmap(pred_label.detach().cpu() == actual_label, cbar=True, cmap="binary_r")
    plt.xlabel("Sentence Length")
    plt.ylabel("Sentence")
    plt.title(title)
    plt.savefig(f"{root_path}/heatmap_{title.lower()}.jpg", dpi=200)
    plt.show()

train_actual_label = train_dataloader.dataset.tensors[1]
val_actual_label = val_dataloader.dataset.tensors[1]
test_actual_label = test_dataloader.dataset.tensors[1]

viz_evaluation(train_pred_label, train_actual_label, f"Training (F1-Score: {(train_f1_score):.4f})")
viz_evaluation(val_pred_label, val_actual_label, f"Validation (F1-Score: {(val_f1_score):.4f})")
viz_evaluation(test_pred_label, test_actual_label, f"Test (F1-Score: {(test_f1_score):.4f})")

# %% [markdown]
# ## Confusion Matrix

# %%
def confusion_matrix(pred_class, actual_class, title, normalize=None):
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize=normalize)
    plt.figure(figsize=(20, 10), dpi=200)
    sns.heatmap(conf_mat(pred_class.detach().cpu(), actual_class), annot=True, fmt=".2g", xticklabels=list(label_to_idx.keys()), yticklabels=list(label_to_idx.keys()));
    plt.yticks(rotation=0)
    plt.title(title)
    plt.xlabel("Actual Class")
    plt.ylabel("Predict Class")
    plt.savefig(f"{root_path}/conf_matrix_{title.lower()}.jpg", dpi=200)

confusion_matrix(train_pred_label, train_actual_label, "Training", "pred")
confusion_matrix(val_pred_label,val_actual_label, "Validation", "pred")
confusion_matrix(test_pred_label, test_actual_label, "Test", "pred")
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 120 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)

# %% [markdown]
# ## Prediction Table

# %%
def number_wrong_pred_each_class(pred_class, actual_class):
    classes, count_class = actual_class.flatten().unique(return_counts=True)
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize="none")
    correct_pred_count_class = conf_mat(pred_class.detach().cpu(), actual_class).diag()
    
    correct_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (correct_pred_count_class))}
    wrong_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (count_class - correct_pred_count_class))}
    
    return correct_pred, wrong_pred

correct_pred, wrong_pred = number_wrong_pred_each_class(train_pred_label, train_actual_label)
print(f"| {'Number class'.ljust(14)} | {'Correct prediction'.ljust(12)} | {'Wrong prediction'.ljust(12)} |")
for (label_correct_pred, count_correct_pred), (label_wrong_pred, count_wrong_pred) in zip(correct_pred.items(), wrong_pred.items()):
    print(f"| {str(label_correct_pred).ljust(6)}: {str(count_correct_pred + count_wrong_pred).ljust(7)}| {label_correct_pred.ljust(6)}: {str(count_correct_pred).ljust(10)} | {label_wrong_pred.ljust(6)}: {str(count_wrong_pred).ljust(8)} |")
# Out:
# | Number class   | Correct prediction | Wrong prediction |
# | CC    : 5346   | CC    : 5202       | CC    : 144      |
# | CD    : 12730  | CD    : 12633      | CD    : 97       |
# | DT    : 269    | DT    : 0          | DT    : 269      |
# | FW    : 1614   | FW    : 1411       | FW    : 203      |
# | IN    : 15342  | IN    : 15219      | IN    : 123      |
# | JJ    : 6981   | JJ    : 6688       | JJ    : 293      |
# | MD    : 3799   | MD    : 3752       | MD    : 47       |
# | NEG   : 1118   | NEG   : 0          | NEG   : 1118     |
# | NN    : 44369  | NN    : 43957      | NN    : 412      |
# | NND   : 1047   | NND   : 545        | NND   : 502      |
# | NNP   : 25175  | NNP   : 24728      | NNP   : 447      |
# | OD    : 524    | OD    : 506        | OD    : 18       |
# | PR    : 3880   | PR    : 3857       | PR    : 23       |
# | PRP   : 5471   | PRP   : 5435       | PRP   : 36       |
# | RB    : 3477   | RB    : 3274       | RB    : 203      |
# | RP    : 141    | RP    : 0          | RP    : 141      |
# | SC    : 9455   | SC    : 9201       | SC    : 254      |
# | SYM   : 1551   | SYM   : 1520       | SYM   : 31       |
# | UH    : 21     | UH    : 0          | UH    : 21       |
# | VB    : 22950  | VB    : 22652      | VB    : 298      |
# | WH    : 184    | WH    : 0          | WH    : 184      |
# | X     : 279    | X     : 8          | X     : 271      |
# | Z     : 18960  | Z     : 18929      | Z     : 31       |
# | <PAD> : 407521 | <PAD> : 407521     | <PAD> : 0        |

# %%
train_actual_label[308], train_pred_label[308]
# Out:
# (tensor([ 8,  3, 12, 19,  8,  8,  8, 16, 19,  4, 10,  8, 10,  0,  4,  1,  8,  8,
#           8,  5,  4,  8, 10,  0, 10, 10, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23]),
#  tensor([ 8,  8, 12, 19,  8,  8,  5, 16, 19,  4, 10,  8, 10,  0,  4,  1,  8,  8,
#           8,  5,  4,  8, 10,  0, 10, 10, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23], device='cuda:0'))

# %%
train_actual_label[308] == train_pred_label[308].detach().cpu()
# Out:
# tensor([ True, False,  True,  True,  True,  True, False,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True])

# %% [markdown]
# ## OOV prediction is correct

# %%
def oov_flag_token(sentences, max_seq_len=hyperparams.max_seq_len):
    sent_copy = deepcopy(sentences)
    sent = []
    oov_flag = []
    
    for sentence in tqdm(sent_copy):
        for token in sentence:
            sent.append(token[2])
        
        for _ in range(max_seq_len- len(sentence)):
            sent.append(False)
        
        oov_flag.append(sent)
        sent = []
        
    return np.array(oov_flag)

train_oov_flag = oov_flag_token(train_sentences, max_seq_len=hyperparams.max_seq_len)
val_oov_flag = oov_flag_token(val_sentences, max_seq_len=hyperparams.max_seq_len)
test_oov_flag = oov_flag_token(test_sentences, max_seq_len=hyperparams.max_seq_len)

def pencentage_oov_pred_correct(pred_oov_flag, oov_flag_tensor):
    oov_correct_counter = 0
    oov_wrong_counter = 0

    for pred, oov_label in tqdm(zip(pred_oov_flag, oov_flag_tensor)):
        if pred == True and oov_label == True:
            oov_correct_counter += 1
        elif pred == False and oov_label == True:
            oov_wrong_counter += 1
        else:
            continue
            
    return oov_correct_counter, oov_wrong_counter

train_pred_oov_flag = (train_actual_label == train_pred_label.detach().cpu()).flatten()
val_pred_oov_flag = (val_actual_label == val_pred_label.detach().cpu()).flatten()
test_pred_oov_flag = (test_actual_label == test_pred_label.detach().cpu()).flatten()
train_oov_flag_tensor = torch.tensor(train_oov_flag).flatten()
val_oov_flag_tensor = torch.tensor(val_oov_flag).flatten()
test_oov_flag_tensor = torch.tensor(test_oov_flag).flatten()

train_oov_correct_counter, train_oov_wrong_counter = pencentage_oov_pred_correct(train_pred_oov_flag, train_oov_flag_tensor)
val_oov_correct_counter, val_oov_wrong_counter = pencentage_oov_pred_correct(val_pred_oov_flag, val_oov_flag_tensor)
test_oov_correct_counter, test_oov_wrong_counter = pencentage_oov_pred_correct(test_pred_oov_flag, test_oov_flag_tensor)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]

# %%
def print_percentage_pred_oov(title, oov_correct_counter, oov_wrong_counter):
    print(f"{title}")
    print(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}")
    print(f"Correct prediction          : {oov_correct_counter}")
    print(f"Wrong prediction            : {oov_wrong_counter}")
    print(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n")
    
    with open(f"{root_path}/oov_summary.txt", "a") as f:
        f.write(f"{title}\n")
        f.write(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}\n")
        f.write(f"Correct prediction          : {oov_correct_counter}\n")
        f.write(f"Wrong prediction            : {oov_wrong_counter}\n")
        f.write(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n\n")

# %%
print_percentage_pred_oov("Training", train_oov_correct_counter, train_oov_wrong_counter)
print_percentage_pred_oov("Validation", val_oov_correct_counter, val_oov_wrong_counter)
print_percentage_pred_oov("Test", test_oov_correct_counter, test_oov_wrong_counter)

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(train_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(val_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(test_oov_flag, cmap=plt.cm.binary_r);
