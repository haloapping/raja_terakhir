# %% [markdown]
# # Import modules

# %%
import csv
import os
import pickle
import pytz
import torch
import timeit
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from copy import deepcopy
from datetime import datetime
from einops import rearrange
from itertools import chain
from time import time
from torch import nn, optim
from torchmetrics.classification import MulticlassAccuracy, MulticlassF1Score, MulticlassConfusionMatrix
from torch.optim import lr_scheduler
from tqdm.notebook import tqdm
from torch.utils.data import TensorDataset, DataLoader
from polyglot.mapping import Embedding, CaseExpander, DigitExpander

# %% [markdown]
# # Hyperparameters

# %%
class Hyperparams:
     def __init__(
        self,
        context_size=35,
        fold=4,
        max_seq_len=82,
        input_size=64,
        batch_size=32,
        num_hidden_layer=1,
        hidden_size=128,
        dropout=0,
        bias=True,
        output_size=24,
        shuffle=True,
        lr=0.005,
        batch_first=False,
        bidirectional=True,
        init_wb_with_kaiming_normal=True,
        n_epoch=50,
        patience=50,
        device="cuda" if torch.cuda.is_available() else "cpu"
    ):
        self.context_size = context_size
        self.fold = fold
        self.input_size = input_size
        self.max_seq_len = max_seq_len
        self.batch_size = batch_size
        self.num_hidden_layer = num_hidden_layer
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.output_size = output_size
        self.shuffle = shuffle
        self.lr = lr
        self.batch_first = batch_first
        self.bidirectional = bidirectional
        self.init_wb_with_kaiming_normal = init_wb_with_kaiming_normal
        self.n_epoch = n_epoch
        self.patience = patience
        self.device = device

hyperparams = Hyperparams()

# %% [markdown]
# # Dataset

# %%
id_pos_tag = pd.read_csv("../../../datasets/raw/Indonesian_Manually_Tagged_Corpus.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False) 
train = pd.read_csv(f"../../../datasets/raw/cv/train/train.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
val = pd.read_csv(f"../../../datasets/raw/cv/val/val.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
test = pd.read_csv(f"../../../datasets/raw/cv/test/test.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)

# %% [markdown]
# # Pre-trained Word Embedding

# %%
embeddings = Embedding.load("../../../word_embeddings/polyglot/idn_embeddings.tar.bz2")
embeddings.apply_expansion(DigitExpander)
embeddings.apply_expansion(CaseExpander)

oov_embeddings = pickle.load(open(f"../../../logs/comick/{hyperparams.context_size}_contexts/10-11-2022_13-22-21/oov_embedding_dict.pkl", "rb"))

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Add OOV Flag

# %%
def add_oov_flag(tokens, embeddings):
    oov_flags = []
    
    for token in tqdm(tokens):
        try:
            if token not in embeddings:
                oov_flags.append(True)
            else:
                oov_flags.append(False)
        except:
            oov_flags.append(False)
        
    return pd.DataFrame(oov_flags, columns=["is_oov"])

id_pos_tag_oov_flags = add_oov_flag(id_pos_tag["token"].values, embeddings)
train_oov_flags = add_oov_flag(train["token"].values, embeddings)
val_oov_flags = add_oov_flag(val["token"].values, embeddings)
test_oov_flags = add_oov_flag(test["token"].values, embeddings)
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/191849 [00:00<?, ?it/s]
#   0%|          | 0/21364 [00:00<?, ?it/s]
#   0%|          | 0/53439 [00:00<?, ?it/s]

# %% [markdown]
# ## Concate OOV Flag

# %%
id_pos_tag_df = pd.concat([id_pos_tag, id_pos_tag_oov_flags], axis=1)
train_df = pd.concat([train, train_oov_flags], axis=1)
val_df = pd.concat([val, val_oov_flags], axis=1)
test_df = pd.concat([test, test_oov_flags], axis=1)

# %% [markdown]
# ## Lowercase OOV Token

# %%
id_pos_tag_df['token'] = np.where(id_pos_tag_df['is_oov'] == True, id_pos_tag_df['token'].str.lower(), id_pos_tag_df['token'])
train_df['token'] = np.where(train_df['is_oov'] == True, train_df['token'].str.lower(), train_df['token'])
val_df['token'] = np.where(val_df['is_oov'] == True, val_df['token'].str.lower(), val_df['token'])
test_df['token'] = np.where(test_df['is_oov'] == True, test_df['token'].str.lower(), test_df['token'])

# %% [markdown]
# ## Embedding Dict, Index to Token and Token to Index

# %%
tokens = list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None))

def embedding_dict(tokens, embeddings, oov_embeddings):
    embedding = {}
    
    for token in tokens:
        if token[0] is not np.nan:
            if token[2] == False or token[0] in embeddings:
                embedding[token[0]] = embeddings[token[0]]
            else:
                embedding[token[0]] = oov_embeddings[token[0].lower()]

    return embedding

embedding_dict = embedding_dict(tokens, embeddings, oov_embeddings)
embedding_dict["<PAD>"] = embeddings["<PAD>"]
word_embeddings = nn.Embedding.from_pretrained(torch.FloatTensor(np.array(list(embedding_dict.values()))), padding_idx=list(embedding_dict.keys()).index("<PAD>"), freeze=True)

idx_to_token = {idx: token for idx, token in enumerate(list(embedding_dict.keys()))}
token_to_idx = {token: idx for idx, token in enumerate(list(embedding_dict.keys()))}

# %% [markdown]
# ## Token to Sentence

# %%
def make_sentence(tokens, max_length_sentence=hyperparams.max_seq_len):
    sentence = []
    sentences = []

    for token in tqdm(tokens):
        if token[0] is not np.nan:
            sentence.append(token)
        else:
            sentences.append(sentence[:max_length_sentence])
            sentence = []

    return sentences

all_sentence = make_sentence(list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
train_sentences = make_sentence(list(train_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
val_sentences = make_sentence(list(test_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
test_sentences = make_sentence(list(val_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/191849 [00:00<?, ?it/s]
#   0%|          | 0/53439 [00:00<?, ?it/s]
#   0%|          | 0/21364 [00:00<?, ?it/s]

# %% [markdown]
# ## Word Token, Padding, and Word token to Index

# %%
def tokenize_docs(docs, idx_token):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token[idx_token])
        sentences.append(new_sentence)
        new_sentence = []

    return sentences

def padding(docs, max_seq_len=hyperparams.max_seq_len, mode="post", val_pad="<PAD>"):
    docs = deepcopy(docs)
    doc_with_pad = []
    docs_with_pad = []

    for doc in tqdm(docs):
        if mode == "pre":
            for _ in range(max_seq_len - len(doc)):
                doc.insert(0, val_pad)
        elif mode == "post":
            for _ in range(max_seq_len - len(doc)):
                doc.append(val_pad)
        else:
            return f"Mode {mode} is not available, use instead 'pre' or 'post'."
        
        docs_with_pad.append(doc)
        
    return np.array(docs_with_pad)

def sent_to_idx(docs, token_to_idx):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token_to_idx[token])
        sentences.append(new_sentence)
        new_sentence = []

    return np.array(sentences)

def convert_feature_to_idx(docs, idx_token, token_to_idx, max_seq_len):
    sentences = tokenize_docs(docs, idx_token)
    sentences_with_pad = padding(sentences, max_seq_len=max_seq_len, mode="post", val_pad="<PAD>")
    sentences_to_idx = sent_to_idx(sentences_with_pad, token_to_idx)
    
    return sentences_to_idx

train_sentence_idxs = convert_feature_to_idx(train_sentences, 0, token_to_idx, hyperparams.max_seq_len)
val_sentence_idxs = convert_feature_to_idx(val_sentences, 0, token_to_idx, hyperparams.max_seq_len)
test_sentence_idxs = convert_feature_to_idx(test_sentences, 0, token_to_idx, hyperparams.max_seq_len)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]

# %% [markdown]
# ## Encode Class

# %%
classes = sorted(np.delete(id_pos_tag_df["tag"].unique(), 3))
idx_to_label = {idx: label for idx, label in enumerate(classes + ["<PAD>"])}
label_to_idx = {label: idx for idx, label in enumerate(classes + ["<PAD>"])}

def encode_class(docs, label_to_idx, seq_len=hyperparams.max_seq_len):
    class_idxs = []
    classes = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            class_idxs.append(label_to_idx[token[1]])
            
        for _ in range(seq_len - len(sentence)):
            class_idxs.append(label_to_idx["<PAD>"])
                
        classes.append(class_idxs)
        class_idxs = []

    return np.array(classes)
        
train_class_idxs = encode_class(train_sentences, label_to_idx)
val_class_idxs = encode_class(val_sentences, label_to_idx)
test_class_idxs = encode_class(test_sentences, label_to_idx)

print(f"Training shape   : {train_sentence_idxs.shape, train_class_idxs.shape}")
print(f"validation shape : {val_class_idxs.shape, val_class_idxs.shape}")
print(f"Test shape       : {test_sentence_idxs.shape, test_class_idxs.shape}")
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# Training shape   : ((7222, 82), (7222, 82))
# validation shape : ((2006, 82), (2006, 82))
# Test shape       : ((802, 82), (802, 82))

# %% [markdown]
# ## Note
#
# - Number of sentences = 10030
# - Train : 72% (7222)
# - Val   : 8% (802)
# - Test  : 20% (2006)

# %% [markdown]
# # Build Model

# %% [markdown]
# ## Feature and Actual Class

# %%
train_feature = torch.LongTensor(train_sentence_idxs)
val_feature = torch.LongTensor(val_sentence_idxs)
test_feature = torch.LongTensor(test_sentence_idxs)

train_class = torch.LongTensor(train_class_idxs)
val_class = torch.LongTensor(val_class_idxs)
test_class = torch.LongTensor(test_class_idxs)

# %%
train_feature.shape, val_feature.shape, test_feature.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %%
train_class.shape, val_class.shape, test_class.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %% [markdown]
# ## Tensor Dataset

# %%
train_dataset = TensorDataset(train_feature, train_class)
val_dataset = TensorDataset(val_feature, val_class)
test_dataset = TensorDataset(test_feature, test_class)

# %% [markdown]
# ## Dataloader

# %%
train_dataloader = DataLoader(train_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
val_dataloader = DataLoader(val_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
test_dataloader = DataLoader(test_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)

# %% [markdown]
# ## Model

# %%
class POSTagger(nn.Module):
    def __init__(
        self,
        input_size=hyperparams.input_size,
        hidden_size=hyperparams.hidden_size,
        dropout=hyperparams.dropout,
        bias=hyperparams.bias,
        num_layers=hyperparams.num_hidden_layer,
        output_size=hyperparams.output_size,
        batch_first=hyperparams.batch_first,
        bidirectional=hyperparams.bidirectional,
        init_wb_with_kaiming_normal=hyperparams.init_wb_with_kaiming_normal
    ):
        super(POSTagger, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.num_layers = num_layers
        self.output_size = output_size
        self.batch_first = batch_first
        self.bidirectional = bidirectional
                
        self.feature = nn.LSTM(
            input_size = self.input_size,
            hidden_size = self.hidden_size,
            bias = self.bias,
            dropout = self.dropout,
            num_layers = self.num_layers,
            batch_first = self.batch_first,
            bidirectional = self.bidirectional
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(in_features=2 * self.hidden_size if hyperparams.bidirectional else self.hidden_size, out_features=self.output_size, bias=self.bias),
            nn.Softmax(dim=-1)
        )
        
        if init_wb_with_kaiming_normal:
            self.init_wb()

    def init_wb(self):
        for module in self.modules():
            if isinstance(module, (nn.Linear, nn.LSTM)):
                for name, param in module.named_parameters():
                    if "weight" in name:
                        nn.init.kaiming_normal_(param)
                    else:
                        nn.init.kaiming_normal_(param.reshape(1, -1))
        
    def forward(self, feature, hidden=None):
        output, (hidden, memory) = self.feature(feature, None)
        prob = self.classifier(output)

        return prob
    
model = POSTagger().to(hyperparams.device)
model
# Out:
# POSTagger(
#   (feature): LSTM(64, 128, bidirectional=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=24, bias=True)
#     (1): Softmax(dim=-1)
#   )
# )

# %% [markdown]
# ## Optimizer, Criterion, and Metric

# %%
optimizer = optim.Adam(model.parameters(), lr=hyperparams.lr)
criterion = nn.CrossEntropyLoss().to(hyperparams.device)
train_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", verbose=True, factor=0.5)

# %%
sum(param.numel() for param in model.parameters() if param.requires_grad)
# Out:
# 204824

# %% [markdown]
# ## Training Step

# %%
def training_step(dataloader, model, optimizer, criterion, metric, scheduler=None):
    model.train()
    
    batch_losses = []
    batch_metric_scores = []
    
    for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
        # Forward Propagation
        feature = rearrange(feature, "n s -> s n")
        actual_label = rearrange(actual_label, "n s -> s n")
        embedding = word_embeddings(feature)
        
        prob = model(
            embedding.to(hyperparams.device),
            actual_label.to(hyperparams.device)
        )
        
        prob = prob.reshape(-1, prob.shape[-1])
        actual_label = actual_label.reshape(-1)

        loss = criterion(prob, actual_label.to(hyperparams.device))
        metric_score = metric(prob, actual_label.to(hyperparams.device))
        metric_score = metric.compute()
                
        if scheduler is not None:
            scheduler.step(loss)
        
        batch_losses.append(loss.item())
        batch_metric_scores.append(metric_score)
        
        if len(dataloader) < 10:
            if batch % 1 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
        else:
            if batch % 15 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            
        # Backward Propagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Validation Step

# %%
def validation_step(dataloader, model, criterion, metric):
    model.eval()
    
    batch_losses = []
    batch_metric_scores = []
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob, actual_label.to(hyperparams.device))
            metric_score = metric.compute()

            batch_losses.append(loss.item())
            batch_metric_scores.append(metric_score)
            
            if len(dataloader) < 10 and (batch % 1 == 0 or batch == len(dataloader)):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            else:
                if batch % 15 == 0 or batch == len(dataloader):
                    batch_name = "Batch-" + str(batch)
                    print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                    with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                        f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Looping Step

# %%
now = datetime.now(pytz.timezone("Asia/Ujung_Pandang"))
path_name = now.strftime("%m-%d-%Y_%H-%M-%S")
root_path = f"../../../logs/classifier/{hyperparams.context_size}_contexts/fold_0{hyperparams.fold}/{path_name}"
os.makedirs(root_path)

def looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric, n_epoch=hyperparams.n_epoch, patience=hyperparams.patience, monitor="loss"):    
    start_time = time()
    
    epoch_training_losses = []
    epoch_training_metric_scores = []
    epoch_val_losses = []
    epoch_val_metric_scores = []
    patience_counter = 0
    
    # Hyperparameters
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write(f"HYPERPARAMETERS\n")
        f.write(f"{'-' * 80}\n")
        for name, value in vars(hyperparams).items():
            f.write(f"{name}: {value}\n")
        
        f.write("\n\nTRAINING PROGRESS\n")
        f.write(f"{'-' * 80}\n")
    
    # Training Progress
    for epoch in range(1, n_epoch + 1):
        print(f"EPOCH-{epoch}")
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"EPOCH-{epoch}\n")
            f.write(f"Training Step\n")
            
        # Training Step
        print("Training Step")
        batch_training_losses, batch_training_metric_scores = training_step(train_dataloader, model, optimizer, criterion, train_metric, scheduler=None)
        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))

        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))
        epoch_training_losses.append(epoch_training_loss.item())

        epoch_training_metric_score = torch.mean(torch.FloatTensor(batch_training_metric_scores))
        epoch_training_metric_scores.append(epoch_training_metric_score.item())
        
        # Validation Step
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"\nValidation Step\n")
            
        print("\nValidation Step")
        batch_val_losses, batch_val_metric_scores = validation_step(val_dataloader, model, criterion, val_metric)
        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))

        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))
        epoch_val_losses.append(epoch_val_loss.item())

        epoch_val_metric_score = torch.mean(torch.FloatTensor(batch_val_metric_scores))
        epoch_val_metric_scores.append(epoch_val_metric_score.item())
        
        with open(f"{root_path}/training_history.txt", "a") as f:
            if monitor == "loss":
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_losses[-1] < epoch_training_losses[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
            else:
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_metric_scores[-1] > epoch_training_metric_scores[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗\n")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
                    
            print("=" * 80, end="\n\n")
            
            f.write(f"{'=' * 80}\n\n")
            
            if patience_counter == patience:
                print(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                
                f.write(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                break
        
        train_metric.reset()
        val_metric.reset()
        
    finish_time = time()
    
    # Training plot 
    fig, (ax_loss, ax_metric_score) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    fig.suptitle(f"Training with context size = {hyperparams.context_size}")

    ax_loss.set_title("Loss")
    ax_loss.set_xlabel("Epoch")
    ax_loss.set_ylabel("Score")
    ax_loss.plot(epoch_training_losses, "green", label="Training")
    ax_loss.plot(epoch_val_losses, "orange", label="Validation")
    ax_loss.legend()
    ax_loss.grid()

    ax_metric_score.set_title("F1 Score")
    ax_metric_score.set_xlabel("Epoch")
    ax_metric_score.set_ylabel("Score")
    ax_metric_score.plot(epoch_training_metric_scores, "green", label="Training")
    ax_metric_score.plot(epoch_val_metric_scores, "orange", label="Validation")
    ax_metric_score.legend()
    ax_metric_score.grid()

    plt.savefig(f"{root_path}/training_plot.jpg", dpi=200)                        
    
    print("TRAINING SUMMARY")
    name_best_training_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_training_metric = f"Best {str(train_metric).split('(')[0]} validation".ljust(34)
    name_best_validation_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_validation_metric = f"Best {str(val_metric).split('(')[0]} validation".ljust(34)
    name_training_time = f"Training duration".ljust(34)
    name_training_date = f"Training date".ljust(34)
    
    print(f"{name_best_training_loss}: {best_training_loss:.4f}")
    print(f"{name_best_validation_loss}: {best_val_loss:.4f}")
    print(f"{name_best_training_metric}: {best_training_metric:.4f}")
    print(f"{name_best_validation_metric}: {best_val_metric:.4f}")
    print(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.")
    print(f"{name_training_date}: {now}")
    
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write("\nTRAINING SUMMARY\n")
        f.write(f"{'-' * 80}\n")
        f.write(f"{name_best_training_loss}: {best_training_loss:.4f}\n")
        f.write(f"{name_best_validation_loss}: {best_val_loss:.4f}\n")
        f.write(f"{name_best_training_metric}: {best_training_metric:.4f}\n")
        f.write(f"{name_best_validation_metric}: {best_val_metric:.4f}\n")
        f.write(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.\n")
        f.write(f"{name_training_date}: {now}\n")
    
    # Save epoch losses, epoch metric scores, model, state dict, and oov embedding dict
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_training_losses
    }).to_csv(f"{root_path}/training_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_training_metric_scores
    }).to_csv(f"{root_path}/training_metric_scores.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_val_losses
    }).to_csv(f"{root_path}/val_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_val_metric_scores
    }).to_csv(f"{root_path}/val_metric_scores.csv", index=False)    
    
    filename_model_params = f"{root_path}/model_params.pth"
    torch.save(best_state_dict, filename_model_params)
    
    return epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores

epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores = looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric)
# Out:
# EPOCH-1
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.5299 | MulticlassF1Score=0.1216
# Batch-30 : CrossEntropyLoss=2.4897 | MulticlassF1Score=0.2009
# Batch-45 : CrossEntropyLoss=2.4285 | MulticlassF1Score=0.2637
# Batch-60 : CrossEntropyLoss=2.4215 | MulticlassF1Score=0.3014
# Batch-75 : CrossEntropyLoss=2.4048 | MulticlassF1Score=0.3494
# Batch-90 : CrossEntropyLoss=2.3892 | MulticlassF1Score=0.3864
# Batch-105: CrossEntropyLoss=2.3819 | MulticlassF1Score=0.4129
# Batch-120: CrossEntropyLoss=2.3628 | MulticlassF1Score=0.4358
# Batch-135: CrossEntropyLoss=2.3496 | MulticlassF1Score=0.4609
# Batch-150: CrossEntropyLoss=2.3626 | MulticlassF1Score=0.4815
# Batch-165: CrossEntropyLoss=2.3520 | MulticlassF1Score=0.4985
# Batch-180: CrossEntropyLoss=2.3471 | MulticlassF1Score=0.5135
# Batch-195: CrossEntropyLoss=2.3340 | MulticlassF1Score=0.5283
# Batch-210: CrossEntropyLoss=2.3412 | MulticlassF1Score=0.5417
# Batch-225: CrossEntropyLoss=2.3312 | MulticlassF1Score=0.5531
# Batch-226: CrossEntropyLoss=2.3331 | MulticlassF1Score=0.5535
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3601 | MulticlassF1Score=0.7135
# Batch-30 : CrossEntropyLoss=2.3325 | MulticlassF1Score=0.7173
# Batch-45 : CrossEntropyLoss=2.3513 | MulticlassF1Score=0.7159
# Batch-60 : CrossEntropyLoss=2.3413 | MulticlassF1Score=0.7159
# Batch-63 : CrossEntropyLoss=2.3474 | MulticlassF1Score=0.7150
#
# Training   : Mean CrossEntropyLoss = 2.3975 | Mean MulticlassF1Score = 0.3885
# Validation : Mean CrossEntropyLoss = 2.3379 | Mean MulticlassF1Score = 0.7180
# ================================================================================
#
# EPOCH-2
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3391 | MulticlassF1Score=0.7128
# Batch-30 : CrossEntropyLoss=2.3482 | MulticlassF1Score=0.7155
# Batch-45 : CrossEntropyLoss=2.3408 | MulticlassF1Score=0.7169
# Batch-60 : CrossEntropyLoss=2.3399 | MulticlassF1Score=0.7190
# Batch-75 : CrossEntropyLoss=2.3263 | MulticlassF1Score=0.7184
# Batch-90 : CrossEntropyLoss=2.3430 | MulticlassF1Score=0.7164
# Batch-105: CrossEntropyLoss=2.3363 | MulticlassF1Score=0.7165
# Batch-120: CrossEntropyLoss=2.3338 | MulticlassF1Score=0.7181
# Batch-135: CrossEntropyLoss=2.3294 | MulticlassF1Score=0.7185
# Batch-150: CrossEntropyLoss=2.3437 | MulticlassF1Score=0.7194
# Batch-165: CrossEntropyLoss=2.3323 | MulticlassF1Score=0.7196
# Batch-180: CrossEntropyLoss=2.3414 | MulticlassF1Score=0.7201
# Batch-195: CrossEntropyLoss=2.3271 | MulticlassF1Score=0.7230
# Batch-210: CrossEntropyLoss=2.3162 | MulticlassF1Score=0.7260
# Batch-225: CrossEntropyLoss=2.3148 | MulticlassF1Score=0.7289
# Batch-226: CrossEntropyLoss=2.3299 | MulticlassF1Score=0.7290
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3210 | MulticlassF1Score=0.7713
# Batch-30 : CrossEntropyLoss=2.3192 | MulticlassF1Score=0.7710
# Batch-45 : CrossEntropyLoss=2.3172 | MulticlassF1Score=0.7729
# Batch-60 : CrossEntropyLoss=2.3082 | MulticlassF1Score=0.7714
# Batch-63 : CrossEntropyLoss=2.3155 | MulticlassF1Score=0.7714
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3325 | Mean MulticlassF1Score = 0.7188
# Validation : Mean CrossEntropyLoss = 2.3198 | Mean MulticlassF1Score = 0.7702
# ================================================================================
#
# EPOCH-3
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3202 | MulticlassF1Score=0.7786
# Batch-30 : CrossEntropyLoss=2.3123 | MulticlassF1Score=0.7754
# Batch-45 : CrossEntropyLoss=2.3038 | MulticlassF1Score=0.7825
# Batch-60 : CrossEntropyLoss=2.3010 | MulticlassF1Score=0.7851
# Batch-75 : CrossEntropyLoss=2.3138 | MulticlassF1Score=0.7877
# Batch-90 : CrossEntropyLoss=2.3158 | MulticlassF1Score=0.7872
# Batch-105: CrossEntropyLoss=2.3179 | MulticlassF1Score=0.7888
# Batch-120: CrossEntropyLoss=2.3162 | MulticlassF1Score=0.7892
# Batch-135: CrossEntropyLoss=2.3256 | MulticlassF1Score=0.7883
# Batch-150: CrossEntropyLoss=2.3174 | MulticlassF1Score=0.7890
# Batch-165: CrossEntropyLoss=2.3162 | MulticlassF1Score=0.7892
# Batch-180: CrossEntropyLoss=2.3100 | MulticlassF1Score=0.7899
# Batch-195: CrossEntropyLoss=2.3058 | MulticlassF1Score=0.7909
# Batch-210: CrossEntropyLoss=2.3072 | MulticlassF1Score=0.7908
# Batch-225: CrossEntropyLoss=2.3174 | MulticlassF1Score=0.7909
# Batch-226: CrossEntropyLoss=2.3182 | MulticlassF1Score=0.7909
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3135 | MulticlassF1Score=0.7946
# Batch-30 : CrossEntropyLoss=2.3197 | MulticlassF1Score=0.7961
# Batch-45 : CrossEntropyLoss=2.3024 | MulticlassF1Score=0.7944
# Batch-60 : CrossEntropyLoss=2.3113 | MulticlassF1Score=0.7941
# Batch-63 : CrossEntropyLoss=2.3181 | MulticlassF1Score=0.7939
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3130 | Mean MulticlassF1Score = 0.7863
# Validation : Mean CrossEntropyLoss = 2.3120 | Mean MulticlassF1Score = 0.7958
# ================================================================================
#
# EPOCH-4
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3045 | MulticlassF1Score=0.8020
# Batch-30 : CrossEntropyLoss=2.3200 | MulticlassF1Score=0.7972
# Batch-45 : CrossEntropyLoss=2.3134 | MulticlassF1Score=0.7985
# Batch-60 : CrossEntropyLoss=2.3215 | MulticlassF1Score=0.7969
# Batch-75 : CrossEntropyLoss=2.3033 | MulticlassF1Score=0.7987
# Batch-90 : CrossEntropyLoss=2.3111 | MulticlassF1Score=0.7987
# Batch-105: CrossEntropyLoss=2.3170 | MulticlassF1Score=0.7982
# Batch-120: CrossEntropyLoss=2.3071 | MulticlassF1Score=0.7976
# Batch-135: CrossEntropyLoss=2.3159 | MulticlassF1Score=0.7967
# Batch-150: CrossEntropyLoss=2.3058 | MulticlassF1Score=0.7969
# Batch-165: CrossEntropyLoss=2.3029 | MulticlassF1Score=0.7970
# Batch-180: CrossEntropyLoss=2.3142 | MulticlassF1Score=0.7973
# Batch-195: CrossEntropyLoss=2.3186 | MulticlassF1Score=0.7974
# Batch-210: CrossEntropyLoss=2.3101 | MulticlassF1Score=0.7977
# Batch-225: CrossEntropyLoss=2.3004 | MulticlassF1Score=0.7974
# Batch-226: CrossEntropyLoss=2.3083 | MulticlassF1Score=0.7975
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3113 | MulticlassF1Score=0.8034
# Batch-30 : CrossEntropyLoss=2.3071 | MulticlassF1Score=0.8025
# Batch-45 : CrossEntropyLoss=2.3070 | MulticlassF1Score=0.8002
# Batch-60 : CrossEntropyLoss=2.3008 | MulticlassF1Score=0.7989
# Batch-63 : CrossEntropyLoss=2.3011 | MulticlassF1Score=0.7988
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3106 | Mean MulticlassF1Score = 0.7978
# Validation : Mean CrossEntropyLoss = 2.3104 | Mean MulticlassF1Score = 0.8006
# ================================================================================
#
# EPOCH-5
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3123 | MulticlassF1Score=0.8110
# Batch-30 : CrossEntropyLoss=2.3030 | MulticlassF1Score=0.8123
# Batch-45 : CrossEntropyLoss=2.3074 | MulticlassF1Score=0.8099
# Batch-60 : CrossEntropyLoss=2.2974 | MulticlassF1Score=0.8104
# Batch-75 : CrossEntropyLoss=2.3083 | MulticlassF1Score=0.8108
# Batch-90 : CrossEntropyLoss=2.3070 | MulticlassF1Score=0.8101
# Batch-105: CrossEntropyLoss=2.3093 | MulticlassF1Score=0.8111
# Batch-120: CrossEntropyLoss=2.3136 | MulticlassF1Score=0.8121
# Batch-135: CrossEntropyLoss=2.2987 | MulticlassF1Score=0.8129
# Batch-150: CrossEntropyLoss=2.2933 | MulticlassF1Score=0.8128
# Batch-165: CrossEntropyLoss=2.3023 | MulticlassF1Score=0.8137
# Batch-180: CrossEntropyLoss=2.2909 | MulticlassF1Score=0.8153
# Batch-195: CrossEntropyLoss=2.3012 | MulticlassF1Score=0.8170
# Batch-210: CrossEntropyLoss=2.2862 | MulticlassF1Score=0.8182
# Batch-225: CrossEntropyLoss=2.2885 | MulticlassF1Score=0.8193
# Batch-226: CrossEntropyLoss=2.2906 | MulticlassF1Score=0.8194
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2932 | MulticlassF1Score=0.8311
# Batch-30 : CrossEntropyLoss=2.2999 | MulticlassF1Score=0.8345
# Batch-45 : CrossEntropyLoss=2.3020 | MulticlassF1Score=0.8350
# Batch-60 : CrossEntropyLoss=2.2988 | MulticlassF1Score=0.8343
# Batch-63 : CrossEntropyLoss=2.3031 | MulticlassF1Score=0.8342
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3038 | Mean MulticlassF1Score = 0.8129
# Validation : Mean CrossEntropyLoss = 2.2994 | Mean MulticlassF1Score = 0.8331
# ================================================================================
#
# EPOCH-6
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3025 | MulticlassF1Score=0.8352
# Batch-30 : CrossEntropyLoss=2.2873 | MulticlassF1Score=0.8395
# Batch-45 : CrossEntropyLoss=2.3006 | MulticlassF1Score=0.8400
# Batch-60 : CrossEntropyLoss=2.3070 | MulticlassF1Score=0.8398
# Batch-75 : CrossEntropyLoss=2.2896 | MulticlassF1Score=0.8402
# Batch-90 : CrossEntropyLoss=2.2995 | MulticlassF1Score=0.8400
# Batch-105: CrossEntropyLoss=2.3032 | MulticlassF1Score=0.8392
# Batch-120: CrossEntropyLoss=2.3106 | MulticlassF1Score=0.8391
# Batch-135: CrossEntropyLoss=2.2937 | MulticlassF1Score=0.8395
# Batch-150: CrossEntropyLoss=2.2919 | MulticlassF1Score=0.8391
# Batch-165: CrossEntropyLoss=2.2864 | MulticlassF1Score=0.8393
# Batch-180: CrossEntropyLoss=2.2991 | MulticlassF1Score=0.8394
# Batch-195: CrossEntropyLoss=2.3118 | MulticlassF1Score=0.8393
# Batch-210: CrossEntropyLoss=2.2916 | MulticlassF1Score=0.8396
# Batch-225: CrossEntropyLoss=2.2864 | MulticlassF1Score=0.8400
# Batch-226: CrossEntropyLoss=2.2971 | MulticlassF1Score=0.8401
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3013 | MulticlassF1Score=0.8335
# Batch-30 : CrossEntropyLoss=2.2945 | MulticlassF1Score=0.8351
# Batch-45 : CrossEntropyLoss=2.3003 | MulticlassF1Score=0.8353
# Batch-60 : CrossEntropyLoss=2.2934 | MulticlassF1Score=0.8359
# Batch-63 : CrossEntropyLoss=2.2991 | MulticlassF1Score=0.8362
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2972 | Mean MulticlassF1Score = 0.8386
# Validation : Mean CrossEntropyLoss = 2.2987 | Mean MulticlassF1Score = 0.8371
# ================================================================================
#
# EPOCH-7
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2945 | MulticlassF1Score=0.8486
# Batch-30 : CrossEntropyLoss=2.3009 | MulticlassF1Score=0.8492
# Batch-45 : CrossEntropyLoss=2.2962 | MulticlassF1Score=0.8470
# Batch-60 : CrossEntropyLoss=2.2983 | MulticlassF1Score=0.8468
# Batch-75 : CrossEntropyLoss=2.2972 | MulticlassF1Score=0.8465
# Batch-90 : CrossEntropyLoss=2.2977 | MulticlassF1Score=0.8460
# Batch-105: CrossEntropyLoss=2.2939 | MulticlassF1Score=0.8454
# Batch-120: CrossEntropyLoss=2.2991 | MulticlassF1Score=0.8444
# Batch-135: CrossEntropyLoss=2.3040 | MulticlassF1Score=0.8434
# Batch-150: CrossEntropyLoss=2.2983 | MulticlassF1Score=0.8439
# Batch-165: CrossEntropyLoss=2.2960 | MulticlassF1Score=0.8439
# Batch-180: CrossEntropyLoss=2.3023 | MulticlassF1Score=0.8431
# Batch-195: CrossEntropyLoss=2.2994 | MulticlassF1Score=0.8431
# Batch-210: CrossEntropyLoss=2.2959 | MulticlassF1Score=0.8430
# Batch-225: CrossEntropyLoss=2.2926 | MulticlassF1Score=0.8428
# Batch-226: CrossEntropyLoss=2.2951 | MulticlassF1Score=0.8428
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2895 | MulticlassF1Score=0.8422
# Batch-30 : CrossEntropyLoss=2.3007 | MulticlassF1Score=0.8373
# Batch-45 : CrossEntropyLoss=2.3093 | MulticlassF1Score=0.8371
# Batch-60 : CrossEntropyLoss=2.2953 | MulticlassF1Score=0.8372
# Batch-63 : CrossEntropyLoss=2.3003 | MulticlassF1Score=0.8365
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2963 | Mean MulticlassF1Score = 0.8454
# Validation : Mean CrossEntropyLoss = 2.2985 | Mean MulticlassF1Score = 0.8377
# ================================================================================
#
# EPOCH-8
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2894 | MulticlassF1Score=0.8489
# Batch-30 : CrossEntropyLoss=2.2904 | MulticlassF1Score=0.8495
# Batch-45 : CrossEntropyLoss=2.3057 | MulticlassF1Score=0.8470
# Batch-60 : CrossEntropyLoss=2.2959 | MulticlassF1Score=0.8455
# Batch-75 : CrossEntropyLoss=2.2902 | MulticlassF1Score=0.8456
# Batch-90 : CrossEntropyLoss=2.2983 | MulticlassF1Score=0.8461
# Batch-105: CrossEntropyLoss=2.3039 | MulticlassF1Score=0.8447
# Batch-120: CrossEntropyLoss=2.2950 | MulticlassF1Score=0.8438
# Batch-135: CrossEntropyLoss=2.2940 | MulticlassF1Score=0.8441
# Batch-150: CrossEntropyLoss=2.2979 | MulticlassF1Score=0.8444
# Batch-165: CrossEntropyLoss=2.2996 | MulticlassF1Score=0.8441
# Batch-180: CrossEntropyLoss=2.2943 | MulticlassF1Score=0.8442
# Batch-195: CrossEntropyLoss=2.2908 | MulticlassF1Score=0.8454
# Batch-210: CrossEntropyLoss=2.2907 | MulticlassF1Score=0.8467
# Batch-225: CrossEntropyLoss=2.2872 | MulticlassF1Score=0.8481
# Batch-226: CrossEntropyLoss=2.2968 | MulticlassF1Score=0.8481
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2889 | MulticlassF1Score=0.8550
# Batch-30 : CrossEntropyLoss=2.2924 | MulticlassF1Score=0.8588
# Batch-45 : CrossEntropyLoss=2.2815 | MulticlassF1Score=0.8602
# Batch-60 : CrossEntropyLoss=2.2986 | MulticlassF1Score=0.8613
# Batch-63 : CrossEntropyLoss=2.2881 | MulticlassF1Score=0.8619
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2948 | Mean MulticlassF1Score = 0.8460
# Validation : Mean CrossEntropyLoss = 2.2911 | Mean MulticlassF1Score = 0.8592
# ================================================================================
#
# EPOCH-9
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2840 | MulticlassF1Score=0.8694
# Batch-30 : CrossEntropyLoss=2.2942 | MulticlassF1Score=0.8720
# Batch-45 : CrossEntropyLoss=2.2856 | MulticlassF1Score=0.8705
# Batch-60 : CrossEntropyLoss=2.2845 | MulticlassF1Score=0.8709
# Batch-75 : CrossEntropyLoss=2.2879 | MulticlassF1Score=0.8715
# Batch-90 : CrossEntropyLoss=2.2873 | MulticlassF1Score=0.8715
# Batch-105: CrossEntropyLoss=2.2877 | MulticlassF1Score=0.8717
# Batch-120: CrossEntropyLoss=2.2859 | MulticlassF1Score=0.8718
# Batch-135: CrossEntropyLoss=2.2856 | MulticlassF1Score=0.8714
# Batch-150: CrossEntropyLoss=2.2763 | MulticlassF1Score=0.8717
# Batch-165: CrossEntropyLoss=2.2870 | MulticlassF1Score=0.8722
# Batch-180: CrossEntropyLoss=2.2854 | MulticlassF1Score=0.8727
# Batch-195: CrossEntropyLoss=2.2864 | MulticlassF1Score=0.8726
# Batch-210: CrossEntropyLoss=2.2823 | MulticlassF1Score=0.8725
# Batch-225: CrossEntropyLoss=2.2864 | MulticlassF1Score=0.8727
# Batch-226: CrossEntropyLoss=2.2965 | MulticlassF1Score=0.8726
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2884 | MulticlassF1Score=0.8618
# Batch-30 : CrossEntropyLoss=2.2868 | MulticlassF1Score=0.8646
# Batch-45 : CrossEntropyLoss=2.2866 | MulticlassF1Score=0.8664
# Batch-60 : CrossEntropyLoss=2.2912 | MulticlassF1Score=0.8670
# Batch-63 : CrossEntropyLoss=2.2974 | MulticlassF1Score=0.8667
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2873 | Mean MulticlassF1Score = 0.8717
# Validation : Mean CrossEntropyLoss = 2.2893 | Mean MulticlassF1Score = 0.8637
# ================================================================================
#
# EPOCH-10
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2923 | MulticlassF1Score=0.8742
# Batch-30 : CrossEntropyLoss=2.2847 | MulticlassF1Score=0.8729
# Batch-45 : CrossEntropyLoss=2.2840 | MulticlassF1Score=0.8766
# Batch-60 : CrossEntropyLoss=2.2790 | MulticlassF1Score=0.8768
# Batch-75 : CrossEntropyLoss=2.2743 | MulticlassF1Score=0.8814
# Batch-90 : CrossEntropyLoss=2.2759 | MulticlassF1Score=0.8835
# Batch-105: CrossEntropyLoss=2.2859 | MulticlassF1Score=0.8856
# Batch-120: CrossEntropyLoss=2.2795 | MulticlassF1Score=0.8871
# Batch-135: CrossEntropyLoss=2.2741 | MulticlassF1Score=0.8890
# Batch-150: CrossEntropyLoss=2.2786 | MulticlassF1Score=0.8902
# Batch-165: CrossEntropyLoss=2.2772 | MulticlassF1Score=0.8918
# Batch-180: CrossEntropyLoss=2.2831 | MulticlassF1Score=0.8924
# Batch-195: CrossEntropyLoss=2.2770 | MulticlassF1Score=0.8930
# Batch-210: CrossEntropyLoss=2.2844 | MulticlassF1Score=0.8936
# Batch-225: CrossEntropyLoss=2.2747 | MulticlassF1Score=0.8944
# Batch-226: CrossEntropyLoss=2.2787 | MulticlassF1Score=0.8944
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2787 | MulticlassF1Score=0.9015
# Batch-30 : CrossEntropyLoss=2.2824 | MulticlassF1Score=0.8970
# Batch-45 : CrossEntropyLoss=2.2883 | MulticlassF1Score=0.8949
# Batch-60 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.8946
# Batch-63 : CrossEntropyLoss=2.2821 | MulticlassF1Score=0.8946
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2807 | Mean MulticlassF1Score = 0.8848
# Validation : Mean CrossEntropyLoss = 2.2806 | Mean MulticlassF1Score = 0.8979
# ================================================================================
#
# EPOCH-11
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2764 | MulticlassF1Score=0.9060
# Batch-30 : CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9087
# Batch-45 : CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9140
# Batch-60 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9166
# Batch-75 : CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9174
# Batch-90 : CrossEntropyLoss=2.2786 | MulticlassF1Score=0.9183
# Batch-105: CrossEntropyLoss=2.2786 | MulticlassF1Score=0.9175
# Batch-120: CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9175
# Batch-135: CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9180
# Batch-150: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9183
# Batch-165: CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9187
# Batch-180: CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9186
# Batch-195: CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9186
# Batch-210: CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9187
# Batch-225: CrossEntropyLoss=2.2771 | MulticlassF1Score=0.9188
# Batch-226: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9188
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2839 | MulticlassF1Score=0.9089
# Batch-30 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9105
# Batch-45 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9123
# Batch-60 : CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9118
# Batch-63 : CrossEntropyLoss=2.2774 | MulticlassF1Score=0.9112
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2733 | Mean MulticlassF1Score = 0.9157
# Validation : Mean CrossEntropyLoss = 2.2757 | Mean MulticlassF1Score = 0.9107
# ================================================================================
#
# EPOCH-12
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9251
# Batch-30 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9254
# Batch-45 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9252
# Batch-60 : CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9243
# Batch-75 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9245
# Batch-90 : CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9239
# Batch-105: CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9232
# Batch-120: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9232
# Batch-135: CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9238
# Batch-150: CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9237
# Batch-165: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9235
# Batch-180: CrossEntropyLoss=2.2764 | MulticlassF1Score=0.9231
# Batch-195: CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9229
# Batch-210: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9231
# Batch-225: CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9231
# Batch-226: CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9231
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2774 | MulticlassF1Score=0.9079
# Batch-30 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9107
# Batch-45 : CrossEntropyLoss=2.2787 | MulticlassF1Score=0.9124
# Batch-60 : CrossEntropyLoss=2.2765 | MulticlassF1Score=0.9116
# Batch-63 : CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9118
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2717 | Mean MulticlassF1Score = 0.9239
# Validation : Mean CrossEntropyLoss = 2.2752 | Mean MulticlassF1Score = 0.9102
# ================================================================================
#
# EPOCH-13
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9251
# Batch-30 : CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9229
# Batch-45 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9243
# Batch-60 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9250
# Batch-75 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9243
# Batch-90 : CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9253
# Batch-105: CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9244
# Batch-120: CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9249
# Batch-135: CrossEntropyLoss=2.2762 | MulticlassF1Score=0.9251
# Batch-150: CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9251
# Batch-165: CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9251
# Batch-180: CrossEntropyLoss=2.2776 | MulticlassF1Score=0.9247
# Batch-195: CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9249
# Batch-210: CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9250
# Batch-225: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9249
# Batch-226: CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9250
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9150
# Batch-30 : CrossEntropyLoss=2.2794 | MulticlassF1Score=0.9111
# Batch-45 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9131
# Batch-60 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9131
# Batch-63 : CrossEntropyLoss=2.2800 | MulticlassF1Score=0.9126
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2710 | Mean MulticlassF1Score = 0.9250
# Validation : Mean CrossEntropyLoss = 2.2750 | Mean MulticlassF1Score = 0.9134
# ================================================================================
#
# EPOCH-14
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9255
# Batch-30 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9281
# Batch-45 : CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9283
# Batch-60 : CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9277
# Batch-75 : CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9283
# Batch-90 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9283
# Batch-105: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9281
# Batch-120: CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9272
# Batch-135: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9268
# Batch-150: CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9271
# Batch-165: CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9271
# Batch-180: CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9270
# Batch-195: CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9270
# Batch-210: CrossEntropyLoss=2.2808 | MulticlassF1Score=0.9266
# Batch-225: CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9264
# Batch-226: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9265
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2774 | MulticlassF1Score=0.9154
# Batch-30 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9125
# Batch-45 : CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9137
# Batch-60 : CrossEntropyLoss=2.2772 | MulticlassF1Score=0.9128
# Batch-63 : CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9132
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2705 | Mean MulticlassF1Score = 0.9273
# Validation : Mean CrossEntropyLoss = 2.2747 | Mean MulticlassF1Score = 0.9143
# ================================================================================
#
# EPOCH-15
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9259
# Batch-30 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9266
# Batch-45 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9259
# Batch-60 : CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9263
# Batch-75 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9259
# Batch-90 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9269
# Batch-105: CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9267
# Batch-120: CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9271
# Batch-135: CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9274
# Batch-150: CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9273
# Batch-165: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9274
# Batch-180: CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9277
# Batch-195: CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9278
# Batch-210: CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9278
# Batch-225: CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9277
# Batch-226: CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9276
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9150
# Batch-30 : CrossEntropyLoss=2.2844 | MulticlassF1Score=0.9119
# Batch-45 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9110
# Batch-60 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9143
# Batch-63 : CrossEntropyLoss=2.2809 | MulticlassF1Score=0.9146
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2701 | Mean MulticlassF1Score = 0.9271
# Validation : Mean CrossEntropyLoss = 2.2744 | Mean MulticlassF1Score = 0.9123
# ================================================================================
#
# EPOCH-16
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9299
# Batch-30 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9298
# Batch-45 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9291
# Batch-60 : CrossEntropyLoss=2.2802 | MulticlassF1Score=0.9289
# Batch-75 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9293
# Batch-90 : CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9287
# Batch-105: CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9285
# Batch-120: CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9285
# Batch-135: CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9289
# Batch-150: CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9289
# Batch-165: CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9287
# Batch-180: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9290
# Batch-195: CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9292
# Batch-210: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9291
# Batch-225: CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9290
# Batch-226: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9290
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9153
# Batch-30 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9146
# Batch-45 : CrossEntropyLoss=2.2781 | MulticlassF1Score=0.9137
# Batch-60 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9139
# Batch-63 : CrossEntropyLoss=2.2761 | MulticlassF1Score=0.9140
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2696 | Mean MulticlassF1Score = 0.9291
# Validation : Mean CrossEntropyLoss = 2.2744 | Mean MulticlassF1Score = 0.9139
# ================================================================================
#
# EPOCH-17
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9285
# Batch-30 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9311
# Batch-45 : CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9328
# Batch-60 : CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9321
# Batch-75 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9319
# Batch-90 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9313
# Batch-105: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9313
# Batch-120: CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9307
# Batch-135: CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9311
# Batch-150: CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9308
# Batch-165: CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9308
# Batch-180: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9306
# Batch-195: CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9306
# Batch-210: CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9304
# Batch-225: CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9302
# Batch-226: CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9302
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2773 | MulticlassF1Score=0.9126
# Batch-30 : CrossEntropyLoss=2.2777 | MulticlassF1Score=0.9157
# Batch-45 : CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9146
# Batch-60 : CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9151
# Batch-63 : CrossEntropyLoss=2.2747 | MulticlassF1Score=0.9152
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2692 | Mean MulticlassF1Score = 0.9310
# Validation : Mean CrossEntropyLoss = 2.2741 | Mean MulticlassF1Score = 0.9142
# ================================================================================
#
# EPOCH-18
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9341
# Batch-30 : CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9325
# Batch-45 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9316
# Batch-60 : CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9317
# Batch-75 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9317
# Batch-90 : CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9309
# Batch-105: CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9305
# Batch-120: CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9305
# Batch-135: CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9308
# Batch-150: CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9307
# Batch-165: CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9308
# Batch-180: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9308
# Batch-195: CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9308
# Batch-210: CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9309
# Batch-225: CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9312
# Batch-226: CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9312
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9157
# Batch-30 : CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9161
# Batch-45 : CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9161
# Batch-60 : CrossEntropyLoss=2.2769 | MulticlassF1Score=0.9159
# Batch-63 : CrossEntropyLoss=2.2832 | MulticlassF1Score=0.9154
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2689 | Mean MulticlassF1Score = 0.9313
# Validation : Mean CrossEntropyLoss = 2.2740 | Mean MulticlassF1Score = 0.9174
# ================================================================================
#
# EPOCH-19
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9307
# Batch-30 : CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9346
# Batch-45 : CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9327
# Batch-60 : CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9326
# Batch-75 : CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9328
# Batch-90 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9328
# Batch-105: CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9323
# Batch-120: CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9323
# Batch-135: CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9323
# Batch-150: CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9319
# Batch-165: CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9318
# Batch-180: CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9314
# Batch-195: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9315
# Batch-210: CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9317
# Batch-225: CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9315
# Batch-226: CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9315
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9122
# Batch-30 : CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9156
# Batch-45 : CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9165
# Batch-60 : CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9157
# Batch-63 : CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9160
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2687 | Mean MulticlassF1Score = 0.9321
# Validation : Mean CrossEntropyLoss = 2.2737 | Mean MulticlassF1Score = 0.9157
# ================================================================================
#
# EPOCH-20
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9325
# Batch-30 : CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9309
# Batch-45 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9324
# Batch-60 : CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9329
# Batch-75 : CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9323
# Batch-90 : CrossEntropyLoss=2.2774 | MulticlassF1Score=0.9324
# Batch-105: CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9321
# Batch-120: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9320
# Batch-135: CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9320
# Batch-150: CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9324
# Batch-165: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9322
# Batch-180: CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9321
# Batch-195: CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9321
# Batch-210: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9321
# Batch-225: CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9319
# Batch-226: CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9319
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9141
# Batch-30 : CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9140
# Batch-45 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9151
# Batch-60 : CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9151
# Batch-63 : CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9156
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2686 | Mean MulticlassF1Score = 0.9321
# Validation : Mean CrossEntropyLoss = 2.2738 | Mean MulticlassF1Score = 0.9150
# ================================================================================
#
# EPOCH-21
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9286
# Batch-30 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9299
# Batch-45 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9320
# Batch-60 : CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9327
# Batch-75 : CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9319
# Batch-90 : CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9324
# Batch-105: CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9328
# Batch-120: CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9330
# Batch-135: CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9327
# Batch-150: CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9327
# Batch-165: CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9332
# Batch-180: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9330
# Batch-195: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9328
# Batch-210: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9326
# Batch-225: CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9327
# Batch-226: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9326
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2822 | MulticlassF1Score=0.9095
# Batch-30 : CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9140
# Batch-45 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9159
# Batch-60 : CrossEntropyLoss=2.2759 | MulticlassF1Score=0.9157
# Batch-63 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9155
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2684 | Mean MulticlassF1Score = 0.9320
# Validation : Mean CrossEntropyLoss = 2.2738 | Mean MulticlassF1Score = 0.9143
# ================================================================================
#
# EPOCH-22
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9313
# Batch-30 : CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9306
# Batch-45 : CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9320
# Batch-60 : CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9334
# Batch-75 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9324
# Batch-90 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9318
# Batch-105: CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9319
# Batch-120: CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9324
# Batch-135: CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9324
# Batch-150: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9328
# Batch-165: CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9327
# Batch-180: CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9325
# Batch-195: CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9328
# Batch-210: CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9328
# Batch-225: CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9329
# Batch-226: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9329
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9165
# Batch-30 : CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9145
# Batch-45 : CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9150
# Batch-60 : CrossEntropyLoss=2.2772 | MulticlassF1Score=0.9150
# Batch-63 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9155
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2682 | Mean MulticlassF1Score = 0.9325
# Validation : Mean CrossEntropyLoss = 2.2738 | Mean MulticlassF1Score = 0.9155
# ================================================================================
#
# EPOCH-23
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9370
# Batch-30 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9354
# Batch-45 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9350
# Batch-60 : CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9342
# Batch-75 : CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9334
# Batch-90 : CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9339
# Batch-105: CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9341
# Batch-120: CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9337
# Batch-135: CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9338
# Batch-150: CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9335
# Batch-165: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9331
# Batch-180: CrossEntropyLoss=2.2622 | MulticlassF1Score=0.9332
# Batch-195: CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9334
# Batch-210: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9336
# Batch-225: CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9334
# Batch-226: CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9334
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9157
# Batch-30 : CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9162
# Batch-45 : CrossEntropyLoss=2.2756 | MulticlassF1Score=0.9162
# Batch-60 : CrossEntropyLoss=2.2759 | MulticlassF1Score=0.9150
# Batch-63 : CrossEntropyLoss=2.2768 | MulticlassF1Score=0.9152
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2681 | Mean MulticlassF1Score = 0.9343
# Validation : Mean CrossEntropyLoss = 2.2739 | Mean MulticlassF1Score = 0.9166
# ================================================================================
#
# EPOCH-24
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2611 | MulticlassF1Score=0.9386
# Batch-30 : CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9358
# Batch-45 : CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9356
# Batch-60 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9343
# Batch-75 : CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9338
# Batch-90 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9332
# Batch-105: CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9332
# Batch-120: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9330
# Batch-135: CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9330
# Batch-150: CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9331
# Batch-165: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9332
# Batch-180: CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9334
# Batch-195: CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9335
# Batch-210: CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9335
# Batch-225: CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9335
# Batch-226: CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9334
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9200
# Batch-30 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9204
# Batch-45 : CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9201
# Batch-60 : CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9199
# Batch-63 : CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9199
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2681 | Mean MulticlassF1Score = 0.9340
# Validation : Mean CrossEntropyLoss = 2.2725 | Mean MulticlassF1Score = 0.9190
# Patience = 1/50❗
# ================================================================================
#
# EPOCH-25
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9398
# Batch-30 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9390
# Batch-45 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9407
# Batch-60 : CrossEntropyLoss=2.2747 | MulticlassF1Score=0.9389
# Batch-75 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9387
# Batch-90 : CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9387
# Batch-105: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9382
# Batch-120: CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9378
# Batch-135: CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9375
# Batch-150: CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9372
# Batch-165: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9373
# Batch-180: CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9372
# Batch-195: CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9371
# Batch-210: CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9369
# Batch-225: CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9369
# Batch-226: CrossEntropyLoss=2.2611 | MulticlassF1Score=0.9369
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2778 | MulticlassF1Score=0.9190
# Batch-30 : CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9198
# Batch-45 : CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9207
# Batch-60 : CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9205
# Batch-63 : CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9206
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2670 | Mean MulticlassF1Score = 0.9384
# Validation : Mean CrossEntropyLoss = 2.2722 | Mean MulticlassF1Score = 0.9197
# ================================================================================
#
# EPOCH-26
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9410
# Batch-30 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9400
# Batch-45 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9395
# Batch-60 : CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9381
# Batch-75 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9385
# Batch-90 : CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9381
# Batch-105: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9381
# Batch-120: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9380
# Batch-135: CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9376
# Batch-150: CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9376
# Batch-165: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9377
# Batch-180: CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9381
# Batch-195: CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9379
# Batch-210: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9377
# Batch-225: CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9380
# Batch-226: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9381
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9233
# Batch-30 : CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9226
# Batch-45 : CrossEntropyLoss=2.2783 | MulticlassF1Score=0.9215
# Batch-60 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9208
# Batch-63 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9207
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2667 | Mean MulticlassF1Score = 0.9386
# Validation : Mean CrossEntropyLoss = 2.2722 | Mean MulticlassF1Score = 0.9224
# ================================================================================
#
# EPOCH-27
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9380
# Batch-30 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9388
# Batch-45 : CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9402
# Batch-60 : CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9396
# Batch-75 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9397
# Batch-90 : CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9395
# Batch-105: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9391
# Batch-120: CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9389
# Batch-135: CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9389
# Batch-150: CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9386
# Batch-165: CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9387
# Batch-180: CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9386
# Batch-195: CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9385
# Batch-210: CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9384
# Batch-225: CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9383
# Batch-226: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9383
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9223
# Batch-30 : CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9219
# Batch-45 : CrossEntropyLoss=2.2756 | MulticlassF1Score=0.9214
# Batch-60 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9207
# Batch-63 : CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9206
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2667 | Mean MulticlassF1Score = 0.9390
# Validation : Mean CrossEntropyLoss = 2.2722 | Mean MulticlassF1Score = 0.9209
# ================================================================================
#
# EPOCH-28
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9432
# Batch-30 : CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9405
# Batch-45 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9402
# Batch-60 : CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9391
# Batch-75 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9394
# Batch-90 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9395
# Batch-105: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9394
# Batch-120: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9396
# Batch-135: CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9397
# Batch-150: CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9395
# Batch-165: CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9391
# Batch-180: CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9387
# Batch-195: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9386
# Batch-210: CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9383
# Batch-225: CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9386
# Batch-226: CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9385
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9225
# Batch-30 : CrossEntropyLoss=2.2747 | MulticlassF1Score=0.9200
# Batch-45 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9218
# Batch-60 : CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9208
# Batch-63 : CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9212
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2666 | Mean MulticlassF1Score = 0.9397
# Validation : Mean CrossEntropyLoss = 2.2719 | Mean MulticlassF1Score = 0.9217
# ================================================================================
#
# EPOCH-29
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9404
# Batch-30 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9405
# Batch-45 : CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9400
# Batch-60 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9402
# Batch-75 : CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9406
# Batch-90 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9405
# Batch-105: CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9401
# Batch-120: CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9397
# Batch-135: CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9399
# Batch-150: CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9399
# Batch-165: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9401
# Batch-180: CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9402
# ...
# Batch-30 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9477
# Batch-45 : CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9480
# Batch-60 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9486
# Batch-63 : CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9484
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2569 | Mean MulticlassF1Score = 0.9690
# Validation : Mean CrossEntropyLoss = 2.2636 | Mean MulticlassF1Score = 0.9476
# ================================================================================
#
# EPOCH-42
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9704
# Batch-30 : CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9716
# Batch-45 : CrossEntropyLoss=2.2532 | MulticlassF1Score=0.9717
# Batch-60 : CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9710
# Batch-75 : CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9707
# Batch-90 : CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9703
# Batch-105: CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9704
# Batch-120: CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9698
# Batch-135: CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9697
# Batch-150: CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9698
# Batch-165: CrossEntropyLoss=2.2547 | MulticlassF1Score=0.9698
# Batch-180: CrossEntropyLoss=2.2597 | MulticlassF1Score=0.9697
# Batch-195: CrossEntropyLoss=2.2551 | MulticlassF1Score=0.9697
# Batch-210: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9696
# Batch-225: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9696
# Batch-226: CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9696
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9488
# Batch-30 : CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9492
# Batch-45 : CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9490
# Batch-60 : CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9486
# Batch-63 : CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9487
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2569 | Mean MulticlassF1Score = 0.9702
# Validation : Mean CrossEntropyLoss = 2.2634 | Mean MulticlassF1Score = 0.9494
# ================================================================================
#
# EPOCH-43
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9699
# Batch-30 : CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9719
# Batch-45 : CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9703
# Batch-60 : CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9707
# Batch-75 : CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9707
# Batch-90 : CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9710
# Batch-105: CrossEntropyLoss=2.2551 | MulticlassF1Score=0.9712
# Batch-120: CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9709
# Batch-135: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9709
# Batch-150: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9708
# Batch-165: CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9707
# Batch-180: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9706
# Batch-195: CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9709
# Batch-210: CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9708
# Batch-225: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9706
# Batch-226: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9706
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9494
# Batch-30 : CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9498
# Batch-45 : CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9502
# Batch-60 : CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9494
# Batch-63 : CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9491
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2565 | Mean MulticlassF1Score = 0.9707
# Validation : Mean CrossEntropyLoss = 2.2633 | Mean MulticlassF1Score = 0.9491
# ================================================================================
#
# EPOCH-44
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9726
# Batch-30 : CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9701
# Batch-45 : CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9715
# Batch-60 : CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9716
# Batch-75 : CrossEntropyLoss=2.2524 | MulticlassF1Score=0.9714
# Batch-90 : CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9709
# Batch-105: CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9713
# Batch-120: CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9714
# Batch-135: CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9712
# Batch-150: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9711
# Batch-165: CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9708
# Batch-180: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9708
# Batch-195: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9709
# Batch-210: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9709
# Batch-225: CrossEntropyLoss=2.2519 | MulticlassF1Score=0.9708
# Batch-226: CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9708
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9536
# Batch-30 : CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9507
# Batch-45 : CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9495
# Batch-60 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9493
# Batch-63 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9492
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2565 | Mean MulticlassF1Score = 0.9712
# Validation : Mean CrossEntropyLoss = 2.2634 | Mean MulticlassF1Score = 0.9500
# ================================================================================
#
# EPOCH-45
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2541 | MulticlassF1Score=0.9688
# Batch-30 : CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9699
# Batch-45 : CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9704
# Batch-60 : CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9705
# Batch-75 : CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9710
# Batch-90 : CrossEntropyLoss=2.2543 | MulticlassF1Score=0.9711
# Batch-105: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9707
# Batch-120: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9708
# Batch-135: CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9707
# Batch-150: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9708
# Batch-165: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9707
# Batch-180: CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9709
# Batch-195: CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9706
# Batch-210: CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9708
# Batch-225: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9708
# Batch-226: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9708
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9508
# Batch-30 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9491
# Batch-45 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9495
# Batch-60 : CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9494
# Batch-63 : CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9501
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2564 | Mean MulticlassF1Score = 0.9704
# Validation : Mean CrossEntropyLoss = 2.2630 | Mean MulticlassF1Score = 0.9490
# ================================================================================
#
# EPOCH-46
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9706
# Batch-30 : CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9718
# Batch-45 : CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9714
# Batch-60 : CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9717
# Batch-75 : CrossEntropyLoss=2.2538 | MulticlassF1Score=0.9712
# Batch-90 : CrossEntropyLoss=2.2542 | MulticlassF1Score=0.9716
# Batch-105: CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9719
# Batch-120: CrossEntropyLoss=2.2536 | MulticlassF1Score=0.9719
# Batch-135: CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9721
# Batch-150: CrossEntropyLoss=2.2533 | MulticlassF1Score=0.9722
# Batch-165: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9720
# Batch-180: CrossEntropyLoss=2.2603 | MulticlassF1Score=0.9718
# Batch-195: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9717
# Batch-210: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9715
# Batch-225: CrossEntropyLoss=2.2536 | MulticlassF1Score=0.9714
# Batch-226: CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9714
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9465
# Batch-30 : CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9487
# Batch-45 : CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9482
# Batch-60 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9486
# Batch-63 : CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9493
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2563 | Mean MulticlassF1Score = 0.9717
# Validation : Mean CrossEntropyLoss = 2.2632 | Mean MulticlassF1Score = 0.9481
# ================================================================================
#
# EPOCH-47
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2541 | MulticlassF1Score=0.9721
# Batch-30 : CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9715
# Batch-45 : CrossEntropyLoss=2.2538 | MulticlassF1Score=0.9720
# Batch-60 : CrossEntropyLoss=2.2539 | MulticlassF1Score=0.9720
# Batch-75 : CrossEntropyLoss=2.2523 | MulticlassF1Score=0.9721
# Batch-90 : CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9721
# Batch-105: CrossEntropyLoss=2.2535 | MulticlassF1Score=0.9721
# Batch-120: CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9720
# Batch-135: CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9717
# Batch-150: CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9719
# Batch-165: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9718
# Batch-180: CrossEntropyLoss=2.2528 | MulticlassF1Score=0.9717
# Batch-195: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9716
# Batch-210: CrossEntropyLoss=2.2535 | MulticlassF1Score=0.9715
# Batch-225: CrossEntropyLoss=2.2542 | MulticlassF1Score=0.9714
# Batch-226: CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9714
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9461
# Batch-30 : CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9498
# Batch-45 : CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9497
# Batch-60 : CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9501
# Batch-63 : CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9501
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2562 | Mean MulticlassF1Score = 0.9718
# Validation : Mean CrossEntropyLoss = 2.2631 | Mean MulticlassF1Score = 0.9487
# ================================================================================
#
# EPOCH-48
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9697
# Batch-30 : CrossEntropyLoss=2.2538 | MulticlassF1Score=0.9711
# Batch-45 : CrossEntropyLoss=2.2542 | MulticlassF1Score=0.9717
# Batch-60 : CrossEntropyLoss=2.2532 | MulticlassF1Score=0.9725
# Batch-75 : CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9720
# Batch-90 : CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9723
# Batch-105: CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9720
# Batch-120: CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9718
# Batch-135: CrossEntropyLoss=2.2531 | MulticlassF1Score=0.9718
# Batch-150: CrossEntropyLoss=2.2597 | MulticlassF1Score=0.9721
# Batch-165: CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9721
# Batch-180: CrossEntropyLoss=2.2522 | MulticlassF1Score=0.9719
# Batch-195: CrossEntropyLoss=2.2522 | MulticlassF1Score=0.9720
# Batch-210: CrossEntropyLoss=2.2541 | MulticlassF1Score=0.9721
# Batch-225: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9720
# Batch-226: CrossEntropyLoss=2.2533 | MulticlassF1Score=0.9720
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9486
# Batch-30 : CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9497
# Batch-45 : CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9496
# Batch-60 : CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9500
# Batch-63 : CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9503
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2560 | Mean MulticlassF1Score = 0.9717
# Validation : Mean CrossEntropyLoss = 2.2630 | Mean MulticlassF1Score = 0.9498
# ================================================================================
#
# EPOCH-49
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9710
# Batch-30 : CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9710
# Batch-45 : CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9716
# Batch-60 : CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9717
# Batch-75 : CrossEntropyLoss=2.2542 | MulticlassF1Score=0.9720
# Batch-90 : CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9728
# Batch-105: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9727
# Batch-120: CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9729
# Batch-135: CrossEntropyLoss=2.2523 | MulticlassF1Score=0.9727
# Batch-150: CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9729
# Batch-165: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9728
# Batch-180: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9728
# Batch-195: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9727
# Batch-210: CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9726
# Batch-225: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9725
# Batch-226: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9725
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9488
# Batch-30 : CrossEntropyLoss=2.2612 | MulticlassF1Score=0.9470
# Batch-45 : CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9492
# Batch-60 : CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9497
# Batch-63 : CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9499
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2559 | Mean MulticlassF1Score = 0.9724
# Validation : Mean CrossEntropyLoss = 2.2630 | Mean MulticlassF1Score = 0.9491
# ================================================================================
#
# EPOCH-50
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2541 | MulticlassF1Score=0.9729
# Batch-30 : CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9724
# Batch-45 : CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9716
# Batch-60 : CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9721
# Batch-75 : CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9718
# Batch-90 : CrossEntropyLoss=2.2542 | MulticlassF1Score=0.9720
# Batch-105: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9726
# Batch-120: CrossEntropyLoss=2.2547 | MulticlassF1Score=0.9725
# Batch-135: CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9722
# Batch-150: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9722
# Batch-165: CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9721
# Batch-180: CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9724
# Batch-195: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9723
# Batch-210: CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9723
# Batch-225: CrossEntropyLoss=2.2535 | MulticlassF1Score=0.9725
# Batch-226: CrossEntropyLoss=2.2519 | MulticlassF1Score=0.9725
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9468
# Batch-30 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9468
# Batch-45 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9485
# Batch-60 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9494
# Batch-63 : CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9496
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2559 | Mean MulticlassF1Score = 0.9723
# Validation : Mean CrossEntropyLoss = 2.2631 | Mean MulticlassF1Score = 0.9483
# ================================================================================
#
# TRAINING SUMMARY
# Best CrossEntropyLoss training    : 2.2559
# Best CrossEntropyLoss training    : 2.2631
# Best MulticlassF1Score validation : 0.9723
# Best MulticlassF1Score validation : 0.9483
# Training duration                 : 4.2968 minutes.
# Training date                     : 2022-10-19 08:37:22.274867+08:00

# %% [markdown]
# ## End Training

# %% [markdown]
# # Evaluation

# %%
def evaluation(dataloader, model, criterion, metric):
    model.eval()
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)
            pred = rearrange(prob.argmax(dim=1).reshape(feature.shape[0], len(dataloader.dataset)), "s n -> n s")

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob.argmax(dim=1), actual_label.to(hyperparams.device))
            metric_score = metric.compute()

    return loss, metric_score, pred

train_dataloader = DataLoader(train_dataset, batch_size=len(train_dataset))
val_dataloader = DataLoader(val_dataset, batch_size=len(val_dataset))
test_dataloader = DataLoader(test_dataset, batch_size=len(test_dataset))

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
train_loss, train_f1_score, train_pred_label = evaluation(train_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_loss, val_f1_score, val_pred_label = evaluation(val_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
test_loss, test_f1_score, test_pred_label = evaluation(test_dataloader, model, criterion, metric)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9728, device='cuda:0'),
#  tensor(0.9496, device='cuda:0'),
#  tensor(0.9499, device='cuda:0'))

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9728, device='cuda:0'),
#  tensor(0.9496, device='cuda:0'),
#  tensor(0.9499, device='cuda:0'))

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns

def viz_evaluation(pred_label, actual_label, title):
    plt.figure(figsize=(15, 7), dpi=200)
    sns.heatmap(pred_label.detach().cpu() == actual_label, cbar=True, cmap="binary_r")
    plt.xlabel("Sentence Length")
    plt.ylabel("Sentence")
    plt.title(title)
    plt.savefig(f"{root_path}/heatmap_{title.lower()}.jpg", dpi=200)
    plt.show()

train_actual_label = train_dataloader.dataset.tensors[1]
val_actual_label = val_dataloader.dataset.tensors[1]
test_actual_label = test_dataloader.dataset.tensors[1]

viz_evaluation(train_pred_label, train_actual_label, f"Training (F1-Score: {(train_f1_score):.4f})")
viz_evaluation(val_pred_label, val_actual_label, f"Validation (F1-Score: {(val_f1_score):.4f})")
viz_evaluation(test_pred_label, test_actual_label, f"Test (F1-Score: {(test_f1_score):.4f})")

# %% [markdown]
# ## Confusion Matrix

# %%
def confusion_matrix(pred_class, actual_class, title, normalize=None):
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize=normalize)
    plt.figure(figsize=(20, 10), dpi=200)
    sns.heatmap(conf_mat(pred_class.detach().cpu(), actual_class), annot=True, fmt=".2g", xticklabels=list(label_to_idx.keys()), yticklabels=list(label_to_idx.keys()));
    plt.yticks(rotation=0)
    plt.title(title)
    plt.xlabel("Actual Class")
    plt.ylabel("Predict Class")
    plt.savefig(f"{root_path}/conf_matrix_{title.lower()}.jpg", dpi=200)

confusion_matrix(train_pred_label, train_actual_label, "Training", "pred")
confusion_matrix(val_pred_label,val_actual_label, "Validation", "pred")
confusion_matrix(test_pred_label, test_actual_label, "Test", "pred")
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 96 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 144 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)

# %% [markdown]
# ## Prediction Table

# %%
def number_wrong_pred_each_class(pred_class, actual_class):
    classes, count_class = actual_class.flatten().unique(return_counts=True)
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize="none")
    correct_pred_count_class = conf_mat(pred_class.detach().cpu(), actual_class).diag()
    
    correct_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (correct_pred_count_class))}
    wrong_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (count_class - correct_pred_count_class))}
    
    return correct_pred, wrong_pred

correct_pred, wrong_pred = number_wrong_pred_each_class(train_pred_label, train_actual_label)
print(f"| {'Number class'.ljust(14)} | {'Correct prediction'.ljust(12)} | {'Wrong prediction'.ljust(12)} |")
for (label_correct_pred, count_correct_pred), (label_wrong_pred, count_wrong_pred) in zip(correct_pred.items(), wrong_pred.items()):
    print(f"| {str(label_correct_pred).ljust(6)}: {str(count_correct_pred + count_wrong_pred).ljust(7)}| {label_correct_pred.ljust(6)}: {str(count_correct_pred).ljust(10)} | {label_wrong_pred.ljust(6)}: {str(count_wrong_pred).ljust(8)} |")
# Out:
# | Number class   | Correct prediction | Wrong prediction |
# | CC    : 5397   | CC    : 5318       | CC    : 79       |
# | CD    : 12862  | CD    : 12771      | CD    : 91       |
# | DT    : 278    | DT    : 0          | DT    : 278      |
# | FW    : 1605   | FW    : 1343       | FW    : 262      |
# | IN    : 15290  | IN    : 15151      | IN    : 139      |
# | JJ    : 7025   | JJ    : 6728       | JJ    : 297      |
# | MD    : 3798   | MD    : 3723       | MD    : 75       |
# | NEG   : 1101   | NEG   : 0          | NEG   : 1101     |
# | NN    : 44472  | NN    : 43930      | NN    : 542      |
# | NND   : 1033   | NND   : 904        | NND   : 129      |
# | NNP   : 25007  | NNP   : 24540      | NNP   : 467      |
# | OD    : 519    | OD    : 498        | OD    : 21       |
# | PR    : 3880   | PR    : 3839       | PR    : 41       |
# | PRP   : 5449   | PRP   : 5369       | PRP   : 80       |
# | RB    : 3502   | RB    : 3282       | RB    : 220      |
# | RP    : 131    | RP    : 0          | RP    : 131      |
# | SC    : 9421   | SC    : 9179       | SC    : 242      |
# | SYM   : 1564   | SYM   : 1550       | SYM   : 14       |
# | UH    : 21     | UH    : 5          | UH    : 16       |
# | VB    : 22760  | VB    : 22436      | VB    : 324      |
# | WH    : 180    | WH    : 0          | WH    : 180      |
# | X     : 290    | X     : 4          | X     : 286      |
# | Z     : 19042  | Z     : 19039      | Z     : 3        |
# | <PAD> : 407577 | <PAD> : 407577     | <PAD> : 0        |

# %%
train_actual_label[308], train_pred_label[308]
# Out:
# (tensor([ 8,  3, 12, 19,  8,  8,  8, 16, 19,  4, 10,  8, 10,  0,  4,  1,  8,  8,
#           8,  5,  4,  8, 10,  0, 10, 10, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23]),
#  tensor([ 8,  8, 12, 19,  8,  8,  5, 16, 19,  4, 10,  8, 10,  0,  4,  1,  8,  8,
#           8,  5,  4,  8, 10,  0, 10, 10, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23], device='cuda:0'))

# %%
train_actual_label[308] == train_pred_label[308].detach().cpu()
# Out:
# tensor([ True, False,  True,  True,  True,  True, False,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True])

# %% [markdown]
# ## OOV prediction is correct

# %%
def oov_flag_token(sentences, max_seq_len=hyperparams.max_seq_len):
    sent_copy = deepcopy(sentences)
    sent = []
    oov_flag = []
    
    for sentence in tqdm(sent_copy):
        for token in sentence:
            sent.append(token[2])
        
        for _ in range(max_seq_len- len(sentence)):
            sent.append(False)
        
        oov_flag.append(sent)
        sent = []
        
    return np.array(oov_flag)

train_oov_flag = oov_flag_token(train_sentences, max_seq_len=hyperparams.max_seq_len)
val_oov_flag = oov_flag_token(val_sentences, max_seq_len=hyperparams.max_seq_len)
test_oov_flag = oov_flag_token(test_sentences, max_seq_len=hyperparams.max_seq_len)

def pencentage_oov_pred_correct(pred_oov_flag, oov_flag_tensor):
    oov_correct_counter = 0
    oov_wrong_counter = 0

    for pred, oov_label in tqdm(zip(pred_oov_flag, oov_flag_tensor)):
        if pred == True and oov_label == True:
            oov_correct_counter += 1
        elif pred == False and oov_label == True:
            oov_wrong_counter += 1
        else:
            continue
            
    return oov_correct_counter, oov_wrong_counter

train_pred_oov_flag = (train_actual_label == train_pred_label.detach().cpu()).flatten()
val_pred_oov_flag = (val_actual_label == val_pred_label.detach().cpu()).flatten()
test_pred_oov_flag = (test_actual_label == test_pred_label.detach().cpu()).flatten()
train_oov_flag_tensor = torch.tensor(train_oov_flag).flatten()
val_oov_flag_tensor = torch.tensor(val_oov_flag).flatten()
test_oov_flag_tensor = torch.tensor(test_oov_flag).flatten()

train_oov_correct_counter, train_oov_wrong_counter = pencentage_oov_pred_correct(train_pred_oov_flag, train_oov_flag_tensor)
val_oov_correct_counter, val_oov_wrong_counter = pencentage_oov_pred_correct(val_pred_oov_flag, val_oov_flag_tensor)
test_oov_correct_counter, test_oov_wrong_counter = pencentage_oov_pred_correct(test_pred_oov_flag, test_oov_flag_tensor)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
def print_percentage_pred_oov(title, oov_correct_counter, oov_wrong_counter):
    print(f"{title}")
    print(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}")
    print(f"Correct prediction          : {oov_correct_counter}")
    print(f"Wrong prediction            : {oov_wrong_counter}")
    print(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n")
    
    with open(f"{root_path}/oov_summary.txt", "a") as f:
        f.write(f"{title}\n")
        f.write(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}\n")
        f.write(f"Correct prediction          : {oov_correct_counter}\n")
        f.write(f"Wrong prediction            : {oov_wrong_counter}\n")
        f.write(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n\n")

# %%
print_percentage_pred_oov("Training", train_oov_correct_counter, train_oov_wrong_counter)
print_percentage_pred_oov("Validation", val_oov_correct_counter, val_oov_wrong_counter)
print_percentage_pred_oov("Test", test_oov_correct_counter, test_oov_wrong_counter)
# Out:
# Training
# Number OOV token            : 11971
# Correct prediction          : 11399
# Wrong prediction            : 572
# Percentage correct oov pred : 95.22178598279176
#
# Validation
# Number OOV token            : 3190
# Correct prediction          : 2877
# Wrong prediction            : 313
# Percentage correct oov pred : 90.18808777429467
#
# Test
# Number OOV token            : 1401
# Correct prediction          : 1278
# Wrong prediction            : 123
# Percentage correct oov pred : 91.22055674518201

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(train_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(val_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(test_oov_flag, cmap=plt.cm.binary_r);
