# %% [markdown]
# # Import modules

# %%
import csv
import os
import pickle
import pytz
import torch
import timeit
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from copy import deepcopy
from datetime import datetime
from einops import rearrange
from itertools import chain
from time import time
from torch import nn, optim
from torchmetrics.classification import MulticlassAccuracy, MulticlassF1Score, MulticlassConfusionMatrix
from torch.optim import lr_scheduler
from tqdm.notebook import tqdm
from torch.utils.data import TensorDataset, DataLoader
from polyglot.mapping import Embedding, CaseExpander, DigitExpander

# %% [markdown]
# # Hyperparameters

# %%
class Hyperparams:
     def __init__(
        self,
        context_size=45,
        fold=5,
        max_seq_len=82,
        input_size=64,
        batch_size=32,
        num_hidden_layer=1,
        hidden_size=128,
        dropout=0,
        bias=True,
        output_size=24,
        shuffle=True,
        lr=0.005,
        batch_first=False,
        bidirectional=True,
        init_wb_with_kaiming_normal=True,
        n_epoch=50,
        patience=50,
        device="cuda" if torch.cuda.is_available() else "cpu"
    ):
        self.context_size = context_size
        self.fold = fold
        self.input_size = input_size
        self.max_seq_len = max_seq_len
        self.batch_size = batch_size
        self.num_hidden_layer = num_hidden_layer
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.output_size = output_size
        self.shuffle = shuffle
        self.lr = lr
        self.batch_first = batch_first
        self.bidirectional = bidirectional
        self.init_wb_with_kaiming_normal = init_wb_with_kaiming_normal
        self.n_epoch = n_epoch
        self.patience = patience
        self.device = device

hyperparams = Hyperparams()

# %% [markdown]
# # Dataset

# %%
id_pos_tag = pd.read_csv("../../../datasets/raw/Indonesian_Manually_Tagged_Corpus.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False) 
train = pd.read_csv(f"../../../datasets/raw/cv/train/train.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
val = pd.read_csv(f"../../../datasets/raw/cv/val/val.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
test = pd.read_csv(f"../../../datasets/raw/cv/test/test.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)

# %% [markdown]
# # Pre-trained Word Embedding

# %%
embeddings = Embedding.load("../../../word_embeddings/polyglot/idn_embeddings.tar.bz2")
embeddings.apply_expansion(DigitExpander)
embeddings.apply_expansion(CaseExpander)

oov_embeddings = pickle.load(open(f"../../../logs/comick/{hyperparams.context_size}_contexts/10-11-2022_14-39-31/oov_embedding_dict.pkl", "rb"))

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Add OOV Flag

# %%
def add_oov_flag(tokens, embeddings):
    oov_flags = []
    
    for token in tqdm(tokens):
        try:
            if token not in embeddings:
                oov_flags.append(True)
            else:
                oov_flags.append(False)
        except:
            oov_flags.append(False)
        
    return pd.DataFrame(oov_flags, columns=["is_oov"])

id_pos_tag_oov_flags = add_oov_flag(id_pos_tag["token"].values, embeddings)
train_oov_flags = add_oov_flag(train["token"].values, embeddings)
val_oov_flags = add_oov_flag(val["token"].values, embeddings)
test_oov_flags = add_oov_flag(test["token"].values, embeddings)
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/191905 [00:00<?, ?it/s]
#   0%|          | 0/21691 [00:00<?, ?it/s]
#   0%|          | 0/53056 [00:00<?, ?it/s]

# %% [markdown]
# ## Concate OOV Flag

# %%
id_pos_tag_df = pd.concat([id_pos_tag, id_pos_tag_oov_flags], axis=1)
train_df = pd.concat([train, train_oov_flags], axis=1)
val_df = pd.concat([val, val_oov_flags], axis=1)
test_df = pd.concat([test, test_oov_flags], axis=1)

# %% [markdown]
# ## Lowercase OOV Token

# %%
id_pos_tag_df['token'] = np.where(id_pos_tag_df['is_oov'] == True, id_pos_tag_df['token'].str.lower(), id_pos_tag_df['token'])
train_df['token'] = np.where(train_df['is_oov'] == True, train_df['token'].str.lower(), train_df['token'])
val_df['token'] = np.where(val_df['is_oov'] == True, val_df['token'].str.lower(), val_df['token'])
test_df['token'] = np.where(test_df['is_oov'] == True, test_df['token'].str.lower(), test_df['token'])

# %% [markdown]
# ## Embedding Dict, Index to Token and Token to Index

# %%
tokens = list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None))

def embedding_dict(tokens, embeddings, oov_embeddings):
    embedding = {}
    
    for token in tokens:
        if token[0] is not np.nan:
            if token[2] == False or token[0] in embeddings:
                embedding[token[0]] = embeddings[token[0]]
            else:
                embedding[token[0]] = oov_embeddings[token[0].lower()]

    return embedding

embedding_dict = embedding_dict(tokens, embeddings, oov_embeddings)
embedding_dict["<PAD>"] = embeddings["<PAD>"]
word_embeddings = nn.Embedding.from_pretrained(torch.FloatTensor(np.array(list(embedding_dict.values()))), padding_idx=list(embedding_dict.keys()).index("<PAD>"), freeze=True)

idx_to_token = {idx: token for idx, token in enumerate(list(embedding_dict.keys()))}
token_to_idx = {token: idx for idx, token in enumerate(list(embedding_dict.keys()))}

# %% [markdown]
# ## Token to Sentence

# %%
def make_sentence(tokens, max_length_sentence=hyperparams.max_seq_len):
    sentence = []
    sentences = []

    for token in tqdm(tokens):
        if token[0] is not np.nan:
            sentence.append(token)
        else:
            sentences.append(sentence[:max_length_sentence])
            sentence = []

    return sentences

all_sentence = make_sentence(list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
train_sentences = make_sentence(list(train_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
val_sentences = make_sentence(list(test_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
test_sentences = make_sentence(list(val_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/191905 [00:00<?, ?it/s]
#   0%|          | 0/53056 [00:00<?, ?it/s]
#   0%|          | 0/21691 [00:00<?, ?it/s]

# %% [markdown]
# ## Word Token, Padding, and Word token to Index

# %%
def tokenize_docs(docs, idx_token):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token[idx_token])
        sentences.append(new_sentence)
        new_sentence = []

    return sentences

def padding(docs, max_seq_len=hyperparams.max_seq_len, mode="post", val_pad="<PAD>"):
    docs = deepcopy(docs)
    doc_with_pad = []
    docs_with_pad = []

    for doc in tqdm(docs):
        if mode == "pre":
            for _ in range(max_seq_len - len(doc)):
                doc.insert(0, val_pad)
        elif mode == "post":
            for _ in range(max_seq_len - len(doc)):
                doc.append(val_pad)
        else:
            return f"Mode {mode} is not available, use instead 'pre' or 'post'."
        
        docs_with_pad.append(doc)
        
    return np.array(docs_with_pad)

def sent_to_idx(docs, token_to_idx):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token_to_idx[token])
        sentences.append(new_sentence)
        new_sentence = []

    return np.array(sentences)

def convert_feature_to_idx(docs, idx_token, token_to_idx, max_seq_len):
    sentences = tokenize_docs(docs, idx_token)
    sentences_with_pad = padding(sentences, max_seq_len=max_seq_len, mode="post", val_pad="<PAD>")
    sentences_to_idx = sent_to_idx(sentences_with_pad, token_to_idx)
    
    return sentences_to_idx

train_sentence_idxs = convert_feature_to_idx(train_sentences, 0, token_to_idx, hyperparams.max_seq_len)
val_sentence_idxs = convert_feature_to_idx(val_sentences, 0, token_to_idx, hyperparams.max_seq_len)
test_sentence_idxs = convert_feature_to_idx(test_sentences, 0, token_to_idx, hyperparams.max_seq_len)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]

# %% [markdown]
# ## Encode Class

# %%
classes = sorted(np.delete(id_pos_tag_df["tag"].unique(), 3))
idx_to_label = {idx: label for idx, label in enumerate(classes + ["<PAD>"])}
label_to_idx = {label: idx for idx, label in enumerate(classes + ["<PAD>"])}

def encode_class(docs, label_to_idx, seq_len=hyperparams.max_seq_len):
    class_idxs = []
    classes = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            class_idxs.append(label_to_idx[token[1]])
            
        for _ in range(seq_len - len(sentence)):
            class_idxs.append(label_to_idx["<PAD>"])
                
        classes.append(class_idxs)
        class_idxs = []

    return np.array(classes)
        
train_class_idxs = encode_class(train_sentences, label_to_idx)
val_class_idxs = encode_class(val_sentences, label_to_idx)
test_class_idxs = encode_class(test_sentences, label_to_idx)

print(f"Training shape   : {train_sentence_idxs.shape, train_class_idxs.shape}")
print(f"validation shape : {val_class_idxs.shape, val_class_idxs.shape}")
print(f"Test shape       : {test_sentence_idxs.shape, test_class_idxs.shape}")
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# Training shape   : ((7222, 82), (7222, 82))
# validation shape : ((2006, 82), (2006, 82))
# Test shape       : ((802, 82), (802, 82))

# %% [markdown]
# ## Note
#
# - Number of sentences = 10030
# - Train : 72% (7222)
# - Val   : 8% (802)
# - Test  : 20% (2006)

# %% [markdown]
# # Build Model

# %% [markdown]
# ## Feature and Actual Class

# %%
train_feature = torch.LongTensor(train_sentence_idxs)
val_feature = torch.LongTensor(val_sentence_idxs)
test_feature = torch.LongTensor(test_sentence_idxs)

train_class = torch.LongTensor(train_class_idxs)
val_class = torch.LongTensor(val_class_idxs)
test_class = torch.LongTensor(test_class_idxs)

# %%
train_feature.shape, val_feature.shape, test_feature.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %%
train_class.shape, val_class.shape, test_class.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %% [markdown]
# ## Tensor Dataset

# %%
train_dataset = TensorDataset(train_feature, train_class)
val_dataset = TensorDataset(val_feature, val_class)
test_dataset = TensorDataset(test_feature, test_class)

# %% [markdown]
# ## Dataloader

# %%
train_dataloader = DataLoader(train_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
val_dataloader = DataLoader(val_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
test_dataloader = DataLoader(test_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)

# %% [markdown]
# ## Model

# %%
class POSTagger(nn.Module):
    def __init__(
        self,
        input_size=hyperparams.input_size,
        hidden_size=hyperparams.hidden_size,
        dropout=hyperparams.dropout,
        bias=hyperparams.bias,
        num_layers=hyperparams.num_hidden_layer,
        output_size=hyperparams.output_size,
        batch_first=hyperparams.batch_first,
        bidirectional=hyperparams.bidirectional,
        init_wb_with_kaiming_normal=hyperparams.init_wb_with_kaiming_normal
    ):
        super(POSTagger, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.num_layers = num_layers
        self.output_size = output_size
        self.batch_first = batch_first
        self.bidirectional = bidirectional
                
        self.feature = nn.LSTM(
            input_size = self.input_size,
            hidden_size = self.hidden_size,
            bias = self.bias,
            dropout = self.dropout,
            num_layers = self.num_layers,
            batch_first = self.batch_first,
            bidirectional = self.bidirectional
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(in_features=2 * self.hidden_size if hyperparams.bidirectional else self.hidden_size, out_features=self.output_size, bias=self.bias),
            nn.Softmax(dim=-1)
        )
        
        if init_wb_with_kaiming_normal:
            self.init_wb()

    def init_wb(self):
        for module in self.modules():
            if isinstance(module, (nn.Linear, nn.LSTM)):
                for name, param in module.named_parameters():
                    if "weight" in name:
                        nn.init.kaiming_normal_(param)
                    else:
                        nn.init.kaiming_normal_(param.reshape(1, -1))
        
    def forward(self, feature, hidden=None):
        output, (hidden, memory) = self.feature(feature, None)
        prob = self.classifier(output)

        return prob
    
model = POSTagger().to(hyperparams.device)
model
# Out:
# POSTagger(
#   (feature): LSTM(64, 128, bidirectional=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=24, bias=True)
#     (1): Softmax(dim=-1)
#   )
# )

# %% [markdown]
# ## Optimizer, Criterion, and Metric

# %%
optimizer = optim.Adam(model.parameters(), lr=hyperparams.lr)
criterion = nn.CrossEntropyLoss().to(hyperparams.device)
train_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", verbose=True, factor=0.5)

# %%
sum(param.numel() for param in model.parameters() if param.requires_grad)
# Out:
# 204824

# %% [markdown]
# ## Training Step

# %%
def training_step(dataloader, model, optimizer, criterion, metric, scheduler=None):
    model.train()
    
    batch_losses = []
    batch_metric_scores = []
    
    for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
        # Forward Propagation
        feature = rearrange(feature, "n s -> s n")
        actual_label = rearrange(actual_label, "n s -> s n")
        embedding = word_embeddings(feature)
        
        prob = model(
            embedding.to(hyperparams.device),
            actual_label.to(hyperparams.device)
        )
        
        prob = prob.reshape(-1, prob.shape[-1])
        actual_label = actual_label.reshape(-1)

        loss = criterion(prob, actual_label.to(hyperparams.device))
        metric_score = metric(prob, actual_label.to(hyperparams.device))
        metric_score = metric.compute()
                
        if scheduler is not None:
            scheduler.step(loss)
        
        batch_losses.append(loss.item())
        batch_metric_scores.append(metric_score)
        
        if len(dataloader) < 10:
            if batch % 1 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
        else:
            if batch % 15 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            
        # Backward Propagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Validation Step

# %%
def validation_step(dataloader, model, criterion, metric):
    model.eval()
    
    batch_losses = []
    batch_metric_scores = []
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob, actual_label.to(hyperparams.device))
            metric_score = metric.compute()

            batch_losses.append(loss.item())
            batch_metric_scores.append(metric_score)
            
            if len(dataloader) < 10 and (batch % 1 == 0 or batch == len(dataloader)):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            else:
                if batch % 15 == 0 or batch == len(dataloader):
                    batch_name = "Batch-" + str(batch)
                    print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                    with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                        f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Looping Step

# %%
now = datetime.now(pytz.timezone("Asia/Ujung_Pandang"))
path_name = now.strftime("%m-%d-%Y_%H-%M-%S")
root_path = f"../../../logs/classifier/{hyperparams.context_size}_contexts/fold_0{hyperparams.fold}/{path_name}"
os.makedirs(root_path)

def looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric, n_epoch=hyperparams.n_epoch, patience=hyperparams.patience, monitor="loss"):    
    start_time = time()
    
    epoch_training_losses = []
    epoch_training_metric_scores = []
    epoch_val_losses = []
    epoch_val_metric_scores = []
    patience_counter = 0
    
    # Hyperparameters
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write(f"HYPERPARAMETERS\n")
        f.write(f"{'-' * 80}\n")
        for name, value in vars(hyperparams).items():
            f.write(f"{name}: {value}\n")
        
        f.write("\n\nTRAINING PROGRESS\n")
        f.write(f"{'-' * 80}\n")
    
    # Training Progress
    for epoch in range(1, n_epoch + 1):
        print(f"EPOCH-{epoch}")
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"EPOCH-{epoch}\n")
            f.write(f"Training Step\n")
            
        # Training Step
        print("Training Step")
        batch_training_losses, batch_training_metric_scores = training_step(train_dataloader, model, optimizer, criterion, train_metric, scheduler=None)
        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))

        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))
        epoch_training_losses.append(epoch_training_loss.item())

        epoch_training_metric_score = torch.mean(torch.FloatTensor(batch_training_metric_scores))
        epoch_training_metric_scores.append(epoch_training_metric_score.item())
        
        # Validation Step
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"\nValidation Step\n")
            
        print("\nValidation Step")
        batch_val_losses, batch_val_metric_scores = validation_step(val_dataloader, model, criterion, val_metric)
        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))

        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))
        epoch_val_losses.append(epoch_val_loss.item())

        epoch_val_metric_score = torch.mean(torch.FloatTensor(batch_val_metric_scores))
        epoch_val_metric_scores.append(epoch_val_metric_score.item())
        
        with open(f"{root_path}/training_history.txt", "a") as f:
            if monitor == "loss":
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_losses[-1] < epoch_training_losses[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
            else:
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_metric_scores[-1] > epoch_training_metric_scores[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗\n")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
                    
            print("=" * 80, end="\n\n")
            
            f.write(f"{'=' * 80}\n\n")
            
            if patience_counter == patience:
                print(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                
                f.write(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                break
        
        train_metric.reset()
        val_metric.reset()
        
    finish_time = time()
    
    # Training plot 
    fig, (ax_loss, ax_metric_score) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    fig.suptitle(f"Training with context size = {hyperparams.context_size}")

    ax_loss.set_title("Loss")
    ax_loss.set_xlabel("Epoch")
    ax_loss.set_ylabel("Score")
    ax_loss.plot(epoch_training_losses, "green", label="Training")
    ax_loss.plot(epoch_val_losses, "orange", label="Validation")
    ax_loss.legend()
    ax_loss.grid()

    ax_metric_score.set_title("F1 Score")
    ax_metric_score.set_xlabel("Epoch")
    ax_metric_score.set_ylabel("Score")
    ax_metric_score.plot(epoch_training_metric_scores, "green", label="Training")
    ax_metric_score.plot(epoch_val_metric_scores, "orange", label="Validation")
    ax_metric_score.legend()
    ax_metric_score.grid()

    plt.savefig(f"{root_path}/training_plot.jpg", dpi=200)                        
    
    print("TRAINING SUMMARY")
    name_best_training_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_training_metric = f"Best {str(train_metric).split('(')[0]} validation".ljust(34)
    name_best_validation_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_validation_metric = f"Best {str(val_metric).split('(')[0]} validation".ljust(34)
    name_training_time = f"Training duration".ljust(34)
    name_training_date = f"Training date".ljust(34)
    
    print(f"{name_best_training_loss}: {best_training_loss:.4f}")
    print(f"{name_best_validation_loss}: {best_val_loss:.4f}")
    print(f"{name_best_training_metric}: {best_training_metric:.4f}")
    print(f"{name_best_validation_metric}: {best_val_metric:.4f}")
    print(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.")
    print(f"{name_training_date}: {now}")
    
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write("\nTRAINING SUMMARY\n")
        f.write(f"{'-' * 80}\n")
        f.write(f"{name_best_training_loss}: {best_training_loss:.4f}\n")
        f.write(f"{name_best_validation_loss}: {best_val_loss:.4f}\n")
        f.write(f"{name_best_training_metric}: {best_training_metric:.4f}\n")
        f.write(f"{name_best_validation_metric}: {best_val_metric:.4f}\n")
        f.write(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.\n")
        f.write(f"{name_training_date}: {now}\n")
    
    # Save epoch losses, epoch metric scores, model, state dict, and oov embedding dict
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_training_losses
    }).to_csv(f"{root_path}/training_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_training_metric_scores
    }).to_csv(f"{root_path}/training_metric_scores.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_val_losses
    }).to_csv(f"{root_path}/val_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_val_metric_scores
    }).to_csv(f"{root_path}/val_metric_scores.csv", index=False)    
    
    filename_model_params = f"{root_path}/model_params.pth"
    torch.save(best_state_dict, filename_model_params)
    
    return epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores

epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores = looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric)
# Out:
# EPOCH-1
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.5040 | MulticlassF1Score=0.1687
# Batch-30 : CrossEntropyLoss=2.4711 | MulticlassF1Score=0.2103
# Batch-45 : CrossEntropyLoss=2.5023 | MulticlassF1Score=0.2234
# Batch-60 : CrossEntropyLoss=2.4733 | MulticlassF1Score=0.2316
# Batch-75 : CrossEntropyLoss=2.4871 | MulticlassF1Score=0.2423
# Batch-90 : CrossEntropyLoss=2.4156 | MulticlassF1Score=0.2673
# Batch-105: CrossEntropyLoss=2.4245 | MulticlassF1Score=0.2917
# Batch-120: CrossEntropyLoss=2.4117 | MulticlassF1Score=0.3110
# Batch-135: CrossEntropyLoss=2.4192 | MulticlassF1Score=0.3257
# Batch-150: CrossEntropyLoss=2.3973 | MulticlassF1Score=0.3417
# Batch-165: CrossEntropyLoss=2.3679 | MulticlassF1Score=0.3655
# Batch-180: CrossEntropyLoss=2.3435 | MulticlassF1Score=0.3894
# Batch-195: CrossEntropyLoss=2.3423 | MulticlassF1Score=0.4111
# Batch-210: CrossEntropyLoss=2.3500 | MulticlassF1Score=0.4297
# Batch-225: CrossEntropyLoss=2.3521 | MulticlassF1Score=0.4461
# Batch-226: CrossEntropyLoss=2.3553 | MulticlassF1Score=0.4467
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3515 | MulticlassF1Score=0.6572
# Batch-30 : CrossEntropyLoss=2.3569 | MulticlassF1Score=0.6647
# Batch-45 : CrossEntropyLoss=2.3477 | MulticlassF1Score=0.6658
# Batch-60 : CrossEntropyLoss=2.3610 | MulticlassF1Score=0.6680
# Batch-63 : CrossEntropyLoss=2.3467 | MulticlassF1Score=0.6680
#
# Training   : Mean CrossEntropyLoss = 2.4302 | Mean MulticlassF1Score = 0.3000
# Validation : Mean CrossEntropyLoss = 2.3509 | Mean MulticlassF1Score = 0.6625
# ================================================================================
#
# EPOCH-2
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3355 | MulticlassF1Score=0.6821
# Batch-30 : CrossEntropyLoss=2.3424 | MulticlassF1Score=0.6900
# Batch-45 : CrossEntropyLoss=2.3361 | MulticlassF1Score=0.7007
# Batch-60 : CrossEntropyLoss=2.3392 | MulticlassF1Score=0.7077
# Batch-75 : CrossEntropyLoss=2.3311 | MulticlassF1Score=0.7127
# Batch-90 : CrossEntropyLoss=2.3384 | MulticlassF1Score=0.7141
# Batch-105: CrossEntropyLoss=2.3376 | MulticlassF1Score=0.7162
# Batch-120: CrossEntropyLoss=2.3267 | MulticlassF1Score=0.7180
# Batch-135: CrossEntropyLoss=2.3235 | MulticlassF1Score=0.7239
# Batch-150: CrossEntropyLoss=2.3161 | MulticlassF1Score=0.7310
# Batch-165: CrossEntropyLoss=2.3108 | MulticlassF1Score=0.7372
# Batch-180: CrossEntropyLoss=2.3185 | MulticlassF1Score=0.7418
# Batch-195: CrossEntropyLoss=2.3109 | MulticlassF1Score=0.7467
# Batch-210: CrossEntropyLoss=2.3198 | MulticlassF1Score=0.7504
# Batch-225: CrossEntropyLoss=2.3120 | MulticlassF1Score=0.7538
# Batch-226: CrossEntropyLoss=2.3184 | MulticlassF1Score=0.7539
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3018 | MulticlassF1Score=0.8016
# Batch-30 : CrossEntropyLoss=2.3103 | MulticlassF1Score=0.7961
# Batch-45 : CrossEntropyLoss=2.3101 | MulticlassF1Score=0.7955
# Batch-60 : CrossEntropyLoss=2.3105 | MulticlassF1Score=0.7975
# Batch-63 : CrossEntropyLoss=2.3108 | MulticlassF1Score=0.7976
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3252 | Mean MulticlassF1Score = 0.7194
# Validation : Mean CrossEntropyLoss = 2.3109 | Mean MulticlassF1Score = 0.7978
# ================================================================================
#
# EPOCH-3
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3064 | MulticlassF1Score=0.8049
# Batch-30 : CrossEntropyLoss=2.3107 | MulticlassF1Score=0.8037
# Batch-45 : CrossEntropyLoss=2.3108 | MulticlassF1Score=0.8026
# Batch-60 : CrossEntropyLoss=2.3001 | MulticlassF1Score=0.8043
# Batch-75 : CrossEntropyLoss=2.3161 | MulticlassF1Score=0.8041
# Batch-90 : CrossEntropyLoss=2.3114 | MulticlassF1Score=0.8037
# Batch-105: CrossEntropyLoss=2.3145 | MulticlassF1Score=0.8046
# Batch-120: CrossEntropyLoss=2.3048 | MulticlassF1Score=0.8039
# Batch-135: CrossEntropyLoss=2.3080 | MulticlassF1Score=0.8045
# Batch-150: CrossEntropyLoss=2.3113 | MulticlassF1Score=0.8041
# Batch-165: CrossEntropyLoss=2.3172 | MulticlassF1Score=0.8049
# Batch-180: CrossEntropyLoss=2.3032 | MulticlassF1Score=0.8048
# Batch-195: CrossEntropyLoss=2.3091 | MulticlassF1Score=0.8048
# Batch-210: CrossEntropyLoss=2.3083 | MulticlassF1Score=0.8048
# Batch-225: CrossEntropyLoss=2.3058 | MulticlassF1Score=0.8050
# Batch-226: CrossEntropyLoss=2.3121 | MulticlassF1Score=0.8049
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3073 | MulticlassF1Score=0.8046
# Batch-30 : CrossEntropyLoss=2.3053 | MulticlassF1Score=0.8061
# Batch-45 : CrossEntropyLoss=2.3068 | MulticlassF1Score=0.8053
# Batch-60 : CrossEntropyLoss=2.3135 | MulticlassF1Score=0.8029
# Batch-63 : CrossEntropyLoss=2.3326 | MulticlassF1Score=0.8022
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3086 | Mean MulticlassF1Score = 0.8045
# Validation : Mean CrossEntropyLoss = 2.3090 | Mean MulticlassF1Score = 0.8036
# ================================================================================
#
# EPOCH-4
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3027 | MulticlassF1Score=0.8093
# Batch-30 : CrossEntropyLoss=2.3103 | MulticlassF1Score=0.8100
# Batch-45 : CrossEntropyLoss=2.3022 | MulticlassF1Score=0.8076
# Batch-60 : CrossEntropyLoss=2.2972 | MulticlassF1Score=0.8079
# Batch-75 : CrossEntropyLoss=2.3026 | MulticlassF1Score=0.8090
# Batch-90 : CrossEntropyLoss=2.3138 | MulticlassF1Score=0.8093
# Batch-105: CrossEntropyLoss=2.3062 | MulticlassF1Score=0.8090
# Batch-120: CrossEntropyLoss=2.3098 | MulticlassF1Score=0.8090
# Batch-135: CrossEntropyLoss=2.3023 | MulticlassF1Score=0.8081
# Batch-150: CrossEntropyLoss=2.3191 | MulticlassF1Score=0.8079
# Batch-165: CrossEntropyLoss=2.3044 | MulticlassF1Score=0.8096
# Batch-180: CrossEntropyLoss=2.2914 | MulticlassF1Score=0.8106
# Batch-195: CrossEntropyLoss=2.2958 | MulticlassF1Score=0.8120
# Batch-210: CrossEntropyLoss=2.3011 | MulticlassF1Score=0.8132
# Batch-225: CrossEntropyLoss=2.3047 | MulticlassF1Score=0.8144
# Batch-226: CrossEntropyLoss=2.2977 | MulticlassF1Score=0.8144
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3049 | MulticlassF1Score=0.8217
# Batch-30 : CrossEntropyLoss=2.2933 | MulticlassF1Score=0.8247
# Batch-45 : CrossEntropyLoss=2.3018 | MulticlassF1Score=0.8245
# Batch-60 : CrossEntropyLoss=2.2996 | MulticlassF1Score=0.8240
# Batch-63 : CrossEntropyLoss=2.3023 | MulticlassF1Score=0.8235
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3054 | Mean MulticlassF1Score = 0.8095
# Validation : Mean CrossEntropyLoss = 2.3025 | Mean MulticlassF1Score = 0.8228
# ================================================================================
#
# EPOCH-5
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3109 | MulticlassF1Score=0.8294
# Batch-30 : CrossEntropyLoss=2.2940 | MulticlassF1Score=0.8301
# Batch-45 : CrossEntropyLoss=2.3016 | MulticlassF1Score=0.8303
# Batch-60 : CrossEntropyLoss=2.2987 | MulticlassF1Score=0.8285
# Batch-75 : CrossEntropyLoss=2.3011 | MulticlassF1Score=0.8304
# Batch-90 : CrossEntropyLoss=2.3015 | MulticlassF1Score=0.8293
# Batch-105: CrossEntropyLoss=2.2946 | MulticlassF1Score=0.8297
# Batch-120: CrossEntropyLoss=2.3062 | MulticlassF1Score=0.8302
# Batch-135: CrossEntropyLoss=2.3006 | MulticlassF1Score=0.8301
# Batch-150: CrossEntropyLoss=2.3133 | MulticlassF1Score=0.8299
# Batch-165: CrossEntropyLoss=2.3023 | MulticlassF1Score=0.8307
# Batch-180: CrossEntropyLoss=2.3039 | MulticlassF1Score=0.8305
# Batch-195: CrossEntropyLoss=2.2969 | MulticlassF1Score=0.8305
# Batch-210: CrossEntropyLoss=2.3003 | MulticlassF1Score=0.8307
# Batch-225: CrossEntropyLoss=2.2961 | MulticlassF1Score=0.8307
# Batch-226: CrossEntropyLoss=2.2937 | MulticlassF1Score=0.8307
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2971 | MulticlassF1Score=0.8301
# Batch-30 : CrossEntropyLoss=2.3005 | MulticlassF1Score=0.8291
# Batch-45 : CrossEntropyLoss=2.3084 | MulticlassF1Score=0.8284
# Batch-60 : CrossEntropyLoss=2.3083 | MulticlassF1Score=0.8252
# Batch-63 : CrossEntropyLoss=2.3068 | MulticlassF1Score=0.8249
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3002 | Mean MulticlassF1Score = 0.8300
# Validation : Mean CrossEntropyLoss = 2.3018 | Mean MulticlassF1Score = 0.8271
# ================================================================================
#
# EPOCH-6
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2919 | MulticlassF1Score=0.8389
# Batch-30 : CrossEntropyLoss=2.2998 | MulticlassF1Score=0.8329
# Batch-45 : CrossEntropyLoss=2.2980 | MulticlassF1Score=0.8334
# Batch-60 : CrossEntropyLoss=2.2946 | MulticlassF1Score=0.8343
# Batch-75 : CrossEntropyLoss=2.2929 | MulticlassF1Score=0.8326
# Batch-90 : CrossEntropyLoss=2.2974 | MulticlassF1Score=0.8328
# Batch-105: CrossEntropyLoss=2.2968 | MulticlassF1Score=0.8326
# Batch-120: CrossEntropyLoss=2.3082 | MulticlassF1Score=0.8332
# Batch-135: CrossEntropyLoss=2.2973 | MulticlassF1Score=0.8330
# Batch-150: CrossEntropyLoss=2.2907 | MulticlassF1Score=0.8330
# Batch-165: CrossEntropyLoss=2.3031 | MulticlassF1Score=0.8328
# Batch-180: CrossEntropyLoss=2.3040 | MulticlassF1Score=0.8326
# Batch-195: CrossEntropyLoss=2.2969 | MulticlassF1Score=0.8329
# Batch-210: CrossEntropyLoss=2.2999 | MulticlassF1Score=0.8325
# Batch-225: CrossEntropyLoss=2.2967 | MulticlassF1Score=0.8326
# Batch-226: CrossEntropyLoss=2.3044 | MulticlassF1Score=0.8326
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2963 | MulticlassF1Score=0.8314
# Batch-30 : CrossEntropyLoss=2.3008 | MulticlassF1Score=0.8288
# Batch-45 : CrossEntropyLoss=2.2978 | MulticlassF1Score=0.8272
# Batch-60 : CrossEntropyLoss=2.2969 | MulticlassF1Score=0.8270
# Batch-63 : CrossEntropyLoss=2.3082 | MulticlassF1Score=0.8264
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2996 | Mean MulticlassF1Score = 0.8335
# Validation : Mean CrossEntropyLoss = 2.3013 | Mean MulticlassF1Score = 0.8293
# ================================================================================
#
# EPOCH-7
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2960 | MulticlassF1Score=0.8397
# Batch-30 : CrossEntropyLoss=2.2946 | MulticlassF1Score=0.8376
# Batch-45 : CrossEntropyLoss=2.2959 | MulticlassF1Score=0.8346
# Batch-60 : CrossEntropyLoss=2.2916 | MulticlassF1Score=0.8340
# Batch-75 : CrossEntropyLoss=2.2978 | MulticlassF1Score=0.8342
# Batch-90 : CrossEntropyLoss=2.2916 | MulticlassF1Score=0.8340
# Batch-105: CrossEntropyLoss=2.2942 | MulticlassF1Score=0.8340
# Batch-120: CrossEntropyLoss=2.3018 | MulticlassF1Score=0.8346
# Batch-135: CrossEntropyLoss=2.2906 | MulticlassF1Score=0.8345
# Batch-150: CrossEntropyLoss=2.2956 | MulticlassF1Score=0.8345
# Batch-165: CrossEntropyLoss=2.3049 | MulticlassF1Score=0.8342
# Batch-180: CrossEntropyLoss=2.3125 | MulticlassF1Score=0.8338
# Batch-195: CrossEntropyLoss=2.2906 | MulticlassF1Score=0.8342
# Batch-210: CrossEntropyLoss=2.2961 | MulticlassF1Score=0.8348
# Batch-225: CrossEntropyLoss=2.3007 | MulticlassF1Score=0.8355
# Batch-226: CrossEntropyLoss=2.2891 | MulticlassF1Score=0.8356
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3058 | MulticlassF1Score=0.8395
# Batch-30 : CrossEntropyLoss=2.2974 | MulticlassF1Score=0.8408
# Batch-45 : CrossEntropyLoss=2.2979 | MulticlassF1Score=0.8403
# Batch-60 : CrossEntropyLoss=2.3055 | MulticlassF1Score=0.8413
# Batch-63 : CrossEntropyLoss=2.2963 | MulticlassF1Score=0.8410
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2986 | Mean MulticlassF1Score = 0.8348
# Validation : Mean CrossEntropyLoss = 2.2972 | Mean MulticlassF1Score = 0.8385
# ================================================================================
#
# EPOCH-8
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2964 | MulticlassF1Score=0.8449
# Batch-30 : CrossEntropyLoss=2.2933 | MulticlassF1Score=0.8459
# Batch-45 : CrossEntropyLoss=2.2903 | MulticlassF1Score=0.8466
# Batch-60 : CrossEntropyLoss=2.2973 | MulticlassF1Score=0.8488
# Batch-75 : CrossEntropyLoss=2.2860 | MulticlassF1Score=0.8482
# Batch-90 : CrossEntropyLoss=2.2940 | MulticlassF1Score=0.8486
# Batch-105: CrossEntropyLoss=2.2917 | MulticlassF1Score=0.8495
# Batch-120: CrossEntropyLoss=2.3009 | MulticlassF1Score=0.8492
# Batch-135: CrossEntropyLoss=2.2909 | MulticlassF1Score=0.8497
# Batch-150: CrossEntropyLoss=2.2954 | MulticlassF1Score=0.8500
# Batch-165: CrossEntropyLoss=2.2948 | MulticlassF1Score=0.8504
# Batch-180: CrossEntropyLoss=2.2852 | MulticlassF1Score=0.8506
# Batch-195: CrossEntropyLoss=2.2906 | MulticlassF1Score=0.8511
# Batch-210: CrossEntropyLoss=2.2953 | MulticlassF1Score=0.8512
# Batch-225: CrossEntropyLoss=2.3030 | MulticlassF1Score=0.8513
# Batch-226: CrossEntropyLoss=2.3023 | MulticlassF1Score=0.8512
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2971 | MulticlassF1Score=0.8507
# Batch-30 : CrossEntropyLoss=2.3021 | MulticlassF1Score=0.8493
# Batch-45 : CrossEntropyLoss=2.2899 | MulticlassF1Score=0.8509
# Batch-60 : CrossEntropyLoss=2.2835 | MulticlassF1Score=0.8520
# Batch-63 : CrossEntropyLoss=2.2880 | MulticlassF1Score=0.8516
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2939 | Mean MulticlassF1Score = 0.8487
# Validation : Mean CrossEntropyLoss = 2.2936 | Mean MulticlassF1Score = 0.8496
# ================================================================================
#
# EPOCH-9
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2906 | MulticlassF1Score=0.8585
# Batch-30 : CrossEntropyLoss=2.2907 | MulticlassF1Score=0.8582
# Batch-45 : CrossEntropyLoss=2.2973 | MulticlassF1Score=0.8585
# Batch-60 : CrossEntropyLoss=2.2951 | MulticlassF1Score=0.8584
# Batch-75 : CrossEntropyLoss=2.2871 | MulticlassF1Score=0.8588
# Batch-90 : CrossEntropyLoss=2.2955 | MulticlassF1Score=0.8602
# Batch-105: CrossEntropyLoss=2.2894 | MulticlassF1Score=0.8598
# Batch-120: CrossEntropyLoss=2.2947 | MulticlassF1Score=0.8592
# Batch-135: CrossEntropyLoss=2.2793 | MulticlassF1Score=0.8603
# Batch-150: CrossEntropyLoss=2.2828 | MulticlassF1Score=0.8603
# Batch-165: CrossEntropyLoss=2.2831 | MulticlassF1Score=0.8608
# Batch-180: CrossEntropyLoss=2.2989 | MulticlassF1Score=0.8604
# Batch-195: CrossEntropyLoss=2.2873 | MulticlassF1Score=0.8606
# Batch-210: CrossEntropyLoss=2.2801 | MulticlassF1Score=0.8608
# Batch-225: CrossEntropyLoss=2.2952 | MulticlassF1Score=0.8608
# Batch-226: CrossEntropyLoss=2.2898 | MulticlassF1Score=0.8608
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2922 | MulticlassF1Score=0.8522
# Batch-30 : CrossEntropyLoss=2.2888 | MulticlassF1Score=0.8556
# Batch-45 : CrossEntropyLoss=2.3028 | MulticlassF1Score=0.8546
# Batch-60 : CrossEntropyLoss=2.2922 | MulticlassF1Score=0.8538
# Batch-63 : CrossEntropyLoss=2.2955 | MulticlassF1Score=0.8540
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2909 | Mean MulticlassF1Score = 0.8598
# Validation : Mean CrossEntropyLoss = 2.2929 | Mean MulticlassF1Score = 0.8538
# ================================================================================
#
# EPOCH-10
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2823 | MulticlassF1Score=0.8612
# Batch-30 : CrossEntropyLoss=2.2867 | MulticlassF1Score=0.8650
# Batch-45 : CrossEntropyLoss=2.2954 | MulticlassF1Score=0.8658
# Batch-60 : CrossEntropyLoss=2.2917 | MulticlassF1Score=0.8655
# Batch-75 : CrossEntropyLoss=2.2949 | MulticlassF1Score=0.8643
# Batch-90 : CrossEntropyLoss=2.2858 | MulticlassF1Score=0.8639
# Batch-105: CrossEntropyLoss=2.2919 | MulticlassF1Score=0.8636
# Batch-120: CrossEntropyLoss=2.2889 | MulticlassF1Score=0.8644
# Batch-135: CrossEntropyLoss=2.2801 | MulticlassF1Score=0.8642
# Batch-150: CrossEntropyLoss=2.2950 | MulticlassF1Score=0.8639
# Batch-165: CrossEntropyLoss=2.2879 | MulticlassF1Score=0.8640
# Batch-180: CrossEntropyLoss=2.2867 | MulticlassF1Score=0.8638
# Batch-195: CrossEntropyLoss=2.2899 | MulticlassF1Score=0.8634
# Batch-210: CrossEntropyLoss=2.2870 | MulticlassF1Score=0.8640
# Batch-225: CrossEntropyLoss=2.2934 | MulticlassF1Score=0.8639
# Batch-226: CrossEntropyLoss=2.2947 | MulticlassF1Score=0.8638
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2876 | MulticlassF1Score=0.8529
# Batch-30 : CrossEntropyLoss=2.2884 | MulticlassF1Score=0.8553
# Batch-45 : CrossEntropyLoss=2.2928 | MulticlassF1Score=0.8556
# Batch-60 : CrossEntropyLoss=2.2854 | MulticlassF1Score=0.8555
# Batch-63 : CrossEntropyLoss=2.2855 | MulticlassF1Score=0.8553
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2899 | Mean MulticlassF1Score = 0.8639
# Validation : Mean CrossEntropyLoss = 2.2923 | Mean MulticlassF1Score = 0.8547
# ================================================================================
#
# EPOCH-11
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2766 | MulticlassF1Score=0.8693
# Batch-30 : CrossEntropyLoss=2.2900 | MulticlassF1Score=0.8642
# Batch-45 : CrossEntropyLoss=2.2917 | MulticlassF1Score=0.8661
# Batch-60 : CrossEntropyLoss=2.2941 | MulticlassF1Score=0.8667
# Batch-75 : CrossEntropyLoss=2.2789 | MulticlassF1Score=0.8669
# Batch-90 : CrossEntropyLoss=2.2998 | MulticlassF1Score=0.8667
# Batch-105: CrossEntropyLoss=2.2929 | MulticlassF1Score=0.8664
# Batch-120: CrossEntropyLoss=2.2880 | MulticlassF1Score=0.8655
# Batch-135: CrossEntropyLoss=2.2889 | MulticlassF1Score=0.8649
# Batch-150: CrossEntropyLoss=2.2882 | MulticlassF1Score=0.8648
# Batch-165: CrossEntropyLoss=2.2869 | MulticlassF1Score=0.8654
# Batch-180: CrossEntropyLoss=2.2861 | MulticlassF1Score=0.8657
# Batch-195: CrossEntropyLoss=2.2878 | MulticlassF1Score=0.8655
# Batch-210: CrossEntropyLoss=2.2869 | MulticlassF1Score=0.8657
# Batch-225: CrossEntropyLoss=2.2823 | MulticlassF1Score=0.8660
# Batch-226: CrossEntropyLoss=2.2959 | MulticlassF1Score=0.8660
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2896 | MulticlassF1Score=0.8601
# Batch-30 : CrossEntropyLoss=2.2932 | MulticlassF1Score=0.8585
# Batch-45 : CrossEntropyLoss=2.2962 | MulticlassF1Score=0.8583
# Batch-60 : CrossEntropyLoss=2.2931 | MulticlassF1Score=0.8567
# Batch-63 : CrossEntropyLoss=2.2898 | MulticlassF1Score=0.8569
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2892 | Mean MulticlassF1Score = 0.8662
# Validation : Mean CrossEntropyLoss = 2.2917 | Mean MulticlassF1Score = 0.8580
# ================================================================================
#
# EPOCH-12
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2949 | MulticlassF1Score=0.8583
# Batch-30 : CrossEntropyLoss=2.2826 | MulticlassF1Score=0.8703
# Batch-45 : CrossEntropyLoss=2.2796 | MulticlassF1Score=0.8780
# Batch-60 : CrossEntropyLoss=2.2838 | MulticlassF1Score=0.8816
# Batch-75 : CrossEntropyLoss=2.2786 | MulticlassF1Score=0.8838
# Batch-90 : CrossEntropyLoss=2.2798 | MulticlassF1Score=0.8851
# Batch-105: CrossEntropyLoss=2.2795 | MulticlassF1Score=0.8861
# Batch-120: CrossEntropyLoss=2.2792 | MulticlassF1Score=0.8869
# Batch-135: CrossEntropyLoss=2.2753 | MulticlassF1Score=0.8883
# Batch-150: CrossEntropyLoss=2.2803 | MulticlassF1Score=0.8895
# Batch-165: CrossEntropyLoss=2.2814 | MulticlassF1Score=0.8898
# Batch-180: CrossEntropyLoss=2.2825 | MulticlassF1Score=0.8903
# Batch-195: CrossEntropyLoss=2.2773 | MulticlassF1Score=0.8907
# Batch-210: CrossEntropyLoss=2.2785 | MulticlassF1Score=0.8913
# Batch-225: CrossEntropyLoss=2.2791 | MulticlassF1Score=0.8920
# Batch-226: CrossEntropyLoss=2.2827 | MulticlassF1Score=0.8920
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2762 | MulticlassF1Score=0.8850
# Batch-30 : CrossEntropyLoss=2.2799 | MulticlassF1Score=0.8862
# Batch-45 : CrossEntropyLoss=2.2780 | MulticlassF1Score=0.8880
# Batch-60 : CrossEntropyLoss=2.2776 | MulticlassF1Score=0.8890
# Batch-63 : CrossEntropyLoss=2.2917 | MulticlassF1Score=0.8886
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2815 | Mean MulticlassF1Score = 0.8834
# Validation : Mean CrossEntropyLoss = 2.2824 | Mean MulticlassF1Score = 0.8866
# ================================================================================
#
# EPOCH-13
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.8978
# Batch-30 : CrossEntropyLoss=2.2790 | MulticlassF1Score=0.9015
# Batch-45 : CrossEntropyLoss=2.2856 | MulticlassF1Score=0.9003
# Batch-60 : CrossEntropyLoss=2.2824 | MulticlassF1Score=0.9010
# Batch-75 : CrossEntropyLoss=2.2857 | MulticlassF1Score=0.8999
# Batch-90 : CrossEntropyLoss=2.2771 | MulticlassF1Score=0.8997
# Batch-105: CrossEntropyLoss=2.2817 | MulticlassF1Score=0.9002
# Batch-120: CrossEntropyLoss=2.2754 | MulticlassF1Score=0.9010
# Batch-135: CrossEntropyLoss=2.2795 | MulticlassF1Score=0.9006
# Batch-150: CrossEntropyLoss=2.2768 | MulticlassF1Score=0.9011
# Batch-165: CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9007
# Batch-180: CrossEntropyLoss=2.2834 | MulticlassF1Score=0.9006
# Batch-195: CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9008
# Batch-210: CrossEntropyLoss=2.2805 | MulticlassF1Score=0.9008
# Batch-225: CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9009
# Batch-226: CrossEntropyLoss=2.2868 | MulticlassF1Score=0.9008
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2722 | MulticlassF1Score=0.8984
# Batch-30 : CrossEntropyLoss=2.2842 | MulticlassF1Score=0.8945
# Batch-45 : CrossEntropyLoss=2.2880 | MulticlassF1Score=0.8913
# Batch-60 : CrossEntropyLoss=2.2839 | MulticlassF1Score=0.8916
# Batch-63 : CrossEntropyLoss=2.2826 | MulticlassF1Score=0.8914
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2786 | Mean MulticlassF1Score = 0.9002
# Validation : Mean CrossEntropyLoss = 2.2813 | Mean MulticlassF1Score = 0.8953
# ================================================================================
#
# EPOCH-14
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2782 | MulticlassF1Score=0.9065
# Batch-30 : CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9037
# Batch-45 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9042
# Batch-60 : CrossEntropyLoss=2.2769 | MulticlassF1Score=0.9034
# Batch-75 : CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9029
# Batch-90 : CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9039
# Batch-105: CrossEntropyLoss=2.2859 | MulticlassF1Score=0.9043
# Batch-120: CrossEntropyLoss=2.2805 | MulticlassF1Score=0.9042
# Batch-135: CrossEntropyLoss=2.2862 | MulticlassF1Score=0.9047
# Batch-150: CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9043
# Batch-165: CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9059
# Batch-180: CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9078
# Batch-195: CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9085
# Batch-210: CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9101
# Batch-225: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9113
# Batch-226: CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9113
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9155
# Batch-30 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9189
# Batch-45 : CrossEntropyLoss=2.2754 | MulticlassF1Score=0.9184
# Batch-60 : CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9183
# Batch-63 : CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9181
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2753 | Mean MulticlassF1Score = 0.9055
# Validation : Mean CrossEntropyLoss = 2.2732 | Mean MulticlassF1Score = 0.9178
# ================================================================================
#
# EPOCH-15
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9310
# Batch-30 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9326
# Batch-45 : CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9320
# Batch-60 : CrossEntropyLoss=2.2769 | MulticlassF1Score=0.9330
# Batch-75 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9324
# Batch-90 : CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9331
# Batch-105: CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9336
# Batch-120: CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9339
# Batch-135: CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9338
# Batch-150: CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9336
# Batch-165: CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9337
# Batch-180: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9335
# Batch-195: CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9334
# Batch-210: CrossEntropyLoss=2.2767 | MulticlassF1Score=0.9333
# Batch-225: CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9330
# Batch-226: CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9330
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9205
# Batch-30 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9208
# Batch-45 : CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9206
# Batch-60 : CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9210
# Batch-63 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9214
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2686 | Mean MulticlassF1Score = 0.9327
# Validation : Mean CrossEntropyLoss = 2.2722 | Mean MulticlassF1Score = 0.9213
# ================================================================================
#
# EPOCH-16
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9384
# Batch-30 : CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9379
# Batch-45 : CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9366
# Batch-60 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9356
# Batch-75 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9355
# Batch-90 : CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9361
# Batch-105: CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9362
# Batch-120: CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9356
# Batch-135: CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9358
# Batch-150: CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9356
# Batch-165: CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9355
# Batch-180: CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9355
# Batch-195: CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9352
# Batch-210: CrossEntropyLoss=2.2772 | MulticlassF1Score=0.9351
# Batch-225: CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9349
# Batch-226: CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9349
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9223
# Batch-30 : CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9215
# Batch-45 : CrossEntropyLoss=2.2767 | MulticlassF1Score=0.9211
# Batch-60 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9212
# Batch-63 : CrossEntropyLoss=2.2751 | MulticlassF1Score=0.9215
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2679 | Mean MulticlassF1Score = 0.9362
# Validation : Mean CrossEntropyLoss = 2.2719 | Mean MulticlassF1Score = 0.9220
# ================================================================================
#
# EPOCH-17
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9334
# Batch-30 : CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9352
# Batch-45 : CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9363
# Batch-60 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9362
# Batch-75 : CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9364
# Batch-90 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9373
# Batch-105: CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9373
# Batch-120: CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9375
# Batch-135: CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9376
# Batch-150: CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9370
# Batch-165: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9370
# Batch-180: CrossEntropyLoss=2.2589 | MulticlassF1Score=0.9372
# Batch-195: CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9370
# Batch-210: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9365
# Batch-225: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9365
# Batch-226: CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9365
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9233
# Batch-30 : CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9218
# Batch-45 : CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9228
# Batch-60 : CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9232
# Batch-63 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9224
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2674 | Mean MulticlassF1Score = 0.9364
# Validation : Mean CrossEntropyLoss = 2.2717 | Mean MulticlassF1Score = 0.9230
# ================================================================================
#
# EPOCH-18
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9354
# Batch-30 : CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9366
# Batch-45 : CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9368
# Batch-60 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9376
# Batch-75 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9376
# Batch-90 : CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9386
# Batch-105: CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9386
# Batch-120: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9384
# Batch-135: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9380
# Batch-150: CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9378
# Batch-165: CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9377
# Batch-180: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9375
# Batch-195: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9377
# Batch-210: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9376
# Batch-225: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9376
# Batch-226: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9376
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9245
# Batch-30 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9245
# Batch-45 : CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9233
# Batch-60 : CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9234
# Batch-63 : CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9235
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2670 | Mean MulticlassF1Score = 0.9378
# Validation : Mean CrossEntropyLoss = 2.2713 | Mean MulticlassF1Score = 0.9236
# ================================================================================
#
# EPOCH-19
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9366
# Batch-30 : CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9400
# Batch-45 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9391
# Batch-60 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9387
# Batch-75 : CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9382
# Batch-90 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9387
# Batch-105: CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9389
# Batch-120: CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9391
# Batch-135: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9387
# Batch-150: CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9391
# Batch-165: CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9388
# Batch-180: CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9389
# Batch-195: CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9389
# Batch-210: CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9391
# Batch-225: CrossEntropyLoss=2.2762 | MulticlassF1Score=0.9387
# Batch-226: CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9387
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9242
# Batch-30 : CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9234
# Batch-45 : CrossEntropyLoss=2.2767 | MulticlassF1Score=0.9225
# Batch-60 : CrossEntropyLoss=2.2767 | MulticlassF1Score=0.9219
# Batch-63 : CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9219
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2665 | Mean MulticlassF1Score = 0.9386
# Validation : Mean CrossEntropyLoss = 2.2717 | Mean MulticlassF1Score = 0.9233
# ================================================================================
#
# EPOCH-20
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9353
# Batch-30 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9363
# Batch-45 : CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9372
# Batch-60 : CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9377
# Batch-75 : CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9381
# Batch-90 : CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9393
# Batch-105: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9389
# Batch-120: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9390
# Batch-135: CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9390
# Batch-150: CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9391
# Batch-165: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9392
# Batch-180: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9392
# Batch-195: CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9392
# Batch-210: CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9392
# Batch-225: CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9393
# Batch-226: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9393
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9219
# Batch-30 : CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9233
# Batch-45 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9231
# Batch-60 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9241
# Batch-63 : CrossEntropyLoss=2.2771 | MulticlassF1Score=0.9240
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2664 | Mean MulticlassF1Score = 0.9383
# Validation : Mean CrossEntropyLoss = 2.2711 | Mean MulticlassF1Score = 0.9225
# ================================================================================
#
# EPOCH-21
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9388
# Batch-30 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9409
# Batch-45 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9407
# Batch-60 : CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9398
# Batch-75 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9399
# Batch-90 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9389
# Batch-105: CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9391
# Batch-120: CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9392
# Batch-135: CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9395
# Batch-150: CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9396
# Batch-165: CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9400
# Batch-180: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9400
# Batch-195: CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9402
# Batch-210: CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9405
# Batch-225: CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9403
# Batch-226: CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9403
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9248
# Batch-30 : CrossEntropyLoss=2.2754 | MulticlassF1Score=0.9232
# Batch-45 : CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9234
# Batch-60 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9237
# Batch-63 : CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9236
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2660 | Mean MulticlassF1Score = 0.9396
# Validation : Mean CrossEntropyLoss = 2.2711 | Mean MulticlassF1Score = 0.9234
# ================================================================================
#
# EPOCH-22
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9422
# Batch-30 : CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9435
# Batch-45 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9427
# Batch-60 : CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9431
# Batch-75 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9424
# Batch-90 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9421
# Batch-105: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9419
# Batch-120: CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9419
# Batch-135: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9412
# Batch-150: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9413
# Batch-165: CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9410
# Batch-180: CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9412
# Batch-195: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9412
# Batch-210: CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9411
# Batch-225: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9409
# Batch-226: CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9409
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9234
# Batch-30 : CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9239
# Batch-45 : CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9245
# Batch-60 : CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9240
# Batch-63 : CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9237
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2658 | Mean MulticlassF1Score = 0.9416
# Validation : Mean CrossEntropyLoss = 2.2711 | Mean MulticlassF1Score = 0.9227
# ================================================================================
#
# EPOCH-23
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9416
# Batch-30 : CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9407
# Batch-45 : CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9401
# Batch-60 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9407
# Batch-75 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9410
# Batch-90 : CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9416
# Batch-105: CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9418
# Batch-120: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9415
# Batch-135: CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9409
# Batch-150: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9408
# Batch-165: CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9407
# Batch-180: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9407
# Batch-195: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9408
# Batch-210: CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9410
# Batch-225: CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9411
# Batch-226: CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9412
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9267
# Batch-30 : CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9257
# Batch-45 : CrossEntropyLoss=2.2780 | MulticlassF1Score=0.9245
# Batch-60 : CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9237
# Batch-63 : CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9238
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2657 | Mean MulticlassF1Score = 0.9409
# Validation : Mean CrossEntropyLoss = 2.2711 | Mean MulticlassF1Score = 0.9251
# ================================================================================
#
# EPOCH-24
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9383
# Batch-30 : CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9415
# Batch-45 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9410
# Batch-60 : CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9414
# Batch-75 : CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9412
# Batch-90 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9413
# Batch-105: CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9410
# Batch-120: CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9409
# Batch-135: CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9408
# Batch-150: CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9408
# Batch-165: CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9407
# Batch-180: CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9412
# Batch-195: CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9410
# Batch-210: CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9414
# Batch-225: CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9415
# Batch-226: CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9414
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9268
# Batch-30 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9228
# Batch-45 : CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9228
# Batch-60 : CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9233
# Batch-63 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9236
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2656 | Mean MulticlassF1Score = 0.9410
# Validation : Mean CrossEntropyLoss = 2.2712 | Mean MulticlassF1Score = 0.9249
# ================================================================================
#
# EPOCH-25
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9424
# Batch-30 : CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9440
# Batch-45 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9434
# Batch-60 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9428
# Batch-75 : CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9432
# Batch-90 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9431
# Batch-105: CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9426
# Batch-120: CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9423
# Batch-135: CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9423
# Batch-150: CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9419
# Batch-165: CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9418
# Batch-180: CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9419
# Batch-195: CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9419
# Batch-210: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9418
# Batch-225: CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9416
# Batch-226: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9416
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9253
# Batch-30 : CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9259
# Batch-45 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9244
# Batch-60 : CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9240
# Batch-63 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9243
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2656 | Mean MulticlassF1Score = 0.9424
# Validation : Mean CrossEntropyLoss = 2.2709 | Mean MulticlassF1Score = 0.9246
# ================================================================================
#
# EPOCH-26
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9448
# Batch-30 : CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9433
# Batch-45 : CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9429
# Batch-60 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9425
# Batch-75 : CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9424
# Batch-90 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9423
# Batch-105: CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9427
# Batch-120: CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9430
# Batch-135: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9425
# Batch-150: CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9424
# Batch-165: CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9424
# Batch-180: CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9426
# Batch-195: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9426
# Batch-210: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9425
# Batch-225: CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9425
# Batch-226: CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9425
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9259
# Batch-30 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9256
# Batch-45 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9264
# Batch-60 : CrossEntropyLoss=2.2765 | MulticlassF1Score=0.9253
# Batch-63 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9250
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2653 | Mean MulticlassF1Score = 0.9426
# Validation : Mean CrossEntropyLoss = 2.2707 | Mean MulticlassF1Score = 0.9242
# ================================================================================
#
# EPOCH-27
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9386
# Batch-30 : CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9420
# Batch-45 : CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9433
# Batch-60 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9437
# Batch-75 : CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9437
# Batch-90 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9436
# Batch-105: CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9434
# Batch-120: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9435
# Batch-135: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9433
# Batch-150: CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9432
# Batch-165: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9431
# Batch-180: CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9430
# Batch-195: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9426
# Batch-210: CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9427
# Batch-225: CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9428
# Batch-226: CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9427
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9244
# Batch-30 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9232
# Batch-45 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9236
# Batch-60 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9248
# Batch-63 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9248
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2652 | Mean MulticlassF1Score = 0.9427
# Validation : Mean CrossEntropyLoss = 2.2708 | Mean MulticlassF1Score = 0.9234
# ================================================================================
#
# EPOCH-28
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9439
# Batch-30 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9460
# Batch-45 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9445
# Batch-60 : CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9439
# Batch-75 : CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9435
# Batch-90 : CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9434
# Batch-105: CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9430
# Batch-120: CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9428
# Batch-135: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9428
# Batch-150: CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9429
# Batch-165: CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9429
# Batch-180: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9428
# Batch-195: CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9431
# Batch-210: CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9432
# Batch-225: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9431
# Batch-226: CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9431
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9229
# Batch-30 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9238
# Batch-45 : CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9244
# Batch-60 : CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9246
# Batch-63 : CrossEntropyLoss=2.2753 | MulticlassF1Score=0.9243
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2651 | Mean MulticlassF1Score = 0.9435
# Validation : Mean CrossEntropyLoss = 2.2710 | Mean MulticlassF1Score = 0.9230
# ================================================================================
#
# EPOCH-29
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2622 | MulticlassF1Score=0.9459
# Batch-30 : CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9437
# Batch-45 : CrossEntropyLoss=2.2612 | MulticlassF1Score=0.9430
# Batch-60 : CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9436
# Batch-75 : CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9441
# Batch-90 : CrossEntropyLoss=2.2612 | MulticlassF1Score=0.9434
# Batch-105: CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9440
# Batch-120: CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9435
# Batch-135: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9432
# Batch-150: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9437
# Batch-165: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9435
# Batch-180: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9432
# ...
# Batch-45 : CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9473
# Batch-60 : CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9463
# Batch-63 : CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9464
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2573 | Mean MulticlassF1Score = 0.9681
# Validation : Mean CrossEntropyLoss = 2.2641 | Mean MulticlassF1Score = 0.9480
# ================================================================================
#
# EPOCH-42
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9695
# Batch-30 : CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9683
# Batch-45 : CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9684
# Batch-60 : CrossEntropyLoss=2.2597 | MulticlassF1Score=0.9681
# Batch-75 : CrossEntropyLoss=2.2597 | MulticlassF1Score=0.9681
# Batch-90 : CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9680
# Batch-105: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9681
# Batch-120: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9686
# Batch-135: CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9685
# Batch-150: CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9686
# Batch-165: CrossEntropyLoss=2.2535 | MulticlassF1Score=0.9686
# Batch-180: CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9687
# Batch-195: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9687
# Batch-210: CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9686
# Batch-225: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9685
# Batch-226: CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9685
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9428
# Batch-30 : CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9428
# Batch-45 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9427
# Batch-60 : CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9453
# Batch-63 : CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9451
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2571 | Mean MulticlassF1Score = 0.9687
# Validation : Mean CrossEntropyLoss = 2.2644 | Mean MulticlassF1Score = 0.9435
# ================================================================================
#
# EPOCH-43
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9703
# Batch-30 : CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9687
# Batch-45 : CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9699
# Batch-60 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9694
# Batch-75 : CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9692
# Batch-90 : CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9692
# Batch-105: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9688
# Batch-120: CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9687
# Batch-135: CrossEntropyLoss=2.2589 | MulticlassF1Score=0.9687
# Batch-150: CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9690
# Batch-165: CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9690
# Batch-180: CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9690
# Batch-195: CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9690
# Batch-210: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9688
# Batch-225: CrossEntropyLoss=2.2544 | MulticlassF1Score=0.9688
# Batch-226: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9687
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9481
# Batch-30 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9462
# Batch-45 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9448
# Batch-60 : CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9461
# Batch-63 : CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9463
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2570 | Mean MulticlassF1Score = 0.9692
# Validation : Mean CrossEntropyLoss = 2.2641 | Mean MulticlassF1Score = 0.9459
# ================================================================================
#
# EPOCH-44
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9692
# Batch-30 : CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9696
# Batch-45 : CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9699
# Batch-60 : CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9696
# Batch-75 : CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9695
# Batch-90 : CrossEntropyLoss=2.2531 | MulticlassF1Score=0.9696
# Batch-105: CrossEntropyLoss=2.2589 | MulticlassF1Score=0.9693
# Batch-120: CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9692
# Batch-135: CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9691
# Batch-150: CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9691
# Batch-165: CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9692
# Batch-180: CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9691
# Batch-195: CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9690
# Batch-210: CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9689
# Batch-225: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9687
# Batch-226: CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9687
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9483
# Batch-30 : CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9476
# Batch-45 : CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9455
# Batch-60 : CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9453
# Batch-63 : CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9453
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2571 | Mean MulticlassF1Score = 0.9693
# Validation : Mean CrossEntropyLoss = 2.2644 | Mean MulticlassF1Score = 0.9458
# Patience = 1/50❗
# ================================================================================
#
# EPOCH-45
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2547 | MulticlassF1Score=0.9690
# Batch-30 : CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9691
# Batch-45 : CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9681
# Batch-60 : CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9679
# Batch-75 : CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9684
# Batch-90 : CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9683
# Batch-105: CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9682
# Batch-120: CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9684
# Batch-135: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9685
# Batch-150: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9688
# Batch-165: CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9688
# Batch-180: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9692
# Batch-195: CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9694
# Batch-210: CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9697
# Batch-225: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9696
# Batch-226: CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9696
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9442
# Batch-30 : CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9473
# Batch-45 : CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9480
# Batch-60 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9476
# Batch-63 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9476
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2568 | Mean MulticlassF1Score = 0.9688
# Validation : Mean CrossEntropyLoss = 2.2637 | Mean MulticlassF1Score = 0.9473
# ================================================================================
#
# EPOCH-46
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2547 | MulticlassF1Score=0.9746
# Batch-30 : CrossEntropyLoss=2.2543 | MulticlassF1Score=0.9728
# Batch-45 : CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9726
# Batch-60 : CrossEntropyLoss=2.2523 | MulticlassF1Score=0.9730
# Batch-75 : CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9724
# Batch-90 : CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9722
# Batch-105: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9721
# Batch-120: CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9723
# Batch-135: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9718
# Batch-150: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9716
# Batch-165: CrossEntropyLoss=2.2547 | MulticlassF1Score=0.9719
# Batch-180: CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9718
# Batch-195: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9717
# Batch-210: CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9715
# Batch-225: CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9716
# Batch-226: CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9716
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9524
# Batch-30 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9483
# Batch-45 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9488
# Batch-60 : CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9486
# Batch-63 : CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9490
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2562 | Mean MulticlassF1Score = 0.9724
# Validation : Mean CrossEntropyLoss = 2.2633 | Mean MulticlassF1Score = 0.9497
# ================================================================================
#
# EPOCH-47
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9751
# Batch-30 : CrossEntropyLoss=2.2520 | MulticlassF1Score=0.9738
# Batch-45 : CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9729
# Batch-60 : CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9724
# Batch-75 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9725
# Batch-90 : CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9722
# Batch-105: CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9722
# Batch-120: CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9723
# Batch-135: CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9719
# Batch-150: CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9717
# Batch-165: CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9718
# Batch-180: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9718
# Batch-195: CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9717
# Batch-210: CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9717
# Batch-225: CrossEntropyLoss=2.2597 | MulticlassF1Score=0.9716
# Batch-226: CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9716
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9494
# Batch-30 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9468
# Batch-45 : CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9485
# Batch-60 : CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9492
# Batch-63 : CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9495
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2562 | Mean MulticlassF1Score = 0.9723
# Validation : Mean CrossEntropyLoss = 2.2632 | Mean MulticlassF1Score = 0.9478
# ================================================================================
#
# EPOCH-48
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9699
# Batch-30 : CrossEntropyLoss=2.2540 | MulticlassF1Score=0.9704
# Batch-45 : CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9706
# Batch-60 : CrossEntropyLoss=2.2532 | MulticlassF1Score=0.9715
# Batch-75 : CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9715
# Batch-90 : CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9714
# Batch-105: CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9716
# Batch-120: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9716
# Batch-135: CrossEntropyLoss=2.2524 | MulticlassF1Score=0.9717
# Batch-150: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9716
# Batch-165: CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9716
# Batch-180: CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9715
# Batch-195: CrossEntropyLoss=2.2539 | MulticlassF1Score=0.9716
# Batch-210: CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9716
# Batch-225: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9717
# Batch-226: CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9717
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9534
# Batch-30 : CrossEntropyLoss=2.2612 | MulticlassF1Score=0.9511
# Batch-45 : CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9492
# Batch-60 : CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9482
# Batch-63 : CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9480
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2562 | Mean MulticlassF1Score = 0.9713
# Validation : Mean CrossEntropyLoss = 2.2635 | Mean MulticlassF1Score = 0.9509
# ================================================================================
#
# EPOCH-49
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9728
# Batch-30 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9733
# Batch-45 : CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9725
# Batch-60 : CrossEntropyLoss=2.2535 | MulticlassF1Score=0.9725
# Batch-75 : CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9719
# Batch-90 : CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9722
# Batch-105: CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9717
# Batch-120: CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9720
# Batch-135: CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9719
# Batch-150: CrossEntropyLoss=2.2541 | MulticlassF1Score=0.9720
# Batch-165: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9722
# Batch-180: CrossEntropyLoss=2.2526 | MulticlassF1Score=0.9724
# Batch-195: CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9724
# Batch-210: CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9721
# Batch-225: CrossEntropyLoss=2.2536 | MulticlassF1Score=0.9721
# Batch-226: CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9721
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9440
# Batch-30 : CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9477
# Batch-45 : CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9476
# Batch-60 : CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9496
# Batch-63 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9493
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2560 | Mean MulticlassF1Score = 0.9722
# Validation : Mean CrossEntropyLoss = 2.2631 | Mean MulticlassF1Score = 0.9477
# ================================================================================
#
# EPOCH-50
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9719
# Batch-30 : CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9727
# Batch-45 : CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9722
# Batch-60 : CrossEntropyLoss=2.2542 | MulticlassF1Score=0.9723
# Batch-75 : CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9716
# Batch-90 : CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9720
# Batch-105: CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9722
# Batch-120: CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9724
# Batch-135: CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9723
# Batch-150: CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9725
# Batch-165: CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9725
# Batch-180: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9726
# Batch-195: CrossEntropyLoss=2.2538 | MulticlassF1Score=0.9727
# Batch-210: CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9726
# Batch-225: CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9726
# Batch-226: CrossEntropyLoss=2.2551 | MulticlassF1Score=0.9726
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9486
# Batch-30 : CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9480
# Batch-45 : CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9486
# Batch-60 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9495
# Batch-63 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9494
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2559 | Mean MulticlassF1Score = 0.9722
# Validation : Mean CrossEntropyLoss = 2.2631 | Mean MulticlassF1Score = 0.9487
# ================================================================================
#
# TRAINING SUMMARY
# Best CrossEntropyLoss training    : 2.2559
# Best CrossEntropyLoss training    : 2.2631
# Best MulticlassF1Score validation : 0.9722
# Best MulticlassF1Score validation : 0.9487
# Training duration                 : 2.6359 minutes.
# Training date                     : 2022-10-19 10:42:28.096647+08:00

# %% [markdown]
# ## End Training

# %% [markdown]
# # Evaluation

# %%
def evaluation(dataloader, model, criterion, metric):
    model.eval()
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)
            pred = rearrange(prob.argmax(dim=1).reshape(feature.shape[0], len(dataloader.dataset)), "s n -> n s")

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob.argmax(dim=1), actual_label.to(hyperparams.device))
            metric_score = metric.compute()

    return loss, metric_score, pred

train_dataloader = DataLoader(train_dataset, batch_size=len(train_dataset))
val_dataloader = DataLoader(val_dataset, batch_size=len(val_dataset))
test_dataloader = DataLoader(test_dataset, batch_size=len(test_dataset))

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
train_loss, train_f1_score, train_pred_label = evaluation(train_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_loss, val_f1_score, val_pred_label = evaluation(val_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
test_loss, test_f1_score, test_pred_label = evaluation(test_dataloader, model, criterion, metric)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9729, device='cuda:0'),
#  tensor(0.9494, device='cuda:0'),
#  tensor(0.9493, device='cuda:0'))

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9729, device='cuda:0'),
#  tensor(0.9494, device='cuda:0'),
#  tensor(0.9493, device='cuda:0'))

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns

def viz_evaluation(pred_label, actual_label, title):
    plt.figure(figsize=(15, 7), dpi=200)
    sns.heatmap(pred_label.detach().cpu() == actual_label, cbar=True, cmap="binary_r")
    plt.xlabel("Sentence Length")
    plt.ylabel("Sentence")
    plt.title(title)
    plt.savefig(f"{root_path}/heatmap_{title.lower()}.jpg", dpi=200)
    plt.show()

train_actual_label = train_dataloader.dataset.tensors[1]
val_actual_label = val_dataloader.dataset.tensors[1]
test_actual_label = test_dataloader.dataset.tensors[1]

viz_evaluation(train_pred_label, train_actual_label, f"Training (F1-Score: {(train_f1_score):.4f})")
viz_evaluation(val_pred_label, val_actual_label, f"Validation (F1-Score: {(val_f1_score):.4f})")
viz_evaluation(test_pred_label, test_actual_label, f"Test (F1-Score: {(test_f1_score):.4f})")

# %% [markdown]
# ## Confusion Matrix

# %%
def confusion_matrix(pred_class, actual_class, title, normalize=None):
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize=normalize)
    plt.figure(figsize=(20, 10), dpi=200)
    sns.heatmap(conf_mat(pred_class.detach().cpu(), actual_class), annot=True, fmt=".2g", xticklabels=list(label_to_idx.keys()), yticklabels=list(label_to_idx.keys()));
    plt.yticks(rotation=0)
    plt.title(title)
    plt.xlabel("Actual Class")
    plt.ylabel("Predict Class")
    plt.savefig(f"{root_path}/conf_matrix_{title.lower()}.jpg", dpi=200)

confusion_matrix(train_pred_label, train_actual_label, "Training", "pred")
confusion_matrix(val_pred_label,val_actual_label, "Validation", "pred")
confusion_matrix(test_pred_label, test_actual_label, "Test", "pred")
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 120 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 144 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)

# %% [markdown]
# ## Prediction Table

# %%
def number_wrong_pred_each_class(pred_class, actual_class):
    classes, count_class = actual_class.flatten().unique(return_counts=True)
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize="none")
    correct_pred_count_class = conf_mat(pred_class.detach().cpu(), actual_class).diag()
    
    correct_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (correct_pred_count_class))}
    wrong_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (count_class - correct_pred_count_class))}
    
    return correct_pred, wrong_pred

correct_pred, wrong_pred = number_wrong_pred_each_class(train_pred_label, train_actual_label)
print(f"| {'Number class'.ljust(14)} | {'Correct prediction'.ljust(12)} | {'Wrong prediction'.ljust(12)} |")
for (label_correct_pred, count_correct_pred), (label_wrong_pred, count_wrong_pred) in zip(correct_pred.items(), wrong_pred.items()):
    print(f"| {str(label_correct_pred).ljust(6)}: {str(count_correct_pred + count_wrong_pred).ljust(7)}| {label_correct_pred.ljust(6)}: {str(count_correct_pred).ljust(10)} | {label_wrong_pred.ljust(6)}: {str(count_wrong_pred).ljust(8)} |")
# Out:
# | Number class   | Correct prediction | Wrong prediction |
# | CC    : 5346   | CC    : 5225       | CC    : 121      |
# | CD    : 12730  | CD    : 12664      | CD    : 66       |
# | DT    : 269    | DT    : 0          | DT    : 269      |
# | FW    : 1614   | FW    : 1404       | FW    : 210      |
# | IN    : 15342  | IN    : 15207      | IN    : 135      |
# | JJ    : 6981   | JJ    : 6519       | JJ    : 462      |
# | MD    : 3799   | MD    : 3712       | MD    : 87       |
# | NEG   : 1118   | NEG   : 0          | NEG   : 1118     |
# | NN    : 44369  | NN    : 43942      | NN    : 427      |
# | NND   : 1047   | NND   : 938        | NND   : 109      |
# | NNP   : 25175  | NNP   : 24759      | NNP   : 416      |
# | OD    : 524    | OD    : 510        | OD    : 14       |
# | PR    : 3880   | PR    : 3829       | PR    : 51       |
# | PRP   : 5471   | PRP   : 5393       | PRP   : 78       |
# | RB    : 3477   | RB    : 3303       | RB    : 174      |
# | RP    : 141    | RP    : 0          | RP    : 141      |
# | SC    : 9455   | SC    : 9185       | SC    : 270      |
# | SYM   : 1551   | SYM   : 1503       | SYM   : 48       |
# | UH    : 21     | UH    : 0          | UH    : 21       |
# | VB    : 22950  | VB    : 22627      | VB    : 323      |
# | WH    : 184    | WH    : 0          | WH    : 184      |
# | X     : 279    | X     : 1          | X     : 278      |
# | Z     : 18960  | Z     : 18957      | Z     : 3        |
# | <PAD> : 407521 | <PAD> : 407521     | <PAD> : 0        |

# %%
train_actual_label[308], train_pred_label[308]
# Out:
# (tensor([ 8,  3, 12, 19,  8,  8,  8, 16, 19,  4, 10,  8, 10,  0,  4,  1,  8,  8,
#           8,  5,  4,  8, 10,  0, 10, 10, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23]),
#  tensor([ 8,  8, 12, 19,  8,  8,  5, 16, 19,  4, 10,  8, 10,  0,  4,  1,  8,  8,
#           8,  5,  4,  8, 10,  0, 10, 10, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23], device='cuda:0'))

# %%
train_actual_label[308] == train_pred_label[308].detach().cpu()
# Out:
# tensor([ True, False,  True,  True,  True,  True, False,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True])

# %% [markdown]
# ## OOV prediction is correct

# %%
def oov_flag_token(sentences, max_seq_len=hyperparams.max_seq_len):
    sent_copy = deepcopy(sentences)
    sent = []
    oov_flag = []
    
    for sentence in tqdm(sent_copy):
        for token in sentence:
            sent.append(token[2])
        
        for _ in range(max_seq_len- len(sentence)):
            sent.append(False)
        
        oov_flag.append(sent)
        sent = []
        
    return np.array(oov_flag)

train_oov_flag = oov_flag_token(train_sentences, max_seq_len=hyperparams.max_seq_len)
val_oov_flag = oov_flag_token(val_sentences, max_seq_len=hyperparams.max_seq_len)
test_oov_flag = oov_flag_token(test_sentences, max_seq_len=hyperparams.max_seq_len)

def pencentage_oov_pred_correct(pred_oov_flag, oov_flag_tensor):
    oov_correct_counter = 0
    oov_wrong_counter = 0

    for pred, oov_label in tqdm(zip(pred_oov_flag, oov_flag_tensor)):
        if pred == True and oov_label == True:
            oov_correct_counter += 1
        elif pred == False and oov_label == True:
            oov_wrong_counter += 1
        else:
            continue
            
    return oov_correct_counter, oov_wrong_counter

train_pred_oov_flag = (train_actual_label == train_pred_label.detach().cpu()).flatten()
val_pred_oov_flag = (val_actual_label == val_pred_label.detach().cpu()).flatten()
test_pred_oov_flag = (test_actual_label == test_pred_label.detach().cpu()).flatten()
train_oov_flag_tensor = torch.tensor(train_oov_flag).flatten()
val_oov_flag_tensor = torch.tensor(val_oov_flag).flatten()
test_oov_flag_tensor = torch.tensor(test_oov_flag).flatten()

train_oov_correct_counter, train_oov_wrong_counter = pencentage_oov_pred_correct(train_pred_oov_flag, train_oov_flag_tensor)
val_oov_correct_counter, val_oov_wrong_counter = pencentage_oov_pred_correct(val_pred_oov_flag, val_oov_flag_tensor)
test_oov_correct_counter, test_oov_wrong_counter = pencentage_oov_pred_correct(test_pred_oov_flag, test_oov_flag_tensor)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
def print_percentage_pred_oov(title, oov_correct_counter, oov_wrong_counter):
    print(f"{title}")
    print(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}")
    print(f"Correct prediction          : {oov_correct_counter}")
    print(f"Wrong prediction            : {oov_wrong_counter}")
    print(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n")
    
    with open(f"{root_path}/oov_summary.txt", "a") as f:
        f.write(f"{title}\n")
        f.write(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}\n")
        f.write(f"Correct prediction          : {oov_correct_counter}\n")
        f.write(f"Wrong prediction            : {oov_wrong_counter}\n")
        f.write(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n\n")

# %%
print_percentage_pred_oov("Training", train_oov_correct_counter, train_oov_wrong_counter)
print_percentage_pred_oov("Validation", val_oov_correct_counter, val_oov_wrong_counter)
print_percentage_pred_oov("Test", test_oov_correct_counter, test_oov_wrong_counter)
# Out:
# Training
# Number OOV token            : 11806
# Correct prediction          : 11138
# Wrong prediction            : 668
# Percentage correct oov pred : 94.34186007115026
#
# Validation
# Number OOV token            : 3366
# Correct prediction          : 2997
# Wrong prediction            : 369
# Percentage correct oov pred : 89.03743315508021
#
# Test
# Number OOV token            : 1390
# Correct prediction          : 1247
# Wrong prediction            : 143
# Percentage correct oov pred : 89.71223021582733

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(train_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(val_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(test_oov_flag, cmap=plt.cm.binary_r);
