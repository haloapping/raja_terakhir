# %% [markdown]
# # Import modules

# %%
import csv
import os
import pickle
import pytz
import torch
import timeit
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from copy import deepcopy
from datetime import datetime
from einops import rearrange
from itertools import chain
from time import time
from torch import nn, optim
from torchmetrics.classification import MulticlassAccuracy, MulticlassF1Score, MulticlassConfusionMatrix
from torch.optim import lr_scheduler
from tqdm.notebook import tqdm
from torch.utils.data import TensorDataset, DataLoader
from polyglot.mapping import Embedding, CaseExpander, DigitExpander

# %% [markdown]
# # Hyperparameters

# %%
class Hyperparams:
     def __init__(
        self,
        context_size=65,
        fold=5,
        max_seq_len=82,
        input_size=64,
        batch_size=32,
        num_hidden_layer=1,
        hidden_size=128,
        dropout=0,
        bias=True,
        output_size=24,
        shuffle=True,
        lr=0.005,
        batch_first=False,
        bidirectional=True,
        init_wb_with_kaiming_normal=True,
        n_epoch=50,
        patience=50,
        device="cuda" if torch.cuda.is_available() else "cpu"
    ):
        self.context_size = context_size
        self.fold = fold
        self.input_size = input_size
        self.max_seq_len = max_seq_len
        self.batch_size = batch_size
        self.num_hidden_layer = num_hidden_layer
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.output_size = output_size
        self.shuffle = shuffle
        self.lr = lr
        self.batch_first = batch_first
        self.bidirectional = bidirectional
        self.init_wb_with_kaiming_normal = init_wb_with_kaiming_normal
        self.n_epoch = n_epoch
        self.patience = patience
        self.device = device

hyperparams = Hyperparams()

# %% [markdown]
# # Dataset

# %%
id_pos_tag = pd.read_csv("../../../datasets/raw/Indonesian_Manually_Tagged_Corpus.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False) 
train = pd.read_csv(f"../../../datasets/raw/cv/train/train.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
val = pd.read_csv(f"../../../datasets/raw/cv/val/val.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
test = pd.read_csv(f"../../../datasets/raw/cv/test/test.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)

# %% [markdown]
# # Pre-trained Word Embedding

# %%
embeddings = Embedding.load("../../../word_embeddings/polyglot/idn_embeddings.tar.bz2")
embeddings.apply_expansion(DigitExpander)
embeddings.apply_expansion(CaseExpander)

oov_embeddings = pickle.load(open(f"../../../logs/comick/{hyperparams.context_size}_contexts/10-11-2022_17-31-59/oov_embedding_dict.pkl", "rb"))

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Add OOV Flag

# %%
def add_oov_flag(tokens, embeddings):
    oov_flags = []
    
    for token in tqdm(tokens):
        try:
            if token not in embeddings:
                oov_flags.append(True)
            else:
                oov_flags.append(False)
        except:
            oov_flags.append(False)
        
    return pd.DataFrame(oov_flags, columns=["is_oov"])

id_pos_tag_oov_flags = add_oov_flag(id_pos_tag["token"].values, embeddings)
train_oov_flags = add_oov_flag(train["token"].values, embeddings)
val_oov_flags = add_oov_flag(val["token"].values, embeddings)
test_oov_flags = add_oov_flag(test["token"].values, embeddings)
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/191905 [00:00<?, ?it/s]
#   0%|          | 0/21691 [00:00<?, ?it/s]
#   0%|          | 0/53056 [00:00<?, ?it/s]

# %% [markdown]
# ## Concate OOV Flag

# %%
id_pos_tag_df = pd.concat([id_pos_tag, id_pos_tag_oov_flags], axis=1)
train_df = pd.concat([train, train_oov_flags], axis=1)
val_df = pd.concat([val, val_oov_flags], axis=1)
test_df = pd.concat([test, test_oov_flags], axis=1)

# %% [markdown]
# ## Lowercase OOV Token

# %%
id_pos_tag_df['token'] = np.where(id_pos_tag_df['is_oov'] == True, id_pos_tag_df['token'].str.lower(), id_pos_tag_df['token'])
train_df['token'] = np.where(train_df['is_oov'] == True, train_df['token'].str.lower(), train_df['token'])
val_df['token'] = np.where(val_df['is_oov'] == True, val_df['token'].str.lower(), val_df['token'])
test_df['token'] = np.where(test_df['is_oov'] == True, test_df['token'].str.lower(), test_df['token'])

# %% [markdown]
# ## Embedding Dict, Index to Token and Token to Index

# %%
tokens = list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None))

def embedding_dict(tokens, embeddings, oov_embeddings):
    embedding = {}
    
    for token in tokens:
        if token[0] is not np.nan:
            if token[2] == False or token[0] in embeddings:
                embedding[token[0]] = embeddings[token[0]]
            else:
                embedding[token[0]] = oov_embeddings[token[0].lower()]

    return embedding

embedding_dict = embedding_dict(tokens, embeddings, oov_embeddings)
embedding_dict["<PAD>"] = embeddings["<PAD>"]
word_embeddings = nn.Embedding.from_pretrained(torch.FloatTensor(np.array(list(embedding_dict.values()))), padding_idx=list(embedding_dict.keys()).index("<PAD>"), freeze=True)

idx_to_token = {idx: token for idx, token in enumerate(list(embedding_dict.keys()))}
token_to_idx = {token: idx for idx, token in enumerate(list(embedding_dict.keys()))}

# %% [markdown]
# ## Token to Sentence

# %%
def make_sentence(tokens, max_length_sentence=hyperparams.max_seq_len):
    sentence = []
    sentences = []

    for token in tqdm(tokens):
        if token[0] is not np.nan:
            sentence.append(token)
        else:
            sentences.append(sentence[:max_length_sentence])
            sentence = []

    return sentences

all_sentence = make_sentence(list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
train_sentences = make_sentence(list(train_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
val_sentences = make_sentence(list(test_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
test_sentences = make_sentence(list(val_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/191905 [00:00<?, ?it/s]
#   0%|          | 0/53056 [00:00<?, ?it/s]
#   0%|          | 0/21691 [00:00<?, ?it/s]

# %% [markdown]
# ## Word Token, Padding, and Word token to Index

# %%
def tokenize_docs(docs, idx_token):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token[idx_token])
        sentences.append(new_sentence)
        new_sentence = []

    return sentences

def padding(docs, max_seq_len=hyperparams.max_seq_len, mode="post", val_pad="<PAD>"):
    docs = deepcopy(docs)
    doc_with_pad = []
    docs_with_pad = []

    for doc in tqdm(docs):
        if mode == "pre":
            for _ in range(max_seq_len - len(doc)):
                doc.insert(0, val_pad)
        elif mode == "post":
            for _ in range(max_seq_len - len(doc)):
                doc.append(val_pad)
        else:
            return f"Mode {mode} is not available, use instead 'pre' or 'post'."
        
        docs_with_pad.append(doc)
        
    return np.array(docs_with_pad)

def sent_to_idx(docs, token_to_idx):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token_to_idx[token])
        sentences.append(new_sentence)
        new_sentence = []

    return np.array(sentences)

def convert_feature_to_idx(docs, idx_token, token_to_idx, max_seq_len):
    sentences = tokenize_docs(docs, idx_token)
    sentences_with_pad = padding(sentences, max_seq_len=max_seq_len, mode="post", val_pad="<PAD>")
    sentences_to_idx = sent_to_idx(sentences_with_pad, token_to_idx)
    
    return sentences_to_idx

train_sentence_idxs = convert_feature_to_idx(train_sentences, 0, token_to_idx, hyperparams.max_seq_len)
val_sentence_idxs = convert_feature_to_idx(val_sentences, 0, token_to_idx, hyperparams.max_seq_len)
test_sentence_idxs = convert_feature_to_idx(test_sentences, 0, token_to_idx, hyperparams.max_seq_len)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]

# %% [markdown]
# ## Encode Class

# %%
classes = sorted(np.delete(id_pos_tag_df["tag"].unique(), 3))
idx_to_label = {idx: label for idx, label in enumerate(classes + ["<PAD>"])}
label_to_idx = {label: idx for idx, label in enumerate(classes + ["<PAD>"])}

def encode_class(docs, label_to_idx, seq_len=hyperparams.max_seq_len):
    class_idxs = []
    classes = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            class_idxs.append(label_to_idx[token[1]])
            
        for _ in range(seq_len - len(sentence)):
            class_idxs.append(label_to_idx["<PAD>"])
                
        classes.append(class_idxs)
        class_idxs = []

    return np.array(classes)
        
train_class_idxs = encode_class(train_sentences, label_to_idx)
val_class_idxs = encode_class(val_sentences, label_to_idx)
test_class_idxs = encode_class(test_sentences, label_to_idx)

print(f"Training shape   : {train_sentence_idxs.shape, train_class_idxs.shape}")
print(f"validation shape : {val_class_idxs.shape, val_class_idxs.shape}")
print(f"Test shape       : {test_sentence_idxs.shape, test_class_idxs.shape}")
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# Training shape   : ((7222, 82), (7222, 82))
# validation shape : ((2006, 82), (2006, 82))
# Test shape       : ((802, 82), (802, 82))

# %% [markdown]
# ## Note
#
# - Number of sentences = 10030
# - Train : 72% (7222)
# - Val   : 8% (802)
# - Test  : 20% (2006)

# %% [markdown]
# # Build Model

# %% [markdown]
# ## Feature and Actual Class

# %%
train_feature = torch.LongTensor(train_sentence_idxs)
val_feature = torch.LongTensor(val_sentence_idxs)
test_feature = torch.LongTensor(test_sentence_idxs)

train_class = torch.LongTensor(train_class_idxs)
val_class = torch.LongTensor(val_class_idxs)
test_class = torch.LongTensor(test_class_idxs)

# %%
train_feature.shape, val_feature.shape, test_feature.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %%
train_class.shape, val_class.shape, test_class.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %% [markdown]
# ## Tensor Dataset

# %%
train_dataset = TensorDataset(train_feature, train_class)
val_dataset = TensorDataset(val_feature, val_class)
test_dataset = TensorDataset(test_feature, test_class)

# %% [markdown]
# ## Dataloader

# %%
train_dataloader = DataLoader(train_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
val_dataloader = DataLoader(val_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
test_dataloader = DataLoader(test_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)

# %% [markdown]
# ## Model

# %%
class POSTagger(nn.Module):
    def __init__(
        self,
        input_size=hyperparams.input_size,
        hidden_size=hyperparams.hidden_size,
        dropout=hyperparams.dropout,
        bias=hyperparams.bias,
        num_layers=hyperparams.num_hidden_layer,
        output_size=hyperparams.output_size,
        batch_first=hyperparams.batch_first,
        bidirectional=hyperparams.bidirectional,
        init_wb_with_kaiming_normal=hyperparams.init_wb_with_kaiming_normal
    ):
        super(POSTagger, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.num_layers = num_layers
        self.output_size = output_size
        self.batch_first = batch_first
        self.bidirectional = bidirectional
                
        self.feature = nn.LSTM(
            input_size = self.input_size,
            hidden_size = self.hidden_size,
            bias = self.bias,
            dropout = self.dropout,
            num_layers = self.num_layers,
            batch_first = self.batch_first,
            bidirectional = self.bidirectional
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(in_features=2 * self.hidden_size if hyperparams.bidirectional else self.hidden_size, out_features=self.output_size, bias=self.bias),
            nn.Softmax(dim=-1)
        )
        
        if init_wb_with_kaiming_normal:
            self.init_wb()

    def init_wb(self):
        for module in self.modules():
            if isinstance(module, (nn.Linear, nn.LSTM)):
                for name, param in module.named_parameters():
                    if "weight" in name:
                        nn.init.kaiming_normal_(param)
                    else:
                        nn.init.kaiming_normal_(param.reshape(1, -1))
        
    def forward(self, feature, hidden=None):
        output, (hidden, memory) = self.feature(feature, None)
        prob = self.classifier(output)

        return prob
    
model = POSTagger().to(hyperparams.device)
model
# Out:
# POSTagger(
#   (feature): LSTM(64, 128, bidirectional=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=24, bias=True)
#     (1): Softmax(dim=-1)
#   )
# )

# %% [markdown]
# ## Optimizer, Criterion, and Metric

# %%
optimizer = optim.Adam(model.parameters(), lr=hyperparams.lr)
criterion = nn.CrossEntropyLoss().to(hyperparams.device)
train_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", verbose=True, factor=0.5)

# %%
sum(param.numel() for param in model.parameters() if param.requires_grad)
# Out:
# 204824

# %% [markdown]
# ## Training Step

# %%
def training_step(dataloader, model, optimizer, criterion, metric, scheduler=None):
    model.train()
    
    batch_losses = []
    batch_metric_scores = []
    
    for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
        # Forward Propagation
        feature = rearrange(feature, "n s -> s n")
        actual_label = rearrange(actual_label, "n s -> s n")
        embedding = word_embeddings(feature)
        
        prob = model(
            embedding.to(hyperparams.device),
            actual_label.to(hyperparams.device)
        )
        
        prob = prob.reshape(-1, prob.shape[-1])
        actual_label = actual_label.reshape(-1)

        loss = criterion(prob, actual_label.to(hyperparams.device))
        metric_score = metric(prob, actual_label.to(hyperparams.device))
        metric_score = metric.compute()
                
        if scheduler is not None:
            scheduler.step(loss)
        
        batch_losses.append(loss.item())
        batch_metric_scores.append(metric_score)
        
        if len(dataloader) < 10:
            if batch % 1 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
        else:
            if batch % 15 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            
        # Backward Propagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Validation Step

# %%
def validation_step(dataloader, model, criterion, metric):
    model.eval()
    
    batch_losses = []
    batch_metric_scores = []
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob, actual_label.to(hyperparams.device))
            metric_score = metric.compute()

            batch_losses.append(loss.item())
            batch_metric_scores.append(metric_score)
            
            if len(dataloader) < 10 and (batch % 1 == 0 or batch == len(dataloader)):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            else:
                if batch % 15 == 0 or batch == len(dataloader):
                    batch_name = "Batch-" + str(batch)
                    print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                    with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                        f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Looping Step

# %%
now = datetime.now(pytz.timezone("Asia/Ujung_Pandang"))
path_name = now.strftime("%m-%d-%Y_%H-%M-%S")
root_path = f"../../../logs/classifier/{hyperparams.context_size}_contexts/fold_0{hyperparams.fold}/{path_name}"
os.makedirs(root_path)

def looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric, n_epoch=hyperparams.n_epoch, patience=hyperparams.patience, monitor="loss"):    
    start_time = time()
    
    epoch_training_losses = []
    epoch_training_metric_scores = []
    epoch_val_losses = []
    epoch_val_metric_scores = []
    patience_counter = 0
    
    # Hyperparameters
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write(f"HYPERPARAMETERS\n")
        f.write(f"{'-' * 80}\n")
        for name, value in vars(hyperparams).items():
            f.write(f"{name}: {value}\n")
        
        f.write("\n\nTRAINING PROGRESS\n")
        f.write(f"{'-' * 80}\n")
    
    # Training Progress
    for epoch in range(1, n_epoch + 1):
        print(f"EPOCH-{epoch}")
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"EPOCH-{epoch}\n")
            f.write(f"Training Step\n")
            
        # Training Step
        print("Training Step")
        batch_training_losses, batch_training_metric_scores = training_step(train_dataloader, model, optimizer, criterion, train_metric, scheduler=None)
        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))

        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))
        epoch_training_losses.append(epoch_training_loss.item())

        epoch_training_metric_score = torch.mean(torch.FloatTensor(batch_training_metric_scores))
        epoch_training_metric_scores.append(epoch_training_metric_score.item())
        
        # Validation Step
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"\nValidation Step\n")
            
        print("\nValidation Step")
        batch_val_losses, batch_val_metric_scores = validation_step(val_dataloader, model, criterion, val_metric)
        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))

        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))
        epoch_val_losses.append(epoch_val_loss.item())

        epoch_val_metric_score = torch.mean(torch.FloatTensor(batch_val_metric_scores))
        epoch_val_metric_scores.append(epoch_val_metric_score.item())
        
        with open(f"{root_path}/training_history.txt", "a") as f:
            if monitor == "loss":
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_losses[-1] < epoch_training_losses[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
            else:
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_metric_scores[-1] > epoch_training_metric_scores[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗\n")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
                    
            print("=" * 80, end="\n\n")
            
            f.write(f"{'=' * 80}\n\n")
            
            if patience_counter == patience:
                print(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                
                f.write(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                break
        
        train_metric.reset()
        val_metric.reset()
        
    finish_time = time()
    
    # Training plot 
    fig, (ax_loss, ax_metric_score) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    fig.suptitle(f"Training with context size = {hyperparams.context_size}")

    ax_loss.set_title("Loss")
    ax_loss.set_xlabel("Epoch")
    ax_loss.set_ylabel("Score")
    ax_loss.plot(epoch_training_losses, "green", label="Training")
    ax_loss.plot(epoch_val_losses, "orange", label="Validation")
    ax_loss.legend()
    ax_loss.grid()

    ax_metric_score.set_title("F1 Score")
    ax_metric_score.set_xlabel("Epoch")
    ax_metric_score.set_ylabel("Score")
    ax_metric_score.plot(epoch_training_metric_scores, "green", label="Training")
    ax_metric_score.plot(epoch_val_metric_scores, "orange", label="Validation")
    ax_metric_score.legend()
    ax_metric_score.grid()

    plt.savefig(f"{root_path}/training_plot.jpg", dpi=200)                        
    
    print("TRAINING SUMMARY")
    name_best_training_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_training_metric = f"Best {str(train_metric).split('(')[0]} validation".ljust(34)
    name_best_validation_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_validation_metric = f"Best {str(val_metric).split('(')[0]} validation".ljust(34)
    name_training_time = f"Training duration".ljust(34)
    name_training_date = f"Training date".ljust(34)
    
    print(f"{name_best_training_loss}: {best_training_loss:.4f}")
    print(f"{name_best_validation_loss}: {best_val_loss:.4f}")
    print(f"{name_best_training_metric}: {best_training_metric:.4f}")
    print(f"{name_best_validation_metric}: {best_val_metric:.4f}")
    print(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.")
    print(f"{name_training_date}: {now}")
    
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write("\nTRAINING SUMMARY\n")
        f.write(f"{'-' * 80}\n")
        f.write(f"{name_best_training_loss}: {best_training_loss:.4f}\n")
        f.write(f"{name_best_validation_loss}: {best_val_loss:.4f}\n")
        f.write(f"{name_best_training_metric}: {best_training_metric:.4f}\n")
        f.write(f"{name_best_validation_metric}: {best_val_metric:.4f}\n")
        f.write(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.\n")
        f.write(f"{name_training_date}: {now}\n")
    
    # Save epoch losses, epoch metric scores, model, state dict, and oov embedding dict
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_training_losses
    }).to_csv(f"{root_path}/training_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_training_metric_scores
    }).to_csv(f"{root_path}/training_metric_scores.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_val_losses
    }).to_csv(f"{root_path}/val_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_val_metric_scores
    }).to_csv(f"{root_path}/val_metric_scores.csv", index=False)    
    
    filename_model_params = f"{root_path}/model_params.pth"
    torch.save(best_state_dict, filename_model_params)
    
    return epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores

epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores = looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric)
# Out:
# EPOCH-1
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.5023 | MulticlassF1Score=0.1336
# Batch-30 : CrossEntropyLoss=2.4440 | MulticlassF1Score=0.1954
# Batch-45 : CrossEntropyLoss=2.4304 | MulticlassF1Score=0.2208
# Batch-60 : CrossEntropyLoss=2.4124 | MulticlassF1Score=0.2582
# Batch-75 : CrossEntropyLoss=2.4001 | MulticlassF1Score=0.3067
# Batch-90 : CrossEntropyLoss=2.3768 | MulticlassF1Score=0.3480
# Batch-105: CrossEntropyLoss=2.3888 | MulticlassF1Score=0.3863
# Batch-120: CrossEntropyLoss=2.3734 | MulticlassF1Score=0.4206
# Batch-135: CrossEntropyLoss=2.3570 | MulticlassF1Score=0.4484
# Batch-150: CrossEntropyLoss=2.3645 | MulticlassF1Score=0.4711
# Batch-165: CrossEntropyLoss=2.3595 | MulticlassF1Score=0.4894
# Batch-180: CrossEntropyLoss=2.3535 | MulticlassF1Score=0.5049
# Batch-195: CrossEntropyLoss=2.3538 | MulticlassF1Score=0.5175
# Batch-210: CrossEntropyLoss=2.3697 | MulticlassF1Score=0.5282
# Batch-225: CrossEntropyLoss=2.3430 | MulticlassF1Score=0.5385
# Batch-226: CrossEntropyLoss=2.3350 | MulticlassF1Score=0.5390
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3466 | MulticlassF1Score=0.6710
# Batch-30 : CrossEntropyLoss=2.3340 | MulticlassF1Score=0.6735
# Batch-45 : CrossEntropyLoss=2.3489 | MulticlassF1Score=0.6718
# Batch-60 : CrossEntropyLoss=2.3531 | MulticlassF1Score=0.6733
# Batch-63 : CrossEntropyLoss=2.3621 | MulticlassF1Score=0.6734
#
# Training   : Mean CrossEntropyLoss = 2.4025 | Mean MulticlassF1Score = 0.3697
# Validation : Mean CrossEntropyLoss = 2.3482 | Mean MulticlassF1Score = 0.6717
# ================================================================================
#
# EPOCH-2
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3505 | MulticlassF1Score=0.6999
# Batch-30 : CrossEntropyLoss=2.3466 | MulticlassF1Score=0.7103
# Batch-45 : CrossEntropyLoss=2.3324 | MulticlassF1Score=0.7098
# Batch-60 : CrossEntropyLoss=2.3267 | MulticlassF1Score=0.7199
# Batch-75 : CrossEntropyLoss=2.3309 | MulticlassF1Score=0.7289
# Batch-90 : CrossEntropyLoss=2.3116 | MulticlassF1Score=0.7369
# Batch-105: CrossEntropyLoss=2.3135 | MulticlassF1Score=0.7447
# Batch-120: CrossEntropyLoss=2.3173 | MulticlassF1Score=0.7494
# Batch-135: CrossEntropyLoss=2.3061 | MulticlassF1Score=0.7547
# Batch-150: CrossEntropyLoss=2.3247 | MulticlassF1Score=0.7571
# Batch-165: CrossEntropyLoss=2.3163 | MulticlassF1Score=0.7593
# Batch-180: CrossEntropyLoss=2.3228 | MulticlassF1Score=0.7621
# Batch-195: CrossEntropyLoss=2.3147 | MulticlassF1Score=0.7646
# Batch-210: CrossEntropyLoss=2.3085 | MulticlassF1Score=0.7665
# Batch-225: CrossEntropyLoss=2.3174 | MulticlassF1Score=0.7681
# Batch-226: CrossEntropyLoss=2.3242 | MulticlassF1Score=0.7681
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3165 | MulticlassF1Score=0.7918
# Batch-30 : CrossEntropyLoss=2.3132 | MulticlassF1Score=0.7925
# Batch-45 : CrossEntropyLoss=2.3089 | MulticlassF1Score=0.7905
# Batch-60 : CrossEntropyLoss=2.3255 | MulticlassF1Score=0.7877
# Batch-63 : CrossEntropyLoss=2.3198 | MulticlassF1Score=0.7880
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3209 | Mean MulticlassF1Score = 0.7399
# Validation : Mean CrossEntropyLoss = 2.3137 | Mean MulticlassF1Score = 0.7911
# ================================================================================
#
# EPOCH-3
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3189 | MulticlassF1Score=0.7867
# Batch-30 : CrossEntropyLoss=2.3110 | MulticlassF1Score=0.7895
# Batch-45 : CrossEntropyLoss=2.3070 | MulticlassF1Score=0.7926
# Batch-60 : CrossEntropyLoss=2.3079 | MulticlassF1Score=0.7930
# Batch-75 : CrossEntropyLoss=2.3212 | MulticlassF1Score=0.7931
# Batch-90 : CrossEntropyLoss=2.2990 | MulticlassF1Score=0.7930
# Batch-105: CrossEntropyLoss=2.3103 | MulticlassF1Score=0.7929
# Batch-120: CrossEntropyLoss=2.3186 | MulticlassF1Score=0.7937
# Batch-135: CrossEntropyLoss=2.3109 | MulticlassF1Score=0.7937
# Batch-150: CrossEntropyLoss=2.3100 | MulticlassF1Score=0.7947
# Batch-165: CrossEntropyLoss=2.3030 | MulticlassF1Score=0.7942
# Batch-180: CrossEntropyLoss=2.3198 | MulticlassF1Score=0.7941
# Batch-195: CrossEntropyLoss=2.3194 | MulticlassF1Score=0.7942
# Batch-210: CrossEntropyLoss=2.3100 | MulticlassF1Score=0.7945
# Batch-225: CrossEntropyLoss=2.3123 | MulticlassF1Score=0.7943
# Batch-226: CrossEntropyLoss=2.3109 | MulticlassF1Score=0.7944
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3192 | MulticlassF1Score=0.7886
# Batch-30 : CrossEntropyLoss=2.3082 | MulticlassF1Score=0.7896
# Batch-45 : CrossEntropyLoss=2.3099 | MulticlassF1Score=0.7892
# Batch-60 : CrossEntropyLoss=2.3063 | MulticlassF1Score=0.7906
# Batch-63 : CrossEntropyLoss=2.3174 | MulticlassF1Score=0.7906
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3117 | Mean MulticlassF1Score = 0.7924
# Validation : Mean CrossEntropyLoss = 2.3124 | Mean MulticlassF1Score = 0.7888
# ================================================================================
#
# EPOCH-4
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3111 | MulticlassF1Score=0.7946
# Batch-30 : CrossEntropyLoss=2.3075 | MulticlassF1Score=0.7945
# Batch-45 : CrossEntropyLoss=2.3138 | MulticlassF1Score=0.7964
# Batch-60 : CrossEntropyLoss=2.3085 | MulticlassF1Score=0.7962
# Batch-75 : CrossEntropyLoss=2.3145 | MulticlassF1Score=0.7948
# Batch-90 : CrossEntropyLoss=2.3095 | MulticlassF1Score=0.7949
# Batch-105: CrossEntropyLoss=2.3066 | MulticlassF1Score=0.7947
# Batch-120: CrossEntropyLoss=2.3111 | MulticlassF1Score=0.7955
# Batch-135: CrossEntropyLoss=2.3047 | MulticlassF1Score=0.7962
# Batch-150: CrossEntropyLoss=2.3190 | MulticlassF1Score=0.7962
# Batch-165: CrossEntropyLoss=2.3027 | MulticlassF1Score=0.7964
# Batch-180: CrossEntropyLoss=2.3001 | MulticlassF1Score=0.7968
# Batch-195: CrossEntropyLoss=2.3135 | MulticlassF1Score=0.7971
# Batch-210: CrossEntropyLoss=2.3067 | MulticlassF1Score=0.7976
# Batch-225: CrossEntropyLoss=2.3136 | MulticlassF1Score=0.7975
# Batch-226: CrossEntropyLoss=2.3085 | MulticlassF1Score=0.7976
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3203 | MulticlassF1Score=0.8000
# Batch-30 : CrossEntropyLoss=2.3037 | MulticlassF1Score=0.7972
# Batch-45 : CrossEntropyLoss=2.3152 | MulticlassF1Score=0.7942
# Batch-60 : CrossEntropyLoss=2.3115 | MulticlassF1Score=0.7928
# Batch-63 : CrossEntropyLoss=2.3179 | MulticlassF1Score=0.7919
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3105 | Mean MulticlassF1Score = 0.7957
# Validation : Mean CrossEntropyLoss = 2.3119 | Mean MulticlassF1Score = 0.7982
# ================================================================================
#
# EPOCH-5
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3066 | MulticlassF1Score=0.8043
# Batch-30 : CrossEntropyLoss=2.3151 | MulticlassF1Score=0.7987
# Batch-45 : CrossEntropyLoss=2.3095 | MulticlassF1Score=0.7948
# Batch-60 : CrossEntropyLoss=2.3099 | MulticlassF1Score=0.7959
# Batch-75 : CrossEntropyLoss=2.3141 | MulticlassF1Score=0.7980
# Batch-90 : CrossEntropyLoss=2.3087 | MulticlassF1Score=0.7969
# Batch-105: CrossEntropyLoss=2.3124 | MulticlassF1Score=0.7988
# Batch-120: CrossEntropyLoss=2.3264 | MulticlassF1Score=0.7996
# Batch-135: CrossEntropyLoss=2.3053 | MulticlassF1Score=0.8008
# Batch-150: CrossEntropyLoss=2.3136 | MulticlassF1Score=0.8014
# Batch-165: CrossEntropyLoss=2.3091 | MulticlassF1Score=0.8026
# Batch-180: CrossEntropyLoss=2.2908 | MulticlassF1Score=0.8046
# Batch-195: CrossEntropyLoss=2.2979 | MulticlassF1Score=0.8065
# Batch-210: CrossEntropyLoss=2.2982 | MulticlassF1Score=0.8088
# Batch-225: CrossEntropyLoss=2.3001 | MulticlassF1Score=0.8104
# Batch-226: CrossEntropyLoss=2.2959 | MulticlassF1Score=0.8105
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2918 | MulticlassF1Score=0.8307
# Batch-30 : CrossEntropyLoss=2.3012 | MulticlassF1Score=0.8315
# Batch-45 : CrossEntropyLoss=2.3040 | MulticlassF1Score=0.8316
# Batch-60 : CrossEntropyLoss=2.3044 | MulticlassF1Score=0.8305
# Batch-63 : CrossEntropyLoss=2.3039 | MulticlassF1Score=0.8307
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3064 | Mean MulticlassF1Score = 0.8013
# Validation : Mean CrossEntropyLoss = 2.2999 | Mean MulticlassF1Score = 0.8309
# ================================================================================
#
# EPOCH-6
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2993 | MulticlassF1Score=0.8379
# Batch-30 : CrossEntropyLoss=2.3040 | MulticlassF1Score=0.8398
# Batch-45 : CrossEntropyLoss=2.2882 | MulticlassF1Score=0.8422
# Batch-60 : CrossEntropyLoss=2.2972 | MulticlassF1Score=0.8424
# Batch-75 : CrossEntropyLoss=2.3045 | MulticlassF1Score=0.8409
# Batch-90 : CrossEntropyLoss=2.2942 | MulticlassF1Score=0.8414
# Batch-105: CrossEntropyLoss=2.2940 | MulticlassF1Score=0.8409
# Batch-120: CrossEntropyLoss=2.2930 | MulticlassF1Score=0.8407
# Batch-135: CrossEntropyLoss=2.2886 | MulticlassF1Score=0.8405
# Batch-150: CrossEntropyLoss=2.2978 | MulticlassF1Score=0.8404
# Batch-165: CrossEntropyLoss=2.2939 | MulticlassF1Score=0.8404
# Batch-180: CrossEntropyLoss=2.3055 | MulticlassF1Score=0.8402
# Batch-195: CrossEntropyLoss=2.2983 | MulticlassF1Score=0.8401
# Batch-210: CrossEntropyLoss=2.2915 | MulticlassF1Score=0.8404
# Batch-225: CrossEntropyLoss=2.2998 | MulticlassF1Score=0.8401
# Batch-226: CrossEntropyLoss=2.2872 | MulticlassF1Score=0.8402
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2988 | MulticlassF1Score=0.8325
# Batch-30 : CrossEntropyLoss=2.2910 | MulticlassF1Score=0.8356
# Batch-45 : CrossEntropyLoss=2.2947 | MulticlassF1Score=0.8334
# Batch-60 : CrossEntropyLoss=2.2953 | MulticlassF1Score=0.8329
# Batch-63 : CrossEntropyLoss=2.3086 | MulticlassF1Score=0.8324
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2973 | Mean MulticlassF1Score = 0.8409
# Validation : Mean CrossEntropyLoss = 2.2994 | Mean MulticlassF1Score = 0.8318
# ================================================================================
#
# EPOCH-7
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2929 | MulticlassF1Score=0.8352
# Batch-30 : CrossEntropyLoss=2.3063 | MulticlassF1Score=0.8375
# Batch-45 : CrossEntropyLoss=2.2894 | MulticlassF1Score=0.8391
# Batch-60 : CrossEntropyLoss=2.2890 | MulticlassF1Score=0.8424
# Batch-75 : CrossEntropyLoss=2.2980 | MulticlassF1Score=0.8418
# Batch-90 : CrossEntropyLoss=2.2996 | MulticlassF1Score=0.8424
# Batch-105: CrossEntropyLoss=2.3025 | MulticlassF1Score=0.8420
# Batch-120: CrossEntropyLoss=2.3025 | MulticlassF1Score=0.8414
# Batch-135: CrossEntropyLoss=2.2876 | MulticlassF1Score=0.8411
# Batch-150: CrossEntropyLoss=2.2923 | MulticlassF1Score=0.8409
# Batch-165: CrossEntropyLoss=2.2997 | MulticlassF1Score=0.8413
# Batch-180: CrossEntropyLoss=2.2871 | MulticlassF1Score=0.8412
# Batch-195: CrossEntropyLoss=2.2972 | MulticlassF1Score=0.8413
# Batch-210: CrossEntropyLoss=2.2913 | MulticlassF1Score=0.8420
# Batch-225: CrossEntropyLoss=2.3053 | MulticlassF1Score=0.8418
# Batch-226: CrossEntropyLoss=2.3046 | MulticlassF1Score=0.8417
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2951 | MulticlassF1Score=0.8323
# Batch-30 : CrossEntropyLoss=2.2983 | MulticlassF1Score=0.8352
# Batch-45 : CrossEntropyLoss=2.3024 | MulticlassF1Score=0.8338
# Batch-60 : CrossEntropyLoss=2.2864 | MulticlassF1Score=0.8336
# Batch-63 : CrossEntropyLoss=2.2933 | MulticlassF1Score=0.8342
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2967 | Mean MulticlassF1Score = 0.8408
# Validation : Mean CrossEntropyLoss = 2.2988 | Mean MulticlassF1Score = 0.8331
# ================================================================================
#
# EPOCH-8
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2920 | MulticlassF1Score=0.8453
# Batch-30 : CrossEntropyLoss=2.2911 | MulticlassF1Score=0.8465
# Batch-45 : CrossEntropyLoss=2.2799 | MulticlassF1Score=0.8437
# Batch-60 : CrossEntropyLoss=2.2886 | MulticlassF1Score=0.8412
# Batch-75 : CrossEntropyLoss=2.3007 | MulticlassF1Score=0.8419
# Batch-90 : CrossEntropyLoss=2.3020 | MulticlassF1Score=0.8413
# Batch-105: CrossEntropyLoss=2.2894 | MulticlassF1Score=0.8427
# Batch-120: CrossEntropyLoss=2.2901 | MulticlassF1Score=0.8440
# Batch-135: CrossEntropyLoss=2.2967 | MulticlassF1Score=0.8441
# Batch-150: CrossEntropyLoss=2.2932 | MulticlassF1Score=0.8439
# Batch-165: CrossEntropyLoss=2.2919 | MulticlassF1Score=0.8441
# Batch-180: CrossEntropyLoss=2.2979 | MulticlassF1Score=0.8441
# Batch-195: CrossEntropyLoss=2.2914 | MulticlassF1Score=0.8437
# Batch-210: CrossEntropyLoss=2.2924 | MulticlassF1Score=0.8434
# Batch-225: CrossEntropyLoss=2.3056 | MulticlassF1Score=0.8434
# Batch-226: CrossEntropyLoss=2.3006 | MulticlassF1Score=0.8434
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2945 | MulticlassF1Score=0.8331
# Batch-30 : CrossEntropyLoss=2.2956 | MulticlassF1Score=0.8335
# Batch-45 : CrossEntropyLoss=2.3026 | MulticlassF1Score=0.8355
# Batch-60 : CrossEntropyLoss=2.3006 | MulticlassF1Score=0.8352
# Batch-63 : CrossEntropyLoss=2.3074 | MulticlassF1Score=0.8344
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2961 | Mean MulticlassF1Score = 0.8433
# Validation : Mean CrossEntropyLoss = 2.2987 | Mean MulticlassF1Score = 0.8328
# ================================================================================
#
# EPOCH-9
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2985 | MulticlassF1Score=0.8520
# Batch-30 : CrossEntropyLoss=2.2900 | MulticlassF1Score=0.8506
# Batch-45 : CrossEntropyLoss=2.2851 | MulticlassF1Score=0.8514
# Batch-60 : CrossEntropyLoss=2.2958 | MulticlassF1Score=0.8537
# Batch-75 : CrossEntropyLoss=2.3007 | MulticlassF1Score=0.8552
# Batch-90 : CrossEntropyLoss=2.2988 | MulticlassF1Score=0.8556
# Batch-105: CrossEntropyLoss=2.2881 | MulticlassF1Score=0.8572
# Batch-120: CrossEntropyLoss=2.2795 | MulticlassF1Score=0.8596
# Batch-135: CrossEntropyLoss=2.2839 | MulticlassF1Score=0.8626
# Batch-150: CrossEntropyLoss=2.2797 | MulticlassF1Score=0.8648
# Batch-165: CrossEntropyLoss=2.2828 | MulticlassF1Score=0.8667
# Batch-180: CrossEntropyLoss=2.2833 | MulticlassF1Score=0.8684
# Batch-195: CrossEntropyLoss=2.2870 | MulticlassF1Score=0.8696
# Batch-210: CrossEntropyLoss=2.2815 | MulticlassF1Score=0.8705
# Batch-225: CrossEntropyLoss=2.2854 | MulticlassF1Score=0.8712
# Batch-226: CrossEntropyLoss=2.2955 | MulticlassF1Score=0.8712
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2788 | MulticlassF1Score=0.8771
# Batch-30 : CrossEntropyLoss=2.2775 | MulticlassF1Score=0.8782
# Batch-45 : CrossEntropyLoss=2.2927 | MulticlassF1Score=0.8767
# Batch-60 : CrossEntropyLoss=2.2912 | MulticlassF1Score=0.8783
# Batch-63 : CrossEntropyLoss=2.2905 | MulticlassF1Score=0.8783
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2880 | Mean MulticlassF1Score = 0.8602
# Validation : Mean CrossEntropyLoss = 2.2856 | Mean MulticlassF1Score = 0.8763
# ================================================================================
#
# EPOCH-10
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2835 | MulticlassF1Score=0.8883
# Batch-30 : CrossEntropyLoss=2.2841 | MulticlassF1Score=0.8904
# Batch-45 : CrossEntropyLoss=2.2813 | MulticlassF1Score=0.8899
# Batch-60 : CrossEntropyLoss=2.2817 | MulticlassF1Score=0.8898
# Batch-75 : CrossEntropyLoss=2.2825 | MulticlassF1Score=0.8879
# Batch-90 : CrossEntropyLoss=2.2819 | MulticlassF1Score=0.8881
# Batch-105: CrossEntropyLoss=2.2812 | MulticlassF1Score=0.8876
# Batch-120: CrossEntropyLoss=2.2756 | MulticlassF1Score=0.8881
# Batch-135: CrossEntropyLoss=2.2867 | MulticlassF1Score=0.8883
# Batch-150: CrossEntropyLoss=2.2884 | MulticlassF1Score=0.8888
# Batch-165: CrossEntropyLoss=2.2814 | MulticlassF1Score=0.8895
# Batch-180: CrossEntropyLoss=2.2811 | MulticlassF1Score=0.8894
# Batch-195: CrossEntropyLoss=2.2872 | MulticlassF1Score=0.8887
# Batch-210: CrossEntropyLoss=2.2859 | MulticlassF1Score=0.8889
# Batch-225: CrossEntropyLoss=2.2827 | MulticlassF1Score=0.8894
# Batch-226: CrossEntropyLoss=2.2809 | MulticlassF1Score=0.8894
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2826 | MulticlassF1Score=0.8821
# Batch-30 : CrossEntropyLoss=2.2837 | MulticlassF1Score=0.8814
# Batch-45 : CrossEntropyLoss=2.2833 | MulticlassF1Score=0.8810
# Batch-60 : CrossEntropyLoss=2.2814 | MulticlassF1Score=0.8812
# Batch-63 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.8815
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2822 | Mean MulticlassF1Score = 0.8889
# Validation : Mean CrossEntropyLoss = 2.2843 | Mean MulticlassF1Score = 0.8813
# ================================================================================
#
# EPOCH-11
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2858 | MulticlassF1Score=0.8949
# Batch-30 : CrossEntropyLoss=2.2764 | MulticlassF1Score=0.8924
# Batch-45 : CrossEntropyLoss=2.2890 | MulticlassF1Score=0.8923
# Batch-60 : CrossEntropyLoss=2.2870 | MulticlassF1Score=0.8914
# Batch-75 : CrossEntropyLoss=2.2800 | MulticlassF1Score=0.8927
# Batch-90 : CrossEntropyLoss=2.2866 | MulticlassF1Score=0.8923
# Batch-105: CrossEntropyLoss=2.2811 | MulticlassF1Score=0.8927
# Batch-120: CrossEntropyLoss=2.2789 | MulticlassF1Score=0.8924
# Batch-135: CrossEntropyLoss=2.2816 | MulticlassF1Score=0.8928
# Batch-150: CrossEntropyLoss=2.2863 | MulticlassF1Score=0.8924
# Batch-165: CrossEntropyLoss=2.2793 | MulticlassF1Score=0.8924
# Batch-180: CrossEntropyLoss=2.2840 | MulticlassF1Score=0.8925
# Batch-195: CrossEntropyLoss=2.2850 | MulticlassF1Score=0.8929
# Batch-210: CrossEntropyLoss=2.2797 | MulticlassF1Score=0.8930
# Batch-225: CrossEntropyLoss=2.2789 | MulticlassF1Score=0.8933
# Batch-226: CrossEntropyLoss=2.2848 | MulticlassF1Score=0.8933
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2817 | MulticlassF1Score=0.8871
# Batch-30 : CrossEntropyLoss=2.2850 | MulticlassF1Score=0.8848
# Batch-45 : CrossEntropyLoss=2.2877 | MulticlassF1Score=0.8862
# Batch-60 : CrossEntropyLoss=2.2867 | MulticlassF1Score=0.8862
# Batch-63 : CrossEntropyLoss=2.2844 | MulticlassF1Score=0.8863
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2809 | Mean MulticlassF1Score = 0.8931
# Validation : Mean CrossEntropyLoss = 2.2830 | Mean MulticlassF1Score = 0.8866
# ================================================================================
#
# EPOCH-12
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2808 | MulticlassF1Score=0.8961
# Batch-30 : CrossEntropyLoss=2.2775 | MulticlassF1Score=0.8970
# Batch-45 : CrossEntropyLoss=2.2763 | MulticlassF1Score=0.8994
# Batch-60 : CrossEntropyLoss=2.2760 | MulticlassF1Score=0.8995
# Batch-75 : CrossEntropyLoss=2.2811 | MulticlassF1Score=0.8995
# Batch-90 : CrossEntropyLoss=2.2795 | MulticlassF1Score=0.8997
# Batch-105: CrossEntropyLoss=2.2817 | MulticlassF1Score=0.8993
# Batch-120: CrossEntropyLoss=2.2823 | MulticlassF1Score=0.8991
# Batch-135: CrossEntropyLoss=2.2897 | MulticlassF1Score=0.8990
# Batch-150: CrossEntropyLoss=2.2864 | MulticlassF1Score=0.8988
# Batch-165: CrossEntropyLoss=2.2768 | MulticlassF1Score=0.8987
# Batch-180: CrossEntropyLoss=2.2801 | MulticlassF1Score=0.8983
# Batch-195: CrossEntropyLoss=2.2753 | MulticlassF1Score=0.8982
# Batch-210: CrossEntropyLoss=2.2783 | MulticlassF1Score=0.8980
# Batch-225: CrossEntropyLoss=2.2797 | MulticlassF1Score=0.8984
# Batch-226: CrossEntropyLoss=2.2774 | MulticlassF1Score=0.8984
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2811 | MulticlassF1Score=0.8881
# Batch-30 : CrossEntropyLoss=2.2849 | MulticlassF1Score=0.8886
# Batch-45 : CrossEntropyLoss=2.2803 | MulticlassF1Score=0.8870
# Batch-60 : CrossEntropyLoss=2.2867 | MulticlassF1Score=0.8885
# Batch-63 : CrossEntropyLoss=2.2789 | MulticlassF1Score=0.8888
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2792 | Mean MulticlassF1Score = 0.8983
# Validation : Mean CrossEntropyLoss = 2.2820 | Mean MulticlassF1Score = 0.8863
# ================================================================================
#
# EPOCH-13
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2771 | MulticlassF1Score=0.9038
# Batch-30 : CrossEntropyLoss=2.2771 | MulticlassF1Score=0.9017
# Batch-45 : CrossEntropyLoss=2.2800 | MulticlassF1Score=0.9020
# Batch-60 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9027
# Batch-75 : CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9025
# Batch-90 : CrossEntropyLoss=2.2845 | MulticlassF1Score=0.9017
# Batch-105: CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9016
# Batch-120: CrossEntropyLoss=2.2882 | MulticlassF1Score=0.9017
# Batch-135: CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9021
# Batch-150: CrossEntropyLoss=2.2795 | MulticlassF1Score=0.9020
# Batch-165: CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9021
# Batch-180: CrossEntropyLoss=2.2857 | MulticlassF1Score=0.9018
# Batch-195: CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9014
# Batch-210: CrossEntropyLoss=2.2809 | MulticlassF1Score=0.9010
# Batch-225: CrossEntropyLoss=2.2853 | MulticlassF1Score=0.9008
# Batch-226: CrossEntropyLoss=2.2800 | MulticlassF1Score=0.9008
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2851 | MulticlassF1Score=0.8856
# Batch-30 : CrossEntropyLoss=2.2771 | MulticlassF1Score=0.8881
# Batch-45 : CrossEntropyLoss=2.2778 | MulticlassF1Score=0.8877
# Batch-60 : CrossEntropyLoss=2.2838 | MulticlassF1Score=0.8889
# Batch-63 : CrossEntropyLoss=2.2821 | MulticlassF1Score=0.8892
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2785 | Mean MulticlassF1Score = 0.9019
# Validation : Mean CrossEntropyLoss = 2.2819 | Mean MulticlassF1Score = 0.8886
# ================================================================================
#
# EPOCH-14
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2848 | MulticlassF1Score=0.9057
# Batch-30 : CrossEntropyLoss=2.2817 | MulticlassF1Score=0.9010
# Batch-45 : CrossEntropyLoss=2.2817 | MulticlassF1Score=0.9017
# Batch-60 : CrossEntropyLoss=2.2850 | MulticlassF1Score=0.9024
# Batch-75 : CrossEntropyLoss=2.2747 | MulticlassF1Score=0.9040
# Batch-90 : CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9075
# Batch-105: CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9101
# Batch-120: CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9126
# Batch-135: CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9141
# Batch-150: CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9156
# Batch-165: CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9166
# Batch-180: CrossEntropyLoss=2.2758 | MulticlassF1Score=0.9178
# Batch-195: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9187
# Batch-210: CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9194
# Batch-225: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9201
# Batch-226: CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9201
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9146
# Batch-30 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9177
# Batch-45 : CrossEntropyLoss=2.2766 | MulticlassF1Score=0.9183
# Batch-60 : CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9188
# Batch-63 : CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9189
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2726 | Mean MulticlassF1Score = 0.9107
# Validation : Mean CrossEntropyLoss = 2.2729 | Mean MulticlassF1Score = 0.9173
# ================================================================================
#
# EPOCH-15
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9295
# Batch-30 : CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9297
# Batch-45 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9311
# Batch-60 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9308
# Batch-75 : CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9311
# Batch-90 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9304
# Batch-105: CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9309
# Batch-120: CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9311
# Batch-135: CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9314
# Batch-150: CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9316
# Batch-165: CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9318
# Batch-180: CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9321
# Batch-195: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9324
# Batch-210: CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9323
# Batch-225: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9322
# Batch-226: CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9322
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9176
# Batch-30 : CrossEntropyLoss=2.2768 | MulticlassF1Score=0.9205
# Batch-45 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9205
# Batch-60 : CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9199
# Batch-63 : CrossEntropyLoss=2.2839 | MulticlassF1Score=0.9196
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2688 | Mean MulticlassF1Score = 0.9311
# Validation : Mean CrossEntropyLoss = 2.2726 | Mean MulticlassF1Score = 0.9185
# ================================================================================
#
# EPOCH-16
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9362
# Batch-30 : CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9360
# Batch-45 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9359
# Batch-60 : CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9353
# Batch-75 : CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9355
# Batch-90 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9345
# Batch-105: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9342
# Batch-120: CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9343
# Batch-135: CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9341
# Batch-150: CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9343
# Batch-165: CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9341
# Batch-180: CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9339
# Batch-195: CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9341
# Batch-210: CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9339
# Batch-225: CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9337
# Batch-226: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9337
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2756 | MulticlassF1Score=0.9155
# Batch-30 : CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9169
# Batch-45 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9184
# Batch-60 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9200
# Batch-63 : CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9199
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2682 | Mean MulticlassF1Score = 0.9348
# Validation : Mean CrossEntropyLoss = 2.2724 | Mean MulticlassF1Score = 0.9169
# ================================================================================
#
# EPOCH-17
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9320
# Batch-30 : CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9346
# Batch-45 : CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9340
# Batch-60 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9333
# Batch-75 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9339
# Batch-90 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9340
# Batch-105: CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9339
# Batch-120: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9344
# Batch-135: CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9341
# Batch-150: CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9344
# Batch-165: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9344
# Batch-180: CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9346
# Batch-195: CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9348
# Batch-210: CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9346
# Batch-225: CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9344
# Batch-226: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9344
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9177
# Batch-30 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9211
# Batch-45 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9220
# Batch-60 : CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9203
# Batch-63 : CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9204
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2679 | Mean MulticlassF1Score = 0.9342
# Validation : Mean CrossEntropyLoss = 2.2722 | Mean MulticlassF1Score = 0.9195
# ================================================================================
#
# EPOCH-18
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9364
# Batch-30 : CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9351
# Batch-45 : CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9352
# Batch-60 : CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9350
# Batch-75 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9345
# Batch-90 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9351
# Batch-105: CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9352
# Batch-120: CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9357
# Batch-135: CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9358
# Batch-150: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9355
# Batch-165: CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9354
# Batch-180: CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9356
# Batch-195: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9358
# Batch-210: CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9353
# Batch-225: CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9353
# Batch-226: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9353
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9188
# Batch-30 : CrossEntropyLoss=2.2782 | MulticlassF1Score=0.9192
# Batch-45 : CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9200
# Batch-60 : CrossEntropyLoss=2.2764 | MulticlassF1Score=0.9196
# Batch-63 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9201
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2676 | Mean MulticlassF1Score = 0.9356
# Validation : Mean CrossEntropyLoss = 2.2722 | Mean MulticlassF1Score = 0.9192
# ================================================================================
#
# EPOCH-19
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9390
# Batch-30 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9370
# Batch-45 : CrossEntropyLoss=2.2767 | MulticlassF1Score=0.9368
# Batch-60 : CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9362
# Batch-75 : CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9363
# Batch-90 : CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9362
# Batch-105: CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9364
# Batch-120: CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9364
# Batch-135: CrossEntropyLoss=2.2792 | MulticlassF1Score=0.9367
# Batch-150: CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9364
# Batch-165: CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9364
# Batch-180: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9363
# Batch-195: CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9361
# Batch-210: CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9362
# Batch-225: CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9361
# Batch-226: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9361
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9224
# Batch-30 : CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9222
# Batch-45 : CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9210
# Batch-60 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9210
# Batch-63 : CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9208
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2674 | Mean MulticlassF1Score = 0.9366
# Validation : Mean CrossEntropyLoss = 2.2721 | Mean MulticlassF1Score = 0.9208
# ================================================================================
#
# EPOCH-20
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9397
# Batch-30 : CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9368
# Batch-45 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9383
# Batch-60 : CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9372
# Batch-75 : CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9373
# Batch-90 : CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9380
# Batch-105: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9380
# Batch-120: CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9376
# Batch-135: CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9375
# Batch-150: CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9373
# Batch-165: CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9372
# Batch-180: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9372
# Batch-195: CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9371
# Batch-210: CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9369
# Batch-225: CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9370
# Batch-226: CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9370
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9148
# Batch-30 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9181
# Batch-45 : CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9199
# Batch-60 : CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9207
# Batch-63 : CrossEntropyLoss=2.2747 | MulticlassF1Score=0.9204
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2670 | Mean MulticlassF1Score = 0.9377
# Validation : Mean CrossEntropyLoss = 2.2722 | Mean MulticlassF1Score = 0.9193
# ================================================================================
#
# EPOCH-21
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9373
# Batch-30 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9377
# Batch-45 : CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9380
# Batch-60 : CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9370
# Batch-75 : CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9370
# Batch-90 : CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9367
# Batch-105: CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9367
# Batch-120: CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9371
# Batch-135: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9375
# Batch-150: CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9369
# Batch-165: CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9371
# Batch-180: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9369
# Batch-195: CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9370
# Batch-210: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9372
# Batch-225: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9375
# Batch-226: CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9375
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9185
# Batch-30 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9195
# Batch-45 : CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9194
# Batch-60 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9200
# Batch-63 : CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9201
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2668 | Mean MulticlassF1Score = 0.9371
# Validation : Mean CrossEntropyLoss = 2.2721 | Mean MulticlassF1Score = 0.9204
# ================================================================================
#
# EPOCH-22
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9381
# Batch-30 : CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9378
# Batch-45 : CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9387
# Batch-60 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9387
# Batch-75 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9386
# Batch-90 : CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9388
# Batch-105: CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9391
# Batch-120: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9386
# Batch-135: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9390
# Batch-150: CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9388
# Batch-165: CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9387
# Batch-180: CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9388
# Batch-195: CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9386
# Batch-210: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9387
# Batch-225: CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9382
# Batch-226: CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9382
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9224
# Batch-30 : CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9206
# Batch-45 : CrossEntropyLoss=2.2772 | MulticlassF1Score=0.9216
# Batch-60 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9209
# Batch-63 : CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9210
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2666 | Mean MulticlassF1Score = 0.9385
# Validation : Mean CrossEntropyLoss = 2.2719 | Mean MulticlassF1Score = 0.9212
# ================================================================================
#
# EPOCH-23
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9371
# Batch-30 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9403
# Batch-45 : CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9400
# Batch-60 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9389
# Batch-75 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9395
# Batch-90 : CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9388
# Batch-105: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9389
# Batch-120: CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9388
# Batch-135: CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9388
# Batch-150: CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9387
# Batch-165: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9385
# Batch-180: CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9385
# Batch-195: CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9385
# Batch-210: CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9385
# Batch-225: CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9385
# Batch-226: CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9385
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9221
# Batch-30 : CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9198
# Batch-45 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9209
# Batch-60 : CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9203
# Batch-63 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9207
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2665 | Mean MulticlassF1Score = 0.9389
# Validation : Mean CrossEntropyLoss = 2.2720 | Mean MulticlassF1Score = 0.9213
# ================================================================================
#
# EPOCH-24
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9379
# Batch-30 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9400
# Batch-45 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9387
# Batch-60 : CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9395
# Batch-75 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9395
# Batch-90 : CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9393
# Batch-105: CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9389
# Batch-120: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9389
# Batch-135: CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9391
# Batch-150: CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9390
# Batch-165: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9387
# Batch-180: CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9386
# Batch-195: CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9384
# Batch-210: CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9386
# Batch-225: CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9387
# Batch-226: CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9387
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2769 | MulticlassF1Score=0.9213
# Batch-30 : CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9200
# Batch-45 : CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9209
# Batch-60 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9209
# Batch-63 : CrossEntropyLoss=2.2751 | MulticlassF1Score=0.9206
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2664 | Mean MulticlassF1Score = 0.9388
# Validation : Mean CrossEntropyLoss = 2.2721 | Mean MulticlassF1Score = 0.9209
# ================================================================================
#
# EPOCH-25
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2753 | MulticlassF1Score=0.9368
# Batch-30 : CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9373
# Batch-45 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9380
# Batch-60 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9374
# Batch-75 : CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9372
# Batch-90 : CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9381
# Batch-105: CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9383
# Batch-120: CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9384
# Batch-135: CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9387
# Batch-150: CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9391
# Batch-165: CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9391
# Batch-180: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9389
# Batch-195: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9392
# Batch-210: CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9392
# Batch-225: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9391
# Batch-226: CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9390
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9231
# Batch-30 : CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9241
# Batch-45 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9227
# Batch-60 : CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9216
# Batch-63 : CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9216
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2663 | Mean MulticlassF1Score = 0.9383
# Validation : Mean CrossEntropyLoss = 2.2717 | Mean MulticlassF1Score = 0.9230
# ================================================================================
#
# EPOCH-26
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9422
# Batch-30 : CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9428
# Batch-45 : CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9430
# Batch-60 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9437
# Batch-75 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9439
# Batch-90 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9431
# Batch-105: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9430
# Batch-120: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9427
# Batch-135: CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9430
# Batch-150: CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9430
# Batch-165: CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9432
# Batch-180: CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9429
# Batch-195: CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9426
# Batch-210: CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9423
# Batch-225: CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9424
# Batch-226: CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9424
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2770 | MulticlassF1Score=0.9258
# Batch-30 : CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9251
# Batch-45 : CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9232
# Batch-60 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9221
# Batch-63 : CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9224
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2654 | Mean MulticlassF1Score = 0.9431
# Validation : Mean CrossEntropyLoss = 2.2715 | Mean MulticlassF1Score = 0.9242
# ================================================================================
#
# EPOCH-27
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9461
# Batch-30 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9438
# Batch-45 : CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9443
# Batch-60 : CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9444
# Batch-75 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9433
# Batch-90 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9434
# Batch-105: CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9431
# Batch-120: CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9429
# Batch-135: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9430
# Batch-150: CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9426
# Batch-165: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9427
# Batch-180: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9419
# Batch-195: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9420
# Batch-210: CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9422
# Batch-225: CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9426
# Batch-226: CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9426
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9253
# Batch-30 : CrossEntropyLoss=2.2780 | MulticlassF1Score=0.9241
# Batch-45 : CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9239
# Batch-60 : CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9242
# Batch-63 : CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9241
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2653 | Mean MulticlassF1Score = 0.9433
# Validation : Mean CrossEntropyLoss = 2.2709 | Mean MulticlassF1Score = 0.9253
# ================================================================================
#
# EPOCH-28
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9469
# Batch-30 : CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9445
# Batch-45 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9433
# Batch-60 : CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9436
# Batch-75 : CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9440
# Batch-90 : CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9433
# Batch-105: CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9435
# Batch-120: CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9435
# Batch-135: CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9434
# Batch-150: CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9434
# Batch-165: CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9432
# Batch-180: CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9431
# Batch-195: CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9431
# Batch-210: CrossEntropyLoss=2.2603 | MulticlassF1Score=0.9431
# Batch-225: CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9428
# Batch-226: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9428
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9241
# Batch-30 : CrossEntropyLoss=2.2758 | MulticlassF1Score=0.9229
# Batch-45 : CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9227
# Batch-60 : CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9233
# Batch-63 : CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9229
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2651 | Mean MulticlassF1Score = 0.9439
# Validation : Mean CrossEntropyLoss = 2.2713 | Mean MulticlassF1Score = 0.9219
# ================================================================================
#
# EPOCH-29
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9448
# Batch-30 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9443
# Batch-45 : CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9447
# Batch-60 : CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9439
# Batch-75 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9437
# Batch-90 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9431
# Batch-105: CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9431
# Batch-120: CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9432
# Batch-135: CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9434
# Batch-150: CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9436
# Batch-165: CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9435
# Batch-180: CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9432
# ...
# Batch-45 : CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9448
# Batch-60 : CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9463
# Batch-63 : CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9467
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2571 | Mean MulticlassF1Score = 0.9691
# Validation : Mean CrossEntropyLoss = 2.2639 | Mean MulticlassF1Score = 0.9464
# ================================================================================
#
# EPOCH-42
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9684
# Batch-30 : CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9668
# Batch-45 : CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9663
# Batch-60 : CrossEntropyLoss=2.2551 | MulticlassF1Score=0.9666
# Batch-75 : CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9667
# Batch-90 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9669
# Batch-105: CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9674
# Batch-120: CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9675
# Batch-135: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9677
# Batch-150: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9677
# Batch-165: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9676
# Batch-180: CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9674
# Batch-195: CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9676
# Batch-210: CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9676
# Batch-225: CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9677
# Batch-226: CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9677
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9455
# Batch-30 : CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9451
# Batch-45 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9468
# Batch-60 : CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9466
# Batch-63 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9459
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2574 | Mean MulticlassF1Score = 0.9674
# Validation : Mean CrossEntropyLoss = 2.2642 | Mean MulticlassF1Score = 0.9461
# Patience = 3/50❗
# ================================================================================
#
# EPOCH-43
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9696
# Batch-30 : CrossEntropyLoss=2.2534 | MulticlassF1Score=0.9676
# Batch-45 : CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9670
# Batch-60 : CrossEntropyLoss=2.2539 | MulticlassF1Score=0.9679
# Batch-75 : CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9676
# Batch-90 : CrossEntropyLoss=2.2540 | MulticlassF1Score=0.9678
# Batch-105: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9680
# Batch-120: CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9682
# Batch-135: CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9683
# Batch-150: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9683
# Batch-165: CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9684
# Batch-180: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9684
# Batch-195: CrossEntropyLoss=2.2551 | MulticlassF1Score=0.9685
# Batch-210: CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9683
# Batch-225: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9679
# Batch-226: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9680
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9481
# Batch-30 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9475
# Batch-45 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9467
# Batch-60 : CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9460
# Batch-63 : CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9456
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2573 | Mean MulticlassF1Score = 0.9679
# Validation : Mean CrossEntropyLoss = 2.2642 | Mean MulticlassF1Score = 0.9467
# ================================================================================
#
# EPOCH-44
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9680
# Batch-30 : CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9682
# Batch-45 : CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9686
# Batch-60 : CrossEntropyLoss=2.2544 | MulticlassF1Score=0.9689
# Batch-75 : CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9682
# Batch-90 : CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9679
# Batch-105: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9681
# Batch-120: CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9683
# Batch-135: CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9680
# Batch-150: CrossEntropyLoss=2.2544 | MulticlassF1Score=0.9684
# Batch-165: CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9686
# Batch-180: CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9685
# Batch-195: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9684
# Batch-210: CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9684
# Batch-225: CrossEntropyLoss=2.2536 | MulticlassF1Score=0.9680
# Batch-226: CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9681
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9451
# Batch-30 : CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9453
# Batch-45 : CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9453
# Batch-60 : CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9468
# Batch-63 : CrossEntropyLoss=2.2611 | MulticlassF1Score=0.9466
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2573 | Mean MulticlassF1Score = 0.9684
# Validation : Mean CrossEntropyLoss = 2.2640 | Mean MulticlassF1Score = 0.9450
# ================================================================================
#
# EPOCH-45
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9680
# Batch-30 : CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9689
# Batch-45 : CrossEntropyLoss=2.2543 | MulticlassF1Score=0.9684
# Batch-60 : CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9693
# Batch-75 : CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9690
# Batch-90 : CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9690
# Batch-105: CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9689
# Batch-120: CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9686
# Batch-135: CrossEntropyLoss=2.2534 | MulticlassF1Score=0.9685
# Batch-150: CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9685
# Batch-165: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9683
# Batch-180: CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9684
# Batch-195: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9683
# Batch-210: CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9682
# Batch-225: CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9682
# Batch-226: CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9682
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9476
# Batch-30 : CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9477
# Batch-45 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9469
# Batch-60 : CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9466
# Batch-63 : CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9464
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2573 | Mean MulticlassF1Score = 0.9685
# Validation : Mean CrossEntropyLoss = 2.2640 | Mean MulticlassF1Score = 0.9467
# ================================================================================
#
# EPOCH-46
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9703
# Batch-30 : CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9693
# Batch-45 : CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9693
# Batch-60 : CrossEntropyLoss=2.2520 | MulticlassF1Score=0.9692
# Batch-75 : CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9692
# Batch-90 : CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9689
# Batch-105: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9691
# Batch-120: CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9693
# Batch-135: CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9691
# Batch-150: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9686
# Batch-165: CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9686
# Batch-180: CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9686
# Batch-195: CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9685
# Batch-210: CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9684
# Batch-225: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9685
# Batch-226: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9685
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9494
# Batch-30 : CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9490
# Batch-45 : CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9486
# Batch-60 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9467
# Batch-63 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9470
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2572 | Mean MulticlassF1Score = 0.9689
# Validation : Mean CrossEntropyLoss = 2.2638 | Mean MulticlassF1Score = 0.9484
# ================================================================================
#
# EPOCH-47
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9660
# Batch-30 : CrossEntropyLoss=2.2539 | MulticlassF1Score=0.9677
# Batch-45 : CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9677
# Batch-60 : CrossEntropyLoss=2.2538 | MulticlassF1Score=0.9675
# Batch-75 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9682
# Batch-90 : CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9685
# Batch-105: CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9684
# Batch-120: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9684
# Batch-135: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9687
# Batch-150: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9687
# Batch-165: CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9687
# Batch-180: CrossEntropyLoss=2.2551 | MulticlassF1Score=0.9685
# Batch-195: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9687
# Batch-210: CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9688
# Batch-225: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9687
# Batch-226: CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9687
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9465
# Batch-30 : CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9483
# Batch-45 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9471
# Batch-60 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9468
# Batch-63 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9467
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2571 | Mean MulticlassF1Score = 0.9682
# Validation : Mean CrossEntropyLoss = 2.2639 | Mean MulticlassF1Score = 0.9468
# ================================================================================
#
# EPOCH-48
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9721
# Batch-30 : CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9706
# Batch-45 : CrossEntropyLoss=2.2524 | MulticlassF1Score=0.9704
# Batch-60 : CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9700
# Batch-75 : CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9700
# Batch-90 : CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9701
# Batch-105: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9699
# Batch-120: CrossEntropyLoss=2.2603 | MulticlassF1Score=0.9695
# Batch-135: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9693
# Batch-150: CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9693
# Batch-165: CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9692
# Batch-180: CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9689
# Batch-195: CrossEntropyLoss=2.2551 | MulticlassF1Score=0.9689
# Batch-210: CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9689
# Batch-225: CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9690
# Batch-226: CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9690
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9462
# Batch-30 : CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9463
# Batch-45 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9463
# Batch-60 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9464
# Batch-63 : CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9468
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2570 | Mean MulticlassF1Score = 0.9698
# Validation : Mean CrossEntropyLoss = 2.2638 | Mean MulticlassF1Score = 0.9453
# ================================================================================
#
# EPOCH-49
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9714
# Batch-30 : CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9703
# Batch-45 : CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9694
# Batch-60 : CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9694
# Batch-75 : CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9690
# Batch-90 : CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9690
# Batch-105: CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9692
# Batch-120: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9694
# Batch-135: CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9697
# Batch-150: CrossEntropyLoss=2.2530 | MulticlassF1Score=0.9697
# Batch-165: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9696
# Batch-180: CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9697
# Batch-195: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9695
# Batch-210: CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9696
# Batch-225: CrossEntropyLoss=2.2533 | MulticlassF1Score=0.9695
# Batch-226: CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9695
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9493
# Batch-30 : CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9484
# Batch-45 : CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9482
# Batch-60 : CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9473
# Batch-63 : CrossEntropyLoss=2.2612 | MulticlassF1Score=0.9472
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2568 | Mean MulticlassF1Score = 0.9698
# Validation : Mean CrossEntropyLoss = 2.2638 | Mean MulticlassF1Score = 0.9473
# ================================================================================
#
# EPOCH-50
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9712
# Batch-30 : CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9700
# Batch-45 : CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9710
# Batch-60 : CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9704
# Batch-75 : CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9700
# Batch-90 : CrossEntropyLoss=2.2542 | MulticlassF1Score=0.9697
# Batch-105: CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9702
# Batch-120: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9705
# Batch-135: CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9701
# Batch-150: CrossEntropyLoss=2.2543 | MulticlassF1Score=0.9698
# Batch-165: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9698
# Batch-180: CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9697
# Batch-195: CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9695
# Batch-210: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9695
# Batch-225: CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9694
# Batch-226: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9694
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9440
# Batch-30 : CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9455
# Batch-45 : CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9474
# Batch-60 : CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9469
# Batch-63 : CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9471
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2568 | Mean MulticlassF1Score = 0.9702
# Validation : Mean CrossEntropyLoss = 2.2638 | Mean MulticlassF1Score = 0.9463
# Patience = 4/50❗
# ================================================================================
#
# TRAINING SUMMARY
# Best CrossEntropyLoss training    : 2.2568
# Best CrossEntropyLoss training    : 2.2638
# Best MulticlassF1Score validation : 0.9698
# Best MulticlassF1Score validation : 0.9473
# Training duration                 : 2.5911 minutes.
# Training date                     : 2022-10-19 11:47:00.709126+08:00

# %% [markdown]
# ## End Training

# %% [markdown]
# # Evaluation

# %%
def evaluation(dataloader, model, criterion, metric):
    model.eval()
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)
            pred = rearrange(prob.argmax(dim=1).reshape(feature.shape[0], len(dataloader.dataset)), "s n -> n s")

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob.argmax(dim=1), actual_label.to(hyperparams.device))
            metric_score = metric.compute()

    return loss, metric_score, pred

train_dataloader = DataLoader(train_dataset, batch_size=len(train_dataset))
val_dataloader = DataLoader(val_dataset, batch_size=len(val_dataset))
test_dataloader = DataLoader(test_dataset, batch_size=len(test_dataset))

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
train_loss, train_f1_score, train_pred_label = evaluation(train_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_loss, val_f1_score, val_pred_label = evaluation(val_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
test_loss, test_f1_score, test_pred_label = evaluation(test_dataloader, model, criterion, metric)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9700, device='cuda:0'),
#  tensor(0.9471, device='cuda:0'),
#  tensor(0.9471, device='cuda:0'))

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9700, device='cuda:0'),
#  tensor(0.9471, device='cuda:0'),
#  tensor(0.9471, device='cuda:0'))

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns

def viz_evaluation(pred_label, actual_label, title):
    plt.figure(figsize=(15, 7), dpi=200)
    sns.heatmap(pred_label.detach().cpu() == actual_label, cbar=True, cmap="binary_r")
    plt.xlabel("Sentence Length")
    plt.ylabel("Sentence")
    plt.title(title)
    plt.savefig(f"{root_path}/heatmap_{title.lower()}.jpg", dpi=200)
    plt.show()

train_actual_label = train_dataloader.dataset.tensors[1]
val_actual_label = val_dataloader.dataset.tensors[1]
test_actual_label = test_dataloader.dataset.tensors[1]

viz_evaluation(train_pred_label, train_actual_label, f"Training (F1-Score: {(train_f1_score):.4f})")
viz_evaluation(val_pred_label, val_actual_label, f"Validation (F1-Score: {(val_f1_score):.4f})")
viz_evaluation(test_pred_label, test_actual_label, f"Test (F1-Score: {(test_f1_score):.4f})")

# %% [markdown]
# ## Confusion Matrix

# %%
def confusion_matrix(pred_class, actual_class, title, normalize=None):
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize=normalize)
    plt.figure(figsize=(20, 10), dpi=200)
    sns.heatmap(conf_mat(pred_class.detach().cpu(), actual_class), annot=True, fmt=".2g", xticklabels=list(label_to_idx.keys()), yticklabels=list(label_to_idx.keys()));
    plt.yticks(rotation=0)
    plt.title(title)
    plt.xlabel("Actual Class")
    plt.ylabel("Predict Class")
    plt.savefig(f"{root_path}/conf_matrix_{title.lower()}.jpg", dpi=200)

confusion_matrix(train_pred_label, train_actual_label, "Training", "pred")
confusion_matrix(val_pred_label,val_actual_label, "Validation", "pred")
confusion_matrix(test_pred_label, test_actual_label, "Test", "pred")
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 144 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)

# %% [markdown]
# ## Prediction Table

# %%
def number_wrong_pred_each_class(pred_class, actual_class):
    classes, count_class = actual_class.flatten().unique(return_counts=True)
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize="none")
    correct_pred_count_class = conf_mat(pred_class.detach().cpu(), actual_class).diag()
    
    correct_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (correct_pred_count_class))}
    wrong_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (count_class - correct_pred_count_class))}
    
    return correct_pred, wrong_pred

correct_pred, wrong_pred = number_wrong_pred_each_class(train_pred_label, train_actual_label)
print(f"| {'Number class'.ljust(14)} | {'Correct prediction'.ljust(12)} | {'Wrong prediction'.ljust(12)} |")
for (label_correct_pred, count_correct_pred), (label_wrong_pred, count_wrong_pred) in zip(correct_pred.items(), wrong_pred.items()):
    print(f"| {str(label_correct_pred).ljust(6)}: {str(count_correct_pred + count_wrong_pred).ljust(7)}| {label_correct_pred.ljust(6)}: {str(count_correct_pred).ljust(10)} | {label_wrong_pred.ljust(6)}: {str(count_wrong_pred).ljust(8)} |")
# Out:
# | Number class   | Correct prediction | Wrong prediction |
# | CC    : 5346   | CC    : 5205       | CC    : 141      |
# | CD    : 12730  | CD    : 12585      | CD    : 145      |
# | DT    : 269    | DT    : 0          | DT    : 269      |
# | FW    : 1614   | FW    : 1465       | FW    : 149      |
# | IN    : 15342  | IN    : 15232      | IN    : 110      |
# | JJ    : 6981   | JJ    : 6624       | JJ    : 357      |
# | MD    : 3799   | MD    : 3715       | MD    : 84       |
# | NEG   : 1118   | NEG   : 0          | NEG   : 1118     |
# | NN    : 44369  | NN    : 43830      | NN    : 539      |
# | NND   : 1047   | NND   : 919        | NND   : 128      |
# | NNP   : 25175  | NNP   : 24745      | NNP   : 430      |
# | OD    : 524    | OD    : 23         | OD    : 501      |
# | PR    : 3880   | PR    : 3848       | PR    : 32       |
# | PRP   : 5471   | PRP   : 5401       | PRP   : 70       |
# | RB    : 3477   | RB    : 3287       | RB    : 190      |
# | RP    : 141    | RP    : 0          | RP    : 141      |
# | SC    : 9455   | SC    : 9185       | SC    : 270      |
# | SYM   : 1551   | SYM   : 1497       | SYM   : 54       |
# | UH    : 21     | UH    : 0          | UH    : 21       |
# | VB    : 22950  | VB    : 22624      | VB    : 326      |
# | WH    : 184    | WH    : 0          | WH    : 184      |
# | X     : 279    | X     : 0          | X     : 279      |
# | Z     : 18960  | Z     : 18958      | Z     : 2        |
# | <PAD> : 407521 | <PAD> : 407521     | <PAD> : 0        |

# %%
train_actual_label[308], train_pred_label[308]
# Out:
# (tensor([ 8,  3, 12, 19,  8,  8,  8, 16, 19,  4, 10,  8, 10,  0,  4,  1,  8,  8,
#           8,  5,  4,  8, 10,  0, 10, 10, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23]),
#  tensor([ 8,  8, 12, 19,  8,  8,  5, 16, 19,  4, 10,  8, 10,  0,  4,  1,  8,  8,
#           8,  5,  4,  8, 10,  0, 10, 10, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23], device='cuda:0'))

# %%
train_actual_label[308] == train_pred_label[308].detach().cpu()
# Out:
# tensor([ True, False,  True,  True,  True,  True, False,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True])

# %% [markdown]
# ## OOV prediction is correct

# %%
def oov_flag_token(sentences, max_seq_len=hyperparams.max_seq_len):
    sent_copy = deepcopy(sentences)
    sent = []
    oov_flag = []
    
    for sentence in tqdm(sent_copy):
        for token in sentence:
            sent.append(token[2])
        
        for _ in range(max_seq_len- len(sentence)):
            sent.append(False)
        
        oov_flag.append(sent)
        sent = []
        
    return np.array(oov_flag)

train_oov_flag = oov_flag_token(train_sentences, max_seq_len=hyperparams.max_seq_len)
val_oov_flag = oov_flag_token(val_sentences, max_seq_len=hyperparams.max_seq_len)
test_oov_flag = oov_flag_token(test_sentences, max_seq_len=hyperparams.max_seq_len)

def pencentage_oov_pred_correct(pred_oov_flag, oov_flag_tensor):
    oov_correct_counter = 0
    oov_wrong_counter = 0

    for pred, oov_label in tqdm(zip(pred_oov_flag, oov_flag_tensor)):
        if pred == True and oov_label == True:
            oov_correct_counter += 1
        elif pred == False and oov_label == True:
            oov_wrong_counter += 1
        else:
            continue
            
    return oov_correct_counter, oov_wrong_counter

train_pred_oov_flag = (train_actual_label == train_pred_label.detach().cpu()).flatten()
val_pred_oov_flag = (val_actual_label == val_pred_label.detach().cpu()).flatten()
test_pred_oov_flag = (test_actual_label == test_pred_label.detach().cpu()).flatten()
train_oov_flag_tensor = torch.tensor(train_oov_flag).flatten()
val_oov_flag_tensor = torch.tensor(val_oov_flag).flatten()
test_oov_flag_tensor = torch.tensor(test_oov_flag).flatten()

train_oov_correct_counter, train_oov_wrong_counter = pencentage_oov_pred_correct(train_pred_oov_flag, train_oov_flag_tensor)
val_oov_correct_counter, val_oov_wrong_counter = pencentage_oov_pred_correct(val_pred_oov_flag, val_oov_flag_tensor)
test_oov_correct_counter, test_oov_wrong_counter = pencentage_oov_pred_correct(test_pred_oov_flag, test_oov_flag_tensor)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
def print_percentage_pred_oov(title, oov_correct_counter, oov_wrong_counter):
    print(f"{title}")
    print(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}")
    print(f"Correct prediction          : {oov_correct_counter}")
    print(f"Wrong prediction            : {oov_wrong_counter}")
    print(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n")
    
    with open(f"{root_path}/oov_summary.txt", "a") as f:
        f.write(f"{title}\n")
        f.write(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}\n")
        f.write(f"Correct prediction          : {oov_correct_counter}\n")
        f.write(f"Wrong prediction            : {oov_wrong_counter}\n")
        f.write(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n\n")

# %%
print_percentage_pred_oov("Training", train_oov_correct_counter, train_oov_wrong_counter)
print_percentage_pred_oov("Validation", val_oov_correct_counter, val_oov_wrong_counter)
print_percentage_pred_oov("Test", test_oov_correct_counter, test_oov_wrong_counter)
# Out:
# Training
# Number OOV token            : 11806
# Correct prediction          : 11141
# Wrong prediction            : 665
# Percentage correct oov pred : 94.36727087921396
#
# Validation
# Number OOV token            : 3366
# Correct prediction          : 2993
# Wrong prediction            : 373
# Percentage correct oov pred : 88.91859774212716
#
# Test
# Number OOV token            : 1390
# Correct prediction          : 1235
# Wrong prediction            : 155
# Percentage correct oov pred : 88.84892086330936

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(train_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(val_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(test_oov_flag, cmap=plt.cm.binary_r);
