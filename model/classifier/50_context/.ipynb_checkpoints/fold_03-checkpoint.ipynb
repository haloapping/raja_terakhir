# %% [markdown]
# # Import modules

# %%
import csv
import os
import pickle
import pytz
import torch
import timeit
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from copy import deepcopy
from datetime import datetime
from einops import rearrange
from itertools import chain
from time import time
from torch import nn, optim
from torchmetrics.classification import MulticlassAccuracy, MulticlassF1Score, MulticlassConfusionMatrix
from torch.optim import lr_scheduler
from tqdm.notebook import tqdm
from torch.utils.data import TensorDataset, DataLoader
from polyglot.mapping import Embedding, CaseExpander, DigitExpander

# %% [markdown]
# # Hyperparameters

# %%
class Hyperparams:
     def __init__(
        self,
        context_size=50,
        fold=3,
        max_seq_len=82,
        input_size=64,
        batch_size=32,
        num_hidden_layer=1,
        hidden_size=128,
        dropout=0,
        bias=True,
        output_size=24,
        shuffle=True,
        lr=0.005,
        batch_first=False,
        bidirectional=True,
        init_wb_with_kaiming_normal=True,
        n_epoch=50,
        patience=50,
        device="cuda" if torch.cuda.is_available() else "cpu"
    ):
        self.context_size = context_size
        self.fold = fold
        self.input_size = input_size
        self.max_seq_len = max_seq_len
        self.batch_size = batch_size
        self.num_hidden_layer = num_hidden_layer
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.output_size = output_size
        self.shuffle = shuffle
        self.lr = lr
        self.batch_first = batch_first
        self.bidirectional = bidirectional
        self.init_wb_with_kaiming_normal = init_wb_with_kaiming_normal
        self.n_epoch = n_epoch
        self.patience = patience
        self.device = device

hyperparams = Hyperparams()

# %% [markdown]
# # Dataset

# %%
id_pos_tag = pd.read_csv("../../../datasets/raw/Indonesian_Manually_Tagged_Corpus.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False) 
train = pd.read_csv(f"../../../datasets/raw/cv/train/train.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
val = pd.read_csv(f"../../../datasets/raw/cv/val/val.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
test = pd.read_csv(f"../../../datasets/raw/cv/test/test.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)

# %% [markdown]
# # Pre-trained Word Embedding

# %%
embeddings = Embedding.load("../../../word_embeddings/polyglot/idn_embeddings.tar.bz2")
embeddings.apply_expansion(DigitExpander)
embeddings.apply_expansion(CaseExpander)

oov_embeddings = pickle.load(open(f"../../../logs/comick/{hyperparams.context_size}_contexts/10-11-2022_15-24-28/oov_embedding_dict.pkl", "rb"))

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Add OOV Flag

# %%
def add_oov_flag(tokens, embeddings):
    oov_flags = []
    
    for token in tqdm(tokens):
        try:
            if token not in embeddings:
                oov_flags.append(True)
            else:
                oov_flags.append(False)
        except:
            oov_flags.append(False)
        
    return pd.DataFrame(oov_flags, columns=["is_oov"])

id_pos_tag_oov_flags = add_oov_flag(id_pos_tag["token"].values, embeddings)
train_oov_flags = add_oov_flag(train["token"].values, embeddings)
val_oov_flags = add_oov_flag(val["token"].values, embeddings)
test_oov_flags = add_oov_flag(test["token"].values, embeddings)
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/192215 [00:00<?, ?it/s]
#   0%|          | 0/21143 [00:00<?, ?it/s]
#   0%|          | 0/53294 [00:00<?, ?it/s]

# %% [markdown]
# ## Concate OOV Flag

# %%
id_pos_tag_df = pd.concat([id_pos_tag, id_pos_tag_oov_flags], axis=1)
train_df = pd.concat([train, train_oov_flags], axis=1)
val_df = pd.concat([val, val_oov_flags], axis=1)
test_df = pd.concat([test, test_oov_flags], axis=1)

# %% [markdown]
# ## Lowercase OOV Token

# %%
id_pos_tag_df['token'] = np.where(id_pos_tag_df['is_oov'] == True, id_pos_tag_df['token'].str.lower(), id_pos_tag_df['token'])
train_df['token'] = np.where(train_df['is_oov'] == True, train_df['token'].str.lower(), train_df['token'])
val_df['token'] = np.where(val_df['is_oov'] == True, val_df['token'].str.lower(), val_df['token'])
test_df['token'] = np.where(test_df['is_oov'] == True, test_df['token'].str.lower(), test_df['token'])

# %% [markdown]
# ## Embedding Dict, Index to Token and Token to Index

# %%
tokens = list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None))

def embedding_dict(tokens, embeddings, oov_embeddings):
    embedding = {}
    
    for token in tokens:
        if token[0] is not np.nan:
            if token[2] == False or token[0] in embeddings:
                embedding[token[0]] = embeddings[token[0]]
            else:
                embedding[token[0]] = oov_embeddings[token[0].lower()]

    return embedding

embedding_dict = embedding_dict(tokens, embeddings, oov_embeddings)
embedding_dict["<PAD>"] = embeddings["<PAD>"]
word_embeddings = nn.Embedding.from_pretrained(torch.FloatTensor(np.array(list(embedding_dict.values()))), padding_idx=list(embedding_dict.keys()).index("<PAD>"), freeze=True)

idx_to_token = {idx: token for idx, token in enumerate(list(embedding_dict.keys()))}
token_to_idx = {token: idx for idx, token in enumerate(list(embedding_dict.keys()))}

# %% [markdown]
# ## Token to Sentence

# %%
def make_sentence(tokens, max_length_sentence=hyperparams.max_seq_len):
    sentence = []
    sentences = []

    for token in tqdm(tokens):
        if token[0] is not np.nan:
            sentence.append(token)
        else:
            sentences.append(sentence[:max_length_sentence])
            sentence = []

    return sentences

all_sentence = make_sentence(list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
train_sentences = make_sentence(list(train_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
val_sentences = make_sentence(list(test_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
test_sentences = make_sentence(list(val_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/192215 [00:00<?, ?it/s]
#   0%|          | 0/53294 [00:00<?, ?it/s]
#   0%|          | 0/21143 [00:00<?, ?it/s]

# %% [markdown]
# ## Word Token, Padding, and Word token to Index

# %%
def tokenize_docs(docs, idx_token):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token[idx_token])
        sentences.append(new_sentence)
        new_sentence = []

    return sentences

def padding(docs, max_seq_len=hyperparams.max_seq_len, mode="post", val_pad="<PAD>"):
    docs = deepcopy(docs)
    doc_with_pad = []
    docs_with_pad = []

    for doc in tqdm(docs):
        if mode == "pre":
            for _ in range(max_seq_len - len(doc)):
                doc.insert(0, val_pad)
        elif mode == "post":
            for _ in range(max_seq_len - len(doc)):
                doc.append(val_pad)
        else:
            return f"Mode {mode} is not available, use instead 'pre' or 'post'."
        
        docs_with_pad.append(doc)
        
    return np.array(docs_with_pad)

def sent_to_idx(docs, token_to_idx):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token_to_idx[token])
        sentences.append(new_sentence)
        new_sentence = []

    return np.array(sentences)

def convert_feature_to_idx(docs, idx_token, token_to_idx, max_seq_len):
    sentences = tokenize_docs(docs, idx_token)
    sentences_with_pad = padding(sentences, max_seq_len=max_seq_len, mode="post", val_pad="<PAD>")
    sentences_to_idx = sent_to_idx(sentences_with_pad, token_to_idx)
    
    return sentences_to_idx

train_sentence_idxs = convert_feature_to_idx(train_sentences, 0, token_to_idx, hyperparams.max_seq_len)
val_sentence_idxs = convert_feature_to_idx(val_sentences, 0, token_to_idx, hyperparams.max_seq_len)
test_sentence_idxs = convert_feature_to_idx(test_sentences, 0, token_to_idx, hyperparams.max_seq_len)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]

# %% [markdown]
# ## Encode Class

# %%
classes = sorted(np.delete(id_pos_tag_df["tag"].unique(), 3))
idx_to_label = {idx: label for idx, label in enumerate(classes + ["<PAD>"])}
label_to_idx = {label: idx for idx, label in enumerate(classes + ["<PAD>"])}

def encode_class(docs, label_to_idx, seq_len=hyperparams.max_seq_len):
    class_idxs = []
    classes = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            class_idxs.append(label_to_idx[token[1]])
            
        for _ in range(seq_len - len(sentence)):
            class_idxs.append(label_to_idx["<PAD>"])
                
        classes.append(class_idxs)
        class_idxs = []

    return np.array(classes)
        
train_class_idxs = encode_class(train_sentences, label_to_idx)
val_class_idxs = encode_class(val_sentences, label_to_idx)
test_class_idxs = encode_class(test_sentences, label_to_idx)

print(f"Training shape   : {train_sentence_idxs.shape, train_class_idxs.shape}")
print(f"validation shape : {val_class_idxs.shape, val_class_idxs.shape}")
print(f"Test shape       : {test_sentence_idxs.shape, test_class_idxs.shape}")
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# Training shape   : ((7222, 82), (7222, 82))
# validation shape : ((2006, 82), (2006, 82))
# Test shape       : ((802, 82), (802, 82))

# %% [markdown]
# ## Note
#
# - Number of sentences = 10030
# - Train : 72% (7222)
# - Val   : 8% (802)
# - Test  : 20% (2006)

# %% [markdown]
# # Build Model

# %% [markdown]
# ## Feature and Actual Class

# %%
train_feature = torch.LongTensor(train_sentence_idxs)
val_feature = torch.LongTensor(val_sentence_idxs)
test_feature = torch.LongTensor(test_sentence_idxs)

train_class = torch.LongTensor(train_class_idxs)
val_class = torch.LongTensor(val_class_idxs)
test_class = torch.LongTensor(test_class_idxs)

# %%
train_feature.shape, val_feature.shape, test_feature.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %%
train_class.shape, val_class.shape, test_class.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %% [markdown]
# ## Tensor Dataset

# %%
train_dataset = TensorDataset(train_feature, train_class)
val_dataset = TensorDataset(val_feature, val_class)
test_dataset = TensorDataset(test_feature, test_class)

# %% [markdown]
# ## Dataloader

# %%
train_dataloader = DataLoader(train_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
val_dataloader = DataLoader(val_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
test_dataloader = DataLoader(test_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)

# %% [markdown]
# ## Model

# %%
class POSTagger(nn.Module):
    def __init__(
        self,
        input_size=hyperparams.input_size,
        hidden_size=hyperparams.hidden_size,
        dropout=hyperparams.dropout,
        bias=hyperparams.bias,
        num_layers=hyperparams.num_hidden_layer,
        output_size=hyperparams.output_size,
        batch_first=hyperparams.batch_first,
        bidirectional=hyperparams.bidirectional,
        init_wb_with_kaiming_normal=hyperparams.init_wb_with_kaiming_normal
    ):
        super(POSTagger, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.num_layers = num_layers
        self.output_size = output_size
        self.batch_first = batch_first
        self.bidirectional = bidirectional
                
        self.feature = nn.LSTM(
            input_size = self.input_size,
            hidden_size = self.hidden_size,
            bias = self.bias,
            dropout = self.dropout,
            num_layers = self.num_layers,
            batch_first = self.batch_first,
            bidirectional = self.bidirectional
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(in_features=2 * self.hidden_size if hyperparams.bidirectional else self.hidden_size, out_features=self.output_size, bias=self.bias),
            nn.Softmax(dim=-1)
        )
        
        if init_wb_with_kaiming_normal:
            self.init_wb()

    def init_wb(self):
        for module in self.modules():
            if isinstance(module, (nn.Linear, nn.LSTM)):
                for name, param in module.named_parameters():
                    if "weight" in name:
                        nn.init.kaiming_normal_(param)
                    else:
                        nn.init.kaiming_normal_(param.reshape(1, -1))
        
    def forward(self, feature, hidden=None):
        output, (hidden, memory) = self.feature(feature, None)
        prob = self.classifier(output)

        return prob
    
model = POSTagger().to(hyperparams.device)
model
# Out:
# POSTagger(
#   (feature): LSTM(64, 128, bidirectional=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=24, bias=True)
#     (1): Softmax(dim=-1)
#   )
# )

# %% [markdown]
# ## Optimizer, Criterion, and Metric

# %%
optimizer = optim.Adam(model.parameters(), lr=hyperparams.lr)
criterion = nn.CrossEntropyLoss().to(hyperparams.device)
train_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", verbose=True, factor=0.5)

# %%
sum(param.numel() for param in model.parameters() if param.requires_grad)
# Out:
# 204824

# %% [markdown]
# ## Training Step

# %%
def training_step(dataloader, model, optimizer, criterion, metric, scheduler=None):
    model.train()
    
    batch_losses = []
    batch_metric_scores = []
    
    for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
        # Forward Propagation
        feature = rearrange(feature, "n s -> s n")
        actual_label = rearrange(actual_label, "n s -> s n")
        embedding = word_embeddings(feature)
        
        prob = model(
            embedding.to(hyperparams.device),
            actual_label.to(hyperparams.device)
        )
        
        prob = prob.reshape(-1, prob.shape[-1])
        actual_label = actual_label.reshape(-1)

        loss = criterion(prob, actual_label.to(hyperparams.device))
        metric_score = metric(prob, actual_label.to(hyperparams.device))
        metric_score = metric.compute()
                
        if scheduler is not None:
            scheduler.step(loss)
        
        batch_losses.append(loss.item())
        batch_metric_scores.append(metric_score)
        
        if len(dataloader) < 10:
            if batch % 1 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
        else:
            if batch % 15 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            
        # Backward Propagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Validation Step

# %%
def validation_step(dataloader, model, criterion, metric):
    model.eval()
    
    batch_losses = []
    batch_metric_scores = []
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob, actual_label.to(hyperparams.device))
            metric_score = metric.compute()

            batch_losses.append(loss.item())
            batch_metric_scores.append(metric_score)
            
            if len(dataloader) < 10 and (batch % 1 == 0 or batch == len(dataloader)):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            else:
                if batch % 15 == 0 or batch == len(dataloader):
                    batch_name = "Batch-" + str(batch)
                    print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                    with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                        f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Looping Step

# %%
now = datetime.now(pytz.timezone("Asia/Ujung_Pandang"))
path_name = now.strftime("%m-%d-%Y_%H-%M-%S")
root_path = f"../../../logs/classifier/{hyperparams.context_size}_contexts/fold_0{hyperparams.fold}/{path_name}"
os.makedirs(root_path)

def looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric, n_epoch=hyperparams.n_epoch, patience=hyperparams.patience, monitor="loss"):    
    start_time = time()
    
    epoch_training_losses = []
    epoch_training_metric_scores = []
    epoch_val_losses = []
    epoch_val_metric_scores = []
    patience_counter = 0
    
    # Hyperparameters
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write(f"HYPERPARAMETERS\n")
        f.write(f"{'-' * 80}\n")
        for name, value in vars(hyperparams).items():
            f.write(f"{name}: {value}\n")
        
        f.write("\n\nTRAINING PROGRESS\n")
        f.write(f"{'-' * 80}\n")
    
    # Training Progress
    for epoch in range(1, n_epoch + 1):
        print(f"EPOCH-{epoch}")
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"EPOCH-{epoch}\n")
            f.write(f"Training Step\n")
            
        # Training Step
        print("Training Step")
        batch_training_losses, batch_training_metric_scores = training_step(train_dataloader, model, optimizer, criterion, train_metric, scheduler=None)
        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))

        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))
        epoch_training_losses.append(epoch_training_loss.item())

        epoch_training_metric_score = torch.mean(torch.FloatTensor(batch_training_metric_scores))
        epoch_training_metric_scores.append(epoch_training_metric_score.item())
        
        # Validation Step
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"\nValidation Step\n")
            
        print("\nValidation Step")
        batch_val_losses, batch_val_metric_scores = validation_step(val_dataloader, model, criterion, val_metric)
        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))

        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))
        epoch_val_losses.append(epoch_val_loss.item())

        epoch_val_metric_score = torch.mean(torch.FloatTensor(batch_val_metric_scores))
        epoch_val_metric_scores.append(epoch_val_metric_score.item())
        
        with open(f"{root_path}/training_history.txt", "a") as f:
            if monitor == "loss":
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_losses[-1] < epoch_training_losses[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
            else:
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_metric_scores[-1] > epoch_training_metric_scores[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗\n")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
                    
            print("=" * 80, end="\n\n")
            
            f.write(f"{'=' * 80}\n\n")
            
            if patience_counter == patience:
                print(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                
                f.write(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                break
        
        train_metric.reset()
        val_metric.reset()
        
    finish_time = time()
    
    # Training plot 
    fig, (ax_loss, ax_metric_score) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    fig.suptitle(f"Training with context size = {hyperparams.context_size}")

    ax_loss.set_title("Loss")
    ax_loss.set_xlabel("Epoch")
    ax_loss.set_ylabel("Score")
    ax_loss.plot(epoch_training_losses, "green", label="Training")
    ax_loss.plot(epoch_val_losses, "orange", label="Validation")
    ax_loss.legend()
    ax_loss.grid()

    ax_metric_score.set_title("F1 Score")
    ax_metric_score.set_xlabel("Epoch")
    ax_metric_score.set_ylabel("Score")
    ax_metric_score.plot(epoch_training_metric_scores, "green", label="Training")
    ax_metric_score.plot(epoch_val_metric_scores, "orange", label="Validation")
    ax_metric_score.legend()
    ax_metric_score.grid()

    plt.savefig(f"{root_path}/training_plot.jpg", dpi=200)                        
    
    print("TRAINING SUMMARY")
    name_best_training_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_training_metric = f"Best {str(train_metric).split('(')[0]} validation".ljust(34)
    name_best_validation_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_validation_metric = f"Best {str(val_metric).split('(')[0]} validation".ljust(34)
    name_training_time = f"Training duration".ljust(34)
    name_training_date = f"Training date".ljust(34)
    
    print(f"{name_best_training_loss}: {best_training_loss:.4f}")
    print(f"{name_best_validation_loss}: {best_val_loss:.4f}")
    print(f"{name_best_training_metric}: {best_training_metric:.4f}")
    print(f"{name_best_validation_metric}: {best_val_metric:.4f}")
    print(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.")
    print(f"{name_training_date}: {now}")
    
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write("\nTRAINING SUMMARY\n")
        f.write(f"{'-' * 80}\n")
        f.write(f"{name_best_training_loss}: {best_training_loss:.4f}\n")
        f.write(f"{name_best_validation_loss}: {best_val_loss:.4f}\n")
        f.write(f"{name_best_training_metric}: {best_training_metric:.4f}\n")
        f.write(f"{name_best_validation_metric}: {best_val_metric:.4f}\n")
        f.write(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.\n")
        f.write(f"{name_training_date}: {now}\n")
    
    # Save epoch losses, epoch metric scores, model, state dict, and oov embedding dict
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_training_losses
    }).to_csv(f"{root_path}/training_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_training_metric_scores
    }).to_csv(f"{root_path}/training_metric_scores.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_val_losses
    }).to_csv(f"{root_path}/val_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_val_metric_scores
    }).to_csv(f"{root_path}/val_metric_scores.csv", index=False)    
    
    filename_model_params = f"{root_path}/model_params.pth"
    torch.save(best_state_dict, filename_model_params)
    
    return epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores

epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores = looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric)
# Out:
# EPOCH-1
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.5308 | MulticlassF1Score=0.0944
# Batch-30 : CrossEntropyLoss=2.4658 | MulticlassF1Score=0.1795
# Batch-45 : CrossEntropyLoss=2.4554 | MulticlassF1Score=0.2538
# Batch-60 : CrossEntropyLoss=2.3743 | MulticlassF1Score=0.3165
# Batch-75 : CrossEntropyLoss=2.3883 | MulticlassF1Score=0.3679
# Batch-90 : CrossEntropyLoss=2.3723 | MulticlassF1Score=0.4036
# Batch-105: CrossEntropyLoss=2.3742 | MulticlassF1Score=0.4294
# Batch-120: CrossEntropyLoss=2.4130 | MulticlassF1Score=0.4488
# Batch-135: CrossEntropyLoss=2.3719 | MulticlassF1Score=0.4637
# Batch-150: CrossEntropyLoss=2.3919 | MulticlassF1Score=0.4749
# Batch-165: CrossEntropyLoss=2.3445 | MulticlassF1Score=0.4891
# Batch-180: CrossEntropyLoss=2.3515 | MulticlassF1Score=0.5033
# Batch-195: CrossEntropyLoss=2.3673 | MulticlassF1Score=0.5161
# Batch-210: CrossEntropyLoss=2.3561 | MulticlassF1Score=0.5275
# Batch-225: CrossEntropyLoss=2.3229 | MulticlassF1Score=0.5400
# Batch-226: CrossEntropyLoss=2.3450 | MulticlassF1Score=0.5405
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3399 | MulticlassF1Score=0.7043
# Batch-30 : CrossEntropyLoss=2.3306 | MulticlassF1Score=0.7079
# Batch-45 : CrossEntropyLoss=2.3501 | MulticlassF1Score=0.7083
# Batch-60 : CrossEntropyLoss=2.3375 | MulticlassF1Score=0.7088
# Batch-63 : CrossEntropyLoss=2.3538 | MulticlassF1Score=0.7090
#
# Training   : Mean CrossEntropyLoss = 2.4028 | Mean MulticlassF1Score = 0.3888
# Validation : Mean CrossEntropyLoss = 2.3405 | Mean MulticlassF1Score = 0.7067
# ================================================================================
#
# EPOCH-2
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3385 | MulticlassF1Score=0.7110
# Batch-30 : CrossEntropyLoss=2.3289 | MulticlassF1Score=0.7146
# Batch-45 : CrossEntropyLoss=2.3489 | MulticlassF1Score=0.7130
# Batch-60 : CrossEntropyLoss=2.3349 | MulticlassF1Score=0.7139
# Batch-75 : CrossEntropyLoss=2.3456 | MulticlassF1Score=0.7153
# Batch-90 : CrossEntropyLoss=2.3312 | MulticlassF1Score=0.7150
# Batch-105: CrossEntropyLoss=2.3361 | MulticlassF1Score=0.7151
# Batch-120: CrossEntropyLoss=2.3289 | MulticlassF1Score=0.7156
# Batch-135: CrossEntropyLoss=2.3316 | MulticlassF1Score=0.7174
# Batch-150: CrossEntropyLoss=2.3368 | MulticlassF1Score=0.7178
# Batch-165: CrossEntropyLoss=2.3310 | MulticlassF1Score=0.7179
# Batch-180: CrossEntropyLoss=2.3382 | MulticlassF1Score=0.7187
# Batch-195: CrossEntropyLoss=2.3388 | MulticlassF1Score=0.7192
# Batch-210: CrossEntropyLoss=2.3386 | MulticlassF1Score=0.7191
# Batch-225: CrossEntropyLoss=2.3439 | MulticlassF1Score=0.7193
# Batch-226: CrossEntropyLoss=2.3247 | MulticlassF1Score=0.7193
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3200 | MulticlassF1Score=0.7338
# Batch-30 : CrossEntropyLoss=2.3370 | MulticlassF1Score=0.7295
# Batch-45 : CrossEntropyLoss=2.3215 | MulticlassF1Score=0.7291
# Batch-60 : CrossEntropyLoss=2.3411 | MulticlassF1Score=0.7275
# Batch-63 : CrossEntropyLoss=2.3309 | MulticlassF1Score=0.7263
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3357 | Mean MulticlassF1Score = 0.7162
# Validation : Mean CrossEntropyLoss = 2.3331 | Mean MulticlassF1Score = 0.7298
# ================================================================================
#
# EPOCH-3
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3265 | MulticlassF1Score=0.7345
# Batch-30 : CrossEntropyLoss=2.3220 | MulticlassF1Score=0.7354
# Batch-45 : CrossEntropyLoss=2.3156 | MulticlassF1Score=0.7463
# Batch-60 : CrossEntropyLoss=2.3265 | MulticlassF1Score=0.7546
# Batch-75 : CrossEntropyLoss=2.3191 | MulticlassF1Score=0.7607
# Batch-90 : CrossEntropyLoss=2.3161 | MulticlassF1Score=0.7659
# Batch-105: CrossEntropyLoss=2.3043 | MulticlassF1Score=0.7696
# Batch-120: CrossEntropyLoss=2.3063 | MulticlassF1Score=0.7731
# Batch-135: CrossEntropyLoss=2.3142 | MulticlassF1Score=0.7754
# Batch-150: CrossEntropyLoss=2.3098 | MulticlassF1Score=0.7765
# Batch-165: CrossEntropyLoss=2.3154 | MulticlassF1Score=0.7777
# Batch-180: CrossEntropyLoss=2.3122 | MulticlassF1Score=0.7792
# Batch-195: CrossEntropyLoss=2.3157 | MulticlassF1Score=0.7798
# Batch-210: CrossEntropyLoss=2.3000 | MulticlassF1Score=0.7813
# Batch-225: CrossEntropyLoss=2.3177 | MulticlassF1Score=0.7821
# Batch-226: CrossEntropyLoss=2.3058 | MulticlassF1Score=0.7822
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3173 | MulticlassF1Score=0.7964
# Batch-30 : CrossEntropyLoss=2.3086 | MulticlassF1Score=0.7936
# Batch-45 : CrossEntropyLoss=2.3042 | MulticlassF1Score=0.7955
# Batch-60 : CrossEntropyLoss=2.3057 | MulticlassF1Score=0.7940
# Batch-63 : CrossEntropyLoss=2.3154 | MulticlassF1Score=0.7942
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3159 | Mean MulticlassF1Score = 0.7645
# Validation : Mean CrossEntropyLoss = 2.3118 | Mean MulticlassF1Score = 0.7970
# ================================================================================
#
# EPOCH-4
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3148 | MulticlassF1Score=0.7941
# Batch-30 : CrossEntropyLoss=2.3147 | MulticlassF1Score=0.7932
# Batch-45 : CrossEntropyLoss=2.3048 | MulticlassF1Score=0.7939
# Batch-60 : CrossEntropyLoss=2.2933 | MulticlassF1Score=0.7944
# Batch-75 : CrossEntropyLoss=2.3086 | MulticlassF1Score=0.7964
# Batch-90 : CrossEntropyLoss=2.3049 | MulticlassF1Score=0.7951
# Batch-105: CrossEntropyLoss=2.2975 | MulticlassF1Score=0.7962
# Batch-120: CrossEntropyLoss=2.3117 | MulticlassF1Score=0.7981
# Batch-135: CrossEntropyLoss=2.3013 | MulticlassF1Score=0.7996
# Batch-150: CrossEntropyLoss=2.3106 | MulticlassF1Score=0.8013
# Batch-165: CrossEntropyLoss=2.3097 | MulticlassF1Score=0.8036
# Batch-180: CrossEntropyLoss=2.3003 | MulticlassF1Score=0.8058
# Batch-195: CrossEntropyLoss=2.3017 | MulticlassF1Score=0.8075
# Batch-210: CrossEntropyLoss=2.2984 | MulticlassF1Score=0.8091
# Batch-225: CrossEntropyLoss=2.2992 | MulticlassF1Score=0.8103
# Batch-226: CrossEntropyLoss=2.3147 | MulticlassF1Score=0.8103
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3050 | MulticlassF1Score=0.8298
# Batch-30 : CrossEntropyLoss=2.3031 | MulticlassF1Score=0.8272
# Batch-45 : CrossEntropyLoss=2.3061 | MulticlassF1Score=0.8274
# Batch-60 : CrossEntropyLoss=2.2975 | MulticlassF1Score=0.8265
# Batch-63 : CrossEntropyLoss=2.2929 | MulticlassF1Score=0.8263
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3069 | Mean MulticlassF1Score = 0.7992
# Validation : Mean CrossEntropyLoss = 2.3018 | Mean MulticlassF1Score = 0.8278
# ================================================================================
#
# EPOCH-5
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2946 | MulticlassF1Score=0.8319
# Batch-30 : CrossEntropyLoss=2.2955 | MulticlassF1Score=0.8331
# Batch-45 : CrossEntropyLoss=2.3039 | MulticlassF1Score=0.8321
# Batch-60 : CrossEntropyLoss=2.3006 | MulticlassF1Score=0.8308
# Batch-75 : CrossEntropyLoss=2.2929 | MulticlassF1Score=0.8302
# Batch-90 : CrossEntropyLoss=2.3139 | MulticlassF1Score=0.8310
# Batch-105: CrossEntropyLoss=2.3036 | MulticlassF1Score=0.8307
# Batch-120: CrossEntropyLoss=2.3060 | MulticlassF1Score=0.8292
# Batch-135: CrossEntropyLoss=2.3041 | MulticlassF1Score=0.8292
# Batch-150: CrossEntropyLoss=2.2983 | MulticlassF1Score=0.8296
# Batch-165: CrossEntropyLoss=2.3048 | MulticlassF1Score=0.8292
# Batch-180: CrossEntropyLoss=2.2957 | MulticlassF1Score=0.8293
# Batch-195: CrossEntropyLoss=2.3051 | MulticlassF1Score=0.8291
# Batch-210: CrossEntropyLoss=2.3005 | MulticlassF1Score=0.8287
# Batch-225: CrossEntropyLoss=2.2932 | MulticlassF1Score=0.8285
# Batch-226: CrossEntropyLoss=2.2916 | MulticlassF1Score=0.8285
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2962 | MulticlassF1Score=0.8239
# Batch-30 : CrossEntropyLoss=2.3027 | MulticlassF1Score=0.8238
# Batch-45 : CrossEntropyLoss=2.3009 | MulticlassF1Score=0.8277
# Batch-60 : CrossEntropyLoss=2.2949 | MulticlassF1Score=0.8267
# Batch-63 : CrossEntropyLoss=2.2971 | MulticlassF1Score=0.8263
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3011 | Mean MulticlassF1Score = 0.8302
# Validation : Mean CrossEntropyLoss = 2.3015 | Mean MulticlassF1Score = 0.8249
# ================================================================================
#
# EPOCH-6
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3048 | MulticlassF1Score=0.8240
# Batch-30 : CrossEntropyLoss=2.3099 | MulticlassF1Score=0.8263
# Batch-45 : CrossEntropyLoss=2.3004 | MulticlassF1Score=0.8273
# Batch-60 : CrossEntropyLoss=2.2967 | MulticlassF1Score=0.8292
# Batch-75 : CrossEntropyLoss=2.2966 | MulticlassF1Score=0.8290
# Batch-90 : CrossEntropyLoss=2.2958 | MulticlassF1Score=0.8289
# Batch-105: CrossEntropyLoss=2.3037 | MulticlassF1Score=0.8288
# Batch-120: CrossEntropyLoss=2.2965 | MulticlassF1Score=0.8288
# Batch-135: CrossEntropyLoss=2.2981 | MulticlassF1Score=0.8289
# Batch-150: CrossEntropyLoss=2.3056 | MulticlassF1Score=0.8289
# Batch-165: CrossEntropyLoss=2.3019 | MulticlassF1Score=0.8292
# Batch-180: CrossEntropyLoss=2.2916 | MulticlassF1Score=0.8302
# Batch-195: CrossEntropyLoss=2.3010 | MulticlassF1Score=0.8304
# Batch-210: CrossEntropyLoss=2.3051 | MulticlassF1Score=0.8305
# Batch-225: CrossEntropyLoss=2.2983 | MulticlassF1Score=0.8307
# Batch-226: CrossEntropyLoss=2.2959 | MulticlassF1Score=0.8307
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2934 | MulticlassF1Score=0.8339
# Batch-30 : CrossEntropyLoss=2.3066 | MulticlassF1Score=0.8320
# Batch-45 : CrossEntropyLoss=2.3092 | MulticlassF1Score=0.8305
# Batch-60 : CrossEntropyLoss=2.2966 | MulticlassF1Score=0.8290
# Batch-63 : CrossEntropyLoss=2.2951 | MulticlassF1Score=0.8285
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3002 | Mean MulticlassF1Score = 0.8285
# Validation : Mean CrossEntropyLoss = 2.3008 | Mean MulticlassF1Score = 0.8297
# ================================================================================
#
# EPOCH-7
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2998 | MulticlassF1Score=0.8301
# Batch-30 : CrossEntropyLoss=2.2946 | MulticlassF1Score=0.8323
# Batch-45 : CrossEntropyLoss=2.3048 | MulticlassF1Score=0.8338
# Batch-60 : CrossEntropyLoss=2.3042 | MulticlassF1Score=0.8355
# Batch-75 : CrossEntropyLoss=2.3028 | MulticlassF1Score=0.8350
# Batch-90 : CrossEntropyLoss=2.3011 | MulticlassF1Score=0.8340
# Batch-105: CrossEntropyLoss=2.3066 | MulticlassF1Score=0.8331
# Batch-120: CrossEntropyLoss=2.2955 | MulticlassF1Score=0.8327
# Batch-135: CrossEntropyLoss=2.2977 | MulticlassF1Score=0.8330
# Batch-150: CrossEntropyLoss=2.2987 | MulticlassF1Score=0.8331
# Batch-165: CrossEntropyLoss=2.3007 | MulticlassF1Score=0.8337
# Batch-180: CrossEntropyLoss=2.2963 | MulticlassF1Score=0.8346
# Batch-195: CrossEntropyLoss=2.2981 | MulticlassF1Score=0.8352
# Batch-210: CrossEntropyLoss=2.2992 | MulticlassF1Score=0.8361
# Batch-225: CrossEntropyLoss=2.2927 | MulticlassF1Score=0.8370
# Batch-226: CrossEntropyLoss=2.2903 | MulticlassF1Score=0.8371
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2925 | MulticlassF1Score=0.8425
# Batch-30 : CrossEntropyLoss=2.3027 | MulticlassF1Score=0.8424
# Batch-45 : CrossEntropyLoss=2.2902 | MulticlassF1Score=0.8436
# Batch-60 : CrossEntropyLoss=2.2924 | MulticlassF1Score=0.8433
# Batch-63 : CrossEntropyLoss=2.2979 | MulticlassF1Score=0.8430
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2983 | Mean MulticlassF1Score = 0.8342
# Validation : Mean CrossEntropyLoss = 2.2967 | Mean MulticlassF1Score = 0.8413
# ================================================================================
#
# EPOCH-8
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2960 | MulticlassF1Score=0.8480
# Batch-30 : CrossEntropyLoss=2.2892 | MulticlassF1Score=0.8476
# Batch-45 : CrossEntropyLoss=2.2939 | MulticlassF1Score=0.8484
# Batch-60 : CrossEntropyLoss=2.2957 | MulticlassF1Score=0.8479
# Batch-75 : CrossEntropyLoss=2.2979 | MulticlassF1Score=0.8498
# Batch-90 : CrossEntropyLoss=2.2870 | MulticlassF1Score=0.8498
# Batch-105: CrossEntropyLoss=2.3072 | MulticlassF1Score=0.8507
# Batch-120: CrossEntropyLoss=2.2939 | MulticlassF1Score=0.8505
# Batch-135: CrossEntropyLoss=2.2852 | MulticlassF1Score=0.8530
# Batch-150: CrossEntropyLoss=2.2828 | MulticlassF1Score=0.8549
# Batch-165: CrossEntropyLoss=2.2826 | MulticlassF1Score=0.8560
# Batch-180: CrossEntropyLoss=2.2896 | MulticlassF1Score=0.8576
# Batch-195: CrossEntropyLoss=2.2918 | MulticlassF1Score=0.8587
# Batch-210: CrossEntropyLoss=2.2865 | MulticlassF1Score=0.8603
# Batch-225: CrossEntropyLoss=2.2862 | MulticlassF1Score=0.8612
# Batch-226: CrossEntropyLoss=2.2861 | MulticlassF1Score=0.8613
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2844 | MulticlassF1Score=0.8691
# Batch-30 : CrossEntropyLoss=2.2852 | MulticlassF1Score=0.8698
# Batch-45 : CrossEntropyLoss=2.2901 | MulticlassF1Score=0.8709
# Batch-60 : CrossEntropyLoss=2.2786 | MulticlassF1Score=0.8720
# Batch-63 : CrossEntropyLoss=2.2887 | MulticlassF1Score=0.8726
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2911 | Mean MulticlassF1Score = 0.8522
# Validation : Mean CrossEntropyLoss = 2.2875 | Mean MulticlassF1Score = 0.8700
# ================================================================================
#
# EPOCH-9
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2783 | MulticlassF1Score=0.8828
# Batch-30 : CrossEntropyLoss=2.2824 | MulticlassF1Score=0.8832
# Batch-45 : CrossEntropyLoss=2.2855 | MulticlassF1Score=0.8814
# Batch-60 : CrossEntropyLoss=2.2854 | MulticlassF1Score=0.8798
# Batch-75 : CrossEntropyLoss=2.2808 | MulticlassF1Score=0.8804
# Batch-90 : CrossEntropyLoss=2.2833 | MulticlassF1Score=0.8807
# Batch-105: CrossEntropyLoss=2.2761 | MulticlassF1Score=0.8805
# Batch-120: CrossEntropyLoss=2.2840 | MulticlassF1Score=0.8802
# Batch-135: CrossEntropyLoss=2.2921 | MulticlassF1Score=0.8803
# Batch-150: CrossEntropyLoss=2.2807 | MulticlassF1Score=0.8798
# Batch-165: CrossEntropyLoss=2.2971 | MulticlassF1Score=0.8795
# Batch-180: CrossEntropyLoss=2.2840 | MulticlassF1Score=0.8792
# Batch-195: CrossEntropyLoss=2.2820 | MulticlassF1Score=0.8794
# Batch-210: CrossEntropyLoss=2.2883 | MulticlassF1Score=0.8795
# Batch-225: CrossEntropyLoss=2.2855 | MulticlassF1Score=0.8792
# Batch-226: CrossEntropyLoss=2.2775 | MulticlassF1Score=0.8792
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2860 | MulticlassF1Score=0.8730
# Batch-30 : CrossEntropyLoss=2.2894 | MulticlassF1Score=0.8737
# Batch-45 : CrossEntropyLoss=2.2848 | MulticlassF1Score=0.8759
# Batch-60 : CrossEntropyLoss=2.2848 | MulticlassF1Score=0.8755
# Batch-63 : CrossEntropyLoss=2.2962 | MulticlassF1Score=0.8755
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2854 | Mean MulticlassF1Score = 0.8804
# Validation : Mean CrossEntropyLoss = 2.2865 | Mean MulticlassF1Score = 0.8733
# ================================================================================
#
# EPOCH-10
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2797 | MulticlassF1Score=0.8840
# Batch-30 : CrossEntropyLoss=2.2847 | MulticlassF1Score=0.8822
# Batch-45 : CrossEntropyLoss=2.2767 | MulticlassF1Score=0.8814
# Batch-60 : CrossEntropyLoss=2.2781 | MulticlassF1Score=0.8801
# Batch-75 : CrossEntropyLoss=2.2829 | MulticlassF1Score=0.8805
# Batch-90 : CrossEntropyLoss=2.2760 | MulticlassF1Score=0.8817
# Batch-105: CrossEntropyLoss=2.2846 | MulticlassF1Score=0.8821
# Batch-120: CrossEntropyLoss=2.2841 | MulticlassF1Score=0.8820
# Batch-135: CrossEntropyLoss=2.2883 | MulticlassF1Score=0.8818
# Batch-150: CrossEntropyLoss=2.2807 | MulticlassF1Score=0.8818
# Batch-165: CrossEntropyLoss=2.2926 | MulticlassF1Score=0.8819
# Batch-180: CrossEntropyLoss=2.2855 | MulticlassF1Score=0.8824
# Batch-195: CrossEntropyLoss=2.2880 | MulticlassF1Score=0.8823
# Batch-210: CrossEntropyLoss=2.2883 | MulticlassF1Score=0.8824
# Batch-225: CrossEntropyLoss=2.2813 | MulticlassF1Score=0.8823
# Batch-226: CrossEntropyLoss=2.2748 | MulticlassF1Score=0.8824
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2800 | MulticlassF1Score=0.8776
# Batch-30 : CrossEntropyLoss=2.2897 | MulticlassF1Score=0.8768
# Batch-45 : CrossEntropyLoss=2.2827 | MulticlassF1Score=0.8758
# Batch-60 : CrossEntropyLoss=2.2786 | MulticlassF1Score=0.8766
# Batch-63 : CrossEntropyLoss=2.2994 | MulticlassF1Score=0.8764
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2844 | Mean MulticlassF1Score = 0.8820
# Validation : Mean CrossEntropyLoss = 2.2862 | Mean MulticlassF1Score = 0.8763
# ================================================================================
#
# EPOCH-11
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2696 | MulticlassF1Score=0.8891
# Batch-30 : CrossEntropyLoss=2.2790 | MulticlassF1Score=0.8892
# Batch-45 : CrossEntropyLoss=2.2801 | MulticlassF1Score=0.8894
# Batch-60 : CrossEntropyLoss=2.2825 | MulticlassF1Score=0.8884
# Batch-75 : CrossEntropyLoss=2.2830 | MulticlassF1Score=0.8870
# Batch-90 : CrossEntropyLoss=2.2893 | MulticlassF1Score=0.8868
# Batch-105: CrossEntropyLoss=2.2829 | MulticlassF1Score=0.8861
# Batch-120: CrossEntropyLoss=2.2884 | MulticlassF1Score=0.8851
# Batch-135: CrossEntropyLoss=2.2815 | MulticlassF1Score=0.8849
# Batch-150: CrossEntropyLoss=2.2845 | MulticlassF1Score=0.8848
# Batch-165: CrossEntropyLoss=2.2815 | MulticlassF1Score=0.8848
# Batch-180: CrossEntropyLoss=2.2828 | MulticlassF1Score=0.8848
# Batch-195: CrossEntropyLoss=2.2927 | MulticlassF1Score=0.8850
# Batch-210: CrossEntropyLoss=2.2837 | MulticlassF1Score=0.8848
# Batch-225: CrossEntropyLoss=2.2849 | MulticlassF1Score=0.8847
# Batch-226: CrossEntropyLoss=2.2864 | MulticlassF1Score=0.8847
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2788 | MulticlassF1Score=0.8824
# Batch-30 : CrossEntropyLoss=2.2879 | MulticlassF1Score=0.8766
# Batch-45 : CrossEntropyLoss=2.2861 | MulticlassF1Score=0.8764
# Batch-60 : CrossEntropyLoss=2.2783 | MulticlassF1Score=0.8774
# Batch-63 : CrossEntropyLoss=2.2825 | MulticlassF1Score=0.8781
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2836 | Mean MulticlassF1Score = 0.8865
# Validation : Mean CrossEntropyLoss = 2.2855 | Mean MulticlassF1Score = 0.8783
# ================================================================================
#
# EPOCH-12
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2802 | MulticlassF1Score=0.8927
# Batch-30 : CrossEntropyLoss=2.2784 | MulticlassF1Score=0.8895
# Batch-45 : CrossEntropyLoss=2.2800 | MulticlassF1Score=0.8897
# Batch-60 : CrossEntropyLoss=2.2828 | MulticlassF1Score=0.8898
# Batch-75 : CrossEntropyLoss=2.2785 | MulticlassF1Score=0.8890
# Batch-90 : CrossEntropyLoss=2.2812 | MulticlassF1Score=0.8879
# Batch-105: CrossEntropyLoss=2.2844 | MulticlassF1Score=0.8879
# Batch-120: CrossEntropyLoss=2.2816 | MulticlassF1Score=0.8880
# Batch-135: CrossEntropyLoss=2.2816 | MulticlassF1Score=0.8880
# Batch-150: CrossEntropyLoss=2.2772 | MulticlassF1Score=0.8874
# Batch-165: CrossEntropyLoss=2.2779 | MulticlassF1Score=0.8877
# Batch-180: CrossEntropyLoss=2.2807 | MulticlassF1Score=0.8871
# Batch-195: CrossEntropyLoss=2.2819 | MulticlassF1Score=0.8866
# Batch-210: CrossEntropyLoss=2.2883 | MulticlassF1Score=0.8864
# Batch-225: CrossEntropyLoss=2.2884 | MulticlassF1Score=0.8867
# Batch-226: CrossEntropyLoss=2.2869 | MulticlassF1Score=0.8866
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2820 | MulticlassF1Score=0.8777
# Batch-30 : CrossEntropyLoss=2.2834 | MulticlassF1Score=0.8781
# Batch-45 : CrossEntropyLoss=2.2916 | MulticlassF1Score=0.8790
# Batch-60 : CrossEntropyLoss=2.2939 | MulticlassF1Score=0.8788
# Batch-63 : CrossEntropyLoss=2.2863 | MulticlassF1Score=0.8787
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2829 | Mean MulticlassF1Score = 0.8884
# Validation : Mean CrossEntropyLoss = 2.2853 | Mean MulticlassF1Score = 0.8772
# ================================================================================
#
# EPOCH-13
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2851 | MulticlassF1Score=0.8863
# Batch-30 : CrossEntropyLoss=2.2743 | MulticlassF1Score=0.8893
# Batch-45 : CrossEntropyLoss=2.2797 | MulticlassF1Score=0.8893
# Batch-60 : CrossEntropyLoss=2.2873 | MulticlassF1Score=0.8886
# Batch-75 : CrossEntropyLoss=2.2854 | MulticlassF1Score=0.8890
# Batch-90 : CrossEntropyLoss=2.2856 | MulticlassF1Score=0.8888
# Batch-105: CrossEntropyLoss=2.2869 | MulticlassF1Score=0.8884
# Batch-120: CrossEntropyLoss=2.2790 | MulticlassF1Score=0.8886
# Batch-135: CrossEntropyLoss=2.2773 | MulticlassF1Score=0.8885
# Batch-150: CrossEntropyLoss=2.2844 | MulticlassF1Score=0.8887
# Batch-165: CrossEntropyLoss=2.2816 | MulticlassF1Score=0.8888
# Batch-180: CrossEntropyLoss=2.2834 | MulticlassF1Score=0.8892
# Batch-195: CrossEntropyLoss=2.2843 | MulticlassF1Score=0.8889
# Batch-210: CrossEntropyLoss=2.2823 | MulticlassF1Score=0.8887
# Batch-225: CrossEntropyLoss=2.2806 | MulticlassF1Score=0.8891
# Batch-226: CrossEntropyLoss=2.2848 | MulticlassF1Score=0.8891
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2834 | MulticlassF1Score=0.8823
# Batch-30 : CrossEntropyLoss=2.2775 | MulticlassF1Score=0.8824
# Batch-45 : CrossEntropyLoss=2.2819 | MulticlassF1Score=0.8827
# Batch-60 : CrossEntropyLoss=2.2872 | MulticlassF1Score=0.8821
# Batch-63 : CrossEntropyLoss=2.2803 | MulticlassF1Score=0.8823
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2821 | Mean MulticlassF1Score = 0.8887
# Validation : Mean CrossEntropyLoss = 2.2841 | Mean MulticlassF1Score = 0.8824
# ================================================================================
#
# EPOCH-14
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2824 | MulticlassF1Score=0.8925
# Batch-30 : CrossEntropyLoss=2.2803 | MulticlassF1Score=0.8929
# Batch-45 : CrossEntropyLoss=2.2787 | MulticlassF1Score=0.8929
# Batch-60 : CrossEntropyLoss=2.2833 | MulticlassF1Score=0.8930
# Batch-75 : CrossEntropyLoss=2.2898 | MulticlassF1Score=0.8930
# Batch-90 : CrossEntropyLoss=2.2815 | MulticlassF1Score=0.8932
# Batch-105: CrossEntropyLoss=2.2801 | MulticlassF1Score=0.8931
# Batch-120: CrossEntropyLoss=2.2778 | MulticlassF1Score=0.8934
# Batch-135: CrossEntropyLoss=2.2749 | MulticlassF1Score=0.8940
# Batch-150: CrossEntropyLoss=2.2738 | MulticlassF1Score=0.8950
# Batch-165: CrossEntropyLoss=2.2751 | MulticlassF1Score=0.8971
# Batch-180: CrossEntropyLoss=2.2752 | MulticlassF1Score=0.8991
# Batch-195: CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9004
# Batch-210: CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9020
# Batch-225: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9031
# Batch-226: CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9032
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2762 | MulticlassF1Score=0.9096
# Batch-30 : CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9090
# Batch-45 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9091
# Batch-60 : CrossEntropyLoss=2.2761 | MulticlassF1Score=0.9095
# Batch-63 : CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9098
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2779 | Mean MulticlassF1Score = 0.8954
# Validation : Mean CrossEntropyLoss = 2.2759 | Mean MulticlassF1Score = 0.9089
# ================================================================================
#
# EPOCH-15
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9260
# Batch-30 : CrossEntropyLoss=2.2756 | MulticlassF1Score=0.9240
# Batch-45 : CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9250
# Batch-60 : CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9248
# Batch-75 : CrossEntropyLoss=2.2766 | MulticlassF1Score=0.9250
# Batch-90 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9248
# Batch-105: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9244
# Batch-120: CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9242
# Batch-135: CrossEntropyLoss=2.2751 | MulticlassF1Score=0.9238
# Batch-150: CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9238
# Batch-165: CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9233
# Batch-180: CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9232
# Batch-195: CrossEntropyLoss=2.2766 | MulticlassF1Score=0.9231
# Batch-210: CrossEntropyLoss=2.2772 | MulticlassF1Score=0.9226
# Batch-225: CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9226
# Batch-226: CrossEntropyLoss=2.2779 | MulticlassF1Score=0.9226
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2775 | MulticlassF1Score=0.9128
# Batch-30 : CrossEntropyLoss=2.2788 | MulticlassF1Score=0.9113
# Batch-45 : CrossEntropyLoss=2.2805 | MulticlassF1Score=0.9106
# Batch-60 : CrossEntropyLoss=2.2762 | MulticlassF1Score=0.9114
# Batch-63 : CrossEntropyLoss=2.2787 | MulticlassF1Score=0.9111
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2718 | Mean MulticlassF1Score = 0.9242
# Validation : Mean CrossEntropyLoss = 2.2753 | Mean MulticlassF1Score = 0.9113
# ================================================================================
#
# EPOCH-16
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9286
# Batch-30 : CrossEntropyLoss=2.2761 | MulticlassF1Score=0.9261
# Batch-45 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9264
# Batch-60 : CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9266
# Batch-75 : CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9260
# Batch-90 : CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9257
# Batch-105: CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9257
# Batch-120: CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9253
# Batch-135: CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9249
# Batch-150: CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9243
# Batch-165: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9246
# Batch-180: CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9245
# Batch-195: CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9242
# Batch-210: CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9240
# Batch-225: CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9239
# Batch-226: CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9240
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9110
# Batch-30 : CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9122
# Batch-45 : CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9112
# Batch-60 : CrossEntropyLoss=2.2774 | MulticlassF1Score=0.9112
# Batch-63 : CrossEntropyLoss=2.2824 | MulticlassF1Score=0.9109
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2712 | Mean MulticlassF1Score = 0.9255
# Validation : Mean CrossEntropyLoss = 2.2753 | Mean MulticlassF1Score = 0.9115
# ================================================================================
#
# EPOCH-17
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9247
# Batch-30 : CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9261
# Batch-45 : CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9266
# Batch-60 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9256
# Batch-75 : CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9257
# Batch-90 : CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9254
# Batch-105: CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9247
# Batch-120: CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9254
# Batch-135: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9252
# Batch-150: CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9253
# Batch-165: CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9254
# Batch-180: CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9253
# Batch-195: CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9253
# Batch-210: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9254
# Batch-225: CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9253
# Batch-226: CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9254
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2777 | MulticlassF1Score=0.9126
# Batch-30 : CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9116
# Batch-45 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9122
# Batch-60 : CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9115
# Batch-63 : CrossEntropyLoss=2.2768 | MulticlassF1Score=0.9116
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2708 | Mean MulticlassF1Score = 0.9253
# Validation : Mean CrossEntropyLoss = 2.2750 | Mean MulticlassF1Score = 0.9129
# ================================================================================
#
# EPOCH-18
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9252
# Batch-30 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9248
# Batch-45 : CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9253
# Batch-60 : CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9267
# Batch-75 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9261
# Batch-90 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9261
# Batch-105: CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9261
# Batch-120: CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9265
# Batch-135: CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9265
# Batch-150: CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9268
# Batch-165: CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9270
# Batch-180: CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9267
# Batch-195: CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9268
# Batch-210: CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9266
# Batch-225: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9261
# Batch-226: CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9261
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2747 | MulticlassF1Score=0.9079
# Batch-30 : CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9122
# Batch-45 : CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9120
# Batch-60 : CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9124
# Batch-63 : CrossEntropyLoss=2.2832 | MulticlassF1Score=0.9120
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2705 | Mean MulticlassF1Score = 0.9261
# Validation : Mean CrossEntropyLoss = 2.2749 | Mean MulticlassF1Score = 0.9112
# ================================================================================
#
# EPOCH-19
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9279
# Batch-30 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9272
# Batch-45 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9283
# Batch-60 : CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9274
# Batch-75 : CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9268
# Batch-90 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9276
# Batch-105: CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9279
# Batch-120: CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9272
# Batch-135: CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9271
# Batch-150: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9273
# Batch-165: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9275
# Batch-180: CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9273
# Batch-195: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9271
# Batch-210: CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9271
# Batch-225: CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9270
# Batch-226: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9270
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9126
# Batch-30 : CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9140
# Batch-45 : CrossEntropyLoss=2.2747 | MulticlassF1Score=0.9144
# Batch-60 : CrossEntropyLoss=2.2795 | MulticlassF1Score=0.9122
# Batch-63 : CrossEntropyLoss=2.2769 | MulticlassF1Score=0.9117
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2702 | Mean MulticlassF1Score = 0.9274
# Validation : Mean CrossEntropyLoss = 2.2750 | Mean MulticlassF1Score = 0.9130
# ================================================================================
#
# EPOCH-20
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9295
# Batch-30 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9289
# Batch-45 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9284
# Batch-60 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9280
# Batch-75 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9288
# Batch-90 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9284
# Batch-105: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9281
# Batch-120: CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9279
# Batch-135: CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9274
# Batch-150: CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9275
# Batch-165: CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9272
# Batch-180: CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9271
# Batch-195: CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9273
# Batch-210: CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9273
# Batch-225: CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9272
# Batch-226: CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9272
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2780 | MulticlassF1Score=0.9125
# Batch-30 : CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9124
# Batch-45 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9127
# Batch-60 : CrossEntropyLoss=2.2765 | MulticlassF1Score=0.9118
# Batch-63 : CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9122
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2701 | Mean MulticlassF1Score = 0.9281
# Validation : Mean CrossEntropyLoss = 2.2749 | Mean MulticlassF1Score = 0.9122
# ================================================================================
#
# EPOCH-21
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9291
# Batch-30 : CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9277
# Batch-45 : CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9262
# Batch-60 : CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9278
# Batch-75 : CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9274
# Batch-90 : CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9271
# Batch-105: CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9273
# Batch-120: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9277
# Batch-135: CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9282
# Batch-150: CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9280
# Batch-165: CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9280
# Batch-180: CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9281
# Batch-195: CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9280
# Batch-210: CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9281
# Batch-225: CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9281
# Batch-226: CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9281
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9100
# Batch-30 : CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9129
# Batch-45 : CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9129
# Batch-60 : CrossEntropyLoss=2.2778 | MulticlassF1Score=0.9122
# Batch-63 : CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9125
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2698 | Mean MulticlassF1Score = 0.9280
# Validation : Mean CrossEntropyLoss = 2.2747 | Mean MulticlassF1Score = 0.9117
# ================================================================================
#
# EPOCH-22
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9293
# Batch-30 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9293
# Batch-45 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9310
# Batch-60 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9308
# Batch-75 : CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9297
# Batch-90 : CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9293
# Batch-105: CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9299
# Batch-120: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9300
# Batch-135: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9297
# Batch-150: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9293
# Batch-165: CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9289
# Batch-180: CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9285
# Batch-195: CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9287
# Batch-210: CrossEntropyLoss=2.2762 | MulticlassF1Score=0.9287
# Batch-225: CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9289
# Batch-226: CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9290
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9131
# Batch-30 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9135
# Batch-45 : CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9131
# Batch-60 : CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9119
# Batch-63 : CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9122
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2695 | Mean MulticlassF1Score = 0.9294
# Validation : Mean CrossEntropyLoss = 2.2747 | Mean MulticlassF1Score = 0.9130
# ================================================================================
#
# EPOCH-23
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9280
# Batch-30 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9293
# Batch-45 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9299
# Batch-60 : CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9304
# Batch-75 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9301
# Batch-90 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9295
# Batch-105: CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9287
# Batch-120: CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9292
# Batch-135: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9292
# Batch-150: CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9289
# Batch-165: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9288
# Batch-180: CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9288
# Batch-195: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9291
# Batch-210: CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9290
# Batch-225: CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9292
# Batch-226: CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9292
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9141
# Batch-30 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9104
# Batch-45 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9119
# Batch-60 : CrossEntropyLoss=2.2782 | MulticlassF1Score=0.9119
# Batch-63 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9120
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2694 | Mean MulticlassF1Score = 0.9289
# Validation : Mean CrossEntropyLoss = 2.2747 | Mean MulticlassF1Score = 0.9119
# ================================================================================
#
# EPOCH-24
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9320
# Batch-30 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9294
# Batch-45 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9300
# Batch-60 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9300
# Batch-75 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9304
# Batch-90 : CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9310
# Batch-105: CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9304
# Batch-120: CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9306
# Batch-135: CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9303
# Batch-150: CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9302
# Batch-165: CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9304
# Batch-180: CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9300
# Batch-195: CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9297
# Batch-210: CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9298
# Batch-225: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9297
# Batch-226: CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9297
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9115
# Batch-30 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9138
# Batch-45 : CrossEntropyLoss=2.2791 | MulticlassF1Score=0.9135
# Batch-60 : CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9131
# Batch-63 : CrossEntropyLoss=2.2747 | MulticlassF1Score=0.9129
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2693 | Mean MulticlassF1Score = 0.9303
# Validation : Mean CrossEntropyLoss = 2.2745 | Mean MulticlassF1Score = 0.9116
# ================================================================================
#
# EPOCH-25
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9315
# Batch-30 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9301
# Batch-45 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9303
# Batch-60 : CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9315
# Batch-75 : CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9309
# Batch-90 : CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9306
# Batch-105: CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9309
# Batch-120: CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9303
# Batch-135: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9303
# Batch-150: CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9305
# Batch-165: CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9307
# Batch-180: CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9302
# Batch-195: CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9300
# Batch-210: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9300
# Batch-225: CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9302
# Batch-226: CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9302
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2747 | MulticlassF1Score=0.9099
# Batch-30 : CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9121
# Batch-45 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9127
# Batch-60 : CrossEntropyLoss=2.2758 | MulticlassF1Score=0.9143
# Batch-63 : CrossEntropyLoss=2.2786 | MulticlassF1Score=0.9139
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2691 | Mean MulticlassF1Score = 0.9305
# Validation : Mean CrossEntropyLoss = 2.2742 | Mean MulticlassF1Score = 0.9113
# ================================================================================
#
# EPOCH-26
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9339
# Batch-30 : CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9330
# Batch-45 : CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9333
# Batch-60 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9339
# Batch-75 : CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9335
# Batch-90 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9336
# Batch-105: CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9331
# Batch-120: CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9329
# Batch-135: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9328
# Batch-150: CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9327
# Batch-165: CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9327
# Batch-180: CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9325
# Batch-195: CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9325
# Batch-210: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9324
# Batch-225: CrossEntropyLoss=2.2753 | MulticlassF1Score=0.9320
# Batch-226: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9319
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2751 | MulticlassF1Score=0.9111
# Batch-30 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9133
# Batch-45 : CrossEntropyLoss=2.2769 | MulticlassF1Score=0.9144
# Batch-60 : CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9151
# Batch-63 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9148
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2685 | Mean MulticlassF1Score = 0.9332
# Validation : Mean CrossEntropyLoss = 2.2740 | Mean MulticlassF1Score = 0.9136
# ================================================================================
#
# EPOCH-27
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9331
# Batch-30 : CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9330
# Batch-45 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9333
# Batch-60 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9323
# Batch-75 : CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9325
# Batch-90 : CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9322
# Batch-105: CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9321
# Batch-120: CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9325
# Batch-135: CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9325
# Batch-150: CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9324
# Batch-165: CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9324
# Batch-180: CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9321
# Batch-195: CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9321
# Batch-210: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9322
# Batch-225: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9323
# Batch-226: CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9324
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2765 | MulticlassF1Score=0.9123
# Batch-30 : CrossEntropyLoss=2.2800 | MulticlassF1Score=0.9125
# Batch-45 : CrossEntropyLoss=2.2751 | MulticlassF1Score=0.9147
# Batch-60 : CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9158
# Batch-63 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9154
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2684 | Mean MulticlassF1Score = 0.9324
# Validation : Mean CrossEntropyLoss = 2.2738 | Mean MulticlassF1Score = 0.9150
# ================================================================================
#
# EPOCH-28
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9304
# Batch-30 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9327
# Batch-45 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9314
# Batch-60 : CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9320
# Batch-75 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9327
# Batch-90 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9327
# Batch-105: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9329
# Batch-120: CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9325
# Batch-135: CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9328
# Batch-150: CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9339
# Batch-165: CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9345
# Batch-180: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9354
# Batch-195: CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9359
# Batch-210: CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9362
# Batch-225: CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9366
# Batch-226: CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9366
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9233
# Batch-30 : CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9245
# Batch-45 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9226
# Batch-60 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9239
# Batch-63 : CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9237
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2671 | Mean MulticlassF1Score = 0.9332
# Validation : Mean CrossEntropyLoss = 2.2711 | Mean MulticlassF1Score = 0.9233
# ================================================================================
#
# EPOCH-29
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9427
# Batch-30 : CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9415
# Batch-45 : CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9408
# Batch-60 : CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9415
# Batch-75 : CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9411
# Batch-90 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9410
# Batch-105: CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9416
# Batch-120: CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9419
# Batch-135: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9422
# Batch-150: CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9421
# Batch-165: CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9419
# Batch-180: CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9417
# ...
# Batch-45 : CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9261
# Batch-60 : CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9267
# Batch-63 : CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9266
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2639 | Mean MulticlassF1Score = 0.9485
# Validation : Mean CrossEntropyLoss = 2.2702 | Mean MulticlassF1Score = 0.9243
# Patience = 1/50❗
# ================================================================================
#
# EPOCH-42
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9471
# Batch-30 : CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9470
# Batch-45 : CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9460
# Batch-60 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9462
# Batch-75 : CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9458
# Batch-90 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9458
# Batch-105: CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9456
# Batch-120: CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9455
# Batch-135: CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9458
# Batch-150: CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9463
# Batch-165: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9461
# Batch-180: CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9464
# Batch-195: CrossEntropyLoss=2.2612 | MulticlassF1Score=0.9466
# Batch-210: CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9464
# Batch-225: CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9465
# Batch-226: CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9465
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9278
# Batch-30 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9281
# Batch-45 : CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9275
# Batch-60 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9263
# Batch-63 : CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9262
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2640 | Mean MulticlassF1Score = 0.9463
# Validation : Mean CrossEntropyLoss = 2.2703 | Mean MulticlassF1Score = 0.9282
# Patience = 2/50❗
# ================================================================================
#
# EPOCH-43
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9520
# Batch-30 : CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9484
# Batch-45 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9478
# Batch-60 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9476
# Batch-75 : CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9477
# Batch-90 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9478
# Batch-105: CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9468
# Batch-120: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9464
# Batch-135: CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9466
# Batch-150: CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9468
# Batch-165: CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9468
# Batch-180: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9470
# Batch-195: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9473
# Batch-210: CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9473
# Batch-225: CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9470
# Batch-226: CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9471
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9318
# Batch-30 : CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9280
# Batch-45 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9273
# Batch-60 : CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9264
# Batch-63 : CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9267
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2638 | Mean MulticlassF1Score = 0.9476
# Validation : Mean CrossEntropyLoss = 2.2702 | Mean MulticlassF1Score = 0.9293
# ================================================================================
#
# EPOCH-44
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9456
# Batch-30 : CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9480
# Batch-45 : CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9468
# Batch-60 : CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9475
# Batch-75 : CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9474
# Batch-90 : CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9477
# Batch-105: CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9476
# Batch-120: CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9479
# Batch-135: CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9479
# Batch-150: CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9483
# Batch-165: CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9483
# Batch-180: CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9480
# Batch-195: CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9481
# Batch-210: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9480
# Batch-225: CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9476
# Batch-226: CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9476
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9266
# Batch-30 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9265
# Batch-45 : CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9276
# Batch-60 : CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9271
# Batch-63 : CrossEntropyLoss=2.2767 | MulticlassF1Score=0.9266
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2636 | Mean MulticlassF1Score = 0.9475
# Validation : Mean CrossEntropyLoss = 2.2702 | Mean MulticlassF1Score = 0.9272
# ================================================================================
#
# EPOCH-45
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2589 | MulticlassF1Score=0.9482
# Batch-30 : CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9488
# Batch-45 : CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9520
# Batch-60 : CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9551
# Batch-75 : CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9575
# Batch-90 : CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9584
# Batch-105: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9597
# Batch-120: CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9608
# Batch-135: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9614
# Batch-150: CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9613
# Batch-165: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9618
# Batch-180: CrossEntropyLoss=2.2543 | MulticlassF1Score=0.9624
# Batch-195: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9628
# Batch-210: CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9630
# Batch-225: CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9634
# Batch-226: CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9634
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9421
# Batch-30 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9441
# Batch-45 : CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9452
# Batch-60 : CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9454
# Batch-63 : CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9456
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2588 | Mean MulticlassF1Score = 0.9580
# Validation : Mean CrossEntropyLoss = 2.2645 | Mean MulticlassF1Score = 0.9449
# ================================================================================
#
# EPOCH-46
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9669
# Batch-30 : CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9693
# Batch-45 : CrossEntropyLoss=2.2551 | MulticlassF1Score=0.9686
# Batch-60 : CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9688
# Batch-75 : CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9690
# Batch-90 : CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9685
# Batch-105: CrossEntropyLoss=2.2547 | MulticlassF1Score=0.9684
# Batch-120: CrossEntropyLoss=2.2524 | MulticlassF1Score=0.9683
# Batch-135: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9684
# Batch-150: CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9685
# Batch-165: CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9683
# Batch-180: CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9684
# Batch-195: CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9685
# Batch-210: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9684
# Batch-225: CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9684
# Batch-226: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9684
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9464
# Batch-30 : CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9477
# Batch-45 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9487
# Batch-60 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9480
# Batch-63 : CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9476
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2573 | Mean MulticlassF1Score = 0.9685
# Validation : Mean CrossEntropyLoss = 2.2637 | Mean MulticlassF1Score = 0.9470
# ================================================================================
#
# EPOCH-47
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9661
# Batch-30 : CrossEntropyLoss=2.2530 | MulticlassF1Score=0.9685
# Batch-45 : CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9700
# Batch-60 : CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9710
# Batch-75 : CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9706
# Batch-90 : CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9704
# Batch-105: CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9697
# Batch-120: CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9698
# Batch-135: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9698
# Batch-150: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9698
# Batch-165: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9699
# Batch-180: CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9697
# Batch-195: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9695
# Batch-210: CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9693
# Batch-225: CrossEntropyLoss=2.2535 | MulticlassF1Score=0.9692
# Batch-226: CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9692
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9446
# Batch-30 : CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9473
# Batch-45 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9470
# Batch-60 : CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9470
# Batch-63 : CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9470
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2570 | Mean MulticlassF1Score = 0.9695
# Validation : Mean CrossEntropyLoss = 2.2639 | Mean MulticlassF1Score = 0.9469
# ================================================================================
#
# EPOCH-48
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9721
# Batch-30 : CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9712
# Batch-45 : CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9709
# Batch-60 : CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9700
# Batch-75 : CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9695
# Batch-90 : CrossEntropyLoss=2.2541 | MulticlassF1Score=0.9698
# Batch-105: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9703
# Batch-120: CrossEntropyLoss=2.2533 | MulticlassF1Score=0.9703
# Batch-135: CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9702
# Batch-150: CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9700
# Batch-165: CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9701
# Batch-180: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9704
# Batch-195: CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9703
# Batch-210: CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9702
# Batch-225: CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9701
# Batch-226: CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9702
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9465
# Batch-30 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9490
# Batch-45 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9505
# Batch-60 : CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9498
# Batch-63 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9493
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2567 | Mean MulticlassF1Score = 0.9704
# Validation : Mean CrossEntropyLoss = 2.2632 | Mean MulticlassF1Score = 0.9476
# ================================================================================
#
# EPOCH-49
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2534 | MulticlassF1Score=0.9701
# Batch-30 : CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9710
# Batch-45 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9708
# Batch-60 : CrossEntropyLoss=2.2547 | MulticlassF1Score=0.9714
# Batch-75 : CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9707
# Batch-90 : CrossEntropyLoss=2.2543 | MulticlassF1Score=0.9712
# Batch-105: CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9713
# Batch-120: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9714
# Batch-135: CrossEntropyLoss=2.2530 | MulticlassF1Score=0.9713
# Batch-150: CrossEntropyLoss=2.2535 | MulticlassF1Score=0.9712
# Batch-165: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9714
# Batch-180: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9714
# Batch-195: CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9713
# Batch-210: CrossEntropyLoss=2.2589 | MulticlassF1Score=0.9712
# Batch-225: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9710
# Batch-226: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9710
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9457
# Batch-30 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9487
# Batch-45 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9476
# Batch-60 : CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9485
# Batch-63 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9490
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2564 | Mean MulticlassF1Score = 0.9711
# Validation : Mean CrossEntropyLoss = 2.2633 | Mean MulticlassF1Score = 0.9477
# ================================================================================
#
# EPOCH-50
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9712
# Batch-30 : CrossEntropyLoss=2.2538 | MulticlassF1Score=0.9714
# Batch-45 : CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9711
# Batch-60 : CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9717
# Batch-75 : CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9717
# Batch-90 : CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9722
# Batch-105: CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9722
# Batch-120: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9720
# Batch-135: CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9718
# Batch-150: CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9716
# Batch-165: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9717
# Batch-180: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9714
# Batch-195: CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9713
# Batch-210: CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9715
# Batch-225: CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9713
# Batch-226: CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9713
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9475
# Batch-30 : CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9482
# Batch-45 : CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9498
# Batch-60 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9495
# Batch-63 : CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9493
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2563 | Mean MulticlassF1Score = 0.9715
# Validation : Mean CrossEntropyLoss = 2.2631 | Mean MulticlassF1Score = 0.9477
# ================================================================================
#
# TRAINING SUMMARY
# Best CrossEntropyLoss training    : 2.2563
# Best CrossEntropyLoss training    : 2.2631
# Best MulticlassF1Score validation : 0.9715
# Best MulticlassF1Score validation : 0.9477
# Training duration                 : 2.7180 minutes.
# Training date                     : 2022-10-19 10:52:41.956872+08:00

# %% [markdown]
# ## End Training

# %% [markdown]
# # Evaluation

# %%
def evaluation(dataloader, model, criterion, metric):
    model.eval()
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)
            pred = rearrange(prob.argmax(dim=1).reshape(feature.shape[0], len(dataloader.dataset)), "s n -> n s")

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob.argmax(dim=1), actual_label.to(hyperparams.device))
            metric_score = metric.compute()

    return loss, metric_score, pred

train_dataloader = DataLoader(train_dataset, batch_size=len(train_dataset))
val_dataloader = DataLoader(val_dataset, batch_size=len(val_dataset))
test_dataloader = DataLoader(test_dataset, batch_size=len(test_dataset))

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
train_loss, train_f1_score, train_pred_label = evaluation(train_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_loss, val_f1_score, val_pred_label = evaluation(val_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
test_loss, test_f1_score, test_pred_label = evaluation(test_dataloader, model, criterion, metric)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9719, device='cuda:0'),
#  tensor(0.9493, device='cuda:0'),
#  tensor(0.9470, device='cuda:0'))

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9719, device='cuda:0'),
#  tensor(0.9493, device='cuda:0'),
#  tensor(0.9470, device='cuda:0'))

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns

def viz_evaluation(pred_label, actual_label, title):
    plt.figure(figsize=(15, 7), dpi=200)
    sns.heatmap(pred_label.detach().cpu() == actual_label, cbar=True, cmap="binary_r")
    plt.xlabel("Sentence Length")
    plt.ylabel("Sentence")
    plt.title(title)
    plt.savefig(f"{root_path}/heatmap_{title.lower()}.jpg", dpi=200)
    plt.show()

train_actual_label = train_dataloader.dataset.tensors[1]
val_actual_label = val_dataloader.dataset.tensors[1]
test_actual_label = test_dataloader.dataset.tensors[1]

viz_evaluation(train_pred_label, train_actual_label, f"Training (F1-Score: {(train_f1_score):.4f})")
viz_evaluation(val_pred_label, val_actual_label, f"Validation (F1-Score: {(val_f1_score):.4f})")
viz_evaluation(test_pred_label, test_actual_label, f"Test (F1-Score: {(test_f1_score):.4f})")

# %% [markdown]
# ## Confusion Matrix

# %%
def confusion_matrix(pred_class, actual_class, title, normalize=None):
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize=normalize)
    plt.figure(figsize=(20, 10), dpi=200)
    sns.heatmap(conf_mat(pred_class.detach().cpu(), actual_class), annot=True, fmt=".2g", xticklabels=list(label_to_idx.keys()), yticklabels=list(label_to_idx.keys()));
    plt.yticks(rotation=0)
    plt.title(title)
    plt.xlabel("Actual Class")
    plt.ylabel("Predict Class")
    plt.savefig(f"{root_path}/conf_matrix_{title.lower()}.jpg", dpi=200)

confusion_matrix(train_pred_label, train_actual_label, "Training", "pred")
confusion_matrix(val_pred_label,val_actual_label, "Validation", "pred")
confusion_matrix(test_pred_label, test_actual_label, "Test", "pred")
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 120 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 144 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)

# %% [markdown]
# ## Prediction Table

# %%
def number_wrong_pred_each_class(pred_class, actual_class):
    classes, count_class = actual_class.flatten().unique(return_counts=True)
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize="none")
    correct_pred_count_class = conf_mat(pred_class.detach().cpu(), actual_class).diag()
    
    correct_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (correct_pred_count_class))}
    wrong_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (count_class - correct_pred_count_class))}
    
    return correct_pred, wrong_pred

correct_pred, wrong_pred = number_wrong_pred_each_class(train_pred_label, train_actual_label)
print(f"| {'Number class'.ljust(14)} | {'Correct prediction'.ljust(12)} | {'Wrong prediction'.ljust(12)} |")
for (label_correct_pred, count_correct_pred), (label_wrong_pred, count_wrong_pred) in zip(correct_pred.items(), wrong_pred.items()):
    print(f"| {str(label_correct_pred).ljust(6)}: {str(count_correct_pred + count_wrong_pred).ljust(7)}| {label_correct_pred.ljust(6)}: {str(count_correct_pred).ljust(10)} | {label_wrong_pred.ljust(6)}: {str(count_wrong_pred).ljust(8)} |")
# Out:
# | Number class   | Correct prediction | Wrong prediction |
# | CC    : 5391   | CC    : 5281       | CC    : 110      |
# | CD    : 12882  | CD    : 12786      | CD    : 96       |
# | DT    : 273    | DT    : 0          | DT    : 273      |
# | FW    : 1690   | FW    : 1510       | FW    : 180      |
# | IN    : 15403  | IN    : 15278      | IN    : 125      |
# | JJ    : 7018   | JJ    : 6694       | JJ    : 324      |
# | MD    : 3810   | MD    : 3690       | MD    : 120      |
# | NEG   : 1082   | NEG   : 0          | NEG   : 1082     |
# | NN    : 44728  | NN    : 44260      | NN    : 468      |
# | NND   : 1019   | NND   : 905        | NND   : 114      |
# | NNP   : 24885  | NNP   : 24454      | NNP   : 431      |
# | OD    : 534    | OD    : 520        | OD    : 14       |
# | PR    : 3842   | PR    : 3554       | PR    : 288      |
# | PRP   : 5405   | PRP   : 5361       | PRP   : 44       |
# | RB    : 3553   | RB    : 3339       | RB    : 214      |
# | RP    : 144    | RP    : 0          | RP    : 144      |
# | SC    : 9487   | SC    : 9214       | SC    : 273      |
# | SYM   : 1550   | SYM   : 1493       | SYM   : 57       |
# | UH    : 26     | UH    : 0          | UH    : 26       |
# | VB    : 22846  | VB    : 22495      | VB    : 351      |
# | WH    : 188    | WH    : 0          | WH    : 188      |
# | X     : 279    | X     : 9          | X     : 270      |
# | Z     : 18958  | Z     : 18955      | Z     : 3        |
# | <PAD> : 407211 | <PAD> : 407211     | <PAD> : 0        |

# %%
train_actual_label[308], train_pred_label[308]
# Out:
# (tensor([ 8, 19, 22, 10, 22, 19, 10,  6, 19,  4,  1,  8, 16, 19,  8, 19,  0,  8,
#           5, 16, 19, 19,  8,  8, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23]),
#  tensor([ 8, 19, 22, 10, 22, 19, 10,  6, 19,  4,  1,  8, 16, 19,  8,  5,  0,  8,
#           5, 16, 19, 19,  8,  8, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23], device='cuda:0'))

# %%
train_actual_label[308] == train_pred_label[308].detach().cpu()
# Out:
# tensor([ True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True, False,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True])

# %% [markdown]
# ## OOV prediction is correct

# %%
def oov_flag_token(sentences, max_seq_len=hyperparams.max_seq_len):
    sent_copy = deepcopy(sentences)
    sent = []
    oov_flag = []
    
    for sentence in tqdm(sent_copy):
        for token in sentence:
            sent.append(token[2])
        
        for _ in range(max_seq_len- len(sentence)):
            sent.append(False)
        
        oov_flag.append(sent)
        sent = []
        
    return np.array(oov_flag)

train_oov_flag = oov_flag_token(train_sentences, max_seq_len=hyperparams.max_seq_len)
val_oov_flag = oov_flag_token(val_sentences, max_seq_len=hyperparams.max_seq_len)
test_oov_flag = oov_flag_token(test_sentences, max_seq_len=hyperparams.max_seq_len)

def pencentage_oov_pred_correct(pred_oov_flag, oov_flag_tensor):
    oov_correct_counter = 0
    oov_wrong_counter = 0

    for pred, oov_label in tqdm(zip(pred_oov_flag, oov_flag_tensor)):
        if pred == True and oov_label == True:
            oov_correct_counter += 1
        elif pred == False and oov_label == True:
            oov_wrong_counter += 1
        else:
            continue
            
    return oov_correct_counter, oov_wrong_counter

train_pred_oov_flag = (train_actual_label == train_pred_label.detach().cpu()).flatten()
val_pred_oov_flag = (val_actual_label == val_pred_label.detach().cpu()).flatten()
test_pred_oov_flag = (test_actual_label == test_pred_label.detach().cpu()).flatten()
train_oov_flag_tensor = torch.tensor(train_oov_flag).flatten()
val_oov_flag_tensor = torch.tensor(val_oov_flag).flatten()
test_oov_flag_tensor = torch.tensor(test_oov_flag).flatten()

train_oov_correct_counter, train_oov_wrong_counter = pencentage_oov_pred_correct(train_pred_oov_flag, train_oov_flag_tensor)
val_oov_correct_counter, val_oov_wrong_counter = pencentage_oov_pred_correct(val_pred_oov_flag, val_oov_flag_tensor)
test_oov_correct_counter, test_oov_wrong_counter = pencentage_oov_pred_correct(test_pred_oov_flag, test_oov_flag_tensor)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
def print_percentage_pred_oov(title, oov_correct_counter, oov_wrong_counter):
    print(f"{title}")
    print(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}")
    print(f"Correct prediction          : {oov_correct_counter}")
    print(f"Wrong prediction            : {oov_wrong_counter}")
    print(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n")
    
    with open(f"{root_path}/oov_summary.txt", "a") as f:
        f.write(f"{title}\n")
        f.write(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}\n")
        f.write(f"Correct prediction          : {oov_correct_counter}\n")
        f.write(f"Wrong prediction            : {oov_wrong_counter}\n")
        f.write(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n\n")

# %%
print_percentage_pred_oov("Training", train_oov_correct_counter, train_oov_wrong_counter)
print_percentage_pred_oov("Validation", val_oov_correct_counter, val_oov_wrong_counter)
print_percentage_pred_oov("Test", test_oov_correct_counter, test_oov_wrong_counter)
# Out:
# Training
# Number OOV token            : 11808
# Correct prediction          : 11228
# Wrong prediction            : 580
# Percentage correct oov pred : 95.08807588075881
#
# Validation
# Number OOV token            : 3395
# Correct prediction          : 3058
# Wrong prediction            : 337
# Percentage correct oov pred : 90.07363770250369
#
# Test
# Number OOV token            : 1359
# Correct prediction          : 1222
# Wrong prediction            : 137
# Percentage correct oov pred : 89.91905813097866

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(train_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(val_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(test_oov_flag, cmap=plt.cm.binary_r);
