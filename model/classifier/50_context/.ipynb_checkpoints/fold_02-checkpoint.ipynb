# %% [markdown]
# # Import modules

# %%
import csv
import os
import pickle
import pytz
import torch
import timeit
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from copy import deepcopy
from datetime import datetime
from einops import rearrange
from itertools import chain
from time import time
from torch import nn, optim
from torchmetrics.classification import MulticlassAccuracy, MulticlassF1Score, MulticlassConfusionMatrix
from torch.optim import lr_scheduler
from tqdm.notebook import tqdm
from torch.utils.data import TensorDataset, DataLoader
from polyglot.mapping import Embedding, CaseExpander, DigitExpander

# %% [markdown]
# # Hyperparameters

# %%
class Hyperparams:
     def __init__(
        self,
        context_size=50,
        fold=2,
        max_seq_len=82,
        input_size=64,
        batch_size=32,
        num_hidden_layer=1,
        hidden_size=128,
        dropout=0,
        bias=True,
        output_size=24,
        shuffle=True,
        lr=0.005,
        batch_first=False,
        bidirectional=True,
        init_wb_with_kaiming_normal=True,
        n_epoch=50,
        patience=50,
        device="cuda" if torch.cuda.is_available() else "cpu"
    ):
        self.context_size = context_size
        self.fold = fold
        self.input_size = input_size
        self.max_seq_len = max_seq_len
        self.batch_size = batch_size
        self.num_hidden_layer = num_hidden_layer
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.output_size = output_size
        self.shuffle = shuffle
        self.lr = lr
        self.batch_first = batch_first
        self.bidirectional = bidirectional
        self.init_wb_with_kaiming_normal = init_wb_with_kaiming_normal
        self.n_epoch = n_epoch
        self.patience = patience
        self.device = device

hyperparams = Hyperparams()

# %% [markdown]
# # Dataset

# %%
id_pos_tag = pd.read_csv("../../../datasets/raw/Indonesian_Manually_Tagged_Corpus.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False) 
train = pd.read_csv(f"../../../datasets/raw/cv/train/train.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
val = pd.read_csv(f"../../../datasets/raw/cv/val/val.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
test = pd.read_csv(f"../../../datasets/raw/cv/test/test.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)

# %% [markdown]
# # Pre-trained Word Embedding

# %%
embeddings = Embedding.load("../../../word_embeddings/polyglot/idn_embeddings.tar.bz2")
embeddings.apply_expansion(DigitExpander)
embeddings.apply_expansion(CaseExpander)

oov_embeddings = pickle.load(open(f"../../../logs/comick/{hyperparams.context_size}_contexts/10-11-2022_15-24-28/oov_embedding_dict.pkl", "rb"))

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Add OOV Flag

# %%
def add_oov_flag(tokens, embeddings):
    oov_flags = []
    
    for token in tqdm(tokens):
        try:
            if token not in embeddings:
                oov_flags.append(True)
            else:
                oov_flags.append(False)
        except:
            oov_flags.append(False)
        
    return pd.DataFrame(oov_flags, columns=["is_oov"])

id_pos_tag_oov_flags = add_oov_flag(id_pos_tag["token"].values, embeddings)
train_oov_flags = add_oov_flag(train["token"].values, embeddings)
val_oov_flags = add_oov_flag(val["token"].values, embeddings)
test_oov_flags = add_oov_flag(test["token"].values, embeddings)
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/192008 [00:00<?, ?it/s]
#   0%|          | 0/21405 [00:00<?, ?it/s]
#   0%|          | 0/53239 [00:00<?, ?it/s]

# %% [markdown]
# ## Concate OOV Flag

# %%
id_pos_tag_df = pd.concat([id_pos_tag, id_pos_tag_oov_flags], axis=1)
train_df = pd.concat([train, train_oov_flags], axis=1)
val_df = pd.concat([val, val_oov_flags], axis=1)
test_df = pd.concat([test, test_oov_flags], axis=1)

# %% [markdown]
# ## Lowercase OOV Token

# %%
id_pos_tag_df['token'] = np.where(id_pos_tag_df['is_oov'] == True, id_pos_tag_df['token'].str.lower(), id_pos_tag_df['token'])
train_df['token'] = np.where(train_df['is_oov'] == True, train_df['token'].str.lower(), train_df['token'])
val_df['token'] = np.where(val_df['is_oov'] == True, val_df['token'].str.lower(), val_df['token'])
test_df['token'] = np.where(test_df['is_oov'] == True, test_df['token'].str.lower(), test_df['token'])

# %% [markdown]
# ## Embedding Dict, Index to Token and Token to Index

# %%
tokens = list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None))

def embedding_dict(tokens, embeddings, oov_embeddings):
    embedding = {}
    
    for token in tokens:
        if token[0] is not np.nan:
            if token[2] == False or token[0] in embeddings:
                embedding[token[0]] = embeddings[token[0]]
            else:
                embedding[token[0]] = oov_embeddings[token[0].lower()]

    return embedding

embedding_dict = embedding_dict(tokens, embeddings, oov_embeddings)
embedding_dict["<PAD>"] = embeddings["<PAD>"]
word_embeddings = nn.Embedding.from_pretrained(torch.FloatTensor(np.array(list(embedding_dict.values()))), padding_idx=list(embedding_dict.keys()).index("<PAD>"), freeze=True)

idx_to_token = {idx: token for idx, token in enumerate(list(embedding_dict.keys()))}
token_to_idx = {token: idx for idx, token in enumerate(list(embedding_dict.keys()))}

# %% [markdown]
# ## Token to Sentence

# %%
def make_sentence(tokens, max_length_sentence=hyperparams.max_seq_len):
    sentence = []
    sentences = []

    for token in tqdm(tokens):
        if token[0] is not np.nan:
            sentence.append(token)
        else:
            sentences.append(sentence[:max_length_sentence])
            sentence = []

    return sentences

all_sentence = make_sentence(list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
train_sentences = make_sentence(list(train_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
val_sentences = make_sentence(list(test_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
test_sentences = make_sentence(list(val_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/192008 [00:00<?, ?it/s]
#   0%|          | 0/53239 [00:00<?, ?it/s]
#   0%|          | 0/21405 [00:00<?, ?it/s]

# %% [markdown]
# ## Word Token, Padding, and Word token to Index

# %%
def tokenize_docs(docs, idx_token):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token[idx_token])
        sentences.append(new_sentence)
        new_sentence = []

    return sentences

def padding(docs, max_seq_len=hyperparams.max_seq_len, mode="post", val_pad="<PAD>"):
    docs = deepcopy(docs)
    doc_with_pad = []
    docs_with_pad = []

    for doc in tqdm(docs):
        if mode == "pre":
            for _ in range(max_seq_len - len(doc)):
                doc.insert(0, val_pad)
        elif mode == "post":
            for _ in range(max_seq_len - len(doc)):
                doc.append(val_pad)
        else:
            return f"Mode {mode} is not available, use instead 'pre' or 'post'."
        
        docs_with_pad.append(doc)
        
    return np.array(docs_with_pad)

def sent_to_idx(docs, token_to_idx):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token_to_idx[token])
        sentences.append(new_sentence)
        new_sentence = []

    return np.array(sentences)

def convert_feature_to_idx(docs, idx_token, token_to_idx, max_seq_len):
    sentences = tokenize_docs(docs, idx_token)
    sentences_with_pad = padding(sentences, max_seq_len=max_seq_len, mode="post", val_pad="<PAD>")
    sentences_to_idx = sent_to_idx(sentences_with_pad, token_to_idx)
    
    return sentences_to_idx

train_sentence_idxs = convert_feature_to_idx(train_sentences, 0, token_to_idx, hyperparams.max_seq_len)
val_sentence_idxs = convert_feature_to_idx(val_sentences, 0, token_to_idx, hyperparams.max_seq_len)
test_sentence_idxs = convert_feature_to_idx(test_sentences, 0, token_to_idx, hyperparams.max_seq_len)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]

# %% [markdown]
# ## Encode Class

# %%
classes = sorted(np.delete(id_pos_tag_df["tag"].unique(), 3))
idx_to_label = {idx: label for idx, label in enumerate(classes + ["<PAD>"])}
label_to_idx = {label: idx for idx, label in enumerate(classes + ["<PAD>"])}

def encode_class(docs, label_to_idx, seq_len=hyperparams.max_seq_len):
    class_idxs = []
    classes = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            class_idxs.append(label_to_idx[token[1]])
            
        for _ in range(seq_len - len(sentence)):
            class_idxs.append(label_to_idx["<PAD>"])
                
        classes.append(class_idxs)
        class_idxs = []

    return np.array(classes)
        
train_class_idxs = encode_class(train_sentences, label_to_idx)
val_class_idxs = encode_class(val_sentences, label_to_idx)
test_class_idxs = encode_class(test_sentences, label_to_idx)

print(f"Training shape   : {train_sentence_idxs.shape, train_class_idxs.shape}")
print(f"validation shape : {val_class_idxs.shape, val_class_idxs.shape}")
print(f"Test shape       : {test_sentence_idxs.shape, test_class_idxs.shape}")
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# Training shape   : ((7222, 82), (7222, 82))
# validation shape : ((2006, 82), (2006, 82))
# Test shape       : ((802, 82), (802, 82))

# %% [markdown]
# ## Note
#
# - Number of sentences = 10030
# - Train : 72% (7222)
# - Val   : 8% (802)
# - Test  : 20% (2006)

# %% [markdown]
# # Build Model

# %% [markdown]
# ## Feature and Actual Class

# %%
train_feature = torch.LongTensor(train_sentence_idxs)
val_feature = torch.LongTensor(val_sentence_idxs)
test_feature = torch.LongTensor(test_sentence_idxs)

train_class = torch.LongTensor(train_class_idxs)
val_class = torch.LongTensor(val_class_idxs)
test_class = torch.LongTensor(test_class_idxs)

# %%
train_feature.shape, val_feature.shape, test_feature.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %%
train_class.shape, val_class.shape, test_class.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %% [markdown]
# ## Tensor Dataset

# %%
train_dataset = TensorDataset(train_feature, train_class)
val_dataset = TensorDataset(val_feature, val_class)
test_dataset = TensorDataset(test_feature, test_class)

# %% [markdown]
# ## Dataloader

# %%
train_dataloader = DataLoader(train_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
val_dataloader = DataLoader(val_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
test_dataloader = DataLoader(test_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)

# %% [markdown]
# ## Model

# %%
class POSTagger(nn.Module):
    def __init__(
        self,
        input_size=hyperparams.input_size,
        hidden_size=hyperparams.hidden_size,
        dropout=hyperparams.dropout,
        bias=hyperparams.bias,
        num_layers=hyperparams.num_hidden_layer,
        output_size=hyperparams.output_size,
        batch_first=hyperparams.batch_first,
        bidirectional=hyperparams.bidirectional,
        init_wb_with_kaiming_normal=hyperparams.init_wb_with_kaiming_normal
    ):
        super(POSTagger, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.num_layers = num_layers
        self.output_size = output_size
        self.batch_first = batch_first
        self.bidirectional = bidirectional
                
        self.feature = nn.LSTM(
            input_size = self.input_size,
            hidden_size = self.hidden_size,
            bias = self.bias,
            dropout = self.dropout,
            num_layers = self.num_layers,
            batch_first = self.batch_first,
            bidirectional = self.bidirectional
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(in_features=2 * self.hidden_size if hyperparams.bidirectional else self.hidden_size, out_features=self.output_size, bias=self.bias),
            nn.Softmax(dim=-1)
        )
        
        if init_wb_with_kaiming_normal:
            self.init_wb()

    def init_wb(self):
        for module in self.modules():
            if isinstance(module, (nn.Linear, nn.LSTM)):
                for name, param in module.named_parameters():
                    if "weight" in name:
                        nn.init.kaiming_normal_(param)
                    else:
                        nn.init.kaiming_normal_(param.reshape(1, -1))
        
    def forward(self, feature, hidden=None):
        output, (hidden, memory) = self.feature(feature, None)
        prob = self.classifier(output)

        return prob
    
model = POSTagger().to(hyperparams.device)
model
# Out:
# POSTagger(
#   (feature): LSTM(64, 128, bidirectional=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=24, bias=True)
#     (1): Softmax(dim=-1)
#   )
# )

# %% [markdown]
# ## Optimizer, Criterion, and Metric

# %%
optimizer = optim.Adam(model.parameters(), lr=hyperparams.lr)
criterion = nn.CrossEntropyLoss().to(hyperparams.device)
train_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", verbose=True, factor=0.5)

# %%
sum(param.numel() for param in model.parameters() if param.requires_grad)
# Out:
# 204824

# %% [markdown]
# ## Training Step

# %%
def training_step(dataloader, model, optimizer, criterion, metric, scheduler=None):
    model.train()
    
    batch_losses = []
    batch_metric_scores = []
    
    for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
        # Forward Propagation
        feature = rearrange(feature, "n s -> s n")
        actual_label = rearrange(actual_label, "n s -> s n")
        embedding = word_embeddings(feature)
        
        prob = model(
            embedding.to(hyperparams.device),
            actual_label.to(hyperparams.device)
        )
        
        prob = prob.reshape(-1, prob.shape[-1])
        actual_label = actual_label.reshape(-1)

        loss = criterion(prob, actual_label.to(hyperparams.device))
        metric_score = metric(prob, actual_label.to(hyperparams.device))
        metric_score = metric.compute()
                
        if scheduler is not None:
            scheduler.step(loss)
        
        batch_losses.append(loss.item())
        batch_metric_scores.append(metric_score)
        
        if len(dataloader) < 10:
            if batch % 1 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
        else:
            if batch % 15 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            
        # Backward Propagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Validation Step

# %%
def validation_step(dataloader, model, criterion, metric):
    model.eval()
    
    batch_losses = []
    batch_metric_scores = []
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob, actual_label.to(hyperparams.device))
            metric_score = metric.compute()

            batch_losses.append(loss.item())
            batch_metric_scores.append(metric_score)
            
            if len(dataloader) < 10 and (batch % 1 == 0 or batch == len(dataloader)):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            else:
                if batch % 15 == 0 or batch == len(dataloader):
                    batch_name = "Batch-" + str(batch)
                    print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                    with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                        f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Looping Step

# %%
now = datetime.now(pytz.timezone("Asia/Ujung_Pandang"))
path_name = now.strftime("%m-%d-%Y_%H-%M-%S")
root_path = f"../../../logs/classifier/{hyperparams.context_size}_contexts/fold_0{hyperparams.fold}/{path_name}"
os.makedirs(root_path)

def looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric, n_epoch=hyperparams.n_epoch, patience=hyperparams.patience, monitor="loss"):    
    start_time = time()
    
    epoch_training_losses = []
    epoch_training_metric_scores = []
    epoch_val_losses = []
    epoch_val_metric_scores = []
    patience_counter = 0
    
    # Hyperparameters
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write(f"HYPERPARAMETERS\n")
        f.write(f"{'-' * 80}\n")
        for name, value in vars(hyperparams).items():
            f.write(f"{name}: {value}\n")
        
        f.write("\n\nTRAINING PROGRESS\n")
        f.write(f"{'-' * 80}\n")
    
    # Training Progress
    for epoch in range(1, n_epoch + 1):
        print(f"EPOCH-{epoch}")
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"EPOCH-{epoch}\n")
            f.write(f"Training Step\n")
            
        # Training Step
        print("Training Step")
        batch_training_losses, batch_training_metric_scores = training_step(train_dataloader, model, optimizer, criterion, train_metric, scheduler=None)
        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))

        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))
        epoch_training_losses.append(epoch_training_loss.item())

        epoch_training_metric_score = torch.mean(torch.FloatTensor(batch_training_metric_scores))
        epoch_training_metric_scores.append(epoch_training_metric_score.item())
        
        # Validation Step
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"\nValidation Step\n")
            
        print("\nValidation Step")
        batch_val_losses, batch_val_metric_scores = validation_step(val_dataloader, model, criterion, val_metric)
        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))

        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))
        epoch_val_losses.append(epoch_val_loss.item())

        epoch_val_metric_score = torch.mean(torch.FloatTensor(batch_val_metric_scores))
        epoch_val_metric_scores.append(epoch_val_metric_score.item())
        
        with open(f"{root_path}/training_history.txt", "a") as f:
            if monitor == "loss":
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_losses[-1] < epoch_training_losses[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
            else:
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_metric_scores[-1] > epoch_training_metric_scores[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗\n")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
                    
            print("=" * 80, end="\n\n")
            
            f.write(f"{'=' * 80}\n\n")
            
            if patience_counter == patience:
                print(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                
                f.write(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                break
        
        train_metric.reset()
        val_metric.reset()
        
    finish_time = time()
    
    # Training plot 
    fig, (ax_loss, ax_metric_score) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    fig.suptitle(f"Training with context size = {hyperparams.context_size}")

    ax_loss.set_title("Loss")
    ax_loss.set_xlabel("Epoch")
    ax_loss.set_ylabel("Score")
    ax_loss.plot(epoch_training_losses, "green", label="Training")
    ax_loss.plot(epoch_val_losses, "orange", label="Validation")
    ax_loss.legend()
    ax_loss.grid()

    ax_metric_score.set_title("F1 Score")
    ax_metric_score.set_xlabel("Epoch")
    ax_metric_score.set_ylabel("Score")
    ax_metric_score.plot(epoch_training_metric_scores, "green", label="Training")
    ax_metric_score.plot(epoch_val_metric_scores, "orange", label="Validation")
    ax_metric_score.legend()
    ax_metric_score.grid()

    plt.savefig(f"{root_path}/training_plot.jpg", dpi=200)                        
    
    print("TRAINING SUMMARY")
    name_best_training_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_training_metric = f"Best {str(train_metric).split('(')[0]} validation".ljust(34)
    name_best_validation_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_validation_metric = f"Best {str(val_metric).split('(')[0]} validation".ljust(34)
    name_training_time = f"Training duration".ljust(34)
    name_training_date = f"Training date".ljust(34)
    
    print(f"{name_best_training_loss}: {best_training_loss:.4f}")
    print(f"{name_best_validation_loss}: {best_val_loss:.4f}")
    print(f"{name_best_training_metric}: {best_training_metric:.4f}")
    print(f"{name_best_validation_metric}: {best_val_metric:.4f}")
    print(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.")
    print(f"{name_training_date}: {now}")
    
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write("\nTRAINING SUMMARY\n")
        f.write(f"{'-' * 80}\n")
        f.write(f"{name_best_training_loss}: {best_training_loss:.4f}\n")
        f.write(f"{name_best_validation_loss}: {best_val_loss:.4f}\n")
        f.write(f"{name_best_training_metric}: {best_training_metric:.4f}\n")
        f.write(f"{name_best_validation_metric}: {best_val_metric:.4f}\n")
        f.write(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.\n")
        f.write(f"{name_training_date}: {now}\n")
    
    # Save epoch losses, epoch metric scores, model, state dict, and oov embedding dict
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_training_losses
    }).to_csv(f"{root_path}/training_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_training_metric_scores
    }).to_csv(f"{root_path}/training_metric_scores.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_val_losses
    }).to_csv(f"{root_path}/val_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_val_metric_scores
    }).to_csv(f"{root_path}/val_metric_scores.csv", index=False)    
    
    filename_model_params = f"{root_path}/model_params.pth"
    torch.save(best_state_dict, filename_model_params)
    
    return epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores

epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores = looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric)
# Out:
# EPOCH-1
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.4989 | MulticlassF1Score=0.1188
# Batch-30 : CrossEntropyLoss=2.4776 | MulticlassF1Score=0.1829
# Batch-45 : CrossEntropyLoss=2.4769 | MulticlassF1Score=0.2107
# Batch-60 : CrossEntropyLoss=2.4526 | MulticlassF1Score=0.2429
# Batch-75 : CrossEntropyLoss=2.4561 | MulticlassF1Score=0.2701
# Batch-90 : CrossEntropyLoss=2.4472 | MulticlassF1Score=0.2867
# Batch-105: CrossEntropyLoss=2.4524 | MulticlassF1Score=0.2996
# Batch-120: CrossEntropyLoss=2.4295 | MulticlassF1Score=0.3151
# Batch-135: CrossEntropyLoss=2.4320 | MulticlassF1Score=0.3319
# Batch-150: CrossEntropyLoss=2.4044 | MulticlassF1Score=0.3460
# Batch-165: CrossEntropyLoss=2.3948 | MulticlassF1Score=0.3628
# Batch-180: CrossEntropyLoss=2.3724 | MulticlassF1Score=0.3800
# Batch-195: CrossEntropyLoss=2.3670 | MulticlassF1Score=0.3960
# Batch-210: CrossEntropyLoss=2.3666 | MulticlassF1Score=0.4107
# Batch-225: CrossEntropyLoss=2.3509 | MulticlassF1Score=0.4270
# Batch-226: CrossEntropyLoss=2.3536 | MulticlassF1Score=0.4276
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3354 | MulticlassF1Score=0.6745
# Batch-30 : CrossEntropyLoss=2.3575 | MulticlassF1Score=0.6728
# Batch-45 : CrossEntropyLoss=2.3717 | MulticlassF1Score=0.6729
# Batch-60 : CrossEntropyLoss=2.3502 | MulticlassF1Score=0.6731
# Batch-63 : CrossEntropyLoss=2.3499 | MulticlassF1Score=0.6731
#
# Training   : Mean CrossEntropyLoss = 2.4357 | Mean MulticlassF1Score = 0.2941
# Validation : Mean CrossEntropyLoss = 2.3511 | Mean MulticlassF1Score = 0.6739
# ================================================================================
#
# EPOCH-2
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3433 | MulticlassF1Score=0.6738
# Batch-30 : CrossEntropyLoss=2.3508 | MulticlassF1Score=0.6736
# Batch-45 : CrossEntropyLoss=2.3541 | MulticlassF1Score=0.6754
# Batch-60 : CrossEntropyLoss=2.3500 | MulticlassF1Score=0.6764
# Batch-75 : CrossEntropyLoss=2.3408 | MulticlassF1Score=0.6770
# Batch-90 : CrossEntropyLoss=2.3307 | MulticlassF1Score=0.6788
# Batch-105: CrossEntropyLoss=2.3388 | MulticlassF1Score=0.6842
# Batch-120: CrossEntropyLoss=2.3271 | MulticlassF1Score=0.6876
# Batch-135: CrossEntropyLoss=2.3258 | MulticlassF1Score=0.6949
# Batch-150: CrossEntropyLoss=2.3186 | MulticlassF1Score=0.7032
# Batch-165: CrossEntropyLoss=2.3184 | MulticlassF1Score=0.7101
# Batch-180: CrossEntropyLoss=2.3189 | MulticlassF1Score=0.7154
# Batch-195: CrossEntropyLoss=2.3107 | MulticlassF1Score=0.7202
# Batch-210: CrossEntropyLoss=2.3209 | MulticlassF1Score=0.7253
# Batch-225: CrossEntropyLoss=2.3125 | MulticlassF1Score=0.7299
# Batch-226: CrossEntropyLoss=2.3143 | MulticlassF1Score=0.7300
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3139 | MulticlassF1Score=0.7886
# Batch-30 : CrossEntropyLoss=2.3127 | MulticlassF1Score=0.7899
# Batch-45 : CrossEntropyLoss=2.3120 | MulticlassF1Score=0.7912
# Batch-60 : CrossEntropyLoss=2.3011 | MulticlassF1Score=0.7906
# Batch-63 : CrossEntropyLoss=2.2992 | MulticlassF1Score=0.7904
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3326 | Mean MulticlassF1Score = 0.6939
# Validation : Mean CrossEntropyLoss = 2.3130 | Mean MulticlassF1Score = 0.7898
# ================================================================================
#
# EPOCH-3
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3056 | MulticlassF1Score=0.7955
# Batch-30 : CrossEntropyLoss=2.3174 | MulticlassF1Score=0.7924
# Batch-45 : CrossEntropyLoss=2.3148 | MulticlassF1Score=0.7926
# Batch-60 : CrossEntropyLoss=2.3136 | MulticlassF1Score=0.7923
# Batch-75 : CrossEntropyLoss=2.3215 | MulticlassF1Score=0.7920
# Batch-90 : CrossEntropyLoss=2.3095 | MulticlassF1Score=0.7924
# Batch-105: CrossEntropyLoss=2.3094 | MulticlassF1Score=0.7924
# Batch-120: CrossEntropyLoss=2.3113 | MulticlassF1Score=0.7939
# Batch-135: CrossEntropyLoss=2.3187 | MulticlassF1Score=0.7938
# Batch-150: CrossEntropyLoss=2.3234 | MulticlassF1Score=0.7931
# Batch-165: CrossEntropyLoss=2.3108 | MulticlassF1Score=0.7934
# Batch-180: CrossEntropyLoss=2.3225 | MulticlassF1Score=0.7937
# Batch-195: CrossEntropyLoss=2.3003 | MulticlassF1Score=0.7938
# Batch-210: CrossEntropyLoss=2.3090 | MulticlassF1Score=0.7944
# Batch-225: CrossEntropyLoss=2.3204 | MulticlassF1Score=0.7942
# Batch-226: CrossEntropyLoss=2.3215 | MulticlassF1Score=0.7942
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3089 | MulticlassF1Score=0.7937
# Batch-30 : CrossEntropyLoss=2.3071 | MulticlassF1Score=0.7943
# Batch-45 : CrossEntropyLoss=2.3120 | MulticlassF1Score=0.7951
# Batch-60 : CrossEntropyLoss=2.3192 | MulticlassF1Score=0.7950
# Batch-63 : CrossEntropyLoss=2.3240 | MulticlassF1Score=0.7952
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3118 | Mean MulticlassF1Score = 0.7935
# Validation : Mean CrossEntropyLoss = 2.3113 | Mean MulticlassF1Score = 0.7934
# ================================================================================
#
# EPOCH-4
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3066 | MulticlassF1Score=0.7986
# Batch-30 : CrossEntropyLoss=2.3111 | MulticlassF1Score=0.8017
# Batch-45 : CrossEntropyLoss=2.3105 | MulticlassF1Score=0.8008
# Batch-60 : CrossEntropyLoss=2.3117 | MulticlassF1Score=0.7988
# Batch-75 : CrossEntropyLoss=2.3062 | MulticlassF1Score=0.7977
# Batch-90 : CrossEntropyLoss=2.3025 | MulticlassF1Score=0.7982
# Batch-105: CrossEntropyLoss=2.3112 | MulticlassF1Score=0.7985
# Batch-120: CrossEntropyLoss=2.3156 | MulticlassF1Score=0.7981
# Batch-135: CrossEntropyLoss=2.3016 | MulticlassF1Score=0.7983
# Batch-150: CrossEntropyLoss=2.3054 | MulticlassF1Score=0.7988
# Batch-165: CrossEntropyLoss=2.3027 | MulticlassF1Score=0.7986
# Batch-180: CrossEntropyLoss=2.3185 | MulticlassF1Score=0.7977
# Batch-195: CrossEntropyLoss=2.3108 | MulticlassF1Score=0.7975
# Batch-210: CrossEntropyLoss=2.3124 | MulticlassF1Score=0.7980
# Batch-225: CrossEntropyLoss=2.3097 | MulticlassF1Score=0.7977
# Batch-226: CrossEntropyLoss=2.2921 | MulticlassF1Score=0.7978
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3122 | MulticlassF1Score=0.7998
# Batch-30 : CrossEntropyLoss=2.3054 | MulticlassF1Score=0.7952
# Batch-45 : CrossEntropyLoss=2.3030 | MulticlassF1Score=0.7963
# Batch-60 : CrossEntropyLoss=2.3088 | MulticlassF1Score=0.7968
# Batch-63 : CrossEntropyLoss=2.3096 | MulticlassF1Score=0.7969
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3104 | Mean MulticlassF1Score = 0.7983
# Validation : Mean CrossEntropyLoss = 2.3104 | Mean MulticlassF1Score = 0.7971
# ================================================================================
#
# EPOCH-5
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3077 | MulticlassF1Score=0.8062
# Batch-30 : CrossEntropyLoss=2.3050 | MulticlassF1Score=0.8033
# Batch-45 : CrossEntropyLoss=2.2999 | MulticlassF1Score=0.8053
# Batch-60 : CrossEntropyLoss=2.3068 | MulticlassF1Score=0.8072
# Batch-75 : CrossEntropyLoss=2.3118 | MulticlassF1Score=0.8086
# Batch-90 : CrossEntropyLoss=2.2928 | MulticlassF1Score=0.8109
# Batch-105: CrossEntropyLoss=2.2965 | MulticlassF1Score=0.8142
# Batch-120: CrossEntropyLoss=2.3013 | MulticlassF1Score=0.8166
# Batch-135: CrossEntropyLoss=2.3089 | MulticlassF1Score=0.8194
# Batch-150: CrossEntropyLoss=2.2953 | MulticlassF1Score=0.8205
# Batch-165: CrossEntropyLoss=2.3001 | MulticlassF1Score=0.8217
# Batch-180: CrossEntropyLoss=2.3009 | MulticlassF1Score=0.8227
# Batch-195: CrossEntropyLoss=2.2887 | MulticlassF1Score=0.8240
# Batch-210: CrossEntropyLoss=2.2985 | MulticlassF1Score=0.8255
# Batch-225: CrossEntropyLoss=2.2994 | MulticlassF1Score=0.8258
# Batch-226: CrossEntropyLoss=2.2998 | MulticlassF1Score=0.8258
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2978 | MulticlassF1Score=0.8352
# Batch-30 : CrossEntropyLoss=2.3092 | MulticlassF1Score=0.8338
# Batch-45 : CrossEntropyLoss=2.3012 | MulticlassF1Score=0.8360
# Batch-60 : CrossEntropyLoss=2.2990 | MulticlassF1Score=0.8365
# Batch-63 : CrossEntropyLoss=2.2865 | MulticlassF1Score=0.8364
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3018 | Mean MulticlassF1Score = 0.8146
# Validation : Mean CrossEntropyLoss = 2.2983 | Mean MulticlassF1Score = 0.8349
# ================================================================================
#
# EPOCH-6
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2894 | MulticlassF1Score=0.8397
# Batch-30 : CrossEntropyLoss=2.2924 | MulticlassF1Score=0.8365
# Batch-45 : CrossEntropyLoss=2.2944 | MulticlassF1Score=0.8407
# Batch-60 : CrossEntropyLoss=2.3036 | MulticlassF1Score=0.8402
# Batch-75 : CrossEntropyLoss=2.3112 | MulticlassF1Score=0.8377
# Batch-90 : CrossEntropyLoss=2.3043 | MulticlassF1Score=0.8383
# Batch-105: CrossEntropyLoss=2.2896 | MulticlassF1Score=0.8394
# Batch-120: CrossEntropyLoss=2.2956 | MulticlassF1Score=0.8403
# Batch-135: CrossEntropyLoss=2.2918 | MulticlassF1Score=0.8410
# Batch-150: CrossEntropyLoss=2.2918 | MulticlassF1Score=0.8409
# Batch-165: CrossEntropyLoss=2.3032 | MulticlassF1Score=0.8410
# Batch-180: CrossEntropyLoss=2.2984 | MulticlassF1Score=0.8412
# Batch-195: CrossEntropyLoss=2.3011 | MulticlassF1Score=0.8405
# Batch-210: CrossEntropyLoss=2.3047 | MulticlassF1Score=0.8403
# Batch-225: CrossEntropyLoss=2.2928 | MulticlassF1Score=0.8398
# Batch-226: CrossEntropyLoss=2.2909 | MulticlassF1Score=0.8400
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2973 | MulticlassF1Score=0.8337
# Batch-30 : CrossEntropyLoss=2.2883 | MulticlassF1Score=0.8348
# Batch-45 : CrossEntropyLoss=2.3003 | MulticlassF1Score=0.8359
# Batch-60 : CrossEntropyLoss=2.2985 | MulticlassF1Score=0.8371
# Batch-63 : CrossEntropyLoss=2.3015 | MulticlassF1Score=0.8371
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2972 | Mean MulticlassF1Score = 0.8396
# Validation : Mean CrossEntropyLoss = 2.2980 | Mean MulticlassF1Score = 0.8363
# ================================================================================
#
# EPOCH-7
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3089 | MulticlassF1Score=0.8418
# Batch-30 : CrossEntropyLoss=2.2885 | MulticlassF1Score=0.8424
# Batch-45 : CrossEntropyLoss=2.3014 | MulticlassF1Score=0.8400
# Batch-60 : CrossEntropyLoss=2.2899 | MulticlassF1Score=0.8398
# Batch-75 : CrossEntropyLoss=2.2919 | MulticlassF1Score=0.8413
# Batch-90 : CrossEntropyLoss=2.3016 | MulticlassF1Score=0.8417
# Batch-105: CrossEntropyLoss=2.3009 | MulticlassF1Score=0.8422
# Batch-120: CrossEntropyLoss=2.2974 | MulticlassF1Score=0.8420
# Batch-135: CrossEntropyLoss=2.2965 | MulticlassF1Score=0.8415
# Batch-150: CrossEntropyLoss=2.3004 | MulticlassF1Score=0.8419
# Batch-165: CrossEntropyLoss=2.2890 | MulticlassF1Score=0.8437
# Batch-180: CrossEntropyLoss=2.2903 | MulticlassF1Score=0.8446
# Batch-195: CrossEntropyLoss=2.2830 | MulticlassF1Score=0.8455
# Batch-210: CrossEntropyLoss=2.2971 | MulticlassF1Score=0.8462
# Batch-225: CrossEntropyLoss=2.2939 | MulticlassF1Score=0.8468
# Batch-226: CrossEntropyLoss=2.2908 | MulticlassF1Score=0.8468
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2905 | MulticlassF1Score=0.8535
# Batch-30 : CrossEntropyLoss=2.3051 | MulticlassF1Score=0.8523
# Batch-45 : CrossEntropyLoss=2.2900 | MulticlassF1Score=0.8535
# Batch-60 : CrossEntropyLoss=2.2930 | MulticlassF1Score=0.8535
# Batch-63 : CrossEntropyLoss=2.2954 | MulticlassF1Score=0.8530
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2952 | Mean MulticlassF1Score = 0.8427
# Validation : Mean CrossEntropyLoss = 2.2934 | Mean MulticlassF1Score = 0.8541
# ================================================================================
#
# EPOCH-8
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2968 | MulticlassF1Score=0.8556
# Batch-30 : CrossEntropyLoss=2.2917 | MulticlassF1Score=0.8556
# Batch-45 : CrossEntropyLoss=2.2907 | MulticlassF1Score=0.8560
# Batch-60 : CrossEntropyLoss=2.2921 | MulticlassF1Score=0.8573
# Batch-75 : CrossEntropyLoss=2.2980 | MulticlassF1Score=0.8587
# Batch-90 : CrossEntropyLoss=2.3073 | MulticlassF1Score=0.8575
# Batch-105: CrossEntropyLoss=2.2956 | MulticlassF1Score=0.8577
# Batch-120: CrossEntropyLoss=2.2835 | MulticlassF1Score=0.8588
# Batch-135: CrossEntropyLoss=2.2917 | MulticlassF1Score=0.8588
# Batch-150: CrossEntropyLoss=2.2923 | MulticlassF1Score=0.8586
# Batch-165: CrossEntropyLoss=2.2943 | MulticlassF1Score=0.8589
# Batch-180: CrossEntropyLoss=2.2880 | MulticlassF1Score=0.8588
# Batch-195: CrossEntropyLoss=2.2940 | MulticlassF1Score=0.8585
# Batch-210: CrossEntropyLoss=2.2880 | MulticlassF1Score=0.8588
# Batch-225: CrossEntropyLoss=2.2989 | MulticlassF1Score=0.8588
# Batch-226: CrossEntropyLoss=2.2827 | MulticlassF1Score=0.8588
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2942 | MulticlassF1Score=0.8519
# Batch-30 : CrossEntropyLoss=2.2871 | MulticlassF1Score=0.8554
# Batch-45 : CrossEntropyLoss=2.2960 | MulticlassF1Score=0.8549
# Batch-60 : CrossEntropyLoss=2.2925 | MulticlassF1Score=0.8547
# Batch-63 : CrossEntropyLoss=2.2957 | MulticlassF1Score=0.8543
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2915 | Mean MulticlassF1Score = 0.8578
# Validation : Mean CrossEntropyLoss = 2.2928 | Mean MulticlassF1Score = 0.8540
# ================================================================================
#
# EPOCH-9
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2847 | MulticlassF1Score=0.8606
# Batch-30 : CrossEntropyLoss=2.2894 | MulticlassF1Score=0.8628
# Batch-45 : CrossEntropyLoss=2.2965 | MulticlassF1Score=0.8609
# Batch-60 : CrossEntropyLoss=2.2814 | MulticlassF1Score=0.8612
# Batch-75 : CrossEntropyLoss=2.2934 | MulticlassF1Score=0.8617
# Batch-90 : CrossEntropyLoss=2.2902 | MulticlassF1Score=0.8617
# Batch-105: CrossEntropyLoss=2.2967 | MulticlassF1Score=0.8607
# Batch-120: CrossEntropyLoss=2.2976 | MulticlassF1Score=0.8604
# Batch-135: CrossEntropyLoss=2.2933 | MulticlassF1Score=0.8602
# Batch-150: CrossEntropyLoss=2.2940 | MulticlassF1Score=0.8608
# Batch-165: CrossEntropyLoss=2.2919 | MulticlassF1Score=0.8600
# Batch-180: CrossEntropyLoss=2.2866 | MulticlassF1Score=0.8602
# Batch-195: CrossEntropyLoss=2.2963 | MulticlassF1Score=0.8602
# Batch-210: CrossEntropyLoss=2.2835 | MulticlassF1Score=0.8602
# Batch-225: CrossEntropyLoss=2.2851 | MulticlassF1Score=0.8606
# Batch-226: CrossEntropyLoss=2.3045 | MulticlassF1Score=0.8605
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3010 | MulticlassF1Score=0.8521
# Batch-30 : CrossEntropyLoss=2.3042 | MulticlassF1Score=0.8533
# Batch-45 : CrossEntropyLoss=2.2911 | MulticlassF1Score=0.8541
# Batch-60 : CrossEntropyLoss=2.2838 | MulticlassF1Score=0.8550
# Batch-63 : CrossEntropyLoss=2.2974 | MulticlassF1Score=0.8545
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2909 | Mean MulticlassF1Score = 0.8605
# Validation : Mean CrossEntropyLoss = 2.2926 | Mean MulticlassF1Score = 0.8535
# ================================================================================
#
# EPOCH-10
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2866 | MulticlassF1Score=0.8671
# Batch-30 : CrossEntropyLoss=2.2895 | MulticlassF1Score=0.8670
# Batch-45 : CrossEntropyLoss=2.2903 | MulticlassF1Score=0.8670
# Batch-60 : CrossEntropyLoss=2.2892 | MulticlassF1Score=0.8662
# Batch-75 : CrossEntropyLoss=2.2929 | MulticlassF1Score=0.8655
# Batch-90 : CrossEntropyLoss=2.2965 | MulticlassF1Score=0.8639
# Batch-105: CrossEntropyLoss=2.2897 | MulticlassF1Score=0.8639
# Batch-120: CrossEntropyLoss=2.2972 | MulticlassF1Score=0.8626
# Batch-135: CrossEntropyLoss=2.2795 | MulticlassF1Score=0.8626
# Batch-150: CrossEntropyLoss=2.2971 | MulticlassF1Score=0.8631
# Batch-165: CrossEntropyLoss=2.2993 | MulticlassF1Score=0.8632
# Batch-180: CrossEntropyLoss=2.2960 | MulticlassF1Score=0.8631
# Batch-195: CrossEntropyLoss=2.2915 | MulticlassF1Score=0.8627
# Batch-210: CrossEntropyLoss=2.2957 | MulticlassF1Score=0.8627
# Batch-225: CrossEntropyLoss=2.2927 | MulticlassF1Score=0.8625
# Batch-226: CrossEntropyLoss=2.2898 | MulticlassF1Score=0.8625
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2859 | MulticlassF1Score=0.8553
# Batch-30 : CrossEntropyLoss=2.3012 | MulticlassF1Score=0.8538
# Batch-45 : CrossEntropyLoss=2.3002 | MulticlassF1Score=0.8559
# Batch-60 : CrossEntropyLoss=2.2901 | MulticlassF1Score=0.8550
# Batch-63 : CrossEntropyLoss=2.2813 | MulticlassF1Score=0.8558
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2902 | Mean MulticlassF1Score = 0.8641
# Validation : Mean CrossEntropyLoss = 2.2921 | Mean MulticlassF1Score = 0.8544
# ================================================================================
#
# EPOCH-11
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2888 | MulticlassF1Score=0.8671
# Batch-30 : CrossEntropyLoss=2.2968 | MulticlassF1Score=0.8636
# Batch-45 : CrossEntropyLoss=2.2866 | MulticlassF1Score=0.8628
# Batch-60 : CrossEntropyLoss=2.2966 | MulticlassF1Score=0.8627
# Batch-75 : CrossEntropyLoss=2.2865 | MulticlassF1Score=0.8640
# Batch-90 : CrossEntropyLoss=2.2833 | MulticlassF1Score=0.8644
# Batch-105: CrossEntropyLoss=2.2918 | MulticlassF1Score=0.8650
# Batch-120: CrossEntropyLoss=2.2884 | MulticlassF1Score=0.8650
# Batch-135: CrossEntropyLoss=2.2974 | MulticlassF1Score=0.8650
# Batch-150: CrossEntropyLoss=2.2930 | MulticlassF1Score=0.8648
# Batch-165: CrossEntropyLoss=2.2865 | MulticlassF1Score=0.8647
# Batch-180: CrossEntropyLoss=2.2901 | MulticlassF1Score=0.8643
# Batch-195: CrossEntropyLoss=2.2811 | MulticlassF1Score=0.8647
# Batch-210: CrossEntropyLoss=2.2866 | MulticlassF1Score=0.8644
# Batch-225: CrossEntropyLoss=2.2827 | MulticlassF1Score=0.8646
# Batch-226: CrossEntropyLoss=2.2937 | MulticlassF1Score=0.8646
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2853 | MulticlassF1Score=0.8570
# Batch-30 : CrossEntropyLoss=2.2892 | MulticlassF1Score=0.8552
# Batch-45 : CrossEntropyLoss=2.3020 | MulticlassF1Score=0.8577
# Batch-60 : CrossEntropyLoss=2.2846 | MulticlassF1Score=0.8572
# Batch-63 : CrossEntropyLoss=2.2981 | MulticlassF1Score=0.8570
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2895 | Mean MulticlassF1Score = 0.8645
# Validation : Mean CrossEntropyLoss = 2.2918 | Mean MulticlassF1Score = 0.8549
# ================================================================================
#
# EPOCH-12
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2903 | MulticlassF1Score=0.8682
# Batch-30 : CrossEntropyLoss=2.2911 | MulticlassF1Score=0.8667
# Batch-45 : CrossEntropyLoss=2.2899 | MulticlassF1Score=0.8676
# Batch-60 : CrossEntropyLoss=2.2875 | MulticlassF1Score=0.8674
# Batch-75 : CrossEntropyLoss=2.2916 | MulticlassF1Score=0.8686
# Batch-90 : CrossEntropyLoss=2.2834 | MulticlassF1Score=0.8722
# Batch-105: CrossEntropyLoss=2.2823 | MulticlassF1Score=0.8745
# Batch-120: CrossEntropyLoss=2.2797 | MulticlassF1Score=0.8771
# Batch-135: CrossEntropyLoss=2.2740 | MulticlassF1Score=0.8786
# Batch-150: CrossEntropyLoss=2.2813 | MulticlassF1Score=0.8798
# Batch-165: CrossEntropyLoss=2.2782 | MulticlassF1Score=0.8812
# Batch-180: CrossEntropyLoss=2.2872 | MulticlassF1Score=0.8816
# Batch-195: CrossEntropyLoss=2.2774 | MulticlassF1Score=0.8829
# Batch-210: CrossEntropyLoss=2.2807 | MulticlassF1Score=0.8836
# Batch-225: CrossEntropyLoss=2.2830 | MulticlassF1Score=0.8841
# Batch-226: CrossEntropyLoss=2.2881 | MulticlassF1Score=0.8841
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2907 | MulticlassF1Score=0.8868
# Batch-30 : CrossEntropyLoss=2.2888 | MulticlassF1Score=0.8835
# Batch-45 : CrossEntropyLoss=2.2919 | MulticlassF1Score=0.8826
# Batch-60 : CrossEntropyLoss=2.2865 | MulticlassF1Score=0.8830
# Batch-63 : CrossEntropyLoss=2.2879 | MulticlassF1Score=0.8835
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2838 | Mean MulticlassF1Score = 0.8751
# Validation : Mean CrossEntropyLoss = 2.2840 | Mean MulticlassF1Score = 0.8844
# ================================================================================
#
# EPOCH-13
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2863 | MulticlassF1Score=0.8967
# Batch-30 : CrossEntropyLoss=2.2747 | MulticlassF1Score=0.8943
# Batch-45 : CrossEntropyLoss=2.2832 | MulticlassF1Score=0.8963
# Batch-60 : CrossEntropyLoss=2.2898 | MulticlassF1Score=0.8957
# Batch-75 : CrossEntropyLoss=2.2812 | MulticlassF1Score=0.8967
# Batch-90 : CrossEntropyLoss=2.2806 | MulticlassF1Score=0.8992
# Batch-105: CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9017
# Batch-120: CrossEntropyLoss=2.2773 | MulticlassF1Score=0.9040
# Batch-135: CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9055
# Batch-150: CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9067
# Batch-165: CrossEntropyLoss=2.2774 | MulticlassF1Score=0.9078
# Batch-180: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9090
# Batch-195: CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9102
# Batch-210: CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9113
# Batch-225: CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9124
# Batch-226: CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9124
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9142
# Batch-30 : CrossEntropyLoss=2.2772 | MulticlassF1Score=0.9153
# Batch-45 : CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9151
# Batch-60 : CrossEntropyLoss=2.2784 | MulticlassF1Score=0.9146
# Batch-63 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9143
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2751 | Mean MulticlassF1Score = 0.9028
# Validation : Mean CrossEntropyLoss = 2.2744 | Mean MulticlassF1Score = 0.9138
# ================================================================================
#
# EPOCH-14
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9293
# Batch-30 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9272
# Batch-45 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9270
# Batch-60 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9268
# Batch-75 : CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9267
# Batch-90 : CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9273
# Batch-105: CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9274
# Batch-120: CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9277
# Batch-135: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9271
# Batch-150: CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9269
# Batch-165: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9266
# Batch-180: CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9269
# Batch-195: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9274
# Batch-210: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9271
# Batch-225: CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9267
# Batch-226: CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9268
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9181
# Batch-30 : CrossEntropyLoss=2.2822 | MulticlassF1Score=0.9155
# Batch-45 : CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9136
# Batch-60 : CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9151
# Batch-63 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9154
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2706 | Mean MulticlassF1Score = 0.9275
# Validation : Mean CrossEntropyLoss = 2.2739 | Mean MulticlassF1Score = 0.9157
# ================================================================================
#
# EPOCH-15
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9287
# Batch-30 : CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9308
# Batch-45 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9291
# Batch-60 : CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9296
# Batch-75 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9286
# Batch-90 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9289
# Batch-105: CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9297
# Batch-120: CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9289
# Batch-135: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9287
# Batch-150: CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9286
# Batch-165: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9286
# Batch-180: CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9287
# Batch-195: CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9288
# Batch-210: CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9289
# Batch-225: CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9283
# Batch-226: CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9282
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9171
# Batch-30 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9154
# Batch-45 : CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9169
# Batch-60 : CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9163
# Batch-63 : CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9163
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2700 | Mean MulticlassF1Score = 0.9290
# Validation : Mean CrossEntropyLoss = 2.2736 | Mean MulticlassF1Score = 0.9152
# ================================================================================
#
# EPOCH-16
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9333
# Batch-30 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9313
# Batch-45 : CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9307
# Batch-60 : CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9305
# Batch-75 : CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9315
# Batch-90 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9310
# Batch-105: CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9308
# Batch-120: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9307
# Batch-135: CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9300
# Batch-150: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9305
# Batch-165: CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9300
# Batch-180: CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9298
# Batch-195: CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9301
# Batch-210: CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9299
# Batch-225: CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9298
# Batch-226: CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9298
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2798 | MulticlassF1Score=0.9199
# Batch-30 : CrossEntropyLoss=2.2805 | MulticlassF1Score=0.9158
# Batch-45 : CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9160
# Batch-60 : CrossEntropyLoss=2.2770 | MulticlassF1Score=0.9168
# Batch-63 : CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9168
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2694 | Mean MulticlassF1Score = 0.9309
# Validation : Mean CrossEntropyLoss = 2.2733 | Mean MulticlassF1Score = 0.9181
# ================================================================================
#
# EPOCH-17
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9333
# Batch-30 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9317
# Batch-45 : CrossEntropyLoss=2.2785 | MulticlassF1Score=0.9311
# Batch-60 : CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9303
# Batch-75 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9314
# Batch-90 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9317
# Batch-105: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9317
# Batch-120: CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9316
# Batch-135: CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9320
# Batch-150: CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9315
# Batch-165: CrossEntropyLoss=2.2754 | MulticlassF1Score=0.9317
# Batch-180: CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9316
# Batch-195: CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9315
# Batch-210: CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9316
# Batch-225: CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9313
# Batch-226: CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9313
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2784 | MulticlassF1Score=0.9173
# Batch-30 : CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9168
# Batch-45 : CrossEntropyLoss=2.2831 | MulticlassF1Score=0.9168
# Batch-60 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9173
# Batch-63 : CrossEntropyLoss=2.2769 | MulticlassF1Score=0.9171
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2689 | Mean MulticlassF1Score = 0.9318
# Validation : Mean CrossEntropyLoss = 2.2732 | Mean MulticlassF1Score = 0.9166
# ================================================================================
#
# EPOCH-18
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9341
# Batch-30 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9333
# Batch-45 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9334
# Batch-60 : CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9321
# Batch-75 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9328
# Batch-90 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9321
# Batch-105: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9323
# Batch-120: CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9318
# Batch-135: CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9324
# Batch-150: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9329
# Batch-165: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9333
# Batch-180: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9332
# Batch-195: CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9326
# Batch-210: CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9325
# Batch-225: CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9325
# Batch-226: CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9325
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9212
# Batch-30 : CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9197
# Batch-45 : CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9187
# Batch-60 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9183
# Batch-63 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9182
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2685 | Mean MulticlassF1Score = 0.9329
# Validation : Mean CrossEntropyLoss = 2.2729 | Mean MulticlassF1Score = 0.9193
# ================================================================================
#
# EPOCH-19
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9345
# Batch-30 : CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9344
# Batch-45 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9343
# Batch-60 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9342
# Batch-75 : CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9334
# Batch-90 : CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9342
# Batch-105: CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9344
# Batch-120: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9350
# Batch-135: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9353
# Batch-150: CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9356
# Batch-165: CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9356
# Batch-180: CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9359
# Batch-195: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9360
# Batch-210: CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9361
# Batch-225: CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9361
# Batch-226: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9361
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9236
# Batch-30 : CrossEntropyLoss=2.2800 | MulticlassF1Score=0.9201
# Batch-45 : CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9212
# Batch-60 : CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9219
# Batch-63 : CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9224
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2674 | Mean MulticlassF1Score = 0.9351
# Validation : Mean CrossEntropyLoss = 2.2717 | Mean MulticlassF1Score = 0.9200
# ================================================================================
#
# EPOCH-20
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9392
# Batch-30 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9372
# Batch-45 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9391
# Batch-60 : CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9394
# Batch-75 : CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9398
# Batch-90 : CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9396
# Batch-105: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9393
# Batch-120: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9390
# Batch-135: CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9389
# Batch-150: CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9388
# Batch-165: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9386
# Batch-180: CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9384
# Batch-195: CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9386
# Batch-210: CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9387
# Batch-225: CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9385
# Batch-226: CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9385
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9216
# Batch-30 : CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9257
# Batch-45 : CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9234
# Batch-60 : CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9230
# Batch-63 : CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9229
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2667 | Mean MulticlassF1Score = 0.9388
# Validation : Mean CrossEntropyLoss = 2.2715 | Mean MulticlassF1Score = 0.9236
# ================================================================================
#
# EPOCH-21
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9391
# Batch-30 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9406
# Batch-45 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9397
# Batch-60 : CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9392
# Batch-75 : CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9396
# Batch-90 : CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9403
# Batch-105: CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9402
# Batch-120: CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9397
# Batch-135: CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9401
# Batch-150: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9400
# Batch-165: CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9396
# Batch-180: CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9399
# Batch-195: CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9398
# Batch-210: CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9396
# Batch-225: CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9393
# Batch-226: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9394
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2770 | MulticlassF1Score=0.9212
# Batch-30 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9246
# Batch-45 : CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9249
# Batch-60 : CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9232
# Batch-63 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9233
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2663 | Mean MulticlassF1Score = 0.9398
# Validation : Mean CrossEntropyLoss = 2.2713 | Mean MulticlassF1Score = 0.9235
# ================================================================================
#
# EPOCH-22
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9393
# Batch-30 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9409
# Batch-45 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9401
# Batch-60 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9403
# Batch-75 : CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9397
# Batch-90 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9395
# Batch-105: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9393
# Batch-120: CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9395
# Batch-135: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9393
# Batch-150: CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9394
# Batch-165: CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9401
# Batch-180: CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9401
# Batch-195: CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9401
# Batch-210: CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9405
# Batch-225: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9405
# Batch-226: CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9405
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9237
# Batch-30 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9230
# Batch-45 : CrossEntropyLoss=2.2815 | MulticlassF1Score=0.9224
# Batch-60 : CrossEntropyLoss=2.2770 | MulticlassF1Score=0.9224
# Batch-63 : CrossEntropyLoss=2.2780 | MulticlassF1Score=0.9227
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2660 | Mean MulticlassF1Score = 0.9399
# Validation : Mean CrossEntropyLoss = 2.2715 | Mean MulticlassF1Score = 0.9219
# ================================================================================
#
# EPOCH-23
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9415
# Batch-30 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9400
# Batch-45 : CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9425
# Batch-60 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9415
# Batch-75 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9416
# Batch-90 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9416
# Batch-105: CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9417
# Batch-120: CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9420
# Batch-135: CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9422
# Batch-150: CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9419
# Batch-165: CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9418
# Batch-180: CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9420
# Batch-195: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9421
# Batch-210: CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9423
# Batch-225: CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9417
# Batch-226: CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9417
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2772 | MulticlassF1Score=0.9198
# Batch-30 : CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9246
# Batch-45 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9241
# Batch-60 : CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9236
# Batch-63 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9237
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2656 | Mean MulticlassF1Score = 0.9417
# Validation : Mean CrossEntropyLoss = 2.2711 | Mean MulticlassF1Score = 0.9244
# ================================================================================
#
# EPOCH-24
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9447
# Batch-30 : CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9453
# Batch-45 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9444
# Batch-60 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9436
# Batch-75 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9431
# Batch-90 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9425
# Batch-105: CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9426
# Batch-120: CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9428
# Batch-135: CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9430
# Batch-150: CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9428
# Batch-165: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9425
# Batch-180: CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9424
# Batch-195: CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9425
# Batch-210: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9423
# Batch-225: CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9424
# Batch-226: CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9425
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2754 | MulticlassF1Score=0.9248
# Batch-30 : CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9224
# Batch-45 : CrossEntropyLoss=2.2783 | MulticlassF1Score=0.9235
# Batch-60 : CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9238
# Batch-63 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9231
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2653 | Mean MulticlassF1Score = 0.9434
# Validation : Mean CrossEntropyLoss = 2.2713 | Mean MulticlassF1Score = 0.9238
# ================================================================================
#
# EPOCH-25
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9430
# Batch-30 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9431
# Batch-45 : CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9433
# Batch-60 : CrossEntropyLoss=2.2756 | MulticlassF1Score=0.9425
# Batch-75 : CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9426
# Batch-90 : CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9416
# Batch-105: CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9426
# Batch-120: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9427
# Batch-135: CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9428
# Batch-150: CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9427
# Batch-165: CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9428
# Batch-180: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9430
# Batch-195: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9431
# Batch-210: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9432
# Batch-225: CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9433
# Batch-226: CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9433
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9260
# Batch-30 : CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9246
# Batch-45 : CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9247
# Batch-60 : CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9249
# Batch-63 : CrossEntropyLoss=2.2775 | MulticlassF1Score=0.9250
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2650 | Mean MulticlassF1Score = 0.9427
# Validation : Mean CrossEntropyLoss = 2.2708 | Mean MulticlassF1Score = 0.9255
# ================================================================================
#
# EPOCH-26
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9443
# Batch-30 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9449
# Batch-45 : CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9455
# Batch-60 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9455
# Batch-75 : CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9465
# Batch-90 : CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9464
# Batch-105: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9464
# Batch-120: CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9462
# Batch-135: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9463
# Batch-150: CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9465
# Batch-165: CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9468
# Batch-180: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9468
# Batch-195: CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9469
# Batch-210: CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9467
# Batch-225: CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9468
# Batch-226: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9468
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9276
# Batch-30 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9273
# Batch-45 : CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9279
# Batch-60 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9284
# Batch-63 : CrossEntropyLoss=2.2751 | MulticlassF1Score=0.9282
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2640 | Mean MulticlassF1Score = 0.9461
# Validation : Mean CrossEntropyLoss = 2.2698 | Mean MulticlassF1Score = 0.9274
# ================================================================================
#
# EPOCH-27
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9460
# Batch-30 : CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9483
# Batch-45 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9479
# Batch-60 : CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9478
# Batch-75 : CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9480
# Batch-90 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9488
# Batch-105: CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9485
# Batch-120: CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9487
# Batch-135: CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9487
# Batch-150: CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9484
# Batch-165: CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9484
# Batch-180: CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9487
# Batch-195: CrossEntropyLoss=2.2612 | MulticlassF1Score=0.9485
# Batch-210: CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9485
# Batch-225: CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9483
# Batch-226: CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9483
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9323
# Batch-30 : CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9296
# Batch-45 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9287
# Batch-60 : CrossEntropyLoss=2.2747 | MulticlassF1Score=0.9283
# Batch-63 : CrossEntropyLoss=2.2779 | MulticlassF1Score=0.9280
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2635 | Mean MulticlassF1Score = 0.9481
# Validation : Mean CrossEntropyLoss = 2.2698 | Mean MulticlassF1Score = 0.9293
# ================================================================================
#
# EPOCH-28
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9518
# Batch-30 : CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9493
# Batch-45 : CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9498
# Batch-60 : CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9490
# Batch-75 : CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9487
# Batch-90 : CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9485
# Batch-105: CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9483
# Batch-120: CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9485
# Batch-135: CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9486
# Batch-150: CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9482
# Batch-165: CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9483
# Batch-180: CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9483
# Batch-195: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9484
# Batch-210: CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9486
# Batch-225: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9489
# Batch-226: CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9488
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9312
# Batch-30 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9297
# Batch-45 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9296
# Batch-60 : CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9287
# Batch-63 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9290
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2633 | Mean MulticlassF1Score = 0.9486
# Validation : Mean CrossEntropyLoss = 2.2695 | Mean MulticlassF1Score = 0.9300
# ================================================================================
#
# EPOCH-29
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9508
# Batch-30 : CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9493
# Batch-45 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9488
# Batch-60 : CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9494
# Batch-75 : CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9498
# Batch-90 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9495
# Batch-105: CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9490
# Batch-120: CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9489
# Batch-135: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9493
# Batch-150: CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9492
# Batch-165: CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9487
# Batch-180: CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9488
# ...
# Batch-45 : CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9485
# Batch-60 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9489
# Batch-63 : CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9492
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2566 | Mean MulticlassF1Score = 0.9704
# Validation : Mean CrossEntropyLoss = 2.2632 | Mean MulticlassF1Score = 0.9478
# ================================================================================
#
# EPOCH-42
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9719
# Batch-30 : CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9709
# Batch-45 : CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9722
# Batch-60 : CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9725
# Batch-75 : CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9723
# Batch-90 : CrossEntropyLoss=2.2541 | MulticlassF1Score=0.9720
# Batch-105: CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9717
# Batch-120: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9717
# Batch-135: CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9717
# Batch-150: CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9716
# Batch-165: CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9718
# Batch-180: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9716
# Batch-195: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9715
# Batch-210: CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9715
# Batch-225: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9717
# Batch-226: CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9717
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9499
# Batch-30 : CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9506
# Batch-45 : CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9507
# Batch-60 : CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9498
# Batch-63 : CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9502
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2562 | Mean MulticlassF1Score = 0.9719
# Validation : Mean CrossEntropyLoss = 2.2630 | Mean MulticlassF1Score = 0.9501
# ================================================================================
#
# EPOCH-43
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9729
# Batch-30 : CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9720
# Batch-45 : CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9728
# Batch-60 : CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9726
# Batch-75 : CrossEntropyLoss=2.2535 | MulticlassF1Score=0.9729
# Batch-90 : CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9728
# Batch-105: CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9725
# Batch-120: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9724
# Batch-135: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9724
# Batch-150: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9723
# Batch-165: CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9722
# Batch-180: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9722
# Batch-195: CrossEntropyLoss=2.2529 | MulticlassF1Score=0.9722
# Batch-210: CrossEntropyLoss=2.2536 | MulticlassF1Score=0.9722
# Batch-225: CrossEntropyLoss=2.2526 | MulticlassF1Score=0.9720
# Batch-226: CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9720
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9463
# Batch-30 : CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9479
# Batch-45 : CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9484
# Batch-60 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9495
# Batch-63 : CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9496
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2561 | Mean MulticlassF1Score = 0.9723
# Validation : Mean CrossEntropyLoss = 2.2631 | Mean MulticlassF1Score = 0.9484
# ================================================================================
#
# EPOCH-44
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9746
# Batch-30 : CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9738
# Batch-45 : CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9727
# Batch-60 : CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9722
# Batch-75 : CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9726
# Batch-90 : CrossEntropyLoss=2.2535 | MulticlassF1Score=0.9731
# Batch-105: CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9727
# Batch-120: CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9722
# Batch-135: CrossEntropyLoss=2.2603 | MulticlassF1Score=0.9721
# Batch-150: CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9723
# Batch-165: CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9724
# Batch-180: CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9725
# Batch-195: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9725
# Batch-210: CrossEntropyLoss=2.2528 | MulticlassF1Score=0.9725
# Batch-225: CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9726
# Batch-226: CrossEntropyLoss=2.2504 | MulticlassF1Score=0.9726
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9499
# Batch-30 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9520
# Batch-45 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9504
# Batch-60 : CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9499
# Batch-63 : CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9495
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2558 | Mean MulticlassF1Score = 0.9729
# Validation : Mean CrossEntropyLoss = 2.2632 | Mean MulticlassF1Score = 0.9504
# ================================================================================
#
# EPOCH-45
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2538 | MulticlassF1Score=0.9762
# Batch-30 : CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9741
# Batch-45 : CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9722
# Batch-60 : CrossEntropyLoss=2.2589 | MulticlassF1Score=0.9713
# Batch-75 : CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9709
# Batch-90 : CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9706
# Batch-105: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9701
# Batch-120: CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9696
# Batch-135: CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9698
# Batch-150: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9696
# Batch-165: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9696
# Batch-180: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9697
# Batch-195: CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9696
# Batch-210: CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9697
# Batch-225: CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9698
# Batch-226: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9698
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9494
# Batch-30 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9474
# Batch-45 : CrossEntropyLoss=2.2611 | MulticlassF1Score=0.9480
# Batch-60 : CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9485
# Batch-63 : CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9491
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2569 | Mean MulticlassF1Score = 0.9710
# Validation : Mean CrossEntropyLoss = 2.2633 | Mean MulticlassF1Score = 0.9480
# Patience = 5/50❗
# ================================================================================
#
# EPOCH-46
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9710
# Batch-30 : CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9716
# Batch-45 : CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9722
# Batch-60 : CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9725
# Batch-75 : CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9723
# Batch-90 : CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9713
# Batch-105: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9715
# Batch-120: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9716
# Batch-135: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9717
# Batch-150: CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9715
# Batch-165: CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9714
# Batch-180: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9712
# Batch-195: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9713
# Batch-210: CrossEntropyLoss=2.2536 | MulticlassF1Score=0.9713
# Batch-225: CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9713
# Batch-226: CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9713
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9495
# Batch-30 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9487
# Batch-45 : CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9486
# Batch-60 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9490
# Batch-63 : CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9492
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2564 | Mean MulticlassF1Score = 0.9716
# Validation : Mean CrossEntropyLoss = 2.2632 | Mean MulticlassF1Score = 0.9486
# ================================================================================
#
# EPOCH-47
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9718
# Batch-30 : CrossEntropyLoss=2.2524 | MulticlassF1Score=0.9724
# Batch-45 : CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9725
# Batch-60 : CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9726
# Batch-75 : CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9730
# Batch-90 : CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9728
# Batch-105: CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9725
# Batch-120: CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9722
# Batch-135: CrossEntropyLoss=2.2531 | MulticlassF1Score=0.9721
# Batch-150: CrossEntropyLoss=2.2535 | MulticlassF1Score=0.9721
# Batch-165: CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9720
# Batch-180: CrossEntropyLoss=2.2538 | MulticlassF1Score=0.9722
# Batch-195: CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9723
# Batch-210: CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9724
# Batch-225: CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9723
# Batch-226: CrossEntropyLoss=2.2597 | MulticlassF1Score=0.9722
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9447
# Batch-30 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9468
# Batch-45 : CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9475
# Batch-60 : CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9489
# Batch-63 : CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9494
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2560 | Mean MulticlassF1Score = 0.9723
# Validation : Mean CrossEntropyLoss = 2.2631 | Mean MulticlassF1Score = 0.9473
# ================================================================================
#
# EPOCH-48
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2520 | MulticlassF1Score=0.9750
# Batch-30 : CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9740
# Batch-45 : CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9739
# Batch-60 : CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9742
# Batch-75 : CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9740
# Batch-90 : CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9738
# Batch-105: CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9735
# Batch-120: CrossEntropyLoss=2.2544 | MulticlassF1Score=0.9733
# Batch-135: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9731
# Batch-150: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9729
# Batch-165: CrossEntropyLoss=2.2542 | MulticlassF1Score=0.9729
# Batch-180: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9727
# Batch-195: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9728
# Batch-210: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9727
# Batch-225: CrossEntropyLoss=2.2519 | MulticlassF1Score=0.9729
# Batch-226: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9728
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9504
# Batch-30 : CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9523
# Batch-45 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9498
# Batch-60 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9494
# Batch-63 : CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9494
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2558 | Mean MulticlassF1Score = 0.9735
# Validation : Mean CrossEntropyLoss = 2.2630 | Mean MulticlassF1Score = 0.9516
# ================================================================================
#
# EPOCH-49
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9724
# Batch-30 : CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9724
# Batch-45 : CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9727
# Batch-60 : CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9733
# Batch-75 : CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9729
# Batch-90 : CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9723
# Batch-105: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9725
# Batch-120: CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9723
# Batch-135: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9726
# Batch-150: CrossEntropyLoss=2.2540 | MulticlassF1Score=0.9728
# Batch-165: CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9725
# Batch-180: CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9729
# Batch-195: CrossEntropyLoss=2.2547 | MulticlassF1Score=0.9730
# Batch-210: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9732
# Batch-225: CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9733
# Batch-226: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9732
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9520
# Batch-30 : CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9503
# Batch-45 : CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9505
# Batch-60 : CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9496
# Batch-63 : CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9493
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2557 | Mean MulticlassF1Score = 0.9728
# Validation : Mean CrossEntropyLoss = 2.2631 | Mean MulticlassF1Score = 0.9514
# ================================================================================
#
# EPOCH-50
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2543 | MulticlassF1Score=0.9765
# Batch-30 : CrossEntropyLoss=2.2530 | MulticlassF1Score=0.9752
# Batch-45 : CrossEntropyLoss=2.2551 | MulticlassF1Score=0.9744
# Batch-60 : CrossEntropyLoss=2.2533 | MulticlassF1Score=0.9743
# Batch-75 : CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9741
# Batch-90 : CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9739
# Batch-105: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9736
# Batch-120: CrossEntropyLoss=2.2541 | MulticlassF1Score=0.9737
# Batch-135: CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9736
# Batch-150: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9736
# Batch-165: CrossEntropyLoss=2.2542 | MulticlassF1Score=0.9738
# Batch-180: CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9737
# Batch-195: CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9734
# Batch-210: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9735
# Batch-225: CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9734
# Batch-226: CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9734
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2622 | MulticlassF1Score=0.9511
# Batch-30 : CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9516
# Batch-45 : CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9495
# Batch-60 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9494
# Batch-63 : CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9495
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2556 | Mean MulticlassF1Score = 0.9742
# Validation : Mean CrossEntropyLoss = 2.2631 | Mean MulticlassF1Score = 0.9511
# ================================================================================
#
# TRAINING SUMMARY
# Best CrossEntropyLoss training    : 2.2556
# Best CrossEntropyLoss training    : 2.2631
# Best MulticlassF1Score validation : 0.9742
# Best MulticlassF1Score validation : 0.9511
# Training duration                 : 1.9513 minutes.
# Training date                     : 2022-10-19 10:49:29.905514+08:00

# %% [markdown]
# ## End Training

# %% [markdown]
# # Evaluation

# %%
def evaluation(dataloader, model, criterion, metric):
    model.eval()
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)
            pred = rearrange(prob.argmax(dim=1).reshape(feature.shape[0], len(dataloader.dataset)), "s n -> n s")

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob.argmax(dim=1), actual_label.to(hyperparams.device))
            metric_score = metric.compute()

    return loss, metric_score, pred

train_dataloader = DataLoader(train_dataset, batch_size=len(train_dataset))
val_dataloader = DataLoader(val_dataset, batch_size=len(val_dataset))
test_dataloader = DataLoader(test_dataset, batch_size=len(test_dataset))

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
train_loss, train_f1_score, train_pred_label = evaluation(train_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_loss, val_f1_score, val_pred_label = evaluation(val_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
test_loss, test_f1_score, test_pred_label = evaluation(test_dataloader, model, criterion, metric)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9737, device='cuda:0'),
#  tensor(0.9495, device='cuda:0'),
#  tensor(0.9497, device='cuda:0'))

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9737, device='cuda:0'),
#  tensor(0.9495, device='cuda:0'),
#  tensor(0.9497, device='cuda:0'))

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns

def viz_evaluation(pred_label, actual_label, title):
    plt.figure(figsize=(15, 7), dpi=200)
    sns.heatmap(pred_label.detach().cpu() == actual_label, cbar=True, cmap="binary_r")
    plt.xlabel("Sentence Length")
    plt.ylabel("Sentence")
    plt.title(title)
    plt.savefig(f"{root_path}/heatmap_{title.lower()}.jpg", dpi=200)
    plt.show()

train_actual_label = train_dataloader.dataset.tensors[1]
val_actual_label = val_dataloader.dataset.tensors[1]
test_actual_label = test_dataloader.dataset.tensors[1]

viz_evaluation(train_pred_label, train_actual_label, f"Training (F1-Score: {(train_f1_score):.4f})")
viz_evaluation(val_pred_label, val_actual_label, f"Validation (F1-Score: {(val_f1_score):.4f})")
viz_evaluation(test_pred_label, test_actual_label, f"Test (F1-Score: {(test_f1_score):.4f})")

# %% [markdown]
# ## Confusion Matrix

# %%
def confusion_matrix(pred_class, actual_class, title, normalize=None):
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize=normalize)
    plt.figure(figsize=(20, 10), dpi=200)
    sns.heatmap(conf_mat(pred_class.detach().cpu(), actual_class), annot=True, fmt=".2g", xticklabels=list(label_to_idx.keys()), yticklabels=list(label_to_idx.keys()));
    plt.yticks(rotation=0)
    plt.title(title)
    plt.xlabel("Actual Class")
    plt.ylabel("Predict Class")
    plt.savefig(f"{root_path}/conf_matrix_{title.lower()}.jpg", dpi=200)

confusion_matrix(train_pred_label, train_actual_label, "Training", "pred")
confusion_matrix(val_pred_label,val_actual_label, "Validation", "pred")
confusion_matrix(test_pred_label, test_actual_label, "Test", "pred")
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 120 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)

# %% [markdown]
# ## Prediction Table

# %%
def number_wrong_pred_each_class(pred_class, actual_class):
    classes, count_class = actual_class.flatten().unique(return_counts=True)
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize="none")
    correct_pred_count_class = conf_mat(pred_class.detach().cpu(), actual_class).diag()
    
    correct_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (correct_pred_count_class))}
    wrong_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (count_class - correct_pred_count_class))}
    
    return correct_pred, wrong_pred

correct_pred, wrong_pred = number_wrong_pred_each_class(train_pred_label, train_actual_label)
print(f"| {'Number class'.ljust(14)} | {'Correct prediction'.ljust(12)} | {'Wrong prediction'.ljust(12)} |")
for (label_correct_pred, count_correct_pred), (label_wrong_pred, count_wrong_pred) in zip(correct_pred.items(), wrong_pred.items()):
    print(f"| {str(label_correct_pred).ljust(6)}: {str(count_correct_pred + count_wrong_pred).ljust(7)}| {label_correct_pred.ljust(6)}: {str(count_correct_pred).ljust(10)} | {label_wrong_pred.ljust(6)}: {str(count_wrong_pred).ljust(8)} |")
# Out:
# | Number class   | Correct prediction | Wrong prediction |
# | CC    : 5336   | CC    : 5196       | CC    : 140      |
# | CD    : 12904  | CD    : 12815      | CD    : 89       |
# | DT    : 263    | DT    : 0          | DT    : 263      |
# | FW    : 1697   | FW    : 1488       | FW    : 209      |
# | IN    : 15290  | IN    : 15157      | IN    : 133      |
# | JJ    : 7049   | JJ    : 6732       | JJ    : 317      |
# | MD    : 3783   | MD    : 3726       | MD    : 57       |
# | NEG   : 1126   | NEG   : 0          | NEG   : 1126     |
# | NN    : 44769  | NN    : 44314      | NN    : 455      |
# | NND   : 998    | NND   : 928        | NND   : 70       |
# | NNP   : 24884  | NNP   : 24467      | NNP   : 417      |
# | OD    : 550    | OD    : 530        | OD    : 20       |
# | PR    : 3878   | PR    : 3718       | PR    : 160      |
# | PRP   : 5355   | PRP   : 5312       | PRP   : 43       |
# | RB    : 3517   | RB    : 3354       | RB    : 163      |
# | RP    : 131    | RP    : 0          | RP    : 131      |
# | SC    : 9467   | SC    : 9242       | SC    : 225      |
# | SYM   : 1570   | SYM   : 1526       | SYM   : 44       |
# | UH    : 21     | UH    : 0          | UH    : 21       |
# | VB    : 22796  | VB    : 22478      | VB    : 318      |
# | WH    : 180    | WH    : 13         | WH    : 167      |
# | X     : 282    | X     : 0          | X     : 282      |
# | Z     : 18940  | Z     : 18936      | Z     : 4        |
# | <PAD> : 407418 | <PAD> : 407418     | <PAD> : 0        |

# %%
train_actual_label[308], train_pred_label[308]
# Out:
# (tensor([ 8, 19, 22, 10, 22, 19, 10,  6, 19,  4,  1,  8, 16, 19,  8, 19,  0,  8,
#           5, 16, 19, 19,  8,  8, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23]),
#  tensor([ 8, 19, 22, 10, 22, 19, 10,  6, 19,  4,  1,  8, 16, 19,  8, 19,  0,  8,
#           5, 16, 19, 19,  8,  8, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23], device='cuda:0'))

# %%
train_actual_label[308] == train_pred_label[308].detach().cpu()
# Out:
# tensor([True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True])

# %% [markdown]
# ## OOV prediction is correct

# %%
def oov_flag_token(sentences, max_seq_len=hyperparams.max_seq_len):
    sent_copy = deepcopy(sentences)
    sent = []
    oov_flag = []
    
    for sentence in tqdm(sent_copy):
        for token in sentence:
            sent.append(token[2])
        
        for _ in range(max_seq_len- len(sentence)):
            sent.append(False)
        
        oov_flag.append(sent)
        sent = []
        
    return np.array(oov_flag)

train_oov_flag = oov_flag_token(train_sentences, max_seq_len=hyperparams.max_seq_len)
val_oov_flag = oov_flag_token(val_sentences, max_seq_len=hyperparams.max_seq_len)
test_oov_flag = oov_flag_token(test_sentences, max_seq_len=hyperparams.max_seq_len)

def pencentage_oov_pred_correct(pred_oov_flag, oov_flag_tensor):
    oov_correct_counter = 0
    oov_wrong_counter = 0

    for pred, oov_label in tqdm(zip(pred_oov_flag, oov_flag_tensor)):
        if pred == True and oov_label == True:
            oov_correct_counter += 1
        elif pred == False and oov_label == True:
            oov_wrong_counter += 1
        else:
            continue
            
    return oov_correct_counter, oov_wrong_counter

train_pred_oov_flag = (train_actual_label == train_pred_label.detach().cpu()).flatten()
val_pred_oov_flag = (val_actual_label == val_pred_label.detach().cpu()).flatten()
test_pred_oov_flag = (test_actual_label == test_pred_label.detach().cpu()).flatten()
train_oov_flag_tensor = torch.tensor(train_oov_flag).flatten()
val_oov_flag_tensor = torch.tensor(val_oov_flag).flatten()
test_oov_flag_tensor = torch.tensor(test_oov_flag).flatten()

train_oov_correct_counter, train_oov_wrong_counter = pencentage_oov_pred_correct(train_pred_oov_flag, train_oov_flag_tensor)
val_oov_correct_counter, val_oov_wrong_counter = pencentage_oov_pred_correct(val_pred_oov_flag, val_oov_flag_tensor)
test_oov_correct_counter, test_oov_wrong_counter = pencentage_oov_pred_correct(test_pred_oov_flag, test_oov_flag_tensor)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
def print_percentage_pred_oov(title, oov_correct_counter, oov_wrong_counter):
    print(f"{title}")
    print(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}")
    print(f"Correct prediction          : {oov_correct_counter}")
    print(f"Wrong prediction            : {oov_wrong_counter}")
    print(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n")
    
    with open(f"{root_path}/oov_summary.txt", "a") as f:
        f.write(f"{title}\n")
        f.write(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}\n")
        f.write(f"Correct prediction          : {oov_correct_counter}\n")
        f.write(f"Wrong prediction            : {oov_wrong_counter}\n")
        f.write(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n\n")

# %%
print_percentage_pred_oov("Training", train_oov_correct_counter, train_oov_wrong_counter)
print_percentage_pred_oov("Validation", val_oov_correct_counter, val_oov_wrong_counter)
print_percentage_pred_oov("Test", test_oov_correct_counter, test_oov_wrong_counter)
# Out:
# Training
# Number OOV token            : 11934
# Correct prediction          : 11362
# Wrong prediction            : 572
# Percentage correct oov pred : 95.20697167755992
#
# Validation
# Number OOV token            : 3261
# Correct prediction          : 2975
# Wrong prediction            : 286
# Percentage correct oov pred : 91.2296841459675
#
# Test
# Number OOV token            : 1367
# Correct prediction          : 1221
# Wrong prediction            : 146
# Percentage correct oov pred : 89.31967812728602

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(train_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(val_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(test_oov_flag, cmap=plt.cm.binary_r);
