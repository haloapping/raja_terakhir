# %% [markdown]
# # Import modules

# %%
import csv
import os
import pickle
import pytz
import torch
import timeit
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from copy import deepcopy
from datetime import datetime
from einops import rearrange
from itertools import chain
from time import time
from torch import nn, optim
from torchmetrics.classification import MulticlassAccuracy, MulticlassF1Score, MulticlassConfusionMatrix
from torch.optim import lr_scheduler
from tqdm.notebook import tqdm
from torch.utils.data import TensorDataset, DataLoader
from polyglot.mapping import Embedding, CaseExpander, DigitExpander

# %% [markdown]
# # Hyperparameters

# %%
class Hyperparams:
     def __init__(
        self,
        context_size=25,
        fold=3,
        max_seq_len=82,
        input_size=64,
        batch_size=32,
        num_hidden_layer=1,
        hidden_size=128,
        dropout=0,
        bias=True,
        output_size=24,
        shuffle=True,
        lr=0.005,
        batch_first=False,
        bidirectional=True,
        init_wb_with_kaiming_normal=True,
        n_epoch=50,
        patience=50,
        device="cuda" if torch.cuda.is_available() else "cpu"
    ):
        self.context_size = context_size
        self.fold = fold
        self.input_size = input_size
        self.max_seq_len = max_seq_len
        self.batch_size = batch_size
        self.num_hidden_layer = num_hidden_layer
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.output_size = output_size
        self.shuffle = shuffle
        self.lr = lr
        self.batch_first = batch_first
        self.bidirectional = bidirectional
        self.init_wb_with_kaiming_normal = init_wb_with_kaiming_normal
        self.n_epoch = n_epoch
        self.patience = patience
        self.device = device

hyperparams = Hyperparams()

# %% [markdown]
# # Dataset

# %%
id_pos_tag = pd.read_csv("../../../datasets/raw/Indonesian_Manually_Tagged_Corpus.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False) 
train = pd.read_csv(f"../../../datasets/raw/cv/train/train.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
val = pd.read_csv(f"../../../datasets/raw/cv/val/val.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
test = pd.read_csv(f"../../../datasets/raw/cv/test/test.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)

# %% [markdown]
# # Pre-trained Word Embedding

# %%
embeddings = Embedding.load("../../../word_embeddings/polyglot/idn_embeddings.tar.bz2")
embeddings.apply_expansion(DigitExpander)
embeddings.apply_expansion(CaseExpander)

oov_embeddings = pickle.load(open(f"../../../logs/comick/{hyperparams.context_size}_contexts/10-11-2022_12-21-42/oov_embedding_dict.pkl", "rb"))

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Add OOV Flag

# %%
def add_oov_flag(tokens, embeddings):
    oov_flags = []
    
    for token in tqdm(tokens):
        try:
            if token not in embeddings:
                oov_flags.append(True)
            else:
                oov_flags.append(False)
        except:
            oov_flags.append(False)
        
    return pd.DataFrame(oov_flags, columns=["is_oov"])

id_pos_tag_oov_flags = add_oov_flag(id_pos_tag["token"].values, embeddings)
train_oov_flags = add_oov_flag(train["token"].values, embeddings)
val_oov_flags = add_oov_flag(val["token"].values, embeddings)
test_oov_flags = add_oov_flag(test["token"].values, embeddings)
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/192215 [00:00<?, ?it/s]
#   0%|          | 0/21143 [00:00<?, ?it/s]
#   0%|          | 0/53294 [00:00<?, ?it/s]

# %% [markdown]
# ## Concate OOV Flag

# %%
id_pos_tag_df = pd.concat([id_pos_tag, id_pos_tag_oov_flags], axis=1)
train_df = pd.concat([train, train_oov_flags], axis=1)
val_df = pd.concat([val, val_oov_flags], axis=1)
test_df = pd.concat([test, test_oov_flags], axis=1)

# %% [markdown]
# ## Lowercase OOV Token

# %%
id_pos_tag_df['token'] = np.where(id_pos_tag_df['is_oov'] == True, id_pos_tag_df['token'].str.lower(), id_pos_tag_df['token'])
train_df['token'] = np.where(train_df['is_oov'] == True, train_df['token'].str.lower(), train_df['token'])
val_df['token'] = np.where(val_df['is_oov'] == True, val_df['token'].str.lower(), val_df['token'])
test_df['token'] = np.where(test_df['is_oov'] == True, test_df['token'].str.lower(), test_df['token'])

# %% [markdown]
# ## Embedding Dict, Index to Token and Token to Index

# %%
tokens = list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None))

def embedding_dict(tokens, embeddings, oov_embeddings):
    embedding = {}
    
    for token in tokens:
        if token[0] is not np.nan:
            if token[2] == False or token[0] in embeddings:
                embedding[token[0]] = embeddings[token[0]]
            else:
                embedding[token[0]] = oov_embeddings[token[0].lower()]

    return embedding

embedding_dict = embedding_dict(tokens, embeddings, oov_embeddings)
embedding_dict["<PAD>"] = embeddings["<PAD>"]
word_embeddings = nn.Embedding.from_pretrained(torch.FloatTensor(np.array(list(embedding_dict.values()))), padding_idx=list(embedding_dict.keys()).index("<PAD>"), freeze=True)

idx_to_token = {idx: token for idx, token in enumerate(list(embedding_dict.keys()))}
token_to_idx = {token: idx for idx, token in enumerate(list(embedding_dict.keys()))}

# %% [markdown]
# ## Token to Sentence

# %%
def make_sentence(tokens, max_length_sentence=hyperparams.max_seq_len):
    sentence = []
    sentences = []

    for token in tqdm(tokens):
        if token[0] is not np.nan:
            sentence.append(token)
        else:
            sentences.append(sentence[:max_length_sentence])
            sentence = []

    return sentences

all_sentence = make_sentence(list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
train_sentences = make_sentence(list(train_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
val_sentences = make_sentence(list(test_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
test_sentences = make_sentence(list(val_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/192215 [00:00<?, ?it/s]
#   0%|          | 0/53294 [00:00<?, ?it/s]
#   0%|          | 0/21143 [00:00<?, ?it/s]

# %% [markdown]
# ## Word Token, Padding, and Word token to Index

# %%
def tokenize_docs(docs, idx_token):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token[idx_token])
        sentences.append(new_sentence)
        new_sentence = []

    return sentences

def padding(docs, max_seq_len=hyperparams.max_seq_len, mode="post", val_pad="<PAD>"):
    docs = deepcopy(docs)
    doc_with_pad = []
    docs_with_pad = []

    for doc in tqdm(docs):
        if mode == "pre":
            for _ in range(max_seq_len - len(doc)):
                doc.insert(0, val_pad)
        elif mode == "post":
            for _ in range(max_seq_len - len(doc)):
                doc.append(val_pad)
        else:
            return f"Mode {mode} is not available, use instead 'pre' or 'post'."
        
        docs_with_pad.append(doc)
        
    return np.array(docs_with_pad)

def sent_to_idx(docs, token_to_idx):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token_to_idx[token])
        sentences.append(new_sentence)
        new_sentence = []

    return np.array(sentences)

def convert_feature_to_idx(docs, idx_token, token_to_idx, max_seq_len):
    sentences = tokenize_docs(docs, idx_token)
    sentences_with_pad = padding(sentences, max_seq_len=max_seq_len, mode="post", val_pad="<PAD>")
    sentences_to_idx = sent_to_idx(sentences_with_pad, token_to_idx)
    
    return sentences_to_idx

train_sentence_idxs = convert_feature_to_idx(train_sentences, 0, token_to_idx, hyperparams.max_seq_len)
val_sentence_idxs = convert_feature_to_idx(val_sentences, 0, token_to_idx, hyperparams.max_seq_len)
test_sentence_idxs = convert_feature_to_idx(test_sentences, 0, token_to_idx, hyperparams.max_seq_len)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]

# %% [markdown]
# ## Encode Class

# %%
classes = sorted(np.delete(id_pos_tag_df["tag"].unique(), 3))
idx_to_label = {idx: label for idx, label in enumerate(classes + ["<PAD>"])}
label_to_idx = {label: idx for idx, label in enumerate(classes + ["<PAD>"])}

def encode_class(docs, label_to_idx, seq_len=hyperparams.max_seq_len):
    class_idxs = []
    classes = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            class_idxs.append(label_to_idx[token[1]])
            
        for _ in range(seq_len - len(sentence)):
            class_idxs.append(label_to_idx["<PAD>"])
                
        classes.append(class_idxs)
        class_idxs = []

    return np.array(classes)
        
train_class_idxs = encode_class(train_sentences, label_to_idx)
val_class_idxs = encode_class(val_sentences, label_to_idx)
test_class_idxs = encode_class(test_sentences, label_to_idx)

print(f"Training shape   : {train_sentence_idxs.shape, train_class_idxs.shape}")
print(f"validation shape : {val_class_idxs.shape, val_class_idxs.shape}")
print(f"Test shape       : {test_sentence_idxs.shape, test_class_idxs.shape}")
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# Training shape   : ((7222, 82), (7222, 82))
# validation shape : ((2006, 82), (2006, 82))
# Test shape       : ((802, 82), (802, 82))

# %% [markdown]
# ## Note
#
# - Number of sentences = 10030
# - Train : 72% (7222)
# - Val   : 8% (802)
# - Test  : 20% (2006)

# %% [markdown]
# # Build Model

# %% [markdown]
# ## Feature and Actual Class

# %%
train_feature = torch.LongTensor(train_sentence_idxs)
val_feature = torch.LongTensor(val_sentence_idxs)
test_feature = torch.LongTensor(test_sentence_idxs)

train_class = torch.LongTensor(train_class_idxs)
val_class = torch.LongTensor(val_class_idxs)
test_class = torch.LongTensor(test_class_idxs)

# %%
train_feature.shape, val_feature.shape, test_feature.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %%
train_class.shape, val_class.shape, test_class.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %% [markdown]
# ## Tensor Dataset

# %%
train_dataset = TensorDataset(train_feature, train_class)
val_dataset = TensorDataset(val_feature, val_class)
test_dataset = TensorDataset(test_feature, test_class)

# %% [markdown]
# ## Dataloader

# %%
train_dataloader = DataLoader(train_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
val_dataloader = DataLoader(val_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
test_dataloader = DataLoader(test_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)

# %% [markdown]
# ## Model

# %%
class POSTagger(nn.Module):
    def __init__(
        self,
        input_size=hyperparams.input_size,
        hidden_size=hyperparams.hidden_size,
        dropout=hyperparams.dropout,
        bias=hyperparams.bias,
        num_layers=hyperparams.num_hidden_layer,
        output_size=hyperparams.output_size,
        batch_first=hyperparams.batch_first,
        bidirectional=hyperparams.bidirectional,
        init_wb_with_kaiming_normal=hyperparams.init_wb_with_kaiming_normal
    ):
        super(POSTagger, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.num_layers = num_layers
        self.output_size = output_size
        self.batch_first = batch_first
        self.bidirectional = bidirectional
                
        self.feature = nn.LSTM(
            input_size = self.input_size,
            hidden_size = self.hidden_size,
            bias = self.bias,
            dropout = self.dropout,
            num_layers = self.num_layers,
            batch_first = self.batch_first,
            bidirectional = self.bidirectional
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(in_features=2 * self.hidden_size if hyperparams.bidirectional else self.hidden_size, out_features=self.output_size, bias=self.bias),
            nn.Softmax(dim=-1)
        )
        
        if init_wb_with_kaiming_normal:
            self.init_wb()

    def init_wb(self):
        for module in self.modules():
            if isinstance(module, (nn.Linear, nn.LSTM)):
                for name, param in module.named_parameters():
                    if "weight" in name:
                        nn.init.kaiming_normal_(param)
                    else:
                        nn.init.kaiming_normal_(param.reshape(1, -1))
        
    def forward(self, feature, hidden=None):
        output, (hidden, memory) = self.feature(feature, None)
        prob = self.classifier(output)

        return prob
    
model = POSTagger().to(hyperparams.device)
model
# Out:
# POSTagger(
#   (feature): LSTM(64, 128, bidirectional=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=24, bias=True)
#     (1): Softmax(dim=-1)
#   )
# )

# %% [markdown]
# ## Optimizer, Criterion, and Metric

# %%
optimizer = optim.Adam(model.parameters(), lr=hyperparams.lr)
criterion = nn.CrossEntropyLoss().to(hyperparams.device)
train_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", verbose=True, factor=0.5)

# %%
sum(param.numel() for param in model.parameters() if param.requires_grad)
# Out:
# 204824

# %% [markdown]
# ## Training Step

# %%
def training_step(dataloader, model, optimizer, criterion, metric, scheduler=None):
    model.train()
    
    batch_losses = []
    batch_metric_scores = []
    
    for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
        # Forward Propagation
        feature = rearrange(feature, "n s -> s n")
        actual_label = rearrange(actual_label, "n s -> s n")
        embedding = word_embeddings(feature)
        
        prob = model(
            embedding.to(hyperparams.device),
            actual_label.to(hyperparams.device)
        )
        
        prob = prob.reshape(-1, prob.shape[-1])
        actual_label = actual_label.reshape(-1)

        loss = criterion(prob, actual_label.to(hyperparams.device))
        metric_score = metric(prob, actual_label.to(hyperparams.device))
        metric_score = metric.compute()
                
        if scheduler is not None:
            scheduler.step(loss)
        
        batch_losses.append(loss.item())
        batch_metric_scores.append(metric_score)
        
        if len(dataloader) < 10:
            if batch % 1 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
        else:
            if batch % 15 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            
        # Backward Propagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Validation Step

# %%
def validation_step(dataloader, model, criterion, metric):
    model.eval()
    
    batch_losses = []
    batch_metric_scores = []
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob, actual_label.to(hyperparams.device))
            metric_score = metric.compute()

            batch_losses.append(loss.item())
            batch_metric_scores.append(metric_score)
            
            if len(dataloader) < 10 and (batch % 1 == 0 or batch == len(dataloader)):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            else:
                if batch % 15 == 0 or batch == len(dataloader):
                    batch_name = "Batch-" + str(batch)
                    print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                    with open(f"../../../logs/classifier/{hyperparams.context_size}_contexts/{root_path}/training_history.txt", "a") as f:
                        f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Looping Step

# %%
now = datetime.now(pytz.timezone("Asia/Ujung_Pandang"))
path_name = now.strftime("%m-%d-%Y_%H-%M-%S")
root_path = f"../../../logs/classifier/{hyperparams.context_size}_contexts/fold_0{hyperparams.fold}/{path_name}"
os.makedirs(root_path)

def looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric, n_epoch=hyperparams.n_epoch, patience=hyperparams.patience, monitor="loss"):    
    start_time = time()
    
    epoch_training_losses = []
    epoch_training_metric_scores = []
    epoch_val_losses = []
    epoch_val_metric_scores = []
    patience_counter = 0
    
    # Hyperparameters
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write(f"HYPERPARAMETERS\n")
        f.write(f"{'-' * 80}\n")
        for name, value in vars(hyperparams).items():
            f.write(f"{name}: {value}\n")
        
        f.write("\n\nTRAINING PROGRESS\n")
        f.write(f"{'-' * 80}\n")
    
    # Training Progress
    for epoch in range(1, n_epoch + 1):
        print(f"EPOCH-{epoch}")
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"EPOCH-{epoch}\n")
            f.write(f"Training Step\n")
            
        # Training Step
        print("Training Step")
        batch_training_losses, batch_training_metric_scores = training_step(train_dataloader, model, optimizer, criterion, train_metric, scheduler=None)
        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))

        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))
        epoch_training_losses.append(epoch_training_loss.item())

        epoch_training_metric_score = torch.mean(torch.FloatTensor(batch_training_metric_scores))
        epoch_training_metric_scores.append(epoch_training_metric_score.item())
        
        # Validation Step
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"\nValidation Step\n")
            
        print("\nValidation Step")
        batch_val_losses, batch_val_metric_scores = validation_step(val_dataloader, model, criterion, val_metric)
        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))

        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))
        epoch_val_losses.append(epoch_val_loss.item())

        epoch_val_metric_score = torch.mean(torch.FloatTensor(batch_val_metric_scores))
        epoch_val_metric_scores.append(epoch_val_metric_score.item())
        
        with open(f"{root_path}/training_history.txt", "a") as f:
            if monitor == "loss":
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_losses[-1] < epoch_training_losses[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
            else:
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_metric_scores[-1] > epoch_training_metric_scores[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗\n")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
                    
            print("=" * 80, end="\n\n")
            
            f.write(f"{'=' * 80}\n\n")
            
            if patience_counter == patience:
                print(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                
                f.write(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                break
        
        train_metric.reset()
        val_metric.reset()
        
    finish_time = time()
    
    # Training plot 
    fig, (ax_loss, ax_metric_score) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    fig.suptitle(f"Training with context size = {hyperparams.context_size}")

    ax_loss.set_title("Loss")
    ax_loss.set_xlabel("Epoch")
    ax_loss.set_ylabel("Score")
    ax_loss.plot(epoch_training_losses, "green", label="Training")
    ax_loss.plot(epoch_val_losses, "orange", label="Validation")
    ax_loss.legend()
    ax_loss.grid()

    ax_metric_score.set_title("F1 Score")
    ax_metric_score.set_xlabel("Epoch")
    ax_metric_score.set_ylabel("Score")
    ax_metric_score.plot(epoch_training_metric_scores, "green", label="Training")
    ax_metric_score.plot(epoch_val_metric_scores, "orange", label="Validation")
    ax_metric_score.legend()
    ax_metric_score.grid()

    plt.savefig(f"{root_path}/training_plot.jpg", dpi=200)                        
    
    print("TRAINING SUMMARY")
    name_best_training_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_training_metric = f"Best {str(train_metric).split('(')[0]} validation".ljust(34)
    name_best_validation_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_validation_metric = f"Best {str(val_metric).split('(')[0]} validation".ljust(34)
    name_training_time = f"Training duration".ljust(34)
    name_training_date = f"Training date".ljust(34)
    
    print(f"{name_best_training_loss}: {best_training_loss:.4f}")
    print(f"{name_best_validation_loss}: {best_val_loss:.4f}")
    print(f"{name_best_training_metric}: {best_training_metric:.4f}")
    print(f"{name_best_validation_metric}: {best_val_metric:.4f}")
    print(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.")
    print(f"{name_training_date}: {now}")
    
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write("\nTRAINING SUMMARY\n")
        f.write(f"{'-' * 80}\n")
        f.write(f"{name_best_training_loss}: {best_training_loss:.4f}\n")
        f.write(f"{name_best_validation_loss}: {best_val_loss:.4f}\n")
        f.write(f"{name_best_training_metric}: {best_training_metric:.4f}\n")
        f.write(f"{name_best_validation_metric}: {best_val_metric:.4f}\n")
        f.write(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.\n")
        f.write(f"{name_training_date}: {now}\n")
    
    # Save epoch losses, epoch metric scores, model, state dict, and oov embedding dict
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_training_losses
    }).to_csv(f"{root_path}/training_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_training_metric_scores
    }).to_csv(f"{root_path}/training_metric_scores.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_val_losses
    }).to_csv(f"{root_path}/val_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_val_metric_scores
    }).to_csv(f"{root_path}/val_metric_scores.csv", index=False)    
    
    filename_model_params = f"{root_path}/model_params.pth"
    torch.save(best_state_dict, filename_model_params)
    
    return epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores

epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores = looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric)
# Out:
# EPOCH-1
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.4791 | MulticlassF1Score=0.1818
# Batch-30 : CrossEntropyLoss=2.4957 | MulticlassF1Score=0.2263
# Batch-45 : CrossEntropyLoss=2.4620 | MulticlassF1Score=0.2716
# Batch-60 : CrossEntropyLoss=2.4323 | MulticlassF1Score=0.2977
# Batch-75 : CrossEntropyLoss=2.4144 | MulticlassF1Score=0.3256
# Batch-90 : CrossEntropyLoss=2.4203 | MulticlassF1Score=0.3522
# Batch-105: CrossEntropyLoss=2.3901 | MulticlassF1Score=0.3764
# Batch-120: CrossEntropyLoss=2.3663 | MulticlassF1Score=0.4097
# Batch-135: CrossEntropyLoss=2.3541 | MulticlassF1Score=0.4360
# Batch-150: CrossEntropyLoss=2.3519 | MulticlassF1Score=0.4586
# Batch-165: CrossEntropyLoss=2.3323 | MulticlassF1Score=0.4768
# Batch-180: CrossEntropyLoss=2.3325 | MulticlassF1Score=0.4939
# Batch-195: CrossEntropyLoss=2.3392 | MulticlassF1Score=0.5106
# Batch-210: CrossEntropyLoss=2.3405 | MulticlassF1Score=0.5258
# Batch-225: CrossEntropyLoss=2.3320 | MulticlassF1Score=0.5392
# Batch-226: CrossEntropyLoss=2.3305 | MulticlassF1Score=0.5397
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3317 | MulticlassF1Score=0.7228
# Batch-30 : CrossEntropyLoss=2.3366 | MulticlassF1Score=0.7232
# Batch-45 : CrossEntropyLoss=2.3385 | MulticlassF1Score=0.7242
# Batch-60 : CrossEntropyLoss=2.3273 | MulticlassF1Score=0.7250
# Batch-63 : CrossEntropyLoss=2.3403 | MulticlassF1Score=0.7246
#
# Training   : Mean CrossEntropyLoss = 2.4043 | Mean MulticlassF1Score = 0.3813
# Validation : Mean CrossEntropyLoss = 2.3343 | Mean MulticlassF1Score = 0.7218
# ================================================================================
#
# EPOCH-2
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3402 | MulticlassF1Score=0.7278
# Batch-30 : CrossEntropyLoss=2.3318 | MulticlassF1Score=0.7330
# Batch-45 : CrossEntropyLoss=2.3390 | MulticlassF1Score=0.7355
# Batch-60 : CrossEntropyLoss=2.3318 | MulticlassF1Score=0.7377
# Batch-75 : CrossEntropyLoss=2.3327 | MulticlassF1Score=0.7391
# Batch-90 : CrossEntropyLoss=2.3287 | MulticlassF1Score=0.7410
# Batch-105: CrossEntropyLoss=2.3183 | MulticlassF1Score=0.7421
# Batch-120: CrossEntropyLoss=2.3180 | MulticlassF1Score=0.7462
# Batch-135: CrossEntropyLoss=2.3106 | MulticlassF1Score=0.7502
# Batch-150: CrossEntropyLoss=2.3135 | MulticlassF1Score=0.7535
# Batch-165: CrossEntropyLoss=2.3136 | MulticlassF1Score=0.7560
# Batch-180: CrossEntropyLoss=2.3154 | MulticlassF1Score=0.7593
# Batch-195: CrossEntropyLoss=2.3079 | MulticlassF1Score=0.7618
# Batch-210: CrossEntropyLoss=2.3183 | MulticlassF1Score=0.7640
# Batch-225: CrossEntropyLoss=2.3239 | MulticlassF1Score=0.7661
# Batch-226: CrossEntropyLoss=2.3222 | MulticlassF1Score=0.7661
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2986 | MulticlassF1Score=0.7973
# Batch-30 : CrossEntropyLoss=2.3180 | MulticlassF1Score=0.7918
# Batch-45 : CrossEntropyLoss=2.3104 | MulticlassF1Score=0.7914
# Batch-60 : CrossEntropyLoss=2.3160 | MulticlassF1Score=0.7901
# Batch-63 : CrossEntropyLoss=2.3058 | MulticlassF1Score=0.7912
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3213 | Mean MulticlassF1Score = 0.7464
# Validation : Mean CrossEntropyLoss = 2.3130 | Mean MulticlassF1Score = 0.7924
# ================================================================================
#
# EPOCH-3
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3197 | MulticlassF1Score=0.7919
# Batch-30 : CrossEntropyLoss=2.3135 | MulticlassF1Score=0.7943
# Batch-45 : CrossEntropyLoss=2.3061 | MulticlassF1Score=0.7951
# Batch-60 : CrossEntropyLoss=2.3128 | MulticlassF1Score=0.7936
# Batch-75 : CrossEntropyLoss=2.3057 | MulticlassF1Score=0.7934
# Batch-90 : CrossEntropyLoss=2.3143 | MulticlassF1Score=0.7945
# Batch-105: CrossEntropyLoss=2.3091 | MulticlassF1Score=0.7957
# Batch-120: CrossEntropyLoss=2.3233 | MulticlassF1Score=0.7947
# Batch-135: CrossEntropyLoss=2.3149 | MulticlassF1Score=0.7945
# Batch-150: CrossEntropyLoss=2.3090 | MulticlassF1Score=0.7956
# Batch-165: CrossEntropyLoss=2.3029 | MulticlassF1Score=0.7954
# Batch-180: CrossEntropyLoss=2.3138 | MulticlassF1Score=0.7949
# Batch-195: CrossEntropyLoss=2.3167 | MulticlassF1Score=0.7949
# Batch-210: CrossEntropyLoss=2.3268 | MulticlassF1Score=0.7950
# Batch-225: CrossEntropyLoss=2.3111 | MulticlassF1Score=0.7946
# Batch-226: CrossEntropyLoss=2.3061 | MulticlassF1Score=0.7947
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3142 | MulticlassF1Score=0.8000
# Batch-30 : CrossEntropyLoss=2.3138 | MulticlassF1Score=0.7954
# Batch-45 : CrossEntropyLoss=2.3028 | MulticlassF1Score=0.7950
# Batch-60 : CrossEntropyLoss=2.3040 | MulticlassF1Score=0.7949
# Batch-63 : CrossEntropyLoss=2.3083 | MulticlassF1Score=0.7953
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3119 | Mean MulticlassF1Score = 0.7944
# Validation : Mean CrossEntropyLoss = 2.3112 | Mean MulticlassF1Score = 0.7962
# ================================================================================
#
# EPOCH-4
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3210 | MulticlassF1Score=0.7929
# Batch-30 : CrossEntropyLoss=2.3129 | MulticlassF1Score=0.7982
# Batch-45 : CrossEntropyLoss=2.3076 | MulticlassF1Score=0.7967
# Batch-60 : CrossEntropyLoss=2.3159 | MulticlassF1Score=0.7968
# Batch-75 : CrossEntropyLoss=2.3059 | MulticlassF1Score=0.7982
# Batch-90 : CrossEntropyLoss=2.3086 | MulticlassF1Score=0.7983
# Batch-105: CrossEntropyLoss=2.3077 | MulticlassF1Score=0.7998
# Batch-120: CrossEntropyLoss=2.2990 | MulticlassF1Score=0.8019
# Batch-135: CrossEntropyLoss=2.3119 | MulticlassF1Score=0.8039
# Batch-150: CrossEntropyLoss=2.3094 | MulticlassF1Score=0.8052
# Batch-165: CrossEntropyLoss=2.2959 | MulticlassF1Score=0.8061
# Batch-180: CrossEntropyLoss=2.2957 | MulticlassF1Score=0.8075
# Batch-195: CrossEntropyLoss=2.3097 | MulticlassF1Score=0.8090
# Batch-210: CrossEntropyLoss=2.3039 | MulticlassF1Score=0.8102
# Batch-225: CrossEntropyLoss=2.2962 | MulticlassF1Score=0.8113
# Batch-226: CrossEntropyLoss=2.3121 | MulticlassF1Score=0.8113
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2866 | MulticlassF1Score=0.8223
# Batch-30 : CrossEntropyLoss=2.2970 | MulticlassF1Score=0.8218
# Batch-45 : CrossEntropyLoss=2.3113 | MulticlassF1Score=0.8241
# Batch-60 : CrossEntropyLoss=2.3011 | MulticlassF1Score=0.8251
# Batch-63 : CrossEntropyLoss=2.2991 | MulticlassF1Score=0.8248
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3065 | Mean MulticlassF1Score = 0.8015
# Validation : Mean CrossEntropyLoss = 2.3022 | Mean MulticlassF1Score = 0.8232
# ================================================================================
#
# EPOCH-5
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3043 | MulticlassF1Score=0.8323
# Batch-30 : CrossEntropyLoss=2.3027 | MulticlassF1Score=0.8289
# Batch-45 : CrossEntropyLoss=2.3041 | MulticlassF1Score=0.8298
# Batch-60 : CrossEntropyLoss=2.3082 | MulticlassF1Score=0.8295
# Batch-75 : CrossEntropyLoss=2.3012 | MulticlassF1Score=0.8285
# Batch-90 : CrossEntropyLoss=2.3041 | MulticlassF1Score=0.8279
# Batch-105: CrossEntropyLoss=2.3026 | MulticlassF1Score=0.8268
# Batch-120: CrossEntropyLoss=2.3052 | MulticlassF1Score=0.8278
# Batch-135: CrossEntropyLoss=2.3016 | MulticlassF1Score=0.8269
# Batch-150: CrossEntropyLoss=2.2977 | MulticlassF1Score=0.8269
# Batch-165: CrossEntropyLoss=2.2963 | MulticlassF1Score=0.8270
# Batch-180: CrossEntropyLoss=2.3044 | MulticlassF1Score=0.8273
# Batch-195: CrossEntropyLoss=2.2991 | MulticlassF1Score=0.8279
# Batch-210: CrossEntropyLoss=2.3022 | MulticlassF1Score=0.8280
# Batch-225: CrossEntropyLoss=2.3064 | MulticlassF1Score=0.8275
# Batch-226: CrossEntropyLoss=2.3039 | MulticlassF1Score=0.8275
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2932 | MulticlassF1Score=0.8240
# Batch-30 : CrossEntropyLoss=2.2981 | MulticlassF1Score=0.8257
# Batch-45 : CrossEntropyLoss=2.2964 | MulticlassF1Score=0.8257
# Batch-60 : CrossEntropyLoss=2.3004 | MulticlassF1Score=0.8262
# Batch-63 : CrossEntropyLoss=2.3017 | MulticlassF1Score=0.8263
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3013 | Mean MulticlassF1Score = 0.8286
# Validation : Mean CrossEntropyLoss = 2.3015 | Mean MulticlassF1Score = 0.8251
# ================================================================================
#
# EPOCH-6
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2977 | MulticlassF1Score=0.8311
# Batch-30 : CrossEntropyLoss=2.3001 | MulticlassF1Score=0.8320
# Batch-45 : CrossEntropyLoss=2.2920 | MulticlassF1Score=0.8315
# Batch-60 : CrossEntropyLoss=2.3087 | MulticlassF1Score=0.8314
# Batch-75 : CrossEntropyLoss=2.3101 | MulticlassF1Score=0.8306
# Batch-90 : CrossEntropyLoss=2.3081 | MulticlassF1Score=0.8284
# Batch-105: CrossEntropyLoss=2.3059 | MulticlassF1Score=0.8291
# Batch-120: CrossEntropyLoss=2.3093 | MulticlassF1Score=0.8296
# Batch-135: CrossEntropyLoss=2.2986 | MulticlassF1Score=0.8304
# Batch-150: CrossEntropyLoss=2.2890 | MulticlassF1Score=0.8304
# Batch-165: CrossEntropyLoss=2.3041 | MulticlassF1Score=0.8304
# Batch-180: CrossEntropyLoss=2.3078 | MulticlassF1Score=0.8307
# Batch-195: CrossEntropyLoss=2.3100 | MulticlassF1Score=0.8309
# Batch-210: CrossEntropyLoss=2.3116 | MulticlassF1Score=0.8309
# Batch-225: CrossEntropyLoss=2.3145 | MulticlassF1Score=0.8303
# Batch-226: CrossEntropyLoss=2.3063 | MulticlassF1Score=0.8302
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3075 | MulticlassF1Score=0.8245
# Batch-30 : CrossEntropyLoss=2.2914 | MulticlassF1Score=0.8277
# Batch-45 : CrossEntropyLoss=2.3047 | MulticlassF1Score=0.8274
# Batch-60 : CrossEntropyLoss=2.2961 | MulticlassF1Score=0.8285
# Batch-63 : CrossEntropyLoss=2.3079 | MulticlassF1Score=0.8281
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3004 | Mean MulticlassF1Score = 0.8307
# Validation : Mean CrossEntropyLoss = 2.3010 | Mean MulticlassF1Score = 0.8264
# ================================================================================
#
# EPOCH-7
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2999 | MulticlassF1Score=0.8318
# Batch-30 : CrossEntropyLoss=2.3017 | MulticlassF1Score=0.8322
# Batch-45 : CrossEntropyLoss=2.2952 | MulticlassF1Score=0.8308
# Batch-60 : CrossEntropyLoss=2.3027 | MulticlassF1Score=0.8313
# Batch-75 : CrossEntropyLoss=2.3060 | MulticlassF1Score=0.8315
# Batch-90 : CrossEntropyLoss=2.2923 | MulticlassF1Score=0.8317
# Batch-105: CrossEntropyLoss=2.2957 | MulticlassF1Score=0.8318
# Batch-120: CrossEntropyLoss=2.2914 | MulticlassF1Score=0.8316
# Batch-135: CrossEntropyLoss=2.2837 | MulticlassF1Score=0.8317
# Batch-150: CrossEntropyLoss=2.2957 | MulticlassF1Score=0.8324
# Batch-165: CrossEntropyLoss=2.2961 | MulticlassF1Score=0.8319
# Batch-180: CrossEntropyLoss=2.2968 | MulticlassF1Score=0.8322
# Batch-195: CrossEntropyLoss=2.3037 | MulticlassF1Score=0.8321
# Batch-210: CrossEntropyLoss=2.2996 | MulticlassF1Score=0.8320
# Batch-225: CrossEntropyLoss=2.3009 | MulticlassF1Score=0.8325
# Batch-226: CrossEntropyLoss=2.2927 | MulticlassF1Score=0.8326
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2923 | MulticlassF1Score=0.8515
# Batch-30 : CrossEntropyLoss=2.2936 | MulticlassF1Score=0.8527
# Batch-45 : CrossEntropyLoss=2.2956 | MulticlassF1Score=0.8502
# Batch-60 : CrossEntropyLoss=2.2914 | MulticlassF1Score=0.8501
# Batch-63 : CrossEntropyLoss=2.3045 | MulticlassF1Score=0.8494
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2995 | Mean MulticlassF1Score = 0.8321
# Validation : Mean CrossEntropyLoss = 2.2951 | Mean MulticlassF1Score = 0.8508
# ================================================================================
#
# EPOCH-8
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2863 | MulticlassF1Score=0.8561
# Batch-30 : CrossEntropyLoss=2.2922 | MulticlassF1Score=0.8588
# Batch-45 : CrossEntropyLoss=2.2861 | MulticlassF1Score=0.8612
# Batch-60 : CrossEntropyLoss=2.2931 | MulticlassF1Score=0.8619
# Batch-75 : CrossEntropyLoss=2.2956 | MulticlassF1Score=0.8631
# Batch-90 : CrossEntropyLoss=2.2924 | MulticlassF1Score=0.8640
# Batch-105: CrossEntropyLoss=2.2831 | MulticlassF1Score=0.8655
# Batch-120: CrossEntropyLoss=2.2909 | MulticlassF1Score=0.8659
# Batch-135: CrossEntropyLoss=2.2888 | MulticlassF1Score=0.8664
# Batch-150: CrossEntropyLoss=2.2926 | MulticlassF1Score=0.8666
# Batch-165: CrossEntropyLoss=2.2898 | MulticlassF1Score=0.8669
# Batch-180: CrossEntropyLoss=2.2886 | MulticlassF1Score=0.8674
# Batch-195: CrossEntropyLoss=2.2954 | MulticlassF1Score=0.8676
# Batch-210: CrossEntropyLoss=2.2824 | MulticlassF1Score=0.8683
# Batch-225: CrossEntropyLoss=2.2878 | MulticlassF1Score=0.8688
# Batch-226: CrossEntropyLoss=2.2885 | MulticlassF1Score=0.8688
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2878 | MulticlassF1Score=0.8662
# Batch-30 : CrossEntropyLoss=2.2825 | MulticlassF1Score=0.8648
# Batch-45 : CrossEntropyLoss=2.2832 | MulticlassF1Score=0.8667
# Batch-60 : CrossEntropyLoss=2.2944 | MulticlassF1Score=0.8664
# Batch-63 : CrossEntropyLoss=2.2808 | MulticlassF1Score=0.8672
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2887 | Mean MulticlassF1Score = 0.8639
# Validation : Mean CrossEntropyLoss = 2.2888 | Mean MulticlassF1Score = 0.8673
# ================================================================================
#
# EPOCH-9
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2872 | MulticlassF1Score=0.8772
# Batch-30 : CrossEntropyLoss=2.2844 | MulticlassF1Score=0.8752
# Batch-45 : CrossEntropyLoss=2.2778 | MulticlassF1Score=0.8759
# Batch-60 : CrossEntropyLoss=2.2790 | MulticlassF1Score=0.8781
# Batch-75 : CrossEntropyLoss=2.2757 | MulticlassF1Score=0.8826
# Batch-90 : CrossEntropyLoss=2.2756 | MulticlassF1Score=0.8863
# Batch-105: CrossEntropyLoss=2.2718 | MulticlassF1Score=0.8902
# Batch-120: CrossEntropyLoss=2.2671 | MulticlassF1Score=0.8928
# Batch-135: CrossEntropyLoss=2.2780 | MulticlassF1Score=0.8950
# Batch-150: CrossEntropyLoss=2.2749 | MulticlassF1Score=0.8968
# Batch-165: CrossEntropyLoss=2.2736 | MulticlassF1Score=0.8982
# Batch-180: CrossEntropyLoss=2.2869 | MulticlassF1Score=0.8992
# Batch-195: CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9006
# Batch-210: CrossEntropyLoss=2.2768 | MulticlassF1Score=0.9020
# Batch-225: CrossEntropyLoss=2.2768 | MulticlassF1Score=0.9030
# Batch-226: CrossEntropyLoss=2.2789 | MulticlassF1Score=0.9030
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9120
# Batch-30 : CrossEntropyLoss=2.2796 | MulticlassF1Score=0.9105
# Batch-45 : CrossEntropyLoss=2.2825 | MulticlassF1Score=0.9082
# Batch-60 : CrossEntropyLoss=2.2783 | MulticlassF1Score=0.9101
# Batch-63 : CrossEntropyLoss=2.2782 | MulticlassF1Score=0.9100
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2784 | Mean MulticlassF1Score = 0.8894
# Validation : Mean CrossEntropyLoss = 2.2761 | Mean MulticlassF1Score = 0.9107
# ================================================================================
#
# EPOCH-10
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9163
# Batch-30 : CrossEntropyLoss=2.2815 | MulticlassF1Score=0.9165
# Batch-45 : CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9157
# Batch-60 : CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9176
# Batch-75 : CrossEntropyLoss=2.2782 | MulticlassF1Score=0.9181
# Batch-90 : CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9185
# Batch-105: CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9190
# Batch-120: CrossEntropyLoss=2.2798 | MulticlassF1Score=0.9184
# Batch-135: CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9185
# Batch-150: CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9184
# Batch-165: CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9183
# Batch-180: CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9183
# Batch-195: CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9181
# Batch-210: CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9179
# Batch-225: CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9178
# Batch-226: CrossEntropyLoss=2.2802 | MulticlassF1Score=0.9177
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9151
# Batch-30 : CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9151
# Batch-45 : CrossEntropyLoss=2.2792 | MulticlassF1Score=0.9137
# Batch-60 : CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9133
# Batch-63 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9136
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2736 | Mean MulticlassF1Score = 0.9180
# Validation : Mean CrossEntropyLoss = 2.2747 | Mean MulticlassF1Score = 0.9151
# ================================================================================
#
# EPOCH-11
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9253
# Batch-30 : CrossEntropyLoss=2.2754 | MulticlassF1Score=0.9227
# Batch-45 : CrossEntropyLoss=2.2794 | MulticlassF1Score=0.9222
# Batch-60 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9207
# Batch-75 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9211
# Batch-90 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9211
# Batch-105: CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9211
# Batch-120: CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9213
# Batch-135: CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9209
# Batch-150: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9216
# Batch-165: CrossEntropyLoss=2.2853 | MulticlassF1Score=0.9207
# Batch-180: CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9204
# Batch-195: CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9207
# Batch-210: CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9216
# Batch-225: CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9213
# Batch-226: CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9214
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2770 | MulticlassF1Score=0.9183
# Batch-30 : CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9163
# Batch-45 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9169
# Batch-60 : CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9154
# Batch-63 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9152
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2723 | Mean MulticlassF1Score = 0.9217
# Validation : Mean CrossEntropyLoss = 2.2743 | Mean MulticlassF1Score = 0.9174
# ================================================================================
#
# EPOCH-12
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2797 | MulticlassF1Score=0.9233
# Batch-30 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9261
# Batch-45 : CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9246
# Batch-60 : CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9234
# Batch-75 : CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9236
# Batch-90 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9236
# Batch-105: CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9237
# Batch-120: CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9233
# Batch-135: CrossEntropyLoss=2.2766 | MulticlassF1Score=0.9237
# Batch-150: CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9236
# Batch-165: CrossEntropyLoss=2.2759 | MulticlassF1Score=0.9239
# Batch-180: CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9241
# Batch-195: CrossEntropyLoss=2.2747 | MulticlassF1Score=0.9235
# Batch-210: CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9232
# Batch-225: CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9234
# Batch-226: CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9234
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9167
# Batch-30 : CrossEntropyLoss=2.2778 | MulticlassF1Score=0.9167
# Batch-45 : CrossEntropyLoss=2.2830 | MulticlassF1Score=0.9161
# Batch-60 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9150
# Batch-63 : CrossEntropyLoss=2.2761 | MulticlassF1Score=0.9148
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2716 | Mean MulticlassF1Score = 0.9240
# Validation : Mean CrossEntropyLoss = 2.2742 | Mean MulticlassF1Score = 0.9168
# ================================================================================
#
# EPOCH-13
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9320
# Batch-30 : CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9283
# Batch-45 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9273
# Batch-60 : CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9266
# Batch-75 : CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9260
# Batch-90 : CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9256
# Batch-105: CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9256
# Batch-120: CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9258
# Batch-135: CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9255
# Batch-150: CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9257
# Batch-165: CrossEntropyLoss=2.2806 | MulticlassF1Score=0.9254
# Batch-180: CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9247
# Batch-195: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9243
# Batch-210: CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9241
# Batch-225: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9242
# Batch-226: CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9242
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9204
# Batch-30 : CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9163
# Batch-45 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9148
# Batch-60 : CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9152
# Batch-63 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9157
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2713 | Mean MulticlassF1Score = 0.9263
# Validation : Mean CrossEntropyLoss = 2.2740 | Mean MulticlassF1Score = 0.9166
# ================================================================================
#
# EPOCH-14
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9240
# Batch-30 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9252
# Batch-45 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9251
# Batch-60 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9257
# Batch-75 : CrossEntropyLoss=2.2778 | MulticlassF1Score=0.9262
# Batch-90 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9255
# Batch-105: CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9257
# Batch-120: CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9262
# Batch-135: CrossEntropyLoss=2.2771 | MulticlassF1Score=0.9258
# Batch-150: CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9260
# Batch-165: CrossEntropyLoss=2.2773 | MulticlassF1Score=0.9259
# Batch-180: CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9258
# Batch-195: CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9256
# Batch-210: CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9258
# Batch-225: CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9254
# Batch-226: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9254
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9225
# Batch-30 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9172
# Batch-45 : CrossEntropyLoss=2.2788 | MulticlassF1Score=0.9161
# Batch-60 : CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9164
# Batch-63 : CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9161
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2709 | Mean MulticlassF1Score = 0.9257
# Validation : Mean CrossEntropyLoss = 2.2738 | Mean MulticlassF1Score = 0.9164
# ================================================================================
#
# EPOCH-15
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9235
# Batch-30 : CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9254
# Batch-45 : CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9270
# Batch-60 : CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9277
# Batch-75 : CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9277
# Batch-90 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9270
# Batch-105: CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9267
# Batch-120: CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9273
# Batch-135: CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9269
# Batch-150: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9268
# Batch-165: CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9267
# Batch-180: CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9270
# Batch-195: CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9275
# Batch-210: CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9279
# Batch-225: CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9280
# Batch-226: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9280
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2791 | MulticlassF1Score=0.9189
# Batch-30 : CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9200
# Batch-45 : CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9198
# Batch-60 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9196
# Batch-63 : CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9197
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2700 | Mean MulticlassF1Score = 0.9268
# Validation : Mean CrossEntropyLoss = 2.2727 | Mean MulticlassF1Score = 0.9201
# ================================================================================
#
# EPOCH-16
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9311
# Batch-30 : CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9311
# Batch-45 : CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9317
# Batch-60 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9314
# Batch-75 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9322
# Batch-90 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9314
# Batch-105: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9315
# Batch-120: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9318
# Batch-135: CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9325
# Batch-150: CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9326
# Batch-165: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9323
# Batch-180: CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9325
# Batch-195: CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9324
# Batch-210: CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9324
# Batch-225: CrossEntropyLoss=2.2622 | MulticlassF1Score=0.9326
# Batch-226: CrossEntropyLoss=2.2765 | MulticlassF1Score=0.9325
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9245
# Batch-30 : CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9203
# Batch-45 : CrossEntropyLoss=2.2770 | MulticlassF1Score=0.9198
# Batch-60 : CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9208
# Batch-63 : CrossEntropyLoss=2.2762 | MulticlassF1Score=0.9210
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2686 | Mean MulticlassF1Score = 0.9317
# Validation : Mean CrossEntropyLoss = 2.2721 | Mean MulticlassF1Score = 0.9223
# ================================================================================
#
# EPOCH-17
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9348
# Batch-30 : CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9367
# Batch-45 : CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9357
# Batch-60 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9355
# Batch-75 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9349
# Batch-90 : CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9345
# Batch-105: CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9341
# Batch-120: CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9340
# Batch-135: CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9345
# Batch-150: CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9344
# Batch-165: CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9345
# Batch-180: CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9345
# Batch-195: CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9344
# Batch-210: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9343
# Batch-225: CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9344
# Batch-226: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9343
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9254
# Batch-30 : CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9230
# Batch-45 : CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9220
# Batch-60 : CrossEntropyLoss=2.2766 | MulticlassF1Score=0.9210
# Batch-63 : CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9212
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2680 | Mean MulticlassF1Score = 0.9349
# Validation : Mean CrossEntropyLoss = 2.2721 | Mean MulticlassF1Score = 0.9231
# ================================================================================
#
# EPOCH-18
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9383
# Batch-30 : CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9373
# Batch-45 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9386
# Batch-60 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9391
# Batch-75 : CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9380
# Batch-90 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9376
# Batch-105: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9370
# Batch-120: CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9367
# Batch-135: CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9370
# Batch-150: CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9365
# Batch-165: CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9367
# Batch-180: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9365
# Batch-195: CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9364
# Batch-210: CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9361
# Batch-225: CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9358
# Batch-226: CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9358
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9202
# Batch-30 : CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9226
# Batch-45 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9222
# Batch-60 : CrossEntropyLoss=2.2781 | MulticlassF1Score=0.9217
# Batch-63 : CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9217
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2675 | Mean MulticlassF1Score = 0.9371
# Validation : Mean CrossEntropyLoss = 2.2720 | Mean MulticlassF1Score = 0.9210
# ================================================================================
#
# EPOCH-19
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9368
# Batch-30 : CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9350
# Batch-45 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9356
# Batch-60 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9356
# Batch-75 : CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9353
# Batch-90 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9349
# Batch-105: CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9356
# Batch-120: CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9360
# Batch-135: CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9361
# Batch-150: CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9365
# Batch-165: CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9363
# Batch-180: CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9363
# Batch-195: CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9359
# Batch-210: CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9360
# Batch-225: CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9359
# Batch-226: CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9360
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9191
# Batch-30 : CrossEntropyLoss=2.2808 | MulticlassF1Score=0.9200
# Batch-45 : CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9210
# Batch-60 : CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9203
# Batch-63 : CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9205
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2675 | Mean MulticlassF1Score = 0.9358
# Validation : Mean CrossEntropyLoss = 2.2723 | Mean MulticlassF1Score = 0.9198
# ================================================================================
#
# EPOCH-20
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9364
# Batch-30 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9344
# Batch-45 : CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9343
# Batch-60 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9341
# Batch-75 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9341
# Batch-90 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9351
# Batch-105: CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9351
# Batch-120: CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9355
# Batch-135: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9358
# Batch-150: CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9361
# Batch-165: CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9360
# Batch-180: CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9359
# Batch-195: CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9358
# Batch-210: CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9358
# Batch-225: CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9359
# Batch-226: CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9359
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9186
# Batch-30 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9188
# Batch-45 : CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9212
# Batch-60 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9217
# Batch-63 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9220
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2675 | Mean MulticlassF1Score = 0.9353
# Validation : Mean CrossEntropyLoss = 2.2719 | Mean MulticlassF1Score = 0.9187
# Patience = 1/50❗
# ================================================================================
#
# EPOCH-21
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9342
# Batch-30 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9351
# Batch-45 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9365
# Batch-60 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9376
# Batch-75 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9387
# Batch-90 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9384
# Batch-105: CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9387
# Batch-120: CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9387
# Batch-135: CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9381
# Batch-150: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9377
# Batch-165: CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9376
# Batch-180: CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9380
# Batch-195: CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9378
# Batch-210: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9376
# Batch-225: CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9376
# Batch-226: CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9376
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2762 | MulticlassF1Score=0.9243
# Batch-30 : CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9220
# Batch-45 : CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9229
# Batch-60 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9218
# Batch-63 : CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9222
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2669 | Mean MulticlassF1Score = 0.9375
# Validation : Mean CrossEntropyLoss = 2.2718 | Mean MulticlassF1Score = 0.9233
# ================================================================================
#
# EPOCH-22
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9381
# Batch-30 : CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9398
# Batch-45 : CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9392
# Batch-60 : CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9388
# Batch-75 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9389
# Batch-90 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9388
# Batch-105: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9389
# Batch-120: CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9389
# Batch-135: CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9384
# Batch-150: CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9384
# Batch-165: CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9384
# Batch-180: CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9385
# Batch-195: CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9385
# Batch-210: CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9383
# Batch-225: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9383
# Batch-226: CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9383
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9204
# Batch-30 : CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9218
# Batch-45 : CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9223
# Batch-60 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9226
# Batch-63 : CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9227
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2666 | Mean MulticlassF1Score = 0.9390
# Validation : Mean CrossEntropyLoss = 2.2716 | Mean MulticlassF1Score = 0.9210
# ================================================================================
#
# EPOCH-23
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9385
# Batch-30 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9397
# Batch-45 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9390
# Batch-60 : CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9385
# Batch-75 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9387
# Batch-90 : CrossEntropyLoss=2.2611 | MulticlassF1Score=0.9390
# Batch-105: CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9387
# Batch-120: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9388
# Batch-135: CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9390
# Batch-150: CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9388
# Batch-165: CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9389
# Batch-180: CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9389
# Batch-195: CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9389
# Batch-210: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9389
# Batch-225: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9390
# Batch-226: CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9390
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9196
# Batch-30 : CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9217
# Batch-45 : CrossEntropyLoss=2.2772 | MulticlassF1Score=0.9221
# Batch-60 : CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9220
# Batch-63 : CrossEntropyLoss=2.2754 | MulticlassF1Score=0.9222
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2664 | Mean MulticlassF1Score = 0.9390
# Validation : Mean CrossEntropyLoss = 2.2717 | Mean MulticlassF1Score = 0.9212
# ================================================================================
#
# EPOCH-24
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9394
# Batch-30 : CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9397
# Batch-45 : CrossEntropyLoss=2.2634 | MulticlassF1Score=0.9392
# Batch-60 : CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9393
# Batch-75 : CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9397
# Batch-90 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9399
# Batch-105: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9401
# Batch-120: CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9402
# Batch-135: CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9404
# Batch-150: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9404
# Batch-165: CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9403
# Batch-180: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9403
# Batch-195: CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9400
# Batch-210: CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9401
# Batch-225: CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9399
# Batch-226: CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9399
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9242
# Batch-30 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9219
# Batch-45 : CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9238
# Batch-60 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9226
# Batch-63 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9224
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2661 | Mean MulticlassF1Score = 0.9400
# Validation : Mean CrossEntropyLoss = 2.2716 | Mean MulticlassF1Score = 0.9230
# ================================================================================
#
# EPOCH-25
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2622 | MulticlassF1Score=0.9375
# Batch-30 : CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9395
# Batch-45 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9394
# Batch-60 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9399
# Batch-75 : CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9400
# Batch-90 : CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9399
# Batch-105: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9402
# Batch-120: CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9401
# Batch-135: CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9401
# Batch-150: CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9400
# Batch-165: CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9401
# Batch-180: CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9402
# Batch-195: CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9404
# Batch-210: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9402
# Batch-225: CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9400
# Batch-226: CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9400
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9215
# Batch-30 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9231
# Batch-45 : CrossEntropyLoss=2.2768 | MulticlassF1Score=0.9216
# Batch-60 : CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9217
# Batch-63 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9221
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2661 | Mean MulticlassF1Score = 0.9397
# Validation : Mean CrossEntropyLoss = 2.2716 | Mean MulticlassF1Score = 0.9211
# ================================================================================
#
# EPOCH-26
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9398
# Batch-30 : CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9394
# Batch-45 : CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9399
# Batch-60 : CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9393
# Batch-75 : CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9405
# Batch-90 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9409
# Batch-105: CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9407
# Batch-120: CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9405
# Batch-135: CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9406
# Batch-150: CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9403
# Batch-165: CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9407
# Batch-180: CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9402
# Batch-195: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9401
# Batch-210: CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9400
# Batch-225: CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9403
# Batch-226: CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9403
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9195
# Batch-30 : CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9217
# Batch-45 : CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9230
# Batch-60 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9227
# Batch-63 : CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9228
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2660 | Mean MulticlassF1Score = 0.9403
# Validation : Mean CrossEntropyLoss = 2.2714 | Mean MulticlassF1Score = 0.9207
# ================================================================================
#
# EPOCH-27
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9438
# Batch-30 : CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9431
# Batch-45 : CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9429
# Batch-60 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9426
# Batch-75 : CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9424
# Batch-90 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9426
# Batch-105: CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9433
# Batch-120: CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9435
# Batch-135: CrossEntropyLoss=2.2686 | MulticlassF1Score=0.9432
# Batch-150: CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9428
# Batch-165: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9424
# Batch-180: CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9421
# Batch-195: CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9418
# Batch-210: CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9416
# Batch-225: CrossEntropyLoss=2.2710 | MulticlassF1Score=0.9413
# Batch-226: CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9413
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9224
# Batch-30 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9211
# Batch-45 : CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9247
# Batch-60 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9227
# Batch-63 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9227
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2656 | Mean MulticlassF1Score = 0.9428
# Validation : Mean CrossEntropyLoss = 2.2714 | Mean MulticlassF1Score = 0.9215
# ================================================================================
#
# EPOCH-28
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9412
# Batch-30 : CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9416
# Batch-45 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9406
# Batch-60 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9412
# Batch-75 : CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9416
# Batch-90 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9411
# Batch-105: CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9416
# Batch-120: CrossEntropyLoss=2.2603 | MulticlassF1Score=0.9422
# Batch-135: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9421
# Batch-150: CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9420
# Batch-165: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9419
# Batch-180: CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9414
# Batch-195: CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9412
# Batch-210: CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9412
# Batch-225: CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9412
# Batch-226: CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9412
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2753 | MulticlassF1Score=0.9211
# Batch-30 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9211
# Batch-45 : CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9219
# Batch-60 : CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9226
# Batch-63 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9227
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2657 | Mean MulticlassF1Score = 0.9414
# Validation : Mean CrossEntropyLoss = 2.2715 | Mean MulticlassF1Score = 0.9208
# Patience = 2/50❗
# ================================================================================
#
# EPOCH-29
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9436
# Batch-30 : CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9428
# Batch-45 : CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9418
# Batch-60 : CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9415
# Batch-75 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9416
# Batch-90 : CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9410
# Batch-105: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9405
# Batch-120: CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9407
# Batch-135: CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9407
# Batch-150: CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9413
# Batch-165: CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9412
# ...
# Batch-45 : CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9451
# Batch-60 : CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9455
# Batch-63 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9456
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2584 | Mean MulticlassF1Score = 0.9648
# Validation : Mean CrossEntropyLoss = 2.2644 | Mean MulticlassF1Score = 0.9462
# Patience = 5/50❗
# ================================================================================
#
# EPOCH-42
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9669
# Batch-30 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9674
# Batch-45 : CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9674
# Batch-60 : CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9678
# Batch-75 : CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9671
# Batch-90 : CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9667
# Batch-105: CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9666
# Batch-120: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9667
# Batch-135: CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9669
# Batch-150: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9670
# Batch-165: CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9668
# Batch-180: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9669
# Batch-195: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9670
# Batch-210: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9668
# Batch-225: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9669
# Batch-226: CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9668
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9448
# Batch-30 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9465
# Batch-45 : CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9475
# Batch-60 : CrossEntropyLoss=2.2612 | MulticlassF1Score=0.9470
# Batch-63 : CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9468
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2577 | Mean MulticlassF1Score = 0.9669
# Validation : Mean CrossEntropyLoss = 2.2640 | Mean MulticlassF1Score = 0.9469
# ================================================================================
#
# EPOCH-43
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9662
# Batch-30 : CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9655
# Batch-45 : CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9662
# Batch-60 : CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9667
# Batch-75 : CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9676
# Batch-90 : CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9679
# Batch-105: CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9681
# Batch-120: CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9681
# Batch-135: CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9681
# Batch-150: CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9680
# Batch-165: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9682
# Batch-180: CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9681
# Batch-195: CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9679
# Batch-210: CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9679
# Batch-225: CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9679
# Batch-226: CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9679
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2597 | MulticlassF1Score=0.9507
# Batch-30 : CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9481
# Batch-45 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9468
# Batch-60 : CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9468
# Batch-63 : CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9468
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2573 | Mean MulticlassF1Score = 0.9675
# Validation : Mean CrossEntropyLoss = 2.2640 | Mean MulticlassF1Score = 0.9481
# ================================================================================
#
# EPOCH-44
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9682
# Batch-30 : CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9687
# Batch-45 : CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9681
# Batch-60 : CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9681
# Batch-75 : CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9678
# Batch-90 : CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9678
# Batch-105: CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9676
# Batch-120: CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9675
# Batch-135: CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9680
# Batch-150: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9683
# Batch-165: CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9681
# Batch-180: CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9680
# Batch-195: CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9683
# Batch-210: CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9682
# Batch-225: CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9682
# Batch-226: CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9683
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9459
# Batch-30 : CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9464
# Batch-45 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9466
# Batch-60 : CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9466
# Batch-63 : CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9466
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2572 | Mean MulticlassF1Score = 0.9680
# Validation : Mean CrossEntropyLoss = 2.2640 | Mean MulticlassF1Score = 0.9474
# ================================================================================
#
# EPOCH-45
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9685
# Batch-30 : CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9680
# Batch-45 : CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9687
# Batch-60 : CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9682
# Batch-75 : CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9681
# Batch-90 : CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9681
# Batch-105: CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9681
# Batch-120: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9682
# Batch-135: CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9683
# Batch-150: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9682
# Batch-165: CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9685
# Batch-180: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9685
# Batch-195: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9686
# Batch-210: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9683
# Batch-225: CrossEntropyLoss=2.2546 | MulticlassF1Score=0.9684
# Batch-226: CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9684
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9514
# Batch-30 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9482
# Batch-45 : CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9479
# Batch-60 : CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9472
# Batch-63 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9474
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2571 | Mean MulticlassF1Score = 0.9685
# Validation : Mean CrossEntropyLoss = 2.2638 | Mean MulticlassF1Score = 0.9500
# ================================================================================
#
# EPOCH-46
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2544 | MulticlassF1Score=0.9693
# Batch-30 : CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9685
# Batch-45 : CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9681
# Batch-60 : CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9688
# Batch-75 : CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9692
# Batch-90 : CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9698
# Batch-105: CrossEntropyLoss=2.2519 | MulticlassF1Score=0.9694
# Batch-120: CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9693
# Batch-135: CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9693
# Batch-150: CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9693
# Batch-165: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9691
# Batch-180: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9690
# Batch-195: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9688
# Batch-210: CrossEntropyLoss=2.2547 | MulticlassF1Score=0.9687
# Batch-225: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9686
# Batch-226: CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9686
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9463
# Batch-30 : CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9459
# Batch-45 : CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9471
# Batch-60 : CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9475
# Batch-63 : CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9476
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2570 | Mean MulticlassF1Score = 0.9690
# Validation : Mean CrossEntropyLoss = 2.2638 | Mean MulticlassF1Score = 0.9463
# ================================================================================
#
# EPOCH-47
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2534 | MulticlassF1Score=0.9686
# Batch-30 : CrossEntropyLoss=2.2533 | MulticlassF1Score=0.9679
# Batch-45 : CrossEntropyLoss=2.2530 | MulticlassF1Score=0.9694
# Batch-60 : CrossEntropyLoss=2.2541 | MulticlassF1Score=0.9695
# Batch-75 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9690
# Batch-90 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9689
# Batch-105: CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9688
# Batch-120: CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9686
# Batch-135: CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9687
# Batch-150: CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9688
# Batch-165: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9688
# Batch-180: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9687
# Batch-195: CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9687
# Batch-210: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9688
# Batch-225: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9689
# Batch-226: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9689
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9485
# Batch-30 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9472
# Batch-45 : CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9473
# Batch-60 : CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9466
# Batch-63 : CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9469
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2570 | Mean MulticlassF1Score = 0.9689
# Validation : Mean CrossEntropyLoss = 2.2639 | Mean MulticlassF1Score = 0.9475
# ================================================================================
#
# EPOCH-48
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9667
# Batch-30 : CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9679
# Batch-45 : CrossEntropyLoss=2.2547 | MulticlassF1Score=0.9681
# Batch-60 : CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9688
# Batch-75 : CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9693
# Batch-90 : CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9690
# Batch-105: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9693
# Batch-120: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9692
# Batch-135: CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9691
# Batch-150: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9690
# Batch-165: CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9690
# Batch-180: CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9689
# Batch-195: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9690
# Batch-210: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9690
# Batch-225: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9691
# Batch-226: CrossEntropyLoss=2.2505 | MulticlassF1Score=0.9691
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9487
# Batch-30 : CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9490
# Batch-45 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9467
# Batch-60 : CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9465
# Batch-63 : CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9466
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2569 | Mean MulticlassF1Score = 0.9689
# Validation : Mean CrossEntropyLoss = 2.2640 | Mean MulticlassF1Score = 0.9481
# ================================================================================
#
# EPOCH-49
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9666
# Batch-30 : CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9671
# Batch-45 : CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9681
# Batch-60 : CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9683
# Batch-75 : CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9686
# Batch-90 : CrossEntropyLoss=2.2543 | MulticlassF1Score=0.9687
# Batch-105: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9686
# Batch-120: CrossEntropyLoss=2.2538 | MulticlassF1Score=0.9693
# Batch-135: CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9690
# Batch-150: CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9690
# Batch-165: CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9691
# Batch-180: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9689
# Batch-195: CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9690
# Batch-210: CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9690
# Batch-225: CrossEntropyLoss=2.2538 | MulticlassF1Score=0.9690
# Batch-226: CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9689
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9493
# Batch-30 : CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9491
# Batch-45 : CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9470
# Batch-60 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9463
# Batch-63 : CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9461
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2571 | Mean MulticlassF1Score = 0.9684
# Validation : Mean CrossEntropyLoss = 2.2640 | Mean MulticlassF1Score = 0.9470
# Patience = 6/50❗
# ================================================================================
#
# EPOCH-50
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9697
# Batch-30 : CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9682
# Batch-45 : CrossEntropyLoss=2.2518 | MulticlassF1Score=0.9691
# Batch-60 : CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9686
# Batch-75 : CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9685
# Batch-90 : CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9689
# Batch-105: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9688
# Batch-120: CrossEntropyLoss=2.2542 | MulticlassF1Score=0.9687
# Batch-135: CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9687
# Batch-150: CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9687
# Batch-165: CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9687
# Batch-180: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9688
# Batch-195: CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9690
# Batch-210: CrossEntropyLoss=2.2531 | MulticlassF1Score=0.9689
# Batch-225: CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9686
# Batch-226: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9686
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9441
# Batch-30 : CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9453
# Batch-45 : CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9461
# Batch-60 : CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9459
# Batch-63 : CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9462
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2572 | Mean MulticlassF1Score = 0.9688
# Validation : Mean CrossEntropyLoss = 2.2640 | Mean MulticlassF1Score = 0.9458
# Patience = 7/50❗
# ================================================================================
#
# TRAINING SUMMARY
# Best CrossEntropyLoss training    : 2.2569
# Best CrossEntropyLoss training    : 2.2640
# Best MulticlassF1Score validation : 0.9689
# Best MulticlassF1Score validation : 0.9481
# Training duration                 : 4.8933 minutes.
# Training date                     : 2022-10-19 08:35:34.552277+08:00

# %% [markdown]
# ## End Training

# %% [markdown]
# # Evaluation

# %%
def evaluation(dataloader, model, criterion, metric):
    model.eval()
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)
            pred = rearrange(prob.argmax(dim=1).reshape(feature.shape[0], len(dataloader.dataset)), "s n -> n s")

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob.argmax(dim=1), actual_label.to(hyperparams.device))
            metric_score = metric.compute()

    return loss, metric_score, pred

train_dataloader = DataLoader(train_dataset, batch_size=len(train_dataset))
val_dataloader = DataLoader(val_dataset, batch_size=len(val_dataset))
test_dataloader = DataLoader(test_dataset, batch_size=len(test_dataset))

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
train_loss, train_f1_score, train_pred_label = evaluation(train_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_loss, val_f1_score, val_pred_label = evaluation(val_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
test_loss, test_f1_score, test_pred_label = evaluation(test_dataloader, model, criterion, metric)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9690, device='cuda:0'),
#  tensor(0.9462, device='cuda:0'),
#  tensor(0.9449, device='cuda:0'))

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9690, device='cuda:0'),
#  tensor(0.9462, device='cuda:0'),
#  tensor(0.9449, device='cuda:0'))

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns

def viz_evaluation(pred_label, actual_label, title):
    plt.figure(figsize=(15, 7), dpi=200)
    sns.heatmap(pred_label.detach().cpu() == actual_label, cbar=True, cmap="binary_r")
    plt.xlabel("Sentence Length")
    plt.ylabel("Sentence")
    plt.title(title)
    plt.savefig(f"{root_path}/heatmap_{title.lower()}.jpg", dpi=200)
    plt.show()

train_actual_label = train_dataloader.dataset.tensors[1]
val_actual_label = val_dataloader.dataset.tensors[1]
test_actual_label = test_dataloader.dataset.tensors[1]

viz_evaluation(train_pred_label, train_actual_label, f"Training (F1-Score: {(train_f1_score):.4f})")
viz_evaluation(val_pred_label, val_actual_label, f"Validation (F1-Score: {(val_f1_score):.4f})")
viz_evaluation(test_pred_label, test_actual_label, f"Test (F1-Score: {(test_f1_score):.4f})")

# %% [markdown]
# ## Confusion Matrix

# %%
def confusion_matrix(pred_class, actual_class, title, normalize=None):
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize=normalize)
    plt.figure(figsize=(20, 10), dpi=200)
    sns.heatmap(conf_mat(pred_class.detach().cpu(), actual_class), annot=True, fmt=".2g", xticklabels=list(label_to_idx.keys()), yticklabels=list(label_to_idx.keys()));
    plt.yticks(rotation=0)
    plt.title(title)
    plt.xlabel("Actual Class")
    plt.ylabel("Predict Class")
    plt.savefig(f"{root_path}/conf_matrix_{title.lower()}.jpg", dpi=200)

confusion_matrix(train_pred_label, train_actual_label, "Training", "pred")
confusion_matrix(val_pred_label,val_actual_label, "Validation", "pred")
confusion_matrix(test_pred_label, test_actual_label, "Test", "pred")
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 120 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 144 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)

# %% [markdown]
# ## Prediction Table

# %%
def number_wrong_pred_each_class(pred_class, actual_class):
    classes, count_class = actual_class.flatten().unique(return_counts=True)
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize="none")
    correct_pred_count_class = conf_mat(pred_class.detach().cpu(), actual_class).diag()
    
    correct_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (correct_pred_count_class))}
    wrong_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (count_class - correct_pred_count_class))}
    
    return correct_pred, wrong_pred

correct_pred, wrong_pred = number_wrong_pred_each_class(train_pred_label, train_actual_label)
print(f"| {'Number class'.ljust(14)} | {'Correct prediction'.ljust(12)} | {'Wrong prediction'.ljust(12)} |")
for (label_correct_pred, count_correct_pred), (label_wrong_pred, count_wrong_pred) in zip(correct_pred.items(), wrong_pred.items()):
    print(f"| {str(label_correct_pred).ljust(6)}: {str(count_correct_pred + count_wrong_pred).ljust(7)}| {label_correct_pred.ljust(6)}: {str(count_correct_pred).ljust(10)} | {label_wrong_pred.ljust(6)}: {str(count_wrong_pred).ljust(8)} |")
# Out:
# | Number class   | Correct prediction | Wrong prediction |
# | CC    : 5391   | CC    : 5247       | CC    : 144      |
# | CD    : 12882  | CD    : 12818      | CD    : 64       |
# | DT    : 273    | DT    : 0          | DT    : 273      |
# | FW    : 1690   | FW    : 1487       | FW    : 203      |
# | IN    : 15403  | IN    : 15249      | IN    : 154      |
# | JJ    : 7018   | JJ    : 6722       | JJ    : 296      |
# | MD    : 3810   | MD    : 3675       | MD    : 135      |
# | NEG   : 1082   | NEG   : 0          | NEG   : 1082     |
# | NN    : 44728  | NN    : 44192      | NN    : 536      |
# | NND   : 1019   | NND   : 316        | NND   : 703      |
# | NNP   : 24885  | NNP   : 24429      | NNP   : 456      |
# | OD    : 534    | OD    : 494        | OD    : 40       |
# | PR    : 3842   | PR    : 3795       | PR    : 47       |
# | PRP   : 5405   | PRP   : 5327       | PRP   : 78       |
# | RB    : 3553   | RB    : 3365       | RB    : 188      |
# | RP    : 144    | RP    : 0          | RP    : 144      |
# | SC    : 9487   | SC    : 9265       | SC    : 222      |
# | SYM   : 1550   | SYM   : 1446       | SYM   : 104      |
# | UH    : 26     | UH    : 5          | UH    : 21       |
# | VB    : 22846  | VB    : 22492      | VB    : 354      |
# | WH    : 188    | WH    : 0          | WH    : 188      |
# | X     : 279    | X     : 0          | X     : 279      |
# | Z     : 18958  | Z     : 18927      | Z     : 31       |
# | <PAD> : 407211 | <PAD> : 407211     | <PAD> : 0        |

# %%
train_actual_label[308], train_pred_label[308]
# Out:
# (tensor([ 8, 19, 22, 10, 22, 19, 10,  6, 19,  4,  1,  8, 16, 19,  8, 19,  0,  8,
#           5, 16, 19, 19,  8,  8, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23]),
#  tensor([ 8, 19, 22, 10, 22, 19, 10,  6, 19,  4,  1,  8, 16, 19,  8, 19,  0,  8,
#           5, 16, 19, 19,  8,  8, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23], device='cuda:0'))

# %%
train_actual_label[308] == train_pred_label[308].detach().cpu()
# Out:
# tensor([True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True])

# %% [markdown]
# ## OOV prediction is correct

# %%
def oov_flag_token(sentences, max_seq_len=hyperparams.max_seq_len):
    sent_copy = deepcopy(sentences)
    sent = []
    oov_flag = []
    
    for sentence in tqdm(sent_copy):
        for token in sentence:
            sent.append(token[2])
        
        for _ in range(max_seq_len- len(sentence)):
            sent.append(False)
        
        oov_flag.append(sent)
        sent = []
        
    return np.array(oov_flag)

train_oov_flag = oov_flag_token(train_sentences, max_seq_len=hyperparams.max_seq_len)
val_oov_flag = oov_flag_token(val_sentences, max_seq_len=hyperparams.max_seq_len)
test_oov_flag = oov_flag_token(test_sentences, max_seq_len=hyperparams.max_seq_len)

def pencentage_oov_pred_correct(pred_oov_flag, oov_flag_tensor):
    oov_correct_counter = 0
    oov_wrong_counter = 0

    for pred, oov_label in tqdm(zip(pred_oov_flag, oov_flag_tensor)):
        if pred == True and oov_label == True:
            oov_correct_counter += 1
        elif pred == False and oov_label == True:
            oov_wrong_counter += 1
        else:
            continue
            
    return oov_correct_counter, oov_wrong_counter

train_pred_oov_flag = (train_actual_label == train_pred_label.detach().cpu()).flatten()
val_pred_oov_flag = (val_actual_label == val_pred_label.detach().cpu()).flatten()
test_pred_oov_flag = (test_actual_label == test_pred_label.detach().cpu()).flatten()
train_oov_flag_tensor = torch.tensor(train_oov_flag).flatten()
val_oov_flag_tensor = torch.tensor(val_oov_flag).flatten()
test_oov_flag_tensor = torch.tensor(test_oov_flag).flatten()

train_oov_correct_counter, train_oov_wrong_counter = pencentage_oov_pred_correct(train_pred_oov_flag, train_oov_flag_tensor)
val_oov_correct_counter, val_oov_wrong_counter = pencentage_oov_pred_correct(val_pred_oov_flag, val_oov_flag_tensor)
test_oov_correct_counter, test_oov_wrong_counter = pencentage_oov_pred_correct(test_pred_oov_flag, test_oov_flag_tensor)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]

# %%
def print_percentage_pred_oov(title, oov_correct_counter, oov_wrong_counter):
    print(f"{title}")
    print(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}")
    print(f"Correct prediction          : {oov_correct_counter}")
    print(f"Wrong prediction            : {oov_wrong_counter}")
    print(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n")
    
    with open(f"{root_path}/oov_summary.txt", "a") as f:
        f.write(f"{title}\n")
        f.write(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}\n")
        f.write(f"Correct prediction          : {oov_correct_counter}\n")
        f.write(f"Wrong prediction            : {oov_wrong_counter}\n")
        f.write(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n\n")

# %%
print_percentage_pred_oov("Training", train_oov_correct_counter, train_oov_wrong_counter)
print_percentage_pred_oov("Validation", val_oov_correct_counter, val_oov_wrong_counter)
print_percentage_pred_oov("Test", test_oov_correct_counter, test_oov_wrong_counter)

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(train_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(val_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(test_oov_flag, cmap=plt.cm.binary_r);
