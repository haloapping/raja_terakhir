# %% [markdown]
# # Import modules

# %%
import csv
import os
import pickle
import pytz
import torch
import timeit
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from copy import deepcopy
from datetime import datetime
from einops import rearrange
from itertools import chain
from time import time
from torch import nn, optim
from torchmetrics.classification import MulticlassAccuracy, MulticlassF1Score, MulticlassConfusionMatrix
from torch.optim import lr_scheduler
from tqdm.notebook import tqdm
from torch.utils.data import TensorDataset, DataLoader
from polyglot.mapping import Embedding, CaseExpander, DigitExpander

# %% [markdown]
# # Hyperparameters

# %%
class Hyperparams:
     def __init__(
        self,
        fold=3,
        max_seq_len=82,
        input_size=64,
        batch_size=32,
        num_hidden_layer=1,
        hidden_size=128,
        dropout=0,
        bias=True,
        output_size=24,
        shuffle=True,
        lr=0.005,
        batch_first=False,
        bidirectional=True,
        init_wb_with_kaiming_normal=True,
        n_epoch=50,
        patience=50,
        device="cuda" if torch.cuda.is_available() else "cpu"
    ):
        self.fold = fold
        self.input_size = input_size
        self.max_seq_len = max_seq_len
        self.batch_size = batch_size
        self.num_hidden_layer = num_hidden_layer
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.output_size = output_size
        self.shuffle = shuffle
        self.lr = lr
        self.batch_first = batch_first
        self.bidirectional = bidirectional
        self.init_wb_with_kaiming_normal = init_wb_with_kaiming_normal
        self.n_epoch = n_epoch
        self.patience = patience
        self.device = device

hyperparams = Hyperparams()

# %% [markdown]
# # Dataset

# %%
id_pos_tag = pd.read_csv("../../datasets/raw/Indonesian_Manually_Tagged_Corpus.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False) 
train = pd.read_csv(f"../../datasets/raw/cv/train/train.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
val = pd.read_csv(f"../../datasets/raw/cv/val/val.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
test = pd.read_csv(f"../../datasets/raw/cv/test/test.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)

# %% [markdown]
# # Pre-trained Word Embedding

# %%
embeddings = Embedding.load("../../word_embeddings/polyglot/idn_embeddings.tar.bz2")
embeddings.apply_expansion(DigitExpander)
embeddings.apply_expansion(CaseExpander)

oov_embeddings = pickle.load(open(f"../../logs/comick/79_contexts/10-11-2022_19-39-04/oov_embedding_dict.pkl", "rb"))
oov_embeddings = {key: embeddings["<UNK>"] for key, _ in oov_embeddings.items()}

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Add OOV Flag

# %%
def add_oov_flag(tokens, embeddings):
    oov_flags = []
    
    for token in tqdm(tokens):
        try:
            if token not in embeddings:
                oov_flags.append(True)
            else:
                oov_flags.append(False)
        except:
            oov_flags.append(False)
        
    return pd.DataFrame(oov_flags, columns=["is_oov"])

id_pos_tag_oov_flags = add_oov_flag(id_pos_tag["token"].values, embeddings)
train_oov_flags = add_oov_flag(train["token"].values, embeddings)
val_oov_flags = add_oov_flag(val["token"].values, embeddings)
test_oov_flags = add_oov_flag(test["token"].values, embeddings)
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/192215 [00:00<?, ?it/s]
#   0%|          | 0/21143 [00:00<?, ?it/s]
#   0%|          | 0/53294 [00:00<?, ?it/s]

# %% [markdown]
# ## Concate OOV Flag

# %%
id_pos_tag_df = pd.concat([id_pos_tag, id_pos_tag_oov_flags], axis=1)
train_df = pd.concat([train, train_oov_flags], axis=1)
val_df = pd.concat([val, val_oov_flags], axis=1)
test_df = pd.concat([test, test_oov_flags], axis=1)

# %% [markdown]
# ## Lowercase OOV Token

# %%
id_pos_tag_df['token'] = np.where(id_pos_tag_df['is_oov'] == True, id_pos_tag_df['token'].str.lower(), id_pos_tag_df['token'])
train_df['token'] = np.where(train_df['is_oov'] == True, train_df['token'].str.lower(), train_df['token'])
val_df['token'] = np.where(val_df['is_oov'] == True, val_df['token'].str.lower(), val_df['token'])
test_df['token'] = np.where(test_df['is_oov'] == True, test_df['token'].str.lower(), test_df['token'])

# %% [markdown]
# ## Embedding Dict, Index to Token and Token to Index

# %%
tokens = list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None))

def embedding_dict(tokens, embeddings, oov_embeddings):
    embedding = {}
    
    for token in tokens:
        if token[0] is not np.nan:
            if token[2] == False or token[0] in embeddings:
                embedding[token[0]] = embeddings[token[0]]
            else:
                embedding[token[0]] = oov_embeddings[token[0].lower()]

    return embedding

embedding_dict = embedding_dict(tokens, embeddings, oov_embeddings)
embedding_dict["<PAD>"] = embeddings["<PAD>"]
word_embeddings = nn.Embedding.from_pretrained(torch.FloatTensor(np.array(list(embedding_dict.values()))), padding_idx=list(embedding_dict.keys()).index("<PAD>"), freeze=True)

idx_to_token = {idx: token for idx, token in enumerate(list(embedding_dict.keys()))}
token_to_idx = {token: idx for idx, token in enumerate(list(embedding_dict.keys()))}

# %% [markdown]
# ## Token to Sentence

# %%
def make_sentence(tokens, max_length_sentence=hyperparams.max_seq_len):
    sentence = []
    sentences = []

    for token in tqdm(tokens):
        if token[0] is not np.nan:
            sentence.append(token)
        else:
            sentences.append(sentence[:max_length_sentence])
            sentence = []

    return sentences

all_sentence = make_sentence(list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
train_sentences = make_sentence(list(train_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
val_sentences = make_sentence(list(test_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
test_sentences = make_sentence(list(val_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/192215 [00:00<?, ?it/s]
#   0%|          | 0/53294 [00:00<?, ?it/s]
#   0%|          | 0/21143 [00:00<?, ?it/s]

# %% [markdown]
# ## Word Token, Padding, and Word token to Index

# %%
def tokenize_docs(docs, idx_token):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token[idx_token])
        sentences.append(new_sentence)
        new_sentence = []

    return sentences

def padding(docs, max_seq_len=hyperparams.max_seq_len, mode="post", val_pad="<PAD>"):
    docs = deepcopy(docs)
    doc_with_pad = []
    docs_with_pad = []

    for doc in tqdm(docs):
        if mode == "pre":
            for _ in range(max_seq_len - len(doc)):
                doc.insert(0, val_pad)
        elif mode == "post":
            for _ in range(max_seq_len - len(doc)):
                doc.append(val_pad)
        else:
            return f"Mode {mode} is not available, use instead 'pre' or 'post'."
        
        docs_with_pad.append(doc)
        
    return np.array(docs_with_pad)

def sent_to_idx(docs, token_to_idx):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token_to_idx[token])
        sentences.append(new_sentence)
        new_sentence = []

    return np.array(sentences)

def convert_feature_to_idx(docs, idx_token, token_to_idx, max_seq_len):
    sentences = tokenize_docs(docs, idx_token)
    sentences_with_pad = padding(sentences, max_seq_len=max_seq_len, mode="post", val_pad="<PAD>")
    sentences_to_idx = sent_to_idx(sentences_with_pad, token_to_idx)
    
    return sentences_to_idx

train_sentence_idxs = convert_feature_to_idx(train_sentences, 0, token_to_idx, hyperparams.max_seq_len)
val_sentence_idxs = convert_feature_to_idx(val_sentences, 0, token_to_idx, hyperparams.max_seq_len)
test_sentence_idxs = convert_feature_to_idx(test_sentences, 0, token_to_idx, hyperparams.max_seq_len)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]

# %% [markdown]
# ## Encode Class

# %%
classes = sorted(np.delete(id_pos_tag_df["tag"].unique(), 3))
idx_to_label = {idx: label for idx, label in enumerate(classes + ["<PAD>"])}
label_to_idx = {label: idx for idx, label in enumerate(classes + ["<PAD>"])}

def encode_class(docs, label_to_idx, seq_len=hyperparams.max_seq_len):
    class_idxs = []
    classes = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            class_idxs.append(label_to_idx[token[1]])
            
        for _ in range(seq_len - len(sentence)):
            class_idxs.append(label_to_idx["<PAD>"])
                
        classes.append(class_idxs)
        class_idxs = []

    return np.array(classes)
        
train_class_idxs = encode_class(train_sentences, label_to_idx)
val_class_idxs = encode_class(val_sentences, label_to_idx)
test_class_idxs = encode_class(test_sentences, label_to_idx)

print(f"Training shape   : {train_sentence_idxs.shape, train_class_idxs.shape}")
print(f"validation shape : {val_class_idxs.shape, val_class_idxs.shape}")
print(f"Test shape       : {test_sentence_idxs.shape, test_class_idxs.shape}")
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# Training shape   : ((7222, 82), (7222, 82))
# validation shape : ((2006, 82), (2006, 82))
# Test shape       : ((802, 82), (802, 82))

# %% [markdown]
# ## Note
#
# - Number of sentences = 10030
# - Train : 72% (7222)
# - Val   : 8% (802)
# - Test  : 20% (2006)

# %% [markdown]
# # Build Model

# %% [markdown]
# ## Feature and Actual Class

# %%
train_feature = torch.LongTensor(train_sentence_idxs)
val_feature = torch.LongTensor(val_sentence_idxs)
test_feature = torch.LongTensor(test_sentence_idxs)

train_class = torch.LongTensor(train_class_idxs)
val_class = torch.LongTensor(val_class_idxs)
test_class = torch.LongTensor(test_class_idxs)

# %%
train_feature.shape, val_feature.shape, test_feature.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %%
train_class.shape, val_class.shape, test_class.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %% [markdown]
# ## Tensor Dataset

# %%
train_dataset = TensorDataset(train_feature, train_class)
val_dataset = TensorDataset(val_feature, val_class)
test_dataset = TensorDataset(test_feature, test_class)

# %% [markdown]
# ## Dataloader

# %%
train_dataloader = DataLoader(train_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
val_dataloader = DataLoader(val_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
test_dataloader = DataLoader(test_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)

# %% [markdown]
# ## Model

# %%
class POSTagger(nn.Module):
    def __init__(
        self,
        input_size=hyperparams.input_size,
        hidden_size=hyperparams.hidden_size,
        dropout=hyperparams.dropout,
        bias=hyperparams.bias,
        num_layers=hyperparams.num_hidden_layer,
        output_size=hyperparams.output_size,
        batch_first=hyperparams.batch_first,
        bidirectional=hyperparams.bidirectional,
        init_wb_with_kaiming_normal=hyperparams.init_wb_with_kaiming_normal
    ):
        super(POSTagger, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.num_layers = num_layers
        self.output_size = output_size
        self.batch_first = batch_first
        self.bidirectional = bidirectional
                
        self.feature = nn.LSTM(
            input_size = self.input_size,
            hidden_size = self.hidden_size,
            bias = self.bias,
            dropout = self.dropout,
            num_layers = self.num_layers,
            batch_first = self.batch_first,
            bidirectional = self.bidirectional
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(in_features=2 * self.hidden_size if hyperparams.bidirectional else self.hidden_size, out_features=self.output_size, bias=self.bias),
            nn.Softmax(dim=-1)
        )
        
        if init_wb_with_kaiming_normal:
            self.init_wb()

    def init_wb(self):
        for module in self.modules():
            if isinstance(module, (nn.Linear, nn.LSTM)):
                for name, param in module.named_parameters():
                    if "weight" in name:
                        nn.init.kaiming_normal_(param)
                    else:
                        nn.init.kaiming_normal_(param.reshape(1, -1))
        
    def forward(self, feature, hidden=None):
        output, (hidden, memory) = self.feature(feature, None)
        prob = self.classifier(output)

        return prob
    
model = POSTagger().to(hyperparams.device)
model
# Out:
# POSTagger(
#   (feature): LSTM(64, 128, bidirectional=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=24, bias=True)
#     (1): Softmax(dim=-1)
#   )
# )

# %% [markdown]
# ## Optimizer, Criterion, and Metric

# %%
optimizer = optim.Adam(model.parameters(), lr=hyperparams.lr)
criterion = nn.CrossEntropyLoss().to(hyperparams.device)
train_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", verbose=True, factor=0.5)

# %%
sum(param.numel() for param in model.parameters() if param.requires_grad)
# Out:
# 204824

# %% [markdown]
# ## Training Step

# %%
def training_step(dataloader, model, optimizer, criterion, metric, scheduler=None):
    model.train()
    
    batch_losses = []
    batch_metric_scores = []
    
    for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
        # Forward Propagation
        feature = rearrange(feature, "n s -> s n")
        actual_label = rearrange(actual_label, "n s -> s n")
        embedding = word_embeddings(feature)
        
        prob = model(
            embedding.to(hyperparams.device),
            actual_label.to(hyperparams.device)
        )
        
        prob = prob.reshape(-1, prob.shape[-1])
        actual_label = actual_label.reshape(-1)

        loss = criterion(prob, actual_label.to(hyperparams.device))
        metric_score = metric(prob, actual_label.to(hyperparams.device))
        metric_score = metric.compute()
                
        if scheduler is not None:
            scheduler.step(loss)
        
        batch_losses.append(loss.item())
        batch_metric_scores.append(metric_score)
        
        if len(dataloader) < 10:
            if batch % 1 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../logs/unk/fold_{hyperparams.fold}/{path_name}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
        else:
            if batch % 15 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../logs/unk/fold_{hyperparams.fold}/{path_name}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            
        # Backward Propagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Validation Step

# %%
def validation_step(dataloader, model, criterion, metric):
    model.eval()
    
    batch_losses = []
    batch_metric_scores = []
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob, actual_label.to(hyperparams.device))
            metric_score = metric.compute()

            batch_losses.append(loss.item())
            batch_metric_scores.append(metric_score)
            
            if len(dataloader) < 10 and (batch % 1 == 0 or batch == len(dataloader)):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../logs/unk/fold_{hyperparams.fold}/{path_name}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            else:
                if batch % 15 == 0 or batch == len(dataloader):
                    batch_name = "Batch-" + str(batch)
                    print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                    with open(f"../../logs/unk/fold_{hyperparams.fold}/{path_name}/training_history.txt", "a") as f:
                        f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Looping Step

# %%
now = datetime.now(pytz.timezone("Asia/Ujung_Pandang"))
path_name = now.strftime("%m-%d-%Y_%H-%M-%S")
root_path = f"../../logs/unk/fold_{hyperparams.fold}/{path_name}"
os.makedirs(root_path)

def looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric, n_epoch=hyperparams.n_epoch, patience=hyperparams.patience, monitor="loss"):    
    start_time = time()
    
    epoch_training_losses = []
    epoch_training_metric_scores = []
    epoch_val_losses = []
    epoch_val_metric_scores = []
    patience_counter = 0
    
    # Hyperparameters
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write(f"HYPERPARAMETERS\n")
        f.write(f"{'-' * 80}\n")
        for name, value in vars(hyperparams).items():
            f.write(f"{name}: {value}\n")
        
        f.write("\n\nTRAINING PROGRESS\n")
        f.write(f"{'-' * 80}\n")
    
    # Training Progress
    for epoch in range(1, n_epoch + 1):
        print(f"EPOCH-{epoch}")
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"EPOCH-{epoch}\n")
            f.write(f"Training Step\n")
            
        # Training Step
        print("Training Step")
        batch_training_losses, batch_training_metric_scores = training_step(train_dataloader, model, optimizer, criterion, train_metric, scheduler=None)
        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))

        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))
        epoch_training_losses.append(epoch_training_loss.item())

        epoch_training_metric_score = torch.mean(torch.FloatTensor(batch_training_metric_scores))
        epoch_training_metric_scores.append(epoch_training_metric_score.item())
        
        # Validation Step
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"\nValidation Step\n")
            
        print("\nValidation Step")
        batch_val_losses, batch_val_metric_scores = validation_step(val_dataloader, model, criterion, val_metric)
        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))

        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))
        epoch_val_losses.append(epoch_val_loss.item())

        epoch_val_metric_score = torch.mean(torch.FloatTensor(batch_val_metric_scores))
        epoch_val_metric_scores.append(epoch_val_metric_score.item())
        
        with open(f"{root_path}/training_history.txt", "a") as f:
            if monitor == "loss":
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_losses[-1] < epoch_training_losses[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
            else:
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_metric_scores[-1] > epoch_training_metric_scores[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗\n")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
                    
            print("=" * 80, end="\n\n")
            
            f.write(f"{'=' * 80}\n\n")
            
            if patience_counter == patience:
                print(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                
                f.write(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                break
        
        train_metric.reset()
        val_metric.reset()
        
    finish_time = time()
    
    # Training plot 
    fig, (ax_loss, ax_metric_score) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    fig.suptitle(f"Training with oov embedding = unknown polyglot")

    ax_loss.set_title("Loss")
    ax_loss.set_xlabel("Epoch")
    ax_loss.set_ylabel("Score")
    ax_loss.plot(epoch_training_losses, "green", label="Training")
    ax_loss.plot(epoch_val_losses, "orange", label="Validation")
    ax_loss.legend()
    ax_loss.grid()

    ax_metric_score.set_title("F1 Score")
    ax_metric_score.set_xlabel("Epoch")
    ax_metric_score.set_ylabel("Score")
    ax_metric_score.plot(epoch_training_metric_scores, "green", label="Training")
    ax_metric_score.plot(epoch_val_metric_scores, "orange", label="Validation")
    ax_metric_score.legend()
    ax_metric_score.grid()

    plt.savefig(f"{root_path}/training_plot.jpg", dpi=200)                        
    
    print("TRAINING SUMMARY")
    name_best_training_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_training_metric = f"Best {str(train_metric).split('(')[0]} validation".ljust(34)
    name_best_validation_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_validation_metric = f"Best {str(val_metric).split('(')[0]} validation".ljust(34)
    name_training_time = f"Training duration".ljust(34)
    name_training_date = f"Training date".ljust(34)
    
    print(f"{name_best_training_loss}: {best_training_loss:.4f}")
    print(f"{name_best_validation_loss}: {best_val_loss:.4f}")
    print(f"{name_best_training_metric}: {best_training_metric:.4f}")
    print(f"{name_best_validation_metric}: {best_val_metric:.4f}")
    print(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.")
    print(f"{name_training_date}: {now}")
    
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write("\nTRAINING SUMMARY\n")
        f.write(f"{'-' * 80}\n")
        f.write(f"{name_best_training_loss}: {best_training_loss:.4f}\n")
        f.write(f"{name_best_validation_loss}: {best_val_loss:.4f}\n")
        f.write(f"{name_best_training_metric}: {best_training_metric:.4f}\n")
        f.write(f"{name_best_validation_metric}: {best_val_metric:.4f}\n")
        f.write(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.\n")
        f.write(f"{name_training_date}: {now}\n")
    
    # Save epoch losses, epoch metric scores, model, state dict, and oov embedding dict
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_training_losses
    }).to_csv(f"{root_path}/training_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_training_metric_scores
    }).to_csv(f"{root_path}/training_metric_scores.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_val_losses
    }).to_csv(f"{root_path}/val_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_val_metric_scores
    }).to_csv(f"{root_path}/val_metric_scores.csv", index=False)    
    
    filename_model_params = f"{root_path}/model_params.pth"
    torch.save(best_state_dict, filename_model_params)
    
    return epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores

epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores = looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric)
# Out:
# EPOCH-1
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.5130 | MulticlassF1Score=0.0960
# Batch-30 : CrossEntropyLoss=2.4931 | MulticlassF1Score=0.1623
# Batch-45 : CrossEntropyLoss=2.4786 | MulticlassF1Score=0.1885
# Batch-60 : CrossEntropyLoss=2.5033 | MulticlassF1Score=0.2026
# Batch-75 : CrossEntropyLoss=2.4465 | MulticlassF1Score=0.2097
# Batch-90 : CrossEntropyLoss=2.4628 | MulticlassF1Score=0.2158
# Batch-105: CrossEntropyLoss=2.4555 | MulticlassF1Score=0.2184
# Batch-120: CrossEntropyLoss=2.4717 | MulticlassF1Score=0.2215
# Batch-135: CrossEntropyLoss=2.4521 | MulticlassF1Score=0.2248
# Batch-150: CrossEntropyLoss=2.4324 | MulticlassF1Score=0.2329
# Batch-165: CrossEntropyLoss=2.4626 | MulticlassF1Score=0.2432
# Batch-180: CrossEntropyLoss=2.4192 | MulticlassF1Score=0.2568
# Batch-195: CrossEntropyLoss=2.4051 | MulticlassF1Score=0.2716
# Batch-210: CrossEntropyLoss=2.4014 | MulticlassF1Score=0.2840
# Batch-225: CrossEntropyLoss=2.3621 | MulticlassF1Score=0.3054
# Batch-226: CrossEntropyLoss=2.3662 | MulticlassF1Score=0.3064
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3618 | MulticlassF1Score=0.6251
# Batch-30 : CrossEntropyLoss=2.3862 | MulticlassF1Score=0.6307
# Batch-45 : CrossEntropyLoss=2.3728 | MulticlassF1Score=0.6326
# Batch-60 : CrossEntropyLoss=2.3738 | MulticlassF1Score=0.6341
# Batch-63 : CrossEntropyLoss=2.3719 | MulticlassF1Score=0.6334
#
# Training   : Mean CrossEntropyLoss = 2.4711 | Mean MulticlassF1Score = 0.2129
# Validation : Mean CrossEntropyLoss = 2.3657 | Mean MulticlassF1Score = 0.6303
# ================================================================================
#
# EPOCH-2
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3379 | MulticlassF1Score=0.6411
# Batch-30 : CrossEntropyLoss=2.3605 | MulticlassF1Score=0.6403
# Batch-45 : CrossEntropyLoss=2.3457 | MulticlassF1Score=0.6486
# Batch-60 : CrossEntropyLoss=2.3364 | MulticlassF1Score=0.6573
# Batch-75 : CrossEntropyLoss=2.3424 | MulticlassF1Score=0.6652
# Batch-90 : CrossEntropyLoss=2.3327 | MulticlassF1Score=0.6682
# Batch-105: CrossEntropyLoss=2.3229 | MulticlassF1Score=0.6767
# Batch-120: CrossEntropyLoss=2.3156 | MulticlassF1Score=0.6848
# Batch-135: CrossEntropyLoss=2.3111 | MulticlassF1Score=0.6920
# Batch-150: CrossEntropyLoss=2.3296 | MulticlassF1Score=0.6985
# Batch-165: CrossEntropyLoss=2.3153 | MulticlassF1Score=0.7045
# Batch-180: CrossEntropyLoss=2.3303 | MulticlassF1Score=0.7099
# Batch-195: CrossEntropyLoss=2.3149 | MulticlassF1Score=0.7142
# Batch-210: CrossEntropyLoss=2.3235 | MulticlassF1Score=0.7179
# Batch-225: CrossEntropyLoss=2.3235 | MulticlassF1Score=0.7210
# Batch-226: CrossEntropyLoss=2.3090 | MulticlassF1Score=0.7211
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3258 | MulticlassF1Score=0.7691
# Batch-30 : CrossEntropyLoss=2.3311 | MulticlassF1Score=0.7654
# Batch-45 : CrossEntropyLoss=2.3248 | MulticlassF1Score=0.7686
# Batch-60 : CrossEntropyLoss=2.3202 | MulticlassF1Score=0.7678
# Batch-63 : CrossEntropyLoss=2.3295 | MulticlassF1Score=0.7677
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3356 | Mean MulticlassF1Score = 0.6803
# Validation : Mean CrossEntropyLoss = 2.3202 | Mean MulticlassF1Score = 0.7679
# ================================================================================
#
# EPOCH-3
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3173 | MulticlassF1Score=0.7739
# Batch-30 : CrossEntropyLoss=2.3256 | MulticlassF1Score=0.7706
# Batch-45 : CrossEntropyLoss=2.3127 | MulticlassF1Score=0.7715
# Batch-60 : CrossEntropyLoss=2.3243 | MulticlassF1Score=0.7711
# Batch-75 : CrossEntropyLoss=2.3246 | MulticlassF1Score=0.7712
# Batch-90 : CrossEntropyLoss=2.3155 | MulticlassF1Score=0.7707
# Batch-105: CrossEntropyLoss=2.3099 | MulticlassF1Score=0.7734
# Batch-120: CrossEntropyLoss=2.3218 | MulticlassF1Score=0.7744
# Batch-135: CrossEntropyLoss=2.3087 | MulticlassF1Score=0.7764
# Batch-150: CrossEntropyLoss=2.3187 | MulticlassF1Score=0.7778
# Batch-165: CrossEntropyLoss=2.3114 | MulticlassF1Score=0.7786
# Batch-180: CrossEntropyLoss=2.3009 | MulticlassF1Score=0.7791
# Batch-195: CrossEntropyLoss=2.3074 | MulticlassF1Score=0.7800
# Batch-210: CrossEntropyLoss=2.3096 | MulticlassF1Score=0.7810
# Batch-225: CrossEntropyLoss=2.3164 | MulticlassF1Score=0.7825
# Batch-226: CrossEntropyLoss=2.3020 | MulticlassF1Score=0.7824
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3085 | MulticlassF1Score=0.7975
# Batch-30 : CrossEntropyLoss=2.3184 | MulticlassF1Score=0.8028
# Batch-45 : CrossEntropyLoss=2.3079 | MulticlassF1Score=0.8040
# Batch-60 : CrossEntropyLoss=2.3105 | MulticlassF1Score=0.8027
# Batch-63 : CrossEntropyLoss=2.3091 | MulticlassF1Score=0.8026
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3156 | Mean MulticlassF1Score = 0.7751
# Validation : Mean CrossEntropyLoss = 2.3092 | Mean MulticlassF1Score = 0.8032
# ================================================================================
#
# EPOCH-4
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3203 | MulticlassF1Score=0.7995
# Batch-30 : CrossEntropyLoss=2.3158 | MulticlassF1Score=0.7969
# Batch-45 : CrossEntropyLoss=2.3080 | MulticlassF1Score=0.7988
# Batch-60 : CrossEntropyLoss=2.3020 | MulticlassF1Score=0.7995
# Batch-75 : CrossEntropyLoss=2.2999 | MulticlassF1Score=0.8020
# Batch-90 : CrossEntropyLoss=2.2990 | MulticlassF1Score=0.8051
# Batch-105: CrossEntropyLoss=2.3077 | MulticlassF1Score=0.8069
# Batch-120: CrossEntropyLoss=2.2995 | MulticlassF1Score=0.8087
# Batch-135: CrossEntropyLoss=2.3095 | MulticlassF1Score=0.8097
# Batch-150: CrossEntropyLoss=2.3110 | MulticlassF1Score=0.8113
# Batch-165: CrossEntropyLoss=2.2917 | MulticlassF1Score=0.8143
# Batch-180: CrossEntropyLoss=2.2897 | MulticlassF1Score=0.8171
# Batch-195: CrossEntropyLoss=2.2959 | MulticlassF1Score=0.8194
# Batch-210: CrossEntropyLoss=2.2905 | MulticlassF1Score=0.8214
# Batch-225: CrossEntropyLoss=2.2936 | MulticlassF1Score=0.8231
# Batch-226: CrossEntropyLoss=2.3002 | MulticlassF1Score=0.8233
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2983 | MulticlassF1Score=0.8539
# Batch-30 : CrossEntropyLoss=2.2891 | MulticlassF1Score=0.8493
# Batch-45 : CrossEntropyLoss=2.2901 | MulticlassF1Score=0.8494
# Batch-60 : CrossEntropyLoss=2.2914 | MulticlassF1Score=0.8506
# Batch-63 : CrossEntropyLoss=2.2872 | MulticlassF1Score=0.8497
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3031 | Mean MulticlassF1Score = 0.8087
# Validation : Mean CrossEntropyLoss = 2.2947 | Mean MulticlassF1Score = 0.8495
# ================================================================================
#
# EPOCH-5
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3127 | MulticlassF1Score=0.8494
# Batch-30 : CrossEntropyLoss=2.2897 | MulticlassF1Score=0.8524
# Batch-45 : CrossEntropyLoss=2.2982 | MulticlassF1Score=0.8523
# Batch-60 : CrossEntropyLoss=2.2983 | MulticlassF1Score=0.8540
# Batch-75 : CrossEntropyLoss=2.2889 | MulticlassF1Score=0.8545
# Batch-90 : CrossEntropyLoss=2.2960 | MulticlassF1Score=0.8538
# Batch-105: CrossEntropyLoss=2.2945 | MulticlassF1Score=0.8524
# Batch-120: CrossEntropyLoss=2.3008 | MulticlassF1Score=0.8528
# Batch-135: CrossEntropyLoss=2.2917 | MulticlassF1Score=0.8529
# Batch-150: CrossEntropyLoss=2.2897 | MulticlassF1Score=0.8520
# Batch-165: CrossEntropyLoss=2.2886 | MulticlassF1Score=0.8528
# Batch-180: CrossEntropyLoss=2.2914 | MulticlassF1Score=0.8529
# Batch-195: CrossEntropyLoss=2.2963 | MulticlassF1Score=0.8523
# Batch-210: CrossEntropyLoss=2.2866 | MulticlassF1Score=0.8525
# Batch-225: CrossEntropyLoss=2.2830 | MulticlassF1Score=0.8527
# Batch-226: CrossEntropyLoss=2.2919 | MulticlassF1Score=0.8528
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2905 | MulticlassF1Score=0.8490
# Batch-30 : CrossEntropyLoss=2.2915 | MulticlassF1Score=0.8500
# Batch-45 : CrossEntropyLoss=2.2907 | MulticlassF1Score=0.8510
# Batch-60 : CrossEntropyLoss=2.2866 | MulticlassF1Score=0.8538
# Batch-63 : CrossEntropyLoss=2.2847 | MulticlassF1Score=0.8542
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2938 | Mean MulticlassF1Score = 0.8530
# Validation : Mean CrossEntropyLoss = 2.2930 | Mean MulticlassF1Score = 0.8509
# ================================================================================
#
# EPOCH-6
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2870 | MulticlassF1Score=0.8568
# Batch-30 : CrossEntropyLoss=2.2927 | MulticlassF1Score=0.8585
# Batch-45 : CrossEntropyLoss=2.3019 | MulticlassF1Score=0.8550
# Batch-60 : CrossEntropyLoss=2.2913 | MulticlassF1Score=0.8567
# Batch-75 : CrossEntropyLoss=2.2886 | MulticlassF1Score=0.8572
# Batch-90 : CrossEntropyLoss=2.2951 | MulticlassF1Score=0.8572
# Batch-105: CrossEntropyLoss=2.2933 | MulticlassF1Score=0.8575
# Batch-120: CrossEntropyLoss=2.2924 | MulticlassF1Score=0.8573
# Batch-135: CrossEntropyLoss=2.2933 | MulticlassF1Score=0.8572
# Batch-150: CrossEntropyLoss=2.2969 | MulticlassF1Score=0.8569
# Batch-165: CrossEntropyLoss=2.2847 | MulticlassF1Score=0.8568
# Batch-180: CrossEntropyLoss=2.2978 | MulticlassF1Score=0.8571
# Batch-195: CrossEntropyLoss=2.2948 | MulticlassF1Score=0.8571
# Batch-210: CrossEntropyLoss=2.2922 | MulticlassF1Score=0.8578
# Batch-225: CrossEntropyLoss=2.2862 | MulticlassF1Score=0.8588
# Batch-226: CrossEntropyLoss=2.2907 | MulticlassF1Score=0.8588
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2866 | MulticlassF1Score=0.8725
# Batch-30 : CrossEntropyLoss=2.2803 | MulticlassF1Score=0.8722
# Batch-45 : CrossEntropyLoss=2.2870 | MulticlassF1Score=0.8734
# Batch-60 : CrossEntropyLoss=2.2878 | MulticlassF1Score=0.8722
# Batch-63 : CrossEntropyLoss=2.2864 | MulticlassF1Score=0.8719
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2918 | Mean MulticlassF1Score = 0.8568
# Validation : Mean CrossEntropyLoss = 2.2881 | Mean MulticlassF1Score = 0.8728
# ================================================================================
#
# EPOCH-7
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2855 | MulticlassF1Score=0.8809
# Batch-30 : CrossEntropyLoss=2.2810 | MulticlassF1Score=0.8794
# Batch-45 : CrossEntropyLoss=2.2812 | MulticlassF1Score=0.8792
# Batch-60 : CrossEntropyLoss=2.2815 | MulticlassF1Score=0.8787
# Batch-75 : CrossEntropyLoss=2.2852 | MulticlassF1Score=0.8781
# Batch-90 : CrossEntropyLoss=2.2958 | MulticlassF1Score=0.8781
# Batch-105: CrossEntropyLoss=2.2810 | MulticlassF1Score=0.8777
# Batch-120: CrossEntropyLoss=2.2927 | MulticlassF1Score=0.8772
# Batch-135: CrossEntropyLoss=2.2873 | MulticlassF1Score=0.8774
# Batch-150: CrossEntropyLoss=2.2834 | MulticlassF1Score=0.8773
# Batch-165: CrossEntropyLoss=2.2889 | MulticlassF1Score=0.8771
# Batch-180: CrossEntropyLoss=2.2857 | MulticlassF1Score=0.8772
# Batch-195: CrossEntropyLoss=2.2895 | MulticlassF1Score=0.8767
# Batch-210: CrossEntropyLoss=2.2839 | MulticlassF1Score=0.8768
# Batch-225: CrossEntropyLoss=2.2827 | MulticlassF1Score=0.8766
# Batch-226: CrossEntropyLoss=2.2840 | MulticlassF1Score=0.8766
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2901 | MulticlassF1Score=0.8685
# Batch-30 : CrossEntropyLoss=2.2918 | MulticlassF1Score=0.8705
# Batch-45 : CrossEntropyLoss=2.2773 | MulticlassF1Score=0.8724
# Batch-60 : CrossEntropyLoss=2.2899 | MulticlassF1Score=0.8733
# Batch-63 : CrossEntropyLoss=2.2883 | MulticlassF1Score=0.8737
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2864 | Mean MulticlassF1Score = 0.8778
# Validation : Mean CrossEntropyLoss = 2.2871 | Mean MulticlassF1Score = 0.8707
# ================================================================================
#
# EPOCH-8
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2760 | MulticlassF1Score=0.8750
# Batch-30 : CrossEntropyLoss=2.2917 | MulticlassF1Score=0.8756
# Batch-45 : CrossEntropyLoss=2.2812 | MulticlassF1Score=0.8765
# Batch-60 : CrossEntropyLoss=2.2912 | MulticlassF1Score=0.8781
# Batch-75 : CrossEntropyLoss=2.2813 | MulticlassF1Score=0.8789
# Batch-90 : CrossEntropyLoss=2.2813 | MulticlassF1Score=0.8788
# Batch-105: CrossEntropyLoss=2.2854 | MulticlassF1Score=0.8795
# Batch-120: CrossEntropyLoss=2.2897 | MulticlassF1Score=0.8791
# Batch-135: CrossEntropyLoss=2.2857 | MulticlassF1Score=0.8791
# Batch-150: CrossEntropyLoss=2.2922 | MulticlassF1Score=0.8783
# Batch-165: CrossEntropyLoss=2.2838 | MulticlassF1Score=0.8784
# Batch-180: CrossEntropyLoss=2.2782 | MulticlassF1Score=0.8788
# Batch-195: CrossEntropyLoss=2.2890 | MulticlassF1Score=0.8787
# Batch-210: CrossEntropyLoss=2.2800 | MulticlassF1Score=0.8789
# Batch-225: CrossEntropyLoss=2.2855 | MulticlassF1Score=0.8790
# Batch-226: CrossEntropyLoss=2.2819 | MulticlassF1Score=0.8790
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2855 | MulticlassF1Score=0.8714
# Batch-30 : CrossEntropyLoss=2.2850 | MulticlassF1Score=0.8713
# Batch-45 : CrossEntropyLoss=2.2786 | MulticlassF1Score=0.8738
# Batch-60 : CrossEntropyLoss=2.2784 | MulticlassF1Score=0.8740
# Batch-63 : CrossEntropyLoss=2.2842 | MulticlassF1Score=0.8742
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2854 | Mean MulticlassF1Score = 0.8781
# Validation : Mean CrossEntropyLoss = 2.2866 | Mean MulticlassF1Score = 0.8716
# ================================================================================
#
# EPOCH-9
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2774 | MulticlassF1Score=0.8783
# Batch-30 : CrossEntropyLoss=2.2867 | MulticlassF1Score=0.8815
# Batch-45 : CrossEntropyLoss=2.2813 | MulticlassF1Score=0.8820
# Batch-60 : CrossEntropyLoss=2.2920 | MulticlassF1Score=0.8821
# Batch-75 : CrossEntropyLoss=2.2974 | MulticlassF1Score=0.8824
# Batch-90 : CrossEntropyLoss=2.2856 | MulticlassF1Score=0.8820
# Batch-105: CrossEntropyLoss=2.2800 | MulticlassF1Score=0.8820
# Batch-120: CrossEntropyLoss=2.2849 | MulticlassF1Score=0.8825
# Batch-135: CrossEntropyLoss=2.2744 | MulticlassF1Score=0.8826
# Batch-150: CrossEntropyLoss=2.2896 | MulticlassF1Score=0.8820
# Batch-165: CrossEntropyLoss=2.2943 | MulticlassF1Score=0.8816
# Batch-180: CrossEntropyLoss=2.2850 | MulticlassF1Score=0.8814
# Batch-195: CrossEntropyLoss=2.2911 | MulticlassF1Score=0.8813
# Batch-210: CrossEntropyLoss=2.2833 | MulticlassF1Score=0.8816
# Batch-225: CrossEntropyLoss=2.2886 | MulticlassF1Score=0.8818
# Batch-226: CrossEntropyLoss=2.2910 | MulticlassF1Score=0.8817
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2880 | MulticlassF1Score=0.8802
# Batch-30 : CrossEntropyLoss=2.2901 | MulticlassF1Score=0.8783
# Batch-45 : CrossEntropyLoss=2.2856 | MulticlassF1Score=0.8773
# Batch-60 : CrossEntropyLoss=2.2836 | MulticlassF1Score=0.8757
# Batch-63 : CrossEntropyLoss=2.2812 | MulticlassF1Score=0.8758
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2845 | Mean MulticlassF1Score = 0.8814
# Validation : Mean CrossEntropyLoss = 2.2861 | Mean MulticlassF1Score = 0.8788
# ================================================================================
#
# EPOCH-10
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2843 | MulticlassF1Score=0.8842
# Batch-30 : CrossEntropyLoss=2.2814 | MulticlassF1Score=0.8839
# Batch-45 : CrossEntropyLoss=2.2774 | MulticlassF1Score=0.8856
# Batch-60 : CrossEntropyLoss=2.2797 | MulticlassF1Score=0.8839
# Batch-75 : CrossEntropyLoss=2.2867 | MulticlassF1Score=0.8836
# Batch-90 : CrossEntropyLoss=2.2805 | MulticlassF1Score=0.8832
# Batch-105: CrossEntropyLoss=2.2850 | MulticlassF1Score=0.8826
# Batch-120: CrossEntropyLoss=2.2904 | MulticlassF1Score=0.8828
# Batch-135: CrossEntropyLoss=2.2870 | MulticlassF1Score=0.8833
# Batch-150: CrossEntropyLoss=2.2837 | MulticlassF1Score=0.8834
# Batch-165: CrossEntropyLoss=2.2798 | MulticlassF1Score=0.8837
# Batch-180: CrossEntropyLoss=2.2906 | MulticlassF1Score=0.8836
# Batch-195: CrossEntropyLoss=2.2816 | MulticlassF1Score=0.8836
# Batch-210: CrossEntropyLoss=2.2789 | MulticlassF1Score=0.8840
# Batch-225: CrossEntropyLoss=2.2779 | MulticlassF1Score=0.8839
# Batch-226: CrossEntropyLoss=2.2855 | MulticlassF1Score=0.8839
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2931 | MulticlassF1Score=0.8726
# Batch-30 : CrossEntropyLoss=2.2824 | MulticlassF1Score=0.8752
# Batch-45 : CrossEntropyLoss=2.2850 | MulticlassF1Score=0.8747
# Batch-60 : CrossEntropyLoss=2.2893 | MulticlassF1Score=0.8762
# Batch-63 : CrossEntropyLoss=2.2823 | MulticlassF1Score=0.8765
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2838 | Mean MulticlassF1Score = 0.8836
# Validation : Mean CrossEntropyLoss = 2.2859 | Mean MulticlassF1Score = 0.8752
# ================================================================================
#
# EPOCH-11
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2812 | MulticlassF1Score=0.8867
# Batch-30 : CrossEntropyLoss=2.2843 | MulticlassF1Score=0.8877
# Batch-45 : CrossEntropyLoss=2.2847 | MulticlassF1Score=0.8878
# Batch-60 : CrossEntropyLoss=2.2772 | MulticlassF1Score=0.8878
# Batch-75 : CrossEntropyLoss=2.2725 | MulticlassF1Score=0.8866
# Batch-90 : CrossEntropyLoss=2.2880 | MulticlassF1Score=0.8859
# Batch-105: CrossEntropyLoss=2.2888 | MulticlassF1Score=0.8863
# Batch-120: CrossEntropyLoss=2.2766 | MulticlassF1Score=0.8891
# Batch-135: CrossEntropyLoss=2.2782 | MulticlassF1Score=0.8912
# Batch-150: CrossEntropyLoss=2.2790 | MulticlassF1Score=0.8931
# Batch-165: CrossEntropyLoss=2.2734 | MulticlassF1Score=0.8950
# Batch-180: CrossEntropyLoss=2.2755 | MulticlassF1Score=0.8964
# Batch-195: CrossEntropyLoss=2.2758 | MulticlassF1Score=0.8975
# Batch-210: CrossEntropyLoss=2.2755 | MulticlassF1Score=0.8987
# Batch-225: CrossEntropyLoss=2.2754 | MulticlassF1Score=0.8996
# Batch-226: CrossEntropyLoss=2.2780 | MulticlassF1Score=0.8996
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2810 | MulticlassF1Score=0.9037
# Batch-30 : CrossEntropyLoss=2.2754 | MulticlassF1Score=0.9025
# Batch-45 : CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9034
# Batch-60 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9041
# Batch-63 : CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9044
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2791 | Mean MulticlassF1Score = 0.8907
# Validation : Mean CrossEntropyLoss = 2.2774 | Mean MulticlassF1Score = 0.9031
# ================================================================================
#
# EPOCH-12
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2841 | MulticlassF1Score=0.9097
# Batch-30 : CrossEntropyLoss=2.2764 | MulticlassF1Score=0.9117
# Batch-45 : CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9137
# Batch-60 : CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9148
# Batch-75 : CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9155
# Batch-90 : CrossEntropyLoss=2.2766 | MulticlassF1Score=0.9156
# Batch-105: CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9156
# Batch-120: CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9160
# Batch-135: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9158
# Batch-150: CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9160
# Batch-165: CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9158
# Batch-180: CrossEntropyLoss=2.2795 | MulticlassF1Score=0.9160
# Batch-195: CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9159
# Batch-210: CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9158
# Batch-225: CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9158
# Batch-226: CrossEntropyLoss=2.2812 | MulticlassF1Score=0.9158
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2788 | MulticlassF1Score=0.9027
# Batch-30 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9052
# Batch-45 : CrossEntropyLoss=2.2762 | MulticlassF1Score=0.9064
# Batch-60 : CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9057
# Batch-63 : CrossEntropyLoss=2.2784 | MulticlassF1Score=0.9055
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2740 | Mean MulticlassF1Score = 0.9152
# Validation : Mean CrossEntropyLoss = 2.2770 | Mean MulticlassF1Score = 0.9045
# ================================================================================
#
# EPOCH-13
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2727 | MulticlassF1Score=0.9161
# Batch-30 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9175
# Batch-45 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9168
# Batch-60 : CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9164
# Batch-75 : CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9177
# Batch-90 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9176
# Batch-105: CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9179
# Batch-120: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9182
# Batch-135: CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9179
# Batch-150: CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9177
# Batch-165: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9176
# Batch-180: CrossEntropyLoss=2.2808 | MulticlassF1Score=0.9175
# Batch-195: CrossEntropyLoss=2.2783 | MulticlassF1Score=0.9172
# Batch-210: CrossEntropyLoss=2.2753 | MulticlassF1Score=0.9171
# Batch-225: CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9173
# Batch-226: CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9173
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2758 | MulticlassF1Score=0.9008
# Batch-30 : CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9039
# Batch-45 : CrossEntropyLoss=2.2801 | MulticlassF1Score=0.9056
# Batch-60 : CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9058
# Batch-63 : CrossEntropyLoss=2.2785 | MulticlassF1Score=0.9054
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2734 | Mean MulticlassF1Score = 0.9173
# Validation : Mean CrossEntropyLoss = 2.2770 | Mean MulticlassF1Score = 0.9020
# ================================================================================
#
# EPOCH-14
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2768 | MulticlassF1Score=0.9205
# Batch-30 : CrossEntropyLoss=2.2758 | MulticlassF1Score=0.9183
# Batch-45 : CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9194
# Batch-60 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9203
# Batch-75 : CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9184
# Batch-90 : CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9188
# Batch-105: CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9192
# Batch-120: CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9197
# Batch-135: CrossEntropyLoss=2.2785 | MulticlassF1Score=0.9196
# Batch-150: CrossEntropyLoss=2.2776 | MulticlassF1Score=0.9190
# Batch-165: CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9185
# Batch-180: CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9185
# Batch-195: CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9188
# Batch-210: CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9186
# Batch-225: CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9188
# Batch-226: CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9189
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2819 | MulticlassF1Score=0.9017
# Batch-30 : CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9056
# Batch-45 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9068
# Batch-60 : CrossEntropyLoss=2.2849 | MulticlassF1Score=0.9066
# Batch-63 : CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9066
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2729 | Mean MulticlassF1Score = 0.9194
# Validation : Mean CrossEntropyLoss = 2.2766 | Mean MulticlassF1Score = 0.9044
# ================================================================================
#
# EPOCH-15
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9206
# Batch-30 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9229
# Batch-45 : CrossEntropyLoss=2.2824 | MulticlassF1Score=0.9202
# Batch-60 : CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9203
# Batch-75 : CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9197
# Batch-90 : CrossEntropyLoss=2.2715 | MulticlassF1Score=0.9198
# Batch-105: CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9204
# Batch-120: CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9208
# Batch-135: CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9212
# Batch-150: CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9203
# Batch-165: CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9203
# Batch-180: CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9202
# Batch-195: CrossEntropyLoss=2.2835 | MulticlassF1Score=0.9199
# Batch-210: CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9201
# Batch-225: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9202
# Batch-226: CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9203
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2785 | MulticlassF1Score=0.9108
# Batch-30 : CrossEntropyLoss=2.2820 | MulticlassF1Score=0.9056
# Batch-45 : CrossEntropyLoss=2.2834 | MulticlassF1Score=0.9055
# Batch-60 : CrossEntropyLoss=2.2758 | MulticlassF1Score=0.9057
# Batch-63 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9063
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2724 | Mean MulticlassF1Score = 0.9205
# Validation : Mean CrossEntropyLoss = 2.2767 | Mean MulticlassF1Score = 0.9071
# ================================================================================
#
# EPOCH-16
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9215
# Batch-30 : CrossEntropyLoss=2.2768 | MulticlassF1Score=0.9225
# Batch-45 : CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9231
# Batch-60 : CrossEntropyLoss=2.2766 | MulticlassF1Score=0.9234
# Batch-75 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9225
# Batch-90 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9217
# Batch-105: CrossEntropyLoss=2.2764 | MulticlassF1Score=0.9204
# Batch-120: CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9211
# Batch-135: CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9213
# Batch-150: CrossEntropyLoss=2.2722 | MulticlassF1Score=0.9213
# Batch-165: CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9215
# Batch-180: CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9212
# Batch-195: CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9214
# Batch-210: CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9214
# Batch-225: CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9213
# Batch-226: CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9213
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9111
# Batch-30 : CrossEntropyLoss=2.2776 | MulticlassF1Score=0.9073
# Batch-45 : CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9076
# Batch-60 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9075
# Batch-63 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9073
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2720 | Mean MulticlassF1Score = 0.9218
# Validation : Mean CrossEntropyLoss = 2.2763 | Mean MulticlassF1Score = 0.9083
# ================================================================================
#
# EPOCH-17
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9188
# Batch-30 : CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9196
# Batch-45 : CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9205
# Batch-60 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9206
# Batch-75 : CrossEntropyLoss=2.2798 | MulticlassF1Score=0.9208
# Batch-90 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9217
# Batch-105: CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9210
# Batch-120: CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9216
# Batch-135: CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9217
# Batch-150: CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9217
# Batch-165: CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9217
# Batch-180: CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9219
# Batch-195: CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9219
# Batch-210: CrossEntropyLoss=2.2764 | MulticlassF1Score=0.9216
# Batch-225: CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9218
# Batch-226: CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9219
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9082
# Batch-30 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9068
# Batch-45 : CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9080
# Batch-60 : CrossEntropyLoss=2.2782 | MulticlassF1Score=0.9070
# Batch-63 : CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9071
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2718 | Mean MulticlassF1Score = 0.9212
# Validation : Mean CrossEntropyLoss = 2.2765 | Mean MulticlassF1Score = 0.9075
# ================================================================================
#
# EPOCH-18
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9225
# Batch-30 : CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9243
# Batch-45 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9251
# Batch-60 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9250
# Batch-75 : CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9242
# Batch-90 : CrossEntropyLoss=2.2758 | MulticlassF1Score=0.9241
# Batch-105: CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9233
# Batch-120: CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9236
# Batch-135: CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9237
# Batch-150: CrossEntropyLoss=2.2797 | MulticlassF1Score=0.9235
# Batch-165: CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9237
# Batch-180: CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9228
# Batch-195: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9225
# Batch-210: CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9226
# Batch-225: CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9225
# Batch-226: CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9226
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2799 | MulticlassF1Score=0.9078
# Batch-30 : CrossEntropyLoss=2.2826 | MulticlassF1Score=0.9057
# Batch-45 : CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9062
# Batch-60 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9069
# Batch-63 : CrossEntropyLoss=2.2823 | MulticlassF1Score=0.9070
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2716 | Mean MulticlassF1Score = 0.9235
# Validation : Mean CrossEntropyLoss = 2.2764 | Mean MulticlassF1Score = 0.9065
# ================================================================================
#
# EPOCH-19
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9217
# Batch-30 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9237
# Batch-45 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9246
# Batch-60 : CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9249
# Batch-75 : CrossEntropyLoss=2.2736 | MulticlassF1Score=0.9244
# Batch-90 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9247
# Batch-105: CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9233
# Batch-120: CrossEntropyLoss=2.2719 | MulticlassF1Score=0.9237
# Batch-135: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9233
# Batch-150: CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9233
# Batch-165: CrossEntropyLoss=2.2771 | MulticlassF1Score=0.9235
# Batch-180: CrossEntropyLoss=2.2759 | MulticlassF1Score=0.9234
# Batch-195: CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9233
# Batch-210: CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9228
# Batch-225: CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9229
# Batch-226: CrossEntropyLoss=2.2765 | MulticlassF1Score=0.9228
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2828 | MulticlassF1Score=0.9061
# Batch-30 : CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9090
# Batch-45 : CrossEntropyLoss=2.2829 | MulticlassF1Score=0.9058
# Batch-60 : CrossEntropyLoss=2.2800 | MulticlassF1Score=0.9060
# Batch-63 : CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9064
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2715 | Mean MulticlassF1Score = 0.9234
# Validation : Mean CrossEntropyLoss = 2.2765 | Mean MulticlassF1Score = 0.9057
# ================================================================================
#
# EPOCH-20
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9210
# Batch-30 : CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9216
# Batch-45 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9234
# Batch-60 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9232
# Batch-75 : CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9232
# Batch-90 : CrossEntropyLoss=2.2772 | MulticlassF1Score=0.9228
# Batch-105: CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9230
# Batch-120: CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9237
# Batch-135: CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9237
# Batch-150: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9235
# Batch-165: CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9237
# Batch-180: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9236
# Batch-195: CrossEntropyLoss=2.2756 | MulticlassF1Score=0.9235
# Batch-210: CrossEntropyLoss=2.2769 | MulticlassF1Score=0.9230
# Batch-225: CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9231
# Batch-226: CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9230
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2766 | MulticlassF1Score=0.9121
# Batch-30 : CrossEntropyLoss=2.2820 | MulticlassF1Score=0.9098
# Batch-45 : CrossEntropyLoss=2.2810 | MulticlassF1Score=0.9071
# Batch-60 : CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9071
# Batch-63 : CrossEntropyLoss=2.2762 | MulticlassF1Score=0.9069
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2714 | Mean MulticlassF1Score = 0.9229
# Validation : Mean CrossEntropyLoss = 2.2764 | Mean MulticlassF1Score = 0.9100
# ================================================================================
#
# EPOCH-21
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9210
# Batch-30 : CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9212
# Batch-45 : CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9213
# Batch-60 : CrossEntropyLoss=2.2765 | MulticlassF1Score=0.9219
# Batch-75 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9214
# Batch-90 : CrossEntropyLoss=2.2761 | MulticlassF1Score=0.9216
# Batch-105: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9232
# Batch-120: CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9230
# Batch-135: CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9238
# Batch-150: CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9233
# Batch-165: CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9229
# Batch-180: CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9229
# Batch-195: CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9235
# Batch-210: CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9237
# Batch-225: CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9237
# Batch-226: CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9237
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2754 | MulticlassF1Score=0.9090
# Batch-30 : CrossEntropyLoss=2.2772 | MulticlassF1Score=0.9088
# Batch-45 : CrossEntropyLoss=2.2753 | MulticlassF1Score=0.9078
# Batch-60 : CrossEntropyLoss=2.2767 | MulticlassF1Score=0.9071
# Batch-63 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9075
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2712 | Mean MulticlassF1Score = 0.9222
# Validation : Mean CrossEntropyLoss = 2.2762 | Mean MulticlassF1Score = 0.9096
# ================================================================================
#
# EPOCH-22
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9234
# Batch-30 : CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9207
# Batch-45 : CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9232
# Batch-60 : CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9243
# Batch-75 : CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9255
# Batch-90 : CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9255
# Batch-105: CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9256
# Batch-120: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9256
# Batch-135: CrossEntropyLoss=2.2769 | MulticlassF1Score=0.9251
# Batch-150: CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9256
# Batch-165: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9252
# Batch-180: CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9252
# Batch-195: CrossEntropyLoss=2.2701 | MulticlassF1Score=0.9248
# Batch-210: CrossEntropyLoss=2.2748 | MulticlassF1Score=0.9241
# Batch-225: CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9246
# Batch-226: CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9246
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2753 | MulticlassF1Score=0.9060
# Batch-30 : CrossEntropyLoss=2.2812 | MulticlassF1Score=0.9066
# Batch-45 : CrossEntropyLoss=2.2799 | MulticlassF1Score=0.9054
# Batch-60 : CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9068
# Batch-63 : CrossEntropyLoss=2.2839 | MulticlassF1Score=0.9067
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2709 | Mean MulticlassF1Score = 0.9245
# Validation : Mean CrossEntropyLoss = 2.2764 | Mean MulticlassF1Score = 0.9068
# ================================================================================
#
# EPOCH-23
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9277
# Batch-30 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9245
# Batch-45 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9250
# Batch-60 : CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9257
# Batch-75 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9258
# Batch-90 : CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9257
# Batch-105: CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9258
# Batch-120: CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9257
# Batch-135: CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9254
# Batch-150: CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9252
# Batch-165: CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9253
# Batch-180: CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9251
# Batch-195: CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9251
# Batch-210: CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9254
# Batch-225: CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9251
# Batch-226: CrossEntropyLoss=2.2812 | MulticlassF1Score=0.9250
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2824 | MulticlassF1Score=0.9085
# Batch-30 : CrossEntropyLoss=2.2778 | MulticlassF1Score=0.9069
# Batch-45 : CrossEntropyLoss=2.2744 | MulticlassF1Score=0.9067
# Batch-60 : CrossEntropyLoss=2.2766 | MulticlassF1Score=0.9075
# Batch-63 : CrossEntropyLoss=2.2889 | MulticlassF1Score=0.9071
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2708 | Mean MulticlassF1Score = 0.9256
# Validation : Mean CrossEntropyLoss = 2.2764 | Mean MulticlassF1Score = 0.9073
# ================================================================================
#
# EPOCH-24
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9249
# Batch-30 : CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9251
# Batch-45 : CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9265
# Batch-60 : CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9260
# Batch-75 : CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9262
# Batch-90 : CrossEntropyLoss=2.2738 | MulticlassF1Score=0.9265
# Batch-105: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9272
# Batch-120: CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9270
# Batch-135: CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9274
# Batch-150: CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9278
# Batch-165: CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9280
# Batch-180: CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9281
# Batch-195: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9282
# Batch-210: CrossEntropyLoss=2.2755 | MulticlassF1Score=0.9282
# Batch-225: CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9280
# Batch-226: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9280
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2804 | MulticlassF1Score=0.9094
# Batch-30 : CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9108
# Batch-45 : CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9102
# Batch-60 : CrossEntropyLoss=2.2762 | MulticlassF1Score=0.9112
# Batch-63 : CrossEntropyLoss=2.2788 | MulticlassF1Score=0.9106
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2699 | Mean MulticlassF1Score = 0.9269
# Validation : Mean CrossEntropyLoss = 2.2752 | Mean MulticlassF1Score = 0.9102
# ================================================================================
#
# EPOCH-25
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9310
# Batch-30 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9272
# Batch-45 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9272
# Batch-60 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9284
# Batch-75 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9303
# Batch-90 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9303
# Batch-105: CrossEntropyLoss=2.2759 | MulticlassF1Score=0.9299
# Batch-120: CrossEntropyLoss=2.2735 | MulticlassF1Score=0.9295
# Batch-135: CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9296
# Batch-150: CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9300
# Batch-165: CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9299
# Batch-180: CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9301
# Batch-195: CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9303
# Batch-210: CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9301
# Batch-225: CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9301
# Batch-226: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9302
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9130
# Batch-30 : CrossEntropyLoss=2.2864 | MulticlassF1Score=0.9109
# Batch-45 : CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9094
# Batch-60 : CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9099
# Batch-63 : CrossEntropyLoss=2.2765 | MulticlassF1Score=0.9099
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2692 | Mean MulticlassF1Score = 0.9294
# Validation : Mean CrossEntropyLoss = 2.2754 | Mean MulticlassF1Score = 0.9119
# ================================================================================
#
# EPOCH-26
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9308
# Batch-30 : CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9313
# Batch-45 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9309
# Batch-60 : CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9308
# Batch-75 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9311
# Batch-90 : CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9315
# Batch-105: CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9306
# Batch-120: CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9303
# Batch-135: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9311
# Batch-150: CrossEntropyLoss=2.2765 | MulticlassF1Score=0.9310
# Batch-165: CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9310
# Batch-180: CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9310
# Batch-195: CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9311
# Batch-210: CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9314
# Batch-225: CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9313
# Batch-226: CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9313
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2788 | MulticlassF1Score=0.9131
# Batch-30 : CrossEntropyLoss=2.2767 | MulticlassF1Score=0.9130
# Batch-45 : CrossEntropyLoss=2.2769 | MulticlassF1Score=0.9119
# Batch-60 : CrossEntropyLoss=2.2781 | MulticlassF1Score=0.9117
# Batch-63 : CrossEntropyLoss=2.2795 | MulticlassF1Score=0.9112
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2688 | Mean MulticlassF1Score = 0.9311
# Validation : Mean CrossEntropyLoss = 2.2751 | Mean MulticlassF1Score = 0.9121
# ================================================================================
#
# EPOCH-27
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9324
# Batch-30 : CrossEntropyLoss=2.2764 | MulticlassF1Score=0.9292
# Batch-45 : CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9293
# Batch-60 : CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9305
# Batch-75 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9313
# Batch-90 : CrossEntropyLoss=2.2734 | MulticlassF1Score=0.9310
# Batch-105: CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9318
# Batch-120: CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9324
# Batch-135: CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9324
# Batch-150: CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9323
# Batch-165: CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9323
# Batch-180: CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9323
# Batch-195: CrossEntropyLoss=2.2750 | MulticlassF1Score=0.9322
# Batch-210: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9320
# Batch-225: CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9320
# Batch-226: CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9320
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9177
# Batch-30 : CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9135
# Batch-45 : CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9125
# Batch-60 : CrossEntropyLoss=2.2729 | MulticlassF1Score=0.9115
# Batch-63 : CrossEntropyLoss=2.2797 | MulticlassF1Score=0.9111
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2686 | Mean MulticlassF1Score = 0.9317
# Validation : Mean CrossEntropyLoss = 2.2750 | Mean MulticlassF1Score = 0.9142
# ================================================================================
#
# EPOCH-28
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9341
# Batch-30 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9343
# Batch-45 : CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9335
# Batch-60 : CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9335
# Batch-75 : CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9341
# Batch-90 : CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9348
# Batch-105: CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9351
# Batch-120: CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9346
# Batch-135: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9345
# Batch-150: CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9345
# Batch-165: CrossEntropyLoss=2.2746 | MulticlassF1Score=0.9340
# Batch-180: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9345
# Batch-195: CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9357
# Batch-210: CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9366
# Batch-225: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9375
# Batch-226: CrossEntropyLoss=2.2627 | MulticlassF1Score=0.9375
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9297
# Batch-30 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9297
# Batch-45 : CrossEntropyLoss=2.2795 | MulticlassF1Score=0.9301
# Batch-60 : CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9301
# Batch-63 : CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9302
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2669 | Mean MulticlassF1Score = 0.9348
# Validation : Mean CrossEntropyLoss = 2.2694 | Mean MulticlassF1Score = 0.9305
# ================================================================================
#
# EPOCH-29
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9512
# Batch-30 : CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9526
# Batch-45 : CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9530
# Batch-60 : CrossEntropyLoss=2.2611 | MulticlassF1Score=0.9534
# Batch-75 : CrossEntropyLoss=2.2612 | MulticlassF1Score=0.9540
# Batch-90 : CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9538
# Batch-105: CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9537
# Batch-120: CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9534
# Batch-135: CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9533
# Batch-150: CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9533
# Batch-165: CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9534
# Batch-180: CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9532
# ...
# Batch-45 : CrossEntropyLoss=2.2753 | MulticlassF1Score=0.9348
# Batch-60 : CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9347
# Batch-63 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9347
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2598 | Mean MulticlassF1Score = 0.9600
# Validation : Mean CrossEntropyLoss = 2.2677 | Mean MulticlassF1Score = 0.9358
# Patience = 1/50❗
# ================================================================================
#
# EPOCH-42
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9636
# Batch-30 : CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9613
# Batch-45 : CrossEntropyLoss=2.2603 | MulticlassF1Score=0.9609
# Batch-60 : CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9612
# Batch-75 : CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9606
# Batch-90 : CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9603
# Batch-105: CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9604
# Batch-120: CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9607
# Batch-135: CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9605
# Batch-150: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9605
# Batch-165: CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9603
# Batch-180: CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9604
# Batch-195: CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9605
# Batch-210: CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9603
# Batch-225: CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9605
# Batch-226: CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9605
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9355
# Batch-30 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9360
# Batch-45 : CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9340
# Batch-60 : CrossEntropyLoss=2.2682 | MulticlassF1Score=0.9353
# Batch-63 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9352
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2597 | Mean MulticlassF1Score = 0.9611
# Validation : Mean CrossEntropyLoss = 2.2676 | Mean MulticlassF1Score = 0.9361
# ================================================================================
#
# EPOCH-43
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9624
# Batch-30 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9612
# Batch-45 : CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9609
# Batch-60 : CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9612
# Batch-75 : CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9614
# Batch-90 : CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9614
# Batch-105: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9615
# Batch-120: CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9613
# Batch-135: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9612
# Batch-150: CrossEntropyLoss=2.2589 | MulticlassF1Score=0.9608
# Batch-165: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9607
# Batch-180: CrossEntropyLoss=2.2622 | MulticlassF1Score=0.9608
# Batch-195: CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9605
# Batch-210: CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9606
# Batch-225: CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9606
# Batch-226: CrossEntropyLoss=2.2567 | MulticlassF1Score=0.9606
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9368
# Batch-30 : CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9372
# Batch-45 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9352
# Batch-60 : CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9349
# Batch-63 : CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9352
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2597 | Mean MulticlassF1Score = 0.9610
# Validation : Mean CrossEntropyLoss = 2.2675 | Mean MulticlassF1Score = 0.9357
# ================================================================================
#
# EPOCH-44
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9612
# Batch-30 : CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9612
# Batch-45 : CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9614
# Batch-60 : CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9610
# Batch-75 : CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9610
# Batch-90 : CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9607
# Batch-105: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9612
# Batch-120: CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9609
# Batch-135: CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9610
# Batch-150: CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9609
# Batch-165: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9612
# Batch-180: CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9609
# Batch-195: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9610
# Batch-210: CrossEntropyLoss=2.2622 | MulticlassF1Score=0.9610
# Batch-225: CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9609
# Batch-226: CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9608
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2708 | MulticlassF1Score=0.9300
# Batch-30 : CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9338
# Batch-45 : CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9347
# Batch-60 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9345
# Batch-63 : CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9347
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2596 | Mean MulticlassF1Score = 0.9611
# Validation : Mean CrossEntropyLoss = 2.2677 | Mean MulticlassF1Score = 0.9330
# ================================================================================
#
# EPOCH-45
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9599
# Batch-30 : CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9607
# Batch-45 : CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9603
# Batch-60 : CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9611
# Batch-75 : CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9614
# Batch-90 : CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9609
# Batch-105: CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9609
# Batch-120: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9617
# Batch-135: CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9616
# Batch-150: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9615
# Batch-165: CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9616
# Batch-180: CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9615
# Batch-195: CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9615
# Batch-210: CrossEntropyLoss=2.2622 | MulticlassF1Score=0.9616
# Batch-225: CrossEntropyLoss=2.2574 | MulticlassF1Score=0.9615
# Batch-226: CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9615
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9352
# Batch-30 : CrossEntropyLoss=2.2685 | MulticlassF1Score=0.9351
# Batch-45 : CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9356
# Batch-60 : CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9346
# Batch-63 : CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9352
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2594 | Mean MulticlassF1Score = 0.9611
# Validation : Mean CrossEntropyLoss = 2.2676 | Mean MulticlassF1Score = 0.9351
# ================================================================================
#
# EPOCH-46
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2603 | MulticlassF1Score=0.9577
# Batch-30 : CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9607
# Batch-45 : CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9611
# Batch-60 : CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9613
# Batch-75 : CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9619
# Batch-90 : CrossEntropyLoss=2.2548 | MulticlassF1Score=0.9616
# Batch-105: CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9617
# Batch-120: CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9612
# Batch-135: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9616
# Batch-150: CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9618
# Batch-165: CrossEntropyLoss=2.2611 | MulticlassF1Score=0.9618
# Batch-180: CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9619
# Batch-195: CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9620
# Batch-210: CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9619
# Batch-225: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9619
# Batch-226: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9619
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9342
# Batch-30 : CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9359
# Batch-45 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9363
# Batch-60 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9356
# Batch-63 : CrossEntropyLoss=2.2716 | MulticlassF1Score=0.9353
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2592 | Mean MulticlassF1Score = 0.9612
# Validation : Mean CrossEntropyLoss = 2.2675 | Mean MulticlassF1Score = 0.9353
# ================================================================================
#
# EPOCH-47
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9616
# Batch-30 : CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9604
# Batch-45 : CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9615
# Batch-60 : CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9615
# Batch-75 : CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9619
# Batch-90 : CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9622
# Batch-105: CrossEntropyLoss=2.2611 | MulticlassF1Score=0.9616
# Batch-120: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9618
# Batch-135: CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9616
# Batch-150: CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9615
# Batch-165: CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9619
# Batch-180: CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9618
# Batch-195: CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9620
# Batch-210: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9620
# Batch-225: CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9621
# Batch-226: CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9621
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9397
# Batch-30 : CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9381
# Batch-45 : CrossEntropyLoss=2.2714 | MulticlassF1Score=0.9381
# Batch-60 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9365
# Batch-63 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9359
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2592 | Mean MulticlassF1Score = 0.9619
# Validation : Mean CrossEntropyLoss = 2.2673 | Mean MulticlassF1Score = 0.9389
# ================================================================================
#
# EPOCH-48
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2570 | MulticlassF1Score=0.9623
# Batch-30 : CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9630
# Batch-45 : CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9631
# Batch-60 : CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9626
# Batch-75 : CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9627
# Batch-90 : CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9625
# Batch-105: CrossEntropyLoss=2.2622 | MulticlassF1Score=0.9626
# Batch-120: CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9630
# Batch-135: CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9628
# Batch-150: CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9631
# Batch-165: CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9632
# Batch-180: CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9631
# Batch-195: CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9629
# Batch-210: CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9627
# Batch-225: CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9627
# Batch-226: CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9627
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9377
# Batch-30 : CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9369
# Batch-45 : CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9355
# Batch-60 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9352
# Batch-63 : CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9355
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2590 | Mean MulticlassF1Score = 0.9627
# Validation : Mean CrossEntropyLoss = 2.2674 | Mean MulticlassF1Score = 0.9364
# ================================================================================
#
# EPOCH-49
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9662
# Batch-30 : CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9653
# Batch-45 : CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9651
# Batch-60 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9652
# Batch-75 : CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9644
# Batch-90 : CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9644
# Batch-105: CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9637
# Batch-120: CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9637
# Batch-135: CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9634
# Batch-150: CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9635
# Batch-165: CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9633
# Batch-180: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9632
# Batch-195: CrossEntropyLoss=2.2535 | MulticlassF1Score=0.9632
# Batch-210: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9631
# Batch-225: CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9632
# Batch-226: CrossEntropyLoss=2.2622 | MulticlassF1Score=0.9632
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9363
# Batch-30 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9360
# Batch-45 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9351
# Batch-60 : CrossEntropyLoss=2.2656 | MulticlassF1Score=0.9357
# Batch-63 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9356
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2588 | Mean MulticlassF1Score = 0.9641
# Validation : Mean CrossEntropyLoss = 2.2674 | Mean MulticlassF1Score = 0.9360
# ================================================================================
#
# EPOCH-50
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9637
# Batch-30 : CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9632
# Batch-45 : CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9637
# Batch-60 : CrossEntropyLoss=2.2529 | MulticlassF1Score=0.9647
# Batch-75 : CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9641
# Batch-90 : CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9642
# Batch-105: CrossEntropyLoss=2.2576 | MulticlassF1Score=0.9642
# Batch-120: CrossEntropyLoss=2.2563 | MulticlassF1Score=0.9640
# Batch-135: CrossEntropyLoss=2.2556 | MulticlassF1Score=0.9643
# Batch-150: CrossEntropyLoss=2.2549 | MulticlassF1Score=0.9644
# Batch-165: CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9642
# Batch-180: CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9643
# Batch-195: CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9641
# Batch-210: CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9641
# Batch-225: CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9639
# Batch-226: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9639
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9349
# Batch-30 : CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9365
# Batch-45 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9368
# Batch-60 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9368
# Batch-63 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9366
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2586 | Mean MulticlassF1Score = 0.9639
# Validation : Mean CrossEntropyLoss = 2.2672 | Mean MulticlassF1Score = 0.9360
# ================================================================================
#
# TRAINING SUMMARY
# Best CrossEntropyLoss training    : 2.2586
# Best CrossEntropyLoss training    : 2.2672
# Best MulticlassF1Score validation : 0.9639
# Best MulticlassF1Score validation : 0.9360
# Training duration                 : 1.9668 minutes.
# Training date                     : 2022-10-24 19:01:16.998791+08:00

# %% [markdown]
# ## End Training

# %% [markdown]
# # Evaluation

# %%
def evaluation(dataloader, model, criterion, metric):
    model.eval()
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)
            pred = rearrange(prob.argmax(dim=1).reshape(feature.shape[0], len(dataloader.dataset)), "s n -> n s")

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob.argmax(dim=1), actual_label.to(hyperparams.device))
            metric_score = metric.compute()

    return loss, metric_score, pred

train_dataloader = DataLoader(train_dataset, batch_size=len(train_dataset))
val_dataloader = DataLoader(val_dataset, batch_size=len(val_dataset))
test_dataloader = DataLoader(test_dataset, batch_size=len(test_dataset))

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
train_loss, train_f1_score, train_pred_label = evaluation(train_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_loss, val_f1_score, val_pred_label = evaluation(val_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
test_loss, test_f1_score, test_pred_label = evaluation(test_dataloader, model, criterion, metric)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9642, device='cuda:0'),
#  tensor(0.9366, device='cuda:0'),
#  tensor(0.9317, device='cuda:0'))

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9642, device='cuda:0'),
#  tensor(0.9366, device='cuda:0'),
#  tensor(0.9317, device='cuda:0'))

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns

def viz_evaluation(pred_label, actual_label, title):
    plt.figure(figsize=(15, 7), dpi=200)
    sns.heatmap(pred_label.detach().cpu() == actual_label, cbar=True, cmap="binary_r")
    plt.xlabel("Sentence Length")
    plt.ylabel("Sentence")
    plt.title(title)
    plt.savefig(f"{root_path}/heatmap_{title.lower()}.jpg", dpi=200)
    plt.show()

train_actual_label = train_dataloader.dataset.tensors[1]
val_actual_label = val_dataloader.dataset.tensors[1]
test_actual_label = test_dataloader.dataset.tensors[1]

viz_evaluation(train_pred_label, train_actual_label, f"Training (F1-Score: {(train_f1_score):.4f})")
viz_evaluation(val_pred_label, val_actual_label, f"Validation (F1-Score: {(val_f1_score):.4f})")
viz_evaluation(test_pred_label, test_actual_label, f"Test (F1-Score: {(test_f1_score):.4f})")

# %% [markdown]
# ## Confusion Matrix

# %%
def confusion_matrix(pred_class, actual_class, title, normalize=None):
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize=normalize)
    plt.figure(figsize=(20, 10), dpi=200)
    sns.heatmap(conf_mat(pred_class.detach().cpu(), actual_class), annot=True, fmt=".2g", xticklabels=list(label_to_idx.keys()), yticklabels=list(label_to_idx.keys()));
    plt.yticks(rotation=0)
    plt.title(title)
    plt.xlabel("Actual Class")
    plt.ylabel("Predict Class")
    plt.savefig(f"{root_path}/conf_matrix_{title.lower()}.jpg", dpi=200)

confusion_matrix(train_pred_label, train_actual_label, "Training", "pred")
confusion_matrix(val_pred_label,val_actual_label, "Validation", "pred")
confusion_matrix(test_pred_label, test_actual_label, "Test", "pred")
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 144 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)

# %% [markdown]
# ## Prediction Table

# %%
def number_wrong_pred_each_class(pred_class, actual_class):
    classes, count_class = actual_class.flatten().unique(return_counts=True)
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize="none")
    correct_pred_count_class = conf_mat(pred_class.detach().cpu(), actual_class).diag()
    
    correct_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (correct_pred_count_class))}
    wrong_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (count_class - correct_pred_count_class))}
    
    return correct_pred, wrong_pred

correct_pred, wrong_pred = number_wrong_pred_each_class(train_pred_label, train_actual_label)
print(f"| {'Number class'.ljust(14)} | {'Correct prediction'.ljust(12)} | {'Wrong prediction'.ljust(12)} |")
for (label_correct_pred, count_correct_pred), (label_wrong_pred, count_wrong_pred) in zip(correct_pred.items(), wrong_pred.items()):
    print(f"| {str(label_correct_pred).ljust(6)}: {str(count_correct_pred + count_wrong_pred).ljust(7)}| {label_correct_pred.ljust(6)}: {str(count_correct_pred).ljust(10)} | {label_wrong_pred.ljust(6)}: {str(count_wrong_pred).ljust(8)} |")
# Out:
# | Number class   | Correct prediction | Wrong prediction |
# | CC    : 5391   | CC    : 5253       | CC    : 138      |
# | CD    : 12882  | CD    : 12740      | CD    : 142      |
# | DT    : 273    | DT    : 0          | DT    : 273      |
# | FW    : 1690   | FW    : 1405       | FW    : 285      |
# | IN    : 15403  | IN    : 15280      | IN    : 123      |
# | JJ    : 7018   | JJ    : 6552       | JJ    : 466      |
# | MD    : 3810   | MD    : 3761       | MD    : 49       |
# | NEG   : 1082   | NEG   : 0          | NEG   : 1082     |
# | NN    : 44728  | NN    : 43995      | NN    : 733      |
# | NND   : 1019   | NND   : 388        | NND   : 631      |
# | NNP   : 24885  | NNP   : 24217      | NNP   : 668      |
# | OD    : 534    | OD    : 392        | OD    : 142      |
# | PR    : 3842   | PR    : 3788       | PR    : 54       |
# | PRP   : 5405   | PRP   : 5278       | PRP   : 127      |
# | RB    : 3553   | RB    : 3287       | RB    : 266      |
# | RP    : 144    | RP    : 0          | RP    : 144      |
# | SC    : 9487   | SC    : 9201       | SC    : 286      |
# | SYM   : 1550   | SYM   : 1469       | SYM   : 81       |
# | UH    : 26     | UH    : 0          | UH    : 26       |
# | VB    : 22846  | VB    : 22443      | VB    : 403      |
# | WH    : 188    | WH    : 0          | WH    : 188      |
# | X     : 279    | X     : 0          | X     : 279      |
# | Z     : 18958  | Z     : 18927      | Z     : 31       |
# | <PAD> : 407211 | <PAD> : 407211     | <PAD> : 0        |

# %%
train_actual_label[308], train_pred_label[308]
# Out:
# (tensor([ 8, 19, 22, 10, 22, 19, 10,  6, 19,  4,  1,  8, 16, 19,  8, 19,  0,  8,
#           5, 16, 19, 19,  8,  8, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23]),
#  tensor([ 8, 19, 22, 10, 22, 19, 10,  6, 19,  4,  1,  8, 16, 19,  8,  5,  0,  8,
#           5, 16, 19, 13,  8,  8, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23], device='cuda:0'))

# %%
train_actual_label[308].detach().cpu() == train_pred_label[308].detach().cpu()
# Out:
# tensor([ True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True, False,  True,  True,  True,  True,
#          True, False,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True])

# %% [markdown]
# ## OOV prediction is correct

# %%
def oov_flag_token(sentences, max_seq_len=hyperparams.max_seq_len):
    sent_copy = deepcopy(sentences)
    sent = []
    oov_flag = []
    
    for sentence in tqdm(sent_copy):
        for token in sentence:
            sent.append(token[2])
        
        for _ in range(max_seq_len- len(sentence)):
            sent.append(False)
        
        oov_flag.append(sent)
        sent = []
        
    return np.array(oov_flag)

train_oov_flag = oov_flag_token(train_sentences, max_seq_len=hyperparams.max_seq_len)
val_oov_flag = oov_flag_token(val_sentences, max_seq_len=hyperparams.max_seq_len)
test_oov_flag = oov_flag_token(test_sentences, max_seq_len=hyperparams.max_seq_len)

def pencentage_oov_pred_correct(pred_oov_flag, oov_flag_tensor):
    oov_correct_counter = 0
    oov_wrong_counter = 0

    for pred, oov_label in tqdm(zip(pred_oov_flag, oov_flag_tensor)):
        if pred == True and oov_label == True:
            oov_correct_counter += 1
        elif pred == False and oov_label == True:
            oov_wrong_counter += 1
        else:
            continue
            
    return oov_correct_counter, oov_wrong_counter

train_pred_oov_flag = (train_actual_label == train_pred_label.detach().cpu()).flatten()
val_pred_oov_flag = (val_actual_label == val_pred_label.detach().cpu()).flatten()
test_pred_oov_flag = (test_actual_label == test_pred_label.detach().cpu()).flatten()
train_oov_flag_tensor = torch.tensor(train_oov_flag).flatten()
val_oov_flag_tensor = torch.tensor(val_oov_flag).flatten()
test_oov_flag_tensor = torch.tensor(test_oov_flag).flatten()

train_oov_correct_counter, train_oov_wrong_counter = pencentage_oov_pred_correct(train_pred_oov_flag, train_oov_flag_tensor)
val_oov_correct_counter, val_oov_wrong_counter = pencentage_oov_pred_correct(val_pred_oov_flag, val_oov_flag_tensor)
test_oov_correct_counter, test_oov_wrong_counter = pencentage_oov_pred_correct(test_pred_oov_flag, test_oov_flag_tensor)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
def print_percentage_pred_oov(title, oov_correct_counter, oov_wrong_counter):
    print(f"{title}")
    print(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}")
    print(f"Correct prediction          : {oov_correct_counter}")
    print(f"Wrong prediction            : {oov_wrong_counter}")
    print(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n")
    
    with open(f"{root_path}/oov_summary.txt", "a") as f:
        f.write(f"{title}\n")
        f.write(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}\n")
        f.write(f"Correct prediction          : {oov_correct_counter}\n")
        f.write(f"Wrong prediction            : {oov_wrong_counter}\n")
        f.write(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n\n")

# %%
print_percentage_pred_oov("Training", train_oov_correct_counter, train_oov_wrong_counter)
print_percentage_pred_oov("Validation", val_oov_correct_counter, val_oov_wrong_counter)
print_percentage_pred_oov("Test", test_oov_correct_counter, test_oov_wrong_counter)
# Out:
# Training
# Number OOV token            : 11808
# Correct prediction          : 10366
# Wrong prediction            : 1442
# Percentage correct oov pred : 87.78794037940379
#
# Validation
# Number OOV token            : 3395
# Correct prediction          : 2455
# Wrong prediction            : 940
# Percentage correct oov pred : 72.31222385861561
#
# Test
# Number OOV token            : 1359
# Correct prediction          : 958
# Wrong prediction            : 401
# Percentage correct oov pred : 70.49300956585725

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(train_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(val_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(test_oov_flag, cmap=plt.cm.binary_r);
