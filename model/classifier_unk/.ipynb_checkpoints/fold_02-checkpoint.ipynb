# %% [markdown]
# # Import modules

# %%
import csv
import os
import pickle
import pytz
import torch
import timeit
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from copy import deepcopy
from datetime import datetime
from einops import rearrange
from itertools import chain
from time import time
from torch import nn, optim
from torchmetrics.classification import MulticlassAccuracy, MulticlassF1Score, MulticlassConfusionMatrix
from torch.optim import lr_scheduler
from tqdm.notebook import tqdm
from torch.utils.data import TensorDataset, DataLoader
from polyglot.mapping import Embedding, CaseExpander, DigitExpander

# %% [markdown]
# # Hyperparameters

# %%
class Hyperparams:
     def __init__(
        self,
        fold=2,
        max_seq_len=82,
        input_size=64,
        batch_size=32,
        num_hidden_layer=1,
        hidden_size=128,
        dropout=0,
        bias=True,
        output_size=24,
        shuffle=True,
        lr=0.005,
        batch_first=False,
        bidirectional=True,
        init_wb_with_kaiming_normal=True,
        n_epoch=50,
        patience=50,
        device="cuda" if torch.cuda.is_available() else "cpu"
    ):
        self.fold = fold
        self.input_size = input_size
        self.max_seq_len = max_seq_len
        self.batch_size = batch_size
        self.num_hidden_layer = num_hidden_layer
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.output_size = output_size
        self.shuffle = shuffle
        self.lr = lr
        self.batch_first = batch_first
        self.bidirectional = bidirectional
        self.init_wb_with_kaiming_normal = init_wb_with_kaiming_normal
        self.n_epoch = n_epoch
        self.patience = patience
        self.device = device

hyperparams = Hyperparams()

# %% [markdown]
# # Dataset

# %%
id_pos_tag = pd.read_csv("../../datasets/raw/Indonesian_Manually_Tagged_Corpus.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False) 
train = pd.read_csv(f"../../datasets/raw/cv/train/train.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
val = pd.read_csv(f"../../datasets/raw/cv/val/val.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)
test = pd.read_csv(f"../../datasets/raw/cv/test/test.0{hyperparams.fold}.tsv", sep="\t", header=None, names=["token", "tag"], quoting=csv.QUOTE_NONE, skip_blank_lines=False)

# %% [markdown]
# # Pre-trained Word Embedding

# %%
embeddings = Embedding.load("../../word_embeddings/polyglot/idn_embeddings.tar.bz2")
embeddings.apply_expansion(DigitExpander)
embeddings.apply_expansion(CaseExpander)

oov_embeddings = pickle.load(open(f"../../logs/comick/79_contexts/10-11-2022_19-39-04/oov_embedding_dict.pkl", "rb"))
oov_embeddings = {key: embeddings["<UNK>"] for key, _ in oov_embeddings.items()}

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Add OOV Flag

# %%
def add_oov_flag(tokens, embeddings):
    oov_flags = []
    
    for token in tqdm(tokens):
        try:
            if token not in embeddings:
                oov_flags.append(True)
            else:
                oov_flags.append(False)
        except:
            oov_flags.append(False)
        
    return pd.DataFrame(oov_flags, columns=["is_oov"])

id_pos_tag_oov_flags = add_oov_flag(id_pos_tag["token"].values, embeddings)
train_oov_flags = add_oov_flag(train["token"].values, embeddings)
val_oov_flags = add_oov_flag(val["token"].values, embeddings)
test_oov_flags = add_oov_flag(test["token"].values, embeddings)
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/192008 [00:00<?, ?it/s]
#   0%|          | 0/21405 [00:00<?, ?it/s]
#   0%|          | 0/53239 [00:00<?, ?it/s]

# %% [markdown]
# ## Concate OOV Flag

# %%
id_pos_tag_df = pd.concat([id_pos_tag, id_pos_tag_oov_flags], axis=1)
train_df = pd.concat([train, train_oov_flags], axis=1)
val_df = pd.concat([val, val_oov_flags], axis=1)
test_df = pd.concat([test, test_oov_flags], axis=1)

# %% [markdown]
# ## Lowercase OOV Token

# %%
id_pos_tag_df['token'] = np.where(id_pos_tag_df['is_oov'] == True, id_pos_tag_df['token'].str.lower(), id_pos_tag_df['token'])
train_df['token'] = np.where(train_df['is_oov'] == True, train_df['token'].str.lower(), train_df['token'])
val_df['token'] = np.where(val_df['is_oov'] == True, val_df['token'].str.lower(), val_df['token'])
test_df['token'] = np.where(test_df['is_oov'] == True, test_df['token'].str.lower(), test_df['token'])

# %% [markdown]
# ## Embedding Dict, Index to Token and Token to Index

# %%
tokens = list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None))

def embedding_dict(tokens, embeddings, oov_embeddings):
    embedding = {}
    
    for token in tokens:
        if token[0] is not np.nan:
            if token[2] == False or token[0] in embeddings:
                embedding[token[0]] = embeddings[token[0]]
            else:
                embedding[token[0]] = oov_embeddings[token[0].lower()]

    return embedding

embedding_dict = embedding_dict(tokens, embeddings, oov_embeddings)
embedding_dict["<PAD>"] = embeddings["<PAD>"]
word_embeddings = nn.Embedding.from_pretrained(torch.FloatTensor(np.array(list(embedding_dict.values()))), padding_idx=list(embedding_dict.keys()).index("<PAD>"), freeze=True)

idx_to_token = {idx: token for idx, token in enumerate(list(embedding_dict.keys()))}
token_to_idx = {token: idx for idx, token in enumerate(list(embedding_dict.keys()))}

# %% [markdown]
# ## Token to Sentence

# %%
def make_sentence(tokens, max_length_sentence=hyperparams.max_seq_len):
    sentence = []
    sentences = []

    for token in tqdm(tokens):
        if token[0] is not np.nan:
            sentence.append(token)
        else:
            sentences.append(sentence[:max_length_sentence])
            sentence = []

    return sentences

all_sentence = make_sentence(list(id_pos_tag_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
train_sentences = make_sentence(list(train_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
val_sentences = make_sentence(list(test_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
test_sentences = make_sentence(list(val_df[["token", "tag", "is_oov"]].itertuples(index=False, name=None)))
# Out:
#   0%|          | 0/266652 [00:00<?, ?it/s]
#   0%|          | 0/192008 [00:00<?, ?it/s]
#   0%|          | 0/53239 [00:00<?, ?it/s]
#   0%|          | 0/21405 [00:00<?, ?it/s]

# %% [markdown]
# ## Word Token, Padding, and Word token to Index

# %%
def tokenize_docs(docs, idx_token):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token[idx_token])
        sentences.append(new_sentence)
        new_sentence = []

    return sentences

def padding(docs, max_seq_len=hyperparams.max_seq_len, mode="post", val_pad="<PAD>"):
    docs = deepcopy(docs)
    doc_with_pad = []
    docs_with_pad = []

    for doc in tqdm(docs):
        if mode == "pre":
            for _ in range(max_seq_len - len(doc)):
                doc.insert(0, val_pad)
        elif mode == "post":
            for _ in range(max_seq_len - len(doc)):
                doc.append(val_pad)
        else:
            return f"Mode {mode} is not available, use instead 'pre' or 'post'."
        
        docs_with_pad.append(doc)
        
    return np.array(docs_with_pad)

def sent_to_idx(docs, token_to_idx):
    new_sentence = []
    sentences = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            new_sentence.append(token_to_idx[token])
        sentences.append(new_sentence)
        new_sentence = []

    return np.array(sentences)

def convert_feature_to_idx(docs, idx_token, token_to_idx, max_seq_len):
    sentences = tokenize_docs(docs, idx_token)
    sentences_with_pad = padding(sentences, max_seq_len=max_seq_len, mode="post", val_pad="<PAD>")
    sentences_to_idx = sent_to_idx(sentences_with_pad, token_to_idx)
    
    return sentences_to_idx

train_sentence_idxs = convert_feature_to_idx(train_sentences, 0, token_to_idx, hyperparams.max_seq_len)
val_sentence_idxs = convert_feature_to_idx(val_sentences, 0, token_to_idx, hyperparams.max_seq_len)
test_sentence_idxs = convert_feature_to_idx(test_sentences, 0, token_to_idx, hyperparams.max_seq_len)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]

# %% [markdown]
# ## Encode Class

# %%
classes = sorted(np.delete(id_pos_tag_df["tag"].unique(), 3))
idx_to_label = {idx: label for idx, label in enumerate(classes + ["<PAD>"])}
label_to_idx = {label: idx for idx, label in enumerate(classes + ["<PAD>"])}

def encode_class(docs, label_to_idx, seq_len=hyperparams.max_seq_len):
    class_idxs = []
    classes = []
    
    for sentence in tqdm(docs):
        for token in sentence:
            class_idxs.append(label_to_idx[token[1]])
            
        for _ in range(seq_len - len(sentence)):
            class_idxs.append(label_to_idx["<PAD>"])
                
        classes.append(class_idxs)
        class_idxs = []

    return np.array(classes)
        
train_class_idxs = encode_class(train_sentences, label_to_idx)
val_class_idxs = encode_class(val_sentences, label_to_idx)
test_class_idxs = encode_class(test_sentences, label_to_idx)

print(f"Training shape   : {train_sentence_idxs.shape, train_class_idxs.shape}")
print(f"validation shape : {val_class_idxs.shape, val_class_idxs.shape}")
print(f"Test shape       : {test_sentence_idxs.shape, test_class_idxs.shape}")
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# Training shape   : ((7222, 82), (7222, 82))
# validation shape : ((2006, 82), (2006, 82))
# Test shape       : ((802, 82), (802, 82))

# %% [markdown]
# ## Note
#
# - Number of sentences = 10030
# - Train : 72% (7222)
# - Val   : 8% (802)
# - Test  : 20% (2006)

# %% [markdown]
# # Build Model

# %% [markdown]
# ## Feature and Actual Class

# %%
train_feature = torch.LongTensor(train_sentence_idxs)
val_feature = torch.LongTensor(val_sentence_idxs)
test_feature = torch.LongTensor(test_sentence_idxs)

train_class = torch.LongTensor(train_class_idxs)
val_class = torch.LongTensor(val_class_idxs)
test_class = torch.LongTensor(test_class_idxs)

# %%
train_feature.shape, val_feature.shape, test_feature.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %%
train_class.shape, val_class.shape, test_class.shape
# Out:
# (torch.Size([7222, 82]), torch.Size([2006, 82]), torch.Size([802, 82]))

# %% [markdown]
# ## Tensor Dataset

# %%
train_dataset = TensorDataset(train_feature, train_class)
val_dataset = TensorDataset(val_feature, val_class)
test_dataset = TensorDataset(test_feature, test_class)

# %% [markdown]
# ## Dataloader

# %%
train_dataloader = DataLoader(train_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
val_dataloader = DataLoader(val_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)
test_dataloader = DataLoader(test_dataset, batch_size=hyperparams.batch_size, shuffle=hyperparams.shuffle)

# %% [markdown]
# ## Model

# %%
class POSTagger(nn.Module):
    def __init__(
        self,
        input_size=hyperparams.input_size,
        hidden_size=hyperparams.hidden_size,
        dropout=hyperparams.dropout,
        bias=hyperparams.bias,
        num_layers=hyperparams.num_hidden_layer,
        output_size=hyperparams.output_size,
        batch_first=hyperparams.batch_first,
        bidirectional=hyperparams.bidirectional,
        init_wb_with_kaiming_normal=hyperparams.init_wb_with_kaiming_normal
    ):
        super(POSTagger, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.dropout = dropout
        self.bias = bias
        self.num_layers = num_layers
        self.output_size = output_size
        self.batch_first = batch_first
        self.bidirectional = bidirectional
                
        self.feature = nn.LSTM(
            input_size = self.input_size,
            hidden_size = self.hidden_size,
            bias = self.bias,
            dropout = self.dropout,
            num_layers = self.num_layers,
            batch_first = self.batch_first,
            bidirectional = self.bidirectional
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(in_features=2 * self.hidden_size if hyperparams.bidirectional else self.hidden_size, out_features=self.output_size, bias=self.bias),
            nn.Softmax(dim=-1)
        )
        
        if init_wb_with_kaiming_normal:
            self.init_wb()

    def init_wb(self):
        for module in self.modules():
            if isinstance(module, (nn.Linear, nn.LSTM)):
                for name, param in module.named_parameters():
                    if "weight" in name:
                        nn.init.kaiming_normal_(param)
                    else:
                        nn.init.kaiming_normal_(param.reshape(1, -1))
        
    def forward(self, feature, hidden=None):
        output, (hidden, memory) = self.feature(feature, None)
        prob = self.classifier(output)

        return prob
    
model = POSTagger().to(hyperparams.device)
model
# Out:
# POSTagger(
#   (feature): LSTM(64, 128, bidirectional=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=24, bias=True)
#     (1): Softmax(dim=-1)
#   )
# )

# %% [markdown]
# ## Optimizer, Criterion, and Metric

# %%
optimizer = optim.Adam(model.parameters(), lr=hyperparams.lr)
criterion = nn.CrossEntropyLoss().to(hyperparams.device)
train_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="global", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", verbose=True, factor=0.5)

# %%
sum(param.numel() for param in model.parameters() if param.requires_grad)
# Out:
# 204824

# %% [markdown]
# ## Training Step

# %%
def training_step(dataloader, model, optimizer, criterion, metric, scheduler=None):
    model.train()
    
    batch_losses = []
    batch_metric_scores = []
    
    for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
        # Forward Propagation
        feature = rearrange(feature, "n s -> s n")
        actual_label = rearrange(actual_label, "n s -> s n")
        embedding = word_embeddings(feature)
        
        prob = model(
            embedding.to(hyperparams.device),
            actual_label.to(hyperparams.device)
        )
        
        prob = prob.reshape(-1, prob.shape[-1])
        actual_label = actual_label.reshape(-1)

        loss = criterion(prob, actual_label.to(hyperparams.device))
        metric_score = metric(prob, actual_label.to(hyperparams.device))
        metric_score = metric.compute()
                
        if scheduler is not None:
            scheduler.step(loss)
        
        batch_losses.append(loss.item())
        batch_metric_scores.append(metric_score)
        
        if len(dataloader) < 10:
            if batch % 1 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../logs/unk/fold_{hyperparams.fold}/{path_name}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
        else:
            if batch % 15 == 0 or batch == len(dataloader):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../logs/unk/fold_{hyperparams.fold}/{path_name}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            
        # Backward Propagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Validation Step

# %%
def validation_step(dataloader, model, criterion, metric):
    model.eval()
    
    batch_losses = []
    batch_metric_scores = []
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob, actual_label.to(hyperparams.device))
            metric_score = metric.compute()

            batch_losses.append(loss.item())
            batch_metric_scores.append(metric_score)
            
            if len(dataloader) < 10 and (batch % 1 == 0 or batch == len(dataloader)):
                batch_name = "Batch-" + str(batch)
                print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                with open(f"../../logs/unk/fold_{hyperparams.fold}/{path_name}/training_history.txt", "a") as f:
                    f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
            else:
                if batch % 15 == 0 or batch == len(dataloader):
                    batch_name = "Batch-" + str(batch)
                    print(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}")
                    with open(f"../../logs/unk/fold_{hyperparams.fold}/{path_name}/training_history.txt", "a") as f:
                        f.write(f"{batch_name.ljust(9)}: {str(criterion).split('(')[0]}={(loss.item()):.4f} | {str(metric).split('(')[0]}={(metric_score):.4f}\n")
    
    return batch_losses, batch_metric_scores

# %% [markdown]
# ## Looping Step

# %%
now = datetime.now(pytz.timezone("Asia/Ujung_Pandang"))
path_name = now.strftime("%m-%d-%Y_%H-%M-%S")
root_path = f"../../logs/unk/fold_{hyperparams.fold}/{path_name}"
os.makedirs(root_path)

def looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric, n_epoch=hyperparams.n_epoch, patience=hyperparams.patience, monitor="loss"):    
    start_time = time()
    
    epoch_training_losses = []
    epoch_training_metric_scores = []
    epoch_val_losses = []
    epoch_val_metric_scores = []
    patience_counter = 0
    
    # Hyperparameters
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write(f"HYPERPARAMETERS\n")
        f.write(f"{'-' * 80}\n")
        for name, value in vars(hyperparams).items():
            f.write(f"{name}: {value}\n")
        
        f.write("\n\nTRAINING PROGRESS\n")
        f.write(f"{'-' * 80}\n")
    
    # Training Progress
    for epoch in range(1, n_epoch + 1):
        print(f"EPOCH-{epoch}")
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"EPOCH-{epoch}\n")
            f.write(f"Training Step\n")
            
        # Training Step
        print("Training Step")
        batch_training_losses, batch_training_metric_scores = training_step(train_dataloader, model, optimizer, criterion, train_metric, scheduler=None)
        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))

        epoch_training_loss = torch.mean(torch.FloatTensor(batch_training_losses))
        epoch_training_losses.append(epoch_training_loss.item())

        epoch_training_metric_score = torch.mean(torch.FloatTensor(batch_training_metric_scores))
        epoch_training_metric_scores.append(epoch_training_metric_score.item())
        
        # Validation Step
        with open(f"{root_path}/training_history.txt", "a") as f:
            f.write(f"\nValidation Step\n")
            
        print("\nValidation Step")
        batch_val_losses, batch_val_metric_scores = validation_step(val_dataloader, model, criterion, val_metric)
        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))

        epoch_val_loss = torch.mean(torch.FloatTensor(batch_val_losses))
        epoch_val_losses.append(epoch_val_loss.item())

        epoch_val_metric_score = torch.mean(torch.FloatTensor(batch_val_metric_scores))
        epoch_val_metric_scores.append(epoch_val_metric_score.item())
        
        with open(f"{root_path}/training_history.txt", "a") as f:
            if monitor == "loss":
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_losses[-1] < epoch_training_losses[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
            else:
                if epoch == 1:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                elif epoch_training_metric_scores[-1] > epoch_training_metric_scores[-2]:
                    best_state_dict = model.state_dict()
                    best_training_loss = epoch_training_loss
                    best_training_metric = epoch_training_metric_score
                    best_val_loss = epoch_val_loss
                    best_val_metric = epoch_val_metric_score
                    
                    print("\nYeah 🎉😄! Model improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    
                    f.write("\nYeah 🎉😄! Model improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                else:
                    patience_counter += 1
                    
                    print("\nHuft 😥! Model not improved.")
                    print(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}")
                    print(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}")
                    print(f"Patience = {patience_counter}/{patience}❗\n")
                    
                    f.write("\nHuft 😥! Model not improved.\n")
                    f.write(f"\nTraining   : Mean {str(criterion).split('(')[0]} = {(epoch_training_loss):.4f} | Mean {str(train_metric).split('(')[0]} = {(epoch_training_metric_score):.4f}\n")
                    f.write(f"Validation : Mean {str(criterion).split('(')[0]} = {(epoch_val_loss):.4f} | Mean {str(val_metric).split('(')[0]} = {(epoch_val_metric_score):.4f}\n")
                    f.write(f"Patience = {patience_counter}/{patience}❗\n")
                    
            print("=" * 80, end="\n\n")
            
            f.write(f"{'=' * 80}\n\n")
            
            if patience_counter == patience:
                print(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                
                f.write(f"Early stopping, patience = {patience_counter}/{patience}❗\n")
                break
        
        train_metric.reset()
        val_metric.reset()
        
    finish_time = time()
    
    # Training plot 
    fig, (ax_loss, ax_metric_score) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    fig.suptitle(f"Training with oov embedding = unknown polyglot")

    ax_loss.set_title("Loss")
    ax_loss.set_xlabel("Epoch")
    ax_loss.set_ylabel("Score")
    ax_loss.plot(epoch_training_losses, "green", label="Training")
    ax_loss.plot(epoch_val_losses, "orange", label="Validation")
    ax_loss.legend()
    ax_loss.grid()

    ax_metric_score.set_title("F1 Score")
    ax_metric_score.set_xlabel("Epoch")
    ax_metric_score.set_ylabel("Score")
    ax_metric_score.plot(epoch_training_metric_scores, "green", label="Training")
    ax_metric_score.plot(epoch_val_metric_scores, "orange", label="Validation")
    ax_metric_score.legend()
    ax_metric_score.grid()

    plt.savefig(f"{root_path}/training_plot.jpg", dpi=200)                        
    
    print("TRAINING SUMMARY")
    name_best_training_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_training_metric = f"Best {str(train_metric).split('(')[0]} validation".ljust(34)
    name_best_validation_loss = f"Best {str(criterion).split('(')[0]} training".ljust(34)
    name_best_validation_metric = f"Best {str(val_metric).split('(')[0]} validation".ljust(34)
    name_training_time = f"Training duration".ljust(34)
    name_training_date = f"Training date".ljust(34)
    
    print(f"{name_best_training_loss}: {best_training_loss:.4f}")
    print(f"{name_best_validation_loss}: {best_val_loss:.4f}")
    print(f"{name_best_training_metric}: {best_training_metric:.4f}")
    print(f"{name_best_validation_metric}: {best_val_metric:.4f}")
    print(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.")
    print(f"{name_training_date}: {now}")
    
    with open(f"{root_path}/training_history.txt", "a") as f:
        f.write("\nTRAINING SUMMARY\n")
        f.write(f"{'-' * 80}\n")
        f.write(f"{name_best_training_loss}: {best_training_loss:.4f}\n")
        f.write(f"{name_best_validation_loss}: {best_val_loss:.4f}\n")
        f.write(f"{name_best_training_metric}: {best_training_metric:.4f}\n")
        f.write(f"{name_best_validation_metric}: {best_val_metric:.4f}\n")
        f.write(f"{name_training_time}: {((finish_time - start_time) / 60):.4f} minutes.\n")
        f.write(f"{name_training_date}: {now}\n")
    
    # Save epoch losses, epoch metric scores, model, state dict, and oov embedding dict
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_training_losses
    }).to_csv(f"{root_path}/training_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_training_metric_scores
    }).to_csv(f"{root_path}/training_metric_scores.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "loss": epoch_val_losses
    }).to_csv(f"{root_path}/val_losses.csv", index=False)
    
    pd.DataFrame({
        "epoch": list(range(1, hyperparams.n_epoch + 1)),
        "f1_score": epoch_val_metric_scores
    }).to_csv(f"{root_path}/val_metric_scores.csv", index=False)    
    
    filename_model_params = f"{root_path}/model_params.pth"
    torch.save(best_state_dict, filename_model_params)
    
    return epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores

epoch_training_losses, epoch_training_metric_scores, epoch_val_losses, epoch_val_metric_scores = looping_step(train_dataloader, val_dataloader, model, optimizer, criterion, train_metric, val_metric)
# Out:
# EPOCH-1
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.4982 | MulticlassF1Score=0.0654
# Batch-30 : CrossEntropyLoss=2.4577 | MulticlassF1Score=0.1428
# Batch-45 : CrossEntropyLoss=2.4949 | MulticlassF1Score=0.1744
# Batch-60 : CrossEntropyLoss=2.4650 | MulticlassF1Score=0.1901
# Batch-75 : CrossEntropyLoss=2.4973 | MulticlassF1Score=0.1993
# Batch-90 : CrossEntropyLoss=2.4924 | MulticlassF1Score=0.2072
# Batch-105: CrossEntropyLoss=2.4685 | MulticlassF1Score=0.2106
# Batch-120: CrossEntropyLoss=2.4821 | MulticlassF1Score=0.2144
# Batch-135: CrossEntropyLoss=2.4784 | MulticlassF1Score=0.2193
# Batch-150: CrossEntropyLoss=2.4317 | MulticlassF1Score=0.2310
# Batch-165: CrossEntropyLoss=2.4186 | MulticlassF1Score=0.2476
# Batch-180: CrossEntropyLoss=2.4040 | MulticlassF1Score=0.2646
# Batch-195: CrossEntropyLoss=2.4111 | MulticlassF1Score=0.2799
# Batch-210: CrossEntropyLoss=2.3872 | MulticlassF1Score=0.2961
# Batch-225: CrossEntropyLoss=2.3841 | MulticlassF1Score=0.3142
# Batch-226: CrossEntropyLoss=2.3494 | MulticlassF1Score=0.3147
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3780 | MulticlassF1Score=0.5602
# Batch-30 : CrossEntropyLoss=2.4025 | MulticlassF1Score=0.5623
# Batch-45 : CrossEntropyLoss=2.3827 | MulticlassF1Score=0.5642
# Batch-60 : CrossEntropyLoss=2.3903 | MulticlassF1Score=0.5669
# Batch-63 : CrossEntropyLoss=2.3825 | MulticlassF1Score=0.5664
#
# Training   : Mean CrossEntropyLoss = 2.4693 | Mean MulticlassF1Score = 0.2082
# Validation : Mean CrossEntropyLoss = 2.3831 | Mean MulticlassF1Score = 0.5647
# ================================================================================
#
# EPOCH-2
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3928 | MulticlassF1Score=0.5637
# Batch-30 : CrossEntropyLoss=2.3618 | MulticlassF1Score=0.5871
# Batch-45 : CrossEntropyLoss=2.3634 | MulticlassF1Score=0.6036
# Batch-60 : CrossEntropyLoss=2.3515 | MulticlassF1Score=0.6136
# Batch-75 : CrossEntropyLoss=2.3635 | MulticlassF1Score=0.6242
# Batch-90 : CrossEntropyLoss=2.3441 | MulticlassF1Score=0.6356
# Batch-105: CrossEntropyLoss=2.3335 | MulticlassF1Score=0.6454
# Batch-120: CrossEntropyLoss=2.3226 | MulticlassF1Score=0.6560
# Batch-135: CrossEntropyLoss=2.3304 | MulticlassF1Score=0.6669
# Batch-150: CrossEntropyLoss=2.3281 | MulticlassF1Score=0.6755
# Batch-165: CrossEntropyLoss=2.3340 | MulticlassF1Score=0.6838
# Batch-180: CrossEntropyLoss=2.3243 | MulticlassF1Score=0.6901
# Batch-195: CrossEntropyLoss=2.3226 | MulticlassF1Score=0.6957
# Batch-210: CrossEntropyLoss=2.3196 | MulticlassF1Score=0.7014
# Batch-225: CrossEntropyLoss=2.3175 | MulticlassF1Score=0.7060
# Batch-226: CrossEntropyLoss=2.3240 | MulticlassF1Score=0.7062
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3258 | MulticlassF1Score=0.7727
# Batch-30 : CrossEntropyLoss=2.3329 | MulticlassF1Score=0.7682
# Batch-45 : CrossEntropyLoss=2.3287 | MulticlassF1Score=0.7695
# Batch-60 : CrossEntropyLoss=2.3205 | MulticlassF1Score=0.7670
# Batch-63 : CrossEntropyLoss=2.3293 | MulticlassF1Score=0.7674
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3402 | Mean MulticlassF1Score = 0.6459
# Validation : Mean CrossEntropyLoss = 2.3204 | Mean MulticlassF1Score = 0.7699
# ================================================================================
#
# EPOCH-3
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3311 | MulticlassF1Score=0.7713
# Batch-30 : CrossEntropyLoss=2.3155 | MulticlassF1Score=0.7725
# Batch-45 : CrossEntropyLoss=2.3137 | MulticlassF1Score=0.7738
# Batch-60 : CrossEntropyLoss=2.3147 | MulticlassF1Score=0.7725
# Batch-75 : CrossEntropyLoss=2.3119 | MulticlassF1Score=0.7716
# Batch-90 : CrossEntropyLoss=2.3301 | MulticlassF1Score=0.7714
# Batch-105: CrossEntropyLoss=2.3121 | MulticlassF1Score=0.7708
# Batch-120: CrossEntropyLoss=2.3227 | MulticlassF1Score=0.7705
# Batch-135: CrossEntropyLoss=2.3207 | MulticlassF1Score=0.7704
# Batch-150: CrossEntropyLoss=2.3230 | MulticlassF1Score=0.7707
# Batch-165: CrossEntropyLoss=2.3247 | MulticlassF1Score=0.7718
# Batch-180: CrossEntropyLoss=2.3114 | MulticlassF1Score=0.7736
# Batch-195: CrossEntropyLoss=2.3251 | MulticlassF1Score=0.7747
# Batch-210: CrossEntropyLoss=2.3030 | MulticlassF1Score=0.7755
# Batch-225: CrossEntropyLoss=2.3247 | MulticlassF1Score=0.7758
# Batch-226: CrossEntropyLoss=2.3185 | MulticlassF1Score=0.7758
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3123 | MulticlassF1Score=0.8043
# Batch-30 : CrossEntropyLoss=2.3096 | MulticlassF1Score=0.8008
# Batch-45 : CrossEntropyLoss=2.3112 | MulticlassF1Score=0.7994
# Batch-60 : CrossEntropyLoss=2.3237 | MulticlassF1Score=0.7980
# Batch-63 : CrossEntropyLoss=2.3110 | MulticlassF1Score=0.7977
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3176 | Mean MulticlassF1Score = 0.7725
# Validation : Mean CrossEntropyLoss = 2.3106 | Mean MulticlassF1Score = 0.8009
# ================================================================================
#
# EPOCH-4
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3118 | MulticlassF1Score=0.8027
# Batch-30 : CrossEntropyLoss=2.3063 | MulticlassF1Score=0.8069
# Batch-45 : CrossEntropyLoss=2.3026 | MulticlassF1Score=0.8100
# Batch-60 : CrossEntropyLoss=2.3059 | MulticlassF1Score=0.8093
# Batch-75 : CrossEntropyLoss=2.3047 | MulticlassF1Score=0.8110
# Batch-90 : CrossEntropyLoss=2.3063 | MulticlassF1Score=0.8107
# Batch-105: CrossEntropyLoss=2.3045 | MulticlassF1Score=0.8122
# Batch-120: CrossEntropyLoss=2.3112 | MulticlassF1Score=0.8122
# Batch-135: CrossEntropyLoss=2.3108 | MulticlassF1Score=0.8131
# Batch-150: CrossEntropyLoss=2.3141 | MulticlassF1Score=0.8138
# Batch-165: CrossEntropyLoss=2.2956 | MulticlassF1Score=0.8147
# Batch-180: CrossEntropyLoss=2.3002 | MulticlassF1Score=0.8155
# Batch-195: CrossEntropyLoss=2.3017 | MulticlassF1Score=0.8160
# Batch-210: CrossEntropyLoss=2.3051 | MulticlassF1Score=0.8165
# Batch-225: CrossEntropyLoss=2.3016 | MulticlassF1Score=0.8169
# Batch-226: CrossEntropyLoss=2.2898 | MulticlassF1Score=0.8169
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3077 | MulticlassF1Score=0.8246
# Batch-30 : CrossEntropyLoss=2.3022 | MulticlassF1Score=0.8227
# Batch-45 : CrossEntropyLoss=2.3056 | MulticlassF1Score=0.8234
# Batch-60 : CrossEntropyLoss=2.2977 | MulticlassF1Score=0.8228
# Batch-63 : CrossEntropyLoss=2.2943 | MulticlassF1Score=0.8228
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3048 | Mean MulticlassF1Score = 0.8116
# Validation : Mean CrossEntropyLoss = 2.3030 | Mean MulticlassF1Score = 0.8236
# ================================================================================
#
# EPOCH-5
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2958 | MulticlassF1Score=0.8218
# Batch-30 : CrossEntropyLoss=2.3028 | MulticlassF1Score=0.8214
# Batch-45 : CrossEntropyLoss=2.3023 | MulticlassF1Score=0.8265
# Batch-60 : CrossEntropyLoss=2.2994 | MulticlassF1Score=0.8259
# Batch-75 : CrossEntropyLoss=2.2915 | MulticlassF1Score=0.8273
# Batch-90 : CrossEntropyLoss=2.3013 | MulticlassF1Score=0.8269
# Batch-105: CrossEntropyLoss=2.2964 | MulticlassF1Score=0.8265
# Batch-120: CrossEntropyLoss=2.2987 | MulticlassF1Score=0.8266
# Batch-135: CrossEntropyLoss=2.2956 | MulticlassF1Score=0.8257
# Batch-150: CrossEntropyLoss=2.3010 | MulticlassF1Score=0.8260
# Batch-165: CrossEntropyLoss=2.3087 | MulticlassF1Score=0.8261
# Batch-180: CrossEntropyLoss=2.3037 | MulticlassF1Score=0.8257
# Batch-195: CrossEntropyLoss=2.3041 | MulticlassF1Score=0.8256
# Batch-210: CrossEntropyLoss=2.3052 | MulticlassF1Score=0.8255
# Batch-225: CrossEntropyLoss=2.3066 | MulticlassF1Score=0.8254
# Batch-226: CrossEntropyLoss=2.3001 | MulticlassF1Score=0.8254
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.3033 | MulticlassF1Score=0.8187
# Batch-30 : CrossEntropyLoss=2.2949 | MulticlassF1Score=0.8213
# Batch-45 : CrossEntropyLoss=2.3030 | MulticlassF1Score=0.8241
# Batch-60 : CrossEntropyLoss=2.2962 | MulticlassF1Score=0.8259
# Batch-63 : CrossEntropyLoss=2.3043 | MulticlassF1Score=0.8259
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.3019 | Mean MulticlassF1Score = 0.8259
# Validation : Mean CrossEntropyLoss = 2.3016 | Mean MulticlassF1Score = 0.8223
# ================================================================================
#
# EPOCH-6
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2933 | MulticlassF1Score=0.8219
# Batch-30 : CrossEntropyLoss=2.2969 | MulticlassF1Score=0.8234
# Batch-45 : CrossEntropyLoss=2.2921 | MulticlassF1Score=0.8253
# Batch-60 : CrossEntropyLoss=2.2917 | MulticlassF1Score=0.8277
# Batch-75 : CrossEntropyLoss=2.3003 | MulticlassF1Score=0.8283
# Batch-90 : CrossEntropyLoss=2.3024 | MulticlassF1Score=0.8279
# Batch-105: CrossEntropyLoss=2.3127 | MulticlassF1Score=0.8289
# Batch-120: CrossEntropyLoss=2.2881 | MulticlassF1Score=0.8292
# Batch-135: CrossEntropyLoss=2.3031 | MulticlassF1Score=0.8282
# Batch-150: CrossEntropyLoss=2.3004 | MulticlassF1Score=0.8288
# Batch-165: CrossEntropyLoss=2.2991 | MulticlassF1Score=0.8308
# Batch-180: CrossEntropyLoss=2.2875 | MulticlassF1Score=0.8331
# Batch-195: CrossEntropyLoss=2.2916 | MulticlassF1Score=0.8356
# Batch-210: CrossEntropyLoss=2.2880 | MulticlassF1Score=0.8388
# Batch-225: CrossEntropyLoss=2.2896 | MulticlassF1Score=0.8406
# Batch-226: CrossEntropyLoss=2.2876 | MulticlassF1Score=0.8407
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2883 | MulticlassF1Score=0.8701
# Batch-30 : CrossEntropyLoss=2.2929 | MulticlassF1Score=0.8707
# Batch-45 : CrossEntropyLoss=2.2926 | MulticlassF1Score=0.8698
# Batch-60 : CrossEntropyLoss=2.2927 | MulticlassF1Score=0.8667
# Batch-63 : CrossEntropyLoss=2.2806 | MulticlassF1Score=0.8676
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2974 | Mean MulticlassF1Score = 0.8292
# Validation : Mean CrossEntropyLoss = 2.2893 | Mean MulticlassF1Score = 0.8712
# ================================================================================
#
# EPOCH-7
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2875 | MulticlassF1Score=0.8712
# Batch-30 : CrossEntropyLoss=2.2889 | MulticlassF1Score=0.8735
# Batch-45 : CrossEntropyLoss=2.2822 | MulticlassF1Score=0.8757
# Batch-60 : CrossEntropyLoss=2.2846 | MulticlassF1Score=0.8751
# Batch-75 : CrossEntropyLoss=2.2935 | MulticlassF1Score=0.8760
# Batch-90 : CrossEntropyLoss=2.2960 | MulticlassF1Score=0.8756
# Batch-105: CrossEntropyLoss=2.2860 | MulticlassF1Score=0.8758
# Batch-120: CrossEntropyLoss=2.2904 | MulticlassF1Score=0.8754
# Batch-135: CrossEntropyLoss=2.2810 | MulticlassF1Score=0.8754
# Batch-150: CrossEntropyLoss=2.2844 | MulticlassF1Score=0.8756
# Batch-165: CrossEntropyLoss=2.2796 | MulticlassF1Score=0.8756
# Batch-180: CrossEntropyLoss=2.2953 | MulticlassF1Score=0.8751
# Batch-195: CrossEntropyLoss=2.2891 | MulticlassF1Score=0.8748
# Batch-210: CrossEntropyLoss=2.2839 | MulticlassF1Score=0.8747
# Batch-225: CrossEntropyLoss=2.2818 | MulticlassF1Score=0.8745
# Batch-226: CrossEntropyLoss=2.2784 | MulticlassF1Score=0.8745
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2883 | MulticlassF1Score=0.8748
# Batch-30 : CrossEntropyLoss=2.2872 | MulticlassF1Score=0.8762
# Batch-45 : CrossEntropyLoss=2.2936 | MulticlassF1Score=0.8745
# Batch-60 : CrossEntropyLoss=2.2824 | MulticlassF1Score=0.8725
# Batch-63 : CrossEntropyLoss=2.2900 | MulticlassF1Score=0.8722
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2871 | Mean MulticlassF1Score = 0.8748
# Validation : Mean CrossEntropyLoss = 2.2875 | Mean MulticlassF1Score = 0.8740
# ================================================================================
#
# EPOCH-8
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2864 | MulticlassF1Score=0.8792
# Batch-30 : CrossEntropyLoss=2.2804 | MulticlassF1Score=0.8810
# Batch-45 : CrossEntropyLoss=2.2893 | MulticlassF1Score=0.8796
# Batch-60 : CrossEntropyLoss=2.2849 | MulticlassF1Score=0.8795
# Batch-75 : CrossEntropyLoss=2.2837 | MulticlassF1Score=0.8787
# Batch-90 : CrossEntropyLoss=2.2854 | MulticlassF1Score=0.8791
# Batch-105: CrossEntropyLoss=2.2791 | MulticlassF1Score=0.8788
# Batch-120: CrossEntropyLoss=2.2847 | MulticlassF1Score=0.8790
# Batch-135: CrossEntropyLoss=2.2785 | MulticlassF1Score=0.8789
# Batch-150: CrossEntropyLoss=2.2886 | MulticlassF1Score=0.8785
# Batch-165: CrossEntropyLoss=2.2840 | MulticlassF1Score=0.8787
# Batch-180: CrossEntropyLoss=2.2890 | MulticlassF1Score=0.8785
# Batch-195: CrossEntropyLoss=2.2724 | MulticlassF1Score=0.8782
# Batch-210: CrossEntropyLoss=2.2862 | MulticlassF1Score=0.8783
# Batch-225: CrossEntropyLoss=2.2741 | MulticlassF1Score=0.8787
# Batch-226: CrossEntropyLoss=2.2852 | MulticlassF1Score=0.8787
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2947 | MulticlassF1Score=0.8722
# Batch-30 : CrossEntropyLoss=2.2854 | MulticlassF1Score=0.8719
# Batch-45 : CrossEntropyLoss=2.2902 | MulticlassF1Score=0.8735
# Batch-60 : CrossEntropyLoss=2.2827 | MulticlassF1Score=0.8742
# Batch-63 : CrossEntropyLoss=2.2962 | MulticlassF1Score=0.8737
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2855 | Mean MulticlassF1Score = 0.8790
# Validation : Mean CrossEntropyLoss = 2.2870 | Mean MulticlassF1Score = 0.8739
# ================================================================================
#
# EPOCH-9
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2811 | MulticlassF1Score=0.8793
# Batch-30 : CrossEntropyLoss=2.2877 | MulticlassF1Score=0.8799
# Batch-45 : CrossEntropyLoss=2.2862 | MulticlassF1Score=0.8808
# Batch-60 : CrossEntropyLoss=2.2862 | MulticlassF1Score=0.8799
# Batch-75 : CrossEntropyLoss=2.2916 | MulticlassF1Score=0.8814
# Batch-90 : CrossEntropyLoss=2.2847 | MulticlassF1Score=0.8814
# Batch-105: CrossEntropyLoss=2.2887 | MulticlassF1Score=0.8810
# Batch-120: CrossEntropyLoss=2.2900 | MulticlassF1Score=0.8803
# Batch-135: CrossEntropyLoss=2.2804 | MulticlassF1Score=0.8806
# Batch-150: CrossEntropyLoss=2.2847 | MulticlassF1Score=0.8807
# Batch-165: CrossEntropyLoss=2.2783 | MulticlassF1Score=0.8812
# Batch-180: CrossEntropyLoss=2.2851 | MulticlassF1Score=0.8812
# Batch-195: CrossEntropyLoss=2.2801 | MulticlassF1Score=0.8813
# Batch-210: CrossEntropyLoss=2.2821 | MulticlassF1Score=0.8813
# Batch-225: CrossEntropyLoss=2.2839 | MulticlassF1Score=0.8814
# Batch-226: CrossEntropyLoss=2.3019 | MulticlassF1Score=0.8814
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2868 | MulticlassF1Score=0.8723
# Batch-30 : CrossEntropyLoss=2.2937 | MulticlassF1Score=0.8723
# Batch-45 : CrossEntropyLoss=2.2844 | MulticlassF1Score=0.8734
# Batch-60 : CrossEntropyLoss=2.2932 | MulticlassF1Score=0.8741
# Batch-63 : CrossEntropyLoss=2.2831 | MulticlassF1Score=0.8740
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2846 | Mean MulticlassF1Score = 0.8810
# Validation : Mean CrossEntropyLoss = 2.2866 | Mean MulticlassF1Score = 0.8735
# ================================================================================
#
# EPOCH-10
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2791 | MulticlassF1Score=0.8820
# Batch-30 : CrossEntropyLoss=2.2843 | MulticlassF1Score=0.8842
# Batch-45 : CrossEntropyLoss=2.2875 | MulticlassF1Score=0.8839
# Batch-60 : CrossEntropyLoss=2.2864 | MulticlassF1Score=0.8830
# Batch-75 : CrossEntropyLoss=2.2812 | MulticlassF1Score=0.8825
# Batch-90 : CrossEntropyLoss=2.2897 | MulticlassF1Score=0.8819
# Batch-105: CrossEntropyLoss=2.2806 | MulticlassF1Score=0.8818
# Batch-120: CrossEntropyLoss=2.2781 | MulticlassF1Score=0.8820
# Batch-135: CrossEntropyLoss=2.2884 | MulticlassF1Score=0.8821
# Batch-150: CrossEntropyLoss=2.2811 | MulticlassF1Score=0.8822
# Batch-165: CrossEntropyLoss=2.2834 | MulticlassF1Score=0.8824
# Batch-180: CrossEntropyLoss=2.2873 | MulticlassF1Score=0.8827
# Batch-195: CrossEntropyLoss=2.2847 | MulticlassF1Score=0.8829
# Batch-210: CrossEntropyLoss=2.2790 | MulticlassF1Score=0.8831
# Batch-225: CrossEntropyLoss=2.2861 | MulticlassF1Score=0.8833
# Batch-226: CrossEntropyLoss=2.2779 | MulticlassF1Score=0.8834
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2919 | MulticlassF1Score=0.8717
# Batch-30 : CrossEntropyLoss=2.2817 | MulticlassF1Score=0.8746
# Batch-45 : CrossEntropyLoss=2.2958 | MulticlassF1Score=0.8736
# Batch-60 : CrossEntropyLoss=2.2803 | MulticlassF1Score=0.8751
# Batch-63 : CrossEntropyLoss=2.2854 | MulticlassF1Score=0.8753
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2839 | Mean MulticlassF1Score = 0.8828
# Validation : Mean CrossEntropyLoss = 2.2863 | Mean MulticlassF1Score = 0.8733
# ================================================================================
#
# EPOCH-11
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2900 | MulticlassF1Score=0.8800
# Batch-30 : CrossEntropyLoss=2.2823 | MulticlassF1Score=0.8822
# Batch-45 : CrossEntropyLoss=2.2817 | MulticlassF1Score=0.8843
# Batch-60 : CrossEntropyLoss=2.2880 | MulticlassF1Score=0.8840
# Batch-75 : CrossEntropyLoss=2.2889 | MulticlassF1Score=0.8838
# Batch-90 : CrossEntropyLoss=2.2882 | MulticlassF1Score=0.8838
# Batch-105: CrossEntropyLoss=2.2755 | MulticlassF1Score=0.8846
# Batch-120: CrossEntropyLoss=2.2777 | MulticlassF1Score=0.8852
# Batch-135: CrossEntropyLoss=2.2826 | MulticlassF1Score=0.8855
# Batch-150: CrossEntropyLoss=2.2793 | MulticlassF1Score=0.8863
# Batch-165: CrossEntropyLoss=2.2853 | MulticlassF1Score=0.8860
# Batch-180: CrossEntropyLoss=2.2798 | MulticlassF1Score=0.8863
# Batch-195: CrossEntropyLoss=2.2846 | MulticlassF1Score=0.8862
# Batch-210: CrossEntropyLoss=2.2862 | MulticlassF1Score=0.8862
# Batch-225: CrossEntropyLoss=2.2883 | MulticlassF1Score=0.8861
# Batch-226: CrossEntropyLoss=2.2832 | MulticlassF1Score=0.8861
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2887 | MulticlassF1Score=0.8778
# Batch-30 : CrossEntropyLoss=2.2834 | MulticlassF1Score=0.8776
# Batch-45 : CrossEntropyLoss=2.2894 | MulticlassF1Score=0.8748
# Batch-60 : CrossEntropyLoss=2.2915 | MulticlassF1Score=0.8752
# Batch-63 : CrossEntropyLoss=2.2907 | MulticlassF1Score=0.8755
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2830 | Mean MulticlassF1Score = 0.8844
# Validation : Mean CrossEntropyLoss = 2.2862 | Mean MulticlassF1Score = 0.8776
# ================================================================================
#
# EPOCH-12
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2907 | MulticlassF1Score=0.8857
# Batch-30 : CrossEntropyLoss=2.2787 | MulticlassF1Score=0.8862
# Batch-45 : CrossEntropyLoss=2.2820 | MulticlassF1Score=0.8871
# Batch-60 : CrossEntropyLoss=2.2819 | MulticlassF1Score=0.8866
# Batch-75 : CrossEntropyLoss=2.2852 | MulticlassF1Score=0.8863
# Batch-90 : CrossEntropyLoss=2.2783 | MulticlassF1Score=0.8867
# Batch-105: CrossEntropyLoss=2.2845 | MulticlassF1Score=0.8863
# Batch-120: CrossEntropyLoss=2.2883 | MulticlassF1Score=0.8856
# Batch-135: CrossEntropyLoss=2.2766 | MulticlassF1Score=0.8862
# Batch-150: CrossEntropyLoss=2.2799 | MulticlassF1Score=0.8864
# Batch-165: CrossEntropyLoss=2.2810 | MulticlassF1Score=0.8868
# Batch-180: CrossEntropyLoss=2.2803 | MulticlassF1Score=0.8868
# Batch-195: CrossEntropyLoss=2.2800 | MulticlassF1Score=0.8872
# Batch-210: CrossEntropyLoss=2.2743 | MulticlassF1Score=0.8876
# Batch-225: CrossEntropyLoss=2.2787 | MulticlassF1Score=0.8876
# Batch-226: CrossEntropyLoss=2.2888 | MulticlassF1Score=0.8875
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2839 | MulticlassF1Score=0.8761
# Batch-30 : CrossEntropyLoss=2.2757 | MulticlassF1Score=0.8763
# Batch-45 : CrossEntropyLoss=2.2843 | MulticlassF1Score=0.8764
# Batch-60 : CrossEntropyLoss=2.2921 | MulticlassF1Score=0.8756
# Batch-63 : CrossEntropyLoss=2.2933 | MulticlassF1Score=0.8756
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2826 | Mean MulticlassF1Score = 0.8865
# Validation : Mean CrossEntropyLoss = 2.2861 | Mean MulticlassF1Score = 0.8760
# ================================================================================
#
# EPOCH-13
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2892 | MulticlassF1Score=0.8908
# Batch-30 : CrossEntropyLoss=2.2813 | MulticlassF1Score=0.8943
# Batch-45 : CrossEntropyLoss=2.2762 | MulticlassF1Score=0.8923
# Batch-60 : CrossEntropyLoss=2.2852 | MulticlassF1Score=0.8907
# Batch-75 : CrossEntropyLoss=2.2813 | MulticlassF1Score=0.8910
# Batch-90 : CrossEntropyLoss=2.2754 | MulticlassF1Score=0.8908
# Batch-105: CrossEntropyLoss=2.2903 | MulticlassF1Score=0.8896
# Batch-120: CrossEntropyLoss=2.2849 | MulticlassF1Score=0.8891
# Batch-135: CrossEntropyLoss=2.2844 | MulticlassF1Score=0.8889
# Batch-150: CrossEntropyLoss=2.2867 | MulticlassF1Score=0.8887
# Batch-165: CrossEntropyLoss=2.2791 | MulticlassF1Score=0.8889
# Batch-180: CrossEntropyLoss=2.2869 | MulticlassF1Score=0.8890
# Batch-195: CrossEntropyLoss=2.2900 | MulticlassF1Score=0.8885
# Batch-210: CrossEntropyLoss=2.2879 | MulticlassF1Score=0.8888
# Batch-225: CrossEntropyLoss=2.2799 | MulticlassF1Score=0.8888
# Batch-226: CrossEntropyLoss=2.2821 | MulticlassF1Score=0.8888
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2847 | MulticlassF1Score=0.8774
# Batch-30 : CrossEntropyLoss=2.2903 | MulticlassF1Score=0.8767
# Batch-45 : CrossEntropyLoss=2.2882 | MulticlassF1Score=0.8782
# Batch-60 : CrossEntropyLoss=2.2853 | MulticlassF1Score=0.8764
# Batch-63 : CrossEntropyLoss=2.2872 | MulticlassF1Score=0.8760
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2821 | Mean MulticlassF1Score = 0.8904
# Validation : Mean CrossEntropyLoss = 2.2859 | Mean MulticlassF1Score = 0.8767
# ================================================================================
#
# EPOCH-14
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2851 | MulticlassF1Score=0.8901
# Batch-30 : CrossEntropyLoss=2.2827 | MulticlassF1Score=0.8895
# Batch-45 : CrossEntropyLoss=2.2815 | MulticlassF1Score=0.8896
# Batch-60 : CrossEntropyLoss=2.2793 | MulticlassF1Score=0.8907
# Batch-75 : CrossEntropyLoss=2.2856 | MulticlassF1Score=0.8903
# Batch-90 : CrossEntropyLoss=2.2840 | MulticlassF1Score=0.8905
# Batch-105: CrossEntropyLoss=2.2786 | MulticlassF1Score=0.8913
# Batch-120: CrossEntropyLoss=2.2834 | MulticlassF1Score=0.8908
# Batch-135: CrossEntropyLoss=2.2770 | MulticlassF1Score=0.8909
# Batch-150: CrossEntropyLoss=2.2798 | MulticlassF1Score=0.8905
# Batch-165: CrossEntropyLoss=2.2793 | MulticlassF1Score=0.8899
# Batch-180: CrossEntropyLoss=2.2822 | MulticlassF1Score=0.8902
# Batch-195: CrossEntropyLoss=2.2844 | MulticlassF1Score=0.8903
# Batch-210: CrossEntropyLoss=2.2757 | MulticlassF1Score=0.8904
# Batch-225: CrossEntropyLoss=2.2771 | MulticlassF1Score=0.8912
# Batch-226: CrossEntropyLoss=2.2773 | MulticlassF1Score=0.8912
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2844 | MulticlassF1Score=0.8974
# Batch-30 : CrossEntropyLoss=2.2794 | MulticlassF1Score=0.8956
# Batch-45 : CrossEntropyLoss=2.2818 | MulticlassF1Score=0.8965
# Batch-60 : CrossEntropyLoss=2.2911 | MulticlassF1Score=0.8956
# Batch-63 : CrossEntropyLoss=2.2770 | MulticlassF1Score=0.8959
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2813 | Mean MulticlassF1Score = 0.8903
# Validation : Mean CrossEntropyLoss = 2.2799 | Mean MulticlassF1Score = 0.8971
# ================================================================================
#
# EPOCH-15
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2760 | MulticlassF1Score=0.9152
# Batch-30 : CrossEntropyLoss=2.2772 | MulticlassF1Score=0.9120
# Batch-45 : CrossEntropyLoss=2.2803 | MulticlassF1Score=0.9129
# Batch-60 : CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9122
# Batch-75 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9127
# Batch-90 : CrossEntropyLoss=2.2737 | MulticlassF1Score=0.9130
# Batch-105: CrossEntropyLoss=2.2725 | MulticlassF1Score=0.9143
# Batch-120: CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9149
# Batch-135: CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9155
# Batch-150: CrossEntropyLoss=2.2794 | MulticlassF1Score=0.9157
# Batch-165: CrossEntropyLoss=2.2709 | MulticlassF1Score=0.9162
# Batch-180: CrossEntropyLoss=2.2754 | MulticlassF1Score=0.9165
# Batch-195: CrossEntropyLoss=2.2756 | MulticlassF1Score=0.9165
# Batch-210: CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9162
# Batch-225: CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9165
# Batch-226: CrossEntropyLoss=2.2877 | MulticlassF1Score=0.9164
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2811 | MulticlassF1Score=0.8998
# Batch-30 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9032
# Batch-45 : CrossEntropyLoss=2.2801 | MulticlassF1Score=0.9034
# Batch-60 : CrossEntropyLoss=2.2768 | MulticlassF1Score=0.9041
# Batch-63 : CrossEntropyLoss=2.2777 | MulticlassF1Score=0.9041
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2737 | Mean MulticlassF1Score = 0.9146
# Validation : Mean CrossEntropyLoss = 2.2773 | Mean MulticlassF1Score = 0.9033
# ================================================================================
#
# EPOCH-16
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9213
# Batch-30 : CrossEntropyLoss=2.2749 | MulticlassF1Score=0.9197
# Batch-45 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9191
# Batch-60 : CrossEntropyLoss=2.2806 | MulticlassF1Score=0.9183
# Batch-75 : CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9193
# Batch-90 : CrossEntropyLoss=2.2763 | MulticlassF1Score=0.9190
# Batch-105: CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9189
# Batch-120: CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9187
# Batch-135: CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9187
# Batch-150: CrossEntropyLoss=2.2730 | MulticlassF1Score=0.9186
# Batch-165: CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9188
# Batch-180: CrossEntropyLoss=2.2766 | MulticlassF1Score=0.9192
# Batch-195: CrossEntropyLoss=2.2806 | MulticlassF1Score=0.9191
# Batch-210: CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9190
# Batch-225: CrossEntropyLoss=2.2765 | MulticlassF1Score=0.9192
# Batch-226: CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9192
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2758 | MulticlassF1Score=0.9032
# Batch-30 : CrossEntropyLoss=2.2764 | MulticlassF1Score=0.9050
# Batch-45 : CrossEntropyLoss=2.2802 | MulticlassF1Score=0.9050
# Batch-60 : CrossEntropyLoss=2.2822 | MulticlassF1Score=0.9040
# Batch-63 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9041
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2727 | Mean MulticlassF1Score = 0.9195
# Validation : Mean CrossEntropyLoss = 2.2772 | Mean MulticlassF1Score = 0.9029
# ================================================================================
#
# EPOCH-17
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2771 | MulticlassF1Score=0.9231
# Batch-30 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9232
# Batch-45 : CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9227
# Batch-60 : CrossEntropyLoss=2.2806 | MulticlassF1Score=0.9226
# Batch-75 : CrossEntropyLoss=2.2728 | MulticlassF1Score=0.9213
# Batch-90 : CrossEntropyLoss=2.2783 | MulticlassF1Score=0.9212
# Batch-105: CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9207
# Batch-120: CrossEntropyLoss=2.2747 | MulticlassF1Score=0.9211
# Batch-135: CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9215
# Batch-150: CrossEntropyLoss=2.2731 | MulticlassF1Score=0.9215
# Batch-165: CrossEntropyLoss=2.2776 | MulticlassF1Score=0.9212
# Batch-180: CrossEntropyLoss=2.2694 | MulticlassF1Score=0.9211
# Batch-195: CrossEntropyLoss=2.2765 | MulticlassF1Score=0.9208
# Batch-210: CrossEntropyLoss=2.2726 | MulticlassF1Score=0.9207
# Batch-225: CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9210
# Batch-226: CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9210
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2767 | MulticlassF1Score=0.9049
# Batch-30 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9046
# Batch-45 : CrossEntropyLoss=2.2778 | MulticlassF1Score=0.9068
# Batch-60 : CrossEntropyLoss=2.2819 | MulticlassF1Score=0.9052
# Batch-63 : CrossEntropyLoss=2.2794 | MulticlassF1Score=0.9052
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2721 | Mean MulticlassF1Score = 0.9219
# Validation : Mean CrossEntropyLoss = 2.2770 | Mean MulticlassF1Score = 0.9047
# ================================================================================
#
# EPOCH-18
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9231
# Batch-30 : CrossEntropyLoss=2.2723 | MulticlassF1Score=0.9203
# Batch-45 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9211
# Batch-60 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9214
# Batch-75 : CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9214
# Batch-90 : CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9223
# Batch-105: CrossEntropyLoss=2.2707 | MulticlassF1Score=0.9217
# Batch-120: CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9212
# Batch-135: CrossEntropyLoss=2.2733 | MulticlassF1Score=0.9216
# Batch-150: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9218
# Batch-165: CrossEntropyLoss=2.2754 | MulticlassF1Score=0.9214
# Batch-180: CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9217
# Batch-195: CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9214
# Batch-210: CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9215
# Batch-225: CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9217
# Batch-226: CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9217
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2769 | MulticlassF1Score=0.9093
# Batch-30 : CrossEntropyLoss=2.2742 | MulticlassF1Score=0.9066
# Batch-45 : CrossEntropyLoss=2.2793 | MulticlassF1Score=0.9053
# Batch-60 : CrossEntropyLoss=2.2718 | MulticlassF1Score=0.9054
# Batch-63 : CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9054
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2718 | Mean MulticlassF1Score = 0.9215
# Validation : Mean CrossEntropyLoss = 2.2768 | Mean MulticlassF1Score = 0.9085
# ================================================================================
#
# EPOCH-19
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9233
# Batch-30 : CrossEntropyLoss=2.2705 | MulticlassF1Score=0.9252
# Batch-45 : CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9245
# Batch-60 : CrossEntropyLoss=2.2703 | MulticlassF1Score=0.9237
# Batch-75 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9239
# Batch-90 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9242
# Batch-105: CrossEntropyLoss=2.2724 | MulticlassF1Score=0.9238
# Batch-120: CrossEntropyLoss=2.2713 | MulticlassF1Score=0.9235
# Batch-135: CrossEntropyLoss=2.2767 | MulticlassF1Score=0.9230
# Batch-150: CrossEntropyLoss=2.2717 | MulticlassF1Score=0.9233
# Batch-165: CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9255
# Batch-180: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9269
# Batch-195: CrossEntropyLoss=2.2622 | MulticlassF1Score=0.9276
# Batch-210: CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9287
# Batch-225: CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9294
# Batch-226: CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9294
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2741 | MulticlassF1Score=0.9237
# Batch-30 : CrossEntropyLoss=2.2753 | MulticlassF1Score=0.9239
# Batch-45 : CrossEntropyLoss=2.2823 | MulticlassF1Score=0.9252
# Batch-60 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9247
# Batch-63 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9253
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2695 | Mean MulticlassF1Score = 0.9246
# Validation : Mean CrossEntropyLoss = 2.2708 | Mean MulticlassF1Score = 0.9244
# ================================================================================
#
# EPOCH-20
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9458
# Batch-30 : CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9453
# Batch-45 : CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9452
# Batch-60 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9449
# Batch-75 : CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9443
# Batch-90 : CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9441
# Batch-105: CrossEntropyLoss=2.2648 | MulticlassF1Score=0.9442
# Batch-120: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9442
# Batch-135: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9438
# Batch-150: CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9444
# Batch-165: CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9445
# Batch-180: CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9443
# Batch-195: CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9440
# Batch-210: CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9439
# Batch-225: CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9437
# Batch-226: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9438
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2732 | MulticlassF1Score=0.9198
# Batch-30 : CrossEntropyLoss=2.2743 | MulticlassF1Score=0.9224
# Batch-45 : CrossEntropyLoss=2.2756 | MulticlassF1Score=0.9251
# Batch-60 : CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9257
# Batch-63 : CrossEntropyLoss=2.2691 | MulticlassF1Score=0.9258
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2651 | Mean MulticlassF1Score = 0.9443
# Validation : Mean CrossEntropyLoss = 2.2706 | Mean MulticlassF1Score = 0.9237
# ================================================================================
#
# EPOCH-21
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9431
# Batch-30 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9415
# Batch-45 : CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9440
# Batch-60 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9441
# Batch-75 : CrossEntropyLoss=2.2622 | MulticlassF1Score=0.9444
# Batch-90 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9446
# Batch-105: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9441
# Batch-120: CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9443
# Batch-135: CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9444
# Batch-150: CrossEntropyLoss=2.2630 | MulticlassF1Score=0.9440
# Batch-165: CrossEntropyLoss=2.2589 | MulticlassF1Score=0.9444
# Batch-180: CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9441
# Batch-195: CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9445
# Batch-210: CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9443
# Batch-225: CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9443
# Batch-226: CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9443
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9274
# Batch-30 : CrossEntropyLoss=2.2669 | MulticlassF1Score=0.9279
# Batch-45 : CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9279
# Batch-60 : CrossEntropyLoss=2.2695 | MulticlassF1Score=0.9266
# Batch-63 : CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9262
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2649 | Mean MulticlassF1Score = 0.9442
# Validation : Mean CrossEntropyLoss = 2.2704 | Mean MulticlassF1Score = 0.9265
# ================================================================================
#
# EPOCH-22
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2673 | MulticlassF1Score=0.9431
# Batch-30 : CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9431
# Batch-45 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9431
# Batch-60 : CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9429
# Batch-75 : CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9431
# Batch-90 : CrossEntropyLoss=2.2660 | MulticlassF1Score=0.9433
# Batch-105: CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9443
# Batch-120: CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9445
# Batch-135: CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9443
# Batch-150: CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9443
# Batch-165: CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9443
# Batch-180: CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9445
# Batch-195: CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9444
# Batch-210: CrossEntropyLoss=2.2612 | MulticlassF1Score=0.9444
# Batch-225: CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9446
# Batch-226: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9446
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2740 | MulticlassF1Score=0.9286
# Batch-30 : CrossEntropyLoss=2.2739 | MulticlassF1Score=0.9288
# Batch-45 : CrossEntropyLoss=2.2672 | MulticlassF1Score=0.9284
# Batch-60 : CrossEntropyLoss=2.2753 | MulticlassF1Score=0.9277
# Batch-63 : CrossEntropyLoss=2.2676 | MulticlassF1Score=0.9275
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2647 | Mean MulticlassF1Score = 0.9439
# Validation : Mean CrossEntropyLoss = 2.2700 | Mean MulticlassF1Score = 0.9297
# ================================================================================
#
# EPOCH-23
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9487
# Batch-30 : CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9481
# Batch-45 : CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9485
# Batch-60 : CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9490
# Batch-75 : CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9481
# Batch-90 : CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9485
# Batch-105: CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9488
# Batch-120: CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9491
# Batch-135: CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9488
# Batch-150: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9489
# Batch-165: CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9490
# Batch-180: CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9490
# Batch-195: CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9488
# Batch-210: CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9487
# Batch-225: CrossEntropyLoss=2.2597 | MulticlassF1Score=0.9489
# Batch-226: CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9489
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9321
# Batch-30 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9321
# Batch-45 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9312
# Batch-60 : CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9298
# Batch-63 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9301
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2634 | Mean MulticlassF1Score = 0.9485
# Validation : Mean CrossEntropyLoss = 2.2693 | Mean MulticlassF1Score = 0.9313
# ================================================================================
#
# EPOCH-24
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2698 | MulticlassF1Score=0.9492
# Batch-30 : CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9498
# Batch-45 : CrossEntropyLoss=2.2651 | MulticlassF1Score=0.9500
# Batch-60 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9509
# Batch-75 : CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9514
# Batch-90 : CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9513
# Batch-105: CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9513
# Batch-120: CrossEntropyLoss=2.2689 | MulticlassF1Score=0.9513
# Batch-135: CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9510
# Batch-150: CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9511
# Batch-165: CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9514
# Batch-180: CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9513
# Batch-195: CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9512
# Batch-210: CrossEntropyLoss=2.2635 | MulticlassF1Score=0.9512
# Batch-225: CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9511
# Batch-226: CrossEntropyLoss=2.2658 | MulticlassF1Score=0.9511
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9348
# Batch-30 : CrossEntropyLoss=2.2712 | MulticlassF1Score=0.9310
# Batch-45 : CrossEntropyLoss=2.2674 | MulticlassF1Score=0.9318
# Batch-60 : CrossEntropyLoss=2.2745 | MulticlassF1Score=0.9312
# Batch-63 : CrossEntropyLoss=2.2664 | MulticlassF1Score=0.9315
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2627 | Mean MulticlassF1Score = 0.9510
# Validation : Mean CrossEntropyLoss = 2.2689 | Mean MulticlassF1Score = 0.9319
# ================================================================================
#
# EPOCH-25
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9505
# Batch-30 : CrossEntropyLoss=2.2680 | MulticlassF1Score=0.9519
# Batch-45 : CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9511
# Batch-60 : CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9518
# Batch-75 : CrossEntropyLoss=2.2612 | MulticlassF1Score=0.9523
# Batch-90 : CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9524
# Batch-105: CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9524
# Batch-120: CrossEntropyLoss=2.2632 | MulticlassF1Score=0.9526
# Batch-135: CrossEntropyLoss=2.2650 | MulticlassF1Score=0.9527
# Batch-150: CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9527
# Batch-165: CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9530
# Batch-180: CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9529
# Batch-195: CrossEntropyLoss=2.2622 | MulticlassF1Score=0.9530
# Batch-210: CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9529
# Batch-225: CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9528
# Batch-226: CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9528
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9317
# Batch-30 : CrossEntropyLoss=2.2757 | MulticlassF1Score=0.9306
# Batch-45 : CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9320
# Batch-60 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9324
# Batch-63 : CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9325
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2622 | Mean MulticlassF1Score = 0.9524
# Validation : Mean CrossEntropyLoss = 2.2684 | Mean MulticlassF1Score = 0.9313
# ================================================================================
#
# EPOCH-26
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9558
# Batch-30 : CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9543
# Batch-45 : CrossEntropyLoss=2.2612 | MulticlassF1Score=0.9541
# Batch-60 : CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9540
# Batch-75 : CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9547
# Batch-90 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9542
# Batch-105: CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9547
# Batch-120: CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9545
# Batch-135: CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9545
# Batch-150: CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9548
# Batch-165: CrossEntropyLoss=2.2655 | MulticlassF1Score=0.9546
# Batch-180: CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9543
# Batch-195: CrossEntropyLoss=2.2600 | MulticlassF1Score=0.9544
# Batch-210: CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9546
# Batch-225: CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9545
# Batch-226: CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9545
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9306
# Batch-30 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9348
# Batch-45 : CrossEntropyLoss=2.2693 | MulticlassF1Score=0.9323
# Batch-60 : CrossEntropyLoss=2.2751 | MulticlassF1Score=0.9331
# Batch-63 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9327
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2616 | Mean MulticlassF1Score = 0.9545
# Validation : Mean CrossEntropyLoss = 2.2683 | Mean MulticlassF1Score = 0.9327
# ================================================================================
#
# EPOCH-27
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2622 | MulticlassF1Score=0.9539
# Batch-30 : CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9555
# Batch-45 : CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9555
# Batch-60 : CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9556
# Batch-75 : CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9549
# Batch-90 : CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9549
# Batch-105: CrossEntropyLoss=2.2637 | MulticlassF1Score=0.9553
# Batch-120: CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9557
# Batch-135: CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9559
# Batch-150: CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9558
# Batch-165: CrossEntropyLoss=2.2640 | MulticlassF1Score=0.9558
# Batch-180: CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9560
# Batch-195: CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9560
# Batch-210: CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9560
# Batch-225: CrossEntropyLoss=2.2628 | MulticlassF1Score=0.9563
# Batch-226: CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9563
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2700 | MulticlassF1Score=0.9366
# Batch-30 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9378
# Batch-45 : CrossEntropyLoss=2.2662 | MulticlassF1Score=0.9369
# Batch-60 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9364
# Batch-63 : CrossEntropyLoss=2.2690 | MulticlassF1Score=0.9368
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2611 | Mean MulticlassF1Score = 0.9554
# Validation : Mean CrossEntropyLoss = 2.2672 | Mean MulticlassF1Score = 0.9370
# ================================================================================
#
# EPOCH-28
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2638 | MulticlassF1Score=0.9583
# Batch-30 : CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9590
# Batch-45 : CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9590
# Batch-60 : CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9591
# Batch-75 : CrossEntropyLoss=2.2589 | MulticlassF1Score=0.9587
# Batch-90 : CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9588
# Batch-105: CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9591
# Batch-120: CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9589
# Batch-135: CrossEntropyLoss=2.2620 | MulticlassF1Score=0.9592
# Batch-150: CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9592
# Batch-165: CrossEntropyLoss=2.2581 | MulticlassF1Score=0.9592
# Batch-180: CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9593
# Batch-195: CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9594
# Batch-210: CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9594
# Batch-225: CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9594
# Batch-226: CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9594
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9351
# Batch-30 : CrossEntropyLoss=2.2671 | MulticlassF1Score=0.9350
# Batch-45 : CrossEntropyLoss=2.2643 | MulticlassF1Score=0.9356
# Batch-60 : CrossEntropyLoss=2.2665 | MulticlassF1Score=0.9361
# Batch-63 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9361
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2601 | Mean MulticlassF1Score = 0.9590
# Validation : Mean CrossEntropyLoss = 2.2675 | Mean MulticlassF1Score = 0.9340
# ================================================================================
#
# EPOCH-29
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2618 | MulticlassF1Score=0.9576
# Batch-30 : CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9581
# Batch-45 : CrossEntropyLoss=2.2646 | MulticlassF1Score=0.9580
# Batch-60 : CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9592
# Batch-75 : CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9592
# Batch-90 : CrossEntropyLoss=2.2562 | MulticlassF1Score=0.9592
# Batch-105: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9594
# Batch-120: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9597
# Batch-135: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9598
# Batch-150: CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9599
# Batch-165: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9602
# Batch-180: CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9600
# ...
# Batch-45 : CrossEntropyLoss=2.2675 | MulticlassF1Score=0.9391
# Batch-60 : CrossEntropyLoss=2.2752 | MulticlassF1Score=0.9371
# Batch-63 : CrossEntropyLoss=2.2649 | MulticlassF1Score=0.9370
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2589 | Mean MulticlassF1Score = 0.9637
# Validation : Mean CrossEntropyLoss = 2.2670 | Mean MulticlassF1Score = 0.9385
# ================================================================================
#
# EPOCH-42
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9617
# Batch-30 : CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9636
# Batch-45 : CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9633
# Batch-60 : CrossEntropyLoss=2.2550 | MulticlassF1Score=0.9637
# Batch-75 : CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9638
# Batch-90 : CrossEntropyLoss=2.2561 | MulticlassF1Score=0.9638
# Batch-105: CrossEntropyLoss=2.2560 | MulticlassF1Score=0.9640
# Batch-120: CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9636
# Batch-135: CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9637
# Batch-150: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9635
# Batch-165: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9635
# Batch-180: CrossEntropyLoss=2.2577 | MulticlassF1Score=0.9634
# Batch-195: CrossEntropyLoss=2.2636 | MulticlassF1Score=0.9634
# Batch-210: CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9633
# Batch-225: CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9632
# Batch-226: CrossEntropyLoss=2.2629 | MulticlassF1Score=0.9631
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9367
# Batch-30 : CrossEntropyLoss=2.2696 | MulticlassF1Score=0.9372
# Batch-45 : CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9378
# Batch-60 : CrossEntropyLoss=2.2697 | MulticlassF1Score=0.9370
# Batch-63 : CrossEntropyLoss=2.2702 | MulticlassF1Score=0.9369
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2588 | Mean MulticlassF1Score = 0.9635
# Validation : Mean CrossEntropyLoss = 2.2670 | Mean MulticlassF1Score = 0.9365
# ================================================================================
#
# EPOCH-43
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9605
# Batch-30 : CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9614
# Batch-45 : CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9608
# Batch-60 : CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9618
# Batch-75 : CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9612
# Batch-90 : CrossEntropyLoss=2.2586 | MulticlassF1Score=0.9618
# Batch-105: CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9620
# Batch-120: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9620
# Batch-135: CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9622
# Batch-150: CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9622
# Batch-165: CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9622
# Batch-180: CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9625
# Batch-195: CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9627
# Batch-210: CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9627
# Batch-225: CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9627
# Batch-226: CrossEntropyLoss=2.2687 | MulticlassF1Score=0.9626
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9349
# Batch-30 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9342
# Batch-45 : CrossEntropyLoss=2.2659 | MulticlassF1Score=0.9349
# Batch-60 : CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9368
# Batch-63 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9368
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2590 | Mean MulticlassF1Score = 0.9619
# Validation : Mean CrossEntropyLoss = 2.2670 | Mean MulticlassF1Score = 0.9333
# Patience = 4/50❗
# ================================================================================
#
# EPOCH-44
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9619
# Batch-30 : CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9620
# Batch-45 : CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9620
# Batch-60 : CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9627
# Batch-75 : CrossEntropyLoss=2.2606 | MulticlassF1Score=0.9628
# Batch-90 : CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9632
# Batch-105: CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9628
# Batch-120: CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9625
# Batch-135: CrossEntropyLoss=2.2599 | MulticlassF1Score=0.9627
# Batch-150: CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9631
# Batch-165: CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9629
# Batch-180: CrossEntropyLoss=2.2596 | MulticlassF1Score=0.9631
# Batch-195: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9629
# Batch-210: CrossEntropyLoss=2.2578 | MulticlassF1Score=0.9628
# Batch-225: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9627
# Batch-226: CrossEntropyLoss=2.2621 | MulticlassF1Score=0.9627
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2711 | MulticlassF1Score=0.9414
# Batch-30 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9384
# Batch-45 : CrossEntropyLoss=2.2678 | MulticlassF1Score=0.9386
# Batch-60 : CrossEntropyLoss=2.2721 | MulticlassF1Score=0.9376
# Batch-63 : CrossEntropyLoss=2.2670 | MulticlassF1Score=0.9375
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2590 | Mean MulticlassF1Score = 0.9627
# Validation : Mean CrossEntropyLoss = 2.2669 | Mean MulticlassF1Score = 0.9386
# ================================================================================
#
# EPOCH-45
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2588 | MulticlassF1Score=0.9637
# Batch-30 : CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9645
# Batch-45 : CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9645
# Batch-60 : CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9631
# Batch-75 : CrossEntropyLoss=2.2624 | MulticlassF1Score=0.9609
# Batch-90 : CrossEntropyLoss=2.2633 | MulticlassF1Score=0.9600
# Batch-105: CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9590
# Batch-120: CrossEntropyLoss=2.2615 | MulticlassF1Score=0.9584
# Batch-135: CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9579
# Batch-150: CrossEntropyLoss=2.2592 | MulticlassF1Score=0.9578
# Batch-165: CrossEntropyLoss=2.2610 | MulticlassF1Score=0.9578
# Batch-180: CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9577
# Batch-195: CrossEntropyLoss=2.2584 | MulticlassF1Score=0.9573
# Batch-210: CrossEntropyLoss=2.2597 | MulticlassF1Score=0.9573
# Batch-225: CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9572
# Batch-226: CrossEntropyLoss=2.2604 | MulticlassF1Score=0.9572
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2666 | MulticlassF1Score=0.9325
# Batch-30 : CrossEntropyLoss=2.2684 | MulticlassF1Score=0.9339
# Batch-45 : CrossEntropyLoss=2.2614 | MulticlassF1Score=0.9350
# Batch-60 : CrossEntropyLoss=2.2652 | MulticlassF1Score=0.9353
# Batch-63 : CrossEntropyLoss=2.2642 | MulticlassF1Score=0.9356
#
# Huft 😥! Model not improved.
#
# Training   : Mean CrossEntropyLoss = 2.2608 | Mean MulticlassF1Score = 0.9598
# Validation : Mean CrossEntropyLoss = 2.2675 | Mean MulticlassF1Score = 0.9336
# Patience = 5/50❗
# ================================================================================
#
# EPOCH-46
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2603 | MulticlassF1Score=0.9604
# Batch-30 : CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9595
# Batch-45 : CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9591
# Batch-60 : CrossEntropyLoss=2.2613 | MulticlassF1Score=0.9590
# Batch-75 : CrossEntropyLoss=2.2616 | MulticlassF1Score=0.9595
# Batch-90 : CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9596
# Batch-105: CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9595
# Batch-120: CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9597
# Batch-135: CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9600
# Batch-150: CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9602
# Batch-165: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9602
# Batch-180: CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9604
# Batch-195: CrossEntropyLoss=2.2598 | MulticlassF1Score=0.9606
# Batch-210: CrossEntropyLoss=2.2609 | MulticlassF1Score=0.9605
# Batch-225: CrossEntropyLoss=2.2569 | MulticlassF1Score=0.9607
# Batch-226: CrossEntropyLoss=2.2591 | MulticlassF1Score=0.9607
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2631 | MulticlassF1Score=0.9387
# Batch-30 : CrossEntropyLoss=2.2663 | MulticlassF1Score=0.9369
# Batch-45 : CrossEntropyLoss=2.2667 | MulticlassF1Score=0.9373
# Batch-60 : CrossEntropyLoss=2.2699 | MulticlassF1Score=0.9374
# Batch-63 : CrossEntropyLoss=2.2654 | MulticlassF1Score=0.9372
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2597 | Mean MulticlassF1Score = 0.9599
# Validation : Mean CrossEntropyLoss = 2.2669 | Mean MulticlassF1Score = 0.9372
# ================================================================================
#
# EPOCH-47
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2568 | MulticlassF1Score=0.9626
# Batch-30 : CrossEntropyLoss=2.2619 | MulticlassF1Score=0.9632
# Batch-45 : CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9631
# Batch-60 : CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9634
# Batch-75 : CrossEntropyLoss=2.2645 | MulticlassF1Score=0.9637
# Batch-90 : CrossEntropyLoss=2.2552 | MulticlassF1Score=0.9632
# Batch-105: CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9634
# Batch-120: CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9637
# Batch-135: CrossEntropyLoss=2.2579 | MulticlassF1Score=0.9638
# Batch-150: CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9637
# Batch-165: CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9634
# Batch-180: CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9632
# Batch-195: CrossEntropyLoss=2.2595 | MulticlassF1Score=0.9631
# Batch-210: CrossEntropyLoss=2.2585 | MulticlassF1Score=0.9632
# Batch-225: CrossEntropyLoss=2.2603 | MulticlassF1Score=0.9630
# Batch-226: CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9630
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2706 | MulticlassF1Score=0.9365
# Batch-30 : CrossEntropyLoss=2.2668 | MulticlassF1Score=0.9350
# Batch-45 : CrossEntropyLoss=2.2661 | MulticlassF1Score=0.9361
# Batch-60 : CrossEntropyLoss=2.2626 | MulticlassF1Score=0.9371
# Batch-63 : CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9376
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2589 | Mean MulticlassF1Score = 0.9631
# Validation : Mean CrossEntropyLoss = 2.2668 | Mean MulticlassF1Score = 0.9373
# ================================================================================
#
# EPOCH-48
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9622
# Batch-30 : CrossEntropyLoss=2.2559 | MulticlassF1Score=0.9633
# Batch-45 : CrossEntropyLoss=2.2554 | MulticlassF1Score=0.9642
# Batch-60 : CrossEntropyLoss=2.2553 | MulticlassF1Score=0.9652
# Batch-75 : CrossEntropyLoss=2.2565 | MulticlassF1Score=0.9649
# Batch-90 : CrossEntropyLoss=2.2558 | MulticlassF1Score=0.9649
# Batch-105: CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9646
# Batch-120: CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9643
# Batch-135: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9644
# Batch-150: CrossEntropyLoss=2.2542 | MulticlassF1Score=0.9642
# Batch-165: CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9643
# Batch-180: CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9643
# Batch-195: CrossEntropyLoss=2.2555 | MulticlassF1Score=0.9643
# Batch-210: CrossEntropyLoss=2.2607 | MulticlassF1Score=0.9640
# Batch-225: CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9640
# Batch-226: CrossEntropyLoss=2.2539 | MulticlassF1Score=0.9641
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2704 | MulticlassF1Score=0.9379
# Batch-30 : CrossEntropyLoss=2.2657 | MulticlassF1Score=0.9377
# Batch-45 : CrossEntropyLoss=2.2679 | MulticlassF1Score=0.9377
# Batch-60 : CrossEntropyLoss=2.2639 | MulticlassF1Score=0.9372
# Batch-63 : CrossEntropyLoss=2.2683 | MulticlassF1Score=0.9372
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2585 | Mean MulticlassF1Score = 0.9641
# Validation : Mean CrossEntropyLoss = 2.2669 | Mean MulticlassF1Score = 0.9384
# ================================================================================
#
# EPOCH-49
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9660
# Batch-30 : CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9671
# Batch-45 : CrossEntropyLoss=2.2625 | MulticlassF1Score=0.9671
# Batch-60 : CrossEntropyLoss=2.2575 | MulticlassF1Score=0.9664
# Batch-75 : CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9654
# Batch-90 : CrossEntropyLoss=2.2537 | MulticlassF1Score=0.9656
# Batch-105: CrossEntropyLoss=2.2545 | MulticlassF1Score=0.9655
# Batch-120: CrossEntropyLoss=2.2590 | MulticlassF1Score=0.9654
# Batch-135: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9652
# Batch-150: CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9650
# Batch-165: CrossEntropyLoss=2.2601 | MulticlassF1Score=0.9650
# Batch-180: CrossEntropyLoss=2.2580 | MulticlassF1Score=0.9651
# Batch-195: CrossEntropyLoss=2.2566 | MulticlassF1Score=0.9651
# Batch-210: CrossEntropyLoss=2.2594 | MulticlassF1Score=0.9648
# Batch-225: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9648
# Batch-226: CrossEntropyLoss=2.2564 | MulticlassF1Score=0.9648
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2720 | MulticlassF1Score=0.9340
# Batch-30 : CrossEntropyLoss=2.2623 | MulticlassF1Score=0.9378
# Batch-45 : CrossEntropyLoss=2.2677 | MulticlassF1Score=0.9379
# Batch-60 : CrossEntropyLoss=2.2641 | MulticlassF1Score=0.9372
# Batch-63 : CrossEntropyLoss=2.2681 | MulticlassF1Score=0.9371
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2582 | Mean MulticlassF1Score = 0.9656
# Validation : Mean CrossEntropyLoss = 2.2669 | Mean MulticlassF1Score = 0.9359
# ================================================================================
#
# EPOCH-50
# Training Step
#   0%|          | 0/226 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9656
# Batch-30 : CrossEntropyLoss=2.2557 | MulticlassF1Score=0.9648
# Batch-45 : CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9644
# Batch-60 : CrossEntropyLoss=2.2593 | MulticlassF1Score=0.9646
# Batch-75 : CrossEntropyLoss=2.2572 | MulticlassF1Score=0.9647
# Batch-90 : CrossEntropyLoss=2.2644 | MulticlassF1Score=0.9647
# Batch-105: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9649
# Batch-120: CrossEntropyLoss=2.2583 | MulticlassF1Score=0.9648
# Batch-135: CrossEntropyLoss=2.2602 | MulticlassF1Score=0.9651
# Batch-150: CrossEntropyLoss=2.2587 | MulticlassF1Score=0.9650
# Batch-165: CrossEntropyLoss=2.2582 | MulticlassF1Score=0.9650
# Batch-180: CrossEntropyLoss=2.2617 | MulticlassF1Score=0.9651
# Batch-195: CrossEntropyLoss=2.2608 | MulticlassF1Score=0.9653
# Batch-210: CrossEntropyLoss=2.2605 | MulticlassF1Score=0.9651
# Batch-225: CrossEntropyLoss=2.2571 | MulticlassF1Score=0.9653
# Batch-226: CrossEntropyLoss=2.2573 | MulticlassF1Score=0.9653
#
# Validation Step
#   0%|          | 0/63 [00:00<?, ?it/s]
# Batch-15 : CrossEntropyLoss=2.2692 | MulticlassF1Score=0.9370
# Batch-30 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9364
# Batch-45 : CrossEntropyLoss=2.2688 | MulticlassF1Score=0.9366
# Batch-60 : CrossEntropyLoss=2.2653 | MulticlassF1Score=0.9373
# Batch-63 : CrossEntropyLoss=2.2647 | MulticlassF1Score=0.9376
#
# Yeah 🎉😄! Model improved.
#
# Training   : Mean CrossEntropyLoss = 2.2581 | Mean MulticlassF1Score = 0.9650
# Validation : Mean CrossEntropyLoss = 2.2668 | Mean MulticlassF1Score = 0.9377
# ================================================================================
#
# TRAINING SUMMARY
# Best CrossEntropyLoss training    : 2.2581
# Best CrossEntropyLoss training    : 2.2668
# Best MulticlassF1Score validation : 0.9650
# Best MulticlassF1Score validation : 0.9377
# Training duration                 : 1.9770 minutes.
# Training date                     : 2022-10-24 18:46:08.801322+08:00

# %% [markdown]
# ## End Training

# %% [markdown]
# # Evaluation

# %%
def evaluation(dataloader, model, criterion, metric):
    model.eval()
    
    with torch.inference_mode():
        for batch, (feature, actual_label) in enumerate(tqdm(dataloader), 1):
            # Forward Propagation
            feature = rearrange(feature, "n s -> s n")
            actual_label = rearrange(actual_label, "n s -> s n")
            embedding = word_embeddings(feature)

            prob = model(
                embedding.to(hyperparams.device),
                actual_label.to(hyperparams.device)
            )

            prob = prob.reshape(-1, prob.shape[-1])
            actual_label = actual_label.reshape(-1)
            pred = rearrange(prob.argmax(dim=1).reshape(feature.shape[0], len(dataloader.dataset)), "s n -> n s")

            loss = criterion(prob, actual_label.to(hyperparams.device))
            metric_score = metric(prob.argmax(dim=1), actual_label.to(hyperparams.device))
            metric_score = metric.compute()

    return loss, metric_score, pred

train_dataloader = DataLoader(train_dataset, batch_size=len(train_dataset))
val_dataloader = DataLoader(val_dataset, batch_size=len(val_dataset))
test_dataloader = DataLoader(test_dataset, batch_size=len(test_dataset))

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
train_loss, train_f1_score, train_pred_label = evaluation(train_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
val_loss, val_f1_score, val_pred_label = evaluation(val_dataloader, model, criterion, metric)

criterion = nn.CrossEntropyLoss().to(hyperparams.device)
metric = MulticlassF1Score(average="micro", num_classes=24, mdmc_average="samplewise", multiclass=True, ignore_index=label_to_idx["<PAD>"]).to(hyperparams.device)
test_loss, test_f1_score, test_pred_label = evaluation(test_dataloader, model, criterion, metric)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9656, device='cuda:0'),
#  tensor(0.9376, device='cuda:0'),
#  tensor(0.9385, device='cuda:0'))

# %%
train_f1_score, val_f1_score, test_f1_score
# Out:
# (tensor(0.9656, device='cuda:0'),
#  tensor(0.9376, device='cuda:0'),
#  tensor(0.9385, device='cuda:0'))

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns

def viz_evaluation(pred_label, actual_label, title):
    plt.figure(figsize=(15, 7), dpi=200)
    sns.heatmap(pred_label.detach().cpu() == actual_label, cbar=True, cmap="binary_r")
    plt.xlabel("Sentence Length")
    plt.ylabel("Sentence")
    plt.title(title)
    plt.savefig(f"{root_path}/heatmap_{title.lower()}.jpg", dpi=200)
    plt.show()

train_actual_label = train_dataloader.dataset.tensors[1]
val_actual_label = val_dataloader.dataset.tensors[1]
test_actual_label = test_dataloader.dataset.tensors[1]

viz_evaluation(train_pred_label, train_actual_label, f"Training (F1-Score: {(train_f1_score):.4f})")
viz_evaluation(val_pred_label, val_actual_label, f"Validation (F1-Score: {(val_f1_score):.4f})")
viz_evaluation(test_pred_label, test_actual_label, f"Test (F1-Score: {(test_f1_score):.4f})")

# %% [markdown]
# ## Confusion Matrix

# %%
def confusion_matrix(pred_class, actual_class, title, normalize=None):
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize=normalize)
    plt.figure(figsize=(20, 10), dpi=200)
    sns.heatmap(conf_mat(pred_class.detach().cpu(), actual_class), annot=True, fmt=".2g", xticklabels=list(label_to_idx.keys()), yticklabels=list(label_to_idx.keys()));
    plt.yticks(rotation=0)
    plt.title(title)
    plt.xlabel("Actual Class")
    plt.ylabel("Predict Class")
    plt.savefig(f"{root_path}/conf_matrix_{title.lower()}.jpg", dpi=200)

confusion_matrix(train_pred_label, train_actual_label, "Training", "pred")
confusion_matrix(val_pred_label,val_actual_label, "Validation", "pred")
confusion_matrix(test_pred_label, test_actual_label, "Test", "pred")
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: 144 NaN values found in confusion matrix have been replaced with zeros.
#   warnings.warn(*args, **kwargs)

# %% [markdown]
# ## Prediction Table

# %%
def number_wrong_pred_each_class(pred_class, actual_class):
    classes, count_class = actual_class.flatten().unique(return_counts=True)
    conf_mat = MulticlassConfusionMatrix(num_classes=24, normalize="none")
    correct_pred_count_class = conf_mat(pred_class.detach().cpu(), actual_class).diag()
    
    correct_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (correct_pred_count_class))}
    wrong_pred = {idx_to_label[label.item()]: count.item() for label, count in zip(classes, (count_class - correct_pred_count_class))}
    
    return correct_pred, wrong_pred

correct_pred, wrong_pred = number_wrong_pred_each_class(train_pred_label, train_actual_label)
print(f"| {'Number class'.ljust(14)} | {'Correct prediction'.ljust(12)} | {'Wrong prediction'.ljust(12)} |")
for (label_correct_pred, count_correct_pred), (label_wrong_pred, count_wrong_pred) in zip(correct_pred.items(), wrong_pred.items()):
    print(f"| {str(label_correct_pred).ljust(6)}: {str(count_correct_pred + count_wrong_pred).ljust(7)}| {label_correct_pred.ljust(6)}: {str(count_correct_pred).ljust(10)} | {label_wrong_pred.ljust(6)}: {str(count_wrong_pred).ljust(8)} |")
# Out:
# | Number class   | Correct prediction | Wrong prediction |
# | CC    : 5336   | CC    : 5210       | CC    : 126      |
# | CD    : 12904  | CD    : 12734      | CD    : 170      |
# | DT    : 263    | DT    : 0          | DT    : 263      |
# | FW    : 1697   | FW    : 1409       | FW    : 288      |
# | IN    : 15290  | IN    : 15154      | IN    : 136      |
# | JJ    : 7049   | JJ    : 6513       | JJ    : 536      |
# | MD    : 3783   | MD    : 3737       | MD    : 46       |
# | NEG   : 1126   | NEG   : 0          | NEG   : 1126     |
# | NN    : 44769  | NN    : 44043      | NN    : 726      |
# | NND   : 998    | NND   : 520        | NND   : 478      |
# | NNP   : 24884  | NNP   : 24183      | NNP   : 701      |
# | OD    : 550    | OD    : 527        | OD    : 23       |
# | PR    : 3878   | PR    : 3816       | PR    : 62       |
# | PRP   : 5355   | PRP   : 5205       | PRP   : 150      |
# | RB    : 3517   | RB    : 3241       | RB    : 276      |
# | RP    : 131    | RP    : 0          | RP    : 131      |
# | SC    : 9467   | SC    : 9197       | SC    : 270      |
# | SYM   : 1570   | SYM   : 1515       | SYM   : 55       |
# | UH    : 21     | UH    : 0          | UH    : 21       |
# | VB    : 22796  | VB    : 22514      | VB    : 282      |
# | WH    : 180    | WH    : 0          | WH    : 180      |
# | X     : 282    | X     : 0          | X     : 282      |
# | Z     : 18940  | Z     : 18908      | Z     : 32       |
# | <PAD> : 407418 | <PAD> : 407418     | <PAD> : 0        |

# %%
train_actual_label[308], train_pred_label[308]
# Out:
# (tensor([ 8, 19, 22, 10, 22, 19, 10,  6, 19,  4,  1,  8, 16, 19,  8, 19,  0,  8,
#           5, 16, 19, 19,  8,  8, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23]),
#  tensor([ 8, 19, 22, 10, 22, 19, 10,  6, 19,  4,  1,  8, 16, 19,  8, 19,  0,  8,
#           5, 16, 19, 19,  8,  8, 22, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23,
#          23, 23, 23, 23, 23, 23, 23, 23, 23, 23], device='cuda:0'))

# %%
train_actual_label[308].detach().cpu() == train_pred_label[308].detach().cpu()
# Out:
# tensor([True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True])

# %% [markdown]
# ## OOV prediction is correct

# %%
def oov_flag_token(sentences, max_seq_len=hyperparams.max_seq_len):
    sent_copy = deepcopy(sentences)
    sent = []
    oov_flag = []
    
    for sentence in tqdm(sent_copy):
        for token in sentence:
            sent.append(token[2])
        
        for _ in range(max_seq_len- len(sentence)):
            sent.append(False)
        
        oov_flag.append(sent)
        sent = []
        
    return np.array(oov_flag)

train_oov_flag = oov_flag_token(train_sentences, max_seq_len=hyperparams.max_seq_len)
val_oov_flag = oov_flag_token(val_sentences, max_seq_len=hyperparams.max_seq_len)
test_oov_flag = oov_flag_token(test_sentences, max_seq_len=hyperparams.max_seq_len)

def pencentage_oov_pred_correct(pred_oov_flag, oov_flag_tensor):
    oov_correct_counter = 0
    oov_wrong_counter = 0

    for pred, oov_label in tqdm(zip(pred_oov_flag, oov_flag_tensor)):
        if pred == True and oov_label == True:
            oov_correct_counter += 1
        elif pred == False and oov_label == True:
            oov_wrong_counter += 1
        else:
            continue
            
    return oov_correct_counter, oov_wrong_counter

train_pred_oov_flag = (train_actual_label == train_pred_label.detach().cpu()).flatten()
val_pred_oov_flag = (val_actual_label == val_pred_label.detach().cpu()).flatten()
test_pred_oov_flag = (test_actual_label == test_pred_label.detach().cpu()).flatten()
train_oov_flag_tensor = torch.tensor(train_oov_flag).flatten()
val_oov_flag_tensor = torch.tensor(val_oov_flag).flatten()
test_oov_flag_tensor = torch.tensor(test_oov_flag).flatten()

train_oov_correct_counter, train_oov_wrong_counter = pencentage_oov_pred_correct(train_pred_oov_flag, train_oov_flag_tensor)
val_oov_correct_counter, val_oov_wrong_counter = pencentage_oov_pred_correct(val_pred_oov_flag, val_oov_flag_tensor)
test_oov_correct_counter, test_oov_wrong_counter = pencentage_oov_pred_correct(test_pred_oov_flag, test_oov_flag_tensor)
# Out:
#   0%|          | 0/7222 [00:00<?, ?it/s]
#   0%|          | 0/2006 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
def print_percentage_pred_oov(title, oov_correct_counter, oov_wrong_counter):
    print(f"{title}")
    print(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}")
    print(f"Correct prediction          : {oov_correct_counter}")
    print(f"Wrong prediction            : {oov_wrong_counter}")
    print(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n")
    
    with open(f"{root_path}/oov_summary.txt", "a") as f:
        f.write(f"{title}\n")
        f.write(f"Number OOV token            : {oov_correct_counter + oov_wrong_counter}\n")
        f.write(f"Correct prediction          : {oov_correct_counter}\n")
        f.write(f"Wrong prediction            : {oov_wrong_counter}\n")
        f.write(f"Percentage correct oov pred : {oov_correct_counter / (oov_correct_counter + oov_wrong_counter) * 100}\n\n")

# %%
print_percentage_pred_oov("Training", train_oov_correct_counter, train_oov_wrong_counter)
print_percentage_pred_oov("Validation", val_oov_correct_counter, val_oov_wrong_counter)
print_percentage_pred_oov("Test", test_oov_correct_counter, test_oov_wrong_counter)
# Out:
# Training
# Number OOV token            : 11934
# Correct prediction          : 10401
# Wrong prediction            : 1533
# Percentage correct oov pred : 87.1543489190548
#
# Validation
# Number OOV token            : 3261
# Correct prediction          : 2363
# Wrong prediction            : 898
# Percentage correct oov pred : 72.46243483593989
#
# Test
# Number OOV token            : 1367
# Correct prediction          : 979
# Wrong prediction            : 388
# Percentage correct oov pred : 71.61667885881492

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(train_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(val_oov_flag, cmap=plt.cm.binary_r);

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(test_oov_flag, cmap=plt.cm.binary_r);
